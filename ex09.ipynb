# %% [markdown]
# # Vector embedding with `gensim`
#
# Let's make use of deep learning through a technique called *embedding* – to analyze the relatedness of the labels used for recipe ingredients.
#
# Among the most closely related ingredients:
#
#   * Some are very close synonyms and should be consolidated to improve data quality
#   * Others are interesting other ingredients that pair frequently, useful for recommendations
#
# On the one hand, this approach is quite helpful for analyzing the NLP annotations that go into a knowledge graph.
# On the other hand it can be used along with [`SKOS`](https://www.w3.org/2004/02/skos/) or similar vocabularies for ontology-based discovery within the graph, e.g., for advanced search UI.

# %% [markdown]
# ## Curating annotations
#
# We'll be working with the labels for ingredients that go into our KG.
# Looking at the raw data, there are many cases where slightly different spellings are being used for the same entity.
#
# As a first step let's define a list of synonyms to substitute, prior to running the vector embedding.
# This will help produce better quality results.
#
# Note that this kind of work comes of the general heading of *curating annotations* ... which is what we spend so much time doing in KG work.
# It's similar to how *data preparation* is ~80% of the workload for data science teams, and for good reason.

# %%
SYNONYMS = {
    "pepper": "black pepper",
    "black pepper": "black pepper",
    
    "egg": "egg",
    "eggs": "egg",

    "vanilla": "vanilla",
    "vanilla extract": "vanilla",
    
    "flour": "flour",
    "all-purpose flour": "flour",

    "onions": "onion",
    "onion": "onion",
        
    "carrots": "carrot",
    "carrot": "carrot",

    "potatoes": "potato",
    "potato": "potato",
    
    "tomatoes": "tomato",
    "fresh tomatoes": "tomato",
    "fresh tomato": "tomato",
    
    "garlic": "garlic",
    "garlic clove": "garlic",
    "garlic cloves": "garlic",
}

# %% [markdown]
# ## Analyze ingredient labels from 250K recipes

# %%
import csv

MAX_ROW = 250000 # 231638

max_context = 0
min_context = 1000

recipes = []
vocab = set()

with open("dat/all_ind.csv", "r") as f:
    reader = csv.reader(f)
    next(reader, None) # remove file header

    for i, row in enumerate(reader):
        id = row[0]
        ind_set = set()
        
        # substitute synonyms
        for ind in set(eval(row[3])):
            if ind in SYNONYMS:
                ind_set.add(SYNONYMS[ind])
            else:
                ind_set.add(ind)
        
        if len(ind_set) > 1:
            recipes.append([id, ind_set])
            vocab.update(ind_set)
        
            max_context = max(max_context, len(ind_set))
            min_context = min(min_context, len(ind_set))

        if i > MAX_ROW:
            break

print("max context: {} unique ingredients per recipe".format(max_context))
print("min context: {} unique ingredients per recipe".format(min_context))
print("vocab size", len(list(vocab)))
# Out:
# max context: 43 unique ingredients per recipe
# min context: 2 unique ingredients per recipe
# vocab size 14931

# %% [markdown]
# Since we've performed this data preparation work, let's use `pickle` to save this larger superset of the recipes dataset to the `tmp.pkl` file.
# Then we can restore it later for other use cases:

# %%
import pickle

pickle.dump(recipes, open("tmp.pkl", "wb"))

recipes
# Out:
# [['137739',
#   {'butter',
#    'honey',
#    'mexican seasoning',
#    'mixed spice',
#    'olive oil',
#    'salt',
#    'winter squash'}],
#  ['31490',
#   {'cheese',
#    'egg',
#    'milk',
#    'prepared pizza crust',
#    'salt and pepper',
#    'sausage patty'}],
#  ['112140',
#   {'cheddar cheese',
#    'chili powder',
#    'diced tomatoes',
#    'ground beef',
#    'ground cumin',
#    'kidney beans',
#    'lettuce',
#    'rotel tomatoes',
#    'salt',
#    'tomato paste',
#    'tomato soup',
#    'water',
#    'yellow onions'}],
#  ['59389',
#   {'black pepper',
#    'new potatoes',
#    'olive oil',
#    'parsley',
#    'red bell pepper',
#    'red wine vinegar',
#    'salt',
#    'shallots',
#    'spreadable cheese with garlic and herbs',
#    'tarragon',
#    'yellow bell pepper'}],
#  ['44061',
#   {'apple cider vinegar',
#    'black pepper',
#    'cinnamon oil',
#    'clove oil',
#    'dry mustard',
#    'salt',
#    'sugar',
#    'tomato juice'}],
#  ['5289',
#   {'apple', 'frozen apple juice concentrate', 'milk', 'vanilla ice cream'}],
#  ['25274',
#   {'extra virgin olive oil',
#    'fennel seeds',
#    'garlic',
#    'green olives',
#    'orange juice',
#    'orange rind',
#    'peppercorn',
#    'red chile',
#    'ripe olives'}],
#  ['67888',
#   {'a.1. original sauce',
#    'brown sugar',
#    'chili powder',
#    'cinnamon sticks',
#    'cracked black pepper',
#    'cumin',
#    'dry mustard',
#    'fresh cilantro leaves',
#    'fresh coarse ground black pepper',
#    'fresh garlic',
#    'fresh ginger',
#    'honey',
#    'liquid smoke',
#    'mirin',
#    'orange, juice of',
#    'pork spareribs',
#    'salt',
#    'soy sauce',
#    'tomato sauce',
#    'water',
#    'white vinegar',
#    'yellow onion'}],
#  ['70971',
#   {'bananas',
#    'chocolate sandwich style cookies',
#    'chocolate syrup',
#    'strawberry ice cream',
#    'vanilla ice cream',
#    'whipped cream'}],
#  ['75452',
#   {'baking soda',
#    'bananas',
#    'cake flour',
#    'egg',
#    'fresh lemon juice',
#    'orange rind',
#    'salt',
#    'sugar',
#    'unsalted butter'}],
#  ['109439',
#   {'prepared horseradish', 'sour cream', 'whole berry cranberry sauce'}],
#  ['42198',
#   {'butter',
#    'egg',
#    'powdered sugar',
#    'strawberry',
#    'vanilla wafers',
#    'walnuts',
#    'whipping cream'}],
#  ['67547',
#   {'bacon',
#    'black pepper',
#    'chicken bouillon cubes',
#    'chili powder',
#    'cornstarch',
#    'dark brown sugar',
#    'garlic powder',
#    'great northern bean',
#    'molasses',
#    'mustard powder',
#    'onion',
#    'salt',
#    'water'}],
#  ['107517',
#   {'brown sugar',
#    'collard greens',
#    'ham hock',
#    'hot sauce',
#    'molasses',
#    'salt',
#    'whiskey'}],
#  ['39959',
#   {'burnet root',
#    'gentian root',
#    'scullcap herb',
#    'spearmint',
#    'wood bethony'}],
#  ['63986',
#   {'chicken rice soup',
#    'dry mustard',
#    'flour',
#    'garlic powder',
#    'lean pork chops',
#    'oil',
#    'salt'}],
#  ['43026',
#   {'cheese', 'cornstarch', 'egg roll wrap', 'oil', 'whole green chilies'}],
#  ['23933', {'butterscotch chips', 'chinese noodles', 'salted peanuts'}],
#  ['8559',
#   {'beef broth',
#    'celery',
#    'cooking oil',
#    'ground pork',
#    'hamburger buns',
#    'onion',
#    'soy sauce'}],
#  ['23850',
#   {'broccoli floret',
#    'canola oil',
#    'cauliflower',
#    'escarole',
#    'fresh herb',
#    'garlic',
#    'great northern bean',
#    'green peas',
#    'ground coriander',
#    'onion',
#    'potato',
#    'red bell pepper',
#    'salt and pepper',
#    'salt free herb and spice seasoning mix',
#    'vegetable bouillon cubes',
#    'water'}],
#  ['76808',
#   {'boiling potatoes',
#    'coarse salt',
#    'fresh ground black pepper',
#    'fresh spinach leaves',
#    'nutmeg',
#    'salt',
#    'unsalted butter',
#    'water'}],
#  ['24701',
#   {'apple juice',
#    'broth',
#    'celery',
#    'dried thyme',
#    'fresh parsley',
#    'olive oil',
#    'onion',
#    'rolled oats',
#    'salt',
#    'scallion',
#    'spinach',
#    'white pepper'}],
#  ['83873',
#   {'boneless skinless chicken breast halves',
#    'condensed cream of chicken soup',
#    'cornstarch',
#    'egg',
#    'flour',
#    'garlic powder',
#    'oil',
#    'paprika',
#    'salt and pepper',
#    'seasoning salt'}],
#  ['107699',
#   {'baking powder',
#    'bread',
#    'brown sugar',
#    'butter',
#    'egg',
#    'flour',
#    'granulated sugar',
#    'ground cinnamon',
#    'milk',
#    'powdered sugar',
#    'salt',
#    'vanilla',
#    'vegetable oil'}],
#  ['49262', {'butter', 'egg yolks', 'lemon, juice of', 'salt', 'white pepper'}],
#  ['48156',
#   {'black cumin',
#    'ground black pepper',
#    'ground coriander',
#    'ground cumin',
#    'ground ginger',
#    'ground turmeric'}],
#  ['54272',
#   {'black pepper',
#    'celery',
#    'chili powder',
#    'diced tomatoes',
#    'garlic',
#    'green pepper',
#    'jalapenos',
#    'kidney beans',
#    'onion',
#    'red pepper flakes',
#    'salt',
#    'vegetarian ground beef'}],
#  ['47366',
#   {'beef bouillon cube',
#    'beef stew meat',
#    'cabbage',
#    'dried parsley',
#    'elbow macaroni',
#    'garbanzo beans',
#    'ground pepper',
#    'ground thyme',
#    'onion',
#    'parmesan cheese',
#    'salt',
#    'tomato',
#    'water',
#    'zucchini'}],
#  ['37073', {'margarine', 'red potatoes', 'rosemary'}],
#  ['44123',
#   {'black beans',
#    'broccoli floret',
#    'broccoli stem',
#    'carrot',
#    'celery',
#    'chicken stock',
#    'cornstarch',
#    'dried oregano',
#    'dried sweet basil leaves',
#    'dried thyme',
#    'dry white wine',
#    'heavy cream',
#    'onion',
#    'salt & fresh ground pepper',
#    'smoked chicken',
#    'tabasco sauce',
#    'unsalted butter',
#    'worcestershire sauce'}],
#  ['27087',
#   {'baking cocoa',
#    'baking powder',
#    'butter',
#    'egg',
#    'flour',
#    'miniature peppermint patties',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['59952',
#   {'black pepper',
#    'cheddar cheese',
#    'cornmeal',
#    'ground beef',
#    'hot chili pepper',
#    'onion',
#    'salt',
#    'sliced ripe olives',
#    'tabasco sauce',
#    'taco sauce',
#    'tomato sauce',
#    'whole kernel corn'}],
#  ['93249', {'butter', 'dry ranch dressing mix', 'french bread'}],
#  ['54100',
#   {'black pepper',
#    'dry mustard',
#    'egg substitute',
#    'fresh breadcrumb',
#    'ground venison',
#    'non-fat powdered milk',
#    'onion',
#    'salt',
#    'water',
#    'worcestershire sauce'}],
#  ['67664', {'frozen juice concentrate', 'milk', 'plain yogurt'}],
#  ['87098',
#   {'carrot',
#    'corn',
#    'diced tomatoes',
#    'green beans',
#    'low sodium chicken broth',
#    'potato',
#    'wax beans',
#    'zucchini'}],
#  ['25775',
#   {'black pepper',
#    'condensed cream of mushroom soup',
#    'crouton',
#    'egg',
#    'frozen chopped spinach',
#    'onion',
#    'salt',
#    'sharp cheddar cheese'}],
#  ['33165',
#   {'black pepper',
#    'celery seed',
#    'diced pimentos',
#    'fat-free mayonnaise',
#    'garlic',
#    'green onion',
#    'low-fat sour cream',
#    'plain low-fat yogurt',
#    'prepared mustard',
#    'red potatoes',
#    'salt',
#    'sugar',
#    'white wine vinegar'}],
#  ['38798',
#   {'egg',
#    'frozen chopped spinach',
#    'garlic powder',
#    'margarine',
#    'onion',
#    'oregano',
#    'sage',
#    'soft breadcrumbs'}],
#  ['22123',
#   {'condensed cream of mushroom & garlic soup',
#    'cooking oil',
#    'cornbread mix',
#    'cream of mushroom soup',
#    'frozen vegetables',
#    'ground beef',
#    'onion',
#    'salt & pepper'}],
#  ['90921',
#   {'angel hair pasta',
#    'garlic',
#    'green onions',
#    'honey',
#    'soy sauce',
#    'stir fry vegetables',
#    'toasted sesame oil',
#    'toasted sesame seeds'}],
#  ['93959',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'buckwheat flour',
#    'butter',
#    'canola oil',
#    'cinnamon',
#    'egg',
#    'flour',
#    'ground cinnamon',
#    'ground cloves',
#    'honey',
#    'low-fat buttermilk',
#    'orange juice',
#    'orange rind',
#    'pecans',
#    'salt',
#    'sugar',
#    'unsweetened cocoa',
#    'yam'}],
#  ['93958',
#   {'baking powder',
#    'baking soda',
#    'boiling water',
#    'buckwheat flour',
#    'canola oil',
#    'egg',
#    'flour',
#    'granulated sugar',
#    'ground cinnamon',
#    'ground cloves',
#    'low-fat buttermilk',
#    'orange juice',
#    'orange rind',
#    'raisins',
#    'salt',
#    'sorghum',
#    'unsweetened cocoa',
#    'yam'}],
#  ['58224',
#   {'american cheese',
#    'beer',
#    'cayenne',
#    'garlic',
#    'ground beef',
#    'prepared yellow mustard',
#    'salt & pepper',
#    'sugar'}],
#  ['33606',
#   {'cheese',
#    'chives',
#    'cider vinegar',
#    'dill pickles',
#    'garlic powder',
#    'green onion',
#    'ham',
#    'italian seasoning',
#    'olive oil',
#    'onion powder',
#    'ripe olives',
#    'salt and pepper',
#    'sweet pepper',
#    'tomato',
#    'tri-color spiral pasta',
#    'water chestnut'}],
#  ['94710',
#   {'basil',
#    'flat leaf parsley',
#    'frozen french fries',
#    'oil',
#    'oregano',
#    'parmesan cheese',
#    'salt & freshly ground black pepper'}],
#  ['35173',
#   {'butter',
#    'cheddar cheese',
#    'deli turkey',
#    'good seasonings italian salad dressing mix',
#    'ham',
#    'mozzarella cheese',
#    'pepperoni',
#    'sandwich bun',
#    'swiss cheese'}],
#  ['83025',
#   {'baking powder',
#    'butter',
#    'egg',
#    'flour',
#    'icing sugar',
#    'milk',
#    'salt',
#    'shortening',
#    'sugar',
#    'vanilla'}],
#  ['52804',
#   {'carrot',
#    'cinnamon',
#    'coconut',
#    'crushed pineapple',
#    'egg',
#    'nutmeg',
#    'oil',
#    'pecans',
#    'vanilla instant pudding mix',
#    'water',
#    'yellow cake mix'}],
#  ['108414',
#   {'butter',
#    'egg',
#    'heavy cream',
#    'honey',
#    'jalapenos',
#    'jiffy corn muffin mix',
#    'onion',
#    'red bell pepper',
#    'sharp cheddar cheese',
#    'whole kernel corn'}],
#  ['26995',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'butter',
#    'cinnamon',
#    'crushed pineapple',
#    'dry yeast',
#    'egg',
#    'flour',
#    'milk',
#    'nuts',
#    'raisins',
#    'salt',
#    'sugar',
#    'vanilla',
#    'vegetable oil',
#    'water'}],
#  ['53402',
#   {'cottage cheese',
#    'dried basil',
#    'egg',
#    'garlic',
#    'ground beef',
#    'ground black pepper',
#    'italian sausage',
#    'lasagna noodle',
#    'mozzarella cheese',
#    'parmesan cheese',
#    'parsley flakes',
#    'ricotta cheese',
#    'salt',
#    'tomato paste',
#    'whole tomato'}],
#  ['59632',
#   {'beef',
#    'black pepper',
#    'cheese',
#    'cottage cheese',
#    'egg',
#    'frozen chopped spinach',
#    'herbs',
#    'olive oil flavored cooking spray',
#    'salt',
#    'spices',
#    'toasted wheat germ'}],
#  ['22526',
#   {'brown sugar',
#    'butter',
#    'cinnamon',
#    'instant vanilla pudding',
#    'raisins',
#    'rolls'}],
#  ['100870',
#   {'garlic',
#    'granulated sugar',
#    'ground beef',
#    'prego spaghetti sauce',
#    'stewed tomatoes',
#    'white onion'}],
#  ['84797',
#   {'beef steaks',
#    'brown sugar',
#    'dried dill weed',
#    'fresh garlic',
#    'fresh lemon juice',
#    'fresh parsley',
#    'honey',
#    'hot sauce',
#    'ketchup',
#    'sour cream',
#    'spicy mustard',
#    'vegetable oil'}],
#  ['35653',
#   {'baking powder', 'butter', 'egg', 'flour', 'milk', 'salt', 'sugar'}],
#  ['32169',
#   {'button mushrooms',
#    'chicken breasts',
#    'dried basil',
#    'dried oregano',
#    'fresh ground black pepper',
#    'fresh parsley',
#    'garlic',
#    'hot sauce',
#    'olive oil',
#    'onion',
#    'parmesan cheese',
#    'pasta',
#    'salsa',
#    'tomato',
#    'water'}],
#  ['24478', {'cider vinegar', 'fresh herb', 'fresh herbs'}],
#  ['44045',
#   {'baking powder',
#    'black pepper',
#    'cream',
#    'egg',
#    'fat',
#    'flour',
#    'fresh corn',
#    'salt'}],
#  ['60219',
#   {'black olives',
#    'cheddar cheese soup',
#    'fettuccine pasta',
#    'jalapeno',
#    'milk',
#    'picante sauce'}],
#  ['81185',
#   {'cilantro',
#    'frozen peas',
#    'hass avocado',
#    'lemons, juice of',
#    'onion',
#    'salt',
#    'tomato'}],
#  ['30131',
#   {'basil',
#    'black pepper',
#    'garlic powder',
#    'lemon juice',
#    'oil',
#    'soy sauce',
#    'worcestershire sauce'}],
#  ['63593',
#   {'apple', 'cream cheese', 'milk', 'pear', 'unflavored gelatin', 'yogurt'}],
#  ['43164',
#   {'bacon',
#    'bay leaf',
#    'black pepper',
#    'butter',
#    'carrot',
#    'oil',
#    'onion',
#    'parsley sprigs',
#    'salt',
#    'thyme',
#    'veal roast'}],
#  ['30300', {'black pepper', 'crackers', 'mayonnaise', 'tomato'}],
#  ['78655',
#   {'brine',
#    'capers',
#    'carrot',
#    'ciabatta',
#    'fresh basil',
#    'fresh parsley',
#    'garlic',
#    'genoa salami',
#    'green olives',
#    'ham',
#    'kalamata olive',
#    'olive oil',
#    'oregano leaves',
#    'provolone cheese',
#    'red wine vinegar',
#    'sweet onion',
#    'tomato'}],
#  ['74805',
#   {'powdered sugar',
#    'vanilla',
#    'vanilla instant pudding mix',
#    'whipping cream'}],
#  ['71635',
#   {'cookie',
#    'cream cheese',
#    'gelatin',
#    'milk',
#    'miniature semisweet chocolate chips',
#    'prepared graham cracker crusts',
#    'sugar',
#    'vanilla'}],
#  ['38276',
#   {'baking powder',
#    'butter',
#    'carrot',
#    'cayenne pepper',
#    'celery',
#    'chili powder',
#    'cloves',
#    'egg',
#    'flour',
#    'green pepper',
#    'ground cumin',
#    'monterey jack cheese',
#    'onion',
#    'oregano',
#    'salt',
#    'sliced mushrooms',
#    'soy sauce',
#    'tomato',
#    'vegetable shortening',
#    'water',
#    'zucchini'}],
#  ['97052', {'half-and-half', 'salt and pepper', 'sweet butter', 'sweet corn'}],
#  ['26835',
#   {'baking soda',
#    'butter',
#    'egg',
#    'flour',
#    'lemon, rind of',
#    'salt',
#    'sugar',
#    'vanilla',
#    'yogurt'}],
#  ['32271',
#   {'butter',
#    'egg',
#    'flour',
#    'nuts',
#    'sugar',
#    'unsweetened chocolate squares',
#    'vanilla'}],
#  ['107229',
#   {'broccoli',
#    'chili-garlic sauce',
#    'cooked chicken',
#    'fresh cilantro',
#    'fresh ginger',
#    'green onions',
#    'reduced sodium soy sauce',
#    'rice vinegar',
#    'sesame oil',
#    'sesame seeds',
#    'vegetable oil',
#    'vermicelli'}],
#  ['5060',
#   {'apples',
#    'celery',
#    'orange juice',
#    'orange rind',
#    'pecans',
#    'philadelphia cream cheese',
#    'sugar'}],
#  ['42570',
#   {'boneless chicken breast',
#    'cayenne',
#    'cumin',
#    'fresh ground pepper',
#    'garlic',
#    'lemon juice',
#    'olive oil',
#    'paprika',
#    'salt',
#    'thyme'}],
#  ['52443',
#   {'baking potato',
#    'garlic powder',
#    'mozzarella cheese',
#    'oregano leaves',
#    'parmesan cheese',
#    'part-skim ricotta cheese',
#    'tomato sauce'}],
#  ['35595',
#   {'black pepper',
#    'cornstarch',
#    'mushroom pieces',
#    'onion',
#    'sodium-free vegetable broth',
#    'tabasco sauce',
#    'tomato puree',
#    'white wine'}],
#  ['108804',
#   {'albacore tuna in water',
#    'bibb lettuce',
#    'black pepper',
#    'fresh basil',
#    'garlic',
#    'light olive oil',
#    'red sweet bell peppers',
#    'red wine vinegar',
#    'salt',
#    'scallions',
#    'white kidney beans'}],
#  ['83950',
#   {'bacon',
#    'beef consomme',
#    'black pepper',
#    'butter',
#    'carrot',
#    'celery',
#    'crushed tomatoes',
#    'dry white wine',
#    'garlic',
#    'ground pork',
#    'lean ground beef',
#    'milk',
#    'nutmeg',
#    'olive oil',
#    'onion',
#    'oregano',
#    'penne pasta',
#    'red pepper flakes',
#    'rubbed sage',
#    'salt'}],
#  ['19208', {'apples', 'red cinnamon candies', 'sugar substitute', 'water'}],
#  ['64302',
#   {'brown sugar',
#    'celery',
#    'cucumber',
#    'elbow macaroni',
#    'green pepper',
#    'ketchup',
#    'lemon juice',
#    'oil',
#    'onion',
#    'tomato'}],
#  ['35964',
#   {'baking powder',
#    'brown sugar',
#    'cocoa',
#    'flour',
#    'hot water',
#    'milk',
#    'salt',
#    'sugar',
#    'vanilla',
#    'vegetable oil'}],
#  ['71457',
#   {'apple pie filling',
#    'butter',
#    'egg',
#    'flour',
#    'milk',
#    'powdered sugar',
#    'salt',
#    'toasted almonds'}],
#  ['95926', {'bananas', 'mayonnaise', 'white bread'}],
#  ['103948',
#   {'boneless skinless chicken thighs',
#    'breadcrumbs',
#    'chicken stock',
#    'dried oregano',
#    'dried thyme',
#    'dry white wine',
#    'flour',
#    'fresh ground black pepper',
#    'garlic powder',
#    'lean ground beef',
#    'milk',
#    'onion',
#    'poultry seasoning',
#    'salt',
#    'vegetable oil'}],
#  ['99024',
#   {'cream cheese', 'lemon juice', 'liquid smoke', 'onion', 'salmon', 'salt'}],
#  ['64045',
#   {'bean sprouts',
#    'brown sugar',
#    'carrot',
#    'desiccated coconut',
#    'garlic',
#    'ginger',
#    'green beans',
#    'ground cayenne pepper',
#    'ground coriander',
#    'ground cumin',
#    'onion',
#    'peanut oil',
#    'peanuts',
#    'red chili pepper',
#    'sambal oelek',
#    'soy sauce',
#    'tempeh',
#    'tomato',
#    'vegetable stock',
#    'water'}],
#  ['41756',
#   {'dried breadcrumbs',
#    'egg',
#    'ground beef',
#    'lemon juice',
#    'onion',
#    'salt and pepper',
#    'sugar',
#    'tomato soup',
#    'water'}],
#  ['112959',
#   {'avocado',
#    'chunky salsa',
#    'fresh cilantro',
#    'hot sauce',
#    'lime juice',
#    'salt and pepper',
#    'soft silken tofu'}],
#  ['83062',
#   {'baking soda',
#    'bananas',
#    'cinnamon',
#    'egg',
#    'flour',
#    'ground cloves',
#    'nutmeg',
#    'salt',
#    'shortening',
#    'walnuts',
#    'white sugar'}],
#  ['98930',
#   {'boneless skinless chicken breast',
#    'dried basil',
#    'lime juice',
#    'olive oil',
#    'salt and pepper',
#    'tomato'}],
#  ['83133',
#   {'beef ribs',
#    'brown sugar',
#    'fresh lemon juice',
#    'ketchup',
#    'mustard',
#    'onion',
#    'salt',
#    'vegetable oil',
#    'water',
#    'worcestershire sauce'}],
#  ['39947', {'egg whites', 'green grape', 'sugar'}],
#  ['44895',
#   {'betty crocker fudge brownie mix',
#    'egg',
#    'milk chocolate candy bars',
#    'vegetable oil',
#    'water'}],
#  ['39363',
#   {'baking powder',
#    'baking soda',
#    'bananas',
#    'butter',
#    'chocolate chips',
#    'egg',
#    'flour',
#    'nuts',
#    'salt',
#    'sugar',
#    'water'}],
#  ['62368',
#   {'brown sugar',
#    'butter',
#    'chocolate chips',
#    'cream cheese',
#    'egg',
#    'flour',
#    'oreo cookie crumbs',
#    'sour cream',
#    'sweetened condensed milk',
#    'vanilla'}],
#  ['111875',
#   {'2% low-fat milk',
#    'banana',
#    'natural-style peanut butter',
#    'sugar-free non-fat vanilla yogurt'}],
#  ['42522',
#   {'bean dip',
#    'cheddar cheese',
#    'cream cheese',
#    'sour cream',
#    'taco seasoning'}],
#  ['34930',
#   {'american cheese',
#    'bacon',
#    'dill weed',
#    'ground sirloin',
#    'iceberg lettuce',
#    "mccormick's montreal brand steak seasoning",
#    'no-salt-added ketchup',
#    'onion',
#    'tomato'}],
#  ['63793',
#   {'chat masala',
#    'chopped tomato',
#    'cucumber',
#    'paprika',
#    'plain yogurt',
#    'potato',
#    'salt'}],
#  ['61973',
#   {'baking soda',
#    'brown sugar',
#    'buttermilk',
#    'carrot',
#    'cinnamon',
#    'corn oil',
#    'egg',
#    'natural bran',
#    'raisins',
#    'salt',
#    'vanilla',
#    'whole wheat flour'}],
#  ['45859',
#   {'grand marnier',
#    'lime juice',
#    'lime wedge',
#    'limeade',
#    'tequila',
#    'triple sec'}],
#  ['58651',
#   {'brown sugar', 'butter', 'flour', 'pecans', 'semi-sweet chocolate chips'}],
#  ['59534',
#   {'black pepper',
#    'butter',
#    'cappelletti pasta',
#    'cheddar cheese',
#    'chopped tomato',
#    'corn',
#    'garlic',
#    'ground beef',
#    'milk',
#    'mushrooms',
#    'onion',
#    'salt',
#    'tomato soup'}],
#  ['24137',
#   {'dry white wine',
#    'extra virgin olive oil',
#    'garlic',
#    'hot water',
#    'parsley',
#    'salt and pepper',
#    'spaghetti',
#    'squid',
#    'tomato sauce'}],
#  ['40237',
#   {'baking soda',
#    'cocoa',
#    'flour',
#    'salt',
#    'sugar',
#    'vanilla',
#    'vegetable oil',
#    'vinegar',
#    'water'}],
#  ['18537', {'applesauce', 'brown sugar', 'clove', 'pork loin chops'}],
#  ['104243',
#   {'butter',
#    'cheddar cheese',
#    'cream cheese',
#    'green olives',
#    'ham',
#    'honey mustard',
#    'leaf lettuce',
#    'mayonnaise',
#    'prepared horseradish',
#    'provolone cheese',
#    'radish sprouts',
#    'roast beef',
#    'roasted red peppers',
#    'swiss cheese',
#    'turkey',
#    'whole wheat bread dough'}],
#  ['105069',
#   {'beef broth',
#    'butter',
#    'flour',
#    'fresh dill',
#    'lemon, juice of',
#    'onion',
#    'salt and pepper',
#    'sour cream',
#    'water',
#    'wild mushrooms'}],
#  ['70099',
#   {'asian chili sauce',
#    'bean sprouts',
#    'carrot',
#    'english cucumber',
#    'fresh cilantro',
#    'fresh ginger',
#    'garlic',
#    'green onions',
#    'honey',
#    'light soy sauce',
#    'rice noodles',
#    'rice wine vinegar',
#    'sesame oil'}],
#  ['333281',
#   {'bittersweet chocolate',
#    'brewed espresso',
#    'egg',
#    'flour',
#    'granulated sugar',
#    'kosher salt',
#    'unsalted butter',
#    'unsweetened cocoa powder',
#    'vanilla'}],
#  ['234069', {'brown sugar', 'dr. pepper cola', 'orange marmalade'}],
#  ['37841',
#   {'fish',
#    'gingerroot',
#    'low sodium soy sauce',
#    'peanut oil',
#    'rice wine',
#    'salt',
#    'scallions',
#    'sesame oil',
#    'white pepper'}],
#  ['144952',
#   {'beef broth',
#    'butter',
#    'flour',
#    'french bread',
#    'garlic',
#    'low sodium beef broth',
#    'olive oil',
#    'parmesan cheese',
#    'romano cheese',
#    'sherry wine',
#    'sugar',
#    'swiss cheese',
#    'yellow onions'}],
#  ['453467',
#   {'baking soda',
#    'brown sugar',
#    'chocolate chips',
#    'egg',
#    'flour',
#    'margarine',
#    'salt',
#    'vanilla',
#    'water',
#    'white sugar',
#    'whole wheat flour'}],
#  ['31835',
#   {'butter',
#    'cornbread',
#    'cream of chicken soup',
#    'egg',
#    'onion',
#    'sage',
#    'squash'}],
#  ['197013',
#   {'bay leaves',
#    'black pepper',
#    'bottled garlic',
#    'dried basil',
#    'dried oregano',
#    'dried parsley',
#    'garlic powder',
#    'italian sausage',
#    'olive oil',
#    'paprika',
#    'salt',
#    'sugar',
#    'tomato sauce',
#    'white onion'}],
#  ['306168',
#   {'cream of chicken soup',
#    'french-fried onions',
#    'frozen broccoli cuts',
#    'garlic powder',
#    'ground black pepper',
#    'milk',
#    'salt',
#    'sharp cheddar cheese',
#    'soy sauce'}],
#  ['286009',
#   {'almond extract',
#    'butter',
#    'egg',
#    'flour',
#    'pure vanilla extract',
#    'sugar',
#    'whole milk'}],
#  ['24514',
#   {'artichoke hearts',
#    'egg',
#    'fresh garlic',
#    'oil',
#    'unsalted butter',
#    'unseasoned breadcrumbs'}],
#  ['42508',
#   {'barbecue sauce',
#    'black pepper',
#    'chicken',
#    'chili powder',
#    'cider vinegar',
#    'hot red pepper sauce',
#    'salt',
#    'worcestershire sauce'}],
#  ['116679',
#   {'cheddar cheese',
#    'cream cheese',
#    'dry onion soup mix',
#    'frozen broccoli',
#    'ritz cracker crumbs',
#    'sour cream',
#    'water chestnuts'}],
#  ['124286',
#   {'baking soda',
#    'cocoa powder',
#    'cool whip',
#    'flour',
#    'instant chocolate pudding mix',
#    'mayonnaise',
#    'milk',
#    'salt',
#    'sugar',
#    'vanilla',
#    'water'}],
#  ['190',
#   {'bouillon',
#    'budweiser beer',
#    'chili powder',
#    'coriander',
#    'cornmeal',
#    'cumin',
#    'flour',
#    'garlic',
#    'hunts tomato sauce',
#    'lean chuck',
#    'lean pork',
#    'louisiana hot sauce',
#    'onion',
#    'oregano leaves',
#    'paprika',
#    'sugar',
#    'unsweetened cocoa',
#    'water'}],
#  ['475785',
#   {'baby spinach',
#    'egg',
#    'fresh garlic',
#    'goat cheese',
#    'kosher salt',
#    'meatloaf mixture',
#    'olive oil',
#    'red bell pepper',
#    'simply potatoes shredded hash browns',
#    'unsalted butter',
#    'unsmoked bacon',
#    'white pepper',
#    'yellow onion'}],
#  ['17265',
#   {'dark brown sugar',
#    'egg',
#    'egg white',
#    'ground cinnamon',
#    'ground cloves',
#    'ground ginger',
#    'heavy cream',
#    'milk',
#    'nutmeg',
#    'pie crusts',
#    'pumpkin puree',
#    'salt'}],
#  ['50662',
#   {'baking powder',
#    'beef',
#    'breadcrumbs',
#    'butter',
#    'celery seed',
#    'cream of chicken soup',
#    'dry onion flakes',
#    'flour',
#    'milk',
#    'onion',
#    'paprika',
#    'poppy seed',
#    'poultry seasoning',
#    'salt',
#    'sour cream',
#    'vegetable oil'}],
#  ['177187',
#   {'baking powder',
#    'baking soda',
#    'blended oatmeal',
#    'brown sugar',
#    'butter',
#    'egg',
#    'flour',
#    'hershey chocolate candy bars',
#    'nuts',
#    'semi-sweet chocolate chips',
#    'sugar',
#    'vanilla'}],
#  ['118843',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'butter',
#    'chocolate chips',
#    'egg',
#    'flour',
#    "hershey's semi-sweet baking chocolate",
#    'nuts',
#    'oatmeal',
#    'salt',
#    'vanilla',
#    'white sugar'}],
#  ['208179', {'butter', 'flour', 'granulated sugar', 'milk', 'vanilla'}],
#  ['500166',
#   {'cheddar cheese',
#    'corn cobs',
#    'ground beef',
#    'lettuce',
#    'onion',
#    'salsa',
#    'taco seasoning',
#    'taco shells',
#    'tomato'}],
#  ['501028',
#   {'beans',
#    'beef bouillon cube',
#    'beef broth',
#    'bell peppers',
#    'black pepper',
#    'chicken bouillon cube',
#    'chunky salsa',
#    'cinnamon',
#    'cumin',
#    'dark chocolate chips',
#    'garlic',
#    'ground coriander',
#    'habanero pepper',
#    'light brown sugar',
#    'mexican chili powder',
#    'salt',
#    'sazon goya',
#    'stewing beef',
#    'stewing pork',
#    'tomato paste',
#    'tortilla chips',
#    'white onion'}],
#  ['136602',
#   {'baking soda',
#    'brown sugar',
#    'butter',
#    'cream cheese',
#    'egg',
#    'flour',
#    'lemon zest',
#    'lime zest',
#    'orange-flavored liqueur',
#    'pecans',
#    'pitted dates',
#    'powdered sugar',
#    'salt',
#    'shortening',
#    'tequila',
#    'triple sec',
#    'warm water'}],
#  ['69190',
#   {'bouillon cubes',
#    'butter',
#    'carrot',
#    'celery',
#    'cream of celery soup',
#    'cream of chicken soup',
#    'milk',
#    'onion',
#    'potato',
#    'potato flakes',
#    'water'}],
#  ['503475',
#   {'apples',
#    'butter',
#    'cinnamon',
#    'cream',
#    'egg',
#    'flour',
#    'lemon, juice of',
#    'milk',
#    'salt',
#    'sugar'}],
#  ['522861',
#   {'butter',
#    'cheese',
#    'fresh coarse ground black pepper',
#    'garlic',
#    'macaroni',
#    'milk',
#    'onion',
#    'salt'}],
#  ['457136',
#   {'black pepper',
#    'cheese',
#    'fine semolina',
#    'heavy cream',
#    'macaroni',
#    'muscat wine',
#    'onion',
#    'potato',
#    'salt water',
#    'unsalted butter'}],
#  ['455351',
#   {'applesauce',
#    'butter',
#    'cheese',
#    'milk',
#    'onion',
#    'penne pasta',
#    'potato',
#    'salt and pepper'}],
#  ['333797', {'dried yellow peas', 'ginger', 'pork', 'salt', 'water'}],
#  ['428056',
#   {'black pepper',
#    'brown mustard',
#    'carrot',
#    'clove',
#    'dried thyme',
#    'dried yellow peas',
#    'ground ginger',
#    'ham bone',
#    'onion',
#    'salt',
#    'water'}],
#  ['306245', {'butter', 'fresh spinach', 'nutmeg', 'water'}],
#  ['523359',
#   {'chili powder',
#    'cornstarch',
#    'dried onion flakes',
#    'garlic powder',
#    'granulated sugar',
#    'ground beef',
#    'ground black pepper',
#    'ground pork',
#    'paprika',
#    'salt',
#    'tomato paste',
#    'water',
#    'white vinegar',
#    'wondra flour'}],
#  ['495314',
#   {'apple cider vinegar',
#    'applesauce',
#    'cayenne',
#    'dark brown sugar',
#    'granulated garlic',
#    'liquid smoke',
#    'maple syrup',
#    'oregano',
#    'ponzu sauce',
#    'salt',
#    'tomato ketchup'}],
#  ['149593',
#   {'baking powder',
#    'baking soda',
#    'butter',
#    'egg',
#    'flour',
#    'salt',
#    'sour cream',
#    'sugar',
#    'vanilla'}],
#  ['227924',
#   {'butter', 'frozen whipped topping', 'oreo cookies', 'vanilla ice cream'}],
#  ['100540', {'butter', 'processed cheese', 'white bread'}],
#  ['155959',
#   {'balsamic vinegar',
#    'fresh ground black pepper',
#    'garlic',
#    'london broil beef',
#    'olive oil',
#    'rosemary',
#    'soy sauce',
#    'worcestershire sauce'}],
#  ['29214',
#   {'chicken broth',
#    'cornstarch',
#    'dried oregano',
#    'dried rosemary',
#    'dried thyme',
#    'dry sherry',
#    'fresh mushrooms',
#    'garlic',
#    'hot pepper sauce',
#    'margarine',
#    'nonfat dry milk powder',
#    'nonfat milk',
#    'parmesan cheese',
#    'salt and black pepper',
#    'spicy brown mustard',
#    'teriyaki sauce'}],
#  ['92533',
#   {'almonds',
#    'butter',
#    'cinnamon',
#    'cream cheese',
#    'egg',
#    'nutmeg',
#    'sour cream',
#    'splenda sugar substitute',
#    'vanilla',
#    'vanilla protein powder'}],
#  ['209203',
#   {'bacon', 'butter', 'real maple syrup', 'refrigerated buttermilk biscuits'}],
#  ['42151',
#   {'horseradish',
#    'mayonnaise',
#    'tabasco sauce',
#    'velveeta cheese',
#    'worcestershire sauce'}],
#  ['327356', {'lemon juice', 'red wine vinegar', 'water'}],
#  ['325509',
#   {'berries',
#    'ground flax seeds',
#    "i can't believe it's not butter spread",
#    'old fashioned oats',
#    'sugar-free syrup',
#    'water'}],
#  ['236184',
#   {'blueberries',
#    'cream cheese',
#    'egg',
#    'flour',
#    'french bread',
#    'frozen blueberries',
#    'maple syrup',
#    'milk',
#    'nuts',
#    'powdered sugar',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['241445',
#   {'bacon',
#    'celery',
#    'cheddar cheese',
#    'chicken broth',
#    'chives',
#    'liquid smoke',
#    'onion',
#    'red potatoes',
#    'salt',
#    'sour cream',
#    'velveeta cheese',
#    'white pepper'}],
#  ['149887',
#   {'active dry yeast',
#    'brown sugar',
#    'butter',
#    'cinnamon',
#    'cream cheese',
#    'egg',
#    'flour',
#    'granulated sugar',
#    'milk',
#    'powdered sugar',
#    'salt',
#    'vanilla pudding mix',
#    'warm water'}],
#  ['112984',
#   {'asparagus',
#    'garlic',
#    'italian seasoning',
#    'part-skim mozzarella cheese',
#    'red bell pepper',
#    'reduced-fat parmesan cheese',
#    'salt and pepper',
#    'spaghetti sauce',
#    'spaghetti squash',
#    'white mushroom'}],
#  ['200148',
#   {'coriander',
#    'cornstarch',
#    'frozen pineapple concentrate',
#    'graham cracker crumbs',
#    'lemon juice',
#    'maple syrup',
#    'margarine',
#    'oil',
#    'soft silken tofu',
#    'vanilla',
#    'vegan cream cheese',
#    'vegan sugar',
#    'water'}],
#  ['445026',
#   {'andouille sausage',
#    'celery',
#    'cooked chicken',
#    'creole seasoning',
#    'flour',
#    'frozen black-eyed peas',
#    'garlic',
#    'green bell pepper',
#    'large raw shrimp',
#    'low sodium chicken broth',
#    'onion',
#    'vegetable oil'}],
#  ['70611',
#   {'cheddar cheese',
#    'cracker',
#    'egg',
#    'ground beef',
#    'onion',
#    'pickle',
#    'salt and pepper',
#    'thousand island dressing'}],
#  ['273326',
#   {'basil',
#    'butter',
#    'cajun spices',
#    'garlic',
#    'heavy whipping cream',
#    'lemon juice',
#    'linguine',
#    'parmesan cheese',
#    'parmesan-romano cheese mix',
#    'parsley',
#    'salmon',
#    'salt',
#    'white pepper'}],
#  ['310570', {'cottage cheese', 'egg', 'feta', 'milk', 'oil', 'phyllo dough'}],
#  ['318677',
#   {'avocado',
#    'cucumber',
#    'imitation crabmeat',
#    'lettuce',
#    'pickled ginger',
#    'seasoned rice vinegar',
#    'soy sauce',
#    'white rice'}],
#  ['80050',
#   {'baking soda',
#    'egg',
#    'flour',
#    'maraschino cherry',
#    'mincemeat',
#    'mixed candied fruit',
#    'sweetened condensed milk',
#    'walnuts'}],
#  ['269984',
#   {'baby carrots',
#    'baking powder',
#    'black pepper',
#    'celery',
#    'chicken breasts',
#    'chicken stock',
#    'egg',
#    'kosher salt',
#    'matzo meal',
#    'oil',
#    'salt',
#    'sugar',
#    'white onion'}],
#  ['317508',
#   {'cheddar cheese',
#    'cream of mushroom soup',
#    'frozen southern style hash brown potatoes',
#    'poppy seed',
#    'sour cream'}],
#  ['53872',
#   {'adobo seasoning',
#    'egg',
#    'fresh garlic cloves',
#    'fresh ground pepper',
#    'ground coriander',
#    'ground sage',
#    'italian seasoned breadcrumbs',
#    'ketchup',
#    'lean ground beef',
#    'low sodium soy sauce',
#    'olive oil',
#    'oregano',
#    'red onion',
#    'sea salt',
#    'veggie shreds cheese'}],
#  ['268942',
#   {'butter',
#    'celery',
#    'cream of celery soup',
#    'green bell pepper',
#    'kraft macaroni and cheese',
#    'mushrooms',
#    'onion',
#    'tuna'}],
#  ['176110',
#   {'black pepper',
#    'cider vinegar',
#    'dry mustard',
#    'garlic',
#    'ketchup',
#    'miracle whip',
#    'paprika',
#    'salt',
#    'sugar',
#    'tabasco sauce',
#    'vegetable oil'}],
#  ['205331',
#   {'extra virgin olive oil',
#    'italian parsley',
#    'kalamata olive',
#    'kosher salt & freshly ground black pepper',
#    'lemon, juice of',
#    'oregano',
#    'pepperoncini peppers',
#    'red bell pepper',
#    'red onion',
#    'red ripe tomatoes',
#    'red wine vinegar',
#    'seedless cucumber',
#    'shallot',
#    'tuna in vegetable oil',
#    'water-packed artichoke hearts'}],
#  ['165856',
#   {'buttermilk',
#    'canola oil',
#    'egg',
#    'ground black pepper',
#    'orange roughy',
#    'seasoning salt',
#    'self-rising flour'}],
#  ['474769',
#   {'bacon',
#    'egg',
#    'egg yolk',
#    'flour',
#    'frozen spinach',
#    'garlic',
#    'goat cheese',
#    'green onion',
#    'salt',
#    'simply potatoes traditional mashed potatoes'}],
#  ['138005',
#   {'boneless pork chops',
#    'cajun seasoning',
#    'canola oil',
#    'egg',
#    'flour',
#    'ground black pepper',
#    'milk',
#    'salt and pepper',
#    'seasoning salt',
#    'self-rising flour'}],
#  ['216945',
#   {'imitation crabmeat',
#    'ramen noodles',
#    'stir fry vegetables',
#    'teriyaki marinade',
#    'water'}],
#  ['164526',
#   {'apple',
#    'banana',
#    'celery',
#    'fresh cilantro leaves',
#    'green bell pepper',
#    'ground red pepper',
#    'pesto sauce',
#    'pumpkin puree',
#    'pumpkin seeds',
#    'red onion',
#    'salt',
#    'small red potato',
#    'smooth cashew butter',
#    'vegetable broth'}],
#  ['50184',
#   {'chili powder',
#    'dry-roasted cashews',
#    'garlic',
#    'margarine',
#    'mushrooms',
#    'nutmeg',
#    'parsley',
#    'vegetable bouillon cubes',
#    'water'}],
#  ['316470',
#   {'ice cubes', 'mangoes', 'oranges', 'strawberries', 'vanilla bean'}],
#  ['343338',
#   {'fresh rosemary',
#    'garlic',
#    'leeks',
#    'olive oil',
#    'russet potatoes',
#    'salt and pepper',
#    'vegetable broth',
#    'white beans'}],
#  ['137434',
#   {'black peppercorns',
#    'boneless skinless chicken breasts',
#    'cardamom pods',
#    'chicken stock',
#    'chili powder',
#    'cinnamon stick',
#    'cloves',
#    'coriander seed',
#    'fresh coriander',
#    'fresh ginger',
#    'garlic',
#    'ground cumin',
#    'onion',
#    'salt & freshly ground black pepper',
#    'soy yogurt',
#    'turmeric'}],
#  ['95534',
#   {'beef bouillon cubes',
#    'black pepper',
#    'boiling water',
#    'dried oregano',
#    'dried thyme',
#    'garlic',
#    'garlic powder',
#    'rump roast',
#    'salt',
#    'tabasco sauce',
#    'worcestershire sauce'}],
#  ['30473', {'ginger', 'honey', 'milk', 'tea bag', 'water'}],
#  ['24470', {'ground beef', 'sausage', 'taco chips', 'velveeta cheese'}],
#  ['311991',
#   {'bell pepper',
#    'brown sugar',
#    'garlic powder',
#    'ground mustard',
#    'hamburger buns',
#    'ketchup',
#    'lean ground beef',
#    'onion',
#    'steak seasoning',
#    'tomato sauce',
#    'white vinegar',
#    'worcestershire sauce'}],
#  ['225707',
#   {'beets',
#    'black pepper',
#    'carrot',
#    'fresh corn kernels',
#    'garlic',
#    'gingerroot',
#    'green onions',
#    'green peppers',
#    'honey',
#    'rice wine vinegar',
#    'safflower oil',
#    'salad greens',
#    'salad seasoning',
#    'salt',
#    'soy sauce',
#    'white mushrooms'}],
#  ['242830',
#   {'chicken broth',
#    'dry white wine',
#    'fennel seeds',
#    'fresh lemon juice',
#    'olive oil',
#    'onion',
#    'paprika',
#    'pork chops'}],
#  ['336744',
#   {'black olives',
#    'egg',
#    'garlic powder',
#    'italian seasoning',
#    'mozzarella cheese',
#    'pepperoni',
#    'ramen noodles',
#    'red bell pepper',
#    'roma tomato'}],
#  ['83542',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'egg',
#    'flour',
#    'milk',
#    'molasses',
#    'natural bran',
#    'oil',
#    'raisins',
#    'salt',
#    'sesame seeds',
#    'sunflower seeds'}],
#  ['91626',
#   {'black tea leaves',
#    'broiler',
#    'brown sugar',
#    'dry sherry',
#    'garlic',
#    'low sodium soy sauce',
#    'minced ginger',
#    'onion',
#    'orange zest',
#    'orange, juice of',
#    'peppercorn'}],
#  ['303457',
#   {'cardamom pods',
#    'cloves',
#    'coriander seed',
#    'fruit vinegar',
#    'gingerroot',
#    'kaffir lime leaves',
#    'lemongrass',
#    'peanut oil',
#    'star anise',
#    'turmeric',
#    'yoghurt'}],
#  ['176717',
#   {'blueberry pie filling',
#    'cool whip',
#    'graham wafers',
#    'vanilla pudding mix'}],
#  ['39226',
#   {'canned jalapeno slices',
#    'cayenne pepper',
#    'chili powder',
#    'cornstarch',
#    'dried onion flakes',
#    'garlic powder',
#    'onion powder',
#    'salt',
#    'sugar',
#    'tomato paste',
#    'vinegar',
#    'water'}],
#  ['216030',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'butter',
#    'cake flour',
#    'corn flakes',
#    'egg',
#    'nuts',
#    'quick-cooking oats',
#    'raisins',
#    'salt',
#    'shredded coconut',
#    'vanilla'}],
#  ['268169',
#   {'black pepper',
#    'butter',
#    'italian spices',
#    'kosher salt',
#    'olive oil',
#    'onion',
#    'whole turkey'}],
#  ['98357',
#   {'cheddar cheese',
#    'chili with beans',
#    'corn chips',
#    'onion',
#    'salsa',
#    'sour cream'}],
#  ['150365',
#   {'black pepper',
#    'cauliflower florets',
#    'egg',
#    'parsley sprig',
#    'plain breadcrumbs',
#    'salt',
#    'vegetable oil'}],
#  ['243251',
#   {'butter',
#    'fresh green beans',
#    'ground black pepper',
#    'kosher salt',
#    'mixed herbs',
#    'olive oil',
#    'onion',
#    'walnuts'}],
#  ['20186',
#   {'american cheese',
#    'ham',
#    'hamburger buns',
#    'ketchup',
#    'sweet pickle relish'}],
#  ['109818', {'bacon', 'carrot', 'sugar', 'tomato soup'}],
#  ['243785',
#   {'brown sugar',
#    'egg',
#    'ground beef',
#    'ketchup',
#    'lipton onion soup mix',
#    'seasoned bread crumbs'}],
#  ['207525',
#   {'bulk pork sausage',
#    'garlic powder',
#    'ground chuck',
#    'ground pepper',
#    'oregano',
#    'rye cocktail bread',
#    'velveeta cheese',
#    'worcestershire sauce'}],
#  ['226246',
#   {'brown sugar',
#    'butter',
#    'caster sugar',
#    'egg',
#    'glace cherries',
#    'milk',
#    'pineapple in syrup',
#    'self-raising flour',
#    'vanilla essence'}],
#  ['353044',
#   {'apple',
#    'banana',
#    'coconut milk',
#    'flax seed oil',
#    'greens',
#    'honey',
#    'oat bran',
#    'water'}],
#  ['263781',
#   {'green onion',
#    'hawaiian bread',
#    "hellmann's mayonnaise",
#    'knorr vegetable soup mix',
#    'sour cream',
#    'water chestnuts'}],
#  ['66932',
#   {'broccoli floret',
#    'brown rice',
#    'carrot',
#    'egg',
#    'olive oil',
#    'peas',
#    'sliced mushrooms',
#    'soy sauce'}],
#  ['48131',
#   {'egg whites',
#    'pumpkin',
#    'pumpkin pie spice',
#    'reduced fat graham cracker crust',
#    'skim milk',
#    'splenda sugar substitute'}],
#  ['32363', {'beef stew', 'biscuits'}],
#  ['293225',
#   {'baking soda',
#    'buttermilk',
#    'creamy peanut butter',
#    'espresso',
#    'extra-large eggs',
#    'heavy cream',
#    'honey roasted peanuts',
#    'light corn syrup',
#    'powdered sugar',
#    'pure vanilla extract',
#    'salt',
#    'semisweet chocolate',
#    'sugar',
#    'unbleached all-purpose flour',
#    'unsalted butter',
#    'unsweetened cocoa'}],
#  ['235173',
#   {'chipotle chile in adobo',
#    'cilantro',
#    'corn kernel',
#    'fresh lime juice',
#    'garlic',
#    'ground cumin',
#    'lime zest',
#    'olive oil',
#    'onion',
#    'red bell pepper',
#    'short-grain brown rice',
#    'yellow cornmeal'}],
#  ['226001',
#   {'butter',
#    'egg',
#    'flour',
#    'instant vanilla pudding',
#    'water',
#    'whipped dessert topping mix'}],
#  ['220186',
#   {'celery',
#    'dijon mustard',
#    'fresh ground pepper',
#    'hard-boiled eggs',
#    'milk',
#    'miracle whip',
#    'mustard',
#    'potato',
#    'salt',
#    'sugar',
#    'white onions',
#    'white pepper'}],
#  ['217201',
#   {'black pepper',
#    'butter',
#    'cayenne pepper',
#    'chili powder',
#    'dried basil',
#    'garlic powder',
#    'lemon juice',
#    'seasoning salt',
#    'soy sauce',
#    'tea bag',
#    'water',
#    'white rice'}],
#  ['194665',
#   {'bisquick',
#    'egg',
#    'feta cheese',
#    'fresh ground pepper',
#    'frozen spinach',
#    'kalamata olive',
#    'milk',
#    'onion',
#    'oregano',
#    'roasted red pepper'}],
#  ['269909',
#   {'allspice',
#    'baking powder',
#    'baking soda',
#    'cinnamon',
#    'egg',
#    'flour',
#    'ground cloves',
#    'nutmeg',
#    'oil',
#    'pecans',
#    'pumpkin',
#    'salt',
#    'sugar',
#    'water'}],
#  ['259693',
#   {'black pepper',
#    'boneless pork chops',
#    'dry onion soup mix',
#    'long-grain rice',
#    'vegetable oil',
#    'water'}],
#  ['161370',
#   {'allspice',
#    'black pepper',
#    'boneless skinless chicken breasts',
#    'brown sugar',
#    'cayenne',
#    'chili powder',
#    'chives',
#    'cinnamon',
#    'clove',
#    'crushed tomatoes',
#    'garlic',
#    'ginger',
#    'habanero pepper',
#    'jamaican jerk spice',
#    'lime juice',
#    'nutmeg',
#    'olive oil',
#    'onion',
#    'onion flakes',
#    'red peppers',
#    'rum',
#    'sage',
#    'thyme'}],
#  ['152261',
#   {'frozen limeade concentrate', 'ice', 'lime sorbet', 'mango', 'strawberry'}],
#  ['152259',
#   {'apple juice',
#    'banana',
#    'ice',
#    'non-fat vanilla frozen yogurt',
#    'strawberry'}],
#  ['303460',
#   {'coriander seed',
#    'cumin',
#    'fish sauce',
#    'fruit vinegar',
#    'garlic',
#    'hoisin sauce',
#    'red chile',
#    'sesame oil',
#    'yoghurt'}],
#  ['270259',
#   {'butter',
#    'candy cane',
#    'egg',
#    'flour',
#    'peppermint extract',
#    'peppermint oreos',
#    'salt',
#    'sugar',
#    'unsweetened chocolate',
#    'unsweetened cocoa powder',
#    'vanilla'}],
#  ['345123',
#   {'canola oil',
#    'celery',
#    'cooked chicken breasts',
#    'cooked rice',
#    'green grapes',
#    'mandarin oranges',
#    'mayonnaise',
#    'orange juice',
#    'pineapple tidbits',
#    'salt',
#    'slivered almonds',
#    'white vinegar'}],
#  ['125195',
#   {'celery',
#    'cheddar cheese',
#    'frozen peas',
#    'hard-boiled eggs',
#    'mayonnaise',
#    'mustard',
#    'onion',
#    'seasoning salt',
#    'sugar',
#    'sweet pickle relish'}],
#  ['141939',
#   {'black pepper',
#    'butter',
#    'buttermilk',
#    'cayenne pepper',
#    'chicken pieces',
#    'dijon mustard',
#    'dried thyme',
#    'dry breadcrumbs',
#    'flour',
#    'fresh garlic',
#    'garlic powder',
#    'hot pepper sauce',
#    'oil',
#    'onion',
#    'paprika',
#    'parmesan cheese',
#    'seasoning salt'}],
#  ['171442',
#   {'allspice',
#    'black pepper',
#    'cinnamon',
#    'fresh garlic',
#    'habanero sauce',
#    'hoisin sauce',
#    'ketchup',
#    'lemon juice',
#    'louisiana hot sauce',
#    'pork baby back ribs',
#    'seasoning salt',
#    'sugar'}],
#  ['212188',
#   {'beef stock',
#    'black pepper',
#    'carrot',
#    'celery',
#    'chicken leg',
#    'corn',
#    'garlic',
#    'italian seasoning',
#    'onion',
#    'peas',
#    'red bell pepper',
#    'rotini pasta',
#    'salt',
#    'spaghetti sauce'}],
#  ['262208',
#   {'aluminum foil',
#    'margarine',
#    'mexicorn whole kernel corn',
#    'pam cooking spray',
#    'salt and pepper',
#    'sour cream',
#    'spinach dip',
#    'stove top stuffing mix monterey style with mushroom and onion'}],
#  ['207857', {'cooking onions', 'pickling spices', 'white vinegar'}],
#  ['221049',
#   {'carrot',
#    'chicken broth',
#    'cooked chicken',
#    'cooked pasta',
#    'egg',
#    'peas',
#    'soy sauce'}],
#  ['221116', {'cake crumbs', 'cool whip', 'cream cheese', 'mixed fruit'}],
#  ['130819',
#   {'butter',
#    'coconut flavoring',
#    'cool whip',
#    'egg',
#    'flour',
#    'lemon flavoring',
#    'pie crust',
#    'squash',
#    'sugar'}],
#  ['20223',
#   {'black pepper',
#    'cream of mushroom soup',
#    'dijon mustard',
#    'dried onion flakes',
#    'dried parsley flakes',
#    'garlic powder',
#    'ground cinnamon',
#    'ground cloves',
#    'ground veal',
#    'salt'}],
#  ['190108',
#   {'black pepper',
#    'brown rice',
#    'catfish nuggets',
#    'chicken stock',
#    'garlic',
#    'gumbo file',
#    'lemon',
#    'mexican-style stewed tomatoes with jalapeno peppers',
#    'okra',
#    'old bay seasoning',
#    'olive oil',
#    'oregano',
#    'parsley',
#    'red onions',
#    'red wine vinegar',
#    'seafood',
#    'small shrimp',
#    'tabasco sauce',
#    'tomato soup'}],
#  ['158372',
#   {'bacon',
#    'egg',
#    'fresh chives',
#    'mild cheddar cheese',
#    'paprika',
#    'sour cream',
#    'white vinegar'}],
#  ['219681',
#   {'chicken breasts',
#    'cracked black pepper',
#    'dried basil',
#    'dried oregano',
#    'dried parsley',
#    'garlic',
#    'garlic salt',
#    'lemon juice',
#    'olive oil',
#    'salt',
#    'sandwich buns',
#    'white vinegar'}],
#  ['261215',
#   {'baking soda',
#    'boiling water',
#    'brown sugar',
#    'cinnamon',
#    'cream',
#    'egg',
#    'flour',
#    'margarine',
#    'nutmeg',
#    'nuts',
#    'quick oats',
#    'salt',
#    'shredded coconut',
#    'vanilla'}],
#  ['179640', {'butter', 'marshmallows', 'rice krispies'}],
#  ['250883',
#   {'cool whip topping',
#    'cream cheese',
#    'frozen limeade concentrate',
#    'orange juice'}],
#  ['140855',
#   {'avocado',
#    'cheddar cheese',
#    'chili powder',
#    'corn chips',
#    'garlic',
#    'green onion',
#    'lemon juice',
#    'lettuce',
#    'pitted ripe olives',
#    'salad oil',
#    'salt',
#    'sour cream',
#    'sugar',
#    'tabasco sauce',
#    'tomato',
#    'tuna'}],
#  ['120297',
#   {'baking potatoes',
#    'chickpeas',
#    'coriander',
#    'fresh coriander',
#    'garlic',
#    'ground cumin',
#    'low-fat yogurt',
#    'olive oil',
#    'salt & freshly ground black pepper',
#    'tahini'}],
#  ['130492',
#   {'baking powder',
#    'buttermilk',
#    'egg',
#    'mayonnaise',
#    'salt',
#    'sugar',
#    'vegetable oil',
#    'yellow cornmeal'}],
#  ['164634',
#   {'apple',
#    'carrot',
#    'gingerroot',
#    'green cabbage',
#    'green onion',
#    'maple syrup',
#    'red cabbage',
#    'rice vinegar',
#    'sesame oil',
#    'soy sauce'}],
#  ['293836',
#   {'black pepper',
#    'canola oil',
#    'chicken soup powder',
#    'garlic powder',
#    'long-grain rice',
#    'orzo pasta',
#    'turmeric',
#    'water'}],
#  ['169586',
#   {'avocado',
#    'celery ribs',
#    'chicken breast',
#    'chicken broth',
#    'chipotle chiles in adobo',
#    'crushed tomatoes',
#    'cumin',
#    'ear of corn',
#    'fresh cilantro',
#    'green bell pepper',
#    'jalapeno pepper',
#    'salt and pepper',
#    'white onion'}],
#  ['261296',
#   {'black pepper',
#    'dried basil',
#    'egg white',
#    'eggplant',
#    'fat free mozzarella cheese',
#    'fiber one cereal',
#    'garlic powder',
#    'italian-style tomato sauce',
#    'reduced-fat parmesan cheese',
#    'salt'}],
#  ['101115', {'beef gravy', 'egg', 'ground beef', 'onion', 'white rice'}],
#  ['271594',
#   {'beans',
#    'black pepper',
#    'black-eyed peas',
#    'carrot',
#    'celery ribs',
#    'garlic',
#    'great northern beans',
#    'ham',
#    'ham bone',
#    'ham soup base',
#    'navy beans',
#    'onion',
#    'pinto beans',
#    'salt',
#    'tomatoes and green chilies',
#    'water'}],
#  ['164291',
#   {'cider vinegar',
#    'feta cheese',
#    'fresh dill',
#    'garlic',
#    'light mayonnaise',
#    'red bell pepper',
#    'skinless chicken breast half'}],
#  ['251528',
#   {'cheese ravioli',
#    'garlic salt',
#    'italian seasoning',
#    'lean ground beef',
#    'mozzarella cheese',
#    'spaghetti sauce'}],
#  ['250833',
#   {'barbecue sauce',
#    'chicken pieces',
#    'lemon juice',
#    'orange marmalade',
#    'worcestershire sauce'}],
#  ['343448',
#   {'coriander',
#    'garlic powder',
#    'ground black pepper',
#    'ground red pepper',
#    'onion powder',
#    'paprika',
#    'salt',
#    'turmeric'}],
#  ['39893',
#   {'black olives',
#    'cream cheese',
#    'green onion',
#    'green pepper',
#    'lettuce',
#    'mayonnaise',
#    'mexican blend cheese',
#    'sour cream',
#    'taco seasoning mix',
#    'tomato'}],
#  ['147477',
#   {'green bell peppers',
#    'green onions',
#    'minced clams',
#    'paprika',
#    'sharp cheddar cheese',
#    'tabasco sauce',
#    'worcestershire sauce'}],
#  ['223349',
#   {'eggplants',
#    'olive oil',
#    'olives',
#    'oregano',
#    'red bell pepper',
#    'red onion',
#    'shrimp',
#    'spaghetti squash',
#    'yellow bell pepper'}],
#  ['86768',
#   {'butter', "confectioners' sugar", 'heavy cream', 'semisweet chocolate'}],
#  ['197001',
#   {'cherry pie filling',
#    'crushed pineapple',
#    'frozen whipped topping',
#    'pecans',
#    'small marshmallow',
#    'sweetened condensed milk'}],
#  ['60938',
#   {'bacon',
#    'cheddar cheese',
#    'green onions',
#    'oil',
#    'potato',
#    'salt',
#    'sour cream'}],
#  ['228491',
#   {'black pepper',
#    'boneless eye of round beef steak',
#    'canola oil',
#    'mozzarella cheese',
#    'onion',
#    'parmesan cheese',
#    'pizza sauce',
#    'plain flour',
#    'salt'}],
#  ['451515',
#   {'bacon grease',
#    'boneless country-style ribs',
#    "campbell's golden mushroom soup",
#    'flour',
#    'ground black pepper',
#    'oregano',
#    'seasoning salt',
#    'soup mix'}],
#  ['353171', {'butter', 'egg', 'flour', 'fruit', 'milk', 'sugar'}],
#  ['354039',
#   {'apples',
#    'baby carrots',
#    'butter',
#    'cardamom',
#    'crescent roll dough',
#    'ground cinnamon',
#    'honey',
#    'sugar'}],
#  ['302399',
#   {'garlic salt',
#    'italian seasoning',
#    'mozzarella cheese',
#    'olive oil',
#    'refrigerated biscuits'}],
#  ['195736',
#   {'active dry yeast', 'butter', 'flour', 'milk', 'salt', 'sugar', 'water'}],
#  ['365946',
#   {'butter',
#    'cream cheese',
#    'egg',
#    'egg yolk',
#    'egg yolks',
#    'flour',
#    'lemon peel',
#    'salt',
#    'sugar',
#    'vanilla',
#    'whipping cream'}],
#  ['221544',
#   {'chili sauce',
#    'country-style dijon mustard',
#    'honey',
#    'little smokies sausages'}],
#  ['175306',
#   {'bacardi dark rum',
#    'grenadine',
#    "meyer's dark rum",
#    'orange curacao',
#    'orange juice',
#    'orgeat syrup',
#    'pineapple juice',
#    'prepared sweet-and-sour mix',
#    'white rum'}],
#  ['211833',
#   {'balsamic vinaigrette',
#    'condensed chicken broth',
#    'dried thyme leaves',
#    'minute white rice',
#    'onion',
#    'pork chops',
#    'red apples',
#    'sliced mushrooms',
#    'water'}],
#  ['276567',
#   {'chili powder',
#    'fresh ground black pepper',
#    'green bell peppers',
#    'horseradish',
#    'onion',
#    'orange juice',
#    'plain nonfat yogurt',
#    'prepared mustard',
#    'red bell peppers',
#    'reduced-calorie mayonnaise',
# ...
#    'egg',
#    'flour',
#    'nuts',
#    'sugar',
#    'vanilla'}],
#  ['79425',
#   {'butter',
#    'caramels',
#    'chocolate cake mix',
#    'chocolate chips',
#    'evaporated milk',
#    'nuts'}],
#  ['213681',
#   {'baking soda',
#    'bananas',
#    'canola oil',
#    'egg',
#    'flour',
#    'raisins',
#    'salt',
#    'sugar',
#    'walnuts'}],
#  ['121712', {'cream cheese', 'thousand island dressing'}],
#  ['155344',
#   {'chili sauce', 'mayonnaise', 'onion powder', 'sweet pickle relish'}],
#  ['175339',
#   {'baking soda',
#    'brown sugar',
#    'chocolate chips',
#    'cream of tartar',
#    'egg',
#    'flaked coconut',
#    'flour',
#    'margarine',
#    'oil',
#    'rice krispies',
#    'rolled oats',
#    'vanilla',
#    'white sugar'}],
#  ['72600',
#   {'baby spinach',
#    'bacon',
#    'buttermilk',
#    'fresh lemon juice',
#    'garlic',
#    'hardboiled egg',
#    'mushrooms',
#    'plain yogurt',
#    'sugar',
#    'unsalted sunflower seeds',
#    'white pepper'}],
#  ['50614',
#   {'bacon',
#    'cauliflower',
#    'cherry tomatoes',
#    'fresh broccoli',
#    'fresh mushrooms',
#    'frozen peas',
#    'green pepper',
#    'italian seasoning',
#    'lettuce',
#    'mayonnaise',
#    'red onion',
#    'sugar'}],
#  ['133784',
#   {'basil leaves',
#    'black pepper',
#    'celery salt',
#    'chili powder',
#    'garlic powder',
#    'ground allspice',
#    'ground oregano',
#    'marjoram leaves',
#    'onion salt',
#    'paprika',
#    'rubbed sage'}],
#  ['235003', {'beer', 'fresh jalapeno', 'ice', 'vodka'}],
#  ['140723',
#   {'anchovy fillets',
#    'baby spinach',
#    'bacon',
#    'dijon mustard',
#    'extra virgin olive oil',
#    'french bread',
#    'fresh mushrooms',
#    'garlic',
#    'lemon juice',
#    'low-fat mayonnaise',
#    'miracle whip light',
#    'oil',
#    'olive oil',
#    'parmesan cheese',
#    'worcestershire sauce'}],
#  ['326839',
#   {'dried italian seasoning',
#    'egg',
#    'ground beef',
#    'ground pepper',
#    'italian cheese blend',
#    'jumbo pasta shells',
#    'mexican blend cheese',
#    'mozzarella cheese',
#    'parmesan-romano cheese mix',
#    'parsley flakes',
#    'ricotta cheese',
#    'salt',
#    'spaghetti sauce'}],
#  ['467326',
#   {'bread machine yeast',
#    'brown sugar',
#    'oil',
#    'salt',
#    'water',
#    'white flour',
#    'whole wheat flour'}],
#  ['43669',
#   {'butter',
#    'cream-style corn',
#    'evaporated milk',
#    'onion',
#    'potato',
#    'salt and pepper',
#    'water',
#    'whole corn'}],
#  ['73566',
#   {'black pepper',
#    'extra virgin olive oil',
#    'flat leaf parsley',
#    'italian seasoned breadcrumbs',
#    'kosher salt',
#    'orecchiette',
#    'parmesan cheese',
#    'prosciutto'}],
#  ['449768',
#   {'cumin seeds', 'fresh ground black pepper', 'olive oil', 'salt', 'tomato'}],
#  ['404661',
#   {'baking soda',
#    'butter',
#    'corn syrup',
#    'molasses',
#    'salted peanuts',
#    'vanilla',
#    'white sugar'}],
#  ['381713',
#   {'bulgar wheat',
#    'cinnamon',
#    'lean ground beef',
#    'onion',
#    'plain yogurt',
#    'salt'}],
#  ['257696',
#   {'apple pie filling',
#    'egg',
#    'instant vanilla pudding',
#    'oil',
#    'water',
#    'yellow cake mix'}],
#  ['187606',
#   {'boneless skinless chicken breasts',
#    'carrot',
#    'italian dressing',
#    'potato'}],
#  ['91515', {'chocolate milk', 'cinnamon rolls', 'egg'}],
#  ['289891',
#   {'baking powder',
#    'butter',
#    'egg',
#    'flour',
#    'milk',
#    'salt',
#    'vanilla',
#    'white sugar'}],
#  ['412073',
#   {'basil',
#    'black pepper',
#    'carrot',
#    'celery',
#    'garlic',
#    'ham',
#    'leeks',
#    'salt',
#    'soup mix',
#    'thyme',
#    'water',
#    'worcestershire sauce'}],
#  ['123746',
#   {'bell peppers',
#    'chili sauce',
#    'egg',
#    'garlic powder',
#    'ground beef',
#    'milk',
#    'onion',
#    'salt and pepper',
#    'saltine crackers',
#    'worcestershire sauce'}],
#  ['206020',
#   {'aluminum foil',
#    'beef tenderloin',
#    'garlic',
#    'limes, juice of',
#    'prepared horseradish',
#    'salt and pepper',
#    'sour cream',
#    'unsalted butter',
#    'worcestershire sauce'}],
#  ['345595',
#   {'baking powder',
#    'baking soda',
#    'carrot',
#    'cinnamon',
#    'cream cheese',
#    'egg',
#    'flour',
#    'margarine',
#    'oil',
#    'pineapple',
#    'powdered sugar',
#    'salt',
#    'sugar',
#    'walnuts'}],
#  ['129227',
#   {'cabbage',
#    'carrot',
#    'celery seed',
#    'mustard seeds',
#    'onion',
#    'salt',
#    'sugar',
#    'turmeric',
#    'water',
#    'white vinegar'}],
#  ['472955',
#   {'alum',
#    'pickling cucumbers',
#    'pickling spices',
#    'salt',
#    'sugar',
#    'vinegar',
#    'water'}],
#  ['17490',
#   {'alum',
#    'canning salt',
#    'cucumbers',
#    'pickling spices',
#    'sugar',
#    'vinegar'}],
#  ['130002',
#   {'allspice',
#    'baking soda',
#    'carrot',
#    'cinnamon',
#    'coconut',
#    'cream cheese',
#    'egg',
#    'flour',
#    'ground cloves',
#    'margarine',
#    'nuts',
#    'oil',
#    'powdered sugar',
#    'raisins',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['53353', {'butter', 'cream', 'lemon extract', 'maple syrup', 'nutmeats'}],
#  ['105756',
#   {'basil',
#    'beans',
#    'carrot',
#    'celery',
#    'chicken bouillon cubes',
#    'chicken broth',
#    'deli ham',
#    'lemon juice',
#    'onion',
#    'parsley',
#    'raw rice',
#    'salt',
#    'tomato',
#    'v8 vegetable juice',
#    'water'}],
#  ['307362',
#   {'hormel chili without beans',
#    'monterey jack cheese',
#    'refried beans',
#    'tortillas'}],
#  ['51803',
#   {'15 bean soup mix',
#    'black pepper',
#    'celery leaves',
#    'chicken bouillon cubes',
#    'dried parsley',
#    'dried rosemary',
#    'garlic',
#    'ham hocks',
#    'olive oil',
#    'onion',
#    'salt',
#    'whole tomatoes'}],
#  ['438263',
#   {'15 bean soup mix',
#    'beef bouillon paste',
#    'black pepper',
#    'diced tomatoes',
#    'garlic',
#    'ham bone',
#    'smoked sausage',
#    'steak sauce',
#    'water',
#    'worcestershire sauce'}],
#  ['525649',
#   {'black pepper',
#    'carrot',
#    'cayenne pepper',
#    'chili powder',
#    'condensed tomato soup',
#    'dried beans',
#    'garlic',
#    'ham',
#    'lemon',
#    'olive oil',
#    'onion',
#    'oregano',
#    'paprika',
#    'salt',
#    'smoked paprika',
#    'thyme',
#    'water'}],
#  ['115160',
#   {'baking soda',
#    'egg',
#    'flour',
#    'ground walnuts',
#    'honey',
#    'liquid honey',
#    'margarine',
#    'plain sweet biscuit crumbs',
#    'sour cream',
#    'sugar'}],
#  ['168222',
#   {'capers',
#    'chicken stock',
#    'fresh chives',
#    'fresh parsley',
#    'fresh tarragon',
#    'garlic',
#    'halibut steaks',
#    'lemon juice',
#    'salt and pepper'}],
#  ['140172',
#   {'boneless sirloin steak',
#    'lipton beefy mushroom soup mix',
#    'new potatoes',
#    'oil',
#    'peas and carrots',
#    'tomato paste',
#    'water'}],
#  ['305112',
#   {'black beans',
#    'frozen corn kernels',
#    'ground beef',
#    'taco seasoning',
#    'tomatoes and green chilies'}],
#  ['53481',
#   {'cheddar cheese',
#    'ketchup',
#    'lean ground beef',
#    'minute white rice',
#    'mustard',
#    'water'}],
#  ['76887',
#   {'chili with beans',
#    'diced tomatoes',
#    'ground beef',
#    'velveeta cheese',
#    'water',
#    'white rice'}],
#  ['392598',
#   {'boneless skinless chicken breast halves',
#    'condensed cream of chicken soup',
#    'ground pepper',
#    'instant rice',
#    'paprika',
#    'vegetable oil',
#    'water'}],
#  ['113197',
#   {'black pepper',
#    'cheese',
#    'chicken breast tenders',
#    'fajita seasoning mix',
#    'lime',
#    'olive oil',
#    'onion',
#    'pico de gallo',
#    'sour cream',
#    'tortilla'}],
#  ['398071',
#   {'cheddar cheese',
#    'chicken',
#    'chicken broth',
#    'kidney beans',
#    'mexicorn',
#    'salsa',
#    'sour cream',
#    'tortilla chips'}],
#  ['66527',
#   {'boneless skinless chicken breasts',
#    'broccoli florets',
#    'condensed cream of chicken soup',
#    'milk',
#    'minute rice',
#    'vegetable oil'}],
#  ['184890',
#   {'chili powder',
#    'cumin',
#    'ground turkey',
#    'kidney beans',
#    'onion',
#    'pinto beans',
#    'salsa',
#    'salt',
#    'stewed tomatoes'}],
#  ['79046',
#   {'cheese',
#    'chili with beans',
#    'flour tortillas',
#    'sour cream',
#    'water',
#    'white minute rice'}],
#  ['356163',
#   {'broccoli',
#    'chili powder',
#    'ketchup',
#    'lean ground beef',
#    'macaroni & cheese dinner mix',
#    'water'}],
#  ['41673',
#   {'allspice',
#    'black pepper',
#    'brown sugar',
#    'cinnamon',
#    'clove',
#    'onion',
#    'salt',
#    'tomato'}],
#  ['506885',
#   {'black pepper',
#    'crushed red pepper flakes',
#    'fresh basil',
#    'fresh oregano',
#    'fresh parmesan cheese',
#    'garlic',
#    'grape tomatoes',
#    'pappardelle pasta',
#    'roasted cashews',
#    'sun-dried tomato packed in oil'}],
#  ['277539',
#   {'chipotle chile in adobo',
#    'garlic',
#    'ground coriander',
#    'ground cumin',
#    'low sodium chicken broth',
#    'onion',
#    'salt',
#    'tomato sauce'}],
#  ['169487',
#   {'fat free cream cheese',
#    'fat-free whipped topping',
#    'reduced fat graham cracker crust',
#    'sugar substitute'}],
#  ['317587',
#   {'fresh linguine',
#    'fresh spinach',
#    'lemon juice',
#    'parmesan cheese',
#    'pesto sauce',
#    'pine nuts',
#    'red onion',
#    'tomato'}],
#  ['20624',
#   {'boneless skinless chicken breast halves',
#    'butter',
#    'chicken broth',
#    'flour',
#    'garlic',
#    'lemon juice',
#    'oil',
#    'salt and pepper'}],
#  ['360232',
#   {'celery ribs',
#    'cracked black pepper',
#    'extra virgin olive oil',
#    'feta cheese',
#    'fresh lemon juice',
#    'fresh parsley',
#    'garbanzo beans',
#    'garlic',
#    'of fresh mint',
#    'romaine lettuce',
#    'salt',
#    'scallion',
#    'tomato'}],
#  ['246548',
#   {'assorted fresh vegetables',
#    'boneless skinless chicken breast',
#    'instant rice',
#    'italian dressing',
#    'oil',
#    'reduced-sodium fat-free chicken broth'}],
#  ['67446',
#   {'butter',
#    'cream cheese',
#    'graham cracker crumbs',
#    'instant lemon pudding',
#    'milk',
#    'powdered sugar'}],
#  ['153028',
#   {'butter', 'cocoa', "confectioners' sugar", 'peanut butter', 'vanilla'}],
#  ['172651',
#   {'italian salad dressing',
#    'parmesan cheese',
#    'smoked turkey breast',
#    'spaghetti',
#    'tomato'}],
#  ['348952',
#   {'chicken bouillon cube',
#    'frozen mixed vegetables',
#    'minute rice',
#    'oil',
#    'pork tenderloin',
#    'soy sauce',
#    'water'}],
#  ['5276',
#   {'chicken bouillon cubes',
#    'green pepper',
#    'hot pepper sauce',
#    'kidney beans',
#    'minute white rice',
#    'oil',
#    'onion',
#    'water'}],
#  ['140173',
#   {'baby peas',
#    'bacon bits',
#    'black pepper',
#    'fettuccine',
#    'garlic salt',
#    'half-and-half cream',
#    'parmesan cheese',
#    'shrimp'}],
#  ['31184',
#   {'angel hair pasta',
#    'butter',
#    'extra virgin olive oil',
#    'frozen shrimp',
#    'garlic',
#    'onion',
#    'salt & pepper',
#    'white wine'}],
#  ['164178',
#   {'celery',
#    'garlic flakes',
#    'hamburger',
#    'hot chili flakes',
#    'jalapenos',
#    'onion',
#    'sliced mushrooms',
#    'sweet green pepper',
#    'sweet red pepper',
#    'tomato sauce & mushrooms'}],
#  ['289025',
#   {'asparagus',
#    'boneless skinless chicken breast',
#    'chicken broth',
#    'chili flakes',
#    'fresh ginger',
#    'garlic',
#    'onion',
#    'rice vinegar',
#    'salt',
#    'soy sauce',
#    'white pepper'}],
#  ['287502',
#   {'dijon mustard',
#    'elbow macaroni',
#    'extra-sharp cheddar cheese',
#    'fresh ground black pepper',
#    'half-and-half',
#    'hot sauce',
#    'kosher salt',
#    'unsalted butter'}],
#  ['75079',
#   {'butter',
#    'dry onion soup mix',
#    'flour',
#    'fresh mushrooms',
#    'round steak',
#    'sour cream',
#    'water'}],
#  ['147100',
#   {'chopped tomatoes',
#    'extra lean ground beef',
#    'lettuce',
#    'mexican blend cheese',
#    'minute white rice',
#    'taco seasoning mix',
#    'water'}],
#  ['233317',
#   {'baby spinach',
#    'cornflour',
#    'dark soy sauce',
#    'lime, juice and zest of',
#    'pak choi',
#    'sunflower oil',
#    'sweet chili sauce',
#    'thai fish sauce',
#    'tiger shrimp',
#    'water'}],
#  ['109793', {'milk', 'minute rice', 'raisins', 'vanilla instant pudding mix'}],
#  ['291409',
#   {'black beans', 'fire-roasted tomatoes', 'kidney beans', 'salsa', 'water'}],
#  ['27275',
#   {'cream cheese',
#    'fettuccine pasta',
#    'margarine',
#    'milk',
#    'parmesan cheese'}],
#  ['282812',
#   {'dried fruits',
#    'honey',
#    'milk',
#    'quick oats',
#    'salt',
#    'sugar',
#    'vanilla',
#    'water'}],
#  ['311608',
#   {'15 bean mix',
#    'bay leaves',
#    'black pepper',
#    'carrot',
#    'celery',
#    'chicken bouillon cubes',
#    'diced tomatoes',
#    'garlic',
#    'ham hocks',
#    'onion',
#    'seasoning salt',
#    'tomato sauce',
#    'water'}],
#  ['382234',
#   {'black-eyed peas',
#    'canned green beans',
#    'chili seasoning mix',
#    'corn chips',
#    'dark red kidney beans',
#    'green bell pepper',
#    'ground beef',
#    'ketchup',
#    'onion',
#    'red pepper flakes',
#    'salt and pepper',
#    'sharp cheddar cheese',
#    'vegetable oil',
#    'water',
#    'whole tomatoes'}],
#  ['237391',
#   {'brandy',
#    'butter',
#    'chicken liver',
#    'garlic',
#    'ground black pepper',
#    'heavy cream',
#    'marjoram',
#    'onion',
#    'sage',
#    'salt',
#    'thyme'}],
#  ['266997',
#   {'cayenne pepper',
#    'chili beans',
#    'chili powder',
#    'cumin',
#    'diced tomatoes',
#    'lean ground beef',
#    'onion',
#    'oregano',
#    'salt',
#    'sliced mushrooms',
#    'sour cream'}],
#  ['21916',
#   {'cool whip topping',
#    'frozen pound cake',
#    'jello instant vanilla pudding mix',
#    'orange liqueur',
#    'strawberries',
#    'strawberry',
#    'sugar',
#    'white chocolate baking squares'}],
#  ['229451',
#   {'black pepper',
#    'boneless skinless chicken breast halves',
#    'dijon mustard',
#    'dried tarragon',
#    'fresh lemon juice',
#    'worcestershire sauce'}],
#  ['204040', {'basmati rice', 'chicken broth', 'salt and pepper'}],
#  ['82287',
#   {'black olives',
#    'cooked chicken',
#    'cream of chicken soup',
#    'green enchilada sauce',
#    'green onion',
#    'lettuce',
#    'monterey jack cheese',
#    'salsa',
#    'sour cream',
#    'tomato',
#    'tortilla chips'}],
#  ['302815', {'butter', 'garlic', 'parmesan cheese', 'pasta'}],
#  ['311842',
#   {'black pepper',
#    'dried oregano',
#    'feta cheese',
#    'garlic',
#    'large shrimp',
#    'old bay seasoning',
#    'olive oil',
#    'parsley',
#    'tomato'}],
#  ['531148',
#   {'cherry tomatoes',
#    'corn kernels',
#    'herbs',
#    'large shrimp',
#    'lemon, zest of',
#    'olive oil',
#    'red onion',
#    'salt & freshly ground black pepper',
#    'snap peas',
#    'unsalted butter',
#    'zucchini'}],
#  ['364157',
#   {'dried oregano',
#    'fresh lemon juice',
#    'garlic',
#    'olive oil',
#    'parmesan cheese',
#    'salt and pepper',
#    'scallions',
#    'vegetable broth',
#    'white beans'}],
#  ['411979',
#   {'bay leaves',
#    'beans',
#    'carrot',
#    'celery',
#    'chicken stock',
#    'garlic',
#    'italian sausage',
#    'onion',
#    'oregano',
#    'tomato',
#    'water'}],
#  ['102832',
#   {'alum',
#    'cinnamon sticks',
#    'cucumbers',
#    'pickling salt',
#    'pickling spices',
#    'sugar',
#    'white vinegar'}],
#  ['246180', {'barbecue sauce', 'ginger ale', 'onion', 'pork butt'}],
#  ['224908',
#   {'brown sugar',
#    'cold water',
#    'dark molasses',
#    'strong coffee',
#    'sugar',
#    'vanilla bean',
#    'vodka'}],
#  ['364761',
#   {'carrot',
#    'celery',
#    'celery ribs',
#    'chicken bouillon cubes',
#    'chicken broth',
#    'frozen corn',
#    'frozen white corn',
#    'onion',
#    'potato',
#    'whole chickens'}],
#  ['489337',
#   {'basil',
#    'eggplant',
#    'fat-free parmesan cheese',
#    'fennel seed',
#    'lean ground turkey',
#    'low-carb marinara sauce',
#    'nonstick cooking spray',
#    'oregano leaves'}],
#  ['262448', {'mountain dew soda', 'raspberry vodka'}],
#  ['294427',
#   {'apple cider',
#    'arugula',
#    'dijon mustard',
#    'fresh thyme',
#    'gouda cheese',
#    'olive oil',
#    'pancetta',
#    'red onion',
#    'red wine vinegar',
#    'salt and pepper',
#    'shallots',
#    'sherry wine vinegar',
#    'tart apples',
#    'white cheddar cheese',
#    'white vinegar'}],
#  ['328436',
#   {'baby carrots',
#    'baking powder',
#    'baking soda',
#    "confectioners' sugar",
#    'egg',
#    'flour',
#    'light brown sugar',
#    'marshmallow cream',
#    'pumpkin pie spice',
#    'pure vanilla extract',
#    'salt',
#    'unsalted butter',
#    'vegetable oil'}],
#  ['357228',
#   {'baking soda',
#    'butter',
#    'buttermilk',
#    'cinnamon',
#    'clove',
#    'cocoa',
#    'egg',
#    'flour',
#    'nutmeg',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['50246',
#   {'almonds',
#    'cornstarch',
#    'cream of tartar',
#    'egg',
#    'egg yolks',
#    'flour',
#    'milk',
#    'powdered sugar',
#    'sugar',
#    'sweet cream'}],
#  ...]

# %% [markdown]
# Reshape the data into a vector of vectors of ingredients per recipe, to use for training a [*word2vec*](https://arxiv.org/abs/1301.3781) vector embedding model:

# %%
vectors = []

for id, ind_set in recipes:
    v = []
    
    for ind in ind_set:
        v.append(ind)

    vectors.append(v)

vectors
# Out:
# [['mixed spice',
#   'salt',
#   'winter squash',
#   'butter',
#   'mexican seasoning',
#   'honey',
#   'olive oil'],
#  ['cheese',
#   'sausage patty',
#   'egg',
#   'milk',
#   'salt and pepper',
#   'prepared pizza crust'],
#  ['tomato paste',
#   'rotel tomatoes',
#   'ground cumin',
#   'salt',
#   'chili powder',
#   'lettuce',
#   'diced tomatoes',
#   'water',
#   'ground beef',
#   'yellow onions',
#   'cheddar cheese',
#   'kidney beans',
#   'tomato soup'],
#  ['tarragon',
#   'red bell pepper',
#   'salt',
#   'red wine vinegar',
#   'yellow bell pepper',
#   'shallots',
#   'spreadable cheese with garlic and herbs',
#   'new potatoes',
#   'olive oil',
#   'black pepper',
#   'parsley'],
#  ['tomato juice',
#   'clove oil',
#   'salt',
#   'dry mustard',
#   'black pepper',
#   'sugar',
#   'cinnamon oil',
#   'apple cider vinegar'],
#  ['milk', 'vanilla ice cream', 'frozen apple juice concentrate', 'apple'],
#  ['garlic',
#   'red chile',
#   'ripe olives',
#   'extra virgin olive oil',
#   'fennel seeds',
#   'peppercorn',
#   'orange rind',
#   'green olives',
#   'orange juice'],
#  ['pork spareribs',
#   'cinnamon sticks',
#   'salt',
#   'chili powder',
#   'soy sauce',
#   'white vinegar',
#   'water',
#   'fresh cilantro leaves',
#   'cumin',
#   'liquid smoke',
#   'brown sugar',
#   'fresh garlic',
#   'fresh ginger',
#   'tomato sauce',
#   'fresh coarse ground black pepper',
#   'yellow onion',
#   'cracked black pepper',
#   'a.1. original sauce',
#   'mirin',
#   'honey',
#   'dry mustard',
#   'orange, juice of'],
#  ['chocolate sandwich style cookies',
#   'bananas',
#   'strawberry ice cream',
#   'chocolate syrup',
#   'vanilla ice cream',
#   'whipped cream'],
#  ['cake flour',
#   'bananas',
#   'egg',
#   'salt',
#   'baking soda',
#   'orange rind',
#   'unsalted butter',
#   'sugar',
#   'fresh lemon juice'],
#  ['prepared horseradish', 'whole berry cranberry sauce', 'sour cream'],
#  ['whipping cream',
#   'egg',
#   'powdered sugar',
#   'vanilla wafers',
#   'butter',
#   'walnuts',
#   'strawberry'],
#  ['cornstarch',
#   'garlic powder',
#   'dark brown sugar',
#   'great northern bean',
#   'chicken bouillon cubes',
#   'molasses',
#   'onion',
#   'chili powder',
#   'salt',
#   'mustard powder',
#   'bacon',
#   'water',
#   'black pepper'],
#  ['brown sugar',
#   'collard greens',
#   'salt',
#   'molasses',
#   'hot sauce',
#   'whiskey',
#   'ham hock'],
#  ['gentian root', 'scullcap herb', 'wood bethony', 'spearmint', 'burnet root'],
#  ['flour',
#   'garlic powder',
#   'oil',
#   'lean pork chops',
#   'salt',
#   'dry mustard',
#   'chicken rice soup'],
#  ['cheese', 'cornstarch', 'oil', 'egg roll wrap', 'whole green chilies'],
#  ['butterscotch chips', 'chinese noodles', 'salted peanuts'],
#  ['beef broth',
#   'celery',
#   'soy sauce',
#   'onion',
#   'hamburger buns',
#   'ground pork',
#   'cooking oil'],
#  ['garlic',
#   'fresh herb',
#   'ground coriander',
#   'red bell pepper',
#   'great northern bean',
#   'onion',
#   'potato',
#   'cauliflower',
#   'salt free herb and spice seasoning mix',
#   'broccoli floret',
#   'escarole',
#   'canola oil',
#   'water',
#   'salt and pepper',
#   'vegetable bouillon cubes',
#   'green peas'],
#  ['fresh spinach leaves',
#   'fresh ground black pepper',
#   'salt',
#   'nutmeg',
#   'boiling potatoes',
#   'coarse salt',
#   'water',
#   'unsalted butter'],
#  ['apple juice',
#   'white pepper',
#   'rolled oats',
#   'celery',
#   'salt',
#   'broth',
#   'dried thyme',
#   'onion',
#   'fresh parsley',
#   'spinach',
#   'scallion',
#   'olive oil'],
#  ['boneless skinless chicken breast halves',
#   'cornstarch',
#   'garlic powder',
#   'flour',
#   'egg',
#   'oil',
#   'seasoning salt',
#   'salt and pepper',
#   'condensed cream of chicken soup',
#   'paprika'],
#  ['brown sugar',
#   'granulated sugar',
#   'flour',
#   'egg',
#   'milk',
#   'powdered sugar',
#   'salt',
#   'ground cinnamon',
#   'butter',
#   'vegetable oil',
#   'bread',
#   'vanilla',
#   'baking powder'],
#  ['white pepper', 'egg yolks', 'salt', 'lemon, juice of', 'butter'],
#  ['ground turmeric',
#   'ground coriander',
#   'ground cumin',
#   'black cumin',
#   'ground black pepper',
#   'ground ginger'],
#  ['garlic',
#   'celery',
#   'green pepper',
#   'salt',
#   'chili powder',
#   'onion',
#   'diced tomatoes',
#   'jalapenos',
#   'red pepper flakes',
#   'vegetarian ground beef',
#   'kidney beans',
#   'black pepper'],
#  ['elbow macaroni',
#   'zucchini',
#   'ground pepper',
#   'salt',
#   'tomato',
#   'beef stew meat',
#   'dried parsley',
#   'onion',
#   'beef bouillon cube',
#   'water',
#   'parmesan cheese',
#   'cabbage',
#   'garbanzo beans',
#   'ground thyme'],
#  ['margarine', 'red potatoes', 'rosemary'],
#  ['worcestershire sauce',
#   'broccoli stem',
#   'cornstarch',
#   'carrot',
#   'dried oregano',
#   'celery',
#   'dried thyme',
#   'dried sweet basil leaves',
#   'salt & fresh ground pepper',
#   'onion',
#   'heavy cream',
#   'chicken stock',
#   'smoked chicken',
#   'black beans',
#   'broccoli floret',
#   'unsalted butter',
#   'tabasco sauce',
#   'dry white wine'],
#  ['flour',
#   'baking cocoa',
#   'egg',
#   'salt',
#   'butter',
#   'miniature peppermint patties',
#   'sugar',
#   'vanilla',
#   'baking powder'],
#  ['taco sauce',
#   'sliced ripe olives',
#   'ground beef',
#   'salt',
#   'hot chili pepper',
#   'onion',
#   'whole kernel corn',
#   'cornmeal',
#   'tabasco sauce',
#   'cheddar cheese',
#   'tomato sauce',
#   'black pepper'],
#  ['butter', 'dry ranch dressing mix', 'french bread'],
#  ['non-fat powdered milk',
#   'worcestershire sauce',
#   'egg substitute',
#   'ground venison',
#   'salt',
#   'onion',
#   'fresh breadcrumb',
#   'water',
#   'dry mustard',
#   'black pepper'],
#  ['milk', 'plain yogurt', 'frozen juice concentrate'],
#  ['zucchini',
#   'carrot',
#   'wax beans',
#   'potato',
#   'diced tomatoes',
#   'green beans',
#   'low sodium chicken broth',
#   'corn'],
#  ['condensed cream of mushroom soup',
#   'sharp cheddar cheese',
#   'egg',
#   'salt',
#   'frozen chopped spinach',
#   'onion',
#   'crouton',
#   'black pepper'],
#  ['white wine vinegar',
#   'fat-free mayonnaise',
#   'garlic',
#   'prepared mustard',
#   'salt',
#   'celery seed',
#   'diced pimentos',
#   'low-fat sour cream',
#   'green onion',
#   'black pepper',
#   'sugar',
#   'red potatoes',
#   'plain low-fat yogurt'],
#  ['garlic powder',
#   'egg',
#   'frozen chopped spinach',
#   'onion',
#   'sage',
#   'soft breadcrumbs',
#   'margarine',
#   'oregano'],
#  ['cream of mushroom soup',
#   'ground beef',
#   'condensed cream of mushroom & garlic soup',
#   'frozen vegetables',
#   'cornbread mix',
#   'onion',
#   'cooking oil',
#   'salt & pepper'],
#  ['garlic',
#   'angel hair pasta',
#   'toasted sesame seeds',
#   'green onions',
#   'soy sauce',
#   'toasted sesame oil',
#   'stir fry vegetables',
#   'honey'],
#  ['salt',
#   'baking soda',
#   'orange rind',
#   'unsweetened cocoa',
#   'sugar',
#   'brown sugar',
#   'egg',
#   'ground cinnamon',
#   'low-fat buttermilk',
#   'ground cloves',
#   'pecans',
#   'canola oil',
#   'orange juice',
#   'baking powder',
#   'flour',
#   'buckwheat flour',
#   'yam',
#   'butter',
#   'honey',
#   'cinnamon'],
#  ['flour',
#   'granulated sugar',
#   'buckwheat flour',
#   'baking powder',
#   'boiling water',
#   'egg',
#   'yam',
#   'salt',
#   'ground cinnamon',
#   'low-fat buttermilk',
#   'baking soda',
#   'ground cloves',
#   'unsweetened cocoa',
#   'orange rind',
#   'canola oil',
#   'raisins',
#   'orange juice',
#   'sorghum'],
#  ['cayenne',
#   'american cheese',
#   'prepared yellow mustard',
#   'garlic',
#   'beer',
#   'ground beef',
#   'sugar',
#   'salt & pepper'],
#  ['tri-color spiral pasta',
#   'cheese',
#   'garlic powder',
#   'italian seasoning',
#   'chives',
#   'ripe olives',
#   'tomato',
#   'green onion',
#   'dill pickles',
#   'cider vinegar',
#   'onion powder',
#   'ham',
#   'salt and pepper',
#   'water chestnut',
#   'sweet pepper',
#   'olive oil'],
#  ['flat leaf parsley',
#   'oil',
#   'basil',
#   'frozen french fries',
#   'oregano',
#   'parmesan cheese',
#   'salt & freshly ground black pepper'],
#  ['good seasonings italian salad dressing mix',
#   'swiss cheese',
#   'mozzarella cheese',
#   'butter',
#   'deli turkey',
#   'ham',
#   'sandwich bun',
#   'cheddar cheese',
#   'pepperoni'],
#  ['icing sugar',
#   'flour',
#   'egg',
#   'milk',
#   'shortening',
#   'salt',
#   'butter',
#   'sugar',
#   'vanilla',
#   'baking powder'],
#  ['carrot',
#   'crushed pineapple',
#   'egg',
#   'oil',
#   'nutmeg',
#   'vanilla instant pudding mix',
#   'pecans',
#   'yellow cake mix',
#   'water',
#   'cinnamon',
#   'coconut'],
#  ['sharp cheddar cheese',
#   'red bell pepper',
#   'egg',
#   'onion',
#   'jiffy corn muffin mix',
#   'heavy cream',
#   'butter',
#   'jalapenos',
#   'honey',
#   'whole kernel corn'],
#  ['brown sugar',
#   'flour',
#   'nuts',
#   'crushed pineapple',
#   'egg',
#   'milk',
#   'salt',
#   'baking soda',
#   'butter',
#   'raisins',
#   'water',
#   'vegetable oil',
#   'sugar',
#   'cinnamon',
#   'vanilla',
#   'baking powder',
#   'dry yeast'],
#  ['tomato paste',
#   'garlic',
#   'ground beef',
#   'dried basil',
#   'cottage cheese',
#   'egg',
#   'salt',
#   'mozzarella cheese',
#   'ground black pepper',
#   'italian sausage',
#   'whole tomato',
#   'parmesan cheese',
#   'lasagna noodle',
#   'ricotta cheese',
#   'parsley flakes'],
#  ['cheese',
#   'herbs',
#   'olive oil flavored cooking spray',
#   'egg',
#   'cottage cheese',
#   'salt',
#   'frozen chopped spinach',
#   'beef',
#   'black pepper',
#   'toasted wheat germ',
#   'spices'],
#  ['brown sugar',
#   'instant vanilla pudding',
#   'butter',
#   'raisins',
#   'rolls',
#   'cinnamon'],
#  ['granulated sugar',
#   'garlic',
#   'prego spaghetti sauce',
#   'stewed tomatoes',
#   'white onion',
#   'ground beef'],
#  ['brown sugar',
#   'dried dill weed',
#   'spicy mustard',
#   'fresh garlic',
#   'hot sauce',
#   'ketchup',
#   'fresh parsley',
#   'honey',
#   'beef steaks',
#   'sour cream',
#   'vegetable oil',
#   'fresh lemon juice'],
#  ['flour', 'egg', 'milk', 'salt', 'butter', 'sugar', 'baking powder'],
#  ['garlic',
#   'fresh ground black pepper',
#   'dried basil',
#   'dried oregano',
#   'button mushrooms',
#   'tomato',
#   'onion',
#   'fresh parsley',
#   'parmesan cheese',
#   'water',
#   'hot sauce',
#   'pasta',
#   'salsa',
#   'olive oil',
#   'chicken breasts'],
#  ['fresh herbs', 'fresh herb', 'cider vinegar'],
#  ['flour',
#   'egg',
#   'salt',
#   'cream',
#   'fresh corn',
#   'fat',
#   'black pepper',
#   'baking powder'],
#  ['milk',
#   'black olives',
#   'fettuccine pasta',
#   'picante sauce',
#   'jalapeno',
#   'cheddar cheese soup'],
#  ['frozen peas',
#   'lemons, juice of',
#   'salt',
#   'tomato',
#   'onion',
#   'cilantro',
#   'hass avocado'],
#  ['worcestershire sauce',
#   'garlic powder',
#   'oil',
#   'basil',
#   'soy sauce',
#   'black pepper',
#   'lemon juice'],
#  ['apple', 'milk', 'cream cheese', 'unflavored gelatin', 'yogurt', 'pear'],
#  ['carrot',
#   'bay leaf',
#   'oil',
#   'salt',
#   'onion',
#   'veal roast',
#   'butter',
#   'bacon',
#   'black pepper',
#   'thyme',
#   'parsley sprigs'],
#  ['mayonnaise', 'black pepper', 'tomato', 'crackers'],
#  ['garlic',
#   'carrot',
#   'sweet onion',
#   'brine',
#   'ciabatta',
#   'genoa salami',
#   'tomato',
#   'red wine vinegar',
#   'provolone cheese',
#   'green olives',
#   'fresh parsley',
#   'ham',
#   'kalamata olive',
#   'capers',
#   'fresh basil',
#   'oregano leaves',
#   'olive oil'],
#  ['powdered sugar',
#   'vanilla',
#   'whipping cream',
#   'vanilla instant pudding mix'],
#  ['miniature semisweet chocolate chips',
#   'milk',
#   'cream cheese',
#   'prepared graham cracker crusts',
#   'gelatin',
#   'cookie',
#   'sugar',
#   'vanilla'],
#  ['zucchini',
#   'celery',
#   'salt',
#   'chili powder',
#   'soy sauce',
#   'vegetable shortening',
#   'water',
#   'cloves',
#   'monterey jack cheese',
#   'ground cumin',
#   'green pepper',
#   'oregano',
#   'egg',
#   'sliced mushrooms',
#   'tomato',
#   'baking powder',
#   'flour',
#   'carrot',
#   'onion',
#   'butter',
#   'cayenne pepper'],
#  ['sweet butter', 'salt and pepper', 'half-and-half', 'sweet corn'],
#  ['flour',
#   'egg',
#   'salt',
#   'baking soda',
#   'butter',
#   'yogurt',
#   'sugar',
#   'vanilla',
#   'lemon, rind of'],
#  ['flour',
#   'nuts',
#   'egg',
#   'butter',
#   'sugar',
#   'vanilla',
#   'unsweetened chocolate squares'],
#  ['green onions',
#   'fresh cilantro',
#   'reduced sodium soy sauce',
#   'vermicelli',
#   'broccoli',
#   'cooked chicken',
#   'sesame seeds',
#   'rice vinegar',
#   'chili-garlic sauce',
#   'vegetable oil',
#   'fresh ginger',
#   'sesame oil'],
#  ['celery',
#   'apples',
#   'philadelphia cream cheese',
#   'orange rind',
#   'pecans',
#   'sugar',
#   'orange juice'],
#  ['cayenne',
#   'garlic',
#   'salt',
#   'fresh ground pepper',
#   'paprika',
#   'olive oil',
#   'cumin',
#   'thyme',
#   'lemon juice',
#   'boneless chicken breast'],
#  ['garlic powder',
#   'baking potato',
#   'mozzarella cheese',
#   'part-skim ricotta cheese',
#   'parmesan cheese',
#   'oregano leaves',
#   'tomato sauce'],
#  ['cornstarch',
#   'tomato puree',
#   'white wine',
#   'onion',
#   'mushroom pieces',
#   'tabasco sauce',
#   'sodium-free vegetable broth',
#   'black pepper'],
#  ['light olive oil',
#   'bibb lettuce',
#   'garlic',
#   'red sweet bell peppers',
#   'salt',
#   'scallions',
#   'red wine vinegar',
#   'albacore tuna in water',
#   'fresh basil',
#   'black pepper',
#   'white kidney beans'],
#  ['garlic',
#   'crushed tomatoes',
#   'celery',
#   'salt',
#   'red pepper flakes',
#   'dry white wine',
#   'penne pasta',
#   'beef consomme',
#   'nutmeg',
#   'rubbed sage',
#   'oregano',
#   'ground pork',
#   'black pepper',
#   'olive oil',
#   'milk',
#   'carrot',
#   'lean ground beef',
#   'onion',
#   'butter',
#   'bacon'],
#  ['sugar substitute', 'apples', 'red cinnamon candies', 'water'],
#  ['elbow macaroni',
#   'brown sugar',
#   'celery',
#   'oil',
#   'green pepper',
#   'tomato',
#   'onion',
#   'ketchup',
#   'cucumber',
#   'lemon juice'],
#  ['brown sugar',
#   'flour',
#   'milk',
#   'salt',
#   'hot water',
#   'vegetable oil',
#   'sugar',
#   'vanilla',
#   'baking powder',
#   'cocoa'],
#  ['flour',
#   'egg',
#   'milk',
#   'powdered sugar',
#   'salt',
#   'apple pie filling',
#   'toasted almonds',
#   'butter'],
#  ['mayonnaise', 'white bread', 'bananas'],
#  ['flour',
#   'garlic powder',
#   'lean ground beef',
#   'fresh ground black pepper',
#   'dried oregano',
#   'milk',
#   'salt',
#   'dried thyme',
#   'poultry seasoning',
#   'onion',
#   'breadcrumbs',
#   'chicken stock',
#   'boneless skinless chicken thighs',
#   'vegetable oil',
#   'dry white wine'],
#  ['salmon', 'cream cheese', 'salt', 'onion', 'lemon juice', 'liquid smoke'],
#  ['garlic',
#   'soy sauce',
#   'ground cayenne pepper',
#   'water',
#   'brown sugar',
#   'ground cumin',
#   'ginger',
#   'red chili pepper',
#   'desiccated coconut',
#   'sambal oelek',
#   'peanut oil',
#   'vegetable stock',
#   'tomato',
#   'bean sprouts',
#   'carrot',
#   'ground coriander',
#   'peanuts',
#   'onion',
#   'green beans',
#   'tempeh'],
#  ['ground beef',
#   'egg',
#   'onion',
#   'dried breadcrumbs',
#   'water',
#   'salt and pepper',
#   'sugar',
#   'lemon juice',
#   'tomato soup'],
#  ['soft silken tofu',
#   'fresh cilantro',
#   'chunky salsa',
#   'avocado',
#   'lime juice',
#   'hot sauce',
#   'salt and pepper'],
#  ['flour',
#   'bananas',
#   'egg',
#   'salt',
#   'nutmeg',
#   'baking soda',
#   'ground cloves',
#   'walnuts',
#   'white sugar',
#   'cinnamon',
#   'shortening'],
#  ['boneless skinless chicken breast',
#   'dried basil',
#   'tomato',
#   'lime juice',
#   'salt and pepper',
#   'olive oil'],
#  ['worcestershire sauce',
#   'brown sugar',
#   'salt',
#   'onion',
#   'ketchup',
#   'beef ribs',
#   'water',
#   'vegetable oil',
#   'mustard',
#   'fresh lemon juice'],
#  ['sugar', 'green grape', 'egg whites'],
#  ['betty crocker fudge brownie mix',
#   'egg',
#   'milk chocolate candy bars',
#   'water',
#   'vegetable oil'],
#  ['flour',
#   'nuts',
#   'bananas',
#   'egg',
#   'salt',
#   'chocolate chips',
#   'baking soda',
#   'butter',
#   'water',
#   'sugar',
#   'baking powder'],
#  ['brown sugar',
#   'flour',
#   'sweetened condensed milk',
#   'egg',
#   'cream cheese',
#   'chocolate chips',
#   'butter',
#   'oreo cookie crumbs',
#   'sour cream',
#   'vanilla'],
#  ['banana',
#   '2% low-fat milk',
#   'natural-style peanut butter',
#   'sugar-free non-fat vanilla yogurt'],
#  ['taco seasoning',
#   'cream cheese',
#   'cheddar cheese',
#   'sour cream',
#   'bean dip'],
#  ['ground sirloin',
#   'american cheese',
#   'no-salt-added ketchup',
#   'tomato',
#   'onion',
#   'bacon',
#   'dill weed',
#   "mccormick's montreal brand steak seasoning",
#   'iceberg lettuce'],
#  ['salt',
#   'chat masala',
#   'potato',
#   'cucumber',
#   'chopped tomato',
#   'plain yogurt',
#   'paprika'],
#  ['brown sugar',
#   'carrot',
#   'buttermilk',
#   'natural bran',
#   'egg',
#   'whole wheat flour',
#   'salt',
#   'baking soda',
#   'raisins',
#   'corn oil',
#   'cinnamon',
#   'vanilla'],
#  ['lime juice',
#   'tequila',
#   'lime wedge',
#   'limeade',
#   'triple sec',
#   'grand marnier'],
#  ['brown sugar', 'flour', 'semi-sweet chocolate chips', 'pecans', 'butter'],
#  ['garlic',
#   'cappelletti pasta',
#   'milk',
#   'salt',
#   'onion',
#   'butter',
#   'mushrooms',
#   'chopped tomato',
#   'ground beef',
#   'black pepper',
#   'cheddar cheese',
#   'tomato soup',
#   'corn'],
#  ['squid',
#   'garlic',
#   'spaghetti',
#   'extra virgin olive oil',
#   'hot water',
#   'salt and pepper',
#   'parsley',
#   'dry white wine',
#   'tomato sauce'],
#  ['flour',
#   'vegetable oil',
#   'salt',
#   'baking soda',
#   'water',
#   'vinegar',
#   'sugar',
#   'vanilla',
#   'cocoa'],
#  ['applesauce', 'clove', 'brown sugar', 'pork loin chops'],
#  ['whole wheat bread dough',
#   'roast beef',
#   'honey mustard',
#   'swiss cheese',
#   'turkey',
#   'cream cheese',
#   'leaf lettuce',
#   'mayonnaise',
#   'radish sprouts',
#   'provolone cheese',
#   'butter',
#   'green olives',
#   'ham',
#   'roasted red peppers',
#   'prepared horseradish',
#   'cheddar cheese'],
#  ['flour',
#   'beef broth',
#   'lemon, juice of',
#   'fresh dill',
#   'onion',
#   'butter',
#   'wild mushrooms',
#   'sour cream',
#   'water',
#   'salt and pepper'],
#  ['carrot',
#   'garlic',
#   'green onions',
#   'fresh cilantro',
#   'asian chili sauce',
#   'rice wine vinegar',
#   'honey',
#   'bean sprouts',
#   'english cucumber',
#   'light soy sauce',
#   'fresh ginger',
#   'sesame oil',
#   'rice noodles'],
#  ['flour',
#   'granulated sugar',
#   'kosher salt',
#   'egg',
#   'unsweetened cocoa powder',
#   'bittersweet chocolate',
#   'brewed espresso',
#   'unsalted butter',
#   'vanilla'],
#  ['brown sugar', 'orange marmalade', 'dr. pepper cola'],
#  ['peanut oil',
#   'white pepper',
#   'fish',
#   'salt',
#   'scallions',
#   'low sodium soy sauce',
#   'gingerroot',
#   'rice wine',
#   'sesame oil'],
#  ['flour',
#   'garlic',
#   'swiss cheese',
#   'beef broth',
#   'low sodium beef broth',
#   'french bread',
#   'butter',
#   'parmesan cheese',
#   'sherry wine',
#   'sugar',
#   'yellow onions',
#   'romano cheese',
#   'olive oil'],
#  ['brown sugar',
#   'flour',
#   'egg',
#   'whole wheat flour',
#   'salt',
#   'chocolate chips',
#   'baking soda',
#   'margarine',
#   'water',
#   'white sugar',
#   'vanilla'],
#  ['egg',
#   'squash',
#   'onion',
#   'sage',
#   'butter',
#   'cream of chicken soup',
#   'cornbread'],
#  ['garlic powder',
#   'dried basil',
#   'dried oregano',
#   'salt',
#   'bottled garlic',
#   'white onion',
#   'dried parsley',
#   'italian sausage',
#   'bay leaves',
#   'tomato sauce',
#   'olive oil',
#   'black pepper',
#   'sugar',
#   'paprika'],
#  ['garlic powder',
#   'sharp cheddar cheese',
#   'milk',
#   'salt',
#   'frozen broccoli cuts',
#   'soy sauce',
#   'ground black pepper',
#   'cream of chicken soup',
#   'french-fried onions'],
#  ['flour',
#   'egg',
#   'whole milk',
#   'pure vanilla extract',
#   'butter',
#   'almond extract',
#   'sugar'],
#  ['egg',
#   'artichoke hearts',
#   'oil',
#   'fresh garlic',
#   'unseasoned breadcrumbs',
#   'unsalted butter'],
#  ['worcestershire sauce',
#   'hot red pepper sauce',
#   'chicken',
#   'salt',
#   'chili powder',
#   'cider vinegar',
#   'black pepper',
#   'barbecue sauce'],
#  ['cream cheese',
#   'frozen broccoli',
#   'dry onion soup mix',
#   'water chestnuts',
#   'sour cream',
#   'cheddar cheese',
#   'ritz cracker crumbs'],
#  ['cocoa powder',
#   'cool whip',
#   'flour',
#   'milk',
#   'salt',
#   'instant chocolate pudding mix',
#   'baking soda',
#   'mayonnaise',
#   'water',
#   'sugar',
#   'vanilla'],
#  ['lean chuck',
#   'flour',
#   'budweiser beer',
#   'garlic',
#   'hunts tomato sauce',
#   'lean pork',
#   'chili powder',
#   'onion',
#   'bouillon',
#   'coriander',
#   'louisiana hot sauce',
#   'unsweetened cocoa',
#   'water',
#   'cornmeal',
#   'cumin',
#   'sugar',
#   'oregano leaves',
#   'paprika'],
#  ['white pepper',
#   'kosher salt',
#   'simply potatoes shredded hash browns',
#   'red bell pepper',
#   'egg',
#   'goat cheese',
#   'fresh garlic',
#   'unsmoked bacon',
#   'baby spinach',
#   'meatloaf mixture',
#   'yellow onion',
#   'unsalted butter',
#   'olive oil'],
#  ['egg',
#   'milk',
#   'ground cinnamon',
#   'dark brown sugar',
#   'salt',
#   'nutmeg',
#   'heavy cream',
#   'ground cloves',
#   'pie crusts',
#   'pumpkin puree',
#   'egg white',
#   'ground ginger'],
#  ['flour',
#   'milk',
#   'salt',
#   'celery seed',
#   'poultry seasoning',
#   'onion',
#   'breadcrumbs',
#   'paprika',
#   'cream of chicken soup',
#   'butter',
#   'poppy seed',
#   'sour cream',
#   'vegetable oil',
#   'dry onion flakes',
#   'beef',
#   'baking powder'],
#  ['brown sugar',
#   'nuts',
#   'flour',
#   'semi-sweet chocolate chips',
#   'egg',
#   'blended oatmeal',
#   'hershey chocolate candy bars',
#   'baking soda',
#   'butter',
#   'sugar',
#   'vanilla',
#   'baking powder'],
#  ['brown sugar',
#   'nuts',
#   'flour',
#   'egg',
#   'oatmeal',
#   'salt',
#   'chocolate chips',
#   'baking soda',
#   'butter',
#   'white sugar',
#   "hershey's semi-sweet baking chocolate",
#   'vanilla',
#   'baking powder'],
#  ['flour', 'granulated sugar', 'milk', 'butter', 'vanilla'],
#  ['taco seasoning',
#   'taco shells',
#   'corn cobs',
#   'tomato',
#   'lettuce',
#   'onion',
#   'ground beef',
#   'salsa',
#   'cheddar cheese'],
#  ['stewing pork',
#   'garlic',
#   'salt',
#   'tortilla chips',
#   'dark chocolate chips',
#   'cumin',
#   'habanero pepper',
#   'tomato paste',
#   'stewing beef',
#   'light brown sugar',
#   'black pepper',
#   'beans',
#   'beef bouillon cube',
#   'sazon goya',
#   'mexican chili powder',
#   'beef broth',
#   'chicken bouillon cube',
#   'ground coriander',
#   'chunky salsa',
#   'white onion',
#   'cinnamon',
#   'bell peppers'],
#  ['lemon zest',
#   'orange-flavored liqueur',
#   'brown sugar',
#   'flour',
#   'egg',
#   'cream cheese',
#   'powdered sugar',
#   'pitted dates',
#   'salt',
#   'tequila',
#   'baking soda',
#   'pecans',
#   'butter',
#   'warm water',
#   'triple sec',
#   'lime zest',
#   'shortening'],
#  ['bouillon cubes',
#   'carrot',
#   'celery',
#   'milk',
#   'cream of celery soup',
#   'onion',
#   'potato',
#   'cream of chicken soup',
#   'butter',
#   'water',
#   'potato flakes'],
#  ['flour',
#   'egg',
#   'milk',
#   'salt',
#   'cream',
#   'lemon, juice of',
#   'apples',
#   'butter',
#   'sugar',
#   'cinnamon'],
#  ['macaroni',
#   'cheese',
#   'garlic',
#   'milk',
#   'salt',
#   'onion',
#   'butter',
#   'fresh coarse ground black pepper'],
#  ['salt water',
#   'cheese',
#   'macaroni',
#   'fine semolina',
#   'onion',
#   'heavy cream',
#   'potato',
#   'unsalted butter',
#   'black pepper',
#   'muscat wine'],
#  ['cheese',
#   'penne pasta',
#   'milk',
#   'onion',
#   'potato',
#   'applesauce',
#   'butter',
#   'salt and pepper'],
#  ['dried yellow peas', 'salt', 'ginger', 'pork', 'water'],
#  ['ham bone',
#   'carrot',
#   'dried yellow peas',
#   'salt',
#   'dried thyme',
#   'onion',
#   'clove',
#   'brown mustard',
#   'water',
#   'black pepper',
#   'ground ginger'],
#  ['butter', 'nutmeg', 'fresh spinach', 'water'],
#  ['tomato paste',
#   'cornstarch',
#   'granulated sugar',
#   'garlic powder',
#   'ground beef',
#   'dried onion flakes',
#   'salt',
#   'wondra flour',
#   'chili powder',
#   'white vinegar',
#   'ground black pepper',
#   'water',
#   'ground pork',
#   'paprika'],
#  ['cayenne',
#   'tomato ketchup',
#   'dark brown sugar',
#   'salt',
#   'applesauce',
#   'granulated garlic',
#   'oregano',
#   'ponzu sauce',
#   'maple syrup',
#   'apple cider vinegar',
#   'liquid smoke'],
#  ['flour',
#   'egg',
#   'salt',
#   'baking soda',
#   'butter',
#   'sour cream',
#   'sugar',
#   'vanilla',
#   'baking powder'],
#  ['vanilla ice cream', 'butter', 'oreo cookies', 'frozen whipped topping'],
#  ['white bread', 'butter', 'processed cheese'],
#  ['worcestershire sauce',
#   'garlic',
#   'fresh ground black pepper',
#   'soy sauce',
#   'london broil beef',
#   'olive oil',
#   'balsamic vinegar',
#   'rosemary'],
#  ['teriyaki sauce',
#   'cornstarch',
#   'garlic',
#   'salt and black pepper',
#   'dried oregano',
#   'dried thyme',
#   'dried rosemary',
#   'fresh mushrooms',
#   'dry sherry',
#   'nonfat milk',
#   'nonfat dry milk powder',
#   'margarine',
#   'chicken broth',
#   'parmesan cheese',
#   'hot pepper sauce',
#   'spicy brown mustard'],
#  ['splenda sugar substitute',
#   'egg',
#   'cream cheese',
#   'nutmeg',
#   'butter',
#   'vanilla protein powder',
#   'sour cream',
#   'almonds',
#   'cinnamon',
#   'vanilla'],
#  ['real maple syrup', 'refrigerated buttermilk biscuits', 'bacon', 'butter'],
#  ['velveeta cheese',
#   'worcestershire sauce',
#   'horseradish',
#   'mayonnaise',
#   'tabasco sauce'],
#  ['red wine vinegar', 'lemon juice', 'water'],
#  ['ground flax seeds',
#   'berries',
#   'sugar-free syrup',
#   "i can't believe it's not butter spread",
#   'water',
#   'old fashioned oats'],
#  ['flour',
#   'nuts',
#   'egg',
#   'milk',
#   'cream cheese',
#   'salt',
#   'frozen blueberries',
#   'powdered sugar',
#   'french bread',
#   'blueberries',
#   'sugar',
#   'vanilla',
#   'maple syrup'],
#  ['velveeta cheese',
#   'white pepper',
#   'celery',
#   'chives',
#   'salt',
#   'onion',
#   'bacon',
#   'chicken broth',
#   'sour cream',
#   'red potatoes',
#   'cheddar cheese',
#   'liquid smoke'],
#  ['brown sugar',
#   'flour',
#   'granulated sugar',
#   'egg',
#   'milk',
#   'cream cheese',
#   'salt',
#   'powdered sugar',
#   'active dry yeast',
#   'butter',
#   'vanilla pudding mix',
#   'warm water',
#   'cinnamon'],
#  ['garlic',
#   'spaghetti squash',
#   'red bell pepper',
#   'italian seasoning',
#   'reduced-fat parmesan cheese',
#   'white mushroom',
#   'asparagus',
#   'part-skim mozzarella cheese',
#   'spaghetti sauce',
#   'salt and pepper'],
#  ['soft silken tofu',
#   'cornstarch',
#   'oil',
#   'coriander',
#   'frozen pineapple concentrate',
#   'graham cracker crumbs',
#   'vegan sugar',
#   'margarine',
#   'vegan cream cheese',
#   'water',
#   'vanilla',
#   'maple syrup',
#   'lemon juice'],
#  ['frozen black-eyed peas',
#   'garlic',
#   'flour',
#   'celery',
#   'creole seasoning',
#   'andouille sausage',
#   'cooked chicken',
#   'onion',
#   'vegetable oil',
#   'green bell pepper',
#   'low sodium chicken broth',
#   'large raw shrimp'],
#  ['ground beef',
#   'egg',
#   'cracker',
#   'onion',
#   'pickle',
#   'thousand island dressing',
#   'salt and pepper',
#   'cheddar cheese'],
#  ['salmon',
#   'lemon juice',
#   'white pepper',
#   'garlic',
#   'salt',
#   'cajun spices',
#   'basil',
#   'butter',
#   'parmesan cheese',
#   'heavy whipping cream',
#   'linguine',
#   'parsley',
#   'parmesan-romano cheese mix'],
#  ['egg', 'phyllo dough', 'oil', 'feta', 'milk', 'cottage cheese'],
#  ['pickled ginger',
#   'seasoned rice vinegar',
#   'white rice',
#   'avocado',
#   'lettuce',
#   'soy sauce',
#   'cucumber',
#   'imitation crabmeat'],
#  ['flour',
#   'sweetened condensed milk',
#   'egg',
#   'mincemeat',
#   'maraschino cherry',
#   'baking soda',
#   'walnuts',
#   'mixed candied fruit'],
#  ['matzo meal',
#   'kosher salt',
#   'egg',
#   'celery',
#   'oil',
#   'salt',
#   'baby carrots',
#   'white onion',
#   'chicken stock',
#   'black pepper',
#   'sugar',
#   'baking powder',
#   'chicken breasts'],
#  ['cream of mushroom soup',
#   'frozen southern style hash brown potatoes',
#   'sour cream',
#   'cheddar cheese',
#   'poppy seed'],
#  ['lean ground beef',
#   'ground coriander',
#   'fresh garlic cloves',
#   'ground sage',
#   'veggie shreds cheese',
#   'red onion',
#   'adobo seasoning',
#   'sea salt',
#   'egg',
#   'low sodium soy sauce',
#   'fresh ground pepper',
#   'ketchup',
#   'italian seasoned breadcrumbs',
#   'oregano',
#   'olive oil'],
#  ['kraft macaroni and cheese',
#   'celery',
#   'cream of celery soup',
#   'tuna',
#   'onion',
#   'butter',
#   'mushrooms',
#   'green bell pepper'],
#  ['miracle whip',
#   'garlic',
#   'tabasco sauce',
#   'salt',
#   'cider vinegar',
#   'ketchup',
#   'dry mustard',
#   'vegetable oil',
#   'black pepper',
#   'sugar',
#   'paprika'],
#  ['red ripe tomatoes',
#   'red bell pepper',
#   'seedless cucumber',
#   'water-packed artichoke hearts',
#   'red onion',
#   'italian parsley',
#   'lemon, juice of',
#   'shallot',
#   'red wine vinegar',
#   'extra virgin olive oil',
#   'tuna in vegetable oil',
#   'pepperoncini peppers',
#   'oregano',
#   'kosher salt & freshly ground black pepper',
#   'kalamata olive'],
#  ['orange roughy',
#   'buttermilk',
#   'self-rising flour',
#   'egg',
#   'ground black pepper',
#   'canola oil',
#   'seasoning salt'],
#  ['flour',
#   'garlic',
#   'egg',
#   'goat cheese',
#   'salt',
#   'simply potatoes traditional mashed potatoes',
#   'frozen spinach',
#   'bacon',
#   'green onion',
#   'egg yolk'],
#  ['flour',
#   'self-rising flour',
#   'egg',
#   'milk',
#   'ground black pepper',
#   'boneless pork chops',
#   'canola oil',
#   'seasoning salt',
#   'salt and pepper',
#   'cajun seasoning'],
#  ['ramen noodles',
#   'teriyaki marinade',
#   'stir fry vegetables',
#   'water',
#   'imitation crabmeat'],
#  ['pesto sauce',
#   'apple',
#   'red onion',
#   'small red potato',
#   'celery',
#   'salt',
#   'banana',
#   'ground red pepper',
#   'pumpkin puree',
#   'smooth cashew butter',
#   'green bell pepper',
#   'vegetable broth',
#   'fresh cilantro leaves',
#   'pumpkin seeds'],
#  ['garlic',
#   'dry-roasted cashews',
#   'nutmeg',
#   'chili powder',
#   'margarine',
#   'mushrooms',
#   'water',
#   'parsley',
#   'vegetable bouillon cubes'],
#  ['mangoes', 'vanilla bean', 'oranges', 'strawberries', 'ice cubes'],
#  ['fresh rosemary',
#   'garlic',
#   'russet potatoes',
#   'leeks',
#   'white beans',
#   'salt and pepper',
#   'vegetable broth',
#   'olive oil'],
#  ['soy yogurt',
#   'black peppercorns',
#   'garlic',
#   'cloves',
#   'ground cumin',
#   'coriander seed',
#   'cinnamon stick',
#   'boneless skinless chicken breasts',
#   'chili powder',
#   'onion',
#   'fresh coriander',
#   'cardamom pods',
#   'turmeric',
#   'chicken stock',
#   'salt & freshly ground black pepper',
#   'fresh ginger'],
#  ['worcestershire sauce',
#   'garlic',
#   'garlic powder',
#   'dried oregano',
#   'boiling water',
#   'dried thyme',
#   'salt',
#   'tabasco sauce',
#   'rump roast',
#   'beef bouillon cubes',
#   'black pepper'],
#  ['milk', 'ginger', 'tea bag', 'honey', 'water'],
#  ['ground beef', 'sausage', 'velveeta cheese', 'taco chips'],
#  ['worcestershire sauce',
#   'brown sugar',
#   'garlic powder',
#   'bell pepper',
#   'lean ground beef',
#   'onion',
#   'hamburger buns',
#   'ketchup',
#   'white vinegar',
#   'ground mustard',
#   'steak seasoning',
#   'tomato sauce'],
#  ['garlic',
#   'carrot',
#   'green peppers',
#   'green onions',
#   'salad greens',
#   'salt',
#   'fresh corn kernels',
#   'soy sauce',
#   'gingerroot',
#   'rice wine vinegar',
#   'honey',
#   'white mushrooms',
#   'salad seasoning',
#   'black pepper',
#   'beets',
#   'safflower oil'],
#  ['pork chops',
#   'onion',
#   'fennel seeds',
#   'chicken broth',
#   'olive oil',
#   'dry white wine',
#   'paprika',
#   'fresh lemon juice'],
#  ['ramen noodles',
#   'garlic powder',
#   'red bell pepper',
#   'italian seasoning',
#   'egg',
#   'roma tomato',
#   'black olives',
#   'mozzarella cheese',
#   'pepperoni'],
#  ['brown sugar',
#   'flour',
#   'natural bran',
#   'egg',
#   'milk',
#   'oil',
#   'salt',
#   'molasses',
#   'sesame seeds',
#   'baking soda',
#   'sunflower seeds',
#   'raisins',
#   'baking powder'],
#  ['brown sugar',
#   'black tea leaves',
#   'garlic',
#   'broiler',
#   'dry sherry',
#   'low sodium soy sauce',
#   'peppercorn',
#   'onion',
#   'minced ginger',
#   'orange zest',
#   'orange, juice of'],
#  ['peanut oil',
#   'yoghurt',
#   'fruit vinegar',
#   'kaffir lime leaves',
#   'coriander seed',
#   'cardamom pods',
#   'turmeric',
#   'gingerroot',
#   'cloves',
#   'star anise',
#   'lemongrass'],
#  ['cool whip',
#   'vanilla pudding mix',
#   'graham wafers',
#   'blueberry pie filling'],
#  ['tomato paste',
#   'cornstarch',
#   'garlic powder',
#   'dried onion flakes',
#   'salt',
#   'chili powder',
#   'vinegar',
#   'onion powder',
#   'canned jalapeno slices',
#   'water',
#   'cayenne pepper',
#   'sugar'],
#  ['brown sugar',
#   'nuts',
#   'cake flour',
#   'egg',
#   'salt',
#   'vanilla',
#   'baking soda',
#   'butter',
#   'raisins',
#   'corn flakes',
#   'quick-cooking oats',
#   'baking powder',
#   'shredded coconut'],
#  ['kosher salt',
#   'onion',
#   'italian spices',
#   'butter',
#   'olive oil',
#   'black pepper',
#   'whole turkey'],
#  ['corn chips',
#   'onion',
#   'chili with beans',
#   'sour cream',
#   'salsa',
#   'cheddar cheese'],
#  ['egg',
#   'salt',
#   'plain breadcrumbs',
#   'cauliflower florets',
#   'vegetable oil',
#   'black pepper',
#   'parsley sprig'],
#  ['mixed herbs',
#   'kosher salt',
#   'fresh green beans',
#   'onion',
#   'ground black pepper',
#   'butter',
#   'walnuts',
#   'olive oil'],
#  ['american cheese',
#   'hamburger buns',
#   'ketchup',
#   'ham',
#   'sweet pickle relish'],
#  ['sugar', 'carrot', 'bacon', 'tomato soup'],
#  ['brown sugar',
#   'seasoned bread crumbs',
#   'egg',
#   'ketchup',
#   'ground beef',
#   'lipton onion soup mix'],
#  ['velveeta cheese',
#   'worcestershire sauce',
#   'ground pepper',
#   'garlic powder',
#   'bulk pork sausage',
#   'rye cocktail bread',
#   'oregano',
#   'ground chuck'],
#  ['brown sugar',
#   'caster sugar',
#   'egg',
#   'milk',
#   'glace cherries',
#   'butter',
#   'pineapple in syrup',
#   'self-raising flour',
#   'vanilla essence'],
#  ['oat bran',
#   'apple',
#   'banana',
#   'honey',
#   'coconut milk',
#   'greens',
#   'water',
#   'flax seed oil'],
#  ['knorr vegetable soup mix',
#   'water chestnuts',
#   'hawaiian bread',
#   'sour cream',
#   'green onion',
#   "hellmann's mayonnaise"],
#  ['carrot',
#   'egg',
#   'brown rice',
#   'sliced mushrooms',
#   'soy sauce',
#   'broccoli floret',
#   'peas',
#   'olive oil'],
#  ['splenda sugar substitute',
#   'reduced fat graham cracker crust',
#   'egg whites',
#   'skim milk',
#   'pumpkin pie spice',
#   'pumpkin'],
#  ['biscuits', 'beef stew'],
#  ['extra-large eggs',
#   'buttermilk',
#   'creamy peanut butter',
#   'powdered sugar',
#   'salt',
#   'pure vanilla extract',
#   'unbleached all-purpose flour',
#   'baking soda',
#   'espresso',
#   'unsweetened cocoa',
#   'semisweet chocolate',
#   'heavy cream',
#   'honey roasted peanuts',
#   'unsalted butter',
#   'light corn syrup',
#   'sugar'],
#  ['fresh lime juice',
#   'garlic',
#   'corn kernel',
#   'chipotle chile in adobo',
#   'red bell pepper',
#   'ground cumin',
#   'onion',
#   'short-grain brown rice',
#   'yellow cornmeal',
#   'cilantro',
#   'lime zest',
#   'olive oil'],
#  ['flour',
#   'egg',
#   'whipped dessert topping mix',
#   'instant vanilla pudding',
#   'butter',
#   'water'],
#  ['white pepper',
#   'hard-boiled eggs',
#   'miracle whip',
#   'celery',
#   'milk',
#   'salt',
#   'fresh ground pepper',
#   'potato',
#   'white onions',
#   'dijon mustard',
#   'sugar',
#   'mustard'],
#  ['garlic powder',
#   'white rice',
#   'dried basil',
#   'tea bag',
#   'chili powder',
#   'soy sauce',
#   'butter',
#   'seasoning salt',
#   'water',
#   'cayenne pepper',
#   'black pepper',
#   'lemon juice'],
#  ['roasted red pepper',
#   'egg',
#   'milk',
#   'frozen spinach',
#   'onion',
#   'feta cheese',
#   'fresh ground pepper',
#   'oregano',
#   'kalamata olive',
#   'bisquick'],
#  ['flour',
#   'egg',
#   'oil',
#   'salt',
#   'nutmeg',
#   'baking soda',
#   'ground cloves',
#   'pecans',
#   'pumpkin',
#   'water',
#   'sugar',
#   'cinnamon',
#   'baking powder',
#   'allspice'],
#  ['long-grain rice',
#   'dry onion soup mix',
#   'boneless pork chops',
#   'water',
#   'vegetable oil',
#   'black pepper'],
#  ['garlic',
#   'crushed tomatoes',
#   'chili powder',
#   'sage',
#   'habanero pepper',
#   'brown sugar',
#   'onion flakes',
#   'chives',
#   'rum',
#   'ginger',
#   'nutmeg',
#   'lime juice',
#   'jamaican jerk spice',
#   'olive oil',
#   'black pepper',
#   'allspice',
#   'red peppers',
#   'boneless skinless chicken breasts',
#   'cayenne',
#   'onion',
#   'clove',
#   'cinnamon',
#   'thyme'],
#  ['ice', 'mango', 'lime sorbet', 'strawberry', 'frozen limeade concentrate'],
#  ['apple juice',
#   'ice',
#   'non-fat vanilla frozen yogurt',
#   'banana',
#   'strawberry'],
#  ['yoghurt',
#   'garlic',
#   'fruit vinegar',
#   'red chile',
#   'coriander seed',
#   'hoisin sauce',
#   'fish sauce',
#   'cumin',
#   'sesame oil'],
#  ['peppermint extract',
#   'flour',
#   'candy cane',
#   'egg',
#   'unsweetened cocoa powder',
#   'salt',
#   'butter',
#   'peppermint oreos',
#   'unsweetened chocolate',
#   'sugar',
#   'vanilla'],
#  ['cooked rice',
#   'celery',
#   'pineapple tidbits',
#   'salt',
#   'green grapes',
#   'mandarin oranges',
#   'white vinegar',
#   'mayonnaise',
#   'canola oil',
#   'cooked chicken breasts',
#   'orange juice',
#   'slivered almonds'],
#  ['hard-boiled eggs',
#   'frozen peas',
#   'celery',
#   'onion',
#   'mayonnaise',
#   'seasoning salt',
#   'sweet pickle relish',
#   'sugar',
#   'cheddar cheese',
#   'mustard'],
#  ['dry breadcrumbs',
#   'flour',
#   'dijon mustard',
#   'garlic powder',
#   'buttermilk',
#   'oil',
#   'dried thyme',
#   'fresh garlic',
#   'onion',
#   'butter',
#   'seasoning salt',
#   'parmesan cheese',
#   'cayenne pepper',
#   'black pepper',
#   'hot pepper sauce',
#   'chicken pieces',
#   'paprika'],
#  ['sugar',
#   'fresh garlic',
#   'pork baby back ribs',
#   'ketchup',
#   'louisiana hot sauce',
#   'habanero sauce',
#   'hoisin sauce',
#   'seasoning salt',
#   'black pepper',
#   'cinnamon',
#   'lemon juice',
#   'allspice'],
#  ['carrot',
#   'garlic',
#   'red bell pepper',
#   'italian seasoning',
#   'celery',
#   'chicken leg',
#   'salt',
#   'onion',
#   'rotini pasta',
#   'spaghetti sauce',
#   'peas',
#   'black pepper',
#   'beef stock',
#   'corn'],
#  ['stove top stuffing mix monterey style with mushroom and onion',
#   'mexicorn whole kernel corn',
#   'margarine',
#   'spinach dip',
#   'sour cream',
#   'salt and pepper',
#   'aluminum foil',
#   'pam cooking spray'],
#  ['white vinegar', 'pickling spices', 'cooking onions'],
#  ['carrot',
#   'egg',
#   'cooked chicken',
#   'soy sauce',
#   'peas',
#   'chicken broth',
#   'cooked pasta'],
#  ['cream cheese', 'cake crumbs', 'cool whip', 'mixed fruit'],
#  ['cool whip',
#   'pie crust',
#   'flour',
#   'squash',
#   'egg',
#   'coconut flavoring',
#   'butter',
#   'lemon flavoring',
#   'sugar'],
#  ['garlic powder',
#   'cream of mushroom soup',
#   'dried onion flakes',
#   'ground cinnamon',
#   'salt',
#   'ground veal',
#   'dried parsley flakes',
#   'ground cloves',
#   'dijon mustard',
#   'black pepper'],
#  ['garlic',
#   'lemon',
#   'okra',
#   'red onions',
#   'chicken stock',
#   'old bay seasoning',
#   'mexican-style stewed tomatoes with jalapeno peppers',
#   'parsley',
#   'seafood',
#   'oregano',
#   'catfish nuggets',
#   'olive oil',
#   'tabasco sauce',
#   'black pepper',
#   'small shrimp',
#   'gumbo file',
#   'brown rice',
#   'red wine vinegar',
#   'tomato soup'],
#  ['egg',
#   'fresh chives',
#   'white vinegar',
#   'bacon',
#   'sour cream',
#   'mild cheddar cheese',
#   'paprika'],
#  ['garlic',
#   'cracked black pepper',
#   'dried oregano',
#   'dried basil',
#   'salt',
#   'dried parsley',
#   'white vinegar',
#   'sandwich buns',
#   'garlic salt',
#   'olive oil',
#   'lemon juice',
#   'chicken breasts'],
#  ['brown sugar',
#   'nuts',
#   'flour',
#   'boiling water',
#   'quick oats',
#   'egg',
#   'salt',
#   'cream',
#   'nutmeg',
#   'baking soda',
#   'margarine',
#   'cinnamon',
#   'vanilla',
#   'shredded coconut'],
#  ['marshmallows', 'butter', 'rice krispies'],
#  ['cream cheese',
#   'orange juice',
#   'cool whip topping',
#   'frozen limeade concentrate'],
#  ['garlic',
#   'corn chips',
#   'salt',
#   'tomato',
#   'avocado',
#   'tuna',
#   'lettuce',
#   'pitted ripe olives',
#   'chili powder',
#   'green onion',
#   'sour cream',
#   'salad oil',
#   'tabasco sauce',
#   'sugar',
#   'cheddar cheese',
#   'lemon juice'],
#  ['garlic',
#   'ground cumin',
#   'chickpeas',
#   'coriander',
#   'fresh coriander',
#   'low-fat yogurt',
#   'tahini',
#   'salt & freshly ground black pepper',
#   'olive oil',
#   'baking potatoes'],
#  ['buttermilk',
#   'egg',
#   'salt',
#   'mayonnaise',
#   'yellow cornmeal',
#   'vegetable oil',
#   'sugar',
#   'baking powder'],
#  ['carrot',
#   'apple',
#   'soy sauce',
#   'rice vinegar',
#   'gingerroot',
#   'red cabbage',
#   'green cabbage',
#   'green onion',
#   'maple syrup',
#   'sesame oil'],
#  ['garlic powder',
#   'long-grain rice',
#   'turmeric',
#   'canola oil',
#   'orzo pasta',
#   'water',
#   'black pepper',
#   'chicken soup powder'],
#  ['jalapeno pepper',
#   'chicken breast',
#   'crushed tomatoes',
#   'ear of corn',
#   'fresh cilantro',
#   'avocado',
#   'white onion',
#   'celery ribs',
#   'chipotle chiles in adobo',
#   'chicken broth',
#   'salt and pepper',
#   'cumin',
#   'green bell pepper'],
#  ['italian-style tomato sauce',
#   'garlic powder',
#   'dried basil',
#   'salt',
#   'reduced-fat parmesan cheese',
#   'eggplant',
#   'egg white',
#   'fiber one cereal',
#   'black pepper',
#   'fat free mozzarella cheese'],
#  ['white rice', 'egg', 'beef gravy', 'onion', 'ground beef'],
#  ['ham bone',
#   'garlic',
#   'carrot',
#   'tomatoes and green chilies',
#   'great northern beans',
#   'salt',
#   'pinto beans',
#   'onion',
#   'black-eyed peas',
#   'navy beans',
#   'celery ribs',
#   'ham',
#   'water',
#   'black pepper',
#   'beans',
#   'ham soup base'],
#  ['garlic',
#   'red bell pepper',
#   'skinless chicken breast half',
#   'fresh dill',
#   'cider vinegar',
#   'feta cheese',
#   'light mayonnaise'],
#  ['lean ground beef',
#   'italian seasoning',
#   'mozzarella cheese',
#   'cheese ravioli',
#   'spaghetti sauce',
#   'garlic salt'],
#  ['worcestershire sauce',
#   'lemon juice',
#   'chicken pieces',
#   'orange marmalade',
#   'barbecue sauce'],
#  ['garlic powder',
#   'salt',
#   'coriander',
#   'ground black pepper',
#   'ground red pepper',
#   'onion powder',
#   'turmeric',
#   'paprika'],
#  ['cream cheese',
#   'green pepper',
#   'black olives',
#   'tomato',
#   'mexican blend cheese',
#   'lettuce',
#   'mayonnaise',
#   'sour cream',
#   'taco seasoning mix',
#   'green onion'],
#  ['worcestershire sauce',
#   'sharp cheddar cheese',
#   'green onions',
#   'minced clams',
#   'tabasco sauce',
#   'green bell peppers',
#   'paprika'],
#  ['shrimp',
#   'spaghetti squash',
#   'red bell pepper',
#   'red onion',
#   'yellow bell pepper',
#   'eggplants',
#   'oregano',
#   'olives',
#   'olive oil'],
#  ['semisweet chocolate', 'butter', "confectioners' sugar", 'heavy cream'],
#  ['frozen whipped topping',
#   'sweetened condensed milk',
#   'crushed pineapple',
#   'pecans',
#   'cherry pie filling',
#   'small marshmallow'],
#  ['green onions',
#   'oil',
#   'salt',
#   'potato',
#   'bacon',
#   'sour cream',
#   'cheddar cheese'],
#  ['boneless eye of round beef steak',
#   'plain flour',
#   'salt',
#   'mozzarella cheese',
#   'onion',
#   'canola oil',
#   'parmesan cheese',
#   'black pepper',
#   'pizza sauce'],
#  ['flour',
#   'soup mix',
#   'bacon grease',
#   'ground black pepper',
#   'oregano',
#   'seasoning salt',
#   'boneless country-style ribs',
#   "campbell's golden mushroom soup"],
#  ['flour', 'egg', 'milk', 'fruit', 'butter', 'sugar'],
#  ['ground cinnamon',
#   'baby carrots',
#   'apples',
#   'cardamom',
#   'crescent roll dough',
#   'butter',
#   'honey',
#   'sugar'],
#  ['refrigerated biscuits',
#   'italian seasoning',
#   'mozzarella cheese',
#   'garlic salt',
#   'olive oil'],
#  ['flour', 'milk', 'salt', 'active dry yeast', 'butter', 'water', 'sugar'],
#  ['flour',
#   'whipping cream',
#   'egg',
#   'cream cheese',
#   'egg yolks',
#   'salt',
#   'butter',
#   'lemon peel',
#   'egg yolk',
#   'sugar',
#   'vanilla'],
#  ['little smokies sausages',
#   'honey',
#   'chili sauce',
#   'country-style dijon mustard'],
#  ['grenadine',
#   "meyer's dark rum",
#   'pineapple juice',
#   'orgeat syrup',
#   'white rum',
#   'bacardi dark rum',
#   'orange juice',
#   'prepared sweet-and-sour mix',
#   'orange curacao'],
#  ['condensed chicken broth',
#   'pork chops',
#   'sliced mushrooms',
#   'minute white rice',
#   'onion',
#   'dried thyme leaves',
#   'red apples',
#   'balsamic vinaigrette',
#   'water'],
#  ['tomato paste',
#   'prepared mustard',
#   'fresh ground black pepper',
#   'horseradish',
#   'chili powder',
#   'reduced-calorie mayonnaise',
#   'onion',
#   'red bell peppers',
#   'plain nonfat yogurt',
#   'green bell peppers',
#   'orange juice'],
#  ['cool whip',
#   'cold water',
#   'grapes',
#   'nectarines',
#   'peach gelatin',
#   'lemon gelatin',
#   'strawberry gelatin',
#   'strawberries',
#   'orange juice'],
#  ['brown sugar',
#   'flour',
#   'garlic powder',
#   'onion flakes',
#   'dried sage',
#   'salt',
#   'poultry seasoning',
#   'fat-free evaporated milk',
#   'skim milk',
#   'lean ground turkey',
#   'cayenne pepper',
#   'black pepper',
#   'ground marjoram'],
#  ['garlic powder',
#   'sweet onion',
#   'cooking spray',
#   'red bell pepper',
#   'egg',
#   'ground black pepper',
#   'seasoning salt',
#   'ground beef',
#   'french-fried onions',
#   'barbecue sauce'],
#  ['flour',
#   'italian salad dressing',
#   'bay leaf',
#   'beef broth',
#   'crushed tomatoes',
#   'garlic',
#   'carrot',
#   'salt',
#   'green pepper',
#   'beef stew meat',
#   'beef bouillon granules',
#   'onion',
#   'potato',
#   'water',
#   'black pepper',
#   'cold water',
#   'tomato sauce'],
#  ['carrot',
#   'ghee',
#   'garlic',
#   'garam masala',
#   'curry powder',
#   'onion',
#   'potato',
#   'water',
#   'salt and pepper',
#   'tabasco sauce',
#   'kidney beans'],
#  ['orange slice', 'ouzo', 'orange juice', 'ice cube'],
#  ['cream of mushroom soup',
#   'milk',
#   'red pepper',
#   'cream of celery soup',
#   'salt',
#   'crabmeat',
#   'old bay seasoning',
#   'sherry wine',
#   'black pepper',
#   'half-and-half'],
#  ['ground sirloin',
#   'skim milk',
#   'ketchup',
#   'unsalted butter',
#   'salt and pepper',
#   'tomato paste',
#   'brown sugar',
#   'ground turkey',
#   'ground pork',
#   'yellow mustard',
#   'mixed mushrooms',
#   'shallot',
#   'dry sherry',
#   'chicken broth',
#   'sherry wine vinegar',
#   'panko breadcrumbs',
#   'worcestershire sauce',
#   'flour',
#   'egg whites',
#   'onion',
#   'fresh parsley',
#   'bacon'],
#  ['garlic',
#   'lemon, juice of',
#   'new potatoes',
#   'olive oil',
#   'lemon, zest of',
#   'rosemary'],
#  ['dry breadcrumbs',
#   'flour',
#   'garlic',
#   'oil',
#   'chili powder',
#   'onion',
#   'frozen corn',
#   'green chili sauce',
#   'black beans',
#   'cumin',
#   'salsa'],
#  ['caesar salad dressing',
#   'baby shrimp',
#   'green onions',
#   'red bell pepper',
#   'ripe olives',
#   'salt',
#   'fresh ground pepper',
#   'cheese-filled tortellini',
#   'mayonnaise',
#   'sour cream',
#   'fresh spinach'],
#  ['worcestershire sauce',
#   'cheese',
#   'garlic',
#   'celery',
#   'ground turkey',
#   'spike seasoning',
#   'tomato',
#   'onion',
#   'fresh parsley',
#   'salt and pepper',
#   'bell peppers',
#   'olive oil'],
#  ['cornstarch',
#   'slivered almonds',
#   'egg',
#   'cream cheese',
#   'nutmeg',
#   'graham cracker crumbs',
#   'butter',
#   'sour cream',
#   'cinnamon',
#   'heavy whipping cream',
#   'vanilla',
#   'splenda granular',
#   'lemon juice'],
#  ['oil', 'soy sauce', 'ketchup', 'smooth peanut butter', 'chicken pieces'],
#  ['dried sage',
#   'salt',
#   'celery seed',
#   'dried thyme',
#   'onion',
#   'breadcrumbs',
#   'butter',
#   'chicken broth',
#   'black pepper',
#   'parsley'],
#  ['fresh oregano',
#   'garlic',
#   'tomato',
#   'salt and pepper',
#   'fresh basil',
#   'olive oil'],
#  ['cornstarch',
#   'whipping cream',
#   'egg',
#   'salt',
#   'instant chocolate pudding mix',
#   'bittersweet chocolate',
#   'coconut milk',
#   'water',
#   'vegetable oil',
#   'sugar',
#   'coco lopez',
#   'kahlua',
#   "devil's food cake mix",
#   'shredded coconut'],
#  ['old bay seasoning', 'plain tomato juice'],
#  ['carrot',
#   'bay leaf',
#   'garlic',
#   'sweetened condensed milk',
#   'shallot',
#   'curry powder',
#   'canned pumpkin',
#   'onion',
#   'canned unsweetened coconut milk',
#   'coriander',
#   'banana',
#   'butter',
#   'chicken stock',
#   'ground nutmeg',
#   'ground allspice',
#   'cinnamon',
#   'pumpkin seeds'],
#  ['zucchini',
#   'garlic',
#   'ghee',
#   'salt',
#   'tomato',
#   'mayonnaise',
#   'parmesan cheese',
#   'black pepper',
#   'whole wheat bread'],
#  ['cream cheese',
#   'sausage',
#   'diced tomatoes with green chilies',
#   'diced green chilies'],
#  ['garlic',
#   'chili seasoning mix',
#   'beef broth',
#   'red pepper',
#   'white onion',
#   'diced tomatoes',
#   'black beans',
#   'chilies',
#   'chili beans with chipotle pepper',
#   'kidney beans',
#   'tomato sauce',
#   'extra lean ground beef'],
#  ['flour',
#   'carrot',
#   'egg',
#   'cream cheese',
#   'powdered sugar',
#   'salt',
#   'ground cinnamon',
#   'pineapple chunk',
#   'baking soda',
#   'pecans',
#   'ground nutmeg',
#   'butter',
#   'sugar',
#   'vanilla',
#   'baking powder'],
#  ['flour', 'milk', 'butter', 'black pepper', 'dried beef'],
#  ['carrot',
#   'turnips',
#   'salt',
#   'onion',
#   'potato',
#   'split peas',
#   'water',
#   'black pepper'],
#  ['hard-boiled eggs',
#   'corn tortilla strips',
#   'buttermilk',
#   'red onion',
#   'cherry tomatoes',
#   'salad dressing',
#   'steak spice',
#   'roasted garlic and red pepper spice mix',
#   'curry powder',
#   'romaine lettuce',
#   'ketchup',
#   'cooked bacon',
#   'sour cream',
#   'cumin',
#   'sugar',
#   'lemon juice',
#   'granulated garlic'],
#  ['worcestershire sauce',
#   'white pepper',
#   'bibb lettuce',
#   'fresh thyme',
#   'lean ground beef',
#   'ground cumin',
#   'salt',
#   'tomato',
#   'onion',
#   'hamburger buns',
#   'mayonnaise',
#   'papaya',
#   'cayenne pepper',
#   'cheddar cheese'],
#  ['zucchini',
#   'flour',
#   'egg',
#   'salt',
#   'baking soda',
#   'fat',
#   'walnuts',
#   'sugar',
#   'cinnamon',
#   'vanilla'],
#  ['apple',
#   'lemon',
#   'lime',
#   'lime juice',
#   'lemon-flavored vodka',
#   'lemonade',
#   'peach',
#   'dry white wine',
#   'peach schnapps',
#   'lemon juice',
#   'peach puree'],
#  ['brown sugar',
#   'prepared mustard',
#   'hot sauce',
#   'onion',
#   'ketchup',
#   'salt and pepper',
#   'ground moose',
#   'barbecue sauce'],
#  ['dry breadcrumbs',
#   'brown sugar',
#   'cornstarch',
#   'garlic',
#   'lean ground beef',
#   'egg',
#   'salt',
#   'pineapple chunks',
#   'onion',
#   'soy sauce',
#   'white vinegar',
#   'ketchup',
#   'black pepper',
#   'sweet pepper'],
#  ['dark brown sugar', 'chicken wings', 'soy sauce'],
# ...
#  ['oat bran',
#   'vital wheat gluten',
#   'egg',
#   'salt',
#   'whole wheat flour',
#   'wheat germ',
#   'white whole wheat flour',
#   'yeast',
#   'water',
#   'vegetable oil',
#   'sugar'],
#  ['kosher salt',
#   'vital wheat gluten',
#   'whole wheat flour',
#   'yeast',
#   'warm water'],
#  ['egg', 'whole wheat flour', 'salt', 'yeast', 'applesauce', 'honey', 'water'],
#  ['vital wheat gluten',
#   'egg',
#   'whole wheat flour',
#   'salt',
#   'instant yeast',
#   'canola oil',
#   'honey',
#   'water'],
#  ['granulated sugar',
#   'egg whites',
#   'whole wheat flour',
#   'low-fat buttermilk',
#   'salt',
#   'baking soda',
#   'flax seed meal',
#   'canola oil',
#   'baking powder'],
#  ['turbinado sugar',
#   'whole wheat flour',
#   'salt',
#   'baking soda',
#   'butter',
#   'honey',
#   'water',
#   'cinnamon',
#   'vanilla',
#   'baking powder'],
#  ['egg',
#   'whole wheat flour',
#   'salt',
#   'molasses',
#   'low-fat buttermilk',
#   'baking soda',
#   'butter',
#   'raisins',
#   'baking powder'],
#  ['low-fat milk',
#   'egg',
#   'whole wheat flour',
#   'baking soda',
#   'fruit',
#   'canola oil',
#   'sugar',
#   'vanilla',
#   'baking powder'],
#  ['brown sugar',
#   'egg',
#   'milk',
#   'salt',
#   'whole wheat flour',
#   'peanut butter',
#   'butter',
#   'baking powder'],
#  ['whole wheat flour', 'salt', 'instant yeast', 'honey', 'water', 'olive oil'],
#  ['egg', 'whole wheat flour', 'salt', 'yeast', 'honey', 'water', 'olive oil'],
#  ['kosher salt',
#   'gluten',
#   'milk',
#   'whole wheat flour',
#   'baking soda',
#   'butter',
#   'sour cream',
#   'baking powder'],
#  ['cocoa powder',
#   'powdered milk',
#   'egg',
#   'oil',
#   'whole wheat flour',
#   'oatmeal',
#   'salt',
#   'molasses',
#   'fruit',
#   'raisins',
#   'water',
#   'sugar',
#   'cinnamon',
#   'vanilla',
#   'baking powder',
#   'powdered eggs'],
#  ['zucchini',
#   'nuts',
#   'egg',
#   'whole wheat flour',
#   'salt',
#   'baking soda',
#   'vegetable oil',
#   'sugar',
#   'cinnamon',
#   'vanilla',
#   'baking powder'],
#  ['whole wheat flour',
#   'table salt',
#   'instant yeast',
#   'honey',
#   'water',
#   'cooking oil'],
#  ['flour',
#   'nuts',
#   'bananas',
#   'egg',
#   'baking soda',
#   'butter',
#   'sugar',
#   'vanilla'],
#  ['nuts',
#   'chocolate chips',
#   'evaporated milk',
#   'chocolate cake mix',
#   'butter',
#   'caramels'],
#  ['flour',
#   'bananas',
#   'egg',
#   'salt',
#   'baking soda',
#   'walnuts',
#   'canola oil',
#   'raisins',
#   'sugar'],
#  ['cream cheese', 'thousand island dressing'],
#  ['mayonnaise', 'onion powder', 'chili sauce', 'sweet pickle relish'],
#  ['brown sugar',
#   'flour',
#   'rolled oats',
#   'rice krispies',
#   'flaked coconut',
#   'egg',
#   'oil',
#   'cream of tartar',
#   'chocolate chips',
#   'baking soda',
#   'margarine',
#   'white sugar',
#   'vanilla'],
#  ['white pepper',
#   'garlic',
#   'buttermilk',
#   'unsalted sunflower seeds',
#   'baby spinach',
#   'bacon',
#   'mushrooms',
#   'plain yogurt',
#   'sugar',
#   'hardboiled egg',
#   'fresh lemon juice'],
#  ['frozen peas',
#   'italian seasoning',
#   'cherry tomatoes',
#   'red onion',
#   'green pepper',
#   'lettuce',
#   'fresh mushrooms',
#   'cauliflower',
#   'mayonnaise',
#   'bacon',
#   'fresh broccoli',
#   'sugar'],
#  ['garlic powder',
#   'basil leaves',
#   'chili powder',
#   'ground allspice',
#   'rubbed sage',
#   'onion salt',
#   'ground oregano',
#   'black pepper',
#   'marjoram leaves',
#   'paprika',
#   'celery salt'],
#  ['vodka', 'fresh jalapeno', 'ice', 'beer'],
#  ['worcestershire sauce',
#   'garlic',
#   'dijon mustard',
#   'anchovy fillets',
#   'oil',
#   'miracle whip light',
#   'french bread',
#   'extra virgin olive oil',
#   'fresh mushrooms',
#   'baby spinach',
#   'low-fat mayonnaise',
#   'bacon',
#   'parmesan cheese',
#   'olive oil',
#   'lemon juice'],
#  ['ground pepper',
#   'ricotta cheese',
#   'egg',
#   'dried italian seasoning',
#   'salt',
#   'mozzarella cheese',
#   'mexican blend cheese',
#   'spaghetti sauce',
#   'parsley flakes',
#   'ground beef',
#   'jumbo pasta shells',
#   'parmesan-romano cheese mix',
#   'italian cheese blend'],
#  ['brown sugar',
#   'bread machine yeast',
#   'oil',
#   'whole wheat flour',
#   'salt',
#   'white flour',
#   'water'],
#  ['onion',
#   'evaporated milk',
#   'potato',
#   'cream-style corn',
#   'butter',
#   'water',
#   'salt and pepper',
#   'whole corn'],
#  ['kosher salt',
#   'flat leaf parsley',
#   'prosciutto',
#   'extra virgin olive oil',
#   'italian seasoned breadcrumbs',
#   'orecchiette',
#   'parmesan cheese',
#   'black pepper'],
#  ['fresh ground black pepper', 'tomato', 'salt', 'cumin seeds', 'olive oil'],
#  ['molasses',
#   'salted peanuts',
#   'baking soda',
#   'butter',
#   'white sugar',
#   'vanilla',
#   'corn syrup'],
#  ['bulgar wheat',
#   'lean ground beef',
#   'salt',
#   'onion',
#   'plain yogurt',
#   'cinnamon'],
#  ['egg',
#   'instant vanilla pudding',
#   'oil',
#   'apple pie filling',
#   'yellow cake mix',
#   'water'],
#  ['boneless skinless chicken breasts', 'carrot', 'italian dressing', 'potato'],
#  ['cinnamon rolls', 'chocolate milk', 'egg'],
#  ['flour',
#   'egg',
#   'milk',
#   'salt',
#   'butter',
#   'white sugar',
#   'vanilla',
#   'baking powder'],
#  ['worcestershire sauce',
#   'garlic',
#   'carrot',
#   'soup mix',
#   'celery',
#   'salt',
#   'basil',
#   'ham',
#   'water',
#   'black pepper',
#   'leeks',
#   'thyme'],
#  ['worcestershire sauce',
#   'saltine crackers',
#   'garlic powder',
#   'chili sauce',
#   'ground beef',
#   'egg',
#   'milk',
#   'onion',
#   'salt and pepper',
#   'bell peppers'],
#  ['worcestershire sauce',
#   'garlic',
#   'salt and pepper',
#   'beef tenderloin',
#   'limes, juice of',
#   'sour cream',
#   'unsalted butter',
#   'prepared horseradish',
#   'aluminum foil'],
#  ['flour',
#   'carrot',
#   'egg',
#   'cream cheese',
#   'oil',
#   'salt',
#   'powdered sugar',
#   'baking soda',
#   'walnuts',
#   'margarine',
#   'cinnamon',
#   'pineapple',
#   'sugar',
#   'baking powder'],
#  ['carrot',
#   'salt',
#   'celery seed',
#   'onion',
#   'white vinegar',
#   'water',
#   'turmeric',
#   'cabbage',
#   'sugar',
#   'mustard seeds'],
#  ['alum',
#   'salt',
#   'pickling cucumbers',
#   'water',
#   'vinegar',
#   'sugar',
#   'pickling spices'],
#  ['alum', 'canning salt', 'vinegar', 'sugar', 'pickling spices', 'cucumbers'],
#  ['flour',
#   'nuts',
#   'carrot',
#   'egg',
#   'cream cheese',
#   'oil',
#   'salt',
#   'powdered sugar',
#   'baking soda',
#   'ground cloves',
#   'margarine',
#   'raisins',
#   'sugar',
#   'cinnamon',
#   'vanilla',
#   'coconut',
#   'allspice'],
#  ['nutmeats', 'cream', 'lemon extract', 'butter', 'maple syrup'],
#  ['carrot',
#   'raw rice',
#   'celery',
#   'deli ham',
#   'salt',
#   'tomato',
#   'chicken bouillon cubes',
#   'beans',
#   'onion',
#   'basil',
#   'chicken broth',
#   'water',
#   'parsley',
#   'v8 vegetable juice',
#   'lemon juice'],
#  ['hormel chili without beans',
#   'tortillas',
#   'monterey jack cheese',
#   'refried beans'],
#  ['garlic',
#   '15 bean soup mix',
#   'salt',
#   'ham hocks',
#   'whole tomatoes',
#   'dried parsley',
#   'onion',
#   'celery leaves',
#   'dried rosemary',
#   'chicken bouillon cubes',
#   'olive oil',
#   'black pepper'],
#  ['ham bone',
#   'worcestershire sauce',
#   'garlic',
#   '15 bean soup mix',
#   'diced tomatoes',
#   'smoked sausage',
#   'water',
#   'black pepper',
#   'beef bouillon paste',
#   'steak sauce'],
#  ['dried beans',
#   'garlic',
#   'carrot',
#   'smoked paprika',
#   'lemon',
#   'salt',
#   'chili powder',
#   'onion',
#   'paprika',
#   'oregano',
#   'ham',
#   'water',
#   'cayenne pepper',
#   'black pepper',
#   'thyme',
#   'olive oil',
#   'condensed tomato soup'],
#  ['liquid honey',
#   'flour',
#   'egg',
#   'ground walnuts',
#   'baking soda',
#   'margarine',
#   'honey',
#   'sour cream',
#   'sugar',
#   'plain sweet biscuit crumbs'],
#  ['halibut steaks',
#   'garlic',
#   'fresh chives',
#   'capers',
#   'fresh tarragon',
#   'chicken stock',
#   'fresh parsley',
#   'salt and pepper',
#   'lemon juice'],
#  ['tomato paste',
#   'oil',
#   'boneless sirloin steak',
#   'water',
#   'lipton beefy mushroom soup mix',
#   'new potatoes',
#   'peas and carrots'],
#  ['frozen corn kernels',
#   'taco seasoning',
#   'tomatoes and green chilies',
#   'black beans',
#   'ground beef'],
#  ['lean ground beef',
#   'minute white rice',
#   'ketchup',
#   'water',
#   'cheddar cheese',
#   'mustard'],
#  ['velveeta cheese',
#   'white rice',
#   'diced tomatoes',
#   'water',
#   'ground beef',
#   'chili with beans'],
#  ['condensed cream of chicken soup',
#   'boneless skinless chicken breast halves',
#   'ground pepper',
#   'water',
#   'vegetable oil',
#   'instant rice',
#   'paprika'],
#  ['cheese',
#   'fajita seasoning mix',
#   'lime',
#   'chicken breast tenders',
#   'onion',
#   'tortilla',
#   'pico de gallo',
#   'sour cream',
#   'olive oil',
#   'black pepper'],
#  ['mexicorn',
#   'chicken',
#   'tortilla chips',
#   'chicken broth',
#   'sour cream',
#   'salsa',
#   'cheddar cheese',
#   'kidney beans'],
#  ['milk',
#   'boneless skinless chicken breasts',
#   'broccoli florets',
#   'minute rice',
#   'vegetable oil',
#   'condensed cream of chicken soup'],
#  ['ground turkey',
#   'salt',
#   'stewed tomatoes',
#   'onion',
#   'chili powder',
#   'pinto beans',
#   'cumin',
#   'salsa',
#   'kidney beans'],
#  ['cheese',
#   'sour cream',
#   'water',
#   'flour tortillas',
#   'chili with beans',
#   'white minute rice'],
#  ['macaroni & cheese dinner mix',
#   'lean ground beef',
#   'broccoli',
#   'chili powder',
#   'ketchup',
#   'water'],
#  ['brown sugar',
#   'salt',
#   'tomato',
#   'onion',
#   'clove',
#   'black pepper',
#   'cinnamon',
#   'allspice'],
#  ['grape tomatoes',
#   'fresh oregano',
#   'garlic',
#   'crushed red pepper flakes',
#   'sun-dried tomato packed in oil',
#   'roasted cashews',
#   'fresh parmesan cheese',
#   'black pepper',
#   'fresh basil',
#   'pappardelle pasta'],
#  ['garlic',
#   'ground coriander',
#   'chipotle chile in adobo',
#   'ground cumin',
#   'salt',
#   'onion',
#   'low sodium chicken broth',
#   'tomato sauce'],
#  ['sugar substitute',
#   'fat-free whipped topping',
#   'reduced fat graham cracker crust',
#   'fat free cream cheese'],
#  ['pesto sauce',
#   'red onion',
#   'tomato',
#   'pine nuts',
#   'parmesan cheese',
#   'fresh linguine',
#   'lemon juice',
#   'fresh spinach'],
#  ['boneless skinless chicken breast halves',
#   'garlic',
#   'flour',
#   'oil',
#   'butter',
#   'chicken broth',
#   'salt and pepper',
#   'lemon juice'],
#  ['garlic',
#   'garbanzo beans',
#   'cracked black pepper',
#   'salt',
#   'tomato',
#   'extra virgin olive oil',
#   'feta cheese',
#   'celery ribs',
#   'fresh parsley',
#   'of fresh mint',
#   'romaine lettuce',
#   'scallion',
#   'fresh lemon juice'],
#  ['boneless skinless chicken breast',
#   'reduced-sodium fat-free chicken broth',
#   'oil',
#   'assorted fresh vegetables',
#   'instant rice',
#   'italian dressing'],
#  ['cream cheese',
#   'powdered sugar',
#   'milk',
#   'graham cracker crumbs',
#   'butter',
#   'instant lemon pudding'],
#  ["confectioners' sugar", 'peanut butter', 'butter', 'vanilla', 'cocoa'],
#  ['italian salad dressing',
#   'spaghetti',
#   'tomato',
#   'smoked turkey breast',
#   'parmesan cheese'],
#  ['chicken bouillon cube',
#   'oil',
#   'pork tenderloin',
#   'frozen mixed vegetables',
#   'soy sauce',
#   'minute rice',
#   'water'],
#  ['oil',
#   'green pepper',
#   'minute white rice',
#   'chicken bouillon cubes',
#   'onion',
#   'water',
#   'hot pepper sauce',
#   'kidney beans'],
#  ['shrimp',
#   'half-and-half cream',
#   'fettuccine',
#   'bacon bits',
#   'baby peas',
#   'parmesan cheese',
#   'garlic salt',
#   'black pepper'],
#  ['frozen shrimp',
#   'garlic',
#   'angel hair pasta',
#   'white wine',
#   'onion',
#   'extra virgin olive oil',
#   'butter',
#   'salt & pepper'],
#  ['celery',
#   'sliced mushrooms',
#   'garlic flakes',
#   'onion',
#   'jalapenos',
#   'hot chili flakes',
#   'tomato sauce & mushrooms',
#   'sweet red pepper',
#   'hamburger',
#   'sweet green pepper'],
#  ['boneless skinless chicken breast',
#   'white pepper',
#   'garlic',
#   'chili flakes',
#   'salt',
#   'asparagus',
#   'onion',
#   'soy sauce',
#   'rice vinegar',
#   'chicken broth',
#   'fresh ginger'],
#  ['elbow macaroni',
#   'dijon mustard',
#   'kosher salt',
#   'unsalted butter',
#   'fresh ground black pepper',
#   'extra-sharp cheddar cheese',
#   'hot sauce',
#   'half-and-half'],
#  ['flour',
#   'round steak',
#   'dry onion soup mix',
#   'fresh mushrooms',
#   'butter',
#   'sour cream',
#   'water'],
#  ['minute white rice',
#   'mexican blend cheese',
#   'lettuce',
#   'water',
#   'chopped tomatoes',
#   'taco seasoning mix',
#   'extra lean ground beef'],
#  ['sweet chili sauce',
#   'tiger shrimp',
#   'pak choi',
#   'thai fish sauce',
#   'sunflower oil',
#   'baby spinach',
#   'dark soy sauce',
#   'water',
#   'lime, juice and zest of',
#   'cornflour'],
#  ['milk', 'raisins', 'minute rice', 'vanilla instant pudding mix'],
#  ['black beans', 'water', 'salsa', 'fire-roasted tomatoes', 'kidney beans'],
#  ['cream cheese', 'milk', 'fettuccine pasta', 'margarine', 'parmesan cheese'],
#  ['dried fruits',
#   'quick oats',
#   'milk',
#   'salt',
#   'honey',
#   'water',
#   'sugar',
#   'vanilla'],
#  ['15 bean mix',
#   'garlic',
#   'carrot',
#   'celery',
#   'ham hocks',
#   'chicken bouillon cubes',
#   'onion',
#   'diced tomatoes',
#   'bay leaves',
#   'seasoning salt',
#   'water',
#   'black pepper',
#   'tomato sauce'],
#  ['vegetable oil',
#   'chili seasoning mix',
#   'red pepper flakes',
#   'corn chips',
#   'sharp cheddar cheese',
#   'salt and pepper',
#   'whole tomatoes',
#   'onion',
#   'black-eyed peas',
#   'ketchup',
#   'water',
#   'ground beef',
#   'dark red kidney beans',
#   'green bell pepper',
#   'canned green beans'],
#  ['garlic',
#   'salt',
#   'chicken liver',
#   'onion',
#   'ground black pepper',
#   'heavy cream',
#   'butter',
#   'sage',
#   'brandy',
#   'marjoram',
#   'thyme'],
#  ['lean ground beef',
#   'sliced mushrooms',
#   'salt',
#   'chili powder',
#   'onion',
#   'diced tomatoes',
#   'chili beans',
#   'oregano',
#   'sour cream',
#   'cayenne pepper',
#   'cumin'],
#  ['orange liqueur',
#   'cool whip topping',
#   'white chocolate baking squares',
#   'frozen pound cake',
#   'jello instant vanilla pudding mix',
#   'sugar',
#   'strawberry',
#   'strawberries'],
#  ['worcestershire sauce',
#   'boneless skinless chicken breast halves',
#   'dried tarragon',
#   'dijon mustard',
#   'black pepper',
#   'fresh lemon juice'],
#  ['salt and pepper', 'basmati rice', 'chicken broth'],
#  ['tomato',
#   'black olives',
#   'cooked chicken',
#   'lettuce',
#   'tortilla chips',
#   'green enchilada sauce',
#   'cream of chicken soup',
#   'sour cream',
#   'green onion',
#   'salsa',
#   'monterey jack cheese'],
#  ['pasta', 'butter', 'garlic', 'parmesan cheese'],
#  ['garlic',
#   'dried oregano',
#   'tomato',
#   'feta cheese',
#   'old bay seasoning',
#   'olive oil',
#   'black pepper',
#   'parsley',
#   'large shrimp'],
#  ['zucchini',
#   'large shrimp',
#   'herbs',
#   'red onion',
#   'cherry tomatoes',
#   'corn kernels',
#   'snap peas',
#   'salt & freshly ground black pepper',
#   'unsalted butter',
#   'lemon, zest of',
#   'olive oil'],
#  ['garlic',
#   'dried oregano',
#   'scallions',
#   'white beans',
#   'parmesan cheese',
#   'salt and pepper',
#   'vegetable broth',
#   'olive oil',
#   'fresh lemon juice'],
#  ['garlic',
#   'carrot',
#   'celery',
#   'tomato',
#   'onion',
#   'chicken stock',
#   'italian sausage',
#   'bay leaves',
#   'oregano',
#   'water',
#   'beans'],
#  ['alum',
#   'cinnamon sticks',
#   'white vinegar',
#   'sugar',
#   'pickling spices',
#   'cucumbers',
#   'pickling salt'],
#  ['onion', 'pork butt', 'ginger ale', 'barbecue sauce'],
#  ['dark molasses',
#   'brown sugar',
#   'strong coffee',
#   'vanilla bean',
#   'vodka',
#   'sugar',
#   'cold water'],
#  ['carrot',
#   'celery',
#   'frozen white corn',
#   'whole chickens',
#   'chicken bouillon cubes',
#   'onion',
#   'frozen corn',
#   'potato',
#   'celery ribs',
#   'chicken broth'],
#  ['fat-free parmesan cheese',
#   'nonstick cooking spray',
#   'low-carb marinara sauce',
#   'fennel seed',
#   'basil',
#   'eggplant',
#   'lean ground turkey',
#   'oregano leaves'],
#  ['mountain dew soda', 'raspberry vodka'],
#  ['apple cider',
#   'arugula',
#   'white cheddar cheese',
#   'fresh thyme',
#   'pancetta',
#   'red onion',
#   'salt and pepper',
#   'sherry wine vinegar',
#   'tart apples',
#   'red wine vinegar',
#   'shallots',
#   'white vinegar',
#   'gouda cheese',
#   'dijon mustard',
#   'olive oil'],
#  ['flour',
#   'vegetable oil',
#   'egg',
#   'salt',
#   'baby carrots',
#   'pure vanilla extract',
#   'marshmallow cream',
#   "confectioners' sugar",
#   'baking soda',
#   'light brown sugar',
#   'pumpkin pie spice',
#   'unsalted butter',
#   'baking powder'],
#  ['flour',
#   'buttermilk',
#   'egg',
#   'salt',
#   'nutmeg',
#   'baking soda',
#   'clove',
#   'butter',
#   'sugar',
#   'cinnamon',
#   'vanilla',
#   'cocoa'],
#  ['flour',
#   'cornstarch',
#   'egg',
#   'milk',
#   'egg yolks',
#   'cream of tartar',
#   'powdered sugar',
#   'sweet cream',
#   'almonds',
#   'sugar'],
#  ...]

# %% [markdown]
# We'll use the [`Word2Vec`](https://radimrehurek.com/gensim/models/word2vec.html) implementation in the `gensim` library (i.e., *deep learning*) to train an embedding model.
# This approach tends to work best if the training data has at least 100K rows.
#
# Let's also show how to serialize the *word2vec* results, saving them to the `tmp.w2v` file so they could be restored later for other use cases.
#
# NB: there is work in progress which will replace `gensim` with `pytorch` instead.

# %%
import gensim

MIN_COUNT = 2
model_path = "tmp.w2v"

model = gensim.models.Word2Vec(vectors, min_count=MIN_COUNT, window=max_context)
model.save(model_path)

# %% [markdown]
# The `get_related()` function takes any ingredient as input, using the embedding model to find the most similar other ingredients – along with calculating [`levenshtein`](https://github.com/toastdriven/pylev) edit distances (string similarity) among these labels. Then it calculates *percentiles* for both metrics in [`numpy`](https://numpy.org/) and returns the results as a [`pandas`](https://pandas.pydata.org/) DataFrame.

# %%
import numpy as np
import pandas as pd
import pylev

def get_related (model, query, n=20, granularity=100):
    """return a DataFrame of the closely related items"""
    try:
        bins = np.linspace(0, 1, num=granularity, endpoint=True)

        v = sorted(
            model.wv.most_similar(positive=[query], topn=n), 
            key=lambda x: x[1], 
            reverse=True
        )
        
        df = pd.DataFrame(v, columns=["ingredient", "similarity"])
        
        s = df["similarity"]
        quantiles = s.quantile(bins, interpolation="nearest")
        df["sim_pct"] = np.digitize(s, quantiles) - 1
        
        df["levenshtein"] = [ pylev.levenshtein(d, query) / len(query) for d in df["ingredient"] ]
        s = df["levenshtein"]
        quantiles = s.quantile(bins, interpolation="nearest")
        df["lev_pct"] = granularity - np.digitize(s, quantiles)

        return df
    except KeyError:
        return pd.DataFrame(columns=["ingredient", "similarity", "percentile"])

# %% [markdown]
# Let's try this with `dried basil` as the ingredient to query, and review the top `50` most similar other ingredients returned as the DataFrame `df`:

# %%
df = get_related(model, "dried basil", n=50)

pd.set_option("max_rows", None)
df
# Out:
#                                     ingredient  similarity  sim_pct  \
# 0                           dried basil leaves    0.694151       99
# 1                                    dry basil    0.640432       97
# 2                               dried rosemary    0.623488       95
# 3                                  fresh basil    0.608903       93
# 4                      dried italian seasoning    0.580459       91
# 5                     dried sweet basil leaves    0.572005       89
# 6                            italian seasoning    0.562176       87
# 7                               dried marjoram    0.557508       85
# 8                                dried parsley    0.547193       83
# 9                            dried whole thyme    0.536246       81
# 10                                       basil    0.534683       79
# 11                       dried rosemary leaves    0.517563       77
# 12                      italian herb seasoning    0.516329       75
# 13                        dried parsley flakes    0.494413       73
# 14                           hot pepper flakes    0.486427       71
# 15                             globe eggplants    0.484773       69
# 16                                 dry oregano    0.476785       67
# 17                          fresh basil leaves    0.471215       65
# 18                             lasagna noodles    0.466942       63
# 19                     dried red pepper flakes    0.460909       61
# 20                            sliced mushrooms    0.459038       59
# 21                 part-skim mozzarella cheese    0.458995       57
# 22                   italian style breadcrumbs    0.458158       55
# 23                        mild italian sausage    0.456502       53
# 24                   dried chili pepper flakes    0.456417       51
# 25                          hunts tomato paste    0.451725       49
# 26                             fresh mushrooms    0.451020       47
# 27                               parmesan rind    0.450180       45
# 28                    contadina diced tomatoes    0.448351       43
# 29                             italian sausage    0.447932       41
# 30                                chianti wine    0.443112       39
# 31                        small macaroni pasta    0.441096       37
# 32                            italian sausages    0.439240       35
# 33                                  ziti pasta    0.437536       33
# 34                            fresh basil leaf    0.436654       31
# 35                          dried thyme leaves    0.435929       29
# 36                italian-style diced tomatoes    0.434733       27
# 37                       italian seasoning mix    0.429836       25
# 38                       sweet italian sausage    0.428318       23
# 39                               summer squash    0.427028       21
# 40                         dried summer savory    0.425657       19
# 41                         canned tomato sauce    0.422285       17
# 42                                   pepperoni    0.420411       15
# 43                          herb seasoning mix    0.420095       13
# 44                                  orzo pasta    0.418945       11
# 45                              italian spices    0.418704        9
# 46                        dried oregano leaves    0.418589        7
# 47     johnsonville mild italian sausage links    0.418220        5
# 48                dried italian herb seasoning    0.415222        3
# 49  olive oil-flavored vegetable cooking spray    0.411397        1
#
#     levenshtein  lev_pct
# 0      0.636364       82
# 1      0.272727       98
# 2      0.636364       82
# 3      0.363636       96
# 4      1.272727       32
# 5      1.181818       38
# 6      1.090909       46
# 7      0.636364       82
# 8      0.454545       94
# 9      1.000000       58
# 10     0.545455       92
# 11     1.181818       38
# 12     1.454545       18
# 13     1.000000       58
# 14     1.272727       32
# 15     1.181818       38
# 16     0.818182       78
# 17     1.000000       58
# 18     1.181818       38
# 19     1.454545       18
# 20     1.000000       58
# 21     2.090909        4
# 22     1.909091        8
# 23     1.363636       26
# 24     1.545455       14
# 25     1.363636       26
# 26     1.090909       46
# 27     0.909091       70
# 28     1.636364       10
# 29     1.000000       58
# 30     0.909091       70
# 31     1.454545       18
# 32     1.090909       46
# 33     0.636364       82
# 34     0.818182       78
# 35     1.000000       58
# 36     2.090909        4
# 37     1.454545       18
# 38     1.545455       14
# 39     0.909091       70
# 40     1.090909       46
# 41     1.272727       32
# 42     0.909091       70
# 43     1.363636       26
# 44     0.636364       82
# 45     1.090909       46
# 46     1.090909       46
# 47     2.909091        2
# 48     1.636364       10
# 49     3.272727        0

# %% [markdown]
# Note how some of the most similar items, based on vector embedding, are *synonyms* or special forms of our query `dried basil` ingredient: `dried basil leaves`, `dry basil`, `dried sweet basil leaves`, etc. These tend to rank high in terms of levenshtein distance too.

# %% [markdown]
# Let's plot the similarity measures:

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use("ggplot")

df["similarity"].plot(alpha=0.75, rot=0)
plt.show()

# %% [markdown]
# Notice the inflection points at approximately `0.57` and again at `0.47` in that plot.
# We could use some statistical techniques (e.g., clustering) to segment the similarities into a few groups:
#
#   * highest similarity – potential synonyms for the query
#   * mid-range similarity – potential [hypernyms and hyponyms](https://en.wikipedia.org/wiki/Hyponymy_and_hypernymy) for the query
#   * long-tail similarity – other ingredients that pair well with the query

# %% [markdown]
# In this example, below a threshold of the 75th percentile for vector embedding similarity, the related ingredients are less about being synonyms and more about other foods that pair well with basil.
#
# Let's define another function `rank_related()` which ranks the related ingredients based on a combination of these two metrics.
# This uses a cheap approximation of a [*pareto archive*](https://www.cs.bham.ac.uk/~jdk/multi/) for the ranking -- which comes in handing for recommender systems and custom search applications that must combine multiple ranking metrics:

# %%
import math

def rms (values):
    """calculate root mean square"""
    numer = sum([x for x in map(lambda x: float(x)**2.0, values)])
    denom = float(len(values))
    return math.sqrt(numer / denom)

def rank_related (df):
    df2 = df.copy(deep=True)
    df2["related"] = df2.apply(lambda row: rms([row[2], row[4]]), axis=1)
    return df2.sort_values(by=["related"], ascending=False)

# %%
rank_related(df)
# Out:
#                                     ingredient  similarity  sim_pct  \
# 1                                    dry basil    0.640432       97
# 3                                  fresh basil    0.608903       93
# 0                           dried basil leaves    0.694151       99
# 2                               dried rosemary    0.623488       95
# 8                                dried parsley    0.547193       83
# 10                                       basil    0.534683       79
# 7                               dried marjoram    0.557508       85
# 16                                 dry oregano    0.476785       67
# 9                            dried whole thyme    0.536246       81
# 6                            italian seasoning    0.562176       87
# 5                     dried sweet basil leaves    0.572005       89
# 4                      dried italian seasoning    0.580459       91
# 13                        dried parsley flakes    0.494413       73
# 33                                  ziti pasta    0.437536       33
# 17                          fresh basil leaves    0.471215       65
# 11                       dried rosemary leaves    0.517563       77
# 34                            fresh basil leaf    0.436654       31
# 27                               parmesan rind    0.450180       45
# 44                                  orzo pasta    0.418945       11
# 20                            sliced mushrooms    0.459038       59
# 30                                chianti wine    0.443112       39
# 15                             globe eggplants    0.484773       69
# 14                           hot pepper flakes    0.486427       71
# 12                      italian herb seasoning    0.516329       75
# 18                             lasagna noodles    0.466942       63
# 39                               summer squash    0.427028       21
# 42                                   pepperoni    0.420411       15
# 29                             italian sausage    0.447932       41
# 26                             fresh mushrooms    0.451020       47
# 35                          dried thyme leaves    0.435929       29
# 19                     dried red pepper flakes    0.460909       61
# 23                        mild italian sausage    0.456502       53
# 32                            italian sausages    0.439240       35
# 21                 part-skim mozzarella cheese    0.458995       57
# 22                   italian style breadcrumbs    0.458158       55
# 25                          hunts tomato paste    0.451725       49
# 24                   dried chili pepper flakes    0.456417       51
# 40                         dried summer savory    0.425657       19
# 45                              italian spices    0.418704        9
# 46                        dried oregano leaves    0.418589        7
# 28                    contadina diced tomatoes    0.448351       43
# 31                        small macaroni pasta    0.441096       37
# 41                         canned tomato sauce    0.422285       17
# 37                       italian seasoning mix    0.429836       25
# 43                          herb seasoning mix    0.420095       13
# 36                italian-style diced tomatoes    0.434733       27
# 38                       sweet italian sausage    0.428318       23
# 48                dried italian herb seasoning    0.415222        3
# 47     johnsonville mild italian sausage links    0.418220        5
# 49  olive oil-flavored vegetable cooking spray    0.411397        1
#
#     levenshtein  lev_pct    related
# 1      0.272727       98  97.501282
# 3      0.363636       96  94.511904
# 0      0.636364       82  90.898295
# 2      0.636364       82  88.738380
# 8      0.454545       94  88.670739
# 10     0.545455       92  85.746720
# 7      0.636364       82  83.513472
# 16     0.818182       78  72.708321
# 9      1.000000       58  70.445014
# 6      1.090909       46  69.588074
# 5      1.181818       38  68.428795
# 4      1.272727       32  68.209237
# 13     1.000000       58  65.927991
# 33     0.636364       82  62.502000
# 17     1.000000       58  61.599513
# 11     1.181818       38  60.716555
# 34     0.818182       78  59.350653
# 27     0.909091       70  58.843011
# 44     0.636364       82  58.502137
# 20     1.000000       58  58.502137
# 30     0.909091       70  56.661274
# 15     1.181818       38  55.700090
# 14     1.272727       32  55.068140
# 12     1.454545       18  54.538977
# 18     1.181818       38  52.024033
# 39     0.909091       70  51.676881
# 42     0.909091       70  50.621142
# 29     1.000000       58  50.224496
# 26     1.090909       46  46.502688
# 35     1.000000       58  45.853026
# 19     1.454545       18  44.972214
# 23     1.363636       26  41.743263
# 32     1.090909       46  40.871751
# 21     2.090909        4  40.404208
# 22     1.909091        8  39.300127
# 25     1.363636       26  39.223717
# 24     1.545455       14  37.396524
# 40     1.090909       46  35.192329
# 45     1.090909       46  33.143627
# 46     1.090909       46  32.901368
# 28     1.636364       10  31.216983
# 31     1.454545       18  29.094673
# 41     1.272727       32  25.622256
# 37     1.454545       18  21.783021
# 43     1.363636       26  20.554805
# 36     2.090909        4  19.300259
# 38     1.545455       14  19.039433
# 48     1.636364       10   7.382412
# 47     2.909091        2   3.807887
# 49     3.272727        0   0.707107

# %% [markdown]
# Notice how the "synonym" cases tend to move up to the top now?
# Meanwhile while the "pairs well with" are in the lower half of the ranked list: `fresh mushrooms`, `italian turkey sausage`, `cooked spaghetti`, `white kidney beans`, etc.

# %% [markdown]
# ---
#
# ## Exercises

# %% [markdown]
# **Exercise 1:**
#
# Build a report for a *human-in-the-loop* reviewer, using the `rank_related()` function while iterating over `vocab` to make algorithmic suggestions for possible synonyms.

# %% [markdown]
# **Exercise 2:**
#
# How would you make algorithmic suggestions for a reviewer about which ingredients could be related to a query, e.g., using the `skos:broader` and `skos:narrower` relations in the [`skos`](https://www.w3.org/2004/02/skos/) vocabulary to represent *hypernyms* and *hyponyms* respectively?
# This could extend the KG to provide a kind of thesaurus about recipe ingredients.
