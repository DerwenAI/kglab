# %% [markdown]
# # Vector embedding with `gensim`
#
# Let's make use of deep learning through a technique called *embedding* – to analyze the relatedness of the labels used for recipe ingredients.
#
# Among the most closely related ingredients:
#
#   * Some are very close synonyms and should be consolidated to improve data quality
#   * Others are interesting other ingredients that pair frequently, useful for recommendations
#
# On the one hand, this approach is quite helpful for analyzing the NLP annotations that go into a knowledge graph.
# On the other hand it can be used along with [`SKOS`](https://www.w3.org/2004/02/skos/) or similar vocabularies for ontology-based discovery within the graph, e.g., for advanced search UI.

# %% [markdown]
# ## Curating annotations
#
# We'll be working with the labels for ingredients that go into our KG.
# Looking at the raw data, there are many cases where slightly different spellings are being used for the same entity.
#
# As a first step let's define a list of synonyms to substitute, prior to running the vector embedding.
# This will help produce better quality results.
#
# Note that this kind of work comes of the general heading of *curating annotations* ... which is what we spend so much time doing in KG work.
# It's similar to how *data preparation* is ~80% of the workload for data science teams, and for good reason.

# %%
SYNONYMS = {
    "pepper": "black pepper",
    "black pepper": "black pepper",
    
    "egg": "egg",
    "eggs": "egg",

    "vanilla": "vanilla",
    "vanilla extract": "vanilla",
    
    "flour": "flour",
    "all-purpose flour": "flour",

    "onions": "onion",
    "onion": "onion",
        
    "carrots": "carrot",
    "carrot": "carrot",

    "potatoes": "potato",
    "potato": "potato",
    
    "tomatoes": "tomato",
    "fresh tomatoes": "tomato",
    "fresh tomato": "tomato",
    
    "garlic": "garlic",
    "garlic clove": "garlic",
    "garlic cloves": "garlic",
}

# %% [markdown]
# ## Analyze ingredient labels from 250K recipes

# %%
import csv

MAX_ROW = 250000 # 231638

max_context = 0
min_context = 1000

recipes = []
vocab = set()

with open("dat/all_ind.csv", "r") as f:
    reader = csv.reader(f)
    next(reader, None) # remove file header

    for i, row in enumerate(reader):
        id = row[0]
        ind_set = set()
        
        # substitute synonyms
        for ind in set(eval(row[3])):
            if ind in SYNONYMS:
                ind_set.add(SYNONYMS[ind])
            else:
                ind_set.add(ind)
        
        if len(ind_set) > 1:
            recipes.append([id, ind_set])
            vocab.update(ind_set)
        
            max_context = max(max_context, len(ind_set))
            min_context = min(min_context, len(ind_set))

        if i > MAX_ROW:
            break

print("max context: {} unique ingredients per recipe".format(max_context))
print("min context: {} unique ingredients per recipe".format(min_context))
print("vocab size", len(list(vocab)))
# Out:
# max context: 43 unique ingredients per recipe
# min context: 2 unique ingredients per recipe
# vocab size 14931

# %% [markdown]
# Since we've performed this data preparation work, let's use `pickle` to save this larger superset of the recipes dataset to the `tmp.pkl` file.
# Then we can restore it later for other use cases:

# %%
import pickle

pickle.dump(recipes, open("tmp.pkl", "wb"))

recipes
# Out:
# [['137739',
#   {'butter',
#    'honey',
#    'mexican seasoning',
#    'mixed spice',
#    'olive oil',
#    'salt',
#    'winter squash'}],
#  ['31490',
#   {'cheese',
#    'egg',
#    'milk',
#    'prepared pizza crust',
#    'salt and pepper',
#    'sausage patty'}],
#  ['112140',
#   {'cheddar cheese',
#    'chili powder',
#    'diced tomatoes',
#    'ground beef',
#    'ground cumin',
#    'kidney beans',
#    'lettuce',
#    'rotel tomatoes',
#    'salt',
#    'tomato paste',
#    'tomato soup',
#    'water',
#    'yellow onions'}],
#  ['59389',
#   {'black pepper',
#    'new potatoes',
#    'olive oil',
#    'parsley',
#    'red bell pepper',
#    'red wine vinegar',
#    'salt',
#    'shallots',
#    'spreadable cheese with garlic and herbs',
#    'tarragon',
#    'yellow bell pepper'}],
#  ['44061',
#   {'apple cider vinegar',
#    'black pepper',
#    'cinnamon oil',
#    'clove oil',
#    'dry mustard',
#    'salt',
#    'sugar',
#    'tomato juice'}],
#  ['5289',
#   {'apple', 'frozen apple juice concentrate', 'milk', 'vanilla ice cream'}],
#  ['25274',
#   {'extra virgin olive oil',
#    'fennel seeds',
#    'garlic',
#    'green olives',
#    'orange juice',
#    'orange rind',
#    'peppercorn',
#    'red chile',
#    'ripe olives'}],
#  ['67888',
#   {'a.1. original sauce',
#    'brown sugar',
#    'chili powder',
#    'cinnamon sticks',
#    'cracked black pepper',
#    'cumin',
#    'dry mustard',
#    'fresh cilantro leaves',
#    'fresh coarse ground black pepper',
#    'fresh garlic',
#    'fresh ginger',
#    'honey',
#    'liquid smoke',
#    'mirin',
#    'orange, juice of',
#    'pork spareribs',
#    'salt',
#    'soy sauce',
#    'tomato sauce',
#    'water',
#    'white vinegar',
#    'yellow onion'}],
#  ['70971',
#   {'bananas',
#    'chocolate sandwich style cookies',
#    'chocolate syrup',
#    'strawberry ice cream',
#    'vanilla ice cream',
#    'whipped cream'}],
#  ['75452',
#   {'baking soda',
#    'bananas',
#    'cake flour',
#    'egg',
#    'fresh lemon juice',
#    'orange rind',
#    'salt',
#    'sugar',
#    'unsalted butter'}],
#  ['109439',
#   {'prepared horseradish', 'sour cream', 'whole berry cranberry sauce'}],
#  ['42198',
#   {'butter',
#    'egg',
#    'powdered sugar',
#    'strawberry',
#    'vanilla wafers',
#    'walnuts',
#    'whipping cream'}],
#  ['67547',
#   {'bacon',
#    'black pepper',
#    'chicken bouillon cubes',
#    'chili powder',
#    'cornstarch',
#    'dark brown sugar',
#    'garlic powder',
#    'great northern bean',
#    'molasses',
#    'mustard powder',
#    'onion',
#    'salt',
#    'water'}],
#  ['107517',
#   {'brown sugar',
#    'collard greens',
#    'ham hock',
#    'hot sauce',
#    'molasses',
#    'salt',
#    'whiskey'}],
#  ['39959',
#   {'burnet root',
#    'gentian root',
#    'scullcap herb',
#    'spearmint',
#    'wood bethony'}],
#  ['63986',
#   {'chicken rice soup',
#    'dry mustard',
#    'flour',
#    'garlic powder',
#    'lean pork chops',
#    'oil',
#    'salt'}],
#  ['43026',
#   {'cheese', 'cornstarch', 'egg roll wrap', 'oil', 'whole green chilies'}],
#  ['23933', {'butterscotch chips', 'chinese noodles', 'salted peanuts'}],
#  ['8559',
#   {'beef broth',
#    'celery',
#    'cooking oil',
#    'ground pork',
#    'hamburger buns',
#    'onion',
#    'soy sauce'}],
#  ['23850',
#   {'broccoli floret',
#    'canola oil',
#    'cauliflower',
#    'escarole',
#    'fresh herb',
#    'garlic',
#    'great northern bean',
#    'green peas',
#    'ground coriander',
#    'onion',
#    'potato',
#    'red bell pepper',
#    'salt and pepper',
#    'salt free herb and spice seasoning mix',
#    'vegetable bouillon cubes',
#    'water'}],
#  ['76808',
#   {'boiling potatoes',
#    'coarse salt',
#    'fresh ground black pepper',
#    'fresh spinach leaves',
#    'nutmeg',
#    'salt',
#    'unsalted butter',
#    'water'}],
#  ['24701',
#   {'apple juice',
#    'broth',
#    'celery',
#    'dried thyme',
#    'fresh parsley',
#    'olive oil',
#    'onion',
#    'rolled oats',
#    'salt',
#    'scallion',
#    'spinach',
#    'white pepper'}],
#  ['83873',
#   {'boneless skinless chicken breast halves',
#    'condensed cream of chicken soup',
#    'cornstarch',
#    'egg',
#    'flour',
#    'garlic powder',
#    'oil',
#    'paprika',
#    'salt and pepper',
#    'seasoning salt'}],
#  ['107699',
#   {'baking powder',
#    'bread',
#    'brown sugar',
#    'butter',
#    'egg',
#    'flour',
#    'granulated sugar',
#    'ground cinnamon',
#    'milk',
#    'powdered sugar',
#    'salt',
#    'vanilla',
#    'vegetable oil'}],
#  ['49262', {'butter', 'egg yolks', 'lemon, juice of', 'salt', 'white pepper'}],
#  ['48156',
#   {'black cumin',
#    'ground black pepper',
#    'ground coriander',
#    'ground cumin',
#    'ground ginger',
#    'ground turmeric'}],
#  ['54272',
#   {'black pepper',
#    'celery',
#    'chili powder',
#    'diced tomatoes',
#    'garlic',
#    'green pepper',
#    'jalapenos',
#    'kidney beans',
#    'onion',
#    'red pepper flakes',
#    'salt',
#    'vegetarian ground beef'}],
#  ['47366',
#   {'beef bouillon cube',
#    'beef stew meat',
#    'cabbage',
#    'dried parsley',
#    'elbow macaroni',
#    'garbanzo beans',
#    'ground pepper',
#    'ground thyme',
#    'onion',
#    'parmesan cheese',
#    'salt',
#    'tomato',
#    'water',
#    'zucchini'}],
#  ['37073', {'margarine', 'red potatoes', 'rosemary'}],
#  ['44123',
#   {'black beans',
#    'broccoli floret',
#    'broccoli stem',
#    'carrot',
#    'celery',
#    'chicken stock',
#    'cornstarch',
#    'dried oregano',
#    'dried sweet basil leaves',
#    'dried thyme',
#    'dry white wine',
#    'heavy cream',
#    'onion',
#    'salt & fresh ground pepper',
#    'smoked chicken',
#    'tabasco sauce',
#    'unsalted butter',
#    'worcestershire sauce'}],
#  ['27087',
#   {'baking cocoa',
#    'baking powder',
#    'butter',
#    'egg',
#    'flour',
#    'miniature peppermint patties',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['59952',
#   {'black pepper',
#    'cheddar cheese',
#    'cornmeal',
#    'ground beef',
#    'hot chili pepper',
#    'onion',
#    'salt',
#    'sliced ripe olives',
#    'tabasco sauce',
#    'taco sauce',
#    'tomato sauce',
#    'whole kernel corn'}],
#  ['93249', {'butter', 'dry ranch dressing mix', 'french bread'}],
#  ['54100',
#   {'black pepper',
#    'dry mustard',
#    'egg substitute',
#    'fresh breadcrumb',
#    'ground venison',
#    'non-fat powdered milk',
#    'onion',
#    'salt',
#    'water',
#    'worcestershire sauce'}],
#  ['67664', {'frozen juice concentrate', 'milk', 'plain yogurt'}],
#  ['87098',
#   {'carrot',
#    'corn',
#    'diced tomatoes',
#    'green beans',
#    'low sodium chicken broth',
#    'potato',
#    'wax beans',
#    'zucchini'}],
#  ['25775',
#   {'black pepper',
#    'condensed cream of mushroom soup',
#    'crouton',
#    'egg',
#    'frozen chopped spinach',
#    'onion',
#    'salt',
#    'sharp cheddar cheese'}],
#  ['33165',
#   {'black pepper',
#    'celery seed',
#    'diced pimentos',
#    'fat-free mayonnaise',
#    'garlic',
#    'green onion',
#    'low-fat sour cream',
#    'plain low-fat yogurt',
#    'prepared mustard',
#    'red potatoes',
#    'salt',
#    'sugar',
#    'white wine vinegar'}],
#  ['38798',
#   {'egg',
#    'frozen chopped spinach',
#    'garlic powder',
#    'margarine',
#    'onion',
#    'oregano',
#    'sage',
#    'soft breadcrumbs'}],
#  ['22123',
#   {'condensed cream of mushroom & garlic soup',
#    'cooking oil',
#    'cornbread mix',
#    'cream of mushroom soup',
#    'frozen vegetables',
#    'ground beef',
#    'onion',
#    'salt & pepper'}],
#  ['90921',
#   {'angel hair pasta',
#    'garlic',
#    'green onions',
#    'honey',
#    'soy sauce',
#    'stir fry vegetables',
#    'toasted sesame oil',
#    'toasted sesame seeds'}],
#  ['93959',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'buckwheat flour',
#    'butter',
#    'canola oil',
#    'cinnamon',
#    'egg',
#    'flour',
#    'ground cinnamon',
#    'ground cloves',
#    'honey',
#    'low-fat buttermilk',
#    'orange juice',
#    'orange rind',
#    'pecans',
#    'salt',
#    'sugar',
#    'unsweetened cocoa',
#    'yam'}],
#  ['93958',
#   {'baking powder',
#    'baking soda',
#    'boiling water',
#    'buckwheat flour',
#    'canola oil',
#    'egg',
#    'flour',
#    'granulated sugar',
#    'ground cinnamon',
#    'ground cloves',
#    'low-fat buttermilk',
#    'orange juice',
#    'orange rind',
#    'raisins',
#    'salt',
#    'sorghum',
#    'unsweetened cocoa',
#    'yam'}],
#  ['58224',
#   {'american cheese',
#    'beer',
#    'cayenne',
#    'garlic',
#    'ground beef',
#    'prepared yellow mustard',
#    'salt & pepper',
#    'sugar'}],
#  ['33606',
#   {'cheese',
#    'chives',
#    'cider vinegar',
#    'dill pickles',
#    'garlic powder',
#    'green onion',
#    'ham',
#    'italian seasoning',
#    'olive oil',
#    'onion powder',
#    'ripe olives',
#    'salt and pepper',
#    'sweet pepper',
#    'tomato',
#    'tri-color spiral pasta',
#    'water chestnut'}],
#  ['94710',
#   {'basil',
#    'flat leaf parsley',
#    'frozen french fries',
#    'oil',
#    'oregano',
#    'parmesan cheese',
#    'salt & freshly ground black pepper'}],
#  ['35173',
#   {'butter',
#    'cheddar cheese',
#    'deli turkey',
#    'good seasonings italian salad dressing mix',
#    'ham',
#    'mozzarella cheese',
#    'pepperoni',
#    'sandwich bun',
#    'swiss cheese'}],
#  ['83025',
#   {'baking powder',
#    'butter',
#    'egg',
#    'flour',
#    'icing sugar',
#    'milk',
#    'salt',
#    'shortening',
#    'sugar',
#    'vanilla'}],
#  ['52804',
#   {'carrot',
#    'cinnamon',
#    'coconut',
#    'crushed pineapple',
#    'egg',
#    'nutmeg',
#    'oil',
#    'pecans',
#    'vanilla instant pudding mix',
#    'water',
#    'yellow cake mix'}],
#  ['108414',
#   {'butter',
#    'egg',
#    'heavy cream',
#    'honey',
#    'jalapenos',
#    'jiffy corn muffin mix',
#    'onion',
#    'red bell pepper',
#    'sharp cheddar cheese',
#    'whole kernel corn'}],
#  ['26995',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'butter',
#    'cinnamon',
#    'crushed pineapple',
#    'dry yeast',
#    'egg',
#    'flour',
#    'milk',
#    'nuts',
#    'raisins',
#    'salt',
#    'sugar',
#    'vanilla',
#    'vegetable oil',
#    'water'}],
#  ['53402',
#   {'cottage cheese',
#    'dried basil',
#    'egg',
#    'garlic',
#    'ground beef',
#    'ground black pepper',
#    'italian sausage',
#    'lasagna noodle',
#    'mozzarella cheese',
#    'parmesan cheese',
#    'parsley flakes',
#    'ricotta cheese',
#    'salt',
#    'tomato paste',
#    'whole tomato'}],
#  ['59632',
#   {'beef',
#    'black pepper',
#    'cheese',
#    'cottage cheese',
#    'egg',
#    'frozen chopped spinach',
#    'herbs',
#    'olive oil flavored cooking spray',
#    'salt',
#    'spices',
#    'toasted wheat germ'}],
#  ['22526',
#   {'brown sugar',
#    'butter',
#    'cinnamon',
#    'instant vanilla pudding',
#    'raisins',
#    'rolls'}],
#  ['100870',
#   {'garlic',
#    'granulated sugar',
#    'ground beef',
#    'prego spaghetti sauce',
#    'stewed tomatoes',
#    'white onion'}],
#  ['84797',
#   {'beef steaks',
#    'brown sugar',
#    'dried dill weed',
#    'fresh garlic',
#    'fresh lemon juice',
#    'fresh parsley',
#    'honey',
#    'hot sauce',
#    'ketchup',
#    'sour cream',
#    'spicy mustard',
#    'vegetable oil'}],
#  ['35653',
#   {'baking powder', 'butter', 'egg', 'flour', 'milk', 'salt', 'sugar'}],
#  ['32169',
#   {'button mushrooms',
#    'chicken breasts',
#    'dried basil',
#    'dried oregano',
#    'fresh ground black pepper',
#    'fresh parsley',
#    'garlic',
#    'hot sauce',
#    'olive oil',
#    'onion',
#    'parmesan cheese',
#    'pasta',
#    'salsa',
#    'tomato',
#    'water'}],
#  ['24478', {'cider vinegar', 'fresh herb', 'fresh herbs'}],
#  ['44045',
#   {'baking powder',
#    'black pepper',
#    'cream',
#    'egg',
#    'fat',
#    'flour',
#    'fresh corn',
#    'salt'}],
#  ['60219',
#   {'black olives',
#    'cheddar cheese soup',
#    'fettuccine pasta',
#    'jalapeno',
#    'milk',
#    'picante sauce'}],
#  ['81185',
#   {'cilantro',
#    'frozen peas',
#    'hass avocado',
#    'lemons, juice of',
#    'onion',
#    'salt',
#    'tomato'}],
#  ['30131',
#   {'basil',
#    'black pepper',
#    'garlic powder',
#    'lemon juice',
#    'oil',
#    'soy sauce',
#    'worcestershire sauce'}],
#  ['63593',
#   {'apple', 'cream cheese', 'milk', 'pear', 'unflavored gelatin', 'yogurt'}],
#  ['43164',
#   {'bacon',
#    'bay leaf',
#    'black pepper',
#    'butter',
#    'carrot',
#    'oil',
#    'onion',
#    'parsley sprigs',
#    'salt',
#    'thyme',
#    'veal roast'}],
#  ['30300', {'black pepper', 'crackers', 'mayonnaise', 'tomato'}],
#  ['78655',
#   {'brine',
#    'capers',
#    'carrot',
#    'ciabatta',
#    'fresh basil',
#    'fresh parsley',
#    'garlic',
#    'genoa salami',
#    'green olives',
#    'ham',
#    'kalamata olive',
#    'olive oil',
#    'oregano leaves',
#    'provolone cheese',
#    'red wine vinegar',
#    'sweet onion',
#    'tomato'}],
#  ['74805',
#   {'powdered sugar',
#    'vanilla',
#    'vanilla instant pudding mix',
#    'whipping cream'}],
#  ['71635',
#   {'cookie',
#    'cream cheese',
#    'gelatin',
#    'milk',
#    'miniature semisweet chocolate chips',
#    'prepared graham cracker crusts',
#    'sugar',
#    'vanilla'}],
#  ['38276',
#   {'baking powder',
#    'butter',
#    'carrot',
#    'cayenne pepper',
#    'celery',
#    'chili powder',
#    'cloves',
#    'egg',
#    'flour',
#    'green pepper',
#    'ground cumin',
#    'monterey jack cheese',
#    'onion',
#    'oregano',
#    'salt',
#    'sliced mushrooms',
#    'soy sauce',
#    'tomato',
#    'vegetable shortening',
#    'water',
#    'zucchini'}],
#  ['97052', {'half-and-half', 'salt and pepper', 'sweet butter', 'sweet corn'}],
#  ['26835',
#   {'baking soda',
#    'butter',
#    'egg',
#    'flour',
#    'lemon, rind of',
#    'salt',
#    'sugar',
#    'vanilla',
#    'yogurt'}],
#  ['32271',
#   {'butter',
#    'egg',
#    'flour',
#    'nuts',
#    'sugar',
#    'unsweetened chocolate squares',
#    'vanilla'}],
#  ['107229',
#   {'broccoli',
#    'chili-garlic sauce',
#    'cooked chicken',
#    'fresh cilantro',
#    'fresh ginger',
#    'green onions',
#    'reduced sodium soy sauce',
#    'rice vinegar',
#    'sesame oil',
#    'sesame seeds',
#    'vegetable oil',
#    'vermicelli'}],
#  ['5060',
#   {'apples',
#    'celery',
#    'orange juice',
#    'orange rind',
#    'pecans',
#    'philadelphia cream cheese',
#    'sugar'}],
#  ['42570',
#   {'boneless chicken breast',
#    'cayenne',
#    'cumin',
#    'fresh ground pepper',
#    'garlic',
#    'lemon juice',
#    'olive oil',
#    'paprika',
#    'salt',
#    'thyme'}],
#  ['52443',
#   {'baking potato',
#    'garlic powder',
#    'mozzarella cheese',
#    'oregano leaves',
#    'parmesan cheese',
#    'part-skim ricotta cheese',
#    'tomato sauce'}],
#  ['35595',
#   {'black pepper',
#    'cornstarch',
#    'mushroom pieces',
#    'onion',
#    'sodium-free vegetable broth',
#    'tabasco sauce',
#    'tomato puree',
#    'white wine'}],
#  ['108804',
#   {'albacore tuna in water',
#    'bibb lettuce',
#    'black pepper',
#    'fresh basil',
#    'garlic',
#    'light olive oil',
#    'red sweet bell peppers',
#    'red wine vinegar',
#    'salt',
#    'scallions',
#    'white kidney beans'}],
#  ['83950',
#   {'bacon',
#    'beef consomme',
#    'black pepper',
#    'butter',
#    'carrot',
#    'celery',
#    'crushed tomatoes',
#    'dry white wine',
#    'garlic',
#    'ground pork',
#    'lean ground beef',
#    'milk',
#    'nutmeg',
#    'olive oil',
#    'onion',
#    'oregano',
#    'penne pasta',
#    'red pepper flakes',
#    'rubbed sage',
#    'salt'}],
#  ['19208', {'apples', 'red cinnamon candies', 'sugar substitute', 'water'}],
#  ['64302',
#   {'brown sugar',
#    'celery',
#    'cucumber',
#    'elbow macaroni',
#    'green pepper',
#    'ketchup',
#    'lemon juice',
#    'oil',
#    'onion',
#    'tomato'}],
#  ['35964',
#   {'baking powder',
#    'brown sugar',
#    'cocoa',
#    'flour',
#    'hot water',
#    'milk',
#    'salt',
#    'sugar',
#    'vanilla',
#    'vegetable oil'}],
#  ['71457',
#   {'apple pie filling',
#    'butter',
#    'egg',
#    'flour',
#    'milk',
#    'powdered sugar',
#    'salt',
#    'toasted almonds'}],
#  ['95926', {'bananas', 'mayonnaise', 'white bread'}],
#  ['103948',
#   {'boneless skinless chicken thighs',
#    'breadcrumbs',
#    'chicken stock',
#    'dried oregano',
#    'dried thyme',
#    'dry white wine',
#    'flour',
#    'fresh ground black pepper',
#    'garlic powder',
#    'lean ground beef',
#    'milk',
#    'onion',
#    'poultry seasoning',
#    'salt',
#    'vegetable oil'}],
#  ['99024',
#   {'cream cheese', 'lemon juice', 'liquid smoke', 'onion', 'salmon', 'salt'}],
#  ['64045',
#   {'bean sprouts',
#    'brown sugar',
#    'carrot',
#    'desiccated coconut',
#    'garlic',
#    'ginger',
#    'green beans',
#    'ground cayenne pepper',
#    'ground coriander',
#    'ground cumin',
#    'onion',
#    'peanut oil',
#    'peanuts',
#    'red chili pepper',
#    'sambal oelek',
#    'soy sauce',
#    'tempeh',
#    'tomato',
#    'vegetable stock',
#    'water'}],
#  ['41756',
#   {'dried breadcrumbs',
#    'egg',
#    'ground beef',
#    'lemon juice',
#    'onion',
#    'salt and pepper',
#    'sugar',
#    'tomato soup',
#    'water'}],
#  ['112959',
#   {'avocado',
#    'chunky salsa',
#    'fresh cilantro',
#    'hot sauce',
#    'lime juice',
#    'salt and pepper',
#    'soft silken tofu'}],
#  ['83062',
#   {'baking soda',
#    'bananas',
#    'cinnamon',
#    'egg',
#    'flour',
#    'ground cloves',
#    'nutmeg',
#    'salt',
#    'shortening',
#    'walnuts',
#    'white sugar'}],
#  ['98930',
#   {'boneless skinless chicken breast',
#    'dried basil',
#    'lime juice',
#    'olive oil',
#    'salt and pepper',
#    'tomato'}],
#  ['83133',
#   {'beef ribs',
#    'brown sugar',
#    'fresh lemon juice',
#    'ketchup',
#    'mustard',
#    'onion',
#    'salt',
#    'vegetable oil',
#    'water',
#    'worcestershire sauce'}],
#  ['39947', {'egg whites', 'green grape', 'sugar'}],
#  ['44895',
#   {'betty crocker fudge brownie mix',
#    'egg',
#    'milk chocolate candy bars',
#    'vegetable oil',
#    'water'}],
#  ['39363',
#   {'baking powder',
#    'baking soda',
#    'bananas',
#    'butter',
#    'chocolate chips',
#    'egg',
#    'flour',
#    'nuts',
#    'salt',
#    'sugar',
#    'water'}],
#  ['62368',
#   {'brown sugar',
#    'butter',
#    'chocolate chips',
#    'cream cheese',
#    'egg',
#    'flour',
#    'oreo cookie crumbs',
#    'sour cream',
#    'sweetened condensed milk',
#    'vanilla'}],
#  ['111875',
#   {'2% low-fat milk',
#    'banana',
#    'natural-style peanut butter',
#    'sugar-free non-fat vanilla yogurt'}],
#  ['42522',
#   {'bean dip',
#    'cheddar cheese',
#    'cream cheese',
#    'sour cream',
#    'taco seasoning'}],
#  ['34930',
#   {'american cheese',
#    'bacon',
#    'dill weed',
#    'ground sirloin',
#    'iceberg lettuce',
#    "mccormick's montreal brand steak seasoning",
#    'no-salt-added ketchup',
#    'onion',
#    'tomato'}],
#  ['63793',
#   {'chat masala',
#    'chopped tomato',
#    'cucumber',
#    'paprika',
#    'plain yogurt',
#    'potato',
#    'salt'}],
#  ['61973',
#   {'baking soda',
#    'brown sugar',
#    'buttermilk',
#    'carrot',
#    'cinnamon',
#    'corn oil',
#    'egg',
#    'natural bran',
#    'raisins',
#    'salt',
#    'vanilla',
#    'whole wheat flour'}],
#  ['45859',
#   {'grand marnier',
#    'lime juice',
#    'lime wedge',
#    'limeade',
#    'tequila',
#    'triple sec'}],
#  ['58651',
#   {'brown sugar', 'butter', 'flour', 'pecans', 'semi-sweet chocolate chips'}],
#  ['59534',
#   {'black pepper',
#    'butter',
#    'cappelletti pasta',
#    'cheddar cheese',
#    'chopped tomato',
#    'corn',
#    'garlic',
#    'ground beef',
#    'milk',
#    'mushrooms',
#    'onion',
#    'salt',
#    'tomato soup'}],
#  ['24137',
#   {'dry white wine',
#    'extra virgin olive oil',
#    'garlic',
#    'hot water',
#    'parsley',
#    'salt and pepper',
#    'spaghetti',
#    'squid',
#    'tomato sauce'}],
#  ['40237',
#   {'baking soda',
#    'cocoa',
#    'flour',
#    'salt',
#    'sugar',
#    'vanilla',
#    'vegetable oil',
#    'vinegar',
#    'water'}],
#  ['18537', {'applesauce', 'brown sugar', 'clove', 'pork loin chops'}],
#  ['104243',
#   {'butter',
#    'cheddar cheese',
#    'cream cheese',
#    'green olives',
#    'ham',
#    'honey mustard',
#    'leaf lettuce',
#    'mayonnaise',
#    'prepared horseradish',
#    'provolone cheese',
#    'radish sprouts',
#    'roast beef',
#    'roasted red peppers',
#    'swiss cheese',
#    'turkey',
#    'whole wheat bread dough'}],
#  ['105069',
#   {'beef broth',
#    'butter',
#    'flour',
#    'fresh dill',
#    'lemon, juice of',
#    'onion',
#    'salt and pepper',
#    'sour cream',
#    'water',
#    'wild mushrooms'}],
#  ['70099',
#   {'asian chili sauce',
#    'bean sprouts',
#    'carrot',
#    'english cucumber',
#    'fresh cilantro',
#    'fresh ginger',
#    'garlic',
#    'green onions',
#    'honey',
#    'light soy sauce',
#    'rice noodles',
#    'rice wine vinegar',
#    'sesame oil'}],
#  ['333281',
#   {'bittersweet chocolate',
#    'brewed espresso',
#    'egg',
#    'flour',
#    'granulated sugar',
#    'kosher salt',
#    'unsalted butter',
#    'unsweetened cocoa powder',
#    'vanilla'}],
#  ['234069', {'brown sugar', 'dr. pepper cola', 'orange marmalade'}],
#  ['37841',
#   {'fish',
#    'gingerroot',
#    'low sodium soy sauce',
#    'peanut oil',
#    'rice wine',
#    'salt',
#    'scallions',
#    'sesame oil',
#    'white pepper'}],
#  ['144952',
#   {'beef broth',
#    'butter',
#    'flour',
#    'french bread',
#    'garlic',
#    'low sodium beef broth',
#    'olive oil',
#    'parmesan cheese',
#    'romano cheese',
#    'sherry wine',
#    'sugar',
#    'swiss cheese',
#    'yellow onions'}],
#  ['453467',
#   {'baking soda',
#    'brown sugar',
#    'chocolate chips',
#    'egg',
#    'flour',
#    'margarine',
#    'salt',
#    'vanilla',
#    'water',
#    'white sugar',
#    'whole wheat flour'}],
#  ['31835',
#   {'butter',
#    'cornbread',
#    'cream of chicken soup',
#    'egg',
#    'onion',
#    'sage',
#    'squash'}],
#  ['197013',
#   {'bay leaves',
#    'black pepper',
#    'bottled garlic',
#    'dried basil',
#    'dried oregano',
#    'dried parsley',
#    'garlic powder',
#    'italian sausage',
#    'olive oil',
#    'paprika',
#    'salt',
#    'sugar',
#    'tomato sauce',
#    'white onion'}],
#  ['306168',
#   {'cream of chicken soup',
#    'french-fried onions',
#    'frozen broccoli cuts',
#    'garlic powder',
#    'ground black pepper',
#    'milk',
#    'salt',
#    'sharp cheddar cheese',
#    'soy sauce'}],
#  ['286009',
#   {'almond extract',
#    'butter',
#    'egg',
#    'flour',
#    'pure vanilla extract',
#    'sugar',
#    'whole milk'}],
#  ['24514',
#   {'artichoke hearts',
#    'egg',
#    'fresh garlic',
#    'oil',
#    'unsalted butter',
#    'unseasoned breadcrumbs'}],
#  ['42508',
#   {'barbecue sauce',
#    'black pepper',
#    'chicken',
#    'chili powder',
#    'cider vinegar',
#    'hot red pepper sauce',
#    'salt',
#    'worcestershire sauce'}],
#  ['116679',
#   {'cheddar cheese',
#    'cream cheese',
#    'dry onion soup mix',
#    'frozen broccoli',
#    'ritz cracker crumbs',
#    'sour cream',
#    'water chestnuts'}],
#  ['124286',
#   {'baking soda',
#    'cocoa powder',
#    'cool whip',
#    'flour',
#    'instant chocolate pudding mix',
#    'mayonnaise',
#    'milk',
#    'salt',
#    'sugar',
#    'vanilla',
#    'water'}],
#  ['190',
#   {'bouillon',
#    'budweiser beer',
#    'chili powder',
#    'coriander',
#    'cornmeal',
#    'cumin',
#    'flour',
#    'garlic',
#    'hunts tomato sauce',
#    'lean chuck',
#    'lean pork',
#    'louisiana hot sauce',
#    'onion',
#    'oregano leaves',
#    'paprika',
#    'sugar',
#    'unsweetened cocoa',
#    'water'}],
#  ['475785',
#   {'baby spinach',
#    'egg',
#    'fresh garlic',
#    'goat cheese',
#    'kosher salt',
#    'meatloaf mixture',
#    'olive oil',
#    'red bell pepper',
#    'simply potatoes shredded hash browns',
#    'unsalted butter',
#    'unsmoked bacon',
#    'white pepper',
#    'yellow onion'}],
#  ['17265',
#   {'dark brown sugar',
#    'egg',
#    'egg white',
#    'ground cinnamon',
#    'ground cloves',
#    'ground ginger',
#    'heavy cream',
#    'milk',
#    'nutmeg',
#    'pie crusts',
#    'pumpkin puree',
#    'salt'}],
#  ['50662',
#   {'baking powder',
#    'beef',
#    'breadcrumbs',
#    'butter',
#    'celery seed',
#    'cream of chicken soup',
#    'dry onion flakes',
#    'flour',
#    'milk',
#    'onion',
#    'paprika',
#    'poppy seed',
#    'poultry seasoning',
#    'salt',
#    'sour cream',
#    'vegetable oil'}],
#  ['177187',
#   {'baking powder',
#    'baking soda',
#    'blended oatmeal',
#    'brown sugar',
#    'butter',
#    'egg',
#    'flour',
#    'hershey chocolate candy bars',
#    'nuts',
#    'semi-sweet chocolate chips',
#    'sugar',
#    'vanilla'}],
#  ['118843',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'butter',
#    'chocolate chips',
#    'egg',
#    'flour',
#    "hershey's semi-sweet baking chocolate",
#    'nuts',
#    'oatmeal',
#    'salt',
#    'vanilla',
#    'white sugar'}],
#  ['208179', {'butter', 'flour', 'granulated sugar', 'milk', 'vanilla'}],
#  ['500166',
#   {'cheddar cheese',
#    'corn cobs',
#    'ground beef',
#    'lettuce',
#    'onion',
#    'salsa',
#    'taco seasoning',
#    'taco shells',
#    'tomato'}],
#  ['501028',
#   {'beans',
#    'beef bouillon cube',
#    'beef broth',
#    'bell peppers',
#    'black pepper',
#    'chicken bouillon cube',
#    'chunky salsa',
#    'cinnamon',
#    'cumin',
#    'dark chocolate chips',
#    'garlic',
#    'ground coriander',
#    'habanero pepper',
#    'light brown sugar',
#    'mexican chili powder',
#    'salt',
#    'sazon goya',
#    'stewing beef',
#    'stewing pork',
#    'tomato paste',
#    'tortilla chips',
#    'white onion'}],
#  ['136602',
#   {'baking soda',
#    'brown sugar',
#    'butter',
#    'cream cheese',
#    'egg',
#    'flour',
#    'lemon zest',
#    'lime zest',
#    'orange-flavored liqueur',
#    'pecans',
#    'pitted dates',
#    'powdered sugar',
#    'salt',
#    'shortening',
#    'tequila',
#    'triple sec',
#    'warm water'}],
#  ['69190',
#   {'bouillon cubes',
#    'butter',
#    'carrot',
#    'celery',
#    'cream of celery soup',
#    'cream of chicken soup',
#    'milk',
#    'onion',
#    'potato',
#    'potato flakes',
#    'water'}],
#  ['503475',
#   {'apples',
#    'butter',
#    'cinnamon',
#    'cream',
#    'egg',
#    'flour',
#    'lemon, juice of',
#    'milk',
#    'salt',
#    'sugar'}],
#  ['522861',
#   {'butter',
#    'cheese',
#    'fresh coarse ground black pepper',
#    'garlic',
#    'macaroni',
#    'milk',
#    'onion',
#    'salt'}],
#  ['457136',
#   {'black pepper',
#    'cheese',
#    'fine semolina',
#    'heavy cream',
#    'macaroni',
#    'muscat wine',
#    'onion',
#    'potato',
#    'salt water',
#    'unsalted butter'}],
#  ['455351',
#   {'applesauce',
#    'butter',
#    'cheese',
#    'milk',
#    'onion',
#    'penne pasta',
#    'potato',
#    'salt and pepper'}],
#  ['333797', {'dried yellow peas', 'ginger', 'pork', 'salt', 'water'}],
#  ['428056',
#   {'black pepper',
#    'brown mustard',
#    'carrot',
#    'clove',
#    'dried thyme',
#    'dried yellow peas',
#    'ground ginger',
#    'ham bone',
#    'onion',
#    'salt',
#    'water'}],
#  ['306245', {'butter', 'fresh spinach', 'nutmeg', 'water'}],
#  ['523359',
#   {'chili powder',
#    'cornstarch',
#    'dried onion flakes',
#    'garlic powder',
#    'granulated sugar',
#    'ground beef',
#    'ground black pepper',
#    'ground pork',
#    'paprika',
#    'salt',
#    'tomato paste',
#    'water',
#    'white vinegar',
#    'wondra flour'}],
#  ['495314',
#   {'apple cider vinegar',
#    'applesauce',
#    'cayenne',
#    'dark brown sugar',
#    'granulated garlic',
#    'liquid smoke',
#    'maple syrup',
#    'oregano',
#    'ponzu sauce',
#    'salt',
#    'tomato ketchup'}],
#  ['149593',
#   {'baking powder',
#    'baking soda',
#    'butter',
#    'egg',
#    'flour',
#    'salt',
#    'sour cream',
#    'sugar',
#    'vanilla'}],
#  ['227924',
#   {'butter', 'frozen whipped topping', 'oreo cookies', 'vanilla ice cream'}],
#  ['100540', {'butter', 'processed cheese', 'white bread'}],
#  ['155959',
#   {'balsamic vinegar',
#    'fresh ground black pepper',
#    'garlic',
#    'london broil beef',
#    'olive oil',
#    'rosemary',
#    'soy sauce',
#    'worcestershire sauce'}],
#  ['29214',
#   {'chicken broth',
#    'cornstarch',
#    'dried oregano',
#    'dried rosemary',
#    'dried thyme',
#    'dry sherry',
#    'fresh mushrooms',
#    'garlic',
#    'hot pepper sauce',
#    'margarine',
#    'nonfat dry milk powder',
#    'nonfat milk',
#    'parmesan cheese',
#    'salt and black pepper',
#    'spicy brown mustard',
#    'teriyaki sauce'}],
#  ['92533',
#   {'almonds',
#    'butter',
#    'cinnamon',
#    'cream cheese',
#    'egg',
#    'nutmeg',
#    'sour cream',
#    'splenda sugar substitute',
#    'vanilla',
#    'vanilla protein powder'}],
#  ['209203',
#   {'bacon', 'butter', 'real maple syrup', 'refrigerated buttermilk biscuits'}],
#  ['42151',
#   {'horseradish',
#    'mayonnaise',
#    'tabasco sauce',
#    'velveeta cheese',
#    'worcestershire sauce'}],
#  ['327356', {'lemon juice', 'red wine vinegar', 'water'}],
#  ['325509',
#   {'berries',
#    'ground flax seeds',
#    "i can't believe it's not butter spread",
#    'old fashioned oats',
#    'sugar-free syrup',
#    'water'}],
#  ['236184',
#   {'blueberries',
#    'cream cheese',
#    'egg',
#    'flour',
#    'french bread',
#    'frozen blueberries',
#    'maple syrup',
#    'milk',
#    'nuts',
#    'powdered sugar',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['241445',
#   {'bacon',
#    'celery',
#    'cheddar cheese',
#    'chicken broth',
#    'chives',
#    'liquid smoke',
#    'onion',
#    'red potatoes',
#    'salt',
#    'sour cream',
#    'velveeta cheese',
#    'white pepper'}],
#  ['149887',
#   {'active dry yeast',
#    'brown sugar',
#    'butter',
#    'cinnamon',
#    'cream cheese',
#    'egg',
#    'flour',
#    'granulated sugar',
#    'milk',
#    'powdered sugar',
#    'salt',
#    'vanilla pudding mix',
#    'warm water'}],
#  ['112984',
#   {'asparagus',
#    'garlic',
#    'italian seasoning',
#    'part-skim mozzarella cheese',
#    'red bell pepper',
#    'reduced-fat parmesan cheese',
#    'salt and pepper',
#    'spaghetti sauce',
#    'spaghetti squash',
#    'white mushroom'}],
#  ['200148',
#   {'coriander',
#    'cornstarch',
#    'frozen pineapple concentrate',
#    'graham cracker crumbs',
#    'lemon juice',
#    'maple syrup',
#    'margarine',
#    'oil',
#    'soft silken tofu',
#    'vanilla',
#    'vegan cream cheese',
#    'vegan sugar',
#    'water'}],
#  ['445026',
#   {'andouille sausage',
#    'celery',
#    'cooked chicken',
#    'creole seasoning',
#    'flour',
#    'frozen black-eyed peas',
#    'garlic',
#    'green bell pepper',
#    'large raw shrimp',
#    'low sodium chicken broth',
#    'onion',
#    'vegetable oil'}],
#  ['70611',
#   {'cheddar cheese',
#    'cracker',
#    'egg',
#    'ground beef',
#    'onion',
#    'pickle',
#    'salt and pepper',
#    'thousand island dressing'}],
#  ['273326',
#   {'basil',
#    'butter',
#    'cajun spices',
#    'garlic',
#    'heavy whipping cream',
#    'lemon juice',
#    'linguine',
#    'parmesan cheese',
#    'parmesan-romano cheese mix',
#    'parsley',
#    'salmon',
#    'salt',
#    'white pepper'}],
#  ['310570', {'cottage cheese', 'egg', 'feta', 'milk', 'oil', 'phyllo dough'}],
#  ['318677',
#   {'avocado',
#    'cucumber',
#    'imitation crabmeat',
#    'lettuce',
#    'pickled ginger',
#    'seasoned rice vinegar',
#    'soy sauce',
#    'white rice'}],
#  ['80050',
#   {'baking soda',
#    'egg',
#    'flour',
#    'maraschino cherry',
#    'mincemeat',
#    'mixed candied fruit',
#    'sweetened condensed milk',
#    'walnuts'}],
#  ['269984',
#   {'baby carrots',
#    'baking powder',
#    'black pepper',
#    'celery',
#    'chicken breasts',
#    'chicken stock',
#    'egg',
#    'kosher salt',
#    'matzo meal',
#    'oil',
#    'salt',
#    'sugar',
#    'white onion'}],
#  ['317508',
#   {'cheddar cheese',
#    'cream of mushroom soup',
#    'frozen southern style hash brown potatoes',
#    'poppy seed',
#    'sour cream'}],
#  ['53872',
#   {'adobo seasoning',
#    'egg',
#    'fresh garlic cloves',
#    'fresh ground pepper',
#    'ground coriander',
#    'ground sage',
#    'italian seasoned breadcrumbs',
#    'ketchup',
#    'lean ground beef',
#    'low sodium soy sauce',
#    'olive oil',
#    'oregano',
#    'red onion',
#    'sea salt',
#    'veggie shreds cheese'}],
#  ['268942',
#   {'butter',
#    'celery',
#    'cream of celery soup',
#    'green bell pepper',
#    'kraft macaroni and cheese',
#    'mushrooms',
#    'onion',
#    'tuna'}],
#  ['176110',
#   {'black pepper',
#    'cider vinegar',
#    'dry mustard',
#    'garlic',
#    'ketchup',
#    'miracle whip',
#    'paprika',
#    'salt',
#    'sugar',
#    'tabasco sauce',
#    'vegetable oil'}],
#  ['205331',
#   {'extra virgin olive oil',
#    'italian parsley',
#    'kalamata olive',
#    'kosher salt & freshly ground black pepper',
#    'lemon, juice of',
#    'oregano',
#    'pepperoncini peppers',
#    'red bell pepper',
#    'red onion',
#    'red ripe tomatoes',
#    'red wine vinegar',
#    'seedless cucumber',
#    'shallot',
#    'tuna in vegetable oil',
#    'water-packed artichoke hearts'}],
#  ['165856',
#   {'buttermilk',
#    'canola oil',
#    'egg',
#    'ground black pepper',
#    'orange roughy',
#    'seasoning salt',
#    'self-rising flour'}],
#  ['474769',
#   {'bacon',
#    'egg',
#    'egg yolk',
#    'flour',
#    'frozen spinach',
#    'garlic',
#    'goat cheese',
#    'green onion',
#    'salt',
#    'simply potatoes traditional mashed potatoes'}],
#  ['138005',
#   {'boneless pork chops',
#    'cajun seasoning',
#    'canola oil',
#    'egg',
#    'flour',
#    'ground black pepper',
#    'milk',
#    'salt and pepper',
#    'seasoning salt',
#    'self-rising flour'}],
#  ['216945',
#   {'imitation crabmeat',
#    'ramen noodles',
#    'stir fry vegetables',
#    'teriyaki marinade',
#    'water'}],
#  ['164526',
#   {'apple',
#    'banana',
#    'celery',
#    'fresh cilantro leaves',
#    'green bell pepper',
#    'ground red pepper',
#    'pesto sauce',
#    'pumpkin puree',
#    'pumpkin seeds',
#    'red onion',
#    'salt',
#    'small red potato',
#    'smooth cashew butter',
#    'vegetable broth'}],
#  ['50184',
#   {'chili powder',
#    'dry-roasted cashews',
#    'garlic',
#    'margarine',
#    'mushrooms',
#    'nutmeg',
#    'parsley',
#    'vegetable bouillon cubes',
#    'water'}],
#  ['316470',
#   {'ice cubes', 'mangoes', 'oranges', 'strawberries', 'vanilla bean'}],
#  ['343338',
#   {'fresh rosemary',
#    'garlic',
#    'leeks',
#    'olive oil',
#    'russet potatoes',
#    'salt and pepper',
#    'vegetable broth',
#    'white beans'}],
#  ['137434',
#   {'black peppercorns',
#    'boneless skinless chicken breasts',
#    'cardamom pods',
#    'chicken stock',
#    'chili powder',
#    'cinnamon stick',
#    'cloves',
#    'coriander seed',
#    'fresh coriander',
#    'fresh ginger',
#    'garlic',
#    'ground cumin',
#    'onion',
#    'salt & freshly ground black pepper',
#    'soy yogurt',
#    'turmeric'}],
#  ['95534',
#   {'beef bouillon cubes',
#    'black pepper',
#    'boiling water',
#    'dried oregano',
#    'dried thyme',
#    'garlic',
#    'garlic powder',
#    'rump roast',
#    'salt',
#    'tabasco sauce',
#    'worcestershire sauce'}],
#  ['30473', {'ginger', 'honey', 'milk', 'tea bag', 'water'}],
#  ['24470', {'ground beef', 'sausage', 'taco chips', 'velveeta cheese'}],
#  ['311991',
#   {'bell pepper',
#    'brown sugar',
#    'garlic powder',
#    'ground mustard',
#    'hamburger buns',
#    'ketchup',
#    'lean ground beef',
#    'onion',
#    'steak seasoning',
#    'tomato sauce',
#    'white vinegar',
#    'worcestershire sauce'}],
#  ['225707',
#   {'beets',
#    'black pepper',
#    'carrot',
#    'fresh corn kernels',
#    'garlic',
#    'gingerroot',
#    'green onions',
#    'green peppers',
#    'honey',
#    'rice wine vinegar',
#    'safflower oil',
#    'salad greens',
#    'salad seasoning',
#    'salt',
#    'soy sauce',
#    'white mushrooms'}],
#  ['242830',
#   {'chicken broth',
#    'dry white wine',
#    'fennel seeds',
#    'fresh lemon juice',
#    'olive oil',
#    'onion',
#    'paprika',
#    'pork chops'}],
#  ['336744',
#   {'black olives',
#    'egg',
#    'garlic powder',
#    'italian seasoning',
#    'mozzarella cheese',
#    'pepperoni',
#    'ramen noodles',
#    'red bell pepper',
#    'roma tomato'}],
#  ['83542',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'egg',
#    'flour',
#    'milk',
#    'molasses',
#    'natural bran',
#    'oil',
#    'raisins',
#    'salt',
#    'sesame seeds',
#    'sunflower seeds'}],
#  ['91626',
#   {'black tea leaves',
#    'broiler',
#    'brown sugar',
#    'dry sherry',
#    'garlic',
#    'low sodium soy sauce',
#    'minced ginger',
#    'onion',
#    'orange zest',
#    'orange, juice of',
#    'peppercorn'}],
#  ['303457',
#   {'cardamom pods',
#    'cloves',
#    'coriander seed',
#    'fruit vinegar',
#    'gingerroot',
#    'kaffir lime leaves',
#    'lemongrass',
#    'peanut oil',
#    'star anise',
#    'turmeric',
#    'yoghurt'}],
#  ['176717',
#   {'blueberry pie filling',
#    'cool whip',
#    'graham wafers',
#    'vanilla pudding mix'}],
#  ['39226',
#   {'canned jalapeno slices',
#    'cayenne pepper',
#    'chili powder',
#    'cornstarch',
#    'dried onion flakes',
#    'garlic powder',
#    'onion powder',
#    'salt',
#    'sugar',
#    'tomato paste',
#    'vinegar',
#    'water'}],
#  ['216030',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'butter',
#    'cake flour',
#    'corn flakes',
#    'egg',
#    'nuts',
#    'quick-cooking oats',
#    'raisins',
#    'salt',
#    'shredded coconut',
#    'vanilla'}],
#  ['268169',
#   {'black pepper',
#    'butter',
#    'italian spices',
#    'kosher salt',
#    'olive oil',
#    'onion',
#    'whole turkey'}],
#  ['98357',
#   {'cheddar cheese',
#    'chili with beans',
#    'corn chips',
#    'onion',
#    'salsa',
#    'sour cream'}],
#  ['150365',
#   {'black pepper',
#    'cauliflower florets',
#    'egg',
#    'parsley sprig',
#    'plain breadcrumbs',
#    'salt',
#    'vegetable oil'}],
#  ['243251',
#   {'butter',
#    'fresh green beans',
#    'ground black pepper',
#    'kosher salt',
#    'mixed herbs',
#    'olive oil',
#    'onion',
#    'walnuts'}],
#  ['20186',
#   {'american cheese',
#    'ham',
#    'hamburger buns',
#    'ketchup',
#    'sweet pickle relish'}],
#  ['109818', {'bacon', 'carrot', 'sugar', 'tomato soup'}],
#  ['243785',
#   {'brown sugar',
#    'egg',
#    'ground beef',
#    'ketchup',
#    'lipton onion soup mix',
#    'seasoned bread crumbs'}],
#  ['207525',
#   {'bulk pork sausage',
#    'garlic powder',
#    'ground chuck',
#    'ground pepper',
#    'oregano',
#    'rye cocktail bread',
#    'velveeta cheese',
#    'worcestershire sauce'}],
#  ['226246',
#   {'brown sugar',
#    'butter',
#    'caster sugar',
#    'egg',
#    'glace cherries',
#    'milk',
#    'pineapple in syrup',
#    'self-raising flour',
#    'vanilla essence'}],
#  ['353044',
#   {'apple',
#    'banana',
#    'coconut milk',
#    'flax seed oil',
#    'greens',
#    'honey',
#    'oat bran',
#    'water'}],
#  ['263781',
#   {'green onion',
#    'hawaiian bread',
#    "hellmann's mayonnaise",
#    'knorr vegetable soup mix',
#    'sour cream',
#    'water chestnuts'}],
#  ['66932',
#   {'broccoli floret',
#    'brown rice',
#    'carrot',
#    'egg',
#    'olive oil',
#    'peas',
#    'sliced mushrooms',
#    'soy sauce'}],
#  ['48131',
#   {'egg whites',
#    'pumpkin',
#    'pumpkin pie spice',
#    'reduced fat graham cracker crust',
#    'skim milk',
#    'splenda sugar substitute'}],
#  ['32363', {'beef stew', 'biscuits'}],
#  ['293225',
#   {'baking soda',
#    'buttermilk',
#    'creamy peanut butter',
#    'espresso',
#    'extra-large eggs',
#    'heavy cream',
#    'honey roasted peanuts',
#    'light corn syrup',
#    'powdered sugar',
#    'pure vanilla extract',
#    'salt',
#    'semisweet chocolate',
#    'sugar',
#    'unbleached all-purpose flour',
#    'unsalted butter',
#    'unsweetened cocoa'}],
#  ['235173',
#   {'chipotle chile in adobo',
#    'cilantro',
#    'corn kernel',
#    'fresh lime juice',
#    'garlic',
#    'ground cumin',
#    'lime zest',
#    'olive oil',
#    'onion',
#    'red bell pepper',
#    'short-grain brown rice',
#    'yellow cornmeal'}],
#  ['226001',
#   {'butter',
#    'egg',
#    'flour',
#    'instant vanilla pudding',
#    'water',
#    'whipped dessert topping mix'}],
#  ['220186',
#   {'celery',
#    'dijon mustard',
#    'fresh ground pepper',
#    'hard-boiled eggs',
#    'milk',
#    'miracle whip',
#    'mustard',
#    'potato',
#    'salt',
#    'sugar',
#    'white onions',
#    'white pepper'}],
#  ['217201',
#   {'black pepper',
#    'butter',
#    'cayenne pepper',
#    'chili powder',
#    'dried basil',
#    'garlic powder',
#    'lemon juice',
#    'seasoning salt',
#    'soy sauce',
#    'tea bag',
#    'water',
#    'white rice'}],
#  ['194665',
#   {'bisquick',
#    'egg',
#    'feta cheese',
#    'fresh ground pepper',
#    'frozen spinach',
#    'kalamata olive',
#    'milk',
#    'onion',
#    'oregano',
#    'roasted red pepper'}],
#  ['269909',
#   {'allspice',
#    'baking powder',
#    'baking soda',
#    'cinnamon',
#    'egg',
#    'flour',
#    'ground cloves',
#    'nutmeg',
#    'oil',
#    'pecans',
#    'pumpkin',
#    'salt',
#    'sugar',
#    'water'}],
#  ['259693',
#   {'black pepper',
#    'boneless pork chops',
#    'dry onion soup mix',
#    'long-grain rice',
#    'vegetable oil',
#    'water'}],
#  ['161370',
#   {'allspice',
#    'black pepper',
#    'boneless skinless chicken breasts',
#    'brown sugar',
#    'cayenne',
#    'chili powder',
#    'chives',
#    'cinnamon',
#    'clove',
#    'crushed tomatoes',
#    'garlic',
#    'ginger',
#    'habanero pepper',
#    'jamaican jerk spice',
#    'lime juice',
#    'nutmeg',
#    'olive oil',
#    'onion',
#    'onion flakes',
#    'red peppers',
#    'rum',
#    'sage',
#    'thyme'}],
#  ['152261',
#   {'frozen limeade concentrate', 'ice', 'lime sorbet', 'mango', 'strawberry'}],
#  ['152259',
#   {'apple juice',
#    'banana',
#    'ice',
#    'non-fat vanilla frozen yogurt',
#    'strawberry'}],
#  ['303460',
#   {'coriander seed',
#    'cumin',
#    'fish sauce',
#    'fruit vinegar',
#    'garlic',
#    'hoisin sauce',
#    'red chile',
#    'sesame oil',
#    'yoghurt'}],
#  ['270259',
#   {'butter',
#    'candy cane',
#    'egg',
#    'flour',
#    'peppermint extract',
#    'peppermint oreos',
#    'salt',
#    'sugar',
#    'unsweetened chocolate',
#    'unsweetened cocoa powder',
#    'vanilla'}],
#  ['345123',
#   {'canola oil',
#    'celery',
#    'cooked chicken breasts',
#    'cooked rice',
#    'green grapes',
#    'mandarin oranges',
#    'mayonnaise',
#    'orange juice',
#    'pineapple tidbits',
#    'salt',
#    'slivered almonds',
#    'white vinegar'}],
#  ['125195',
#   {'celery',
#    'cheddar cheese',
#    'frozen peas',
#    'hard-boiled eggs',
#    'mayonnaise',
#    'mustard',
#    'onion',
#    'seasoning salt',
#    'sugar',
#    'sweet pickle relish'}],
#  ['141939',
#   {'black pepper',
#    'butter',
#    'buttermilk',
#    'cayenne pepper',
#    'chicken pieces',
#    'dijon mustard',
#    'dried thyme',
#    'dry breadcrumbs',
#    'flour',
#    'fresh garlic',
#    'garlic powder',
#    'hot pepper sauce',
#    'oil',
#    'onion',
#    'paprika',
#    'parmesan cheese',
#    'seasoning salt'}],
#  ['171442',
#   {'allspice',
#    'black pepper',
#    'cinnamon',
#    'fresh garlic',
#    'habanero sauce',
#    'hoisin sauce',
#    'ketchup',
#    'lemon juice',
#    'louisiana hot sauce',
#    'pork baby back ribs',
#    'seasoning salt',
#    'sugar'}],
#  ['212188',
#   {'beef stock',
#    'black pepper',
#    'carrot',
#    'celery',
#    'chicken leg',
#    'corn',
#    'garlic',
#    'italian seasoning',
#    'onion',
#    'peas',
#    'red bell pepper',
#    'rotini pasta',
#    'salt',
#    'spaghetti sauce'}],
#  ['262208',
#   {'aluminum foil',
#    'margarine',
#    'mexicorn whole kernel corn',
#    'pam cooking spray',
#    'salt and pepper',
#    'sour cream',
#    'spinach dip',
#    'stove top stuffing mix monterey style with mushroom and onion'}],
#  ['207857', {'cooking onions', 'pickling spices', 'white vinegar'}],
#  ['221049',
#   {'carrot',
#    'chicken broth',
#    'cooked chicken',
#    'cooked pasta',
#    'egg',
#    'peas',
#    'soy sauce'}],
#  ['221116', {'cake crumbs', 'cool whip', 'cream cheese', 'mixed fruit'}],
#  ['130819',
#   {'butter',
#    'coconut flavoring',
#    'cool whip',
#    'egg',
#    'flour',
#    'lemon flavoring',
#    'pie crust',
#    'squash',
#    'sugar'}],
#  ['20223',
#   {'black pepper',
#    'cream of mushroom soup',
#    'dijon mustard',
#    'dried onion flakes',
#    'dried parsley flakes',
#    'garlic powder',
#    'ground cinnamon',
#    'ground cloves',
#    'ground veal',
#    'salt'}],
#  ['190108',
#   {'black pepper',
#    'brown rice',
#    'catfish nuggets',
#    'chicken stock',
#    'garlic',
#    'gumbo file',
#    'lemon',
#    'mexican-style stewed tomatoes with jalapeno peppers',
#    'okra',
#    'old bay seasoning',
#    'olive oil',
#    'oregano',
#    'parsley',
#    'red onions',
#    'red wine vinegar',
#    'seafood',
#    'small shrimp',
#    'tabasco sauce',
#    'tomato soup'}],
#  ['158372',
#   {'bacon',
#    'egg',
#    'fresh chives',
#    'mild cheddar cheese',
#    'paprika',
#    'sour cream',
#    'white vinegar'}],
#  ['219681',
#   {'chicken breasts',
#    'cracked black pepper',
#    'dried basil',
#    'dried oregano',
#    'dried parsley',
#    'garlic',
#    'garlic salt',
#    'lemon juice',
#    'olive oil',
#    'salt',
#    'sandwich buns',
#    'white vinegar'}],
#  ['261215',
#   {'baking soda',
#    'boiling water',
#    'brown sugar',
#    'cinnamon',
#    'cream',
#    'egg',
#    'flour',
#    'margarine',
#    'nutmeg',
#    'nuts',
#    'quick oats',
#    'salt',
#    'shredded coconut',
#    'vanilla'}],
#  ['179640', {'butter', 'marshmallows', 'rice krispies'}],
#  ['250883',
#   {'cool whip topping',
#    'cream cheese',
#    'frozen limeade concentrate',
#    'orange juice'}],
#  ['140855',
#   {'avocado',
#    'cheddar cheese',
#    'chili powder',
#    'corn chips',
#    'garlic',
#    'green onion',
#    'lemon juice',
#    'lettuce',
#    'pitted ripe olives',
#    'salad oil',
#    'salt',
#    'sour cream',
#    'sugar',
#    'tabasco sauce',
#    'tomato',
#    'tuna'}],
#  ['120297',
#   {'baking potatoes',
#    'chickpeas',
#    'coriander',
#    'fresh coriander',
#    'garlic',
#    'ground cumin',
#    'low-fat yogurt',
#    'olive oil',
#    'salt & freshly ground black pepper',
#    'tahini'}],
#  ['130492',
#   {'baking powder',
#    'buttermilk',
#    'egg',
#    'mayonnaise',
#    'salt',
#    'sugar',
#    'vegetable oil',
#    'yellow cornmeal'}],
#  ['164634',
#   {'apple',
#    'carrot',
#    'gingerroot',
#    'green cabbage',
#    'green onion',
#    'maple syrup',
#    'red cabbage',
#    'rice vinegar',
#    'sesame oil',
#    'soy sauce'}],
#  ['293836',
#   {'black pepper',
#    'canola oil',
#    'chicken soup powder',
#    'garlic powder',
#    'long-grain rice',
#    'orzo pasta',
#    'turmeric',
#    'water'}],
#  ['169586',
#   {'avocado',
#    'celery ribs',
#    'chicken breast',
#    'chicken broth',
#    'chipotle chiles in adobo',
#    'crushed tomatoes',
#    'cumin',
#    'ear of corn',
#    'fresh cilantro',
#    'green bell pepper',
#    'jalapeno pepper',
#    'salt and pepper',
#    'white onion'}],
#  ['261296',
#   {'black pepper',
#    'dried basil',
#    'egg white',
#    'eggplant',
#    'fat free mozzarella cheese',
#    'fiber one cereal',
#    'garlic powder',
#    'italian-style tomato sauce',
#    'reduced-fat parmesan cheese',
#    'salt'}],
#  ['101115', {'beef gravy', 'egg', 'ground beef', 'onion', 'white rice'}],
#  ['271594',
#   {'beans',
#    'black pepper',
#    'black-eyed peas',
#    'carrot',
#    'celery ribs',
#    'garlic',
#    'great northern beans',
#    'ham',
#    'ham bone',
#    'ham soup base',
#    'navy beans',
#    'onion',
#    'pinto beans',
#    'salt',
#    'tomatoes and green chilies',
#    'water'}],
#  ['164291',
#   {'cider vinegar',
#    'feta cheese',
#    'fresh dill',
#    'garlic',
#    'light mayonnaise',
#    'red bell pepper',
#    'skinless chicken breast half'}],
#  ['251528',
#   {'cheese ravioli',
#    'garlic salt',
#    'italian seasoning',
#    'lean ground beef',
#    'mozzarella cheese',
#    'spaghetti sauce'}],
#  ['250833',
#   {'barbecue sauce',
#    'chicken pieces',
#    'lemon juice',
#    'orange marmalade',
#    'worcestershire sauce'}],
#  ['343448',
#   {'coriander',
#    'garlic powder',
#    'ground black pepper',
#    'ground red pepper',
#    'onion powder',
#    'paprika',
#    'salt',
#    'turmeric'}],
#  ['39893',
#   {'black olives',
#    'cream cheese',
#    'green onion',
#    'green pepper',
#    'lettuce',
#    'mayonnaise',
#    'mexican blend cheese',
#    'sour cream',
#    'taco seasoning mix',
#    'tomato'}],
#  ['147477',
#   {'green bell peppers',
#    'green onions',
#    'minced clams',
#    'paprika',
#    'sharp cheddar cheese',
#    'tabasco sauce',
#    'worcestershire sauce'}],
#  ['223349',
#   {'eggplants',
#    'olive oil',
#    'olives',
#    'oregano',
#    'red bell pepper',
#    'red onion',
#    'shrimp',
#    'spaghetti squash',
#    'yellow bell pepper'}],
#  ['86768',
#   {'butter', "confectioners' sugar", 'heavy cream', 'semisweet chocolate'}],
#  ['197001',
#   {'cherry pie filling',
#    'crushed pineapple',
#    'frozen whipped topping',
#    'pecans',
#    'small marshmallow',
#    'sweetened condensed milk'}],
#  ['60938',
#   {'bacon',
#    'cheddar cheese',
#    'green onions',
#    'oil',
#    'potato',
#    'salt',
#    'sour cream'}],
#  ['228491',
#   {'black pepper',
#    'boneless eye of round beef steak',
#    'canola oil',
#    'mozzarella cheese',
#    'onion',
#    'parmesan cheese',
#    'pizza sauce',
#    'plain flour',
#    'salt'}],
#  ['451515',
#   {'bacon grease',
#    'boneless country-style ribs',
#    "campbell's golden mushroom soup",
#    'flour',
#    'ground black pepper',
#    'oregano',
#    'seasoning salt',
#    'soup mix'}],
#  ['353171', {'butter', 'egg', 'flour', 'fruit', 'milk', 'sugar'}],
#  ['354039',
#   {'apples',
#    'baby carrots',
#    'butter',
#    'cardamom',
#    'crescent roll dough',
#    'ground cinnamon',
#    'honey',
#    'sugar'}],
#  ['302399',
#   {'garlic salt',
#    'italian seasoning',
#    'mozzarella cheese',
#    'olive oil',
#    'refrigerated biscuits'}],
#  ['195736',
#   {'active dry yeast', 'butter', 'flour', 'milk', 'salt', 'sugar', 'water'}],
#  ['365946',
#   {'butter',
#    'cream cheese',
#    'egg',
#    'egg yolk',
#    'egg yolks',
#    'flour',
#    'lemon peel',
#    'salt',
#    'sugar',
#    'vanilla',
#    'whipping cream'}],
#  ['221544',
#   {'chili sauce',
#    'country-style dijon mustard',
#    'honey',
#    'little smokies sausages'}],
#  ['175306',
#   {'bacardi dark rum',
#    'grenadine',
#    "meyer's dark rum",
#    'orange curacao',
#    'orange juice',
#    'orgeat syrup',
#    'pineapple juice',
#    'prepared sweet-and-sour mix',
#    'white rum'}],
#  ['211833',
#   {'balsamic vinaigrette',
#    'condensed chicken broth',
#    'dried thyme leaves',
#    'minute white rice',
#    'onion',
#    'pork chops',
#    'red apples',
#    'sliced mushrooms',
#    'water'}],
#  ['276567',
#   {'chili powder',
#    'fresh ground black pepper',
#    'green bell peppers',
#    'horseradish',
#    'onion',
#    'orange juice',
#    'plain nonfat yogurt',
#    'prepared mustard',
#    'red bell peppers',
#    'reduced-calorie mayonnaise',
# ...
#    'egg',
#    'flour',
#    'nuts',
#    'sugar',
#    'vanilla'}],
#  ['79425',
#   {'butter',
#    'caramels',
#    'chocolate cake mix',
#    'chocolate chips',
#    'evaporated milk',
#    'nuts'}],
#  ['213681',
#   {'baking soda',
#    'bananas',
#    'canola oil',
#    'egg',
#    'flour',
#    'raisins',
#    'salt',
#    'sugar',
#    'walnuts'}],
#  ['121712', {'cream cheese', 'thousand island dressing'}],
#  ['155344',
#   {'chili sauce', 'mayonnaise', 'onion powder', 'sweet pickle relish'}],
#  ['175339',
#   {'baking soda',
#    'brown sugar',
#    'chocolate chips',
#    'cream of tartar',
#    'egg',
#    'flaked coconut',
#    'flour',
#    'margarine',
#    'oil',
#    'rice krispies',
#    'rolled oats',
#    'vanilla',
#    'white sugar'}],
#  ['72600',
#   {'baby spinach',
#    'bacon',
#    'buttermilk',
#    'fresh lemon juice',
#    'garlic',
#    'hardboiled egg',
#    'mushrooms',
#    'plain yogurt',
#    'sugar',
#    'unsalted sunflower seeds',
#    'white pepper'}],
#  ['50614',
#   {'bacon',
#    'cauliflower',
#    'cherry tomatoes',
#    'fresh broccoli',
#    'fresh mushrooms',
#    'frozen peas',
#    'green pepper',
#    'italian seasoning',
#    'lettuce',
#    'mayonnaise',
#    'red onion',
#    'sugar'}],
#  ['133784',
#   {'basil leaves',
#    'black pepper',
#    'celery salt',
#    'chili powder',
#    'garlic powder',
#    'ground allspice',
#    'ground oregano',
#    'marjoram leaves',
#    'onion salt',
#    'paprika',
#    'rubbed sage'}],
#  ['235003', {'beer', 'fresh jalapeno', 'ice', 'vodka'}],
#  ['140723',
#   {'anchovy fillets',
#    'baby spinach',
#    'bacon',
#    'dijon mustard',
#    'extra virgin olive oil',
#    'french bread',
#    'fresh mushrooms',
#    'garlic',
#    'lemon juice',
#    'low-fat mayonnaise',
#    'miracle whip light',
#    'oil',
#    'olive oil',
#    'parmesan cheese',
#    'worcestershire sauce'}],
#  ['326839',
#   {'dried italian seasoning',
#    'egg',
#    'ground beef',
#    'ground pepper',
#    'italian cheese blend',
#    'jumbo pasta shells',
#    'mexican blend cheese',
#    'mozzarella cheese',
#    'parmesan-romano cheese mix',
#    'parsley flakes',
#    'ricotta cheese',
#    'salt',
#    'spaghetti sauce'}],
#  ['467326',
#   {'bread machine yeast',
#    'brown sugar',
#    'oil',
#    'salt',
#    'water',
#    'white flour',
#    'whole wheat flour'}],
#  ['43669',
#   {'butter',
#    'cream-style corn',
#    'evaporated milk',
#    'onion',
#    'potato',
#    'salt and pepper',
#    'water',
#    'whole corn'}],
#  ['73566',
#   {'black pepper',
#    'extra virgin olive oil',
#    'flat leaf parsley',
#    'italian seasoned breadcrumbs',
#    'kosher salt',
#    'orecchiette',
#    'parmesan cheese',
#    'prosciutto'}],
#  ['449768',
#   {'cumin seeds', 'fresh ground black pepper', 'olive oil', 'salt', 'tomato'}],
#  ['404661',
#   {'baking soda',
#    'butter',
#    'corn syrup',
#    'molasses',
#    'salted peanuts',
#    'vanilla',
#    'white sugar'}],
#  ['381713',
#   {'bulgar wheat',
#    'cinnamon',
#    'lean ground beef',
#    'onion',
#    'plain yogurt',
#    'salt'}],
#  ['257696',
#   {'apple pie filling',
#    'egg',
#    'instant vanilla pudding',
#    'oil',
#    'water',
#    'yellow cake mix'}],
#  ['187606',
#   {'boneless skinless chicken breasts',
#    'carrot',
#    'italian dressing',
#    'potato'}],
#  ['91515', {'chocolate milk', 'cinnamon rolls', 'egg'}],
#  ['289891',
#   {'baking powder',
#    'butter',
#    'egg',
#    'flour',
#    'milk',
#    'salt',
#    'vanilla',
#    'white sugar'}],
#  ['412073',
#   {'basil',
#    'black pepper',
#    'carrot',
#    'celery',
#    'garlic',
#    'ham',
#    'leeks',
#    'salt',
#    'soup mix',
#    'thyme',
#    'water',
#    'worcestershire sauce'}],
#  ['123746',
#   {'bell peppers',
#    'chili sauce',
#    'egg',
#    'garlic powder',
#    'ground beef',
#    'milk',
#    'onion',
#    'salt and pepper',
#    'saltine crackers',
#    'worcestershire sauce'}],
#  ['206020',
#   {'aluminum foil',
#    'beef tenderloin',
#    'garlic',
#    'limes, juice of',
#    'prepared horseradish',
#    'salt and pepper',
#    'sour cream',
#    'unsalted butter',
#    'worcestershire sauce'}],
#  ['345595',
#   {'baking powder',
#    'baking soda',
#    'carrot',
#    'cinnamon',
#    'cream cheese',
#    'egg',
#    'flour',
#    'margarine',
#    'oil',
#    'pineapple',
#    'powdered sugar',
#    'salt',
#    'sugar',
#    'walnuts'}],
#  ['129227',
#   {'cabbage',
#    'carrot',
#    'celery seed',
#    'mustard seeds',
#    'onion',
#    'salt',
#    'sugar',
#    'turmeric',
#    'water',
#    'white vinegar'}],
#  ['472955',
#   {'alum',
#    'pickling cucumbers',
#    'pickling spices',
#    'salt',
#    'sugar',
#    'vinegar',
#    'water'}],
#  ['17490',
#   {'alum',
#    'canning salt',
#    'cucumbers',
#    'pickling spices',
#    'sugar',
#    'vinegar'}],
#  ['130002',
#   {'allspice',
#    'baking soda',
#    'carrot',
#    'cinnamon',
#    'coconut',
#    'cream cheese',
#    'egg',
#    'flour',
#    'ground cloves',
#    'margarine',
#    'nuts',
#    'oil',
#    'powdered sugar',
#    'raisins',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['53353', {'butter', 'cream', 'lemon extract', 'maple syrup', 'nutmeats'}],
#  ['105756',
#   {'basil',
#    'beans',
#    'carrot',
#    'celery',
#    'chicken bouillon cubes',
#    'chicken broth',
#    'deli ham',
#    'lemon juice',
#    'onion',
#    'parsley',
#    'raw rice',
#    'salt',
#    'tomato',
#    'v8 vegetable juice',
#    'water'}],
#  ['307362',
#   {'hormel chili without beans',
#    'monterey jack cheese',
#    'refried beans',
#    'tortillas'}],
#  ['51803',
#   {'15 bean soup mix',
#    'black pepper',
#    'celery leaves',
#    'chicken bouillon cubes',
#    'dried parsley',
#    'dried rosemary',
#    'garlic',
#    'ham hocks',
#    'olive oil',
#    'onion',
#    'salt',
#    'whole tomatoes'}],
#  ['438263',
#   {'15 bean soup mix',
#    'beef bouillon paste',
#    'black pepper',
#    'diced tomatoes',
#    'garlic',
#    'ham bone',
#    'smoked sausage',
#    'steak sauce',
#    'water',
#    'worcestershire sauce'}],
#  ['525649',
#   {'black pepper',
#    'carrot',
#    'cayenne pepper',
#    'chili powder',
#    'condensed tomato soup',
#    'dried beans',
#    'garlic',
#    'ham',
#    'lemon',
#    'olive oil',
#    'onion',
#    'oregano',
#    'paprika',
#    'salt',
#    'smoked paprika',
#    'thyme',
#    'water'}],
#  ['115160',
#   {'baking soda',
#    'egg',
#    'flour',
#    'ground walnuts',
#    'honey',
#    'liquid honey',
#    'margarine',
#    'plain sweet biscuit crumbs',
#    'sour cream',
#    'sugar'}],
#  ['168222',
#   {'capers',
#    'chicken stock',
#    'fresh chives',
#    'fresh parsley',
#    'fresh tarragon',
#    'garlic',
#    'halibut steaks',
#    'lemon juice',
#    'salt and pepper'}],
#  ['140172',
#   {'boneless sirloin steak',
#    'lipton beefy mushroom soup mix',
#    'new potatoes',
#    'oil',
#    'peas and carrots',
#    'tomato paste',
#    'water'}],
#  ['305112',
#   {'black beans',
#    'frozen corn kernels',
#    'ground beef',
#    'taco seasoning',
#    'tomatoes and green chilies'}],
#  ['53481',
#   {'cheddar cheese',
#    'ketchup',
#    'lean ground beef',
#    'minute white rice',
#    'mustard',
#    'water'}],
#  ['76887',
#   {'chili with beans',
#    'diced tomatoes',
#    'ground beef',
#    'velveeta cheese',
#    'water',
#    'white rice'}],
#  ['392598',
#   {'boneless skinless chicken breast halves',
#    'condensed cream of chicken soup',
#    'ground pepper',
#    'instant rice',
#    'paprika',
#    'vegetable oil',
#    'water'}],
#  ['113197',
#   {'black pepper',
#    'cheese',
#    'chicken breast tenders',
#    'fajita seasoning mix',
#    'lime',
#    'olive oil',
#    'onion',
#    'pico de gallo',
#    'sour cream',
#    'tortilla'}],
#  ['398071',
#   {'cheddar cheese',
#    'chicken',
#    'chicken broth',
#    'kidney beans',
#    'mexicorn',
#    'salsa',
#    'sour cream',
#    'tortilla chips'}],
#  ['66527',
#   {'boneless skinless chicken breasts',
#    'broccoli florets',
#    'condensed cream of chicken soup',
#    'milk',
#    'minute rice',
#    'vegetable oil'}],
#  ['184890',
#   {'chili powder',
#    'cumin',
#    'ground turkey',
#    'kidney beans',
#    'onion',
#    'pinto beans',
#    'salsa',
#    'salt',
#    'stewed tomatoes'}],
#  ['79046',
#   {'cheese',
#    'chili with beans',
#    'flour tortillas',
#    'sour cream',
#    'water',
#    'white minute rice'}],
#  ['356163',
#   {'broccoli',
#    'chili powder',
#    'ketchup',
#    'lean ground beef',
#    'macaroni & cheese dinner mix',
#    'water'}],
#  ['41673',
#   {'allspice',
#    'black pepper',
#    'brown sugar',
#    'cinnamon',
#    'clove',
#    'onion',
#    'salt',
#    'tomato'}],
#  ['506885',
#   {'black pepper',
#    'crushed red pepper flakes',
#    'fresh basil',
#    'fresh oregano',
#    'fresh parmesan cheese',
#    'garlic',
#    'grape tomatoes',
#    'pappardelle pasta',
#    'roasted cashews',
#    'sun-dried tomato packed in oil'}],
#  ['277539',
#   {'chipotle chile in adobo',
#    'garlic',
#    'ground coriander',
#    'ground cumin',
#    'low sodium chicken broth',
#    'onion',
#    'salt',
#    'tomato sauce'}],
#  ['169487',
#   {'fat free cream cheese',
#    'fat-free whipped topping',
#    'reduced fat graham cracker crust',
#    'sugar substitute'}],
#  ['317587',
#   {'fresh linguine',
#    'fresh spinach',
#    'lemon juice',
#    'parmesan cheese',
#    'pesto sauce',
#    'pine nuts',
#    'red onion',
#    'tomato'}],
#  ['20624',
#   {'boneless skinless chicken breast halves',
#    'butter',
#    'chicken broth',
#    'flour',
#    'garlic',
#    'lemon juice',
#    'oil',
#    'salt and pepper'}],
#  ['360232',
#   {'celery ribs',
#    'cracked black pepper',
#    'extra virgin olive oil',
#    'feta cheese',
#    'fresh lemon juice',
#    'fresh parsley',
#    'garbanzo beans',
#    'garlic',
#    'of fresh mint',
#    'romaine lettuce',
#    'salt',
#    'scallion',
#    'tomato'}],
#  ['246548',
#   {'assorted fresh vegetables',
#    'boneless skinless chicken breast',
#    'instant rice',
#    'italian dressing',
#    'oil',
#    'reduced-sodium fat-free chicken broth'}],
#  ['67446',
#   {'butter',
#    'cream cheese',
#    'graham cracker crumbs',
#    'instant lemon pudding',
#    'milk',
#    'powdered sugar'}],
#  ['153028',
#   {'butter', 'cocoa', "confectioners' sugar", 'peanut butter', 'vanilla'}],
#  ['172651',
#   {'italian salad dressing',
#    'parmesan cheese',
#    'smoked turkey breast',
#    'spaghetti',
#    'tomato'}],
#  ['348952',
#   {'chicken bouillon cube',
#    'frozen mixed vegetables',
#    'minute rice',
#    'oil',
#    'pork tenderloin',
#    'soy sauce',
#    'water'}],
#  ['5276',
#   {'chicken bouillon cubes',
#    'green pepper',
#    'hot pepper sauce',
#    'kidney beans',
#    'minute white rice',
#    'oil',
#    'onion',
#    'water'}],
#  ['140173',
#   {'baby peas',
#    'bacon bits',
#    'black pepper',
#    'fettuccine',
#    'garlic salt',
#    'half-and-half cream',
#    'parmesan cheese',
#    'shrimp'}],
#  ['31184',
#   {'angel hair pasta',
#    'butter',
#    'extra virgin olive oil',
#    'frozen shrimp',
#    'garlic',
#    'onion',
#    'salt & pepper',
#    'white wine'}],
#  ['164178',
#   {'celery',
#    'garlic flakes',
#    'hamburger',
#    'hot chili flakes',
#    'jalapenos',
#    'onion',
#    'sliced mushrooms',
#    'sweet green pepper',
#    'sweet red pepper',
#    'tomato sauce & mushrooms'}],
#  ['289025',
#   {'asparagus',
#    'boneless skinless chicken breast',
#    'chicken broth',
#    'chili flakes',
#    'fresh ginger',
#    'garlic',
#    'onion',
#    'rice vinegar',
#    'salt',
#    'soy sauce',
#    'white pepper'}],
#  ['287502',
#   {'dijon mustard',
#    'elbow macaroni',
#    'extra-sharp cheddar cheese',
#    'fresh ground black pepper',
#    'half-and-half',
#    'hot sauce',
#    'kosher salt',
#    'unsalted butter'}],
#  ['75079',
#   {'butter',
#    'dry onion soup mix',
#    'flour',
#    'fresh mushrooms',
#    'round steak',
#    'sour cream',
#    'water'}],
#  ['147100',
#   {'chopped tomatoes',
#    'extra lean ground beef',
#    'lettuce',
#    'mexican blend cheese',
#    'minute white rice',
#    'taco seasoning mix',
#    'water'}],
#  ['233317',
#   {'baby spinach',
#    'cornflour',
#    'dark soy sauce',
#    'lime, juice and zest of',
#    'pak choi',
#    'sunflower oil',
#    'sweet chili sauce',
#    'thai fish sauce',
#    'tiger shrimp',
#    'water'}],
#  ['109793', {'milk', 'minute rice', 'raisins', 'vanilla instant pudding mix'}],
#  ['291409',
#   {'black beans', 'fire-roasted tomatoes', 'kidney beans', 'salsa', 'water'}],
#  ['27275',
#   {'cream cheese',
#    'fettuccine pasta',
#    'margarine',
#    'milk',
#    'parmesan cheese'}],
#  ['282812',
#   {'dried fruits',
#    'honey',
#    'milk',
#    'quick oats',
#    'salt',
#    'sugar',
#    'vanilla',
#    'water'}],
#  ['311608',
#   {'15 bean mix',
#    'bay leaves',
#    'black pepper',
#    'carrot',
#    'celery',
#    'chicken bouillon cubes',
#    'diced tomatoes',
#    'garlic',
#    'ham hocks',
#    'onion',
#    'seasoning salt',
#    'tomato sauce',
#    'water'}],
#  ['382234',
#   {'black-eyed peas',
#    'canned green beans',
#    'chili seasoning mix',
#    'corn chips',
#    'dark red kidney beans',
#    'green bell pepper',
#    'ground beef',
#    'ketchup',
#    'onion',
#    'red pepper flakes',
#    'salt and pepper',
#    'sharp cheddar cheese',
#    'vegetable oil',
#    'water',
#    'whole tomatoes'}],
#  ['237391',
#   {'brandy',
#    'butter',
#    'chicken liver',
#    'garlic',
#    'ground black pepper',
#    'heavy cream',
#    'marjoram',
#    'onion',
#    'sage',
#    'salt',
#    'thyme'}],
#  ['266997',
#   {'cayenne pepper',
#    'chili beans',
#    'chili powder',
#    'cumin',
#    'diced tomatoes',
#    'lean ground beef',
#    'onion',
#    'oregano',
#    'salt',
#    'sliced mushrooms',
#    'sour cream'}],
#  ['21916',
#   {'cool whip topping',
#    'frozen pound cake',
#    'jello instant vanilla pudding mix',
#    'orange liqueur',
#    'strawberries',
#    'strawberry',
#    'sugar',
#    'white chocolate baking squares'}],
#  ['229451',
#   {'black pepper',
#    'boneless skinless chicken breast halves',
#    'dijon mustard',
#    'dried tarragon',
#    'fresh lemon juice',
#    'worcestershire sauce'}],
#  ['204040', {'basmati rice', 'chicken broth', 'salt and pepper'}],
#  ['82287',
#   {'black olives',
#    'cooked chicken',
#    'cream of chicken soup',
#    'green enchilada sauce',
#    'green onion',
#    'lettuce',
#    'monterey jack cheese',
#    'salsa',
#    'sour cream',
#    'tomato',
#    'tortilla chips'}],
#  ['302815', {'butter', 'garlic', 'parmesan cheese', 'pasta'}],
#  ['311842',
#   {'black pepper',
#    'dried oregano',
#    'feta cheese',
#    'garlic',
#    'large shrimp',
#    'old bay seasoning',
#    'olive oil',
#    'parsley',
#    'tomato'}],
#  ['531148',
#   {'cherry tomatoes',
#    'corn kernels',
#    'herbs',
#    'large shrimp',
#    'lemon, zest of',
#    'olive oil',
#    'red onion',
#    'salt & freshly ground black pepper',
#    'snap peas',
#    'unsalted butter',
#    'zucchini'}],
#  ['364157',
#   {'dried oregano',
#    'fresh lemon juice',
#    'garlic',
#    'olive oil',
#    'parmesan cheese',
#    'salt and pepper',
#    'scallions',
#    'vegetable broth',
#    'white beans'}],
#  ['411979',
#   {'bay leaves',
#    'beans',
#    'carrot',
#    'celery',
#    'chicken stock',
#    'garlic',
#    'italian sausage',
#    'onion',
#    'oregano',
#    'tomato',
#    'water'}],
#  ['102832',
#   {'alum',
#    'cinnamon sticks',
#    'cucumbers',
#    'pickling salt',
#    'pickling spices',
#    'sugar',
#    'white vinegar'}],
#  ['246180', {'barbecue sauce', 'ginger ale', 'onion', 'pork butt'}],
#  ['224908',
#   {'brown sugar',
#    'cold water',
#    'dark molasses',
#    'strong coffee',
#    'sugar',
#    'vanilla bean',
#    'vodka'}],
#  ['364761',
#   {'carrot',
#    'celery',
#    'celery ribs',
#    'chicken bouillon cubes',
#    'chicken broth',
#    'frozen corn',
#    'frozen white corn',
#    'onion',
#    'potato',
#    'whole chickens'}],
#  ['489337',
#   {'basil',
#    'eggplant',
#    'fat-free parmesan cheese',
#    'fennel seed',
#    'lean ground turkey',
#    'low-carb marinara sauce',
#    'nonstick cooking spray',
#    'oregano leaves'}],
#  ['262448', {'mountain dew soda', 'raspberry vodka'}],
#  ['294427',
#   {'apple cider',
#    'arugula',
#    'dijon mustard',
#    'fresh thyme',
#    'gouda cheese',
#    'olive oil',
#    'pancetta',
#    'red onion',
#    'red wine vinegar',
#    'salt and pepper',
#    'shallots',
#    'sherry wine vinegar',
#    'tart apples',
#    'white cheddar cheese',
#    'white vinegar'}],
#  ['328436',
#   {'baby carrots',
#    'baking powder',
#    'baking soda',
#    "confectioners' sugar",
#    'egg',
#    'flour',
#    'light brown sugar',
#    'marshmallow cream',
#    'pumpkin pie spice',
#    'pure vanilla extract',
#    'salt',
#    'unsalted butter',
#    'vegetable oil'}],
#  ['357228',
#   {'baking soda',
#    'butter',
#    'buttermilk',
#    'cinnamon',
#    'clove',
#    'cocoa',
#    'egg',
#    'flour',
#    'nutmeg',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['50246',
#   {'almonds',
#    'cornstarch',
#    'cream of tartar',
#    'egg',
#    'egg yolks',
#    'flour',
#    'milk',
#    'powdered sugar',
#    'sugar',
#    'sweet cream'}],
#  ...]

# %% [markdown]
# Reshape the data into a vector of vectors of ingredients per recipe, to use for training a [*word2vec*](https://arxiv.org/abs/1301.3781) vector embedding model:

# %%
vectors = []

for id, ind_set in recipes:
    v = []
    
    for ind in ind_set:
        v.append(ind)

    vectors.append(v)

vectors
# Out:
# [['mixed spice',
#   'mexican seasoning',
#   'honey',
#   'salt',
#   'olive oil',
#   'butter',
#   'winter squash'],
#  ['milk',
#   'salt and pepper',
#   'cheese',
#   'sausage patty',
#   'prepared pizza crust',
#   'egg'],
#  ['chili powder',
#   'rotel tomatoes',
#   'ground cumin',
#   'cheddar cheese',
#   'tomato soup',
#   'kidney beans',
#   'water',
#   'salt',
#   'lettuce',
#   'tomato paste',
#   'ground beef',
#   'diced tomatoes',
#   'yellow onions'],
#  ['shallots',
#   'new potatoes',
#   'black pepper',
#   'tarragon',
#   'olive oil',
#   'spreadable cheese with garlic and herbs',
#   'salt',
#   'yellow bell pepper',
#   'red bell pepper',
#   'parsley',
#   'red wine vinegar'],
#  ['clove oil',
#   'black pepper',
#   'salt',
#   'sugar',
#   'dry mustard',
#   'tomato juice',
#   'apple cider vinegar',
#   'cinnamon oil'],
#  ['milk', 'apple', 'vanilla ice cream', 'frozen apple juice concentrate'],
#  ['orange juice',
#   'red chile',
#   'orange rind',
#   'fennel seeds',
#   'extra virgin olive oil',
#   'green olives',
#   'ripe olives',
#   'garlic',
#   'peppercorn'],
#  ['honey',
#   'orange, juice of',
#   'tomato sauce',
#   'dry mustard',
#   'cinnamon sticks',
#   'a.1. original sauce',
#   'yellow onion',
#   'fresh cilantro leaves',
#   'pork spareribs',
#   'fresh garlic',
#   'liquid smoke',
#   'cracked black pepper',
#   'white vinegar',
#   'brown sugar',
#   'fresh ginger',
#   'mirin',
#   'soy sauce',
#   'cumin',
#   'chili powder',
#   'fresh coarse ground black pepper',
#   'water',
#   'salt'],
#  ['chocolate syrup',
#   'strawberry ice cream',
#   'vanilla ice cream',
#   'bananas',
#   'whipped cream',
#   'chocolate sandwich style cookies'],
#  ['orange rind',
#   'fresh lemon juice',
#   'unsalted butter',
#   'cake flour',
#   'salt',
#   'bananas',
#   'baking soda',
#   'egg',
#   'sugar'],
#  ['whole berry cranberry sauce', 'prepared horseradish', 'sour cream'],
#  ['strawberry',
#   'powdered sugar',
#   'whipping cream',
#   'vanilla wafers',
#   'walnuts',
#   'butter',
#   'egg'],
#  ['cornstarch',
#   'garlic powder',
#   'great northern bean',
#   'chili powder',
#   'black pepper',
#   'mustard powder',
#   'water',
#   'salt',
#   'chicken bouillon cubes',
#   'onion',
#   'bacon',
#   'dark brown sugar',
#   'molasses'],
#  ['ham hock',
#   'collard greens',
#   'whiskey',
#   'brown sugar',
#   'salt',
#   'hot sauce',
#   'molasses'],
#  ['spearmint', 'scullcap herb', 'burnet root', 'gentian root', 'wood bethony'],
#  ['garlic powder',
#   'flour',
#   'oil',
#   'salt',
#   'dry mustard',
#   'lean pork chops',
#   'chicken rice soup'],
#  ['egg roll wrap', 'cornstarch', 'cheese', 'oil', 'whole green chilies'],
#  ['chinese noodles', 'salted peanuts', 'butterscotch chips'],
#  ['ground pork',
#   'beef broth',
#   'celery',
#   'cooking oil',
#   'hamburger buns',
#   'onion',
#   'soy sauce'],
#  ['salt and pepper',
#   'fresh herb',
#   'cauliflower',
#   'salt free herb and spice seasoning mix',
#   'great northern bean',
#   'broccoli floret',
#   'canola oil',
#   'water',
#   'escarole',
#   'green peas',
#   'onion',
#   'ground coriander',
#   'red bell pepper',
#   'garlic',
#   'vegetable bouillon cubes',
#   'potato'],
#  ['fresh spinach leaves',
#   'coarse salt',
#   'unsalted butter',
#   'water',
#   'salt',
#   'fresh ground black pepper',
#   'nutmeg',
#   'boiling potatoes'],
#  ['rolled oats',
#   'dried thyme',
#   'celery',
#   'apple juice',
#   'spinach',
#   'salt',
#   'fresh parsley',
#   'olive oil',
#   'onion',
#   'white pepper',
#   'broth',
#   'scallion'],
#  ['salt and pepper',
#   'cornstarch',
#   'garlic powder',
#   'flour',
#   'boneless skinless chicken breast halves',
#   'seasoning salt',
#   'paprika',
#   'oil',
#   'condensed cream of chicken soup',
#   'egg'],
#  ['granulated sugar',
#   'bread',
#   'milk',
#   'powdered sugar',
#   'vanilla',
#   'vegetable oil',
#   'flour',
#   'brown sugar',
#   'salt',
#   'baking powder',
#   'butter',
#   'egg',
#   'ground cinnamon'],
#  ['lemon, juice of', 'salt', 'butter', 'white pepper', 'egg yolks'],
#  ['ground turmeric',
#   'ground cumin',
#   'black cumin',
#   'ground ginger',
#   'ground coriander',
#   'ground black pepper'],
#  ['chili powder',
#   'black pepper',
#   'jalapenos',
#   'celery',
#   'kidney beans',
#   'salt',
#   'garlic',
#   'vegetarian ground beef',
#   'green pepper',
#   'diced tomatoes',
#   'onion',
#   'red pepper flakes'],
#  ['dried parsley',
#   'beef bouillon cube',
#   'garbanzo beans',
#   'beef stew meat',
#   'elbow macaroni',
#   'ground pepper',
#   'zucchini',
#   'water',
#   'salt',
#   'tomato',
#   'cabbage',
#   'ground thyme',
#   'onion',
#   'parmesan cheese'],
#  ['margarine', 'rosemary', 'red potatoes'],
#  ['tabasco sauce',
#   'cornstarch',
#   'broccoli floret',
#   'dry white wine',
#   'dried thyme',
#   'chicken stock',
#   'dried oregano',
#   'worcestershire sauce',
#   'unsalted butter',
#   'celery',
#   'smoked chicken',
#   'salt & fresh ground pepper',
#   'broccoli stem',
#   'onion',
#   'black beans',
#   'carrot',
#   'heavy cream',
#   'dried sweet basil leaves'],
#  ['miniature peppermint patties',
#   'baking cocoa',
#   'vanilla',
#   'flour',
#   'salt',
#   'baking powder',
#   'butter',
#   'egg',
#   'sugar'],
#  ['tabasco sauce',
#   'sliced ripe olives',
#   'cornmeal',
#   'black pepper',
#   'whole kernel corn',
#   'cheddar cheese',
#   'onion',
#   'salt',
#   'taco sauce',
#   'ground beef',
#   'tomato sauce',
#   'hot chili pepper'],
#  ['butter', 'dry ranch dressing mix', 'french bread'],
#  ['black pepper',
#   'fresh breadcrumb',
#   'ground venison',
#   'worcestershire sauce',
#   'egg substitute',
#   'water',
#   'salt',
#   'non-fat powdered milk',
#   'onion',
#   'dry mustard'],
#  ['milk', 'plain yogurt', 'frozen juice concentrate'],
#  ['wax beans',
#   'zucchini',
#   'green beans',
#   'corn',
#   'diced tomatoes',
#   'low sodium chicken broth',
#   'carrot',
#   'potato'],
#  ['crouton',
#   'black pepper',
#   'condensed cream of mushroom soup',
#   'sharp cheddar cheese',
#   'salt',
#   'frozen chopped spinach',
#   'onion',
#   'egg'],
#  ['diced pimentos',
#   'black pepper',
#   'low-fat sour cream',
#   'red potatoes',
#   'prepared mustard',
#   'salt',
#   'green onion',
#   'sugar',
#   'white wine vinegar',
#   'garlic',
#   'fat-free mayonnaise',
#   'celery seed',
#   'plain low-fat yogurt'],
#  ['garlic powder',
#   'soft breadcrumbs',
#   'oregano',
#   'sage',
#   'frozen chopped spinach',
#   'margarine',
#   'onion',
#   'egg'],
#  ['frozen vegetables',
#   'condensed cream of mushroom & garlic soup',
#   'cream of mushroom soup',
#   'salt & pepper',
#   'cooking oil',
#   'ground beef',
#   'onion',
#   'cornbread mix'],
#  ['green onions',
#   'angel hair pasta',
#   'toasted sesame oil',
#   'toasted sesame seeds',
#   'honey',
#   'stir fry vegetables',
#   'garlic',
#   'soy sauce'],
#  ['unsweetened cocoa',
#   'yam',
#   'honey',
#   'egg',
#   'ground cinnamon',
#   'orange juice',
#   'pecans',
#   'low-fat buttermilk',
#   'butter',
#   'ground cloves',
#   'canola oil',
#   'brown sugar',
#   'baking soda',
#   'buckwheat flour',
#   'orange rind',
#   'cinnamon',
#   'flour',
#   'salt',
#   'baking powder',
#   'sugar'],
#  ['granulated sugar',
#   'orange juice',
#   'buckwheat flour',
#   'unsweetened cocoa',
#   'low-fat buttermilk',
#   'orange rind',
#   'ground cinnamon',
#   'ground cloves',
#   'sorghum',
#   'yam',
#   'canola oil',
#   'boiling water',
#   'flour',
#   'salt',
#   'raisins',
#   'baking powder',
#   'egg',
#   'baking soda'],
#  ['prepared yellow mustard',
#   'beer',
#   'salt & pepper',
#   'cayenne',
#   'ground beef',
#   'american cheese',
#   'garlic',
#   'sugar'],
#  ['salt and pepper',
#   'cider vinegar',
#   'garlic powder',
#   'tri-color spiral pasta',
#   'italian seasoning',
#   'cheese',
#   'onion powder',
#   'water chestnut',
#   'ripe olives',
#   'chives',
#   'green onion',
#   'tomato',
#   'ham',
#   'olive oil',
#   'sweet pepper',
#   'dill pickles'],
#  ['frozen french fries',
#   'oregano',
#   'flat leaf parsley',
#   'oil',
#   'basil',
#   'salt & freshly ground black pepper',
#   'parmesan cheese'],
#  ['deli turkey',
#   'mozzarella cheese',
#   'swiss cheese',
#   'cheddar cheese',
#   'good seasonings italian salad dressing mix',
#   'pepperoni',
#   'ham',
#   'sandwich bun',
#   'butter'],
#  ['milk',
#   'vanilla',
#   'shortening',
#   'flour',
#   'salt',
#   'icing sugar',
#   'baking powder',
#   'butter',
#   'egg',
#   'sugar'],
#  ['pecans',
#   'yellow cake mix',
#   'cinnamon',
#   'crushed pineapple',
#   'oil',
#   'nutmeg',
#   'water',
#   'carrot',
#   'vanilla instant pudding mix',
#   'coconut',
#   'egg'],
#  ['jiffy corn muffin mix',
#   'jalapenos',
#   'whole kernel corn',
#   'sharp cheddar cheese',
#   'honey',
#   'red bell pepper',
#   'onion',
#   'butter',
#   'egg',
#   'heavy cream'],
#  ['milk',
#   'dry yeast',
#   'cinnamon',
#   'vanilla',
#   'vegetable oil',
#   'crushed pineapple',
#   'flour',
#   'water',
#   'salt',
#   'nuts',
#   'brown sugar',
#   'raisins',
#   'baking powder',
#   'butter',
#   'egg',
#   'baking soda',
#   'sugar'],
#  ['dried basil',
#   'cottage cheese',
#   'lasagna noodle',
#   'mozzarella cheese',
#   'whole tomato',
#   'parsley flakes',
#   'salt',
#   'italian sausage',
#   'ground beef',
#   'tomato paste',
#   'garlic',
#   'parmesan cheese',
#   'ricotta cheese',
#   'egg',
#   'ground black pepper'],
#  ['olive oil flavored cooking spray',
#   'cottage cheese',
#   'toasted wheat germ',
#   'spices',
#   'black pepper',
#   'cheese',
#   'salt',
#   'beef',
#   'frozen chopped spinach',
#   'egg',
#   'herbs'],
#  ['instant vanilla pudding',
#   'rolls',
#   'cinnamon',
#   'brown sugar',
#   'raisins',
#   'butter'],
#  ['granulated sugar',
#   'prego spaghetti sauce',
#   'white onion',
#   'stewed tomatoes',
#   'ground beef',
#   'garlic'],
#  ['dried dill weed',
#   'spicy mustard',
#   'vegetable oil',
#   'sour cream',
#   'brown sugar',
#   'honey',
#   'beef steaks',
#   'hot sauce',
#   'ketchup',
#   'fresh garlic',
#   'fresh parsley',
#   'fresh lemon juice'],
#  ['milk', 'flour', 'salt', 'baking powder', 'butter', 'egg', 'sugar'],
#  ['dried basil',
#   'pasta',
#   'parmesan cheese',
#   'dried oregano',
#   'water',
#   'fresh ground black pepper',
#   'garlic',
#   'tomato',
#   'hot sauce',
#   'fresh parsley',
#   'salsa',
#   'olive oil',
#   'onion',
#   'chicken breasts',
#   'button mushrooms'],
#  ['fresh herbs', 'cider vinegar', 'fresh herb'],
#  ['fresh corn',
#   'black pepper',
#   'flour',
#   'salt',
#   'fat',
#   'cream',
#   'baking powder',
#   'egg'],
#  ['milk',
#   'black olives',
#   'fettuccine pasta',
#   'picante sauce',
#   'jalapeno',
#   'cheddar cheese soup'],
#  ['frozen peas',
#   'salt',
#   'cilantro',
#   'tomato',
#   'hass avocado',
#   'onion',
#   'lemons, juice of'],
#  ['garlic powder',
#   'black pepper',
#   'worcestershire sauce',
#   'oil',
#   'basil',
#   'soy sauce',
#   'lemon juice'],
#  ['milk', 'cream cheese', 'apple', 'pear', 'yogurt', 'unflavored gelatin'],
#  ['bay leaf',
#   'thyme',
#   'black pepper',
#   'oil',
#   'parsley sprigs',
#   'salt',
#   'veal roast',
#   'onion',
#   'bacon',
#   'butter',
#   'carrot'],
#  ['black pepper', 'crackers', 'mayonnaise', 'tomato'],
#  ['brine',
#   'kalamata olive',
#   'genoa salami',
#   'sweet onion',
#   'capers',
#   'fresh basil',
#   'green olives',
#   'tomato',
#   'provolone cheese',
#   'ham',
#   'olive oil',
#   'garlic',
#   'fresh parsley',
#   'red wine vinegar',
#   'carrot',
#   'oregano leaves',
#   'ciabatta'],
#  ['whipping cream',
#   'powdered sugar',
#   'vanilla',
#   'vanilla instant pudding mix'],
#  ['milk',
#   'gelatin',
#   'cream cheese',
#   'vanilla',
#   'miniature semisweet chocolate chips',
#   'cookie',
#   'prepared graham cracker crusts',
#   'sugar'],
#  ['carrot',
#   'egg',
#   'oregano',
#   'monterey jack cheese',
#   'butter',
#   'cayenne pepper',
#   'sliced mushrooms',
#   'ground cumin',
#   'tomato',
#   'green pepper',
#   'soy sauce',
#   'chili powder',
#   'celery',
#   'zucchini',
#   'flour',
#   'cloves',
#   'water',
#   'salt',
#   'vegetable shortening',
#   'onion',
#   'baking powder'],
#  ['salt and pepper', 'sweet butter', 'half-and-half', 'sweet corn'],
#  ['lemon, rind of',
#   'vanilla',
#   'flour',
#   'salt',
#   'yogurt',
#   'baking soda',
#   'butter',
#   'egg',
#   'sugar'],
#  ['unsweetened chocolate squares',
#   'vanilla',
#   'flour',
#   'nuts',
#   'butter',
#   'egg',
#   'sugar'],
#  ['green onions',
#   'cooked chicken',
#   'vegetable oil',
#   'vermicelli',
#   'fresh cilantro',
#   'fresh ginger',
#   'broccoli',
#   'rice vinegar',
#   'reduced sodium soy sauce',
#   'sesame oil',
#   'chili-garlic sauce',
#   'sesame seeds'],
#  ['philadelphia cream cheese',
#   'orange juice',
#   'pecans',
#   'orange rind',
#   'celery',
#   'apples',
#   'sugar'],
#  ['thyme',
#   'fresh ground pepper',
#   'salt',
#   'paprika',
#   'cayenne',
#   'olive oil',
#   'garlic',
#   'cumin',
#   'lemon juice',
#   'boneless chicken breast'],
#  ['garlic powder',
#   'mozzarella cheese',
#   'baking potato',
#   'part-skim ricotta cheese',
#   'tomato sauce',
#   'parmesan cheese',
#   'oregano leaves'],
#  ['tabasco sauce',
#   'cornstarch',
#   'black pepper',
#   'tomato puree',
#   'mushroom pieces',
#   'white wine',
#   'onion',
#   'sodium-free vegetable broth'],
#  ['red sweet bell peppers',
#   'albacore tuna in water',
#   'red wine vinegar',
#   'white kidney beans',
#   'black pepper',
#   'fresh basil',
#   'light olive oil',
#   'salt',
#   'scallions',
#   'garlic',
#   'bibb lettuce'],
#  ['nutmeg',
#   'carrot',
#   'red pepper flakes',
#   'lean ground beef',
#   'crushed tomatoes',
#   'oregano',
#   'garlic',
#   'butter',
#   'milk',
#   'ground pork',
#   'rubbed sage',
#   'penne pasta',
#   'bacon',
#   'dry white wine',
#   'black pepper',
#   'celery',
#   'salt',
#   'olive oil',
#   'onion',
#   'beef consomme'],
#  ['apples', 'red cinnamon candies', 'water', 'sugar substitute'],
#  ['elbow macaroni',
#   'celery',
#   'brown sugar',
#   'oil',
#   'onion',
#   'tomato',
#   'green pepper',
#   'ketchup',
#   'cucumber',
#   'lemon juice'],
#  ['milk',
#   'cocoa',
#   'vanilla',
#   'vegetable oil',
#   'flour',
#   'brown sugar',
#   'salt',
#   'baking powder',
#   'hot water',
#   'sugar'],
#  ['milk',
#   'powdered sugar',
#   'apple pie filling',
#   'flour',
#   'salt',
#   'toasted almonds',
#   'butter',
#   'egg'],
#  ['white bread', 'bananas', 'mayonnaise'],
#  ['milk',
#   'lean ground beef',
#   'garlic powder',
#   'dry white wine',
#   'dried thyme',
#   'boneless skinless chicken thighs',
#   'dried oregano',
#   'chicken stock',
#   'vegetable oil',
#   'breadcrumbs',
#   'flour',
#   'salt',
#   'fresh ground black pepper',
#   'poultry seasoning',
#   'onion'],
#  ['salmon', 'cream cheese', 'salt', 'onion', 'liquid smoke', 'lemon juice'],
#  ['green beans',
#   'vegetable stock',
#   'tempeh',
#   'carrot',
#   'peanut oil',
#   'garlic',
#   'ground cumin',
#   'brown sugar',
#   'desiccated coconut',
#   'bean sprouts',
#   'tomato',
#   'soy sauce',
#   'ground cayenne pepper',
#   'red chili pepper',
#   'peanuts',
#   'ginger',
#   'water',
#   'sambal oelek',
#   'ground coriander',
#   'onion'],
#  ['salt and pepper',
#   'dried breadcrumbs',
#   'tomato soup',
#   'water',
#   'ground beef',
#   'onion',
#   'egg',
#   'lemon juice',
#   'sugar'],
#  ['salt and pepper',
#   'chunky salsa',
#   'fresh cilantro',
#   'lime juice',
#   'hot sauce',
#   'soft silken tofu',
#   'avocado'],
#  ['cinnamon',
#   'white sugar',
#   'ground cloves',
#   'shortening',
#   'flour',
#   'salt',
#   'bananas',
#   'nutmeg',
#   'baking soda',
#   'walnuts',
#   'egg'],
#  ['dried basil',
#   'salt and pepper',
#   'tomato',
#   'lime juice',
#   'boneless skinless chicken breast',
#   'olive oil'],
#  ['beef ribs',
#   'worcestershire sauce',
#   'vegetable oil',
#   'brown sugar',
#   'water',
#   'salt',
#   'ketchup',
#   'onion',
#   'mustard',
#   'fresh lemon juice'],
#  ['green grape', 'egg whites', 'sugar'],
#  ['milk chocolate candy bars',
#   'vegetable oil',
#   'water',
#   'betty crocker fudge brownie mix',
#   'egg'],
#  ['flour',
#   'water',
#   'salt',
#   'bananas',
#   'nuts',
#   'sugar',
#   'baking soda',
#   'baking powder',
#   'butter',
#   'egg',
#   'chocolate chips'],
#  ['cream cheese',
#   'sweetened condensed milk',
#   'vanilla',
#   'flour',
#   'sour cream',
#   'brown sugar',
#   'butter',
#   'egg',
#   'oreo cookie crumbs',
#   'chocolate chips'],
#  ['banana',
#   'sugar-free non-fat vanilla yogurt',
#   'natural-style peanut butter',
#   '2% low-fat milk'],
#  ['cream cheese',
#   'taco seasoning',
#   'sour cream',
#   'cheddar cheese',
#   'bean dip'],
#  ["mccormick's montreal brand steak seasoning",
#   'no-salt-added ketchup',
#   'dill weed',
#   'ground sirloin',
#   'iceberg lettuce',
#   'tomato',
#   'american cheese',
#   'onion',
#   'bacon'],
#  ['chopped tomato',
#   'paprika',
#   'salt',
#   'chat masala',
#   'cucumber',
#   'plain yogurt',
#   'potato'],
#  ['corn oil',
#   'buttermilk',
#   'cinnamon',
#   'vanilla',
#   'brown sugar',
#   'whole wheat flour',
#   'salt',
#   'carrot',
#   'natural bran',
#   'raisins',
#   'egg',
#   'baking soda'],
#  ['triple sec',
#   'lime wedge',
#   'tequila',
#   'lime juice',
#   'grand marnier',
#   'limeade'],
#  ['pecans', 'flour', 'brown sugar', 'semi-sweet chocolate chips', 'butter'],
#  ['milk',
#   'black pepper',
#   'cappelletti pasta',
#   'cheddar cheese',
#   'tomato soup',
#   'salt',
#   'corn',
#   'mushrooms',
#   'onion',
#   'ground beef',
#   'garlic',
#   'butter',
#   'chopped tomato'],
#  ['salt and pepper',
#   'dry white wine',
#   'extra virgin olive oil',
#   'parsley',
#   'squid',
#   'garlic',
#   'spaghetti',
#   'tomato sauce',
#   'hot water'],
#  ['cocoa',
#   'vanilla',
#   'vegetable oil',
#   'flour',
#   'water',
#   'salt',
#   'sugar',
#   'baking soda',
#   'vinegar'],
#  ['applesauce', 'pork loin chops', 'clove', 'brown sugar'],
#  ['honey mustard',
#   'leaf lettuce',
#   'cream cheese',
#   'swiss cheese',
#   'whole wheat bread dough',
#   'prepared horseradish',
#   'turkey',
#   'cheddar cheese',
#   'radish sprouts',
#   'green olives',
#   'roasted red peppers',
#   'provolone cheese',
#   'ham',
#   'butter',
#   'roast beef',
#   'mayonnaise'],
#  ['salt and pepper',
#   'fresh dill',
#   'beef broth',
#   'wild mushrooms',
#   'sour cream',
#   'lemon, juice of',
#   'water',
#   'flour',
#   'onion',
#   'butter'],
#  ['asian chili sauce',
#   'green onions',
#   'light soy sauce',
#   'english cucumber',
#   'rice noodles',
#   'bean sprouts',
#   'rice wine vinegar',
#   'fresh ginger',
#   'honey',
#   'fresh cilantro',
#   'garlic',
#   'sesame oil',
#   'carrot'],
#  ['granulated sugar',
#   'kosher salt',
#   'bittersweet chocolate',
#   'brewed espresso',
#   'vanilla',
#   'unsalted butter',
#   'flour',
#   'unsweetened cocoa powder',
#   'egg'],
#  ['orange marmalade', 'dr. pepper cola', 'brown sugar'],
#  ['low sodium soy sauce',
#   'rice wine',
#   'salt',
#   'scallions',
#   'fish',
#   'sesame oil',
#   'gingerroot',
#   'white pepper',
#   'peanut oil'],
#  ['french bread',
#   'sherry wine',
#   'swiss cheese',
#   'low sodium beef broth',
#   'beef broth',
#   'flour',
#   'romano cheese',
#   'olive oil',
#   'garlic',
#   'parmesan cheese',
#   'butter',
#   'yellow onions',
#   'sugar'],
#  ['white sugar',
#   'vanilla',
#   'brown sugar',
#   'water',
#   'salt',
#   'flour',
#   'whole wheat flour',
#   'margarine',
#   'baking soda',
#   'egg',
#   'chocolate chips'],
#  ['sage',
#   'cornbread',
#   'onion',
#   'cream of chicken soup',
#   'butter',
#   'egg',
#   'squash'],
#  ['dried basil',
#   'dried parsley',
#   'garlic powder',
#   'bottled garlic',
#   'black pepper',
#   'dried oregano',
#   'white onion',
#   'bay leaves',
#   'paprika',
#   'salt',
#   'italian sausage',
#   'olive oil',
#   'tomato sauce',
#   'sugar'],
#  ['milk',
#   'garlic powder',
#   'sharp cheddar cheese',
#   'salt',
#   'french-fried onions',
#   'cream of chicken soup',
#   'frozen broccoli cuts',
#   'soy sauce',
#   'ground black pepper'],
#  ['pure vanilla extract',
#   'whole milk',
#   'flour',
#   'almond extract',
#   'butter',
#   'egg',
#   'sugar'],
#  ['egg',
#   'unsalted butter',
#   'oil',
#   'artichoke hearts',
#   'fresh garlic',
#   'unseasoned breadcrumbs'],
#  ['cider vinegar',
#   'hot red pepper sauce',
#   'chicken',
#   'chili powder',
#   'worcestershire sauce',
#   'black pepper',
#   'barbecue sauce',
#   'salt'],
#  ['cream cheese',
#   'cheddar cheese',
#   'sour cream',
#   'frozen broccoli',
#   'ritz cracker crumbs',
#   'dry onion soup mix',
#   'water chestnuts'],
#  ['milk',
#   'cocoa powder',
#   'cool whip',
#   'vanilla',
#   'instant chocolate pudding mix',
#   'flour',
#   'water',
#   'salt',
#   'baking soda',
#   'mayonnaise',
#   'sugar'],
#  ['louisiana hot sauce',
#   'unsweetened cocoa',
#   'chili powder',
#   'cornmeal',
#   'cumin',
#   'lean pork',
#   'coriander',
#   'lean chuck',
#   'flour',
#   'water',
#   'budweiser beer',
#   'paprika',
#   'bouillon',
#   'onion',
#   'garlic',
#   'oregano leaves',
#   'hunts tomato sauce',
#   'sugar'],
#  ['red bell pepper',
#   'goat cheese',
#   'kosher salt',
#   'baby spinach',
#   'meatloaf mixture',
#   'yellow onion',
#   'unsalted butter',
#   'fresh garlic',
#   'olive oil',
#   'simply potatoes shredded hash browns',
#   'egg',
#   'white pepper',
#   'unsmoked bacon'],
#  ['milk',
#   'pie crusts',
#   'ground cloves',
#   'pumpkin puree',
#   'nutmeg',
#   'egg white',
#   'salt',
#   'ground ginger',
#   'dark brown sugar',
#   'egg',
#   'heavy cream',
#   'ground cinnamon'],
#  ['milk',
#   'poppy seed',
#   'celery seed',
#   'vegetable oil',
#   'breadcrumbs',
#   'flour',
#   'sour cream',
#   'paprika',
#   'beef',
#   'salt',
#   'cream of chicken soup',
#   'poultry seasoning',
#   'onion',
#   'baking powder',
#   'butter',
#   'dry onion flakes'],
#  ['vanilla',
#   'flour',
#   'brown sugar',
#   'semi-sweet chocolate chips',
#   'nuts',
#   'hershey chocolate candy bars',
#   'baking soda',
#   'blended oatmeal',
#   'baking powder',
#   'butter',
#   'egg',
#   'sugar'],
#  ['white sugar',
#   'vanilla',
#   "hershey's semi-sweet baking chocolate",
#   'brown sugar',
#   'flour',
#   'oatmeal',
#   'salt',
#   'nuts',
#   'baking soda',
#   'baking powder',
#   'butter',
#   'egg',
#   'chocolate chips'],
#  ['milk', 'granulated sugar', 'vanilla', 'flour', 'butter'],
#  ['taco seasoning',
#   'corn cobs',
#   'cheddar cheese',
#   'lettuce',
#   'tomato',
#   'salsa',
#   'ground beef',
#   'onion',
#   'taco shells'],
#  ['chunky salsa',
#   'white onion',
#   'habanero pepper',
#   'garlic',
#   'stewing beef',
#   'sazon goya',
#   'mexican chili powder',
#   'chicken bouillon cube',
#   'tortilla chips',
#   'cumin',
#   'light brown sugar',
#   'beef bouillon cube',
#   'stewing pork',
#   'bell peppers',
#   'cinnamon',
#   'beef broth',
#   'black pepper',
#   'salt',
#   'tomato paste',
#   'ground coriander',
#   'dark chocolate chips',
#   'beans'],
#  ['triple sec',
#   'warm water',
#   'pecans',
#   'lime zest',
#   'cream cheese',
#   'tequila',
#   'powdered sugar',
#   'shortening',
#   'brown sugar',
#   'flour',
#   'salt',
#   'orange-flavored liqueur',
#   'pitted dates',
#   'lemon zest',
#   'baking soda',
#   'butter',
#   'egg'],
#  ['milk',
#   'celery',
#   'water',
#   'potato flakes',
#   'onion',
#   'cream of chicken soup',
#   'butter',
#   'carrot',
#   'potato',
#   'cream of celery soup',
#   'bouillon cubes'],
#  ['milk',
#   'cinnamon',
#   'flour',
#   'lemon, juice of',
#   'salt',
#   'cream',
#   'apples',
#   'butter',
#   'egg',
#   'sugar'],
#  ['milk',
#   'macaroni',
#   'fresh coarse ground black pepper',
#   'cheese',
#   'salt',
#   'garlic',
#   'onion',
#   'butter'],
#  ['macaroni',
#   'black pepper',
#   'cheese',
#   'unsalted butter',
#   'onion',
#   'muscat wine',
#   'fine semolina',
#   'heavy cream',
#   'potato',
#   'salt water'],
#  ['milk',
#   'salt and pepper',
#   'cheese',
#   'penne pasta',
#   'applesauce',
#   'onion',
#   'butter',
#   'potato'],
#  ['ginger', 'water', 'salt', 'pork', 'dried yellow peas'],
#  ['clove',
#   'dried thyme',
#   'black pepper',
#   'ham bone',
#   'water',
#   'salt',
#   'ground ginger',
#   'onion',
#   'dried yellow peas',
#   'carrot',
#   'brown mustard'],
#  ['water', 'fresh spinach', 'butter', 'nutmeg'],
#  ['granulated sugar',
#   'ground pork',
#   'cornstarch',
#   'garlic powder',
#   'chili powder',
#   'dried onion flakes',
#   'white vinegar',
#   'wondra flour',
#   'water',
#   'paprika',
#   'salt',
#   'ground beef',
#   'tomato paste',
#   'ground black pepper'],
#  ['tomato ketchup',
#   'oregano',
#   'maple syrup',
#   'liquid smoke',
#   'ponzu sauce',
#   'salt',
#   'granulated garlic',
#   'applesauce',
#   'cayenne',
#   'dark brown sugar',
#   'apple cider vinegar'],
#  ['vanilla',
#   'sour cream',
#   'flour',
#   'salt',
#   'baking soda',
#   'baking powder',
#   'butter',
#   'egg',
#   'sugar'],
#  ['frozen whipped topping', 'butter', 'vanilla ice cream', 'oreo cookies'],
#  ['white bread', 'processed cheese', 'butter'],
#  ['worcestershire sauce',
#   'fresh ground black pepper',
#   'rosemary',
#   'olive oil',
#   'garlic',
#   'balsamic vinegar',
#   'london broil beef',
#   'soy sauce'],
#  ['cornstarch',
#   'dry sherry',
#   'dried rosemary',
#   'dried thyme',
#   'hot pepper sauce',
#   'dried oregano',
#   'chicken broth',
#   'salt and black pepper',
#   'teriyaki sauce',
#   'nonfat dry milk powder',
#   'margarine',
#   'fresh mushrooms',
#   'spicy brown mustard',
#   'garlic',
#   'parmesan cheese',
#   'nonfat milk'],
#  ['cream cheese',
#   'cinnamon',
#   'vanilla protein powder',
#   'vanilla',
#   'sour cream',
#   'nutmeg',
#   'almonds',
#   'butter',
#   'egg',
#   'splenda sugar substitute'],
#  ['bacon', 'butter', 'real maple syrup', 'refrigerated buttermilk biscuits'],
#  ['velveeta cheese',
#   'tabasco sauce',
#   'horseradish',
#   'worcestershire sauce',
#   'mayonnaise'],
#  ['water', 'red wine vinegar', 'lemon juice'],
#  ['ground flax seeds',
#   'old fashioned oats',
#   'water',
#   'sugar-free syrup',
#   'berries',
#   "i can't believe it's not butter spread"],
#  ['milk',
#   'french bread',
#   'frozen blueberries',
#   'cream cheese',
#   'maple syrup',
#   'powdered sugar',
#   'vanilla',
#   'flour',
#   'salt',
#   'nuts',
#   'sugar',
#   'egg',
#   'blueberries'],
#  ['velveeta cheese',
#   'chicken broth',
#   'red potatoes',
#   'celery',
#   'sour cream',
#   'cheddar cheese',
#   'salt',
#   'chives',
#   'onion',
#   'bacon',
#   'white pepper',
#   'liquid smoke'],
#  ['granulated sugar',
#   'milk',
#   'warm water',
#   'cream cheese',
#   'active dry yeast',
#   'cinnamon',
#   'powdered sugar',
#   'flour',
#   'brown sugar',
#   'salt',
#   'vanilla pudding mix',
#   'butter',
#   'egg'],
#  ['white mushroom',
#   'salt and pepper',
#   'italian seasoning',
#   'spaghetti squash',
#   'reduced-fat parmesan cheese',
#   'spaghetti sauce',
#   'garlic',
#   'asparagus',
#   'red bell pepper',
#   'part-skim mozzarella cheese'],
#  ['vegan sugar',
#   'cornstarch',
#   'graham cracker crumbs',
#   'maple syrup',
#   'coriander',
#   'vanilla',
#   'oil',
#   'water',
#   'margarine',
#   'frozen pineapple concentrate',
#   'vegan cream cheese',
#   'soft silken tofu',
#   'lemon juice'],
#  ['creole seasoning',
#   'andouille sausage',
#   'green bell pepper',
#   'cooked chicken',
#   'vegetable oil',
#   'celery',
#   'flour',
#   'large raw shrimp',
#   'onion',
#   'garlic',
#   'low sodium chicken broth',
#   'frozen black-eyed peas'],
#  ['salt and pepper',
#   'pickle',
#   'cheddar cheese',
#   'thousand island dressing',
#   'ground beef',
#   'onion',
#   'egg',
#   'cracker'],
#  ['salmon',
#   'parsley',
#   'parmesan-romano cheese mix',
#   'cajun spices',
#   'salt',
#   'basil',
#   'garlic',
#   'parmesan cheese',
#   'butter',
#   'white pepper',
#   'heavy whipping cream',
#   'lemon juice',
#   'linguine'],
#  ['milk', 'cottage cheese', 'phyllo dough', 'oil', 'feta', 'egg'],
#  ['imitation crabmeat',
#   'lettuce',
#   'seasoned rice vinegar',
#   'cucumber',
#   'white rice',
#   'soy sauce',
#   'pickled ginger',
#   'avocado'],
#  ['maraschino cherry',
#   'sweetened condensed milk',
#   'flour',
#   'baking soda',
#   'mincemeat',
#   'walnuts',
#   'egg',
#   'mixed candied fruit'],
#  ['kosher salt',
#   'matzo meal',
#   'black pepper',
#   'chicken stock',
#   'celery',
#   'white onion',
#   'oil',
#   'salt',
#   'chicken breasts',
#   'baby carrots',
#   'baking powder',
#   'egg',
#   'sugar'],
#  ['poppy seed',
#   'cream of mushroom soup',
#   'frozen southern style hash brown potatoes',
#   'sour cream',
#   'cheddar cheese'],
#  ['lean ground beef',
#   'low sodium soy sauce',
#   'red onion',
#   'oregano',
#   'sea salt',
#   'italian seasoned breadcrumbs',
#   'fresh ground pepper',
#   'ground sage',
#   'adobo seasoning',
#   'ground coriander',
#   'olive oil',
#   'fresh garlic cloves',
#   'ketchup',
#   'veggie shreds cheese',
#   'egg'],
#  ['green bell pepper',
#   'celery',
#   'tuna',
#   'kraft macaroni and cheese',
#   'mushrooms',
#   'onion',
#   'butter',
#   'cream of celery soup'],
#  ['tabasco sauce',
#   'cider vinegar',
#   'black pepper',
#   'vegetable oil',
#   'miracle whip',
#   'salt',
#   'paprika',
#   'ketchup',
#   'garlic',
#   'dry mustard',
#   'sugar'],
#  ['pepperoncini peppers',
#   'red ripe tomatoes',
#   'red onion',
#   'oregano',
#   'italian parsley',
#   'water-packed artichoke hearts',
#   'kalamata olive',
#   'extra virgin olive oil',
#   'lemon, juice of',
#   'kosher salt & freshly ground black pepper',
#   'seedless cucumber',
#   'shallot',
#   'red bell pepper',
#   'red wine vinegar',
#   'tuna in vegetable oil'],
#  ['buttermilk',
#   'orange roughy',
#   'canola oil',
#   'seasoning salt',
#   'self-rising flour',
#   'egg',
#   'ground black pepper'],
#  ['goat cheese',
#   'flour',
#   'simply potatoes traditional mashed potatoes',
#   'salt',
#   'garlic',
#   'bacon',
#   'green onion',
#   'egg',
#   'frozen spinach',
#   'egg yolk'],
#  ['milk',
#   'salt and pepper',
#   'canola oil',
#   'flour',
#   'boneless pork chops',
#   'seasoning salt',
#   'cajun seasoning',
#   'self-rising flour',
#   'egg',
#   'ground black pepper'],
#  ['imitation crabmeat',
#   'ramen noodles',
#   'water',
#   'stir fry vegetables',
#   'teriyaki marinade'],
#  ['red onion',
#   'green bell pepper',
#   'apple',
#   'pumpkin puree',
#   'smooth cashew butter',
#   'ground red pepper',
#   'celery',
#   'fresh cilantro leaves',
#   'pumpkin seeds',
#   'banana',
#   'salt',
#   'pesto sauce',
#   'small red potato',
#   'vegetable broth'],
#  ['dry-roasted cashews',
#   'chili powder',
#   'water',
#   'nutmeg',
#   'garlic',
#   'mushrooms',
#   'margarine',
#   'parsley',
#   'vegetable bouillon cubes'],
#  ['mangoes', 'vanilla bean', 'ice cubes', 'oranges', 'strawberries'],
#  ['russet potatoes',
#   'salt and pepper',
#   'leeks',
#   'white beans',
#   'fresh rosemary',
#   'vegetable broth',
#   'olive oil',
#   'garlic'],
#  ['fresh coriander',
#   'turmeric',
#   'chili powder',
#   'coriander seed',
#   'chicken stock',
#   'black peppercorns',
#   'cinnamon stick',
#   'cloves',
#   'ground cumin',
#   'cardamom pods',
#   'fresh ginger',
#   'garlic',
#   'salt & freshly ground black pepper',
#   'onion',
#   'boneless skinless chicken breasts',
#   'soy yogurt'],
#  ['tabasco sauce',
#   'garlic powder',
#   'dried thyme',
#   'black pepper',
#   'dried oregano',
#   'boiling water',
#   'beef bouillon cubes',
#   'worcestershire sauce',
#   'salt',
#   'rump roast',
#   'garlic'],
#  ['milk', 'ginger', 'water', 'honey', 'tea bag'],
#  ['velveeta cheese', 'sausage', 'ground beef', 'taco chips'],
#  ['lean ground beef',
#   'ground mustard',
#   'garlic powder',
#   'worcestershire sauce',
#   'tomato sauce',
#   'bell pepper',
#   'white vinegar',
#   'brown sugar',
#   'hamburger buns',
#   'ketchup',
#   'onion',
#   'steak seasoning'],
#  ['green onions',
#   'fresh corn kernels',
#   'black pepper',
#   'white mushrooms',
#   'green peppers',
#   'carrot',
#   'salt',
#   'rice wine vinegar',
#   'salad seasoning',
#   'beets',
#   'honey',
#   'salad greens',
#   'garlic',
#   'gingerroot',
#   'soy sauce',
#   'safflower oil'],
#  ['pork chops',
#   'fennel seeds',
#   'dry white wine',
#   'chicken broth',
#   'paprika',
#   'olive oil',
#   'onion',
#   'fresh lemon juice'],
#  ['italian seasoning',
#   'garlic powder',
#   'mozzarella cheese',
#   'ramen noodles',
#   'roma tomato',
#   'pepperoni',
#   'red bell pepper',
#   'egg',
#   'black olives'],
#  ['milk',
#   'sesame seeds',
#   'brown sugar',
#   'oil',
#   'flour',
#   'salt',
#   'sunflower seeds',
#   'natural bran',
#   'raisins',
#   'baking powder',
#   'egg',
#   'baking soda',
#   'molasses'],
#  ['minced ginger',
#   'broiler',
#   'low sodium soy sauce',
#   'dry sherry',
#   'orange zest',
#   'brown sugar',
#   'onion',
#   'black tea leaves',
#   'orange, juice of',
#   'garlic',
#   'peppercorn'],
#  ['turmeric',
#   'coriander seed',
#   'yoghurt',
#   'kaffir lime leaves',
#   'star anise',
#   'lemongrass',
#   'cloves',
#   'cardamom pods',
#   'gingerroot',
#   'fruit vinegar',
#   'peanut oil'],
#  ['vanilla pudding mix',
#   'cool whip',
#   'blueberry pie filling',
#   'graham wafers'],
#  ['vinegar',
#   'cornstarch',
#   'garlic powder',
#   'cayenne pepper',
#   'chili powder',
#   'dried onion flakes',
#   'onion powder',
#   'water',
#   'canned jalapeno slices',
#   'salt',
#   'tomato paste',
#   'sugar'],
#  ['vanilla',
#   'cake flour',
#   'brown sugar',
#   'salt',
#   'nuts',
#   'baking powder',
#   'corn flakes',
#   'raisins',
#   'quick-cooking oats',
#   'butter',
#   'egg',
#   'shredded coconut',
#   'baking soda'],
#  ['italian spices',
#   'kosher salt',
#   'black pepper',
#   'whole turkey',
#   'olive oil',
#   'onion',
#   'butter'],
#  ['cheddar cheese',
#   'sour cream',
#   'salsa',
#   'onion',
#   'chili with beans',
#   'corn chips'],
#  ['parsley sprig',
#   'black pepper',
#   'vegetable oil',
#   'salt',
#   'cauliflower florets',
#   'egg',
#   'plain breadcrumbs'],
#  ['mixed herbs',
#   'kosher salt',
#   'fresh green beans',
#   'olive oil',
#   'onion',
#   'walnuts',
#   'butter',
#   'ground black pepper'],
#  ['sweet pickle relish',
#   'hamburger buns',
#   'ham',
#   'ketchup',
#   'american cheese'],
#  ['tomato soup', 'bacon', 'carrot', 'sugar'],
#  ['seasoned bread crumbs',
#   'brown sugar',
#   'lipton onion soup mix',
#   'ground beef',
#   'ketchup',
#   'egg'],
#  ['velveeta cheese',
#   'bulk pork sausage',
#   'rye cocktail bread',
#   'garlic powder',
#   'oregano',
#   'worcestershire sauce',
#   'ground pepper',
#   'ground chuck'],
#  ['milk',
#   'caster sugar',
#   'vanilla essence',
#   'self-raising flour',
#   'glace cherries',
#   'pineapple in syrup',
#   'brown sugar',
#   'butter',
#   'egg'],
#  ['flax seed oil',
#   'apple',
#   'oat bran',
#   'banana',
#   'honey',
#   'water',
#   'coconut milk',
#   'greens'],
#  ['hawaiian bread',
#   'sour cream',
#   'knorr vegetable soup mix',
#   'green onion',
#   'water chestnuts',
#   "hellmann's mayonnaise"],
#  ['peas',
#   'broccoli floret',
#   'sliced mushrooms',
#   'brown rice',
#   'carrot',
#   'olive oil',
#   'egg',
#   'soy sauce'],
#  ['reduced fat graham cracker crust',
#   'pumpkin',
#   'egg whites',
#   'pumpkin pie spice',
#   'skim milk',
#   'splenda sugar substitute'],
#  ['beef stew', 'biscuits'],
#  ['light corn syrup',
#   'honey roasted peanuts',
#   'espresso',
#   'unsweetened cocoa',
#   'buttermilk',
#   'unbleached all-purpose flour',
#   'pure vanilla extract',
#   'creamy peanut butter',
#   'powdered sugar',
#   'unsalted butter',
#   'salt',
#   'semisweet chocolate',
#   'baking soda',
#   'extra-large eggs',
#   'heavy cream',
#   'sugar'],
#  ['red bell pepper',
#   'lime zest',
#   'yellow cornmeal',
#   'short-grain brown rice',
#   'corn kernel',
#   'ground cumin',
#   'fresh lime juice',
#   'onion',
#   'garlic',
#   'cilantro',
#   'olive oil',
#   'chipotle chile in adobo'],
#  ['instant vanilla pudding',
#   'whipped dessert topping mix',
#   'flour',
#   'water',
#   'butter',
#   'egg'],
#  ['milk',
#   'white onions',
#   'celery',
#   'miracle whip',
#   'dijon mustard',
#   'hard-boiled eggs',
#   'fresh ground pepper',
#   'salt',
#   'mustard',
#   'potato',
#   'white pepper',
#   'sugar'],
#  ['dried basil',
#   'tea bag',
#   'garlic powder',
#   'cayenne pepper',
#   'chili powder',
#   'black pepper',
#   'water',
#   'seasoning salt',
#   'butter',
#   'soy sauce',
#   'white rice',
#   'lemon juice'],
#  ['milk',
#   'bisquick',
#   'kalamata olive',
#   'feta cheese',
#   'oregano',
#   'roasted red pepper',
#   'fresh ground pepper',
#   'onion',
#   'egg',
#   'frozen spinach'],
#  ['pecans',
#   'pumpkin',
#   'cinnamon',
#   'ground cloves',
#   'flour',
#   'water',
#   'salt',
#   'nutmeg',
#   'oil',
#   'baking soda',
#   'baking powder',
#   'egg',
#   'allspice',
#   'sugar'],
#  ['black pepper',
#   'vegetable oil',
#   'water',
#   'boneless pork chops',
#   'long-grain rice',
#   'dry onion soup mix'],
#  ['nutmeg',
#   'boneless skinless chicken breasts',
#   'clove',
#   'crushed tomatoes',
#   'habanero pepper',
#   'jamaican jerk spice',
#   'red peppers',
#   'onion flakes',
#   'garlic',
#   'allspice',
#   'rum',
#   'brown sugar',
#   'lime juice',
#   'thyme',
#   'chili powder',
#   'cinnamon',
#   'black pepper',
#   'sage',
#   'ginger',
#   'chives',
#   'cayenne',
#   'olive oil',
#   'onion'],
#  ['ice', 'mango', 'frozen limeade concentrate', 'strawberry', 'lime sorbet'],
#  ['ice',
#   'strawberry',
#   'apple juice',
#   'banana',
#   'non-fat vanilla frozen yogurt'],
#  ['red chile',
#   'fish sauce',
#   'hoisin sauce',
#   'coriander seed',
#   'yoghurt',
#   'garlic',
#   'sesame oil',
#   'cumin',
#   'fruit vinegar'],
#  ['unsweetened chocolate',
#   'peppermint oreos',
#   'vanilla',
#   'flour',
#   'unsweetened cocoa powder',
#   'salt',
#   'candy cane',
#   'peppermint extract',
#   'butter',
#   'egg',
#   'sugar'],
#  ['orange juice',
#   'pineapple tidbits',
#   'mandarin oranges',
#   'canola oil',
#   'white vinegar',
#   'celery',
#   'cooked chicken breasts',
#   'salt',
#   'slivered almonds',
#   'cooked rice',
#   'mayonnaise',
#   'green grapes'],
#  ['frozen peas',
#   'celery',
#   'sweet pickle relish',
#   'cheddar cheese',
#   'hard-boiled eggs',
#   'seasoning salt',
#   'onion',
#   'mustard',
#   'mayonnaise',
#   'sugar'],
#  ['dry breadcrumbs',
#   'garlic powder',
#   'buttermilk',
#   'cayenne pepper',
#   'black pepper',
#   'hot pepper sauce',
#   'dried thyme',
#   'flour',
#   'oil',
#   'dijon mustard',
#   'seasoning salt',
#   'paprika',
#   'fresh garlic',
#   'chicken pieces',
#   'onion',
#   'parmesan cheese',
#   'butter'],
#  ['louisiana hot sauce',
#   'hoisin sauce',
#   'cinnamon',
#   'black pepper',
#   'pork baby back ribs',
#   'habanero sauce',
#   'seasoning salt',
#   'fresh garlic',
#   'ketchup',
#   'allspice',
#   'lemon juice',
#   'sugar'],
#  ['peas',
#   'italian seasoning',
#   'rotini pasta',
#   'black pepper',
#   'chicken leg',
#   'celery',
#   'spaghetti sauce',
#   'salt',
#   'corn',
#   'onion',
#   'red bell pepper',
#   'garlic',
#   'carrot',
#   'beef stock'],
#  ['salt and pepper',
#   'stove top stuffing mix monterey style with mushroom and onion',
#   'aluminum foil',
#   'spinach dip',
#   'pam cooking spray',
#   'sour cream',
#   'margarine',
#   'mexicorn whole kernel corn'],
#  ['pickling spices', 'white vinegar', 'cooking onions'],
#  ['peas',
#   'cooked chicken',
#   'chicken broth',
#   'cooked pasta',
#   'carrot',
#   'egg',
#   'soy sauce'],
#  ['mixed fruit', 'cool whip', 'cream cheese', 'cake crumbs'],
#  ['cool whip',
#   'lemon flavoring',
#   'pie crust',
#   'flour',
#   'coconut flavoring',
#   'sugar',
#   'butter',
#   'egg',
#   'squash'],
#  ['garlic powder',
#   'cream of mushroom soup',
#   'ground cloves',
#   'black pepper',
#   'dried onion flakes',
#   'dried parsley flakes',
#   'ground veal',
#   'dijon mustard',
#   'salt',
#   'ground cinnamon'],
#  ['chicken stock',
#   'gumbo file',
#   'tomato soup',
#   'tabasco sauce',
#   'oregano',
#   'old bay seasoning',
#   'lemon',
#   'garlic',
#   'okra',
#   'small shrimp',
#   'red onions',
#   'parsley',
#   'red wine vinegar',
#   'seafood',
#   'black pepper',
#   'olive oil',
#   'brown rice',
#   'catfish nuggets',
#   'mexican-style stewed tomatoes with jalapeno peppers'],
#  ['mild cheddar cheese',
#   'white vinegar',
#   'sour cream',
#   'paprika',
#   'fresh chives',
#   'bacon',
#   'egg'],
#  ['dried basil',
#   'cracked black pepper',
#   'dried parsley',
#   'sandwich buns',
#   'dried oregano',
#   'white vinegar',
#   'salt',
#   'chicken breasts',
#   'olive oil',
#   'garlic',
#   'garlic salt',
#   'lemon juice'],
#  ['cinnamon',
#   'quick oats',
#   'vanilla',
#   'boiling water',
#   'flour',
#   'brown sugar',
#   'salt',
#   'nutmeg',
#   'nuts',
#   'margarine',
#   'cream',
#   'baking soda',
#   'egg',
#   'shredded coconut'],
#  ['butter', 'rice krispies', 'marshmallows'],
#  ['orange juice',
#   'frozen limeade concentrate',
#   'cream cheese',
#   'cool whip topping'],
#  ['pitted ripe olives',
#   'tabasco sauce',
#   'avocado',
#   'salad oil',
#   'chili powder',
#   'cheddar cheese',
#   'lettuce',
#   'sour cream',
#   'tuna',
#   'tomato',
#   'salt',
#   'garlic',
#   'green onion',
#   'corn chips',
#   'lemon juice',
#   'sugar'],
#  ['low-fat yogurt',
#   'fresh coriander',
#   'coriander',
#   'tahini',
#   'ground cumin',
#   'salt & freshly ground black pepper',
#   'olive oil',
#   'garlic',
#   'chickpeas',
#   'baking potatoes'],
#  ['buttermilk',
#   'yellow cornmeal',
#   'vegetable oil',
#   'salt',
#   'baking powder',
#   'egg',
#   'mayonnaise',
#   'sugar'],
#  ['maple syrup',
#   'apple',
#   'gingerroot',
#   'rice vinegar',
#   'sesame oil',
#   'green onion',
#   'carrot',
#   'soy sauce',
#   'red cabbage',
#   'green cabbage'],
#  ['garlic powder',
#   'turmeric',
#   'black pepper',
#   'canola oil',
#   'water',
#   'orzo pasta',
#   'chicken soup powder',
#   'long-grain rice'],
#  ['crushed tomatoes',
#   'salt and pepper',
#   'chicken breast',
#   'jalapeno pepper',
#   'chipotle chiles in adobo',
#   'green bell pepper',
#   'chicken broth',
#   'white onion',
#   'fresh cilantro',
#   'ear of corn',
#   'celery ribs',
#   'cumin',
#   'avocado'],
#  ['dried basil',
#   'fiber one cereal',
#   'garlic powder',
#   'black pepper',
#   'reduced-fat parmesan cheese',
#   'fat free mozzarella cheese',
#   'italian-style tomato sauce',
#   'eggplant',
#   'salt',
#   'egg white'],
#  ['beef gravy', 'ground beef', 'onion', 'white rice', 'egg'],
#  ['black-eyed peas',
#   'ham soup base',
#   'tomatoes and green chilies',
#   'black pepper',
#   'ham bone',
#   'water',
#   'salt',
#   'celery ribs',
#   'great northern beans',
#   'pinto beans',
#   'ham',
#   'navy beans',
#   'garlic',
#   'beans',
#   'onion',
#   'carrot'],
#  ['light mayonnaise',
#   'cider vinegar',
#   'fresh dill',
#   'feta cheese',
#   'red bell pepper',
#   'garlic',
#   'skinless chicken breast half'],
#  ['lean ground beef',
#   'italian seasoning',
#   'mozzarella cheese',
#   'spaghetti sauce',
#   'cheese ravioli',
#   'garlic salt'],
#  ['orange marmalade',
#   'barbecue sauce',
#   'worcestershire sauce',
#   'chicken pieces',
#   'lemon juice'],
#  ['garlic powder',
#   'turmeric',
#   'ground red pepper',
#   'coriander',
#   'onion powder',
#   'salt',
#   'paprika',
#   'ground black pepper'],
#  ['cream cheese',
#   'taco seasoning mix',
#   'mexican blend cheese',
#   'sour cream',
#   'lettuce',
#   'tomato',
#   'green pepper',
#   'green onion',
#   'black olives',
#   'mayonnaise'],
#  ['tabasco sauce',
#   'minced clams',
#   'green onions',
#   'worcestershire sauce',
#   'sharp cheddar cheese',
#   'paprika',
#   'green bell peppers'],
#  ['shrimp',
#   'red bell pepper',
#   'red onion',
#   'oregano',
#   'spaghetti squash',
#   'olives',
#   'yellow bell pepper',
#   'olive oil',
#   'eggplants'],
#  ['butter', 'heavy cream', "confectioners' sugar", 'semisweet chocolate'],
#  ['pecans',
#   'small marshmallow',
#   'frozen whipped topping',
#   'sweetened condensed milk',
#   'crushed pineapple',
#   'cherry pie filling'],
#  ['green onions',
#   'sour cream',
#   'oil',
#   'salt',
#   'cheddar cheese',
#   'bacon',
#   'potato'],
#  ['mozzarella cheese',
#   'black pepper',
#   'plain flour',
#   'canola oil',
#   'boneless eye of round beef steak',
#   'salt',
#   'pizza sauce',
#   'onion',
#   'parmesan cheese'],
#  ['boneless country-style ribs',
#   'oregano',
#   'flour',
#   'soup mix',
#   'seasoning salt',
#   "campbell's golden mushroom soup",
#   'bacon grease',
#   'ground black pepper'],
#  ['milk', 'flour', 'fruit', 'butter', 'egg', 'sugar'],
#  ['cardamom',
#   'honey',
#   'baby carrots',
#   'apples',
#   'butter',
#   'crescent roll dough',
#   'ground cinnamon',
#   'sugar'],
#  ['italian seasoning',
#   'mozzarella cheese',
#   'refrigerated biscuits',
#   'olive oil',
#   'garlic salt'],
#  ['milk', 'active dry yeast', 'flour', 'water', 'salt', 'butter', 'sugar'],
#  ['cream cheese',
#   'vanilla',
#   'lemon peel',
#   'flour',
#   'salt',
#   'whipping cream',
#   'egg yolks',
#   'egg yolk',
#   'butter',
#   'egg',
#   'sugar'],
#  ['honey',
#   'country-style dijon mustard',
#   'chili sauce',
#   'little smokies sausages'],
#  ['pineapple juice',
#   'grenadine',
#   'orange juice',
#   'orange curacao',
#   'orgeat syrup',
#   "meyer's dark rum",
#   'prepared sweet-and-sour mix',
#   'white rum',
#   'bacardi dark rum'],
#  ['minute white rice',
#   'red apples',
#   'pork chops',
#   'condensed chicken broth',
#   'sliced mushrooms',
#   'water',
#   'dried thyme leaves',
#   'onion',
#   'balsamic vinaigrette'],
#  ['orange juice',
#   'chili powder',
#   'horseradish',
#   'red bell peppers',
#   'prepared mustard',
#   'fresh ground black pepper',
#   'plain nonfat yogurt',
#   'tomato paste',
#   'green bell peppers',
#   'onion',
#   'reduced-calorie mayonnaise'],
#  ['orange juice',
#   'cool whip',
#   'strawberry gelatin',
#   'lemon gelatin',
#   'peach gelatin',
#   'grapes',
#   'cold water',
#   'strawberries',
#   'nectarines'],
#  ['garlic powder',
#   'cayenne pepper',
#   'dried sage',
#   'black pepper',
#   'fat-free evaporated milk',
#   'lean ground turkey',
#   'brown sugar',
#   'flour',
#   'salt',
#   'poultry seasoning',
#   'onion flakes',
#   'skim milk',
#   'ground marjoram'],
#  ['garlic powder',
#   'barbecue sauce',
#   'sweet onion',
#   'seasoning salt',
#   'cooking spray',
#   'french-fried onions',
#   'ground beef',
#   'red bell pepper',
#   'egg',
#   'ground black pepper'],
#  ['crushed tomatoes',
#   'bay leaf',
#   'beef stew meat',
#   'beef broth',
#   'black pepper',
#   'tomato sauce',
#   'flour',
#   'water',
#   'salt',
#   'garlic',
#   'italian salad dressing',
#   'green pepper',
#   'beef bouillon granules',
#   'cold water',
#   'onion',
#   'carrot',
#   'potato'],
#  ['tabasco sauce',
#   'salt and pepper',
#   'ghee',
#   'garam masala',
#   'kidney beans',
#   'water',
#   'onion',
#   'garlic',
#   'curry powder',
#   'carrot',
#   'potato'],
#  ['orange juice', 'orange slice', 'ice cube', 'ouzo'],
#  ['milk',
#   'sherry wine',
#   'cream of mushroom soup',
#   'black pepper',
#   'half-and-half',
#   'crabmeat',
#   'salt',
#   'old bay seasoning',
#   'red pepper',
#   'cream of celery soup'],
#  ['salt and pepper',
#   'dry sherry',
#   'egg whites',
#   'sherry wine vinegar',
#   'worcestershire sauce',
#   'chicken broth',
#   'yellow mustard',
#   'ground pork',
#   'unsalted butter',
#   'brown sugar',
#   'fresh parsley',
#   'mixed mushrooms',
#   'skim milk',
#   'bacon',
#   'panko breadcrumbs',
#   'ground sirloin',
#   'ground turkey',
#   'flour',
#   'shallot',
#   'ketchup',
#   'tomato paste',
#   'onion'],
#  ['new potatoes',
#   'lemon, zest of',
#   'lemon, juice of',
#   'rosemary',
#   'olive oil',
#   'garlic'],
#  ['dry breadcrumbs',
#   'green chili sauce',
#   'chili powder',
#   'flour',
#   'oil',
#   'garlic',
#   'salsa',
#   'onion',
#   'frozen corn',
#   'black beans',
#   'cumin'],
#  ['green onions',
#   'caesar salad dressing',
#   'sour cream',
#   'ripe olives',
#   'fresh spinach',
#   'cheese-filled tortellini',
#   'salt',
#   'fresh ground pepper',
#   'red bell pepper',
#   'baby shrimp',
#   'mayonnaise'],
#  ['salt and pepper',
#   'bell peppers',
#   'spike seasoning',
#   'worcestershire sauce',
#   'cheese',
#   'celery',
#   'ground turkey',
#   'onion',
#   'tomato',
#   'fresh parsley',
#   'olive oil',
#   'garlic'],
#  ['cream cheese',
#   'cornstarch',
#   'graham cracker crumbs',
#   'cinnamon',
#   'vanilla',
#   'splenda granular',
#   'sour cream',
#   'nutmeg',
#   'slivered almonds',
#   'butter',
#   'egg',
#   'heavy whipping cream',
#   'lemon juice'],
#  ['smooth peanut butter', 'oil', 'ketchup', 'chicken pieces', 'soy sauce'],
#  ['celery seed',
#   'dried sage',
#   'dried thyme',
#   'black pepper',
#   'chicken broth',
#   'breadcrumbs',
#   'onion',
#   'salt',
#   'parsley',
#   'butter'],
#  ['salt and pepper',
#   'olive oil',
#   'fresh basil',
#   'tomato',
#   'fresh oregano',
#   'garlic'],
#  ['cornstarch',
#   "devil's food cake mix",
#   'kahlua',
#   'bittersweet chocolate',
#   'vegetable oil',
#   'instant chocolate pudding mix',
#   'water',
#   'whipping cream',
#   'salt',
#   'coco lopez',
#   'coconut milk',
#   'egg',
#   'shredded coconut',
#   'sugar'],
#  ['plain tomato juice', 'old bay seasoning'],
#  ['bay leaf',
#   'canned pumpkin',
#   'ground nutmeg',
#   'cinnamon',
#   'chicken stock',
#   'canned unsweetened coconut milk',
#   'sweetened condensed milk',
#   'coriander',
#   'pumpkin seeds',
#   'banana',
#   'onion',
#   'shallot',
#   'garlic',
#   'curry powder',
#   'butter',
#   'carrot',
#   'ground allspice'],
#  ['ghee',
#   'black pepper',
#   'zucchini',
#   'salt',
#   'tomato',
#   'garlic',
#   'parmesan cheese',
#   'whole wheat bread',
#   'mayonnaise'],
#  ['cream cheese',
#   'diced green chilies',
#   'diced tomatoes with green chilies',
#   'sausage'],
#  ['red pepper',
#   'extra lean ground beef',
#   'beef broth',
#   'chili beans with chipotle pepper',
#   'white onion',
#   'kidney beans',
#   'chilies',
#   'garlic',
#   'diced tomatoes',
#   'tomato sauce',
#   'chili seasoning mix',
#   'black beans'],
#  ['pecans',
#   'cream cheese',
#   'ground nutmeg',
#   'powdered sugar',
#   'vanilla',
#   'flour',
#   'carrot',
#   'salt',
#   'pineapple chunk',
#   'baking soda',
#   'baking powder',
#   'butter',
#   'egg',
#   'ground cinnamon',
#   'sugar'],
#  ['milk', 'black pepper', 'flour', 'dried beef', 'butter'],
#  ['black pepper',
#   'water',
#   'salt',
#   'carrot',
#   'onion',
#   'turnips',
#   'potato',
#   'split peas'],
#  ['cooked bacon',
#   'romaine lettuce',
#   'buttermilk',
#   'red onion',
#   'lemon juice',
#   'roasted garlic and red pepper spice mix',
#   'sour cream',
#   'granulated garlic',
#   'hard-boiled eggs',
#   'sugar',
#   'cherry tomatoes',
#   'ketchup',
#   'steak spice',
#   'curry powder',
#   'cumin',
#   'salad dressing',
#   'corn tortilla strips'],
#  ['lean ground beef',
#   'cayenne pepper',
#   'worcestershire sauce',
#   'ground cumin',
#   'cheddar cheese',
#   'salt',
#   'tomato',
#   'hamburger buns',
#   'onion',
#   'bibb lettuce',
#   'fresh thyme',
#   'white pepper',
#   'papaya',
#   'mayonnaise'],
#  ['cinnamon',
#   'vanilla',
#   'zucchini',
#   'flour',
#   'salt',
#   'fat',
#   'baking soda',
#   'walnuts',
#   'egg',
#   'sugar'],
#  ['peach schnapps',
#   'peach puree',
#   'dry white wine',
#   'apple',
#   'lemonade',
#   'peach',
#   'lemon-flavored vodka',
#   'lime',
#   'lime juice',
#   'lemon',
#   'lemon juice'],
#  ['ground moose',
#   'salt and pepper',
#   'barbecue sauce',
#   'brown sugar',
#   'prepared mustard',
#   'hot sauce',
#   'ketchup',
#   'onion'],
#  ['lean ground beef',
#   'dry breadcrumbs',
#   'cornstarch',
#   'black pepper',
#   'white vinegar',
#   'brown sugar',
#   'onion',
#   'salt',
#   'pineapple chunks',
#   'ketchup',
#   'garlic',
#   'sweet pepper',
#   'egg',
#   'soy sauce'],
#  ['dark brown sugar', 'soy sauce', 'chicken wings'],
# ...
#  ['wheat germ',
#   'oat bran',
#   'egg',
#   'vegetable oil',
#   'vital wheat gluten',
#   'water',
#   'whole wheat flour',
#   'salt',
#   'white whole wheat flour',
#   'yeast',
#   'sugar'],
#  ['warm water',
#   'kosher salt',
#   'vital wheat gluten',
#   'whole wheat flour',
#   'yeast'],
#  ['water', 'salt', 'honey', 'applesauce', 'whole wheat flour', 'yeast', 'egg'],
#  ['instant yeast',
#   'canola oil',
#   'vital wheat gluten',
#   'water',
#   'whole wheat flour',
#   'honey',
#   'salt',
#   'egg'],
#  ['granulated sugar',
#   'egg whites',
#   'low-fat buttermilk',
#   'canola oil',
#   'whole wheat flour',
#   'salt',
#   'baking powder',
#   'baking soda',
#   'flax seed meal'],
#  ['cinnamon',
#   'vanilla',
#   'whole wheat flour',
#   'salt',
#   'turbinado sugar',
#   'honey',
#   'water',
#   'baking soda',
#   'baking powder',
#   'butter'],
#  ['low-fat buttermilk',
#   'raisins',
#   'whole wheat flour',
#   'salt',
#   'baking soda',
#   'baking powder',
#   'butter',
#   'egg',
#   'molasses'],
#  ['vanilla',
#   'canola oil',
#   'whole wheat flour',
#   'fruit',
#   'low-fat milk',
#   'baking soda',
#   'baking powder',
#   'egg',
#   'sugar'],
#  ['milk',
#   'brown sugar',
#   'whole wheat flour',
#   'salt',
#   'peanut butter',
#   'baking powder',
#   'butter',
#   'egg'],
#  ['instant yeast', 'whole wheat flour', 'honey', 'salt', 'water', 'olive oil'],
#  ['water', 'honey', 'salt', 'whole wheat flour', 'yeast', 'olive oil', 'egg'],
#  ['milk',
#   'kosher salt',
#   'gluten',
#   'sour cream',
#   'whole wheat flour',
#   'baking soda',
#   'baking powder',
#   'butter'],
#  ['cocoa powder',
#   'cinnamon',
#   'vanilla',
#   'powdered milk',
#   'whole wheat flour',
#   'oatmeal',
#   'salt',
#   'oil',
#   'fruit',
#   'water',
#   'powdered eggs',
#   'raisins',
#   'sugar',
#   'baking powder',
#   'egg',
#   'molasses'],
#  ['cinnamon',
#   'vanilla',
#   'vegetable oil',
#   'zucchini',
#   'whole wheat flour',
#   'salt',
#   'nuts',
#   'baking soda',
#   'baking powder',
#   'egg',
#   'sugar'],
#  ['instant yeast',
#   'whole wheat flour',
#   'water',
#   'cooking oil',
#   'honey',
#   'table salt'],
#  ['vanilla',
#   'flour',
#   'bananas',
#   'nuts',
#   'baking soda',
#   'butter',
#   'egg',
#   'sugar'],
#  ['evaporated milk',
#   'caramels',
#   'nuts',
#   'butter',
#   'chocolate cake mix',
#   'chocolate chips'],
#  ['canola oil',
#   'flour',
#   'salt',
#   'bananas',
#   'raisins',
#   'walnuts',
#   'egg',
#   'baking soda',
#   'sugar'],
#  ['thousand island dressing', 'cream cheese'],
#  ['mayonnaise', 'chili sauce', 'sweet pickle relish', 'onion powder'],
#  ['rolled oats',
#   'flaked coconut',
#   'rice krispies',
#   'white sugar',
#   'vanilla',
#   'brown sugar',
#   'oil',
#   'flour',
#   'margarine',
#   'baking soda',
#   'cream of tartar',
#   'egg',
#   'chocolate chips'],
#  ['buttermilk',
#   'fresh lemon juice',
#   'baby spinach',
#   'mushrooms',
#   'hardboiled egg',
#   'garlic',
#   'bacon',
#   'unsalted sunflower seeds',
#   'plain yogurt',
#   'white pepper',
#   'sugar'],
#  ['cauliflower',
#   'red onion',
#   'italian seasoning',
#   'frozen peas',
#   'lettuce',
#   'green pepper',
#   'fresh mushrooms',
#   'cherry tomatoes',
#   'bacon',
#   'fresh broccoli',
#   'mayonnaise',
#   'sugar'],
#  ['rubbed sage',
#   'garlic powder',
#   'chili powder',
#   'ground oregano',
#   'black pepper',
#   'onion salt',
#   'paprika',
#   'basil leaves',
#   'celery salt',
#   'ground allspice',
#   'marjoram leaves'],
#  ['vodka', 'ice', 'beer', 'fresh jalapeno'],
#  ['low-fat mayonnaise',
#   'french bread',
#   'bacon',
#   'worcestershire sauce',
#   'baby spinach',
#   'extra virgin olive oil',
#   'dijon mustard',
#   'oil',
#   'fresh mushrooms',
#   'olive oil',
#   'garlic',
#   'parmesan cheese',
#   'miracle whip light',
#   'lemon juice',
#   'anchovy fillets'],
#  ['dried italian seasoning',
#   'mozzarella cheese',
#   'parmesan-romano cheese mix',
#   'italian cheese blend',
#   'jumbo pasta shells',
#   'mexican blend cheese',
#   'parsley flakes',
#   'salt',
#   'ground pepper',
#   'spaghetti sauce',
#   'ricotta cheese',
#   'ground beef',
#   'egg'],
#  ['white flour',
#   'brown sugar',
#   'water',
#   'salt',
#   'oil',
#   'whole wheat flour',
#   'bread machine yeast'],
#  ['salt and pepper',
#   'evaporated milk',
#   'whole corn',
#   'water',
#   'onion',
#   'butter',
#   'potato',
#   'cream-style corn'],
#  ['kosher salt',
#   'black pepper',
#   'extra virgin olive oil',
#   'italian seasoned breadcrumbs',
#   'flat leaf parsley',
#   'orecchiette',
#   'parmesan cheese',
#   'prosciutto'],
#  ['salt', 'fresh ground black pepper', 'tomato', 'olive oil', 'cumin seeds'],
#  ['salted peanuts',
#   'corn syrup',
#   'white sugar',
#   'vanilla',
#   'baking soda',
#   'butter',
#   'molasses'],
#  ['lean ground beef',
#   'cinnamon',
#   'salt',
#   'onion',
#   'plain yogurt',
#   'bulgar wheat'],
#  ['instant vanilla pudding',
#   'yellow cake mix',
#   'apple pie filling',
#   'oil',
#   'water',
#   'egg'],
#  ['carrot', 'potato', 'italian dressing', 'boneless skinless chicken breasts'],
#  ['egg', 'chocolate milk', 'cinnamon rolls'],
#  ['milk',
#   'white sugar',
#   'vanilla',
#   'flour',
#   'salt',
#   'baking powder',
#   'butter',
#   'egg'],
#  ['leeks',
#   'thyme',
#   'black pepper',
#   'worcestershire sauce',
#   'celery',
#   'soup mix',
#   'water',
#   'basil',
#   'salt',
#   'ham',
#   'garlic',
#   'carrot'],
#  ['milk',
#   'salt and pepper',
#   'garlic powder',
#   'bell peppers',
#   'worcestershire sauce',
#   'saltine crackers',
#   'chili sauce',
#   'ground beef',
#   'onion',
#   'egg'],
#  ['salt and pepper',
#   'aluminum foil',
#   'worcestershire sauce',
#   'limes, juice of',
#   'unsalted butter',
#   'prepared horseradish',
#   'sour cream',
#   'beef tenderloin',
#   'garlic'],
#  ['cream cheese',
#   'cinnamon',
#   'powdered sugar',
#   'pineapple',
#   'flour',
#   'oil',
#   'salt',
#   'baking powder',
#   'carrot',
#   'margarine',
#   'baking soda',
#   'walnuts',
#   'egg',
#   'sugar'],
#  ['turmeric',
#   'mustard seeds',
#   'white vinegar',
#   'water',
#   'salt',
#   'cabbage',
#   'onion',
#   'celery seed',
#   'carrot',
#   'sugar'],
#  ['pickling cucumbers',
#   'vinegar',
#   'water',
#   'salt',
#   'alum',
#   'pickling spices',
#   'sugar'],
#  ['vinegar', 'cucumbers', 'canning salt', 'alum', 'pickling spices', 'sugar'],
#  ['cream cheese',
#   'cinnamon',
#   'ground cloves',
#   'powdered sugar',
#   'vanilla',
#   'egg',
#   'flour',
#   'oil',
#   'salt',
#   'nuts',
#   'margarine',
#   'raisins',
#   'coconut',
#   'carrot',
#   'allspice',
#   'baking soda',
#   'sugar'],
#  ['maple syrup', 'cream', 'butter', 'lemon extract', 'nutmeats'],
#  ['v8 vegetable juice',
#   'beans',
#   'deli ham',
#   'raw rice',
#   'chicken broth',
#   'celery',
#   'water',
#   'salt',
#   'basil',
#   'tomato',
#   'onion',
#   'chicken bouillon cubes',
#   'parsley',
#   'carrot',
#   'lemon juice'],
#  ['tortillas',
#   'refried beans',
#   'hormel chili without beans',
#   'monterey jack cheese'],
#  ['15 bean soup mix',
#   'dried parsley',
#   'whole tomatoes',
#   'dried rosemary',
#   'ham hocks',
#   'black pepper',
#   'onion',
#   'salt',
#   'celery leaves',
#   'olive oil',
#   'garlic',
#   'chicken bouillon cubes'],
#  ['15 bean soup mix',
#   'black pepper',
#   'ham bone',
#   'beef bouillon paste',
#   'worcestershire sauce',
#   'smoked sausage',
#   'water',
#   'steak sauce',
#   'diced tomatoes',
#   'garlic'],
#  ['thyme',
#   'cayenne pepper',
#   'dried beans',
#   'chili powder',
#   'black pepper',
#   'oregano',
#   'olive oil',
#   'water',
#   'paprika',
#   'salt',
#   'onion',
#   'ham',
#   'lemon',
#   'garlic',
#   'carrot',
#   'condensed tomato soup',
#   'smoked paprika'],
#  ['ground walnuts',
#   'flour',
#   'sour cream',
#   'honey',
#   'margarine',
#   'liquid honey',
#   'egg',
#   'plain sweet biscuit crumbs',
#   'baking soda',
#   'sugar'],
#  ['salt and pepper',
#   'chicken stock',
#   'halibut steaks',
#   'fresh tarragon',
#   'fresh chives',
#   'fresh parsley',
#   'garlic',
#   'capers',
#   'lemon juice'],
#  ['lipton beefy mushroom soup mix',
#   'new potatoes',
#   'boneless sirloin steak',
#   'peas and carrots',
#   'oil',
#   'water',
#   'tomato paste'],
#  ['tomatoes and green chilies',
#   'taco seasoning',
#   'ground beef',
#   'black beans',
#   'frozen corn kernels'],
#  ['lean ground beef',
#   'minute white rice',
#   'cheddar cheese',
#   'water',
#   'ketchup',
#   'mustard'],
#  ['velveeta cheese',
#   'water',
#   'ground beef',
#   'diced tomatoes',
#   'chili with beans',
#   'white rice'],
#  ['instant rice',
#   'vegetable oil',
#   'ground pepper',
#   'boneless skinless chicken breast halves',
#   'water',
#   'paprika',
#   'condensed cream of chicken soup'],
#  ['chicken breast tenders',
#   'black pepper',
#   'cheese',
#   'sour cream',
#   'lime',
#   'fajita seasoning mix',
#   'tortilla',
#   'olive oil',
#   'onion',
#   'pico de gallo'],
#  ['chicken',
#   'mexicorn',
#   'chicken broth',
#   'cheddar cheese',
#   'kidney beans',
#   'sour cream',
#   'salsa',
#   'tortilla chips'],
#  ['milk',
#   'minute rice',
#   'vegetable oil',
#   'broccoli florets',
#   'condensed cream of chicken soup',
#   'boneless skinless chicken breasts'],
#  ['chili powder',
#   'ground turkey',
#   'kidney beans',
#   'stewed tomatoes',
#   'salt',
#   'pinto beans',
#   'salsa',
#   'onion',
#   'cumin'],
#  ['white minute rice',
#   'cheese',
#   'sour cream',
#   'water',
#   'flour tortillas',
#   'chili with beans'],
#  ['lean ground beef',
#   'macaroni & cheese dinner mix',
#   'chili powder',
#   'water',
#   'broccoli',
#   'ketchup'],
#  ['cinnamon',
#   'black pepper',
#   'brown sugar',
#   'salt',
#   'tomato',
#   'onion',
#   'allspice',
#   'clove'],
#  ['sun-dried tomato packed in oil',
#   'roasted cashews',
#   'black pepper',
#   'fresh basil',
#   'crushed red pepper flakes',
#   'grape tomatoes',
#   'fresh oregano',
#   'garlic',
#   'pappardelle pasta',
#   'fresh parmesan cheese'],
#  ['tomato sauce',
#   'ground cumin',
#   'onion',
#   'salt',
#   'garlic',
#   'ground coriander',
#   'chipotle chile in adobo',
#   'low sodium chicken broth'],
#  ['fat free cream cheese',
#   'reduced fat graham cracker crust',
#   'sugar substitute',
#   'fat-free whipped topping'],
#  ['red onion',
#   'pine nuts',
#   'fresh linguine',
#   'pesto sauce',
#   'fresh spinach',
#   'tomato',
#   'parmesan cheese',
#   'lemon juice'],
#  ['salt and pepper',
#   'chicken broth',
#   'boneless skinless chicken breast halves',
#   'oil',
#   'flour',
#   'garlic',
#   'butter',
#   'lemon juice'],
#  ['cracked black pepper',
#   'romaine lettuce',
#   'garbanzo beans',
#   'feta cheese',
#   'extra virgin olive oil',
#   'scallion',
#   'salt',
#   'celery ribs',
#   'tomato',
#   'fresh parsley',
#   'garlic',
#   'of fresh mint',
#   'fresh lemon juice'],
#  ['instant rice',
#   'italian dressing',
#   'assorted fresh vegetables',
#   'oil',
#   'reduced-sodium fat-free chicken broth',
#   'boneless skinless chicken breast'],
#  ['milk',
#   'graham cracker crumbs',
#   'cream cheese',
#   'powdered sugar',
#   'butter',
#   'instant lemon pudding'],
#  ["confectioners' sugar", 'cocoa', 'vanilla', 'butter', 'peanut butter'],
#  ['smoked turkey breast',
#   'italian salad dressing',
#   'tomato',
#   'spaghetti',
#   'parmesan cheese'],
#  ['minute rice',
#   'pork tenderloin',
#   'chicken bouillon cube',
#   'oil',
#   'water',
#   'frozen mixed vegetables',
#   'soy sauce'],
#  ['minute white rice',
#   'hot pepper sauce',
#   'oil',
#   'water',
#   'kidney beans',
#   'green pepper',
#   'chicken bouillon cubes',
#   'onion'],
#  ['shrimp',
#   'bacon bits',
#   'black pepper',
#   'parmesan cheese',
#   'baby peas',
#   'half-and-half cream',
#   'garlic salt',
#   'fettuccine'],
#  ['frozen shrimp',
#   'angel hair pasta',
#   'extra virgin olive oil',
#   'salt & pepper',
#   'onion',
#   'white wine',
#   'garlic',
#   'butter'],
#  ['hot chili flakes',
#   'hamburger',
#   'sliced mushrooms',
#   'celery',
#   'jalapenos',
#   'onion',
#   'sweet red pepper',
#   'garlic flakes',
#   'tomato sauce & mushrooms',
#   'sweet green pepper'],
#  ['chili flakes',
#   'chicken broth',
#   'onion',
#   'salt',
#   'fresh ginger',
#   'boneless skinless chicken breast',
#   'asparagus',
#   'rice vinegar',
#   'garlic',
#   'soy sauce',
#   'white pepper'],
#  ['kosher salt',
#   'elbow macaroni',
#   'unsalted butter',
#   'dijon mustard',
#   'fresh ground black pepper',
#   'hot sauce',
#   'extra-sharp cheddar cheese',
#   'half-and-half'],
#  ['flour',
#   'water',
#   'sour cream',
#   'round steak',
#   'fresh mushrooms',
#   'butter',
#   'dry onion soup mix'],
#  ['minute white rice',
#   'extra lean ground beef',
#   'taco seasoning mix',
#   'mexican blend cheese',
#   'water',
#   'lettuce',
#   'chopped tomatoes'],
#  ['cornflour',
#   'sunflower oil',
#   'tiger shrimp',
#   'baby spinach',
#   'water',
#   'thai fish sauce',
#   'lime, juice and zest of',
#   'sweet chili sauce',
#   'pak choi',
#   'dark soy sauce'],
#  ['milk', 'minute rice', 'vanilla instant pudding mix', 'raisins'],
#  ['kidney beans', 'water', 'salsa', 'fire-roasted tomatoes', 'black beans'],
#  ['milk', 'cream cheese', 'fettuccine pasta', 'margarine', 'parmesan cheese'],
#  ['milk',
#   'quick oats',
#   'vanilla',
#   'water',
#   'salt',
#   'honey',
#   'dried fruits',
#   'sugar'],
#  ['15 bean mix',
#   'ham hocks',
#   'black pepper',
#   'tomato sauce',
#   'celery',
#   'bay leaves',
#   'water',
#   'seasoning salt',
#   'garlic',
#   'diced tomatoes',
#   'onion',
#   'carrot',
#   'chicken bouillon cubes'],
#  ['salt and pepper',
#   'dark red kidney beans',
#   'black-eyed peas',
#   'whole tomatoes',
#   'green bell pepper',
#   'vegetable oil',
#   'water',
#   'sharp cheddar cheese',
#   'ground beef',
#   'ketchup',
#   'onion',
#   'chili seasoning mix',
#   'canned green beans',
#   'corn chips',
#   'red pepper flakes'],
#  ['thyme',
#   'sage',
#   'chicken liver',
#   'brandy',
#   'onion',
#   'salt',
#   'marjoram',
#   'garlic',
#   'butter',
#   'heavy cream',
#   'ground black pepper'],
#  ['lean ground beef',
#   'chili beans',
#   'cayenne pepper',
#   'oregano',
#   'chili powder',
#   'sliced mushrooms',
#   'sour cream',
#   'salt',
#   'diced tomatoes',
#   'onion',
#   'cumin'],
#  ['strawberry',
#   'frozen pound cake',
#   'white chocolate baking squares',
#   'jello instant vanilla pudding mix',
#   'cool whip topping',
#   'orange liqueur',
#   'strawberries',
#   'sugar'],
#  ['dried tarragon',
#   'black pepper',
#   'worcestershire sauce',
#   'boneless skinless chicken breast halves',
#   'dijon mustard',
#   'fresh lemon juice'],
#  ['salt and pepper', 'chicken broth', 'basmati rice'],
#  ['cooked chicken',
#   'green enchilada sauce',
#   'sour cream',
#   'lettuce',
#   'tomato',
#   'salsa',
#   'tortilla chips',
#   'monterey jack cheese',
#   'cream of chicken soup',
#   'green onion',
#   'black olives'],
#  ['garlic', 'parmesan cheese', 'butter', 'pasta'],
#  ['feta cheese',
#   'black pepper',
#   'dried oregano',
#   'garlic',
#   'tomato',
#   'old bay seasoning',
#   'olive oil',
#   'parsley',
#   'large shrimp'],
#  ['lemon, zest of',
#   'red onion',
#   'unsalted butter',
#   'zucchini',
#   'corn kernels',
#   'salt & freshly ground black pepper',
#   'olive oil',
#   'snap peas',
#   'large shrimp',
#   'herbs',
#   'cherry tomatoes'],
#  ['white beans',
#   'salt and pepper',
#   'dried oregano',
#   'scallions',
#   'vegetable broth',
#   'olive oil',
#   'garlic',
#   'parmesan cheese',
#   'fresh lemon juice'],
#  ['beans',
#   'oregano',
#   'chicken stock',
#   'celery',
#   'bay leaves',
#   'water',
#   'garlic',
#   'tomato',
#   'italian sausage',
#   'onion',
#   'carrot'],
#  ['cinnamon sticks',
#   'white vinegar',
#   'alum',
#   'pickling spices',
#   'sugar',
#   'pickling salt',
#   'cucumbers'],
#  ['onion', 'barbecue sauce', 'pork butt', 'ginger ale'],
#  ['vanilla bean',
#   'strong coffee',
#   'brown sugar',
#   'vodka',
#   'dark molasses',
#   'cold water',
#   'sugar'],
#  ['whole chickens',
#   'frozen white corn',
#   'chicken broth',
#   'celery',
#   'celery ribs',
#   'chicken bouillon cubes',
#   'onion',
#   'frozen corn',
#   'carrot',
#   'potato'],
#  ['fennel seed',
#   'nonstick cooking spray',
#   'lean ground turkey',
#   'fat-free parmesan cheese',
#   'eggplant',
#   'basil',
#   'oregano leaves',
#   'low-carb marinara sauce'],
#  ['mountain dew soda', 'raspberry vodka'],
#  ['shallots',
#   'salt and pepper',
#   'white cheddar cheese',
#   'pancetta',
#   'apple cider',
#   'tart apples',
#   'red onion',
#   'sherry wine vinegar',
#   'olive oil',
#   'gouda cheese',
#   'white vinegar',
#   'dijon mustard',
#   'arugula',
#   'red wine vinegar',
#   'fresh thyme'],
#  ['light brown sugar',
#   'pure vanilla extract',
#   "confectioners' sugar",
#   'marshmallow cream',
#   'vegetable oil',
#   'unsalted butter',
#   'flour',
#   'salt',
#   'pumpkin pie spice',
#   'baby carrots',
#   'baking powder',
#   'egg',
#   'baking soda'],
#  ['buttermilk',
#   'cocoa',
#   'cinnamon',
#   'vanilla',
#   'flour',
#   'salt',
#   'nutmeg',
#   'baking soda',
#   'butter',
#   'egg',
#   'clove',
#   'sugar'],
#  ['milk',
#   'cornstarch',
#   'sweet cream',
#   'powdered sugar',
#   'flour',
#   'sugar',
#   'almonds',
#   'cream of tartar',
#   'egg',
#   'egg yolks'],
#  ...]

# %% [markdown]
# We'll use the [`Word2Vec`](https://radimrehurek.com/gensim/models/word2vec.html) implementation in the `gensim` library (i.e., *deep learning*) to train an embedding model.
# This approach tends to work best if the training data has at least 100K rows.
#
# Let's also show how to serialize the *word2vec* results, saving them to the `tmp.w2v` file so they could be restored later for other use cases.
#
# NB: there is work in progress which will replace `gensim` with `pytorch` instead.

# %%
import gensim

MIN_COUNT = 2
model_path = "tmp.w2v"

model = gensim.models.Word2Vec(vectors, min_count=MIN_COUNT, window=max_context)
model.save(model_path)

# %% [markdown]
# The `get_related()` function takes any ingredient as input, using the embedding model to find the most similar other ingredients – along with calculating [`levenshtein`](https://github.com/toastdriven/pylev) edit distances (string similarity) among these labels. Then it calculates *percentiles* for both metrics in [`numpy`](https://numpy.org/) and returns the results as a [`pandas`](https://pandas.pydata.org/) DataFrame.

# %%
import numpy as np
import pandas as pd
import pylev

def get_related (model, query, n=20, granularity=100):
    """return a DataFrame of the closely related items"""
    try:
        bins = np.linspace(0, 1, num=granularity, endpoint=True)

        v = sorted(
            model.wv.most_similar(positive=[query], topn=n), 
            key=lambda x: x[1], 
            reverse=True
        )
        
        df = pd.DataFrame(v, columns=["ingredient", "similarity"])
        
        s = df["similarity"]
        quantiles = s.quantile(bins, interpolation="nearest")
        df["sim_pct"] = np.digitize(s, quantiles) - 1
        
        df["levenshtein"] = [ pylev.levenshtein(d, query) / len(query) for d in df["ingredient"] ]
        s = df["levenshtein"]
        quantiles = s.quantile(bins, interpolation="nearest")
        df["lev_pct"] = granularity - np.digitize(s, quantiles)

        return df
    except KeyError:
        return pd.DataFrame(columns=["ingredient", "similarity", "percentile"])

# %% [markdown]
# Let's try this with `dried basil` as the ingredient to query, and review the top `50` most similar other ingredients returned as the DataFrame `df`:

# %%
df = get_related(model, "dried basil", n=50)
df
# Out:
#                       ingredient  similarity  sim_pct  levenshtein  lev_pct
# 0             dried basil leaves    0.665803       99     0.636364       80
# 1                      dry basil    0.637117       97     0.272727       98
# 2                 dried rosemary    0.629282       95     0.636364       80
# 3        dried italian seasoning    0.609094       93     1.272727       32
# 4                    fresh basil    0.605998       91     0.363636       94
# 5       dried sweet basil leaves    0.573398       89     1.181818       34
# 6                 dried marjoram    0.571081       87     0.636364       80
# 7              italian seasoning    0.561759       85     1.090909       48
# 8                  dried parsley    0.555392       83     0.454545       88
# 9          dried rosemary leaves    0.542854       81     1.181818       34
# 10        italian herb seasoning    0.542606       79     1.454545       14
# 11          dried parsley flakes    0.515206       77     1.000000       58
# 12             dried whole thyme    0.513710       75     1.000000       58
# 13         italian seasoning mix    0.502569       73     1.454545       14
# 14                italian spices    0.470836       71     1.090909       48
# 15            fresh basil leaves    0.468227       69     1.000000       58
# 16                         basil    0.462741       67     0.545455       86
# 17  italian-style diced tomatoes    0.452107       65     2.090909        0
# 18   part-skim mozzarella cheese    0.451676       63     2.090909        0
# 19            dried thyme leaves    0.451277       61     1.000000       58
# 20            hunts tomato paste    0.450112       59     1.363636       24
# 21       dried red pepper flakes    0.444190       57     1.454545       14
# 22               lasagna noodles    0.444053       55     1.181818       34
# 23        italian-style tomatoes    0.443903       53     1.727273        8
# 24              sliced mushrooms    0.441693       51     1.000000       58
# 25              italian sausages    0.441518       49     1.090909       48
# 26                   dried thyme    0.439497       47     0.454545       88
# 27          bulk italian sausage    0.438718       45     1.454545       14
# 28          small macaroni pasta    0.436131       43     1.454545       14
# 29              fresh basil leaf    0.436065       41     0.818182       76
# 30  dried italian herb seasoning    0.434577       39     1.636364       10
# 31                   sweet basil    0.432007       37     0.363636       94
# 32              cooked spaghetti    0.430076       35     1.090909       48
# 33               fresh mushrooms    0.428796       33     1.090909       48
# 34                 oregano sprig    0.423705       31     0.909091       72
# 35               ground rosemary    0.422089       29     1.000000       58
# 36               lean pork roast    0.421759       27     1.181818       34
# 37               italian sausage    0.421648       25     1.000000       58
# 38     italian style breadcrumbs    0.421049       23     1.909091        4
# 39                 summer squash    0.417856       21     0.909091       72
# 40         instant minced garlic    0.416912       19     1.363636       24
# 41           pitted black olives    0.416569       17     1.181818       34
# 42                   rubbed sage    0.415938       15     0.727273       78
# 43         sweet italian sausage    0.414169       13     1.545455       12
# 44               button mushroom    0.413882       11     1.181818       34
# 45              dried leaf basil    0.410570        9     0.454545       88
# 46            italian vegetables    0.409838        7     1.363636       24
# 47          mild italian sausage    0.409835        5     1.363636       24
# 48             ground beef round    0.409149        3     1.181818       34
# 49       fat-free ricotta cheese    0.409004        1     1.818182        6

# %% [markdown]
# Note how some of the most similar items, based on vector embedding, are *synonyms* or special forms of our query `dried basil` ingredient: `dried basil leaves`, `dry basil`, `dried sweet basil leaves`, etc. These tend to rank high in terms of levenshtein distance too.

# %% [markdown]
# Let's plot the similarity measures:

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use("ggplot")

df["similarity"].plot(alpha=0.75, rot=0)
plt.show()

# %% [markdown]
# Notice the inflection points at approximately `0.57` and again at `0.47` in that plot.
# We could use some statistical techniques (e.g., clustering) to segment the similarities into a few groups:
#
#   * highest similarity – potential synonyms for the query
#   * mid-range similarity – potential [hypernyms and hyponyms](https://en.wikipedia.org/wiki/Hyponymy_and_hypernymy) for the query
#   * long-tail similarity – other ingredients that pair well with the query

# %% [markdown]
# In this example, below a threshold of the 75th percentile for vector embedding similarity, the related ingredients are less about being synonyms and more about other foods that pair well with basil.
#
# Let's define another function `rank_related()` which ranks the related ingredients based on a combination of these two metrics.
# This uses a cheap approximation of a [*pareto archive*](https://www.cs.bham.ac.uk/~jdk/multi/) for the ranking -- which comes in handing for recommender systems and custom search applications that must combine multiple ranking metrics:

# %%
import math

def rms (values):
    """calculate root mean square"""
    numer = sum([x for x in map(lambda x: float(x)**2.0, values)])
    denom = float(len(values))
    return math.sqrt(numer / denom)

def rank_related (df):
    df2 = df.copy(deep=True)
    df2["related"] = df2.apply(lambda row: rms([row[2], row[4]]), axis=1)
    return df2.sort_values(by=["related"], ascending=False)

# %%
rank_related(df)
# Out:
#                       ingredient  similarity  sim_pct  levenshtein  lev_pct  \
# 1                      dry basil    0.637117       97     0.272727       98
# 4                    fresh basil    0.605998       91     0.363636       94
# 0             dried basil leaves    0.665803       99     0.636364       80
# 2                 dried rosemary    0.629282       95     0.636364       80
# 8                  dried parsley    0.555392       83     0.454545       88
# 6                 dried marjoram    0.571081       87     0.636364       80
# 16                         basil    0.462741       67     0.545455       86
# 31                   sweet basil    0.432007       37     0.363636       94
# 26                   dried thyme    0.439497       47     0.454545       88
# 3        dried italian seasoning    0.609094       93     1.272727       32
# 7              italian seasoning    0.561759       85     1.090909       48
# 11          dried parsley flakes    0.515206       77     1.000000       58
# 5       dried sweet basil leaves    0.573398       89     1.181818       34
# 12             dried whole thyme    0.513710       75     1.000000       58
# 15            fresh basil leaves    0.468227       69     1.000000       58
# 45              dried leaf basil    0.410570        9     0.454545       88
# 9          dried rosemary leaves    0.542854       81     1.181818       34
# 29              fresh basil leaf    0.436065       41     0.818182       76
# 14                italian spices    0.470836       71     1.090909       48
# 19            dried thyme leaves    0.451277       61     1.000000       58
# 10        italian herb seasoning    0.542606       79     1.454545       14
# 42                   rubbed sage    0.415938       15     0.727273       78
# 34                 oregano sprig    0.423705       31     0.909091       72
# 24              sliced mushrooms    0.441693       51     1.000000       58
# 39                 summer squash    0.417856       21     0.909091       72
# 13         italian seasoning mix    0.502569       73     1.454545       14
# 25              italian sausages    0.441518       49     1.090909       48
# 17  italian-style diced tomatoes    0.452107       65     2.090909        0
# 35               ground rosemary    0.422089       29     1.000000       58
# 22               lasagna noodles    0.444053       55     1.181818       34
# 20            hunts tomato paste    0.450112       59     1.363636       24
# 37               italian sausage    0.421648       25     1.000000       58
# 18   part-skim mozzarella cheese    0.451676       63     2.090909        0
# 32              cooked spaghetti    0.430076       35     1.090909       48
# 21       dried red pepper flakes    0.444190       57     1.454545       14
# 33               fresh mushrooms    0.428796       33     1.090909       48
# 23        italian-style tomatoes    0.443903       53     1.727273        8
# 27          bulk italian sausage    0.438718       45     1.454545       14
# 28          small macaroni pasta    0.436131       43     1.454545       14
# 36               lean pork roast    0.421759       27     1.181818       34
# 30  dried italian herb seasoning    0.434577       39     1.636364       10
# 41           pitted black olives    0.416569       17     1.181818       34
# 44               button mushroom    0.413882       11     1.181818       34
# 48             ground beef round    0.409149        3     1.181818       34
# 40         instant minced garlic    0.416912       19     1.363636       24
# 46            italian vegetables    0.409838        7     1.363636       24
# 47          mild italian sausage    0.409835        5     1.363636       24
# 38     italian style breadcrumbs    0.421049       23     1.909091        4
# 43         sweet italian sausage    0.414169       13     1.545455       12
# 49       fat-free ricotta cheese    0.409004        1     1.818182        6
#
#       related
# 1   97.501282
# 4   92.512161
# 0   90.002778
# 2   87.820840
# 8   85.536542
# 6   83.573321
# 16  77.087612
# 31  71.431786
# 26  70.544312
# 3   69.544949
# 7   69.025358
# 11  68.165240
# 5   67.368390
# 12  67.041032
# 15  63.737744
# 45  62.549980
# 9   62.116825
# 29  61.061444
# 14  60.601155
# 19  59.518905
# 10  56.731825
# 42  56.164936
# 34  55.430136
# 24  54.612270
# 39  53.033009
# 13  52.559490
# 25  48.502577
# 17  45.961941
# 35  45.853026
# 22  45.721986
# 20  45.038872
# 37  44.659825
# 18  44.547727
# 32  42.005952
# 21  41.503012
# 33  41.188591
# 23  37.901187
# 27  33.324165
# 28  31.976554
# 36  30.700163
# 30  28.469282
# 41  26.879360
# 44  25.268558
# 48  24.135037
# 40  21.644861
# 46  17.677670
# 47  17.334936
# 38  16.507574
# 43  12.509996
# 49   4.301163

# %% [markdown]
# Notice how the "synonym" cases tend to move up to the top now?
# Meanwhile while the "pairs well with" are in the lower half of the ranked list: `fresh mushrooms`, `italian turkey sausage`, `cooked spaghetti`, `white kidney beans`, etc.

# %% [markdown]
# ---
#
# ## Exercises

# %% [markdown]
# **Exercise 1:**
#
# Build a report for a *human-in-the-loop* reviewer, using the `rank_related()` function while iterating over `vocab` to make algorithmic suggestions for possible synonyms.

# %% [markdown]
# **Exercise 2:**
#
# How would you make algorithmic suggestions for a reviewer about which ingredients could be related to a query, e.g., using the `skos:broader` and `skos:narrower` relations in the [`skos`](https://www.w3.org/2004/02/skos/) vocabulary to represent *hypernyms* and *hyponyms* respectively?
# This could extend the KG to provide a kind of thesaurus about recipe ingredients.
