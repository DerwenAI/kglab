# %% [markdown]
# # Vector embedding with `gensim`
#
# Let's make use of deep learning through a technique called *embedding* -- to analyze the relatedness of the labels used for recipe ingredients.
#
# Among the most closely related ingredients:
#
#   * Some are very close synonyms and should be consolidated to improve data quality
#   * Others are interesting other ingredients that pair frequently, useful for recommendations
#
# On the one hand, this approach is quite helpful for analyzing the NLP annotations that go into a knowledge graph.
# On the other hand it can be used along with [`SKOS`](https://www.w3.org/2004/02/skos/) or similar vocabularies for ontology-based discovery within the graph, e.g., for advanced search UI.

# %% [markdown]
# ## Curating annotations
#
# We'll be working with the labels for ingredients that go into our KG.
# Looking at the raw data, there are many cases where slightly different spellings are being used for the same entity.
#
# As a first step let's define a list of synonyms to substitute, prior to running the vector embedding.
# This will help produce better quality results.
#
# Note that this kind of work comes of the general heading of *curating annotations* ... which is what we spend so much time doing in KG work.
# It's similar to how *data preparation* is ~80% of the workload for data science teams, and for good reason.

# %%
SYNONYMS = {
    "pepper": "black pepper",
    "black pepper": "black pepper",
    
    "egg": "egg",
    "eggs": "egg",

    "vanilla": "vanilla",
    "vanilla extract": "vanilla",
    
    "flour": "flour",
    "all-purpose flour": "flour",

    "onions": "onion",
    "onion": "onion",
        
    "carrots": "carrot",
    "carrot": "carrot",

    "potatoes": "potato",
    "potato": "potato",
    
    "tomatoes": "tomato",
    "fresh tomatoes": "tomato",
    "fresh tomato": "tomato",
    
    "garlic": "garlic",
    "garlic clove": "garlic",
    "garlic cloves": "garlic",
}

# %% [markdown]
# ## Analyze ingredient labels from 250K recipes

# %%
import csv

MAX_ROW = 250000 # 231638

max_context = 0
min_context = 1000

recipes = []
vocab = set()

with open("dat/all_ind.csv", "r") as f:
    reader = csv.reader(f)
    next(reader, None) # remove file header

    for i, row in enumerate(reader):
        id = row[0]
        ind_set = set()
        
        # substitute synonyms
        for ind in set(eval(row[3])):
            if ind in SYNONYMS:
                ind_set.add(SYNONYMS[ind])
            else:
                ind_set.add(ind)
        
        if len(ind_set) > 1:
            recipes.append([id, ind_set])
            vocab.update(ind_set)
        
            max_context = max(max_context, len(ind_set))
            min_context = min(min_context, len(ind_set))

        if i > MAX_ROW:
            break

print("max context: {} unique ingredients per recipe".format(max_context))
print("min context: {} unique ingredients per recipe".format(min_context))
print("vocab size", len(list(vocab)))
# Out:
# max context: 43 unique ingredients per recipe
# min context: 2 unique ingredients per recipe
# vocab size 14931

# %%
import pickle

pickle.dump(recipes, open("tmp.pkl", "wb"))

recipes
# Out:
# [['137739',
#   {'butter',
#    'honey',
#    'mexican seasoning',
#    'mixed spice',
#    'olive oil',
#    'salt',
#    'winter squash'}],
#  ['31490',
#   {'cheese',
#    'egg',
#    'milk',
#    'prepared pizza crust',
#    'salt and pepper',
#    'sausage patty'}],
#  ['112140',
#   {'cheddar cheese',
#    'chili powder',
#    'diced tomatoes',
#    'ground beef',
#    'ground cumin',
#    'kidney beans',
#    'lettuce',
#    'rotel tomatoes',
#    'salt',
#    'tomato paste',
#    'tomato soup',
#    'water',
#    'yellow onions'}],
#  ['59389',
#   {'black pepper',
#    'new potatoes',
#    'olive oil',
#    'parsley',
#    'red bell pepper',
#    'red wine vinegar',
#    'salt',
#    'shallots',
#    'spreadable cheese with garlic and herbs',
#    'tarragon',
#    'yellow bell pepper'}],
#  ['44061',
#   {'apple cider vinegar',
#    'black pepper',
#    'cinnamon oil',
#    'clove oil',
#    'dry mustard',
#    'salt',
#    'sugar',
#    'tomato juice'}],
#  ['5289',
#   {'apple', 'frozen apple juice concentrate', 'milk', 'vanilla ice cream'}],
#  ['25274',
#   {'extra virgin olive oil',
#    'fennel seeds',
#    'garlic',
#    'green olives',
#    'orange juice',
#    'orange rind',
#    'peppercorn',
#    'red chile',
#    'ripe olives'}],
#  ['67888',
#   {'a.1. original sauce',
#    'brown sugar',
#    'chili powder',
#    'cinnamon sticks',
#    'cracked black pepper',
#    'cumin',
#    'dry mustard',
#    'fresh cilantro leaves',
#    'fresh coarse ground black pepper',
#    'fresh garlic',
#    'fresh ginger',
#    'honey',
#    'liquid smoke',
#    'mirin',
#    'orange, juice of',
#    'pork spareribs',
#    'salt',
#    'soy sauce',
#    'tomato sauce',
#    'water',
#    'white vinegar',
#    'yellow onion'}],
#  ['70971',
#   {'bananas',
#    'chocolate sandwich style cookies',
#    'chocolate syrup',
#    'strawberry ice cream',
#    'vanilla ice cream',
#    'whipped cream'}],
#  ['75452',
#   {'baking soda',
#    'bananas',
#    'cake flour',
#    'egg',
#    'fresh lemon juice',
#    'orange rind',
#    'salt',
#    'sugar',
#    'unsalted butter'}],
#  ['109439',
#   {'prepared horseradish', 'sour cream', 'whole berry cranberry sauce'}],
#  ['42198',
#   {'butter',
#    'egg',
#    'powdered sugar',
#    'strawberry',
#    'vanilla wafers',
#    'walnuts',
#    'whipping cream'}],
#  ['67547',
#   {'bacon',
#    'black pepper',
#    'chicken bouillon cubes',
#    'chili powder',
#    'cornstarch',
#    'dark brown sugar',
#    'garlic powder',
#    'great northern bean',
#    'molasses',
#    'mustard powder',
#    'onion',
#    'salt',
#    'water'}],
#  ['107517',
#   {'brown sugar',
#    'collard greens',
#    'ham hock',
#    'hot sauce',
#    'molasses',
#    'salt',
#    'whiskey'}],
#  ['39959',
#   {'burnet root',
#    'gentian root',
#    'scullcap herb',
#    'spearmint',
#    'wood bethony'}],
#  ['63986',
#   {'chicken rice soup',
#    'dry mustard',
#    'flour',
#    'garlic powder',
#    'lean pork chops',
#    'oil',
#    'salt'}],
#  ['43026',
#   {'cheese', 'cornstarch', 'egg roll wrap', 'oil', 'whole green chilies'}],
#  ['23933', {'butterscotch chips', 'chinese noodles', 'salted peanuts'}],
#  ['8559',
#   {'beef broth',
#    'celery',
#    'cooking oil',
#    'ground pork',
#    'hamburger buns',
#    'onion',
#    'soy sauce'}],
#  ['23850',
#   {'broccoli floret',
#    'canola oil',
#    'cauliflower',
#    'escarole',
#    'fresh herb',
#    'garlic',
#    'great northern bean',
#    'green peas',
#    'ground coriander',
#    'onion',
#    'potato',
#    'red bell pepper',
#    'salt and pepper',
#    'salt free herb and spice seasoning mix',
#    'vegetable bouillon cubes',
#    'water'}],
#  ['76808',
#   {'boiling potatoes',
#    'coarse salt',
#    'fresh ground black pepper',
#    'fresh spinach leaves',
#    'nutmeg',
#    'salt',
#    'unsalted butter',
#    'water'}],
#  ['24701',
#   {'apple juice',
#    'broth',
#    'celery',
#    'dried thyme',
#    'fresh parsley',
#    'olive oil',
#    'onion',
#    'rolled oats',
#    'salt',
#    'scallion',
#    'spinach',
#    'white pepper'}],
#  ['83873',
#   {'boneless skinless chicken breast halves',
#    'condensed cream of chicken soup',
#    'cornstarch',
#    'egg',
#    'flour',
#    'garlic powder',
#    'oil',
#    'paprika',
#    'salt and pepper',
#    'seasoning salt'}],
#  ['107699',
#   {'baking powder',
#    'bread',
#    'brown sugar',
#    'butter',
#    'egg',
#    'flour',
#    'granulated sugar',
#    'ground cinnamon',
#    'milk',
#    'powdered sugar',
#    'salt',
#    'vanilla',
#    'vegetable oil'}],
#  ['49262', {'butter', 'egg yolks', 'lemon, juice of', 'salt', 'white pepper'}],
#  ['48156',
#   {'black cumin',
#    'ground black pepper',
#    'ground coriander',
#    'ground cumin',
#    'ground ginger',
#    'ground turmeric'}],
#  ['54272',
#   {'black pepper',
#    'celery',
#    'chili powder',
#    'diced tomatoes',
#    'garlic',
#    'green pepper',
#    'jalapenos',
#    'kidney beans',
#    'onion',
#    'red pepper flakes',
#    'salt',
#    'vegetarian ground beef'}],
#  ['47366',
#   {'beef bouillon cube',
#    'beef stew meat',
#    'cabbage',
#    'dried parsley',
#    'elbow macaroni',
#    'garbanzo beans',
#    'ground pepper',
#    'ground thyme',
#    'onion',
#    'parmesan cheese',
#    'salt',
#    'tomato',
#    'water',
#    'zucchini'}],
#  ['37073', {'margarine', 'red potatoes', 'rosemary'}],
#  ['44123',
#   {'black beans',
#    'broccoli floret',
#    'broccoli stem',
#    'carrot',
#    'celery',
#    'chicken stock',
#    'cornstarch',
#    'dried oregano',
#    'dried sweet basil leaves',
#    'dried thyme',
#    'dry white wine',
#    'heavy cream',
#    'onion',
#    'salt & fresh ground pepper',
#    'smoked chicken',
#    'tabasco sauce',
#    'unsalted butter',
#    'worcestershire sauce'}],
#  ['27087',
#   {'baking cocoa',
#    'baking powder',
#    'butter',
#    'egg',
#    'flour',
#    'miniature peppermint patties',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['59952',
#   {'black pepper',
#    'cheddar cheese',
#    'cornmeal',
#    'ground beef',
#    'hot chili pepper',
#    'onion',
#    'salt',
#    'sliced ripe olives',
#    'tabasco sauce',
#    'taco sauce',
#    'tomato sauce',
#    'whole kernel corn'}],
#  ['93249', {'butter', 'dry ranch dressing mix', 'french bread'}],
#  ['54100',
#   {'black pepper',
#    'dry mustard',
#    'egg substitute',
#    'fresh breadcrumb',
#    'ground venison',
#    'non-fat powdered milk',
#    'onion',
#    'salt',
#    'water',
#    'worcestershire sauce'}],
#  ['67664', {'frozen juice concentrate', 'milk', 'plain yogurt'}],
#  ['87098',
#   {'carrot',
#    'corn',
#    'diced tomatoes',
#    'green beans',
#    'low sodium chicken broth',
#    'potato',
#    'wax beans',
#    'zucchini'}],
#  ['25775',
#   {'black pepper',
#    'condensed cream of mushroom soup',
#    'crouton',
#    'egg',
#    'frozen chopped spinach',
#    'onion',
#    'salt',
#    'sharp cheddar cheese'}],
#  ['33165',
#   {'black pepper',
#    'celery seed',
#    'diced pimentos',
#    'fat-free mayonnaise',
#    'garlic',
#    'green onion',
#    'low-fat sour cream',
#    'plain low-fat yogurt',
#    'prepared mustard',
#    'red potatoes',
#    'salt',
#    'sugar',
#    'white wine vinegar'}],
#  ['38798',
#   {'egg',
#    'frozen chopped spinach',
#    'garlic powder',
#    'margarine',
#    'onion',
#    'oregano',
#    'sage',
#    'soft breadcrumbs'}],
#  ['22123',
#   {'condensed cream of mushroom & garlic soup',
#    'cooking oil',
#    'cornbread mix',
#    'cream of mushroom soup',
#    'frozen vegetables',
#    'ground beef',
#    'onion',
#    'salt & pepper'}],
#  ['90921',
#   {'angel hair pasta',
#    'garlic',
#    'green onions',
#    'honey',
#    'soy sauce',
#    'stir fry vegetables',
#    'toasted sesame oil',
#    'toasted sesame seeds'}],
#  ['93959',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'buckwheat flour',
#    'butter',
#    'canola oil',
#    'cinnamon',
#    'egg',
#    'flour',
#    'ground cinnamon',
#    'ground cloves',
#    'honey',
#    'low-fat buttermilk',
#    'orange juice',
#    'orange rind',
#    'pecans',
#    'salt',
#    'sugar',
#    'unsweetened cocoa',
#    'yam'}],
#  ['93958',
#   {'baking powder',
#    'baking soda',
#    'boiling water',
#    'buckwheat flour',
#    'canola oil',
#    'egg',
#    'flour',
#    'granulated sugar',
#    'ground cinnamon',
#    'ground cloves',
#    'low-fat buttermilk',
#    'orange juice',
#    'orange rind',
#    'raisins',
#    'salt',
#    'sorghum',
#    'unsweetened cocoa',
#    'yam'}],
#  ['58224',
#   {'american cheese',
#    'beer',
#    'cayenne',
#    'garlic',
#    'ground beef',
#    'prepared yellow mustard',
#    'salt & pepper',
#    'sugar'}],
#  ['33606',
#   {'cheese',
#    'chives',
#    'cider vinegar',
#    'dill pickles',
#    'garlic powder',
#    'green onion',
#    'ham',
#    'italian seasoning',
#    'olive oil',
#    'onion powder',
#    'ripe olives',
#    'salt and pepper',
#    'sweet pepper',
#    'tomato',
#    'tri-color spiral pasta',
#    'water chestnut'}],
#  ['94710',
#   {'basil',
#    'flat leaf parsley',
#    'frozen french fries',
#    'oil',
#    'oregano',
#    'parmesan cheese',
#    'salt & freshly ground black pepper'}],
#  ['35173',
#   {'butter',
#    'cheddar cheese',
#    'deli turkey',
#    'good seasonings italian salad dressing mix',
#    'ham',
#    'mozzarella cheese',
#    'pepperoni',
#    'sandwich bun',
#    'swiss cheese'}],
#  ['83025',
#   {'baking powder',
#    'butter',
#    'egg',
#    'flour',
#    'icing sugar',
#    'milk',
#    'salt',
#    'shortening',
#    'sugar',
#    'vanilla'}],
#  ['52804',
#   {'carrot',
#    'cinnamon',
#    'coconut',
#    'crushed pineapple',
#    'egg',
#    'nutmeg',
#    'oil',
#    'pecans',
#    'vanilla instant pudding mix',
#    'water',
#    'yellow cake mix'}],
#  ['108414',
#   {'butter',
#    'egg',
#    'heavy cream',
#    'honey',
#    'jalapenos',
#    'jiffy corn muffin mix',
#    'onion',
#    'red bell pepper',
#    'sharp cheddar cheese',
#    'whole kernel corn'}],
#  ['26995',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'butter',
#    'cinnamon',
#    'crushed pineapple',
#    'dry yeast',
#    'egg',
#    'flour',
#    'milk',
#    'nuts',
#    'raisins',
#    'salt',
#    'sugar',
#    'vanilla',
#    'vegetable oil',
#    'water'}],
#  ['53402',
#   {'cottage cheese',
#    'dried basil',
#    'egg',
#    'garlic',
#    'ground beef',
#    'ground black pepper',
#    'italian sausage',
#    'lasagna noodle',
#    'mozzarella cheese',
#    'parmesan cheese',
#    'parsley flakes',
#    'ricotta cheese',
#    'salt',
#    'tomato paste',
#    'whole tomato'}],
#  ['59632',
#   {'beef',
#    'black pepper',
#    'cheese',
#    'cottage cheese',
#    'egg',
#    'frozen chopped spinach',
#    'herbs',
#    'olive oil flavored cooking spray',
#    'salt',
#    'spices',
#    'toasted wheat germ'}],
#  ['22526',
#   {'brown sugar',
#    'butter',
#    'cinnamon',
#    'instant vanilla pudding',
#    'raisins',
#    'rolls'}],
#  ['100870',
#   {'garlic',
#    'granulated sugar',
#    'ground beef',
#    'prego spaghetti sauce',
#    'stewed tomatoes',
#    'white onion'}],
#  ['84797',
#   {'beef steaks',
#    'brown sugar',
#    'dried dill weed',
#    'fresh garlic',
#    'fresh lemon juice',
#    'fresh parsley',
#    'honey',
#    'hot sauce',
#    'ketchup',
#    'sour cream',
#    'spicy mustard',
#    'vegetable oil'}],
#  ['35653',
#   {'baking powder', 'butter', 'egg', 'flour', 'milk', 'salt', 'sugar'}],
#  ['32169',
#   {'button mushrooms',
#    'chicken breasts',
#    'dried basil',
#    'dried oregano',
#    'fresh ground black pepper',
#    'fresh parsley',
#    'garlic',
#    'hot sauce',
#    'olive oil',
#    'onion',
#    'parmesan cheese',
#    'pasta',
#    'salsa',
#    'tomato',
#    'water'}],
#  ['24478', {'cider vinegar', 'fresh herb', 'fresh herbs'}],
#  ['44045',
#   {'baking powder',
#    'black pepper',
#    'cream',
#    'egg',
#    'fat',
#    'flour',
#    'fresh corn',
#    'salt'}],
#  ['60219',
#   {'black olives',
#    'cheddar cheese soup',
#    'fettuccine pasta',
#    'jalapeno',
#    'milk',
#    'picante sauce'}],
#  ['81185',
#   {'cilantro',
#    'frozen peas',
#    'hass avocado',
#    'lemons, juice of',
#    'onion',
#    'salt',
#    'tomato'}],
#  ['30131',
#   {'basil',
#    'black pepper',
#    'garlic powder',
#    'lemon juice',
#    'oil',
#    'soy sauce',
#    'worcestershire sauce'}],
#  ['63593',
#   {'apple', 'cream cheese', 'milk', 'pear', 'unflavored gelatin', 'yogurt'}],
#  ['43164',
#   {'bacon',
#    'bay leaf',
#    'black pepper',
#    'butter',
#    'carrot',
#    'oil',
#    'onion',
#    'parsley sprigs',
#    'salt',
#    'thyme',
#    'veal roast'}],
#  ['30300', {'black pepper', 'crackers', 'mayonnaise', 'tomato'}],
#  ['78655',
#   {'brine',
#    'capers',
#    'carrot',
#    'ciabatta',
#    'fresh basil',
#    'fresh parsley',
#    'garlic',
#    'genoa salami',
#    'green olives',
#    'ham',
#    'kalamata olive',
#    'olive oil',
#    'oregano leaves',
#    'provolone cheese',
#    'red wine vinegar',
#    'sweet onion',
#    'tomato'}],
#  ['74805',
#   {'powdered sugar',
#    'vanilla',
#    'vanilla instant pudding mix',
#    'whipping cream'}],
#  ['71635',
#   {'cookie',
#    'cream cheese',
#    'gelatin',
#    'milk',
#    'miniature semisweet chocolate chips',
#    'prepared graham cracker crusts',
#    'sugar',
#    'vanilla'}],
#  ['38276',
#   {'baking powder',
#    'butter',
#    'carrot',
#    'cayenne pepper',
#    'celery',
#    'chili powder',
#    'cloves',
#    'egg',
#    'flour',
#    'green pepper',
#    'ground cumin',
#    'monterey jack cheese',
#    'onion',
#    'oregano',
#    'salt',
#    'sliced mushrooms',
#    'soy sauce',
#    'tomato',
#    'vegetable shortening',
#    'water',
#    'zucchini'}],
#  ['97052', {'half-and-half', 'salt and pepper', 'sweet butter', 'sweet corn'}],
#  ['26835',
#   {'baking soda',
#    'butter',
#    'egg',
#    'flour',
#    'lemon, rind of',
#    'salt',
#    'sugar',
#    'vanilla',
#    'yogurt'}],
#  ['32271',
#   {'butter',
#    'egg',
#    'flour',
#    'nuts',
#    'sugar',
#    'unsweetened chocolate squares',
#    'vanilla'}],
#  ['107229',
#   {'broccoli',
#    'chili-garlic sauce',
#    'cooked chicken',
#    'fresh cilantro',
#    'fresh ginger',
#    'green onions',
#    'reduced sodium soy sauce',
#    'rice vinegar',
#    'sesame oil',
#    'sesame seeds',
#    'vegetable oil',
#    'vermicelli'}],
#  ['5060',
#   {'apples',
#    'celery',
#    'orange juice',
#    'orange rind',
#    'pecans',
#    'philadelphia cream cheese',
#    'sugar'}],
#  ['42570',
#   {'boneless chicken breast',
#    'cayenne',
#    'cumin',
#    'fresh ground pepper',
#    'garlic',
#    'lemon juice',
#    'olive oil',
#    'paprika',
#    'salt',
#    'thyme'}],
#  ['52443',
#   {'baking potato',
#    'garlic powder',
#    'mozzarella cheese',
#    'oregano leaves',
#    'parmesan cheese',
#    'part-skim ricotta cheese',
#    'tomato sauce'}],
#  ['35595',
#   {'black pepper',
#    'cornstarch',
#    'mushroom pieces',
#    'onion',
#    'sodium-free vegetable broth',
#    'tabasco sauce',
#    'tomato puree',
#    'white wine'}],
#  ['108804',
#   {'albacore tuna in water',
#    'bibb lettuce',
#    'black pepper',
#    'fresh basil',
#    'garlic',
#    'light olive oil',
#    'red sweet bell peppers',
#    'red wine vinegar',
#    'salt',
#    'scallions',
#    'white kidney beans'}],
#  ['83950',
#   {'bacon',
#    'beef consomme',
#    'black pepper',
#    'butter',
#    'carrot',
#    'celery',
#    'crushed tomatoes',
#    'dry white wine',
#    'garlic',
#    'ground pork',
#    'lean ground beef',
#    'milk',
#    'nutmeg',
#    'olive oil',
#    'onion',
#    'oregano',
#    'penne pasta',
#    'red pepper flakes',
#    'rubbed sage',
#    'salt'}],
#  ['19208', {'apples', 'red cinnamon candies', 'sugar substitute', 'water'}],
#  ['64302',
#   {'brown sugar',
#    'celery',
#    'cucumber',
#    'elbow macaroni',
#    'green pepper',
#    'ketchup',
#    'lemon juice',
#    'oil',
#    'onion',
#    'tomato'}],
#  ['35964',
#   {'baking powder',
#    'brown sugar',
#    'cocoa',
#    'flour',
#    'hot water',
#    'milk',
#    'salt',
#    'sugar',
#    'vanilla',
#    'vegetable oil'}],
#  ['71457',
#   {'apple pie filling',
#    'butter',
#    'egg',
#    'flour',
#    'milk',
#    'powdered sugar',
#    'salt',
#    'toasted almonds'}],
#  ['95926', {'bananas', 'mayonnaise', 'white bread'}],
#  ['103948',
#   {'boneless skinless chicken thighs',
#    'breadcrumbs',
#    'chicken stock',
#    'dried oregano',
#    'dried thyme',
#    'dry white wine',
#    'flour',
#    'fresh ground black pepper',
#    'garlic powder',
#    'lean ground beef',
#    'milk',
#    'onion',
#    'poultry seasoning',
#    'salt',
#    'vegetable oil'}],
#  ['99024',
#   {'cream cheese', 'lemon juice', 'liquid smoke', 'onion', 'salmon', 'salt'}],
#  ['64045',
#   {'bean sprouts',
#    'brown sugar',
#    'carrot',
#    'desiccated coconut',
#    'garlic',
#    'ginger',
#    'green beans',
#    'ground cayenne pepper',
#    'ground coriander',
#    'ground cumin',
#    'onion',
#    'peanut oil',
#    'peanuts',
#    'red chili pepper',
#    'sambal oelek',
#    'soy sauce',
#    'tempeh',
#    'tomato',
#    'vegetable stock',
#    'water'}],
#  ['41756',
#   {'dried breadcrumbs',
#    'egg',
#    'ground beef',
#    'lemon juice',
#    'onion',
#    'salt and pepper',
#    'sugar',
#    'tomato soup',
#    'water'}],
#  ['112959',
#   {'avocado',
#    'chunky salsa',
#    'fresh cilantro',
#    'hot sauce',
#    'lime juice',
#    'salt and pepper',
#    'soft silken tofu'}],
#  ['83062',
#   {'baking soda',
#    'bananas',
#    'cinnamon',
#    'egg',
#    'flour',
#    'ground cloves',
#    'nutmeg',
#    'salt',
#    'shortening',
#    'walnuts',
#    'white sugar'}],
#  ['98930',
#   {'boneless skinless chicken breast',
#    'dried basil',
#    'lime juice',
#    'olive oil',
#    'salt and pepper',
#    'tomato'}],
#  ['83133',
#   {'beef ribs',
#    'brown sugar',
#    'fresh lemon juice',
#    'ketchup',
#    'mustard',
#    'onion',
#    'salt',
#    'vegetable oil',
#    'water',
#    'worcestershire sauce'}],
#  ['39947', {'egg whites', 'green grape', 'sugar'}],
#  ['44895',
#   {'betty crocker fudge brownie mix',
#    'egg',
#    'milk chocolate candy bars',
#    'vegetable oil',
#    'water'}],
#  ['39363',
#   {'baking powder',
#    'baking soda',
#    'bananas',
#    'butter',
#    'chocolate chips',
#    'egg',
#    'flour',
#    'nuts',
#    'salt',
#    'sugar',
#    'water'}],
#  ['62368',
#   {'brown sugar',
#    'butter',
#    'chocolate chips',
#    'cream cheese',
#    'egg',
#    'flour',
#    'oreo cookie crumbs',
#    'sour cream',
#    'sweetened condensed milk',
#    'vanilla'}],
#  ['111875',
#   {'2% low-fat milk',
#    'banana',
#    'natural-style peanut butter',
#    'sugar-free non-fat vanilla yogurt'}],
#  ['42522',
#   {'bean dip',
#    'cheddar cheese',
#    'cream cheese',
#    'sour cream',
#    'taco seasoning'}],
#  ['34930',
#   {'american cheese',
#    'bacon',
#    'dill weed',
#    'ground sirloin',
#    'iceberg lettuce',
#    "mccormick's montreal brand steak seasoning",
#    'no-salt-added ketchup',
#    'onion',
#    'tomato'}],
#  ['63793',
#   {'chat masala',
#    'chopped tomato',
#    'cucumber',
#    'paprika',
#    'plain yogurt',
#    'potato',
#    'salt'}],
#  ['61973',
#   {'baking soda',
#    'brown sugar',
#    'buttermilk',
#    'carrot',
#    'cinnamon',
#    'corn oil',
#    'egg',
#    'natural bran',
#    'raisins',
#    'salt',
#    'vanilla',
#    'whole wheat flour'}],
#  ['45859',
#   {'grand marnier',
#    'lime juice',
#    'lime wedge',
#    'limeade',
#    'tequila',
#    'triple sec'}],
#  ['58651',
#   {'brown sugar', 'butter', 'flour', 'pecans', 'semi-sweet chocolate chips'}],
#  ['59534',
#   {'black pepper',
#    'butter',
#    'cappelletti pasta',
#    'cheddar cheese',
#    'chopped tomato',
#    'corn',
#    'garlic',
#    'ground beef',
#    'milk',
#    'mushrooms',
#    'onion',
#    'salt',
#    'tomato soup'}],
#  ['24137',
#   {'dry white wine',
#    'extra virgin olive oil',
#    'garlic',
#    'hot water',
#    'parsley',
#    'salt and pepper',
#    'spaghetti',
#    'squid',
#    'tomato sauce'}],
#  ['40237',
#   {'baking soda',
#    'cocoa',
#    'flour',
#    'salt',
#    'sugar',
#    'vanilla',
#    'vegetable oil',
#    'vinegar',
#    'water'}],
#  ['18537', {'applesauce', 'brown sugar', 'clove', 'pork loin chops'}],
#  ['104243',
#   {'butter',
#    'cheddar cheese',
#    'cream cheese',
#    'green olives',
#    'ham',
#    'honey mustard',
#    'leaf lettuce',
#    'mayonnaise',
#    'prepared horseradish',
#    'provolone cheese',
#    'radish sprouts',
#    'roast beef',
#    'roasted red peppers',
#    'swiss cheese',
#    'turkey',
#    'whole wheat bread dough'}],
#  ['105069',
#   {'beef broth',
#    'butter',
#    'flour',
#    'fresh dill',
#    'lemon, juice of',
#    'onion',
#    'salt and pepper',
#    'sour cream',
#    'water',
#    'wild mushrooms'}],
#  ['70099',
#   {'asian chili sauce',
#    'bean sprouts',
#    'carrot',
#    'english cucumber',
#    'fresh cilantro',
#    'fresh ginger',
#    'garlic',
#    'green onions',
#    'honey',
#    'light soy sauce',
#    'rice noodles',
#    'rice wine vinegar',
#    'sesame oil'}],
#  ['333281',
#   {'bittersweet chocolate',
#    'brewed espresso',
#    'egg',
#    'flour',
#    'granulated sugar',
#    'kosher salt',
#    'unsalted butter',
#    'unsweetened cocoa powder',
#    'vanilla'}],
#  ['234069', {'brown sugar', 'dr. pepper cola', 'orange marmalade'}],
#  ['37841',
#   {'fish',
#    'gingerroot',
#    'low sodium soy sauce',
#    'peanut oil',
#    'rice wine',
#    'salt',
#    'scallions',
#    'sesame oil',
#    'white pepper'}],
#  ['144952',
#   {'beef broth',
#    'butter',
#    'flour',
#    'french bread',
#    'garlic',
#    'low sodium beef broth',
#    'olive oil',
#    'parmesan cheese',
#    'romano cheese',
#    'sherry wine',
#    'sugar',
#    'swiss cheese',
#    'yellow onions'}],
#  ['453467',
#   {'baking soda',
#    'brown sugar',
#    'chocolate chips',
#    'egg',
#    'flour',
#    'margarine',
#    'salt',
#    'vanilla',
#    'water',
#    'white sugar',
#    'whole wheat flour'}],
#  ['31835',
#   {'butter',
#    'cornbread',
#    'cream of chicken soup',
#    'egg',
#    'onion',
#    'sage',
#    'squash'}],
#  ['197013',
#   {'bay leaves',
#    'black pepper',
#    'bottled garlic',
#    'dried basil',
#    'dried oregano',
#    'dried parsley',
#    'garlic powder',
#    'italian sausage',
#    'olive oil',
#    'paprika',
#    'salt',
#    'sugar',
#    'tomato sauce',
#    'white onion'}],
#  ['306168',
#   {'cream of chicken soup',
#    'french-fried onions',
#    'frozen broccoli cuts',
#    'garlic powder',
#    'ground black pepper',
#    'milk',
#    'salt',
#    'sharp cheddar cheese',
#    'soy sauce'}],
#  ['286009',
#   {'almond extract',
#    'butter',
#    'egg',
#    'flour',
#    'pure vanilla extract',
#    'sugar',
#    'whole milk'}],
#  ['24514',
#   {'artichoke hearts',
#    'egg',
#    'fresh garlic',
#    'oil',
#    'unsalted butter',
#    'unseasoned breadcrumbs'}],
#  ['42508',
#   {'barbecue sauce',
#    'black pepper',
#    'chicken',
#    'chili powder',
#    'cider vinegar',
#    'hot red pepper sauce',
#    'salt',
#    'worcestershire sauce'}],
#  ['116679',
#   {'cheddar cheese',
#    'cream cheese',
#    'dry onion soup mix',
#    'frozen broccoli',
#    'ritz cracker crumbs',
#    'sour cream',
#    'water chestnuts'}],
#  ['124286',
#   {'baking soda',
#    'cocoa powder',
#    'cool whip',
#    'flour',
#    'instant chocolate pudding mix',
#    'mayonnaise',
#    'milk',
#    'salt',
#    'sugar',
#    'vanilla',
#    'water'}],
#  ['190',
#   {'bouillon',
#    'budweiser beer',
#    'chili powder',
#    'coriander',
#    'cornmeal',
#    'cumin',
#    'flour',
#    'garlic',
#    'hunts tomato sauce',
#    'lean chuck',
#    'lean pork',
#    'louisiana hot sauce',
#    'onion',
#    'oregano leaves',
#    'paprika',
#    'sugar',
#    'unsweetened cocoa',
#    'water'}],
#  ['475785',
#   {'baby spinach',
#    'egg',
#    'fresh garlic',
#    'goat cheese',
#    'kosher salt',
#    'meatloaf mixture',
#    'olive oil',
#    'red bell pepper',
#    'simply potatoes shredded hash browns',
#    'unsalted butter',
#    'unsmoked bacon',
#    'white pepper',
#    'yellow onion'}],
#  ['17265',
#   {'dark brown sugar',
#    'egg',
#    'egg white',
#    'ground cinnamon',
#    'ground cloves',
#    'ground ginger',
#    'heavy cream',
#    'milk',
#    'nutmeg',
#    'pie crusts',
#    'pumpkin puree',
#    'salt'}],
#  ['50662',
#   {'baking powder',
#    'beef',
#    'breadcrumbs',
#    'butter',
#    'celery seed',
#    'cream of chicken soup',
#    'dry onion flakes',
#    'flour',
#    'milk',
#    'onion',
#    'paprika',
#    'poppy seed',
#    'poultry seasoning',
#    'salt',
#    'sour cream',
#    'vegetable oil'}],
#  ['177187',
#   {'baking powder',
#    'baking soda',
#    'blended oatmeal',
#    'brown sugar',
#    'butter',
#    'egg',
#    'flour',
#    'hershey chocolate candy bars',
#    'nuts',
#    'semi-sweet chocolate chips',
#    'sugar',
#    'vanilla'}],
#  ['118843',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'butter',
#    'chocolate chips',
#    'egg',
#    'flour',
#    "hershey's semi-sweet baking chocolate",
#    'nuts',
#    'oatmeal',
#    'salt',
#    'vanilla',
#    'white sugar'}],
#  ['208179', {'butter', 'flour', 'granulated sugar', 'milk', 'vanilla'}],
#  ['500166',
#   {'cheddar cheese',
#    'corn cobs',
#    'ground beef',
#    'lettuce',
#    'onion',
#    'salsa',
#    'taco seasoning',
#    'taco shells',
#    'tomato'}],
#  ['501028',
#   {'beans',
#    'beef bouillon cube',
#    'beef broth',
#    'bell peppers',
#    'black pepper',
#    'chicken bouillon cube',
#    'chunky salsa',
#    'cinnamon',
#    'cumin',
#    'dark chocolate chips',
#    'garlic',
#    'ground coriander',
#    'habanero pepper',
#    'light brown sugar',
#    'mexican chili powder',
#    'salt',
#    'sazon goya',
#    'stewing beef',
#    'stewing pork',
#    'tomato paste',
#    'tortilla chips',
#    'white onion'}],
#  ['136602',
#   {'baking soda',
#    'brown sugar',
#    'butter',
#    'cream cheese',
#    'egg',
#    'flour',
#    'lemon zest',
#    'lime zest',
#    'orange-flavored liqueur',
#    'pecans',
#    'pitted dates',
#    'powdered sugar',
#    'salt',
#    'shortening',
#    'tequila',
#    'triple sec',
#    'warm water'}],
#  ['69190',
#   {'bouillon cubes',
#    'butter',
#    'carrot',
#    'celery',
#    'cream of celery soup',
#    'cream of chicken soup',
#    'milk',
#    'onion',
#    'potato',
#    'potato flakes',
#    'water'}],
#  ['503475',
#   {'apples',
#    'butter',
#    'cinnamon',
#    'cream',
#    'egg',
#    'flour',
#    'lemon, juice of',
#    'milk',
#    'salt',
#    'sugar'}],
#  ['522861',
#   {'butter',
#    'cheese',
#    'fresh coarse ground black pepper',
#    'garlic',
#    'macaroni',
#    'milk',
#    'onion',
#    'salt'}],
#  ['457136',
#   {'black pepper',
#    'cheese',
#    'fine semolina',
#    'heavy cream',
#    'macaroni',
#    'muscat wine',
#    'onion',
#    'potato',
#    'salt water',
#    'unsalted butter'}],
#  ['455351',
#   {'applesauce',
#    'butter',
#    'cheese',
#    'milk',
#    'onion',
#    'penne pasta',
#    'potato',
#    'salt and pepper'}],
#  ['333797', {'dried yellow peas', 'ginger', 'pork', 'salt', 'water'}],
#  ['428056',
#   {'black pepper',
#    'brown mustard',
#    'carrot',
#    'clove',
#    'dried thyme',
#    'dried yellow peas',
#    'ground ginger',
#    'ham bone',
#    'onion',
#    'salt',
#    'water'}],
#  ['306245', {'butter', 'fresh spinach', 'nutmeg', 'water'}],
#  ['523359',
#   {'chili powder',
#    'cornstarch',
#    'dried onion flakes',
#    'garlic powder',
#    'granulated sugar',
#    'ground beef',
#    'ground black pepper',
#    'ground pork',
#    'paprika',
#    'salt',
#    'tomato paste',
#    'water',
#    'white vinegar',
#    'wondra flour'}],
#  ['495314',
#   {'apple cider vinegar',
#    'applesauce',
#    'cayenne',
#    'dark brown sugar',
#    'granulated garlic',
#    'liquid smoke',
#    'maple syrup',
#    'oregano',
#    'ponzu sauce',
#    'salt',
#    'tomato ketchup'}],
#  ['149593',
#   {'baking powder',
#    'baking soda',
#    'butter',
#    'egg',
#    'flour',
#    'salt',
#    'sour cream',
#    'sugar',
#    'vanilla'}],
#  ['227924',
#   {'butter', 'frozen whipped topping', 'oreo cookies', 'vanilla ice cream'}],
#  ['100540', {'butter', 'processed cheese', 'white bread'}],
#  ['155959',
#   {'balsamic vinegar',
#    'fresh ground black pepper',
#    'garlic',
#    'london broil beef',
#    'olive oil',
#    'rosemary',
#    'soy sauce',
#    'worcestershire sauce'}],
#  ['29214',
#   {'chicken broth',
#    'cornstarch',
#    'dried oregano',
#    'dried rosemary',
#    'dried thyme',
#    'dry sherry',
#    'fresh mushrooms',
#    'garlic',
#    'hot pepper sauce',
#    'margarine',
#    'nonfat dry milk powder',
#    'nonfat milk',
#    'parmesan cheese',
#    'salt and black pepper',
#    'spicy brown mustard',
#    'teriyaki sauce'}],
#  ['92533',
#   {'almonds',
#    'butter',
#    'cinnamon',
#    'cream cheese',
#    'egg',
#    'nutmeg',
#    'sour cream',
#    'splenda sugar substitute',
#    'vanilla',
#    'vanilla protein powder'}],
#  ['209203',
#   {'bacon', 'butter', 'real maple syrup', 'refrigerated buttermilk biscuits'}],
#  ['42151',
#   {'horseradish',
#    'mayonnaise',
#    'tabasco sauce',
#    'velveeta cheese',
#    'worcestershire sauce'}],
#  ['327356', {'lemon juice', 'red wine vinegar', 'water'}],
#  ['325509',
#   {'berries',
#    'ground flax seeds',
#    "i can't believe it's not butter spread",
#    'old fashioned oats',
#    'sugar-free syrup',
#    'water'}],
#  ['236184',
#   {'blueberries',
#    'cream cheese',
#    'egg',
#    'flour',
#    'french bread',
#    'frozen blueberries',
#    'maple syrup',
#    'milk',
#    'nuts',
#    'powdered sugar',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['241445',
#   {'bacon',
#    'celery',
#    'cheddar cheese',
#    'chicken broth',
#    'chives',
#    'liquid smoke',
#    'onion',
#    'red potatoes',
#    'salt',
#    'sour cream',
#    'velveeta cheese',
#    'white pepper'}],
#  ['149887',
#   {'active dry yeast',
#    'brown sugar',
#    'butter',
#    'cinnamon',
#    'cream cheese',
#    'egg',
#    'flour',
#    'granulated sugar',
#    'milk',
#    'powdered sugar',
#    'salt',
#    'vanilla pudding mix',
#    'warm water'}],
#  ['112984',
#   {'asparagus',
#    'garlic',
#    'italian seasoning',
#    'part-skim mozzarella cheese',
#    'red bell pepper',
#    'reduced-fat parmesan cheese',
#    'salt and pepper',
#    'spaghetti sauce',
#    'spaghetti squash',
#    'white mushroom'}],
#  ['200148',
#   {'coriander',
#    'cornstarch',
#    'frozen pineapple concentrate',
#    'graham cracker crumbs',
#    'lemon juice',
#    'maple syrup',
#    'margarine',
#    'oil',
#    'soft silken tofu',
#    'vanilla',
#    'vegan cream cheese',
#    'vegan sugar',
#    'water'}],
#  ['445026',
#   {'andouille sausage',
#    'celery',
#    'cooked chicken',
#    'creole seasoning',
#    'flour',
#    'frozen black-eyed peas',
#    'garlic',
#    'green bell pepper',
#    'large raw shrimp',
#    'low sodium chicken broth',
#    'onion',
#    'vegetable oil'}],
#  ['70611',
#   {'cheddar cheese',
#    'cracker',
#    'egg',
#    'ground beef',
#    'onion',
#    'pickle',
#    'salt and pepper',
#    'thousand island dressing'}],
#  ['273326',
#   {'basil',
#    'butter',
#    'cajun spices',
#    'garlic',
#    'heavy whipping cream',
#    'lemon juice',
#    'linguine',
#    'parmesan cheese',
#    'parmesan-romano cheese mix',
#    'parsley',
#    'salmon',
#    'salt',
#    'white pepper'}],
#  ['310570', {'cottage cheese', 'egg', 'feta', 'milk', 'oil', 'phyllo dough'}],
#  ['318677',
#   {'avocado',
#    'cucumber',
#    'imitation crabmeat',
#    'lettuce',
#    'pickled ginger',
#    'seasoned rice vinegar',
#    'soy sauce',
#    'white rice'}],
#  ['80050',
#   {'baking soda',
#    'egg',
#    'flour',
#    'maraschino cherry',
#    'mincemeat',
#    'mixed candied fruit',
#    'sweetened condensed milk',
#    'walnuts'}],
#  ['269984',
#   {'baby carrots',
#    'baking powder',
#    'black pepper',
#    'celery',
#    'chicken breasts',
#    'chicken stock',
#    'egg',
#    'kosher salt',
#    'matzo meal',
#    'oil',
#    'salt',
#    'sugar',
#    'white onion'}],
#  ['317508',
#   {'cheddar cheese',
#    'cream of mushroom soup',
#    'frozen southern style hash brown potatoes',
#    'poppy seed',
#    'sour cream'}],
#  ['53872',
#   {'adobo seasoning',
#    'egg',
#    'fresh garlic cloves',
#    'fresh ground pepper',
#    'ground coriander',
#    'ground sage',
#    'italian seasoned breadcrumbs',
#    'ketchup',
#    'lean ground beef',
#    'low sodium soy sauce',
#    'olive oil',
#    'oregano',
#    'red onion',
#    'sea salt',
#    'veggie shreds cheese'}],
#  ['268942',
#   {'butter',
#    'celery',
#    'cream of celery soup',
#    'green bell pepper',
#    'kraft macaroni and cheese',
#    'mushrooms',
#    'onion',
#    'tuna'}],
#  ['176110',
#   {'black pepper',
#    'cider vinegar',
#    'dry mustard',
#    'garlic',
#    'ketchup',
#    'miracle whip',
#    'paprika',
#    'salt',
#    'sugar',
#    'tabasco sauce',
#    'vegetable oil'}],
#  ['205331',
#   {'extra virgin olive oil',
#    'italian parsley',
#    'kalamata olive',
#    'kosher salt & freshly ground black pepper',
#    'lemon, juice of',
#    'oregano',
#    'pepperoncini peppers',
#    'red bell pepper',
#    'red onion',
#    'red ripe tomatoes',
#    'red wine vinegar',
#    'seedless cucumber',
#    'shallot',
#    'tuna in vegetable oil',
#    'water-packed artichoke hearts'}],
#  ['165856',
#   {'buttermilk',
#    'canola oil',
#    'egg',
#    'ground black pepper',
#    'orange roughy',
#    'seasoning salt',
#    'self-rising flour'}],
#  ['474769',
#   {'bacon',
#    'egg',
#    'egg yolk',
#    'flour',
#    'frozen spinach',
#    'garlic',
#    'goat cheese',
#    'green onion',
#    'salt',
#    'simply potatoes traditional mashed potatoes'}],
#  ['138005',
#   {'boneless pork chops',
#    'cajun seasoning',
#    'canola oil',
#    'egg',
#    'flour',
#    'ground black pepper',
#    'milk',
#    'salt and pepper',
#    'seasoning salt',
#    'self-rising flour'}],
#  ['216945',
#   {'imitation crabmeat',
#    'ramen noodles',
#    'stir fry vegetables',
#    'teriyaki marinade',
#    'water'}],
#  ['164526',
#   {'apple',
#    'banana',
#    'celery',
#    'fresh cilantro leaves',
#    'green bell pepper',
#    'ground red pepper',
#    'pesto sauce',
#    'pumpkin puree',
#    'pumpkin seeds',
#    'red onion',
#    'salt',
#    'small red potato',
#    'smooth cashew butter',
#    'vegetable broth'}],
#  ['50184',
#   {'chili powder',
#    'dry-roasted cashews',
#    'garlic',
#    'margarine',
#    'mushrooms',
#    'nutmeg',
#    'parsley',
#    'vegetable bouillon cubes',
#    'water'}],
#  ['316470',
#   {'ice cubes', 'mangoes', 'oranges', 'strawberries', 'vanilla bean'}],
#  ['343338',
#   {'fresh rosemary',
#    'garlic',
#    'leeks',
#    'olive oil',
#    'russet potatoes',
#    'salt and pepper',
#    'vegetable broth',
#    'white beans'}],
#  ['137434',
#   {'black peppercorns',
#    'boneless skinless chicken breasts',
#    'cardamom pods',
#    'chicken stock',
#    'chili powder',
#    'cinnamon stick',
#    'cloves',
#    'coriander seed',
#    'fresh coriander',
#    'fresh ginger',
#    'garlic',
#    'ground cumin',
#    'onion',
#    'salt & freshly ground black pepper',
#    'soy yogurt',
#    'turmeric'}],
#  ['95534',
#   {'beef bouillon cubes',
#    'black pepper',
#    'boiling water',
#    'dried oregano',
#    'dried thyme',
#    'garlic',
#    'garlic powder',
#    'rump roast',
#    'salt',
#    'tabasco sauce',
#    'worcestershire sauce'}],
#  ['30473', {'ginger', 'honey', 'milk', 'tea bag', 'water'}],
#  ['24470', {'ground beef', 'sausage', 'taco chips', 'velveeta cheese'}],
#  ['311991',
#   {'bell pepper',
#    'brown sugar',
#    'garlic powder',
#    'ground mustard',
#    'hamburger buns',
#    'ketchup',
#    'lean ground beef',
#    'onion',
#    'steak seasoning',
#    'tomato sauce',
#    'white vinegar',
#    'worcestershire sauce'}],
#  ['225707',
#   {'beets',
#    'black pepper',
#    'carrot',
#    'fresh corn kernels',
#    'garlic',
#    'gingerroot',
#    'green onions',
#    'green peppers',
#    'honey',
#    'rice wine vinegar',
#    'safflower oil',
#    'salad greens',
#    'salad seasoning',
#    'salt',
#    'soy sauce',
#    'white mushrooms'}],
#  ['242830',
#   {'chicken broth',
#    'dry white wine',
#    'fennel seeds',
#    'fresh lemon juice',
#    'olive oil',
#    'onion',
#    'paprika',
#    'pork chops'}],
#  ['336744',
#   {'black olives',
#    'egg',
#    'garlic powder',
#    'italian seasoning',
#    'mozzarella cheese',
#    'pepperoni',
#    'ramen noodles',
#    'red bell pepper',
#    'roma tomato'}],
#  ['83542',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'egg',
#    'flour',
#    'milk',
#    'molasses',
#    'natural bran',
#    'oil',
#    'raisins',
#    'salt',
#    'sesame seeds',
#    'sunflower seeds'}],
#  ['91626',
#   {'black tea leaves',
#    'broiler',
#    'brown sugar',
#    'dry sherry',
#    'garlic',
#    'low sodium soy sauce',
#    'minced ginger',
#    'onion',
#    'orange zest',
#    'orange, juice of',
#    'peppercorn'}],
#  ['303457',
#   {'cardamom pods',
#    'cloves',
#    'coriander seed',
#    'fruit vinegar',
#    'gingerroot',
#    'kaffir lime leaves',
#    'lemongrass',
#    'peanut oil',
#    'star anise',
#    'turmeric',
#    'yoghurt'}],
#  ['176717',
#   {'blueberry pie filling',
#    'cool whip',
#    'graham wafers',
#    'vanilla pudding mix'}],
#  ['39226',
#   {'canned jalapeno slices',
#    'cayenne pepper',
#    'chili powder',
#    'cornstarch',
#    'dried onion flakes',
#    'garlic powder',
#    'onion powder',
#    'salt',
#    'sugar',
#    'tomato paste',
#    'vinegar',
#    'water'}],
#  ['216030',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'butter',
#    'cake flour',
#    'corn flakes',
#    'egg',
#    'nuts',
#    'quick-cooking oats',
#    'raisins',
#    'salt',
#    'shredded coconut',
#    'vanilla'}],
#  ['268169',
#   {'black pepper',
#    'butter',
#    'italian spices',
#    'kosher salt',
#    'olive oil',
#    'onion',
#    'whole turkey'}],
#  ['98357',
#   {'cheddar cheese',
#    'chili with beans',
#    'corn chips',
#    'onion',
#    'salsa',
#    'sour cream'}],
#  ['150365',
#   {'black pepper',
#    'cauliflower florets',
#    'egg',
#    'parsley sprig',
#    'plain breadcrumbs',
#    'salt',
#    'vegetable oil'}],
#  ['243251',
#   {'butter',
#    'fresh green beans',
#    'ground black pepper',
#    'kosher salt',
#    'mixed herbs',
#    'olive oil',
#    'onion',
#    'walnuts'}],
#  ['20186',
#   {'american cheese',
#    'ham',
#    'hamburger buns',
#    'ketchup',
#    'sweet pickle relish'}],
#  ['109818', {'bacon', 'carrot', 'sugar', 'tomato soup'}],
#  ['243785',
#   {'brown sugar',
#    'egg',
#    'ground beef',
#    'ketchup',
#    'lipton onion soup mix',
#    'seasoned bread crumbs'}],
#  ['207525',
#   {'bulk pork sausage',
#    'garlic powder',
#    'ground chuck',
#    'ground pepper',
#    'oregano',
#    'rye cocktail bread',
#    'velveeta cheese',
#    'worcestershire sauce'}],
#  ['226246',
#   {'brown sugar',
#    'butter',
#    'caster sugar',
#    'egg',
#    'glace cherries',
#    'milk',
#    'pineapple in syrup',
#    'self-raising flour',
#    'vanilla essence'}],
#  ['353044',
#   {'apple',
#    'banana',
#    'coconut milk',
#    'flax seed oil',
#    'greens',
#    'honey',
#    'oat bran',
#    'water'}],
#  ['263781',
#   {'green onion',
#    'hawaiian bread',
#    "hellmann's mayonnaise",
#    'knorr vegetable soup mix',
#    'sour cream',
#    'water chestnuts'}],
#  ['66932',
#   {'broccoli floret',
#    'brown rice',
#    'carrot',
#    'egg',
#    'olive oil',
#    'peas',
#    'sliced mushrooms',
#    'soy sauce'}],
#  ['48131',
#   {'egg whites',
#    'pumpkin',
#    'pumpkin pie spice',
#    'reduced fat graham cracker crust',
#    'skim milk',
#    'splenda sugar substitute'}],
#  ['32363', {'beef stew', 'biscuits'}],
#  ['293225',
#   {'baking soda',
#    'buttermilk',
#    'creamy peanut butter',
#    'espresso',
#    'extra-large eggs',
#    'heavy cream',
#    'honey roasted peanuts',
#    'light corn syrup',
#    'powdered sugar',
#    'pure vanilla extract',
#    'salt',
#    'semisweet chocolate',
#    'sugar',
#    'unbleached all-purpose flour',
#    'unsalted butter',
#    'unsweetened cocoa'}],
#  ['235173',
#   {'chipotle chile in adobo',
#    'cilantro',
#    'corn kernel',
#    'fresh lime juice',
#    'garlic',
#    'ground cumin',
#    'lime zest',
#    'olive oil',
#    'onion',
#    'red bell pepper',
#    'short-grain brown rice',
#    'yellow cornmeal'}],
#  ['226001',
#   {'butter',
#    'egg',
#    'flour',
#    'instant vanilla pudding',
#    'water',
#    'whipped dessert topping mix'}],
#  ['220186',
#   {'celery',
#    'dijon mustard',
#    'fresh ground pepper',
#    'hard-boiled eggs',
#    'milk',
#    'miracle whip',
#    'mustard',
#    'potato',
#    'salt',
#    'sugar',
#    'white onions',
#    'white pepper'}],
#  ['217201',
#   {'black pepper',
#    'butter',
#    'cayenne pepper',
#    'chili powder',
#    'dried basil',
#    'garlic powder',
#    'lemon juice',
#    'seasoning salt',
#    'soy sauce',
#    'tea bag',
#    'water',
#    'white rice'}],
#  ['194665',
#   {'bisquick',
#    'egg',
#    'feta cheese',
#    'fresh ground pepper',
#    'frozen spinach',
#    'kalamata olive',
#    'milk',
#    'onion',
#    'oregano',
#    'roasted red pepper'}],
#  ['269909',
#   {'allspice',
#    'baking powder',
#    'baking soda',
#    'cinnamon',
#    'egg',
#    'flour',
#    'ground cloves',
#    'nutmeg',
#    'oil',
#    'pecans',
#    'pumpkin',
#    'salt',
#    'sugar',
#    'water'}],
#  ['259693',
#   {'black pepper',
#    'boneless pork chops',
#    'dry onion soup mix',
#    'long-grain rice',
#    'vegetable oil',
#    'water'}],
#  ['161370',
#   {'allspice',
#    'black pepper',
#    'boneless skinless chicken breasts',
#    'brown sugar',
#    'cayenne',
#    'chili powder',
#    'chives',
#    'cinnamon',
#    'clove',
#    'crushed tomatoes',
#    'garlic',
#    'ginger',
#    'habanero pepper',
#    'jamaican jerk spice',
#    'lime juice',
#    'nutmeg',
#    'olive oil',
#    'onion',
#    'onion flakes',
#    'red peppers',
#    'rum',
#    'sage',
#    'thyme'}],
#  ['152261',
#   {'frozen limeade concentrate', 'ice', 'lime sorbet', 'mango', 'strawberry'}],
#  ['152259',
#   {'apple juice',
#    'banana',
#    'ice',
#    'non-fat vanilla frozen yogurt',
#    'strawberry'}],
#  ['303460',
#   {'coriander seed',
#    'cumin',
#    'fish sauce',
#    'fruit vinegar',
#    'garlic',
#    'hoisin sauce',
#    'red chile',
#    'sesame oil',
#    'yoghurt'}],
#  ['270259',
#   {'butter',
#    'candy cane',
#    'egg',
#    'flour',
#    'peppermint extract',
#    'peppermint oreos',
#    'salt',
#    'sugar',
#    'unsweetened chocolate',
#    'unsweetened cocoa powder',
#    'vanilla'}],
#  ['345123',
#   {'canola oil',
#    'celery',
#    'cooked chicken breasts',
#    'cooked rice',
#    'green grapes',
#    'mandarin oranges',
#    'mayonnaise',
#    'orange juice',
#    'pineapple tidbits',
#    'salt',
#    'slivered almonds',
#    'white vinegar'}],
#  ['125195',
#   {'celery',
#    'cheddar cheese',
#    'frozen peas',
#    'hard-boiled eggs',
#    'mayonnaise',
#    'mustard',
#    'onion',
#    'seasoning salt',
#    'sugar',
#    'sweet pickle relish'}],
#  ['141939',
#   {'black pepper',
#    'butter',
#    'buttermilk',
#    'cayenne pepper',
#    'chicken pieces',
#    'dijon mustard',
#    'dried thyme',
#    'dry breadcrumbs',
#    'flour',
#    'fresh garlic',
#    'garlic powder',
#    'hot pepper sauce',
#    'oil',
#    'onion',
#    'paprika',
#    'parmesan cheese',
#    'seasoning salt'}],
#  ['171442',
#   {'allspice',
#    'black pepper',
#    'cinnamon',
#    'fresh garlic',
#    'habanero sauce',
#    'hoisin sauce',
#    'ketchup',
#    'lemon juice',
#    'louisiana hot sauce',
#    'pork baby back ribs',
#    'seasoning salt',
#    'sugar'}],
#  ['212188',
#   {'beef stock',
#    'black pepper',
#    'carrot',
#    'celery',
#    'chicken leg',
#    'corn',
#    'garlic',
#    'italian seasoning',
#    'onion',
#    'peas',
#    'red bell pepper',
#    'rotini pasta',
#    'salt',
#    'spaghetti sauce'}],
#  ['262208',
#   {'aluminum foil',
#    'margarine',
#    'mexicorn whole kernel corn',
#    'pam cooking spray',
#    'salt and pepper',
#    'sour cream',
#    'spinach dip',
#    'stove top stuffing mix monterey style with mushroom and onion'}],
#  ['207857', {'cooking onions', 'pickling spices', 'white vinegar'}],
#  ['221049',
#   {'carrot',
#    'chicken broth',
#    'cooked chicken',
#    'cooked pasta',
#    'egg',
#    'peas',
#    'soy sauce'}],
#  ['221116', {'cake crumbs', 'cool whip', 'cream cheese', 'mixed fruit'}],
#  ['130819',
#   {'butter',
#    'coconut flavoring',
#    'cool whip',
#    'egg',
#    'flour',
#    'lemon flavoring',
#    'pie crust',
#    'squash',
#    'sugar'}],
#  ['20223',
#   {'black pepper',
#    'cream of mushroom soup',
#    'dijon mustard',
#    'dried onion flakes',
#    'dried parsley flakes',
#    'garlic powder',
#    'ground cinnamon',
#    'ground cloves',
#    'ground veal',
#    'salt'}],
#  ['190108',
#   {'black pepper',
#    'brown rice',
#    'catfish nuggets',
#    'chicken stock',
#    'garlic',
#    'gumbo file',
#    'lemon',
#    'mexican-style stewed tomatoes with jalapeno peppers',
#    'okra',
#    'old bay seasoning',
#    'olive oil',
#    'oregano',
#    'parsley',
#    'red onions',
#    'red wine vinegar',
#    'seafood',
#    'small shrimp',
#    'tabasco sauce',
#    'tomato soup'}],
#  ['158372',
#   {'bacon',
#    'egg',
#    'fresh chives',
#    'mild cheddar cheese',
#    'paprika',
#    'sour cream',
#    'white vinegar'}],
#  ['219681',
#   {'chicken breasts',
#    'cracked black pepper',
#    'dried basil',
#    'dried oregano',
#    'dried parsley',
#    'garlic',
#    'garlic salt',
#    'lemon juice',
#    'olive oil',
#    'salt',
#    'sandwich buns',
#    'white vinegar'}],
#  ['261215',
#   {'baking soda',
#    'boiling water',
#    'brown sugar',
#    'cinnamon',
#    'cream',
#    'egg',
#    'flour',
#    'margarine',
#    'nutmeg',
#    'nuts',
#    'quick oats',
#    'salt',
#    'shredded coconut',
#    'vanilla'}],
#  ['179640', {'butter', 'marshmallows', 'rice krispies'}],
#  ['250883',
#   {'cool whip topping',
#    'cream cheese',
#    'frozen limeade concentrate',
#    'orange juice'}],
#  ['140855',
#   {'avocado',
#    'cheddar cheese',
#    'chili powder',
#    'corn chips',
#    'garlic',
#    'green onion',
#    'lemon juice',
#    'lettuce',
#    'pitted ripe olives',
#    'salad oil',
#    'salt',
#    'sour cream',
#    'sugar',
#    'tabasco sauce',
#    'tomato',
#    'tuna'}],
#  ['120297',
#   {'baking potatoes',
#    'chickpeas',
#    'coriander',
#    'fresh coriander',
#    'garlic',
#    'ground cumin',
#    'low-fat yogurt',
#    'olive oil',
#    'salt & freshly ground black pepper',
#    'tahini'}],
#  ['130492',
#   {'baking powder',
#    'buttermilk',
#    'egg',
#    'mayonnaise',
#    'salt',
#    'sugar',
#    'vegetable oil',
#    'yellow cornmeal'}],
#  ['164634',
#   {'apple',
#    'carrot',
#    'gingerroot',
#    'green cabbage',
#    'green onion',
#    'maple syrup',
#    'red cabbage',
#    'rice vinegar',
#    'sesame oil',
#    'soy sauce'}],
#  ['293836',
#   {'black pepper',
#    'canola oil',
#    'chicken soup powder',
#    'garlic powder',
#    'long-grain rice',
#    'orzo pasta',
#    'turmeric',
#    'water'}],
#  ['169586',
#   {'avocado',
#    'celery ribs',
#    'chicken breast',
#    'chicken broth',
#    'chipotle chiles in adobo',
#    'crushed tomatoes',
#    'cumin',
#    'ear of corn',
#    'fresh cilantro',
#    'green bell pepper',
#    'jalapeno pepper',
#    'salt and pepper',
#    'white onion'}],
#  ['261296',
#   {'black pepper',
#    'dried basil',
#    'egg white',
#    'eggplant',
#    'fat free mozzarella cheese',
#    'fiber one cereal',
#    'garlic powder',
#    'italian-style tomato sauce',
#    'reduced-fat parmesan cheese',
#    'salt'}],
#  ['101115', {'beef gravy', 'egg', 'ground beef', 'onion', 'white rice'}],
#  ['271594',
#   {'beans',
#    'black pepper',
#    'black-eyed peas',
#    'carrot',
#    'celery ribs',
#    'garlic',
#    'great northern beans',
#    'ham',
#    'ham bone',
#    'ham soup base',
#    'navy beans',
#    'onion',
#    'pinto beans',
#    'salt',
#    'tomatoes and green chilies',
#    'water'}],
#  ['164291',
#   {'cider vinegar',
#    'feta cheese',
#    'fresh dill',
#    'garlic',
#    'light mayonnaise',
#    'red bell pepper',
#    'skinless chicken breast half'}],
#  ['251528',
#   {'cheese ravioli',
#    'garlic salt',
#    'italian seasoning',
#    'lean ground beef',
#    'mozzarella cheese',
#    'spaghetti sauce'}],
#  ['250833',
#   {'barbecue sauce',
#    'chicken pieces',
#    'lemon juice',
#    'orange marmalade',
#    'worcestershire sauce'}],
#  ['343448',
#   {'coriander',
#    'garlic powder',
#    'ground black pepper',
#    'ground red pepper',
#    'onion powder',
#    'paprika',
#    'salt',
#    'turmeric'}],
#  ['39893',
#   {'black olives',
#    'cream cheese',
#    'green onion',
#    'green pepper',
#    'lettuce',
#    'mayonnaise',
#    'mexican blend cheese',
#    'sour cream',
#    'taco seasoning mix',
#    'tomato'}],
#  ['147477',
#   {'green bell peppers',
#    'green onions',
#    'minced clams',
#    'paprika',
#    'sharp cheddar cheese',
#    'tabasco sauce',
#    'worcestershire sauce'}],
#  ['223349',
#   {'eggplants',
#    'olive oil',
#    'olives',
#    'oregano',
#    'red bell pepper',
#    'red onion',
#    'shrimp',
#    'spaghetti squash',
#    'yellow bell pepper'}],
#  ['86768',
#   {'butter', "confectioners' sugar", 'heavy cream', 'semisweet chocolate'}],
#  ['197001',
#   {'cherry pie filling',
#    'crushed pineapple',
#    'frozen whipped topping',
#    'pecans',
#    'small marshmallow',
#    'sweetened condensed milk'}],
#  ['60938',
#   {'bacon',
#    'cheddar cheese',
#    'green onions',
#    'oil',
#    'potato',
#    'salt',
#    'sour cream'}],
#  ['228491',
#   {'black pepper',
#    'boneless eye of round beef steak',
#    'canola oil',
#    'mozzarella cheese',
#    'onion',
#    'parmesan cheese',
#    'pizza sauce',
#    'plain flour',
#    'salt'}],
#  ['451515',
#   {'bacon grease',
#    'boneless country-style ribs',
#    "campbell's golden mushroom soup",
#    'flour',
#    'ground black pepper',
#    'oregano',
#    'seasoning salt',
#    'soup mix'}],
#  ['353171', {'butter', 'egg', 'flour', 'fruit', 'milk', 'sugar'}],
#  ['354039',
#   {'apples',
#    'baby carrots',
#    'butter',
#    'cardamom',
#    'crescent roll dough',
#    'ground cinnamon',
#    'honey',
#    'sugar'}],
#  ['302399',
#   {'garlic salt',
#    'italian seasoning',
#    'mozzarella cheese',
#    'olive oil',
#    'refrigerated biscuits'}],
#  ['195736',
#   {'active dry yeast', 'butter', 'flour', 'milk', 'salt', 'sugar', 'water'}],
#  ['365946',
#   {'butter',
#    'cream cheese',
#    'egg',
#    'egg yolk',
#    'egg yolks',
#    'flour',
#    'lemon peel',
#    'salt',
#    'sugar',
#    'vanilla',
#    'whipping cream'}],
#  ['221544',
#   {'chili sauce',
#    'country-style dijon mustard',
#    'honey',
#    'little smokies sausages'}],
#  ['175306',
#   {'bacardi dark rum',
#    'grenadine',
#    "meyer's dark rum",
#    'orange curacao',
#    'orange juice',
#    'orgeat syrup',
#    'pineapple juice',
#    'prepared sweet-and-sour mix',
#    'white rum'}],
#  ['211833',
#   {'balsamic vinaigrette',
#    'condensed chicken broth',
#    'dried thyme leaves',
#    'minute white rice',
#    'onion',
#    'pork chops',
#    'red apples',
#    'sliced mushrooms',
#    'water'}],
#  ['276567',
#   {'chili powder',
#    'fresh ground black pepper',
#    'green bell peppers',
#    'horseradish',
#    'onion',
#    'orange juice',
#    'plain nonfat yogurt',
#    'prepared mustard',
#    'red bell peppers',
#    'reduced-calorie mayonnaise',
# ...
#    'egg',
#    'flour',
#    'nuts',
#    'sugar',
#    'vanilla'}],
#  ['79425',
#   {'butter',
#    'caramels',
#    'chocolate cake mix',
#    'chocolate chips',
#    'evaporated milk',
#    'nuts'}],
#  ['213681',
#   {'baking soda',
#    'bananas',
#    'canola oil',
#    'egg',
#    'flour',
#    'raisins',
#    'salt',
#    'sugar',
#    'walnuts'}],
#  ['121712', {'cream cheese', 'thousand island dressing'}],
#  ['155344',
#   {'chili sauce', 'mayonnaise', 'onion powder', 'sweet pickle relish'}],
#  ['175339',
#   {'baking soda',
#    'brown sugar',
#    'chocolate chips',
#    'cream of tartar',
#    'egg',
#    'flaked coconut',
#    'flour',
#    'margarine',
#    'oil',
#    'rice krispies',
#    'rolled oats',
#    'vanilla',
#    'white sugar'}],
#  ['72600',
#   {'baby spinach',
#    'bacon',
#    'buttermilk',
#    'fresh lemon juice',
#    'garlic',
#    'hardboiled egg',
#    'mushrooms',
#    'plain yogurt',
#    'sugar',
#    'unsalted sunflower seeds',
#    'white pepper'}],
#  ['50614',
#   {'bacon',
#    'cauliflower',
#    'cherry tomatoes',
#    'fresh broccoli',
#    'fresh mushrooms',
#    'frozen peas',
#    'green pepper',
#    'italian seasoning',
#    'lettuce',
#    'mayonnaise',
#    'red onion',
#    'sugar'}],
#  ['133784',
#   {'basil leaves',
#    'black pepper',
#    'celery salt',
#    'chili powder',
#    'garlic powder',
#    'ground allspice',
#    'ground oregano',
#    'marjoram leaves',
#    'onion salt',
#    'paprika',
#    'rubbed sage'}],
#  ['235003', {'beer', 'fresh jalapeno', 'ice', 'vodka'}],
#  ['140723',
#   {'anchovy fillets',
#    'baby spinach',
#    'bacon',
#    'dijon mustard',
#    'extra virgin olive oil',
#    'french bread',
#    'fresh mushrooms',
#    'garlic',
#    'lemon juice',
#    'low-fat mayonnaise',
#    'miracle whip light',
#    'oil',
#    'olive oil',
#    'parmesan cheese',
#    'worcestershire sauce'}],
#  ['326839',
#   {'dried italian seasoning',
#    'egg',
#    'ground beef',
#    'ground pepper',
#    'italian cheese blend',
#    'jumbo pasta shells',
#    'mexican blend cheese',
#    'mozzarella cheese',
#    'parmesan-romano cheese mix',
#    'parsley flakes',
#    'ricotta cheese',
#    'salt',
#    'spaghetti sauce'}],
#  ['467326',
#   {'bread machine yeast',
#    'brown sugar',
#    'oil',
#    'salt',
#    'water',
#    'white flour',
#    'whole wheat flour'}],
#  ['43669',
#   {'butter',
#    'cream-style corn',
#    'evaporated milk',
#    'onion',
#    'potato',
#    'salt and pepper',
#    'water',
#    'whole corn'}],
#  ['73566',
#   {'black pepper',
#    'extra virgin olive oil',
#    'flat leaf parsley',
#    'italian seasoned breadcrumbs',
#    'kosher salt',
#    'orecchiette',
#    'parmesan cheese',
#    'prosciutto'}],
#  ['449768',
#   {'cumin seeds', 'fresh ground black pepper', 'olive oil', 'salt', 'tomato'}],
#  ['404661',
#   {'baking soda',
#    'butter',
#    'corn syrup',
#    'molasses',
#    'salted peanuts',
#    'vanilla',
#    'white sugar'}],
#  ['381713',
#   {'bulgar wheat',
#    'cinnamon',
#    'lean ground beef',
#    'onion',
#    'plain yogurt',
#    'salt'}],
#  ['257696',
#   {'apple pie filling',
#    'egg',
#    'instant vanilla pudding',
#    'oil',
#    'water',
#    'yellow cake mix'}],
#  ['187606',
#   {'boneless skinless chicken breasts',
#    'carrot',
#    'italian dressing',
#    'potato'}],
#  ['91515', {'chocolate milk', 'cinnamon rolls', 'egg'}],
#  ['289891',
#   {'baking powder',
#    'butter',
#    'egg',
#    'flour',
#    'milk',
#    'salt',
#    'vanilla',
#    'white sugar'}],
#  ['412073',
#   {'basil',
#    'black pepper',
#    'carrot',
#    'celery',
#    'garlic',
#    'ham',
#    'leeks',
#    'salt',
#    'soup mix',
#    'thyme',
#    'water',
#    'worcestershire sauce'}],
#  ['123746',
#   {'bell peppers',
#    'chili sauce',
#    'egg',
#    'garlic powder',
#    'ground beef',
#    'milk',
#    'onion',
#    'salt and pepper',
#    'saltine crackers',
#    'worcestershire sauce'}],
#  ['206020',
#   {'aluminum foil',
#    'beef tenderloin',
#    'garlic',
#    'limes, juice of',
#    'prepared horseradish',
#    'salt and pepper',
#    'sour cream',
#    'unsalted butter',
#    'worcestershire sauce'}],
#  ['345595',
#   {'baking powder',
#    'baking soda',
#    'carrot',
#    'cinnamon',
#    'cream cheese',
#    'egg',
#    'flour',
#    'margarine',
#    'oil',
#    'pineapple',
#    'powdered sugar',
#    'salt',
#    'sugar',
#    'walnuts'}],
#  ['129227',
#   {'cabbage',
#    'carrot',
#    'celery seed',
#    'mustard seeds',
#    'onion',
#    'salt',
#    'sugar',
#    'turmeric',
#    'water',
#    'white vinegar'}],
#  ['472955',
#   {'alum',
#    'pickling cucumbers',
#    'pickling spices',
#    'salt',
#    'sugar',
#    'vinegar',
#    'water'}],
#  ['17490',
#   {'alum',
#    'canning salt',
#    'cucumbers',
#    'pickling spices',
#    'sugar',
#    'vinegar'}],
#  ['130002',
#   {'allspice',
#    'baking soda',
#    'carrot',
#    'cinnamon',
#    'coconut',
#    'cream cheese',
#    'egg',
#    'flour',
#    'ground cloves',
#    'margarine',
#    'nuts',
#    'oil',
#    'powdered sugar',
#    'raisins',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['53353', {'butter', 'cream', 'lemon extract', 'maple syrup', 'nutmeats'}],
#  ['105756',
#   {'basil',
#    'beans',
#    'carrot',
#    'celery',
#    'chicken bouillon cubes',
#    'chicken broth',
#    'deli ham',
#    'lemon juice',
#    'onion',
#    'parsley',
#    'raw rice',
#    'salt',
#    'tomato',
#    'v8 vegetable juice',
#    'water'}],
#  ['307362',
#   {'hormel chili without beans',
#    'monterey jack cheese',
#    'refried beans',
#    'tortillas'}],
#  ['51803',
#   {'15 bean soup mix',
#    'black pepper',
#    'celery leaves',
#    'chicken bouillon cubes',
#    'dried parsley',
#    'dried rosemary',
#    'garlic',
#    'ham hocks',
#    'olive oil',
#    'onion',
#    'salt',
#    'whole tomatoes'}],
#  ['438263',
#   {'15 bean soup mix',
#    'beef bouillon paste',
#    'black pepper',
#    'diced tomatoes',
#    'garlic',
#    'ham bone',
#    'smoked sausage',
#    'steak sauce',
#    'water',
#    'worcestershire sauce'}],
#  ['525649',
#   {'black pepper',
#    'carrot',
#    'cayenne pepper',
#    'chili powder',
#    'condensed tomato soup',
#    'dried beans',
#    'garlic',
#    'ham',
#    'lemon',
#    'olive oil',
#    'onion',
#    'oregano',
#    'paprika',
#    'salt',
#    'smoked paprika',
#    'thyme',
#    'water'}],
#  ['115160',
#   {'baking soda',
#    'egg',
#    'flour',
#    'ground walnuts',
#    'honey',
#    'liquid honey',
#    'margarine',
#    'plain sweet biscuit crumbs',
#    'sour cream',
#    'sugar'}],
#  ['168222',
#   {'capers',
#    'chicken stock',
#    'fresh chives',
#    'fresh parsley',
#    'fresh tarragon',
#    'garlic',
#    'halibut steaks',
#    'lemon juice',
#    'salt and pepper'}],
#  ['140172',
#   {'boneless sirloin steak',
#    'lipton beefy mushroom soup mix',
#    'new potatoes',
#    'oil',
#    'peas and carrots',
#    'tomato paste',
#    'water'}],
#  ['305112',
#   {'black beans',
#    'frozen corn kernels',
#    'ground beef',
#    'taco seasoning',
#    'tomatoes and green chilies'}],
#  ['53481',
#   {'cheddar cheese',
#    'ketchup',
#    'lean ground beef',
#    'minute white rice',
#    'mustard',
#    'water'}],
#  ['76887',
#   {'chili with beans',
#    'diced tomatoes',
#    'ground beef',
#    'velveeta cheese',
#    'water',
#    'white rice'}],
#  ['392598',
#   {'boneless skinless chicken breast halves',
#    'condensed cream of chicken soup',
#    'ground pepper',
#    'instant rice',
#    'paprika',
#    'vegetable oil',
#    'water'}],
#  ['113197',
#   {'black pepper',
#    'cheese',
#    'chicken breast tenders',
#    'fajita seasoning mix',
#    'lime',
#    'olive oil',
#    'onion',
#    'pico de gallo',
#    'sour cream',
#    'tortilla'}],
#  ['398071',
#   {'cheddar cheese',
#    'chicken',
#    'chicken broth',
#    'kidney beans',
#    'mexicorn',
#    'salsa',
#    'sour cream',
#    'tortilla chips'}],
#  ['66527',
#   {'boneless skinless chicken breasts',
#    'broccoli florets',
#    'condensed cream of chicken soup',
#    'milk',
#    'minute rice',
#    'vegetable oil'}],
#  ['184890',
#   {'chili powder',
#    'cumin',
#    'ground turkey',
#    'kidney beans',
#    'onion',
#    'pinto beans',
#    'salsa',
#    'salt',
#    'stewed tomatoes'}],
#  ['79046',
#   {'cheese',
#    'chili with beans',
#    'flour tortillas',
#    'sour cream',
#    'water',
#    'white minute rice'}],
#  ['356163',
#   {'broccoli',
#    'chili powder',
#    'ketchup',
#    'lean ground beef',
#    'macaroni & cheese dinner mix',
#    'water'}],
#  ['41673',
#   {'allspice',
#    'black pepper',
#    'brown sugar',
#    'cinnamon',
#    'clove',
#    'onion',
#    'salt',
#    'tomato'}],
#  ['506885',
#   {'black pepper',
#    'crushed red pepper flakes',
#    'fresh basil',
#    'fresh oregano',
#    'fresh parmesan cheese',
#    'garlic',
#    'grape tomatoes',
#    'pappardelle pasta',
#    'roasted cashews',
#    'sun-dried tomato packed in oil'}],
#  ['277539',
#   {'chipotle chile in adobo',
#    'garlic',
#    'ground coriander',
#    'ground cumin',
#    'low sodium chicken broth',
#    'onion',
#    'salt',
#    'tomato sauce'}],
#  ['169487',
#   {'fat free cream cheese',
#    'fat-free whipped topping',
#    'reduced fat graham cracker crust',
#    'sugar substitute'}],
#  ['317587',
#   {'fresh linguine',
#    'fresh spinach',
#    'lemon juice',
#    'parmesan cheese',
#    'pesto sauce',
#    'pine nuts',
#    'red onion',
#    'tomato'}],
#  ['20624',
#   {'boneless skinless chicken breast halves',
#    'butter',
#    'chicken broth',
#    'flour',
#    'garlic',
#    'lemon juice',
#    'oil',
#    'salt and pepper'}],
#  ['360232',
#   {'celery ribs',
#    'cracked black pepper',
#    'extra virgin olive oil',
#    'feta cheese',
#    'fresh lemon juice',
#    'fresh parsley',
#    'garbanzo beans',
#    'garlic',
#    'of fresh mint',
#    'romaine lettuce',
#    'salt',
#    'scallion',
#    'tomato'}],
#  ['246548',
#   {'assorted fresh vegetables',
#    'boneless skinless chicken breast',
#    'instant rice',
#    'italian dressing',
#    'oil',
#    'reduced-sodium fat-free chicken broth'}],
#  ['67446',
#   {'butter',
#    'cream cheese',
#    'graham cracker crumbs',
#    'instant lemon pudding',
#    'milk',
#    'powdered sugar'}],
#  ['153028',
#   {'butter', 'cocoa', "confectioners' sugar", 'peanut butter', 'vanilla'}],
#  ['172651',
#   {'italian salad dressing',
#    'parmesan cheese',
#    'smoked turkey breast',
#    'spaghetti',
#    'tomato'}],
#  ['348952',
#   {'chicken bouillon cube',
#    'frozen mixed vegetables',
#    'minute rice',
#    'oil',
#    'pork tenderloin',
#    'soy sauce',
#    'water'}],
#  ['5276',
#   {'chicken bouillon cubes',
#    'green pepper',
#    'hot pepper sauce',
#    'kidney beans',
#    'minute white rice',
#    'oil',
#    'onion',
#    'water'}],
#  ['140173',
#   {'baby peas',
#    'bacon bits',
#    'black pepper',
#    'fettuccine',
#    'garlic salt',
#    'half-and-half cream',
#    'parmesan cheese',
#    'shrimp'}],
#  ['31184',
#   {'angel hair pasta',
#    'butter',
#    'extra virgin olive oil',
#    'frozen shrimp',
#    'garlic',
#    'onion',
#    'salt & pepper',
#    'white wine'}],
#  ['164178',
#   {'celery',
#    'garlic flakes',
#    'hamburger',
#    'hot chili flakes',
#    'jalapenos',
#    'onion',
#    'sliced mushrooms',
#    'sweet green pepper',
#    'sweet red pepper',
#    'tomato sauce & mushrooms'}],
#  ['289025',
#   {'asparagus',
#    'boneless skinless chicken breast',
#    'chicken broth',
#    'chili flakes',
#    'fresh ginger',
#    'garlic',
#    'onion',
#    'rice vinegar',
#    'salt',
#    'soy sauce',
#    'white pepper'}],
#  ['287502',
#   {'dijon mustard',
#    'elbow macaroni',
#    'extra-sharp cheddar cheese',
#    'fresh ground black pepper',
#    'half-and-half',
#    'hot sauce',
#    'kosher salt',
#    'unsalted butter'}],
#  ['75079',
#   {'butter',
#    'dry onion soup mix',
#    'flour',
#    'fresh mushrooms',
#    'round steak',
#    'sour cream',
#    'water'}],
#  ['147100',
#   {'chopped tomatoes',
#    'extra lean ground beef',
#    'lettuce',
#    'mexican blend cheese',
#    'minute white rice',
#    'taco seasoning mix',
#    'water'}],
#  ['233317',
#   {'baby spinach',
#    'cornflour',
#    'dark soy sauce',
#    'lime, juice and zest of',
#    'pak choi',
#    'sunflower oil',
#    'sweet chili sauce',
#    'thai fish sauce',
#    'tiger shrimp',
#    'water'}],
#  ['109793', {'milk', 'minute rice', 'raisins', 'vanilla instant pudding mix'}],
#  ['291409',
#   {'black beans', 'fire-roasted tomatoes', 'kidney beans', 'salsa', 'water'}],
#  ['27275',
#   {'cream cheese',
#    'fettuccine pasta',
#    'margarine',
#    'milk',
#    'parmesan cheese'}],
#  ['282812',
#   {'dried fruits',
#    'honey',
#    'milk',
#    'quick oats',
#    'salt',
#    'sugar',
#    'vanilla',
#    'water'}],
#  ['311608',
#   {'15 bean mix',
#    'bay leaves',
#    'black pepper',
#    'carrot',
#    'celery',
#    'chicken bouillon cubes',
#    'diced tomatoes',
#    'garlic',
#    'ham hocks',
#    'onion',
#    'seasoning salt',
#    'tomato sauce',
#    'water'}],
#  ['382234',
#   {'black-eyed peas',
#    'canned green beans',
#    'chili seasoning mix',
#    'corn chips',
#    'dark red kidney beans',
#    'green bell pepper',
#    'ground beef',
#    'ketchup',
#    'onion',
#    'red pepper flakes',
#    'salt and pepper',
#    'sharp cheddar cheese',
#    'vegetable oil',
#    'water',
#    'whole tomatoes'}],
#  ['237391',
#   {'brandy',
#    'butter',
#    'chicken liver',
#    'garlic',
#    'ground black pepper',
#    'heavy cream',
#    'marjoram',
#    'onion',
#    'sage',
#    'salt',
#    'thyme'}],
#  ['266997',
#   {'cayenne pepper',
#    'chili beans',
#    'chili powder',
#    'cumin',
#    'diced tomatoes',
#    'lean ground beef',
#    'onion',
#    'oregano',
#    'salt',
#    'sliced mushrooms',
#    'sour cream'}],
#  ['21916',
#   {'cool whip topping',
#    'frozen pound cake',
#    'jello instant vanilla pudding mix',
#    'orange liqueur',
#    'strawberries',
#    'strawberry',
#    'sugar',
#    'white chocolate baking squares'}],
#  ['229451',
#   {'black pepper',
#    'boneless skinless chicken breast halves',
#    'dijon mustard',
#    'dried tarragon',
#    'fresh lemon juice',
#    'worcestershire sauce'}],
#  ['204040', {'basmati rice', 'chicken broth', 'salt and pepper'}],
#  ['82287',
#   {'black olives',
#    'cooked chicken',
#    'cream of chicken soup',
#    'green enchilada sauce',
#    'green onion',
#    'lettuce',
#    'monterey jack cheese',
#    'salsa',
#    'sour cream',
#    'tomato',
#    'tortilla chips'}],
#  ['302815', {'butter', 'garlic', 'parmesan cheese', 'pasta'}],
#  ['311842',
#   {'black pepper',
#    'dried oregano',
#    'feta cheese',
#    'garlic',
#    'large shrimp',
#    'old bay seasoning',
#    'olive oil',
#    'parsley',
#    'tomato'}],
#  ['531148',
#   {'cherry tomatoes',
#    'corn kernels',
#    'herbs',
#    'large shrimp',
#    'lemon, zest of',
#    'olive oil',
#    'red onion',
#    'salt & freshly ground black pepper',
#    'snap peas',
#    'unsalted butter',
#    'zucchini'}],
#  ['364157',
#   {'dried oregano',
#    'fresh lemon juice',
#    'garlic',
#    'olive oil',
#    'parmesan cheese',
#    'salt and pepper',
#    'scallions',
#    'vegetable broth',
#    'white beans'}],
#  ['411979',
#   {'bay leaves',
#    'beans',
#    'carrot',
#    'celery',
#    'chicken stock',
#    'garlic',
#    'italian sausage',
#    'onion',
#    'oregano',
#    'tomato',
#    'water'}],
#  ['102832',
#   {'alum',
#    'cinnamon sticks',
#    'cucumbers',
#    'pickling salt',
#    'pickling spices',
#    'sugar',
#    'white vinegar'}],
#  ['246180', {'barbecue sauce', 'ginger ale', 'onion', 'pork butt'}],
#  ['224908',
#   {'brown sugar',
#    'cold water',
#    'dark molasses',
#    'strong coffee',
#    'sugar',
#    'vanilla bean',
#    'vodka'}],
#  ['364761',
#   {'carrot',
#    'celery',
#    'celery ribs',
#    'chicken bouillon cubes',
#    'chicken broth',
#    'frozen corn',
#    'frozen white corn',
#    'onion',
#    'potato',
#    'whole chickens'}],
#  ['489337',
#   {'basil',
#    'eggplant',
#    'fat-free parmesan cheese',
#    'fennel seed',
#    'lean ground turkey',
#    'low-carb marinara sauce',
#    'nonstick cooking spray',
#    'oregano leaves'}],
#  ['262448', {'mountain dew soda', 'raspberry vodka'}],
#  ['294427',
#   {'apple cider',
#    'arugula',
#    'dijon mustard',
#    'fresh thyme',
#    'gouda cheese',
#    'olive oil',
#    'pancetta',
#    'red onion',
#    'red wine vinegar',
#    'salt and pepper',
#    'shallots',
#    'sherry wine vinegar',
#    'tart apples',
#    'white cheddar cheese',
#    'white vinegar'}],
#  ['328436',
#   {'baby carrots',
#    'baking powder',
#    'baking soda',
#    "confectioners' sugar",
#    'egg',
#    'flour',
#    'light brown sugar',
#    'marshmallow cream',
#    'pumpkin pie spice',
#    'pure vanilla extract',
#    'salt',
#    'unsalted butter',
#    'vegetable oil'}],
#  ['357228',
#   {'baking soda',
#    'butter',
#    'buttermilk',
#    'cinnamon',
#    'clove',
#    'cocoa',
#    'egg',
#    'flour',
#    'nutmeg',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['50246',
#   {'almonds',
#    'cornstarch',
#    'cream of tartar',
#    'egg',
#    'egg yolks',
#    'flour',
#    'milk',
#    'powdered sugar',
#    'sugar',
#    'sweet cream'}],
#  ...]

# %% [markdown]
# Reshape the data into a vector of vectors of ingredients per recipe, to use for training a [*word2vec*](https://arxiv.org/abs/1301.3781) vector embedding model:

# %%
vectors = []

for id, ind_set in recipes:
    v = []
    
    for ind in ind_set:
        v.append(ind)

    vectors.append(v)

vectors
# Out:
# [['honey',
#   'salt',
#   'butter',
#   'winter squash',
#   'mexican seasoning',
#   'olive oil',
#   'mixed spice'],
#  ['prepared pizza crust',
#   'salt and pepper',
#   'cheese',
#   'egg',
#   'sausage patty',
#   'milk'],
#  ['ground cumin',
#   'water',
#   'cheddar cheese',
#   'tomato paste',
#   'salt',
#   'chili powder',
#   'ground beef',
#   'yellow onions',
#   'tomato soup',
#   'lettuce',
#   'kidney beans',
#   'diced tomatoes',
#   'rotel tomatoes'],
#  ['tarragon',
#   'shallots',
#   'red wine vinegar',
#   'salt',
#   'red bell pepper',
#   'yellow bell pepper',
#   'spreadable cheese with garlic and herbs',
#   'olive oil',
#   'new potatoes',
#   'black pepper',
#   'parsley'],
#  ['apple cider vinegar',
#   'cinnamon oil',
#   'tomato juice',
#   'salt',
#   'sugar',
#   'dry mustard',
#   'black pepper',
#   'clove oil'],
#  ['frozen apple juice concentrate', 'vanilla ice cream', 'apple', 'milk'],
#  ['fennel seeds',
#   'green olives',
#   'orange juice',
#   'ripe olives',
#   'red chile',
#   'extra virgin olive oil',
#   'garlic',
#   'orange rind',
#   'peppercorn'],
#  ['mirin',
#   'fresh ginger',
#   'liquid smoke',
#   'soy sauce',
#   'fresh garlic',
#   'yellow onion',
#   'fresh coarse ground black pepper',
#   'cumin',
#   'orange, juice of',
#   'salt',
#   'chili powder',
#   'white vinegar',
#   'brown sugar',
#   'dry mustard',
#   'pork spareribs',
#   'fresh cilantro leaves',
#   'water',
#   'tomato sauce',
#   'honey',
#   'cinnamon sticks',
#   'a.1. original sauce',
#   'cracked black pepper'],
#  ['chocolate sandwich style cookies',
#   'strawberry ice cream',
#   'bananas',
#   'chocolate syrup',
#   'whipped cream',
#   'vanilla ice cream'],
#  ['baking soda',
#   'salt',
#   'unsalted butter',
#   'bananas',
#   'sugar',
#   'egg',
#   'orange rind',
#   'fresh lemon juice',
#   'cake flour'],
#  ['whole berry cranberry sauce', 'prepared horseradish', 'sour cream'],
#  ['strawberry',
#   'butter',
#   'whipping cream',
#   'egg',
#   'vanilla wafers',
#   'powdered sugar',
#   'walnuts'],
#  ['water',
#   'bacon',
#   'dark brown sugar',
#   'mustard powder',
#   'salt',
#   'molasses',
#   'chili powder',
#   'onion',
#   'chicken bouillon cubes',
#   'cornstarch',
#   'great northern bean',
#   'black pepper',
#   'garlic powder'],
#  ['ham hock',
#   'whiskey',
#   'salt',
#   'molasses',
#   'hot sauce',
#   'brown sugar',
#   'collard greens'],
#  ['burnet root', 'spearmint', 'scullcap herb', 'gentian root', 'wood bethony'],
#  ['chicken rice soup',
#   'oil',
#   'salt',
#   'lean pork chops',
#   'flour',
#   'dry mustard',
#   'garlic powder'],
#  ['cheese', 'whole green chilies', 'oil', 'cornstarch', 'egg roll wrap'],
#  ['salted peanuts', 'chinese noodles', 'butterscotch chips'],
#  ['celery',
#   'beef broth',
#   'ground pork',
#   'cooking oil',
#   'soy sauce',
#   'hamburger buns',
#   'onion'],
#  ['vegetable bouillon cubes',
#   'water',
#   'salt and pepper',
#   'fresh herb',
#   'cauliflower',
#   'ground coriander',
#   'onion',
#   'red bell pepper',
#   'garlic',
#   'canola oil',
#   'great northern bean',
#   'broccoli floret',
#   'escarole',
#   'green peas',
#   'potato',
#   'salt free herb and spice seasoning mix'],
#  ['water',
#   'fresh ground black pepper',
#   'salt',
#   'boiling potatoes',
#   'fresh spinach leaves',
#   'unsalted butter',
#   'coarse salt',
#   'nutmeg'],
#  ['celery',
#   'white pepper',
#   'rolled oats',
#   'apple juice',
#   'salt',
#   'spinach',
#   'scallion',
#   'olive oil',
#   'onion',
#   'fresh parsley',
#   'dried thyme',
#   'broth'],
#  ['salt and pepper',
#   'oil',
#   'boneless skinless chicken breast halves',
#   'paprika',
#   'egg',
#   'cornstarch',
#   'seasoning salt',
#   'flour',
#   'condensed cream of chicken soup',
#   'garlic powder'],
#  ['ground cinnamon',
#   'salt',
#   'granulated sugar',
#   'butter',
#   'bread',
#   'egg',
#   'vegetable oil',
#   'powdered sugar',
#   'vanilla',
#   'flour',
#   'brown sugar',
#   'baking powder',
#   'milk'],
#  ['lemon, juice of', 'white pepper', 'salt', 'butter', 'egg yolks'],
#  ['ground cumin',
#   'black cumin',
#   'ground ginger',
#   'ground coriander',
#   'ground black pepper',
#   'ground turmeric'],
#  ['vegetarian ground beef',
#   'celery',
#   'salt',
#   'red pepper flakes',
#   'chili powder',
#   'black pepper',
#   'garlic',
#   'jalapenos',
#   'kidney beans',
#   'onion',
#   'diced tomatoes',
#   'green pepper'],
#  ['water',
#   'parmesan cheese',
#   'elbow macaroni',
#   'beef bouillon cube',
#   'salt',
#   'ground thyme',
#   'zucchini',
#   'cabbage',
#   'tomato',
#   'onion',
#   'garbanzo beans',
#   'ground pepper',
#   'dried parsley',
#   'beef stew meat'],
#  ['rosemary', 'red potatoes', 'margarine'],
#  ['celery',
#   'tabasco sauce',
#   'dried oregano',
#   'dry white wine',
#   'carrot',
#   'worcestershire sauce',
#   'black beans',
#   'onion',
#   'unsalted butter',
#   'heavy cream',
#   'dried sweet basil leaves',
#   'broccoli stem',
#   'chicken stock',
#   'salt & fresh ground pepper',
#   'broccoli floret',
#   'cornstarch',
#   'smoked chicken',
#   'dried thyme'],
#  ['salt',
#   'butter',
#   'baking cocoa',
#   'egg',
#   'miniature peppermint patties',
#   'vanilla',
#   'flour',
#   'sugar',
#   'baking powder'],
#  ['tabasco sauce',
#   'cheddar cheese',
#   'tomato sauce',
#   'sliced ripe olives',
#   'salt',
#   'hot chili pepper',
#   'onion',
#   'taco sauce',
#   'whole kernel corn',
#   'ground beef',
#   'cornmeal',
#   'black pepper'],
#  ['dry ranch dressing mix', 'butter', 'french bread'],
#  ['water',
#   'egg substitute',
#   'worcestershire sauce',
#   'ground venison',
#   'salt',
#   'onion',
#   'fresh breadcrumb',
#   'dry mustard',
#   'black pepper',
#   'non-fat powdered milk'],
#  ['milk', 'plain yogurt', 'frozen juice concentrate'],
#  ['carrot',
#   'low sodium chicken broth',
#   'zucchini',
#   'corn',
#   'wax beans',
#   'diced tomatoes',
#   'green beans',
#   'potato'],
#  ['sharp cheddar cheese',
#   'salt',
#   'condensed cream of mushroom soup',
#   'black pepper',
#   'egg',
#   'crouton',
#   'onion',
#   'frozen chopped spinach'],
#  ['prepared mustard',
#   'diced pimentos',
#   'salt',
#   'low-fat sour cream',
#   'black pepper',
#   'sugar',
#   'white wine vinegar',
#   'fat-free mayonnaise',
#   'plain low-fat yogurt',
#   'garlic',
#   'celery seed',
#   'green onion',
#   'red potatoes'],
#  ['margarine',
#   'oregano',
#   'soft breadcrumbs',
#   'egg',
#   'sage',
#   'onion',
#   'frozen chopped spinach',
#   'garlic powder'],
#  ['salt & pepper',
#   'frozen vegetables',
#   'cooking oil',
#   'cream of mushroom soup',
#   'condensed cream of mushroom & garlic soup',
#   'cornbread mix',
#   'ground beef',
#   'onion'],
#  ['toasted sesame oil',
#   'honey',
#   'soy sauce',
#   'green onions',
#   'stir fry vegetables',
#   'toasted sesame seeds',
#   'garlic',
#   'angel hair pasta'],
#  ['baking soda',
#   'orange juice',
#   'egg',
#   'canola oil',
#   'baking powder',
#   'cinnamon',
#   'ground cinnamon',
#   'pecans',
#   'salt',
#   'buckwheat flour',
#   'butter',
#   'unsweetened cocoa',
#   'ground cloves',
#   'yam',
#   'flour',
#   'brown sugar',
#   'sugar',
#   'low-fat buttermilk',
#   'honey',
#   'orange rind'],
#  ['baking soda',
#   'boiling water',
#   'ground cinnamon',
#   'orange juice',
#   'sorghum',
#   'salt',
#   'granulated sugar',
#   'buckwheat flour',
#   'unsweetened cocoa',
#   'ground cloves',
#   'egg',
#   'baking powder',
#   'canola oil',
#   'yam',
#   'raisins',
#   'orange rind',
#   'flour',
#   'low-fat buttermilk'],
#  ['salt & pepper',
#   'american cheese',
#   'beer',
#   'sugar',
#   'cayenne',
#   'ground beef',
#   'prepared yellow mustard',
#   'garlic'],
#  ['green onion',
#   'salt and pepper',
#   'ham',
#   'cheese',
#   'tri-color spiral pasta',
#   'tomato',
#   'ripe olives',
#   'chives',
#   'onion powder',
#   'water chestnut',
#   'italian seasoning',
#   'olive oil',
#   'dill pickles',
#   'cider vinegar',
#   'sweet pepper',
#   'garlic powder'],
#  ['frozen french fries',
#   'parmesan cheese',
#   'flat leaf parsley',
#   'oil',
#   'oregano',
#   'salt & freshly ground black pepper',
#   'basil'],
#  ['ham',
#   'cheddar cheese',
#   'good seasonings italian salad dressing mix',
#   'sandwich bun',
#   'butter',
#   'pepperoni',
#   'deli turkey',
#   'mozzarella cheese',
#   'swiss cheese'],
#  ['salt',
#   'icing sugar',
#   'butter',
#   'shortening',
#   'egg',
#   'vanilla',
#   'flour',
#   'sugar',
#   'baking powder',
#   'milk'],
#  ['yellow cake mix',
#   'water',
#   'carrot',
#   'coconut',
#   'oil',
#   'pecans',
#   'cinnamon',
#   'vanilla instant pudding mix',
#   'egg',
#   'crushed pineapple',
#   'nutmeg'],
#  ['sharp cheddar cheese',
#   'honey',
#   'jiffy corn muffin mix',
#   'butter',
#   'heavy cream',
#   'red bell pepper',
#   'whole kernel corn',
#   'egg',
#   'onion',
#   'jalapenos'],
#  ['water',
#   'baking soda',
#   'dry yeast',
#   'salt',
#   'butter',
#   'sugar',
#   'milk',
#   'egg',
#   'vegetable oil',
#   'crushed pineapple',
#   'vanilla',
#   'flour',
#   'brown sugar',
#   'nuts',
#   'baking powder',
#   'cinnamon',
#   'raisins'],
#  ['cottage cheese',
#   'tomato paste',
#   'dried basil',
#   'parmesan cheese',
#   'whole tomato',
#   'parsley flakes',
#   'salt',
#   'italian sausage',
#   'egg',
#   'mozzarella cheese',
#   'garlic',
#   'ground black pepper',
#   'ground beef',
#   'ricotta cheese',
#   'lasagna noodle'],
#  ['toasted wheat germ',
#   'cottage cheese',
#   'herbs',
#   'beef',
#   'cheese',
#   'salt',
#   'olive oil flavored cooking spray',
#   'egg',
#   'spices',
#   'black pepper',
#   'frozen chopped spinach'],
#  ['rolls',
#   'instant vanilla pudding',
#   'brown sugar',
#   'butter',
#   'raisins',
#   'cinnamon'],
#  ['white onion',
#   'stewed tomatoes',
#   'granulated sugar',
#   'prego spaghetti sauce',
#   'ground beef',
#   'garlic'],
#  ['dried dill weed',
#   'beef steaks',
#   'honey',
#   'sour cream',
#   'ketchup',
#   'fresh garlic',
#   'fresh lemon juice',
#   'vegetable oil',
#   'hot sauce',
#   'brown sugar',
#   'fresh parsley',
#   'spicy mustard'],
#  ['salt', 'butter', 'egg', 'flour', 'sugar', 'baking powder', 'milk'],
#  ['pasta',
#   'dried oregano',
#   'water',
#   'salsa',
#   'dried basil',
#   'fresh ground black pepper',
#   'parmesan cheese',
#   'button mushrooms',
#   'tomato',
#   'onion',
#   'chicken breasts',
#   'hot sauce',
#   'olive oil',
#   'garlic',
#   'fresh parsley'],
#  ['fresh herbs', 'fresh herb', 'cider vinegar'],
#  ['fat',
#   'fresh corn',
#   'salt',
#   'egg',
#   'baking powder',
#   'flour',
#   'black pepper',
#   'cream'],
#  ['cheddar cheese soup',
#   'fettuccine pasta',
#   'jalapeno',
#   'picante sauce',
#   'black olives',
#   'milk'],
#  ['hass avocado',
#   'salt',
#   'tomato',
#   'frozen peas',
#   'lemons, juice of',
#   'onion',
#   'cilantro'],
#  ['lemon juice',
#   'worcestershire sauce',
#   'oil',
#   'soy sauce',
#   'basil',
#   'black pepper',
#   'garlic powder'],
#  ['cream cheese', 'unflavored gelatin', 'yogurt', 'pear', 'apple', 'milk'],
#  ['bay leaf',
#   'thyme',
#   'bacon',
#   'carrot',
#   'oil',
#   'salt',
#   'butter',
#   'black pepper',
#   'parsley sprigs',
#   'onion',
#   'veal roast'],
#  ['mayonnaise', 'black pepper', 'crackers', 'tomato'],
#  ['capers',
#   'oregano leaves',
#   'green olives',
#   'ham',
#   'red wine vinegar',
#   'carrot',
#   'fresh basil',
#   'provolone cheese',
#   'ciabatta',
#   'tomato',
#   'kalamata olive',
#   'brine',
#   'genoa salami',
#   'olive oil',
#   'garlic',
#   'fresh parsley',
#   'sweet onion'],
#  ['whipping cream',
#   'powdered sugar',
#   'vanilla instant pudding mix',
#   'vanilla'],
#  ['miniature semisweet chocolate chips',
#   'cream cheese',
#   'gelatin',
#   'prepared graham cracker crusts',
#   'vanilla',
#   'cookie',
#   'sugar',
#   'milk'],
#  ['egg',
#   'onion',
#   'baking powder',
#   'celery',
#   'vegetable shortening',
#   'soy sauce',
#   'ground cumin',
#   'salt',
#   'zucchini',
#   'chili powder',
#   'butter',
#   'tomato',
#   'cloves',
#   'cayenne pepper',
#   'flour',
#   'monterey jack cheese',
#   'sliced mushrooms',
#   'water',
#   'carrot',
#   'oregano',
#   'green pepper'],
#  ['half-and-half', 'sweet butter', 'salt and pepper', 'sweet corn'],
#  ['baking soda',
#   'salt',
#   'yogurt',
#   'butter',
#   'lemon, rind of',
#   'egg',
#   'vanilla',
#   'flour',
#   'sugar'],
#  ['butter',
#   'sugar',
#   'egg',
#   'vanilla',
#   'flour',
#   'nuts',
#   'unsweetened chocolate squares'],
#  ['broccoli',
#   'chili-garlic sauce',
#   'fresh ginger',
#   'reduced sodium soy sauce',
#   'rice vinegar',
#   'sesame oil',
#   'green onions',
#   'fresh cilantro',
#   'sesame seeds',
#   'vegetable oil',
#   'cooked chicken',
#   'vermicelli'],
#  ['celery',
#   'philadelphia cream cheese',
#   'orange juice',
#   'pecans',
#   'apples',
#   'sugar',
#   'orange rind'],
#  ['thyme',
#   'lemon juice',
#   'salt',
#   'boneless chicken breast',
#   'paprika',
#   'cayenne',
#   'fresh ground pepper',
#   'olive oil',
#   'garlic',
#   'cumin'],
#  ['baking potato',
#   'oregano leaves',
#   'part-skim ricotta cheese',
#   'parmesan cheese',
#   'tomato sauce',
#   'mozzarella cheese',
#   'garlic powder'],
#  ['sodium-free vegetable broth',
#   'tabasco sauce',
#   'onion',
#   'white wine',
#   'mushroom pieces',
#   'cornstarch',
#   'tomato puree',
#   'black pepper'],
#  ['red wine vinegar',
#   'white kidney beans',
#   'albacore tuna in water',
#   'salt',
#   'scallions',
#   'black pepper',
#   'bibb lettuce',
#   'light olive oil',
#   'garlic',
#   'fresh basil',
#   'red sweet bell peppers'],
#  ['dry white wine',
#   'ground pork',
#   'black pepper',
#   'onion',
#   'celery',
#   'beef consomme',
#   'rubbed sage',
#   'olive oil',
#   'garlic',
#   'nutmeg',
#   'penne pasta',
#   'bacon',
#   'crushed tomatoes',
#   'salt',
#   'butter',
#   'lean ground beef',
#   'carrot',
#   'red pepper flakes',
#   'oregano',
#   'milk'],
#  ['red cinnamon candies', 'apples', 'sugar substitute', 'water'],
#  ['celery',
#   'lemon juice',
#   'elbow macaroni',
#   'oil',
#   'tomato',
#   'ketchup',
#   'brown sugar',
#   'onion',
#   'cucumber',
#   'green pepper'],
#  ['hot water',
#   'salt',
#   'cocoa',
#   'vegetable oil',
#   'vanilla',
#   'flour',
#   'brown sugar',
#   'sugar',
#   'baking powder',
#   'milk'],
#  ['toasted almonds',
#   'salt',
#   'apple pie filling',
#   'butter',
#   'egg',
#   'powdered sugar',
#   'flour',
#   'milk'],
#  ['mayonnaise', 'white bread', 'bananas'],
#  ['dried oregano',
#   'fresh ground black pepper',
#   'dry white wine',
#   'boneless skinless chicken thighs',
#   'salt',
#   'breadcrumbs',
#   'chicken stock',
#   'vegetable oil',
#   'poultry seasoning',
#   'flour',
#   'onion',
#   'dried thyme',
#   'lean ground beef',
#   'garlic powder',
#   'milk'],
#  ['cream cheese', 'lemon juice', 'liquid smoke', 'salt', 'salmon', 'onion'],
#  ['onion',
#   'soy sauce',
#   'garlic',
#   'green beans',
#   'ground cumin',
#   'bean sprouts',
#   'ground coriander',
#   'tomato',
#   'tempeh',
#   'ground cayenne pepper',
#   'sambal oelek',
#   'brown sugar',
#   'red chili pepper',
#   'ginger',
#   'water',
#   'carrot',
#   'desiccated coconut',
#   'vegetable stock',
#   'peanut oil',
#   'peanuts'],
#  ['water',
#   'salt and pepper',
#   'lemon juice',
#   'onion',
#   'egg',
#   'dried breadcrumbs',
#   'tomato soup',
#   'ground beef',
#   'sugar'],
#  ['lime juice',
#   'salt and pepper',
#   'avocado',
#   'fresh cilantro',
#   'chunky salsa',
#   'hot sauce',
#   'soft silken tofu'],
#  ['baking soda',
#   'salt',
#   'cinnamon',
#   'white sugar',
#   'bananas',
#   'ground cloves',
#   'egg',
#   'flour',
#   'shortening',
#   'walnuts',
#   'nutmeg'],
#  ['lime juice',
#   'salt and pepper',
#   'dried basil',
#   'tomato',
#   'olive oil',
#   'boneless skinless chicken breast'],
#  ['water',
#   'worcestershire sauce',
#   'brown sugar',
#   'salt',
#   'ketchup',
#   'onion',
#   'vegetable oil',
#   'mustard',
#   'beef ribs',
#   'fresh lemon juice'],
#  ['sugar', 'egg whites', 'green grape'],
#  ['water',
#   'milk chocolate candy bars',
#   'egg',
#   'vegetable oil',
#   'betty crocker fudge brownie mix'],
#  ['water',
#   'baking soda',
#   'chocolate chips',
#   'salt',
#   'butter',
#   'bananas',
#   'sugar',
#   'egg',
#   'flour',
#   'nuts',
#   'baking powder'],
#  ['chocolate chips',
#   'cream cheese',
#   'sour cream',
#   'butter',
#   'oreo cookie crumbs',
#   'sweetened condensed milk',
#   'egg',
#   'vanilla',
#   'flour',
#   'brown sugar'],
#  ['banana',
#   'sugar-free non-fat vanilla yogurt',
#   'natural-style peanut butter',
#   '2% low-fat milk'],
#  ['taco seasoning',
#   'cheddar cheese',
#   'cream cheese',
#   'sour cream',
#   'bean dip'],
#  ['ground sirloin',
#   'iceberg lettuce',
#   'dill weed',
#   'bacon',
#   'no-salt-added ketchup',
#   'american cheese',
#   'tomato',
#   "mccormick's montreal brand steak seasoning",
#   'onion'],
#  ['plain yogurt',
#   'salt',
#   'chopped tomato',
#   'chat masala',
#   'paprika',
#   'cucumber',
#   'potato'],
#  ['whole wheat flour',
#   'baking soda',
#   'carrot',
#   'salt',
#   'buttermilk',
#   'egg',
#   'corn oil',
#   'vanilla',
#   'natural bran',
#   'brown sugar',
#   'cinnamon',
#   'raisins'],
#  ['lime juice',
#   'triple sec',
#   'tequila',
#   'limeade',
#   'grand marnier',
#   'lime wedge'],
#  ['pecans', 'butter', 'flour', 'brown sugar', 'semi-sweet chocolate chips'],
#  ['cheddar cheese',
#   'chopped tomato',
#   'salt',
#   'cappelletti pasta',
#   'corn',
#   'butter',
#   'onion',
#   'garlic',
#   'tomato soup',
#   'ground beef',
#   'black pepper',
#   'mushrooms',
#   'milk'],
#  ['salt and pepper',
#   'dry white wine',
#   'tomato sauce',
#   'hot water',
#   'spaghetti',
#   'squid',
#   'extra virgin olive oil',
#   'garlic',
#   'parsley'],
#  ['water',
#   'baking soda',
#   'vinegar',
#   'salt',
#   'cocoa',
#   'vegetable oil',
#   'vanilla',
#   'flour',
#   'sugar'],
#  ['applesauce', 'clove', 'brown sugar', 'pork loin chops'],
#  ['turkey',
#   'roasted red peppers',
#   'whole wheat bread dough',
#   'ham',
#   'cheddar cheese',
#   'cream cheese',
#   'green olives',
#   'prepared horseradish',
#   'provolone cheese',
#   'butter',
#   'roast beef',
#   'mayonnaise',
#   'radish sprouts',
#   'leaf lettuce',
#   'honey mustard',
#   'swiss cheese'],
#  ['beef broth',
#   'lemon, juice of',
#   'water',
#   'salt and pepper',
#   'wild mushrooms',
#   'sour cream',
#   'butter',
#   'flour',
#   'onion',
#   'fresh dill'],
#  ['rice wine vinegar',
#   'bean sprouts',
#   'carrot',
#   'fresh ginger',
#   'honey',
#   'rice noodles',
#   'sesame oil',
#   'asian chili sauce',
#   'green onions',
#   'light soy sauce',
#   'fresh cilantro',
#   'english cucumber',
#   'garlic'],
#  ['bittersweet chocolate',
#   'kosher salt',
#   'brewed espresso',
#   'granulated sugar',
#   'unsalted butter',
#   'egg',
#   'unsweetened cocoa powder',
#   'vanilla',
#   'flour'],
#  ['dr. pepper cola', 'brown sugar', 'orange marmalade'],
#  ['white pepper',
#   'gingerroot',
#   'fish',
#   'salt',
#   'sesame oil',
#   'scallions',
#   'peanut oil',
#   'low sodium soy sauce',
#   'rice wine'],
#  ['beef broth',
#   'parmesan cheese',
#   'sherry wine',
#   'french bread',
#   'butter',
#   'low sodium beef broth',
#   'sugar',
#   'romano cheese',
#   'yellow onions',
#   'olive oil',
#   'garlic',
#   'flour',
#   'swiss cheese'],
#  ['whole wheat flour',
#   'water',
#   'baking soda',
#   'margarine',
#   'chocolate chips',
#   'salt',
#   'white sugar',
#   'egg',
#   'vanilla',
#   'flour',
#   'brown sugar'],
#  ['cream of chicken soup',
#   'cornbread',
#   'butter',
#   'egg',
#   'squash',
#   'sage',
#   'onion'],
#  ['white onion',
#   'bay leaves',
#   'dried basil',
#   'dried oregano',
#   'tomato sauce',
#   'bottled garlic',
#   'salt',
#   'sugar',
#   'italian sausage',
#   'paprika',
#   'olive oil',
#   'black pepper',
#   'dried parsley',
#   'garlic powder'],
#  ['sharp cheddar cheese',
#   'cream of chicken soup',
#   'frozen broccoli cuts',
#   'salt',
#   'soy sauce',
#   'ground black pepper',
#   'french-fried onions',
#   'garlic powder',
#   'milk'],
#  ['whole milk',
#   'almond extract',
#   'pure vanilla extract',
#   'butter',
#   'egg',
#   'flour',
#   'sugar'],
#  ['oil',
#   'artichoke hearts',
#   'unsalted butter',
#   'fresh garlic',
#   'egg',
#   'unseasoned breadcrumbs'],
#  ['barbecue sauce',
#   'hot red pepper sauce',
#   'worcestershire sauce',
#   'salt',
#   'chili powder',
#   'chicken',
#   'black pepper',
#   'cider vinegar'],
#  ['cheddar cheese',
#   'cream cheese',
#   'sour cream',
#   'water chestnuts',
#   'frozen broccoli',
#   'dry onion soup mix',
#   'ritz cracker crumbs'],
#  ['water',
#   'cocoa powder',
#   'baking soda',
#   'cool whip',
#   'salt',
#   'mayonnaise',
#   'instant chocolate pudding mix',
#   'vanilla',
#   'flour',
#   'sugar',
#   'milk'],
#  ['oregano leaves',
#   'lean pork',
#   'water',
#   'louisiana hot sauce',
#   'lean chuck',
#   'chili powder',
#   'onion',
#   'coriander',
#   'sugar',
#   'paprika',
#   'unsweetened cocoa',
#   'hunts tomato sauce',
#   'bouillon',
#   'cornmeal',
#   'garlic',
#   'flour',
#   'budweiser beer',
#   'cumin'],
#  ['goat cheese',
#   'white pepper',
#   'simply potatoes shredded hash browns',
#   'unsmoked bacon',
#   'kosher salt',
#   'fresh garlic',
#   'unsalted butter',
#   'baby spinach',
#   'yellow onion',
#   'egg',
#   'red bell pepper',
#   'olive oil',
#   'meatloaf mixture'],
#  ['dark brown sugar',
#   'pie crusts',
#   'ground cinnamon',
#   'pumpkin puree',
#   'egg white',
#   'ground ginger',
#   'salt',
#   'ground cloves',
#   'heavy cream',
#   'egg',
#   'nutmeg',
#   'milk'],
#  ['dry onion flakes',
#   'cream of chicken soup',
#   'beef',
#   'poppy seed',
#   'salt',
#   'breadcrumbs',
#   'sour cream',
#   'butter',
#   'paprika',
#   'poultry seasoning',
#   'vegetable oil',
#   'baking powder',
#   'flour',
#   'onion',
#   'celery seed',
#   'milk'],
#  ['blended oatmeal',
#   'baking soda',
#   'butter',
#   'hershey chocolate candy bars',
#   'egg',
#   'nuts',
#   'baking powder',
#   'vanilla',
#   'flour',
#   'brown sugar',
#   'sugar',
#   'semi-sweet chocolate chips'],
#  ["hershey's semi-sweet baking chocolate",
#   'baking soda',
#   'chocolate chips',
#   'salt',
#   'butter',
#   'white sugar',
#   'oatmeal',
#   'egg',
#   'vanilla',
#   'flour',
#   'brown sugar',
#   'nuts',
#   'baking powder'],
#  ['granulated sugar', 'butter', 'vanilla', 'flour', 'milk'],
#  ['taco seasoning',
#   'cheddar cheese',
#   'salsa',
#   'tomato',
#   'taco shells',
#   'ground beef',
#   'lettuce',
#   'onion',
#   'corn cobs'],
#  ['mexican chili powder',
#   'chunky salsa',
#   'black pepper',
#   'chicken bouillon cube',
#   'beans',
#   'white onion',
#   'beef bouillon cube',
#   'stewing pork',
#   'cumin',
#   'garlic',
#   'cinnamon',
#   'sazon goya',
#   'bell peppers',
#   'stewing beef',
#   'salt',
#   'ground coriander',
#   'tortilla chips',
#   'beef broth',
#   'tomato paste',
#   'dark chocolate chips',
#   'habanero pepper',
#   'light brown sugar'],
#  ['lemon zest',
#   'baking soda',
#   'cream cheese',
#   'triple sec',
#   'pecans',
#   'salt',
#   'lime zest',
#   'tequila',
#   'orange-flavored liqueur',
#   'butter',
#   'pitted dates',
#   'egg',
#   'powdered sugar',
#   'flour',
#   'brown sugar',
#   'warm water',
#   'shortening'],
#  ['celery',
#   'water',
#   'cream of chicken soup',
#   'carrot',
#   'butter',
#   'cream of celery soup',
#   'bouillon cubes',
#   'onion',
#   'potato flakes',
#   'potato',
#   'milk'],
#  ['lemon, juice of',
#   'apples',
#   'salt',
#   'butter',
#   'egg',
#   'flour',
#   'sugar',
#   'cream',
#   'cinnamon',
#   'milk'],
#  ['cheese',
#   'salt',
#   'butter',
#   'garlic',
#   'fresh coarse ground black pepper',
#   'macaroni',
#   'onion',
#   'milk'],
#  ['salt water',
#   'potato',
#   'cheese',
#   'black pepper',
#   'unsalted butter',
#   'heavy cream',
#   'macaroni',
#   'muscat wine',
#   'onion',
#   'fine semolina'],
#  ['applesauce',
#   'penne pasta',
#   'salt and pepper',
#   'cheese',
#   'butter',
#   'onion',
#   'potato',
#   'milk'],
#  ['water', 'ginger', 'salt', 'dried yellow peas', 'pork'],
#  ['clove',
#   'water',
#   'carrot',
#   'ground ginger',
#   'salt',
#   'dried yellow peas',
#   'black pepper',
#   'ham bone',
#   'brown mustard',
#   'onion',
#   'dried thyme'],
#  ['fresh spinach', 'water', 'nutmeg', 'butter'],
#  ['water',
#   'wondra flour',
#   'tomato paste',
#   'dried onion flakes',
#   'ground pork',
#   'salt',
#   'granulated sugar',
#   'chili powder',
#   'paprika',
#   'cornstarch',
#   'white vinegar',
#   'ground black pepper',
#   'ground beef',
#   'garlic powder'],
#  ['applesauce',
#   'ponzu sauce',
#   'apple cider vinegar',
#   'dark brown sugar',
#   'maple syrup',
#   'liquid smoke',
#   'salt',
#   'oregano',
#   'tomato ketchup',
#   'granulated garlic',
#   'cayenne'],
#  ['baking soda',
#   'salt',
#   'sour cream',
#   'butter',
#   'egg',
#   'vanilla',
#   'flour',
#   'sugar',
#   'baking powder'],
#  ['vanilla ice cream', 'oreo cookies', 'frozen whipped topping', 'butter'],
#  ['white bread', 'processed cheese', 'butter'],
#  ['fresh ground black pepper',
#   'worcestershire sauce',
#   'rosemary',
#   'soy sauce',
#   'london broil beef',
#   'olive oil',
#   'garlic',
#   'balsamic vinegar'],
#  ['chicken broth',
#   'dried oregano',
#   'parmesan cheese',
#   'nonfat dry milk powder',
#   'teriyaki sauce',
#   'margarine',
#   'fresh mushrooms',
#   'salt and black pepper',
#   'dry sherry',
#   'nonfat milk',
#   'dried rosemary',
#   'cornstarch',
#   'spicy brown mustard',
#   'garlic',
#   'dried thyme',
#   'hot pepper sauce'],
#  ['nutmeg',
#   'cream cheese',
#   'almonds',
#   'vanilla protein powder',
#   'sour cream',
#   'butter',
#   'splenda sugar substitute',
#   'egg',
#   'vanilla',
#   'cinnamon'],
#  ['refrigerated buttermilk biscuits', 'real maple syrup', 'bacon', 'butter'],
#  ['tabasco sauce',
#   'worcestershire sauce',
#   'mayonnaise',
#   'velveeta cheese',
#   'horseradish'],
#  ['red wine vinegar', 'water', 'lemon juice'],
#  ['ground flax seeds',
#   'water',
#   'berries',
#   "i can't believe it's not butter spread",
#   'sugar-free syrup',
#   'old fashioned oats'],
#  ['cream cheese',
#   'frozen blueberries',
#   'maple syrup',
#   'salt',
#   'blueberries',
#   'sugar',
#   'egg',
#   'milk',
#   'vanilla',
#   'powdered sugar',
#   'nuts',
#   'flour',
#   'french bread'],
#  ['celery',
#   'chicken broth',
#   'white pepper',
#   'cheddar cheese',
#   'bacon',
#   'liquid smoke',
#   'salt',
#   'sour cream',
#   'chives',
#   'velveeta cheese',
#   'onion',
#   'red potatoes'],
#  ['vanilla pudding mix',
#   'cream cheese',
#   'salt',
#   'granulated sugar',
#   'active dry yeast',
#   'butter',
#   'egg',
#   'powdered sugar',
#   'brown sugar',
#   'warm water',
#   'flour',
#   'cinnamon',
#   'milk'],
#  ['reduced-fat parmesan cheese',
#   'salt and pepper',
#   'spaghetti squash',
#   'white mushroom',
#   'part-skim mozzarella cheese',
#   'red bell pepper',
#   'asparagus',
#   'spaghetti sauce',
#   'garlic',
#   'italian seasoning'],
#  ['frozen pineapple concentrate',
#   'water',
#   'graham cracker crumbs',
#   'margarine',
#   'lemon juice',
#   'soft silken tofu',
#   'oil',
#   'maple syrup',
#   'coriander',
#   'vegan cream cheese',
#   'cornstarch',
#   'vanilla',
#   'vegan sugar'],
#  ['celery',
#   'low sodium chicken broth',
#   'large raw shrimp',
#   'onion',
#   'frozen black-eyed peas',
#   'vegetable oil',
#   'creole seasoning',
#   'green bell pepper',
#   'flour',
#   'garlic',
#   'cooked chicken',
#   'andouille sausage'],
#  ['salt and pepper',
#   'cheddar cheese',
#   'pickle',
#   'cracker',
#   'egg',
#   'ground beef',
#   'onion',
#   'thousand island dressing'],
#  ['white pepper',
#   'cajun spices',
#   'parmesan cheese',
#   'parmesan-romano cheese mix',
#   'lemon juice',
#   'salt',
#   'linguine',
#   'butter',
#   'salmon',
#   'heavy whipping cream',
#   'garlic',
#   'parsley',
#   'basil'],
#  ['cottage cheese', 'phyllo dough', 'oil', 'egg', 'feta', 'milk'],
#  ['avocado',
#   'imitation crabmeat',
#   'soy sauce',
#   'lettuce',
#   'seasoned rice vinegar',
#   'cucumber',
#   'pickled ginger',
#   'white rice'],
#  ['baking soda',
#   'mincemeat',
#   'sweetened condensed milk',
#   'egg',
#   'maraschino cherry',
#   'mixed candied fruit',
#   'flour',
#   'walnuts'],
#  ['celery',
#   'baby carrots',
#   'white onion',
#   'kosher salt',
#   'oil',
#   'salt',
#   'chicken breasts',
#   'chicken stock',
#   'egg',
#   'matzo meal',
#   'sugar',
#   'black pepper',
#   'baking powder'],
#  ['cheddar cheese',
#   'poppy seed',
#   'sour cream',
#   'cream of mushroom soup',
#   'frozen southern style hash brown potatoes'],
#  ['sea salt',
#   'red onion',
#   'ground sage',
#   'adobo seasoning',
#   'ground coriander',
#   'oregano',
#   'ketchup',
#   'italian seasoned breadcrumbs',
#   'egg',
#   'fresh ground pepper',
#   'low sodium soy sauce',
#   'olive oil',
#   'veggie shreds cheese',
#   'lean ground beef',
#   'fresh garlic cloves'],
#  ['celery',
#   'kraft macaroni and cheese',
#   'tuna',
#   'butter',
#   'cream of celery soup',
#   'onion',
#   'mushrooms',
#   'green bell pepper'],
#  ['tabasco sauce',
#   'miracle whip',
#   'salt',
#   'ketchup',
#   'black pepper',
#   'sugar',
#   'paprika',
#   'vegetable oil',
#   'dry mustard',
#   'garlic',
#   'cider vinegar'],
#  ['tuna in vegetable oil',
#   'lemon, juice of',
#   'red wine vinegar',
#   'kosher salt & freshly ground black pepper',
#   'red onion',
#   'shallot',
#   'seedless cucumber',
#   'oregano',
#   'extra virgin olive oil',
#   'red bell pepper',
#   'kalamata olive',
#   'water-packed artichoke hearts',
#   'italian parsley',
#   'red ripe tomatoes',
#   'pepperoncini peppers'],
#  ['self-rising flour',
#   'buttermilk',
#   'egg',
#   'orange roughy',
#   'ground black pepper',
#   'canola oil',
#   'seasoning salt'],
#  ['goat cheese',
#   'bacon',
#   'egg yolk',
#   'salt',
#   'simply potatoes traditional mashed potatoes',
#   'egg',
#   'frozen spinach',
#   'flour',
#   'garlic',
#   'green onion'],
#  ['self-rising flour',
#   'salt and pepper',
#   'cajun seasoning',
#   'egg',
#   'canola oil',
#   'ground black pepper',
#   'seasoning salt',
#   'flour',
#   'boneless pork chops',
#   'milk'],
#  ['water',
#   'imitation crabmeat',
#   'ramen noodles',
#   'teriyaki marinade',
#   'stir fry vegetables'],
#  ['celery',
#   'pesto sauce',
#   'red onion',
#   'pumpkin puree',
#   'salt',
#   'smooth cashew butter',
#   'banana',
#   'ground red pepper',
#   'vegetable broth',
#   'small red potato',
#   'green bell pepper',
#   'pumpkin seeds',
#   'fresh cilantro leaves',
#   'apple'],
#  ['vegetable bouillon cubes',
#   'water',
#   'margarine',
#   'mushrooms',
#   'chili powder',
#   'dry-roasted cashews',
#   'garlic',
#   'parsley',
#   'nutmeg'],
#  ['strawberries', 'oranges', 'ice cubes', 'mangoes', 'vanilla bean'],
#  ['salt and pepper',
#   'russet potatoes',
#   'white beans',
#   'leeks',
#   'fresh rosemary',
#   'vegetable broth',
#   'olive oil',
#   'garlic'],
#  ['ground cumin',
#   'fresh ginger',
#   'fresh coriander',
#   'chili powder',
#   'coriander seed',
#   'soy yogurt',
#   'chicken stock',
#   'garlic',
#   'turmeric',
#   'cloves',
#   'black peppercorns',
#   'onion',
#   'boneless skinless chicken breasts',
#   'salt & freshly ground black pepper',
#   'cardamom pods',
#   'cinnamon stick'],
#  ['tabasco sauce',
#   'dried oregano',
#   'beef bouillon cubes',
#   'boiling water',
#   'worcestershire sauce',
#   'salt',
#   'rump roast',
#   'black pepper',
#   'garlic',
#   'dried thyme',
#   'garlic powder'],
#  ['tea bag', 'water', 'ginger', 'honey', 'milk'],
#  ['ground beef', 'velveeta cheese', 'taco chips', 'sausage'],
#  ['bell pepper',
#   'worcestershire sauce',
#   'tomato sauce',
#   'ground mustard',
#   'steak seasoning',
#   'ketchup',
#   'white vinegar',
#   'hamburger buns',
#   'brown sugar',
#   'onion',
#   'lean ground beef',
#   'garlic powder'],
#  ['rice wine vinegar',
#   'gingerroot',
#   'green peppers',
#   'white mushrooms',
#   'carrot',
#   'honey',
#   'salt',
#   'salad seasoning',
#   'soy sauce',
#   'salad greens',
#   'green onions',
#   'fresh corn kernels',
#   'beets',
#   'garlic',
#   'safflower oil',
#   'black pepper'],
#  ['chicken broth',
#   'fennel seeds',
#   'dry white wine',
#   'pork chops',
#   'paprika',
#   'olive oil',
#   'onion',
#   'fresh lemon juice'],
#  ['ramen noodles',
#   'pepperoni',
#   'black olives',
#   'red bell pepper',
#   'egg',
#   'mozzarella cheese',
#   'italian seasoning',
#   'roma tomato',
#   'garlic powder'],
#  ['baking soda',
#   'brown sugar',
#   'oil',
#   'salt',
#   'molasses',
#   'sesame seeds',
#   'sunflower seeds',
#   'egg',
#   'milk',
#   'flour',
#   'natural bran',
#   'baking powder',
#   'raisins'],
#  ['black tea leaves',
#   'brown sugar',
#   'broiler',
#   'onion',
#   'minced ginger',
#   'orange zest',
#   'low sodium soy sauce',
#   'orange, juice of',
#   'garlic',
#   'peppercorn',
#   'dry sherry'],
#  ['gingerroot',
#   'lemongrass',
#   'kaffir lime leaves',
#   'yoghurt',
#   'coriander seed',
#   'turmeric',
#   'peanut oil',
#   'star anise',
#   'cloves',
#   'fruit vinegar',
#   'cardamom pods'],
#  ['vanilla pudding mix',
#   'blueberry pie filling',
#   'cool whip',
#   'graham wafers'],
#  ['canned jalapeno slices',
#   'water',
#   'tomato paste',
#   'vinegar',
#   'dried onion flakes',
#   'salt',
#   'chili powder',
#   'onion powder',
#   'cornstarch',
#   'cayenne pepper',
#   'sugar',
#   'garlic powder'],
#  ['quick-cooking oats',
#   'shredded coconut',
#   'baking soda',
#   'brown sugar',
#   'salt',
#   'butter',
#   'corn flakes',
#   'egg',
#   'vanilla',
#   'raisins',
#   'nuts',
#   'baking powder',
#   'cake flour'],
#  ['kosher salt',
#   'butter',
#   'black pepper',
#   'italian spices',
#   'whole turkey',
#   'olive oil',
#   'onion'],
#  ['cheddar cheese',
#   'salsa',
#   'corn chips',
#   'sour cream',
#   'chili with beans',
#   'onion'],
#  ['plain breadcrumbs',
#   'salt',
#   'parsley sprig',
#   'egg',
#   'vegetable oil',
#   'cauliflower florets',
#   'black pepper'],
#  ['kosher salt',
#   'mixed herbs',
#   'butter',
#   'fresh green beans',
#   'ground black pepper',
#   'olive oil',
#   'onion',
#   'walnuts'],
#  ['ham',
#   'american cheese',
#   'sweet pickle relish',
#   'ketchup',
#   'hamburger buns'],
#  ['sugar', 'bacon', 'carrot', 'tomato soup'],
#  ['seasoned bread crumbs',
#   'ketchup',
#   'egg',
#   'ground beef',
#   'brown sugar',
#   'lipton onion soup mix'],
#  ['bulk pork sausage',
#   'worcestershire sauce',
#   'rye cocktail bread',
#   'ground chuck',
#   'oregano',
#   'velveeta cheese',
#   'ground pepper',
#   'garlic powder'],
#  ['brown sugar',
#   'self-raising flour',
#   'butter',
#   'caster sugar',
#   'pineapple in syrup',
#   'egg',
#   'milk',
#   'vanilla essence',
#   'glace cherries'],
#  ['oat bran',
#   'greens',
#   'water',
#   'honey',
#   'banana',
#   'coconut milk',
#   'flax seed oil',
#   'apple'],
#  ['knorr vegetable soup mix',
#   'sour cream',
#   'water chestnuts',
#   'hawaiian bread',
#   'green onion',
#   "hellmann's mayonnaise"],
#  ['carrot',
#   'soy sauce',
#   'brown rice',
#   'egg',
#   'broccoli floret',
#   'olive oil',
#   'sliced mushrooms',
#   'peas'],
#  ['reduced fat graham cracker crust',
#   'pumpkin pie spice',
#   'pumpkin',
#   'skim milk',
#   'egg whites',
#   'splenda sugar substitute'],
#  ['beef stew', 'biscuits'],
#  ['light corn syrup',
#   'semisweet chocolate',
#   'baking soda',
#   'pure vanilla extract',
#   'honey roasted peanuts',
#   'salt',
#   'espresso',
#   'buttermilk',
#   'extra-large eggs',
#   'unsalted butter',
#   'unsweetened cocoa',
#   'heavy cream',
#   'creamy peanut butter',
#   'powdered sugar',
#   'unbleached all-purpose flour',
#   'sugar'],
#  ['ground cumin',
#   'chipotle chile in adobo',
#   'lime zest',
#   'fresh lime juice',
#   'yellow cornmeal',
#   'onion',
#   'red bell pepper',
#   'corn kernel',
#   'olive oil',
#   'garlic',
#   'short-grain brown rice',
#   'cilantro'],
#  ['water',
#   'whipped dessert topping mix',
#   'instant vanilla pudding',
#   'butter',
#   'egg',
#   'flour'],
#  ['celery',
#   'white pepper',
#   'miracle whip',
#   'hard-boiled eggs',
#   'salt',
#   'dijon mustard',
#   'white onions',
#   'fresh ground pepper',
#   'mustard',
#   'sugar',
#   'potato',
#   'milk'],
#  ['tea bag',
#   'water',
#   'dried basil',
#   'lemon juice',
#   'chili powder',
#   'soy sauce',
#   'butter',
#   'cayenne pepper',
#   'seasoning salt',
#   'white rice',
#   'black pepper',
#   'garlic powder'],
#  ['roasted red pepper',
#   'feta cheese',
#   'oregano',
#   'bisquick',
#   'kalamata olive',
#   'egg',
#   'frozen spinach',
#   'fresh ground pepper',
#   'onion',
#   'milk'],
#  ['water',
#   'allspice',
#   'baking soda',
#   'pumpkin',
#   'oil',
#   'salt',
#   'pecans',
#   'cinnamon',
#   'ground cloves',
#   'egg',
#   'flour',
#   'sugar',
#   'baking powder',
#   'nutmeg'],
#  ['water',
#   'long-grain rice',
#   'dry onion soup mix',
#   'vegetable oil',
#   'black pepper',
#   'boneless pork chops'],
#  ['sage',
#   'cayenne',
#   'onion',
#   'black pepper',
#   'red peppers',
#   'olive oil',
#   'garlic',
#   'nutmeg',
#   'cinnamon',
#   'onion flakes',
#   'clove',
#   'crushed tomatoes',
#   'chili powder',
#   'rum',
#   'brown sugar',
#   'jamaican jerk spice',
#   'lime juice',
#   'ginger',
#   'thyme',
#   'allspice',
#   'chives',
#   'habanero pepper',
#   'boneless skinless chicken breasts'],
#  ['frozen limeade concentrate', 'ice', 'mango', 'strawberry', 'lime sorbet'],
#  ['ice',
#   'strawberry',
#   'apple juice',
#   'banana',
#   'non-fat vanilla frozen yogurt'],
#  ['hoisin sauce',
#   'sesame oil',
#   'fish sauce',
#   'coriander seed',
#   'yoghurt',
#   'red chile',
#   'cumin',
#   'garlic',
#   'fruit vinegar'],
#  ['peppermint oreos',
#   'unsweetened chocolate',
#   'salt',
#   'butter',
#   'peppermint extract',
#   'egg',
#   'unsweetened cocoa powder',
#   'vanilla',
#   'flour',
#   'sugar',
#   'candy cane'],
#  ['celery',
#   'orange juice',
#   'mandarin oranges',
#   'salt',
#   'green grapes',
#   'cooked rice',
#   'mayonnaise',
#   'white vinegar',
#   'canola oil',
#   'slivered almonds',
#   'pineapple tidbits',
#   'cooked chicken breasts'],
#  ['celery',
#   'cheddar cheese',
#   'hard-boiled eggs',
#   'sweet pickle relish',
#   'mayonnaise',
#   'frozen peas',
#   'onion',
#   'seasoning salt',
#   'mustard',
#   'sugar'],
#  ['parmesan cheese',
#   'dry breadcrumbs',
#   'oil',
#   'buttermilk',
#   'chicken pieces',
#   'dijon mustard',
#   'fresh garlic',
#   'butter',
#   'black pepper',
#   'paprika',
#   'seasoning salt',
#   'cayenne pepper',
#   'flour',
#   'onion',
#   'dried thyme',
#   'hot pepper sauce',
#   'garlic powder'],
#  ['allspice',
#   'lemon juice',
#   'hoisin sauce',
#   'habanero sauce',
#   'ketchup',
#   'fresh garlic',
#   'sugar',
#   'black pepper',
#   'seasoning salt',
#   'louisiana hot sauce',
#   'pork baby back ribs',
#   'cinnamon'],
#  ['celery',
#   'rotini pasta',
#   'carrot',
#   'salt',
#   'corn',
#   'chicken leg',
#   'black pepper',
#   'onion',
#   'red bell pepper',
#   'beef stock',
#   'italian seasoning',
#   'spaghetti sauce',
#   'garlic',
#   'peas'],
#  ['salt and pepper',
#   'margarine',
#   'aluminum foil',
#   'mexicorn whole kernel corn',
#   'sour cream',
#   'spinach dip',
#   'pam cooking spray',
#   'stove top stuffing mix monterey style with mushroom and onion'],
#  ['pickling spices', 'white vinegar', 'cooking onions'],
#  ['chicken broth',
#   'carrot',
#   'cooked pasta',
#   'soy sauce',
#   'egg',
#   'cooked chicken',
#   'peas'],
#  ['cake crumbs', 'mixed fruit', 'cool whip', 'cream cheese'],
#  ['pie crust',
#   'cool whip',
#   'butter',
#   'coconut flavoring',
#   'egg',
#   'lemon flavoring',
#   'squash',
#   'flour',
#   'sugar'],
#  ['ground veal',
#   'ground cinnamon',
#   'dried onion flakes',
#   'salt',
#   'cream of mushroom soup',
#   'dijon mustard',
#   'ground cloves',
#   'black pepper',
#   'dried parsley flakes',
#   'garlic powder'],
#  ['tabasco sauce',
#   'brown rice',
#   'small shrimp',
#   'black pepper',
#   'parsley',
#   'tomato soup',
#   'catfish nuggets',
#   'olive oil',
#   'garlic',
#   'mexican-style stewed tomatoes with jalapeno peppers',
#   'gumbo file',
#   'red onions',
#   'red wine vinegar',
#   'old bay seasoning',
#   'okra',
#   'oregano',
#   'chicken stock',
#   'lemon',
#   'seafood'],
#  ['bacon',
#   'mild cheddar cheese',
#   'sour cream',
#   'fresh chives',
#   'paprika',
#   'egg',
#   'white vinegar'],
#  ['garlic salt',
#   'dried oregano',
#   'dried basil',
#   'lemon juice',
#   'salt',
#   'chicken breasts',
#   'white vinegar',
#   'olive oil',
#   'sandwich buns',
#   'garlic',
#   'dried parsley',
#   'cracked black pepper'],
#  ['shredded coconut',
#   'baking soda',
#   'boiling water',
#   'margarine',
#   'salt',
#   'cinnamon',
#   'egg',
#   'vanilla',
#   'flour',
#   'brown sugar',
#   'nuts',
#   'cream',
#   'nutmeg',
#   'quick oats'],
#  ['marshmallows', 'rice krispies', 'butter'],
#  ['frozen limeade concentrate',
#   'cool whip topping',
#   'cream cheese',
#   'orange juice'],
#  ['tabasco sauce',
#   'cheddar cheese',
#   'corn chips',
#   'avocado',
#   'lemon juice',
#   'tuna',
#   'salt',
#   'sour cream',
#   'pitted ripe olives',
#   'chili powder',
#   'tomato',
#   'sugar',
#   'lettuce',
#   'garlic',
#   'green onion',
#   'salad oil'],
#  ['chickpeas',
#   'ground cumin',
#   'baking potatoes',
#   'fresh coriander',
#   'tahini',
#   'coriander',
#   'low-fat yogurt',
#   'olive oil',
#   'garlic',
#   'salt & freshly ground black pepper'],
#  ['salt',
#   'buttermilk',
#   'yellow cornmeal',
#   'mayonnaise',
#   'egg',
#   'vegetable oil',
#   'sugar',
#   'baking powder'],
#  ['gingerroot',
#   'carrot',
#   'red cabbage',
#   'maple syrup',
#   'rice vinegar',
#   'sesame oil',
#   'soy sauce',
#   'green cabbage',
#   'green onion',
#   'apple'],
#  ['water',
#   'orzo pasta',
#   'long-grain rice',
#   'chicken soup powder',
#   'canola oil',
#   'turmeric',
#   'black pepper',
#   'garlic powder'],
#  ['chicken broth',
#   'chipotle chiles in adobo',
#   'salt and pepper',
#   'white onion',
#   'avocado',
#   'crushed tomatoes',
#   'celery ribs',
#   'fresh cilantro',
#   'jalapeno pepper',
#   'chicken breast',
#   'ear of corn',
#   'cumin',
#   'green bell pepper'],
#  ['reduced-fat parmesan cheese',
#   'dried basil',
#   'fat free mozzarella cheese',
#   'egg white',
#   'salt',
#   'fiber one cereal',
#   'italian-style tomato sauce',
#   'black pepper',
#   'eggplant',
#   'garlic powder'],
#  ['egg', 'beef gravy', 'ground beef', 'onion', 'white rice'],
#  ['water',
#   'ham',
#   'black-eyed peas',
#   'carrot',
#   'great northern beans',
#   'ham soup base',
#   'salt',
#   'onion',
#   'black pepper',
#   'celery ribs',
#   'navy beans',
#   'ham bone',
#   'pinto beans',
#   'tomatoes and green chilies',
#   'garlic',
#   'beans'],
#  ['light mayonnaise',
#   'feta cheese',
#   'skinless chicken breast half',
#   'red bell pepper',
#   'garlic',
#   'fresh dill',
#   'cider vinegar'],
#  ['cheese ravioli',
#   'garlic salt',
#   'mozzarella cheese',
#   'italian seasoning',
#   'spaghetti sauce',
#   'lean ground beef'],
#  ['barbecue sauce',
#   'lemon juice',
#   'worcestershire sauce',
#   'orange marmalade',
#   'chicken pieces'],
#  ['salt',
#   'coriander',
#   'onion powder',
#   'paprika',
#   'ground red pepper',
#   'turmeric',
#   'ground black pepper',
#   'garlic powder'],
#  ['green onion',
#   'cream cheese',
#   'sour cream',
#   'mexican blend cheese',
#   'taco seasoning mix',
#   'tomato',
#   'mayonnaise',
#   'lettuce',
#   'black olives',
#   'green pepper'],
#  ['tabasco sauce',
#   'sharp cheddar cheese',
#   'worcestershire sauce',
#   'green onions',
#   'minced clams',
#   'green bell peppers',
#   'paprika'],
#  ['olives',
#   'red onion',
#   'olive oil',
#   'eggplants',
#   'oregano',
#   'red bell pepper',
#   'yellow bell pepper',
#   'spaghetti squash',
#   'shrimp'],
#  ["confectioners' sugar", 'heavy cream', 'semisweet chocolate', 'butter'],
#  ['small marshmallow',
#   'pecans',
#   'cherry pie filling',
#   'crushed pineapple',
#   'sweetened condensed milk',
#   'frozen whipped topping'],
#  ['cheddar cheese',
#   'bacon',
#   'oil',
#   'salt',
#   'sour cream',
#   'green onions',
#   'potato'],
#  ['parmesan cheese',
#   'pizza sauce',
#   'salt',
#   'onion',
#   'plain flour',
#   'mozzarella cheese',
#   'canola oil',
#   'black pepper',
#   'boneless eye of round beef steak'],
#  ['soup mix',
#   "campbell's golden mushroom soup",
#   'bacon grease',
#   'oregano',
#   'seasoning salt',
#   'ground black pepper',
#   'boneless country-style ribs',
#   'flour'],
#  ['butter', 'egg', 'flour', 'sugar', 'fruit', 'milk'],
#  ['baby carrots',
#   'ground cinnamon',
#   'honey',
#   'apples',
#   'crescent roll dough',
#   'cardamom',
#   'butter',
#   'sugar'],
#  ['garlic salt',
#   'mozzarella cheese',
#   'italian seasoning',
#   'olive oil',
#   'refrigerated biscuits'],
#  ['water', 'salt', 'active dry yeast', 'butter', 'flour', 'sugar', 'milk'],
#  ['egg yolk',
#   'cream cheese',
#   'salt',
#   'lemon peel',
#   'butter',
#   'egg yolks',
#   'egg',
#   'whipping cream',
#   'vanilla',
#   'flour',
#   'sugar'],
#  ['honey',
#   'little smokies sausages',
#   'chili sauce',
#   'country-style dijon mustard'],
#  ["meyer's dark rum",
#   'orange juice',
#   'pineapple juice',
#   'prepared sweet-and-sour mix',
#   'white rum',
#   'grenadine',
#   'orgeat syrup',
#   'orange curacao',
#   'bacardi dark rum'],
#  ['water',
#   'balsamic vinaigrette',
#   'onion',
#   'condensed chicken broth',
#   'red apples',
#   'pork chops',
#   'dried thyme leaves',
#   'sliced mushrooms',
#   'minute white rice'],
#  ['prepared mustard',
#   'reduced-calorie mayonnaise',
#   'fresh ground black pepper',
#   'tomato paste',
#   'orange juice',
#   'plain nonfat yogurt',
#   'chili powder',
#   'green bell peppers',
#   'red bell peppers',
#   'onion',
#   'horseradish'],
#  ['strawberry gelatin',
#   'strawberries',
#   'cool whip',
#   'orange juice',
#   'cold water',
#   'lemon gelatin',
#   'nectarines',
#   'grapes',
#   'peach gelatin'],
#  ['dried sage',
#   'salt',
#   'skim milk',
#   'ground marjoram',
#   'fat-free evaporated milk',
#   'poultry seasoning',
#   'lean ground turkey',
#   'cayenne pepper',
#   'flour',
#   'brown sugar',
#   'black pepper',
#   'garlic powder',
#   'onion flakes'],
#  ['barbecue sauce',
#   'cooking spray',
#   'egg',
#   'red bell pepper',
#   'ground beef',
#   'ground black pepper',
#   'french-fried onions',
#   'seasoning salt',
#   'sweet onion',
#   'garlic powder'],
#  ['beef broth',
#   'bay leaf',
#   'water',
#   'carrot',
#   'tomato sauce',
#   'crushed tomatoes',
#   'salt',
#   'italian salad dressing',
#   'black pepper',
#   'green pepper',
#   'garlic',
#   'flour',
#   'beef bouillon granules',
#   'onion',
#   'cold water',
#   'potato',
#   'beef stew meat'],
#  ['tabasco sauce',
#   'salt and pepper',
#   'water',
#   'carrot',
#   'garam masala',
#   'onion',
#   'curry powder',
#   'kidney beans',
#   'garlic',
#   'potato',
#   'ghee'],
#  ['ouzo', 'ice cube', 'orange slice', 'orange juice'],
#  ['half-and-half',
#   'sherry wine',
#   'crabmeat',
#   'salt',
#   'red pepper',
#   'old bay seasoning',
#   'cream of mushroom soup',
#   'cream of celery soup',
#   'black pepper',
#   'milk'],
#  ['ground turkey',
#   'ground pork',
#   'unsalted butter',
#   'sherry wine vinegar',
#   'onion',
#   'chicken broth',
#   'salt and pepper',
#   'egg whites',
#   'skim milk',
#   'ground sirloin',
#   'shallot',
#   'bacon',
#   'worcestershire sauce',
#   'yellow mustard',
#   'mixed mushrooms',
#   'brown sugar',
#   'flour',
#   'dry sherry',
#   'panko breadcrumbs',
#   'tomato paste',
#   'ketchup',
#   'fresh parsley'],
#  ['lemon, juice of',
#   'lemon, zest of',
#   'rosemary',
#   'olive oil',
#   'new potatoes',
#   'garlic'],
#  ['salsa',
#   'frozen corn',
#   'dry breadcrumbs',
#   'oil',
#   'black beans',
#   'chili powder',
#   'green chili sauce',
#   'garlic',
#   'cumin',
#   'onion',
#   'flour'],
#  ['salt',
#   'caesar salad dressing',
#   'sour cream',
#   'baby shrimp',
#   'green onions',
#   'ripe olives',
#   'mayonnaise',
#   'red bell pepper',
#   'fresh ground pepper',
#   'fresh spinach',
#   'cheese-filled tortellini'],
#  ['celery',
#   'salt and pepper',
#   'ground turkey',
#   'bell peppers',
#   'cheese',
#   'worcestershire sauce',
#   'tomato',
#   'onion',
#   'garlic',
#   'olive oil',
#   'spike seasoning',
#   'fresh parsley'],
#  ['nutmeg',
#   'graham cracker crumbs',
#   'lemon juice',
#   'cream cheese',
#   'sour cream',
#   'butter',
#   'egg',
#   'slivered almonds',
#   'splenda granular',
#   'cornstarch',
#   'vanilla',
#   'heavy whipping cream',
#   'cinnamon'],
#  ['smooth peanut butter', 'oil', 'soy sauce', 'chicken pieces', 'ketchup'],
#  ['chicken broth',
#   'dried sage',
#   'parsley',
#   'salt',
#   'breadcrumbs',
#   'butter',
#   'onion',
#   'black pepper',
#   'celery seed',
#   'dried thyme'],
#  ['salt and pepper',
#   'fresh basil',
#   'fresh oregano',
#   'tomato',
#   'olive oil',
#   'garlic'],
#  ['kahlua',
#   'shredded coconut',
#   'water',
#   'bittersweet chocolate',
#   'salt',
#   'instant chocolate pudding mix',
#   "devil's food cake mix",
#   'whipping cream',
#   'egg',
#   'vegetable oil',
#   'cornstarch',
#   'sugar',
#   'coco lopez',
#   'coconut milk'],
#  ['old bay seasoning', 'plain tomato juice'],
#  ['bay leaf',
#   'shallot',
#   'canned unsweetened coconut milk',
#   'carrot',
#   'canned pumpkin',
#   'butter',
#   'onion',
#   'banana',
#   'coriander',
#   'chicken stock',
#   'curry powder',
#   'pumpkin seeds',
#   'ground nutmeg',
#   'sweetened condensed milk',
#   'ground allspice',
#   'garlic',
#   'cinnamon'],
#  ['parmesan cheese',
#   'salt',
#   'zucchini',
#   'tomato',
#   'mayonnaise',
#   'black pepper',
#   'garlic',
#   'whole wheat bread',
#   'ghee'],
#  ['cream cheese',
#   'sausage',
#   'diced tomatoes with green chilies',
#   'diced green chilies'],
#  ['beef broth',
#   'white onion',
#   'chili seasoning mix',
#   'extra lean ground beef',
#   'tomato sauce',
#   'black beans',
#   'red pepper',
#   'chili beans with chipotle pepper',
#   'chilies',
#   'kidney beans',
#   'garlic',
#   'diced tomatoes'],
#  ['baking soda',
#   'carrot',
#   'ground cinnamon',
#   'pineapple chunk',
#   'cream cheese',
#   'pecans',
#   'salt',
#   'butter',
#   'egg',
#   'powdered sugar',
#   'vanilla',
#   'flour',
#   'sugar',
#   'baking powder',
#   'ground nutmeg'],
#  ['butter', 'dried beef', 'flour', 'black pepper', 'milk'],
#  ['water',
#   'carrot',
#   'turnips',
#   'split peas',
#   'salt',
#   'black pepper',
#   'onion',
#   'potato'],
#  ['red onion',
#   'steak spice',
#   'lemon juice',
#   'salad dressing',
#   'hard-boiled eggs',
#   'cooked bacon',
#   'buttermilk',
#   'sour cream',
#   'corn tortilla strips',
#   'cherry tomatoes',
#   'ketchup',
#   'curry powder',
#   'granulated garlic',
#   'roasted garlic and red pepper spice mix',
#   'cumin',
#   'sugar',
#   'romaine lettuce'],
#  ['ground cumin',
#   'white pepper',
#   'cheddar cheese',
#   'worcestershire sauce',
#   'salt',
#   'papaya',
#   'tomato',
#   'mayonnaise',
#   'bibb lettuce',
#   'hamburger buns',
#   'fresh thyme',
#   'cayenne pepper',
#   'onion',
#   'lean ground beef'],
#  ['fat',
#   'baking soda',
#   'salt',
#   'zucchini',
#   'egg',
#   'vanilla',
#   'flour',
#   'sugar',
#   'walnuts',
#   'cinnamon'],
#  ['lime juice',
#   'lemon-flavored vodka',
#   'dry white wine',
#   'lemon juice',
#   'lime',
#   'peach',
#   'peach schnapps',
#   'lemon',
#   'apple',
#   'lemonade',
#   'peach puree'],
#  ['barbecue sauce',
#   'prepared mustard',
#   'salt and pepper',
#   'ground moose',
#   'ketchup',
#   'hot sauce',
#   'brown sugar',
#   'onion'],
#  ['lean ground beef',
#   'dry breadcrumbs',
#   'salt',
#   'soy sauce',
#   'onion',
#   'pineapple chunks',
#   'ketchup',
#   'black pepper',
#   'egg',
#   'white vinegar',
#   'cornstarch',
#   'brown sugar',
#   'garlic',
#   'sweet pepper'],
#  ['chicken wings', 'dark brown sugar', 'soy sauce'],
# ...
#  ['oat bran',
#   'whole wheat flour',
#   'water',
#   'yeast',
#   'salt',
#   'white whole wheat flour',
#   'wheat germ',
#   'egg',
#   'vegetable oil',
#   'sugar',
#   'vital wheat gluten'],
#  ['whole wheat flour',
#   'kosher salt',
#   'yeast',
#   'warm water',
#   'vital wheat gluten'],
#  ['applesauce', 'whole wheat flour', 'water', 'yeast', 'honey', 'salt', 'egg'],
#  ['instant yeast',
#   'whole wheat flour',
#   'water',
#   'honey',
#   'salt',
#   'egg',
#   'canola oil',
#   'vital wheat gluten'],
#  ['whole wheat flour',
#   'baking soda',
#   'salt',
#   'granulated sugar',
#   'egg whites',
#   'canola oil',
#   'flax seed meal',
#   'baking powder',
#   'low-fat buttermilk'],
#  ['whole wheat flour',
#   'water',
#   'baking soda',
#   'honey',
#   'salt',
#   'butter',
#   'turbinado sugar',
#   'vanilla',
#   'baking powder',
#   'cinnamon'],
#  ['whole wheat flour',
#   'baking soda',
#   'salt',
#   'molasses',
#   'butter',
#   'egg',
#   'raisins',
#   'baking powder',
#   'low-fat buttermilk'],
#  ['whole wheat flour',
#   'baking soda',
#   'egg',
#   'low-fat milk',
#   'canola oil',
#   'vanilla',
#   'sugar',
#   'baking powder',
#   'fruit'],
#  ['whole wheat flour',
#   'salt',
#   'butter',
#   'peanut butter',
#   'egg',
#   'brown sugar',
#   'baking powder',
#   'milk'],
#  ['instant yeast', 'whole wheat flour', 'water', 'honey', 'salt', 'olive oil'],
#  ['whole wheat flour', 'water', 'yeast', 'honey', 'salt', 'egg', 'olive oil'],
#  ['whole wheat flour',
#   'gluten',
#   'baking soda',
#   'kosher salt',
#   'sour cream',
#   'butter',
#   'baking powder',
#   'milk'],
#  ['whole wheat flour',
#   'water',
#   'fruit',
#   'oil',
#   'salt',
#   'molasses',
#   'oatmeal',
#   'powdered milk',
#   'powdered eggs',
#   'egg',
#   'vanilla',
#   'raisins',
#   'sugar',
#   'baking powder',
#   'cinnamon',
#   'cocoa powder'],
#  ['whole wheat flour',
#   'baking soda',
#   'salt',
#   'zucchini',
#   'sugar',
#   'egg',
#   'vegetable oil',
#   'vanilla',
#   'nuts',
#   'baking powder',
#   'cinnamon'],
#  ['instant yeast',
#   'whole wheat flour',
#   'water',
#   'honey',
#   'table salt',
#   'cooking oil'],
#  ['baking soda',
#   'butter',
#   'bananas',
#   'sugar',
#   'egg',
#   'vanilla',
#   'flour',
#   'nuts'],
#  ['chocolate cake mix',
#   'caramels',
#   'chocolate chips',
#   'butter',
#   'evaporated milk',
#   'nuts'],
#  ['baking soda',
#   'salt',
#   'bananas',
#   'egg',
#   'canola oil',
#   'flour',
#   'raisins',
#   'sugar',
#   'walnuts'],
#  ['thousand island dressing', 'cream cheese'],
#  ['mayonnaise', 'onion powder', 'chili sauce', 'sweet pickle relish'],
#  ['baking soda',
#   'margarine',
#   'chocolate chips',
#   'oil',
#   'flaked coconut',
#   'cream of tartar',
#   'white sugar',
#   'egg',
#   'rice krispies',
#   'vanilla',
#   'flour',
#   'brown sugar',
#   'rolled oats'],
#  ['white pepper',
#   'plain yogurt',
#   'bacon',
#   'mushrooms',
#   'buttermilk',
#   'baby spinach',
#   'unsalted sunflower seeds',
#   'garlic',
#   'sugar',
#   'fresh lemon juice',
#   'hardboiled egg'],
#  ['bacon',
#   'red onion',
#   'fresh mushrooms',
#   'cauliflower',
#   'cherry tomatoes',
#   'mayonnaise',
#   'frozen peas',
#   'italian seasoning',
#   'lettuce',
#   'sugar',
#   'green pepper',
#   'fresh broccoli'],
#  ['ground oregano',
#   'onion salt',
#   'chili powder',
#   'marjoram leaves',
#   'celery salt',
#   'rubbed sage',
#   'basil leaves',
#   'paprika',
#   'black pepper',
#   'ground allspice',
#   'garlic powder'],
#  ['vodka', 'fresh jalapeno', 'ice', 'beer'],
#  ['low-fat mayonnaise',
#   'parmesan cheese',
#   'bacon',
#   'lemon juice',
#   'worcestershire sauce',
#   'fresh mushrooms',
#   'oil',
#   'dijon mustard',
#   'anchovy fillets',
#   'miracle whip light',
#   'extra virgin olive oil',
#   'baby spinach',
#   'olive oil',
#   'garlic',
#   'french bread'],
#  ['ricotta cheese',
#   'parmesan-romano cheese mix',
#   'italian cheese blend',
#   'parsley flakes',
#   'salt',
#   'mexican blend cheese',
#   'spaghetti sauce',
#   'egg',
#   'mozzarella cheese',
#   'jumbo pasta shells',
#   'ground beef',
#   'ground pepper',
#   'dried italian seasoning'],
#  ['whole wheat flour',
#   'water',
#   'oil',
#   'salt',
#   'white flour',
#   'brown sugar',
#   'bread machine yeast'],
#  ['water',
#   'salt and pepper',
#   'cream-style corn',
#   'whole corn',
#   'butter',
#   'evaporated milk',
#   'onion',
#   'potato'],
#  ['parmesan cheese',
#   'flat leaf parsley',
#   'kosher salt',
#   'extra virgin olive oil',
#   'italian seasoned breadcrumbs',
#   'orecchiette',
#   'black pepper',
#   'prosciutto'],
#  ['fresh ground black pepper', 'salt', 'tomato', 'cumin seeds', 'olive oil'],
#  ['baking soda',
#   'molasses',
#   'butter',
#   'white sugar',
#   'corn syrup',
#   'vanilla',
#   'salted peanuts'],
#  ['plain yogurt',
#   'salt',
#   'bulgar wheat',
#   'onion',
#   'lean ground beef',
#   'cinnamon'],
#  ['yellow cake mix',
#   'water',
#   'instant vanilla pudding',
#   'oil',
#   'apple pie filling',
#   'egg'],
#  ['boneless skinless chicken breasts', 'carrot', 'potato', 'italian dressing'],
#  ['cinnamon rolls', 'egg', 'chocolate milk'],
#  ['salt',
#   'butter',
#   'white sugar',
#   'egg',
#   'vanilla',
#   'flour',
#   'baking powder',
#   'milk'],
#  ['celery',
#   'water',
#   'thyme',
#   'ham',
#   'carrot',
#   'worcestershire sauce',
#   'soup mix',
#   'salt',
#   'leeks',
#   'black pepper',
#   'garlic',
#   'basil'],
#  ['salt and pepper',
#   'bell peppers',
#   'chili sauce',
#   'worcestershire sauce',
#   'saltine crackers',
#   'egg',
#   'milk',
#   'ground beef',
#   'onion',
#   'garlic powder'],
#  ['salt and pepper',
#   'worcestershire sauce',
#   'prepared horseradish',
#   'aluminum foil',
#   'sour cream',
#   'unsalted butter',
#   'beef tenderloin',
#   'limes, juice of',
#   'garlic'],
#  ['baking soda',
#   'carrot',
#   'margarine',
#   'cream cheese',
#   'oil',
#   'salt',
#   'pineapple',
#   'egg',
#   'baking powder',
#   'powdered sugar',
#   'sugar',
#   'flour',
#   'walnuts',
#   'cinnamon'],
#  ['water',
#   'carrot',
#   'salt',
#   'cabbage',
#   'mustard seeds',
#   'sugar',
#   'white vinegar',
#   'turmeric',
#   'onion',
#   'celery seed'],
#  ['pickling cucumbers',
#   'water',
#   'vinegar',
#   'salt',
#   'pickling spices',
#   'alum',
#   'sugar'],
#  ['cucumbers', 'vinegar', 'pickling spices', 'canning salt', 'alum', 'sugar'],
#  ['allspice',
#   'baking soda',
#   'cream cheese',
#   'margarine',
#   'carrot',
#   'oil',
#   'salt',
#   'cinnamon',
#   'ground cloves',
#   'sugar',
#   'egg',
#   'vanilla',
#   'powdered sugar',
#   'raisins',
#   'nuts',
#   'flour',
#   'coconut'],
#  ['maple syrup', 'butter', 'lemon extract', 'cream', 'nutmeats'],
#  ['celery',
#   'chicken broth',
#   'water',
#   'v8 vegetable juice',
#   'carrot',
#   'lemon juice',
#   'salt',
#   'tomato',
#   'chicken bouillon cubes',
#   'deli ham',
#   'onion',
#   'parsley',
#   'raw rice',
#   'beans',
#   'basil'],
#  ['refried beans',
#   'hormel chili without beans',
#   'monterey jack cheese',
#   'tortillas'],
#  ['15 bean soup mix',
#   'salt',
#   'whole tomatoes',
#   'onion',
#   'dried rosemary',
#   'chicken bouillon cubes',
#   'garlic',
#   'ham hocks',
#   'celery leaves',
#   'olive oil',
#   'black pepper',
#   'dried parsley'],
#  ['water',
#   'smoked sausage',
#   '15 bean soup mix',
#   'worcestershire sauce',
#   'beef bouillon paste',
#   'garlic',
#   'ham bone',
#   'black pepper',
#   'diced tomatoes',
#   'steak sauce'],
#  ['lemon',
#   'water',
#   'thyme',
#   'ham',
#   'condensed tomato soup',
#   'carrot',
#   'salt',
#   'chili powder',
#   'oregano',
#   'onion',
#   'paprika',
#   'garlic',
#   'dried beans',
#   'smoked paprika',
#   'cayenne pepper',
#   'olive oil',
#   'black pepper'],
#  ['baking soda',
#   'margarine',
#   'honey',
#   'liquid honey',
#   'sour cream',
#   'ground walnuts',
#   'egg',
#   'flour',
#   'sugar',
#   'plain sweet biscuit crumbs'],
#  ['capers',
#   'salt and pepper',
#   'lemon juice',
#   'halibut steaks',
#   'fresh chives',
#   'chicken stock',
#   'fresh tarragon',
#   'garlic',
#   'fresh parsley'],
#  ['water',
#   'tomato paste',
#   'peas and carrots',
#   'lipton beefy mushroom soup mix',
#   'oil',
#   'boneless sirloin steak',
#   'new potatoes'],
#  ['taco seasoning',
#   'frozen corn kernels',
#   'black beans',
#   'ground beef',
#   'tomatoes and green chilies'],
#  ['water',
#   'cheddar cheese',
#   'ketchup',
#   'mustard',
#   'lean ground beef',
#   'minute white rice'],
#  ['water',
#   'chili with beans',
#   'ground beef',
#   'velveeta cheese',
#   'diced tomatoes',
#   'white rice'],
#  ['water',
#   'condensed cream of chicken soup',
#   'boneless skinless chicken breast halves',
#   'instant rice',
#   'paprika',
#   'vegetable oil',
#   'ground pepper'],
#  ['cheese',
#   'sour cream',
#   'onion',
#   'tortilla',
#   'lime',
#   'fajita seasoning mix',
#   'pico de gallo',
#   'chicken breast tenders',
#   'olive oil',
#   'black pepper'],
#  ['chicken broth',
#   'cheddar cheese',
#   'salsa',
#   'mexicorn',
#   'sour cream',
#   'chicken',
#   'tortilla chips',
#   'kidney beans'],
#  ['broccoli florets',
#   'minute rice',
#   'vegetable oil',
#   'condensed cream of chicken soup',
#   'boneless skinless chicken breasts',
#   'milk'],
#  ['ground turkey',
#   'salsa',
#   'stewed tomatoes',
#   'salt',
#   'chili powder',
#   'pinto beans',
#   'cumin',
#   'kidney beans',
#   'onion'],
#  ['flour tortillas',
#   'water',
#   'cheese',
#   'sour cream',
#   'white minute rice',
#   'chili with beans'],
#  ['broccoli',
#   'water',
#   'macaroni & cheese dinner mix',
#   'chili powder',
#   'ketchup',
#   'lean ground beef'],
#  ['clove',
#   'allspice',
#   'salt',
#   'tomato',
#   'onion',
#   'brown sugar',
#   'black pepper',
#   'cinnamon'],
#  ['grape tomatoes',
#   'fresh parmesan cheese',
#   'fresh basil',
#   'fresh oregano',
#   'sun-dried tomato packed in oil',
#   'crushed red pepper flakes',
#   'pappardelle pasta',
#   'black pepper',
#   'roasted cashews',
#   'garlic'],
#  ['ground cumin',
#   'low sodium chicken broth',
#   'tomato sauce',
#   'chipotle chile in adobo',
#   'salt',
#   'ground coriander',
#   'onion',
#   'garlic'],
#  ['reduced fat graham cracker crust',
#   'fat-free whipped topping',
#   'fat free cream cheese',
#   'sugar substitute'],
#  ['pine nuts',
#   'parmesan cheese',
#   'red onion',
#   'pesto sauce',
#   'lemon juice',
#   'tomato',
#   'fresh linguine',
#   'fresh spinach'],
#  ['chicken broth',
#   'salt and pepper',
#   'lemon juice',
#   'oil',
#   'boneless skinless chicken breast halves',
#   'butter',
#   'flour',
#   'garlic'],
#  ['romaine lettuce',
#   'salt',
#   'feta cheese',
#   'tomato',
#   'of fresh mint',
#   'celery ribs',
#   'scallion',
#   'extra virgin olive oil',
#   'fresh lemon juice',
#   'garbanzo beans',
#   'garlic',
#   'fresh parsley',
#   'cracked black pepper'],
#  ['assorted fresh vegetables',
#   'boneless skinless chicken breast',
#   'oil',
#   'instant rice',
#   'reduced-sodium fat-free chicken broth',
#   'italian dressing'],
#  ['instant lemon pudding',
#   'graham cracker crumbs',
#   'cream cheese',
#   'butter',
#   'powdered sugar',
#   'milk'],
#  ['butter', "confectioners' sugar", 'cocoa', 'vanilla', 'peanut butter'],
#  ['parmesan cheese',
#   'spaghetti',
#   'tomato',
#   'italian salad dressing',
#   'smoked turkey breast'],
#  ['frozen mixed vegetables',
#   'water',
#   'oil',
#   'pork tenderloin',
#   'minute rice',
#   'soy sauce',
#   'chicken bouillon cube'],
#  ['water',
#   'oil',
#   'chicken bouillon cubes',
#   'kidney beans',
#   'onion',
#   'green pepper',
#   'hot pepper sauce',
#   'minute white rice'],
#  ['baby peas',
#   'parmesan cheese',
#   'garlic salt',
#   'fettuccine',
#   'bacon bits',
#   'half-and-half cream',
#   'shrimp',
#   'black pepper'],
#  ['salt & pepper',
#   'frozen shrimp',
#   'butter',
#   'onion',
#   'white wine',
#   'extra virgin olive oil',
#   'garlic',
#   'angel hair pasta'],
#  ['celery',
#   'garlic flakes',
#   'sliced mushrooms',
#   'hamburger',
#   'sweet red pepper',
#   'hot chili flakes',
#   'onion',
#   'jalapenos',
#   'tomato sauce & mushrooms',
#   'sweet green pepper'],
#  ['chicken broth',
#   'white pepper',
#   'chili flakes',
#   'fresh ginger',
#   'salt',
#   'rice vinegar',
#   'soy sauce',
#   'onion',
#   'asparagus',
#   'garlic',
#   'boneless skinless chicken breast'],
#  ['half-and-half',
#   'fresh ground black pepper',
#   'elbow macaroni',
#   'kosher salt',
#   'dijon mustard',
#   'unsalted butter',
#   'extra-sharp cheddar cheese',
#   'hot sauce'],
#  ['water',
#   'fresh mushrooms',
#   'round steak',
#   'sour cream',
#   'butter',
#   'dry onion soup mix',
#   'flour'],
#  ['water',
#   'extra lean ground beef',
#   'mexican blend cheese',
#   'taco seasoning mix',
#   'chopped tomatoes',
#   'lettuce',
#   'minute white rice'],
#  ['tiger shrimp',
#   'water',
#   'thai fish sauce',
#   'dark soy sauce',
#   'sweet chili sauce',
#   'baby spinach',
#   'pak choi',
#   'sunflower oil',
#   'lime, juice and zest of',
#   'cornflour'],
#  ['raisins', 'vanilla instant pudding mix', 'minute rice', 'milk'],
#  ['water', 'salsa', 'black beans', 'kidney beans', 'fire-roasted tomatoes'],
#  ['parmesan cheese', 'cream cheese', 'margarine', 'fettuccine pasta', 'milk'],
#  ['water',
#   'honey',
#   'salt',
#   'milk',
#   'dried fruits',
#   'vanilla',
#   'sugar',
#   'quick oats'],
#  ['celery',
#   'water',
#   'bay leaves',
#   'carrot',
#   'tomato sauce',
#   '15 bean mix',
#   'black pepper',
#   'chicken bouillon cubes',
#   'garlic',
#   'ham hocks',
#   'seasoning salt',
#   'onion',
#   'diced tomatoes'],
#  ['water',
#   'salt and pepper',
#   'chili seasoning mix',
#   'sharp cheddar cheese',
#   'black-eyed peas',
#   'corn chips',
#   'red pepper flakes',
#   'whole tomatoes',
#   'ketchup',
#   'vegetable oil',
#   'dark red kidney beans',
#   'ground beef',
#   'onion',
#   'canned green beans',
#   'green bell pepper'],
#  ['brandy',
#   'thyme',
#   'salt',
#   'marjoram',
#   'butter',
#   'onion',
#   'heavy cream',
#   'chicken liver',
#   'sage',
#   'ground black pepper',
#   'garlic'],
#  ['chili beans',
#   'salt',
#   'sliced mushrooms',
#   'sour cream',
#   'chili powder',
#   'oregano',
#   'cayenne pepper',
#   'cumin',
#   'onion',
#   'diced tomatoes',
#   'lean ground beef'],
#  ['strawberries',
#   'cool whip topping',
#   'strawberry',
#   'orange liqueur',
#   'white chocolate baking squares',
#   'frozen pound cake',
#   'jello instant vanilla pudding mix',
#   'sugar'],
#  ['worcestershire sauce',
#   'boneless skinless chicken breast halves',
#   'dijon mustard',
#   'dried tarragon',
#   'black pepper',
#   'fresh lemon juice'],
#  ['basmati rice', 'chicken broth', 'salt and pepper'],
#  ['green enchilada sauce',
#   'cooked chicken',
#   'salsa',
#   'cream of chicken soup',
#   'sour cream',
#   'tomato',
#   'tortilla chips',
#   'lettuce',
#   'monterey jack cheese',
#   'black olives',
#   'green onion'],
#  ['pasta', 'garlic', 'parmesan cheese', 'butter'],
#  ['large shrimp',
#   'dried oregano',
#   'old bay seasoning',
#   'feta cheese',
#   'tomato',
#   'black pepper',
#   'olive oil',
#   'garlic',
#   'parsley'],
#  ['large shrimp',
#   'lemon, zest of',
#   'red onion',
#   'herbs',
#   'snap peas',
#   'zucchini',
#   'cherry tomatoes',
#   'unsalted butter',
#   'corn kernels',
#   'olive oil',
#   'salt & freshly ground black pepper'],
#  ['dried oregano',
#   'parmesan cheese',
#   'salt and pepper',
#   'white beans',
#   'scallions',
#   'vegetable broth',
#   'olive oil',
#   'garlic',
#   'fresh lemon juice'],
#  ['celery',
#   'water',
#   'bay leaves',
#   'carrot',
#   'tomato',
#   'oregano',
#   'onion',
#   'chicken stock',
#   'italian sausage',
#   'garlic',
#   'beans'],
#  ['cucumbers',
#   'pickling spices',
#   'alum',
#   'cinnamon sticks',
#   'white vinegar',
#   'pickling salt',
#   'sugar'],
#  ['onion', 'barbecue sauce', 'pork butt', 'ginger ale'],
#  ['dark molasses',
#   'strong coffee',
#   'vodka',
#   'vanilla bean',
#   'brown sugar',
#   'sugar',
#   'cold water'],
#  ['celery',
#   'chicken broth',
#   'frozen white corn',
#   'frozen corn',
#   'carrot',
#   'whole chickens',
#   'celery ribs',
#   'chicken bouillon cubes',
#   'onion',
#   'potato'],
#  ['oregano leaves',
#   'fennel seed',
#   'low-carb marinara sauce',
#   'fat-free parmesan cheese',
#   'lean ground turkey',
#   'nonstick cooking spray',
#   'eggplant',
#   'basil'],
#  ['mountain dew soda', 'raspberry vodka'],
#  ['red wine vinegar',
#   'shallots',
#   'salt and pepper',
#   'red onion',
#   'apple cider',
#   'white cheddar cheese',
#   'tart apples',
#   'dijon mustard',
#   'white vinegar',
#   'sherry wine vinegar',
#   'fresh thyme',
#   'arugula',
#   'olive oil',
#   'gouda cheese',
#   'pancetta'],
#  ['baby carrots',
#   'pumpkin pie spice',
#   'baking soda',
#   'salt',
#   'marshmallow cream',
#   'unsalted butter',
#   "confectioners' sugar",
#   'egg',
#   'vegetable oil',
#   'baking powder',
#   'pure vanilla extract',
#   'light brown sugar',
#   'flour'],
#  ['clove',
#   'baking soda',
#   'salt',
#   'buttermilk',
#   'cinnamon',
#   'butter',
#   'egg',
#   'cocoa',
#   'vanilla',
#   'flour',
#   'sugar',
#   'nutmeg'],
#  ['sweet cream',
#   'almonds',
#   'cream of tartar',
#   'egg yolks',
#   'egg',
#   'cornstarch',
#   'powdered sugar',
#   'sugar',
#   'flour',
#   'milk'],
#  ...]

# %% [markdown]
# We'll use the [`Word2Vec`](https://radimrehurek.com/gensim/models/word2vec.html) implementation in the `gensim` library (i.e., *deep learning*) to train an embedding model.
# This approach tends to work best if the training data has at least 100K rows.
# NB: work in progress will replace `gensim` with `pytorch` instead.

# %%
import gensim

MIN_COUNT = 2
model_path = "tmp.w2v"

model = gensim.models.Word2Vec(vectors, min_count=MIN_COUNT, window=max_context)
model.save(model_path)

# %% [markdown]
# The `get_related()` function takes any ingredient as input, using the embedding model to find the most similar other ingredients – along with calculating [`levenshtein`](https://github.com/toastdriven/pylev) edit distances (string similarity) among these labels. Then it calculates *percentiles* for both metrics in [`numpy`](https://numpy.org/) and returns the results as a [`pandas`](https://pandas.pydata.org/) DataFrame.

# %%
import numpy as np
import pandas as pd
import pylev

def get_related (model, query, n=20, granularity=100):
    """return a DataFrame of the closely related items"""
    try:
        bins = np.linspace(0, 1, num=granularity, endpoint=True)

        v = sorted(
            model.wv.most_similar(positive=[query], topn=n), 
            key=lambda x: x[1], 
            reverse=True
        )
        
        df = pd.DataFrame(v, columns=["ingredient", "similarity"])
        
        s = df["similarity"]
        quantiles = s.quantile(bins, interpolation="nearest")
        df["sim_pct"] = np.digitize(s, quantiles) - 1
        
        df["levenshtein"] = [ pylev.levenshtein(d, query) / len(query) for d in df["ingredient"] ]
        s = df["levenshtein"]
        quantiles = s.quantile(bins, interpolation="nearest")
        df["lev_pct"] = granularity - np.digitize(s, quantiles)

        return df
    except KeyError:
        return pd.DataFrame(columns=["ingredient", "similarity", "percentile"])

# %% [markdown]
# Let's try this with `dried basil` as the ingredient to query, and review the top `50` most similar other ingredients returned as the DataFrame `df`:

# %%
df = get_related(model, "dried basil", n=50)
df
# Out:
#                       ingredient  similarity  sim_pct  levenshtein  lev_pct
# 0             dried basil leaves    0.655597       99     0.636364       78
# 1                      dry basil    0.642322       97     0.272727       98
# 2                 dried rosemary    0.607788       95     0.636364       78
# 3                    fresh basil    0.581144       93     0.363636       96
# 4                  dried parsley    0.580861       91     0.454545       90
# 5        dried italian seasoning    0.571377       89     1.272727       24
# 6       dried sweet basil leaves    0.565162       87     1.181818       30
# 7                 dried marjoram    0.554404       85     0.636364       78
# 8              italian seasoning    0.516789       83     1.090909       40
# 9          dried rosemary leaves    0.512254       81     1.181818       30
# 10          dried parsley flakes    0.503559       79     1.000000       54
# 11        italian herb seasoning    0.503113       77     1.454545       16
# 12         italian seasoning mix    0.492832       75     1.454545       16
# 13            fresh basil leaves    0.471349       73     1.000000       54
# 14                   dry oregano    0.470866       71     0.818182       72
# 15                         basil    0.467459       69     0.545455       88
# 16      cooked small shell pasta    0.464186       67     1.636364        8
# 17                   dried thyme    0.459397       65     0.454545       90
# 18                 parmesan rind    0.456412       63     0.909091       66
# 19                italian spices    0.455442       61     1.090909       40
# 20          mild italian sausage    0.455043       59     1.363636       22
# 21      contadina diced tomatoes    0.454260       57     1.636364        8
# 22   part-skim mozzarella cheese    0.449376       55     2.090909        0
# 23               lasagna noodles    0.447548       53     1.181818       30
# 24             dried whole thyme    0.445773       51     1.000000       54
# 25        italian turkey sausage    0.443080       49     1.545455       14
# 26              cooked spaghetti    0.441865       47     1.090909       40
# 27        italian-style tomatoes    0.440036       45     1.727273        6
# 28         whole wheat spaghetti    0.438329       43     1.636364        8
# 29              artichoke hearts    0.436780       41     1.090909       40
# 30                    orzo pasta    0.436590       39     0.636364       78
# 31             hot pepper flakes    0.435463       37     1.272727       24
# 32              fresh basil leaf    0.434169       35     0.818182       72
# 33              italian sausages    0.432996       33     1.090909       40
# 34            dried thyme leaves    0.432500       31     1.000000       54
# 35            white kidney beans    0.430611       29     1.181818       30
# 36               italian sausage    0.429958       27     1.000000       54
# 37                  dried fennel    0.427508       25     0.454545       90
# 38           canned tomato sauce    0.426360       23     1.272727       24
# 39               fresh mushrooms    0.425812       21     1.090909       40
# 40       fat-free ricotta cheese    0.425650       19     1.818182        4
# 41                   stock cubes    0.423456       17     0.909091       66
# 42  italian-style diced tomatoes    0.423372       15     2.090909        0
# 43       dried red pepper flakes    0.422969       13     1.454545       16
# 44              sliced mushrooms    0.422841       11     1.000000       54
# 45           pitted black olives    0.421125        9     1.181818       30
# 46                   bread bowls    0.420395        7     0.636364       78
# 47                   dry lentils    0.419797        5     0.727273       76
# 48                 oregano sprig    0.419636        3     0.909091       66
# 49                 romano cheese    0.419544        1     1.090909       40

# %% [markdown]
# Note how some of the most similar items, based on vector embedding, are *synonyms* or special forms of our query `dried basil` ingredient: `dried basil leaves`, `dry basil`, `dried sweet basil leaves`, etc. These tend to rank high in terms of levenshtein distance too.

# %% [markdown]
# Let's plot the similarity measures:

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use("ggplot")

df["similarity"].plot(alpha=0.75, rot=0)
plt.show()

# %% [markdown]
# Notice the inflection points at approximately `0.57` and again at `0.47` in that plot.
# We could use some statistical techniques (e.g., clustering) to segment the similarities into a few groups:
#
#   * potential synonyms for the query
#   * potential [hypernyms and hyponyms](https://en.wikipedia.org/wiki/Hyponymy_and_hypernymy) for the query
#   * other ingredients that pair well with the query

# %% [markdown]
# In this example, below a threshold of the 75th percentile for vector embedding similarity, the related ingredients are less about being synonyms and more about other foods that pair well with basil.
#
# Let's define another function `rank_related()` which ranks the related ingredients based on a combination of these two metrics.
# This uses a cheap approximation of a [*pareto archive*](https://www.cs.bham.ac.uk/~jdk/multi/) for the ranking -- which comes in handing for recommender systems and custom search applications that must combine multiple ranking metrics:

# %%
import math

def rms (values):
    """calculate root mean square"""
    numer = sum([x for x in map(lambda x: float(x)**2.0, values)])
    denom = float(len(values))
    return math.sqrt(numer / denom)

def rank_related (df):
    df2 = df.copy(deep=True)
    df2["related"] = df2.apply(lambda row: rms([row[2], row[4]]), axis=1)
    return df2.sort_values(by=["related"], ascending=False)

# %%
rank_related(df)
# Out:
#                       ingredient  similarity  sim_pct  levenshtein  lev_pct  \
# 1                      dry basil    0.642322       97     0.272727       98
# 3                    fresh basil    0.581144       93     0.363636       96
# 4                  dried parsley    0.580861       91     0.454545       90
# 0             dried basil leaves    0.655597       99     0.636364       78
# 2                 dried rosemary    0.607788       95     0.636364       78
# 7                 dried marjoram    0.554404       85     0.636364       78
# 15                         basil    0.467459       69     0.545455       88
# 17                   dried thyme    0.459397       65     0.454545       90
# 14                   dry oregano    0.470866       71     0.818182       72
# 10          dried parsley flakes    0.503559       79     1.000000       54
# 37                  dried fennel    0.427508       25     0.454545       90
# 5        dried italian seasoning    0.571377       89     1.272727       24
# 8              italian seasoning    0.516789       83     1.090909       40
# 6       dried sweet basil leaves    0.565162       87     1.181818       30
# 18                 parmesan rind    0.456412       63     0.909091       66
# 13            fresh basil leaves    0.471349       73     1.000000       54
# 30                    orzo pasta    0.436590       39     0.636364       78
# 9          dried rosemary leaves    0.512254       81     1.181818       30
# 32              fresh basil leaf    0.434169       35     0.818182       72
# 11        italian herb seasoning    0.503113       77     1.454545       16
# 46                   bread bowls    0.420395        7     0.636364       78
# 12         italian seasoning mix    0.492832       75     1.454545       16
# 47                   dry lentils    0.419797        5     0.727273       76
# 24             dried whole thyme    0.445773       51     1.000000       54
# 19                italian spices    0.455442       61     1.090909       40
# 41                   stock cubes    0.423456       17     0.909091       66
# 16      cooked small shell pasta    0.464186       67     1.636364        8
# 48                 oregano sprig    0.419636        3     0.909091       66
# 20          mild italian sausage    0.455043       59     1.363636       22
# 34            dried thyme leaves    0.432500       31     1.000000       54
# 26              cooked spaghetti    0.441865       47     1.090909       40
# 23               lasagna noodles    0.447548       53     1.181818       30
# 36               italian sausage    0.429958       27     1.000000       54
# 21      contadina diced tomatoes    0.454260       57     1.636364        8
# 29              artichoke hearts    0.436780       41     1.090909       40
# 44              sliced mushrooms    0.422841       11     1.000000       54
# 22   part-skim mozzarella cheese    0.449376       55     2.090909        0
# 33              italian sausages    0.432996       33     1.090909       40
# 25        italian turkey sausage    0.443080       49     1.545455       14
# 27        italian-style tomatoes    0.440036       45     1.727273        6
# 39               fresh mushrooms    0.425812       21     1.090909       40
# 31             hot pepper flakes    0.435463       37     1.272727       24
# 28         whole wheat spaghetti    0.438329       43     1.636364        8
# 35            white kidney beans    0.430611       29     1.181818       30
# 49                 romano cheese    0.419544        1     1.090909       40
# 38           canned tomato sauce    0.426360       23     1.272727       24
# 45           pitted black olives    0.421125        9     1.181818       30
# 43       dried red pepper flakes    0.422969       13     1.454545       16
# 40       fat-free ricotta cheese    0.425650       19     1.818182        4
# 42  italian-style diced tomatoes    0.423372       15     2.090909        0
#
#       related
# 1   97.501282
# 3   94.511904
# 4   90.501381
# 0   89.120705
# 2   86.916627
# 7   81.575119
# 15  79.072751
# 17  78.501592
# 14  71.501748
# 10  67.664614
# 37  66.049224
# 5   65.180519
# 8   65.149827
# 6   65.073036
# 18  64.517440
# 13  64.206697
# 30  61.664414
# 9   61.077819
# 32  56.608303
# 11  55.610251
# 46  55.375988
# 12  54.226377
# 47  53.856290
# 24  52.521424
# 19  51.580035
# 41  48.192323
# 16  47.712682
# 48  46.717235
# 20  44.525274
# 34  44.028400
# 26  43.640577
# 23  43.063906
# 36  42.690748
# 21  40.700123
# 29  40.503086
# 44  38.967936
# 22  38.890873
# 33  36.667424
# 25  36.034705
# 27  32.101402
# 39  31.945266
# 31  31.184932
# 28  30.927334
# 35  29.504237
# 49  28.293109
# 38  23.505319
# 45  22.147235
# 43  14.577380
# 40  13.729530
# 42  10.606602

# %% [markdown]
# Notice how the "synonym" cases tend to move up to the top now?
# Meanwhile while the "pairs well with" are in the lower half of the ranked list: `fresh mushrooms`, `italian turkey sausage`, `cooked spaghetti`, `white kidney beans`, etc.

# %% [markdown]
# ---
#
# ## Exercises

# %% [markdown]
# **Exercise 1:**
#
# Build a report for a *human-in-the-loop* reviewer, using the `rank_related()` function while iterating over `vocab` to make algorithmic suggestions for possible synonyms.

# %% [markdown]
# **Exercise 2:**
#
# How would you make algorithmic suggestions for a reviewer about which ingredients could be related to a query, e.g., using the `skos:broader` and `skos:narrower` relations in the [`skos`](https://www.w3.org/2004/02/skos/) vocabulary to represent *hypernyms* and *hyponyms* respectively?
# This could extend the KG to provide a kind of thesaurus about recipe ingredients.
