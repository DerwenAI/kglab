# %% [markdown]
# # Vector embedding with `gensim`
#
# Let's make use of deep learning through a technique called *embedding* -- to analyze the relatedness of the labels used for recipe ingredients.
#
# Among the most closely related ingredients:
#
#   * Some are very close synonyms and should be consolidated to improve data quality
#   * Others are interesting other ingredients that pair frequently, useful for recommendations
#
# On the one hand, this approach is quite helpful for analyzing the NLP annotations that go into a knowledge graph.
# On the other hand it can be used along with [`SKOS`](https://www.w3.org/2004/02/skos/) or similar vocabularies for ontology-based discovery within the graph, e.g., for advanced search UI.

# %% [markdown]
# ## Curating annotations
#
# We'll be working with the labels for ingredients that go into our KG.
# Looking at the raw data, there are many cases where slightly different spellings are being used for the same entity.
#
# As a first step let's define a list of synonyms to substitute, prior to running the vector embedding.
# This will help produce better quality results.
#
# Note that this kind of work comes of the general heading of *curating annotations* ... which is what we spend so much time doing in KG work.
# It's similar to how *data preparation* is ~80% of the workload for data science teams, and for good reason.

# %%
SYNONYMS = {
    "egg": "egg",
    "eggs": "egg",

    "vanilla": "vanilla",
    "vanilla extract": "vanilla",

    "onions": "onion",
    "onion": "onion",
        
    "carrots": "carrot",
    "carrot": "carrot",

    "potatoes": "potato",
    "potato": "potato",
    
    "tomatoes": "tomato",
    "fresh tomatoes": "tomato",
    "fresh tomato": "tomato",
    
    "garlic": "garlic",
    "garlic clove": "garlic",
    "garlic cloves": "garlic",
}

# %% [markdown]
# ## Analyze ingredient labels from 250K recipes

# %%
import csv

MAX_ROW = 250000 # 231638

max_context = 0
min_context = 1000

recipes = []
vocab = set()

with open("dat/all_ind.csv", "r") as f:
    reader = csv.reader(f)
    next(reader, None) # remove file header

    for i, row in enumerate(reader):
        id = row[0]
        ind_set = set()
        
        # substitute synonyms
        for ind in set(eval(row[1])):
            if ind in SYNONYMS:
                ind_set.add(SYNONYMS[ind])
            else:
                ind_set.add(ind)
        
        if len(ind_set) > 1:
            recipes.append([id, ind_set])
            vocab.update(ind_set)
        
            max_context = max(max_context, len(ind_set))
            min_context = min(min_context, len(ind_set))

        if i > MAX_ROW:
            break

print("max context: {} unique ingredients per recipe".format(max_context))
print("min context: {} unique ingredients per recipe".format(min_context))
print("vocab size", len(list(vocab)))
# Out:
# max context: 43 unique ingredients per recipe
# min context: 2 unique ingredients per recipe
# vocab size 14933

# %%
recipes
# Out:
# [['137739',
#   {'butter',
#    'honey',
#    'mexican seasoning',
#    'mixed spice',
#    'olive oil',
#    'salt',
#    'winter squash'}],
#  ['31490',
#   {'cheese',
#    'egg',
#    'milk',
#    'prepared pizza crust',
#    'salt and pepper',
#    'sausage patty'}],
#  ['112140',
#   {'cheddar cheese',
#    'chili powder',
#    'diced tomatoes',
#    'ground beef',
#    'ground cumin',
#    'kidney beans',
#    'lettuce',
#    'rotel tomatoes',
#    'salt',
#    'tomato paste',
#    'tomato soup',
#    'water',
#    'yellow onions'}],
#  ['59389',
#   {'new potatoes',
#    'olive oil',
#    'parsley',
#    'pepper',
#    'red bell pepper',
#    'red wine vinegar',
#    'salt',
#    'shallots',
#    'spreadable cheese with garlic and herbs',
#    'tarragon',
#    'yellow bell pepper'}],
#  ['44061',
#   {'apple cider vinegar',
#    'cinnamon oil',
#    'clove oil',
#    'dry mustard',
#    'pepper',
#    'salt',
#    'sugar',
#    'tomato juice'}],
#  ['5289',
#   {'apple', 'frozen apple juice concentrate', 'milk', 'vanilla ice cream'}],
#  ['25274',
#   {'extra virgin olive oil',
#    'fennel seeds',
#    'garlic',
#    'green olives',
#    'orange juice',
#    'orange rind',
#    'peppercorn',
#    'red chile',
#    'ripe olives'}],
#  ['67888',
#   {'a.1. original sauce',
#    'brown sugar',
#    'chili powder',
#    'cinnamon sticks',
#    'cracked black pepper',
#    'cumin',
#    'dry mustard',
#    'fresh cilantro leaves',
#    'fresh coarse ground black pepper',
#    'fresh garlic',
#    'fresh ginger',
#    'honey',
#    'liquid smoke',
#    'mirin',
#    'orange, juice of',
#    'pork spareribs',
#    'salt',
#    'soy sauce',
#    'tomato sauce',
#    'water',
#    'white vinegar',
#    'yellow onion'}],
#  ['70971',
#   {'bananas',
#    'chocolate sandwich style cookies',
#    'chocolate syrup',
#    'strawberry ice cream',
#    'vanilla ice cream',
#    'whipped cream'}],
#  ['75452',
#   {'baking soda',
#    'bananas',
#    'cake flour',
#    'egg',
#    'fresh lemon juice',
#    'orange rind',
#    'salt',
#    'sugar',
#    'unsalted butter'}],
#  ['109439',
#   {'prepared horseradish', 'sour cream', 'whole berry cranberry sauce'}],
#  ['42198',
#   {'butter',
#    'egg',
#    'powdered sugar',
#    'strawberry',
#    'vanilla wafers',
#    'walnuts',
#    'whipping cream'}],
#  ['67547',
#   {'bacon',
#    'black pepper',
#    'chicken bouillon cubes',
#    'chili powder',
#    'cornstarch',
#    'dark brown sugar',
#    'garlic powder',
#    'great northern bean',
#    'molasses',
#    'mustard powder',
#    'onion',
#    'salt',
#    'water'}],
#  ['107517',
#   {'brown sugar',
#    'collard greens',
#    'ham hock',
#    'hot sauce',
#    'molasses',
#    'salt',
#    'whiskey'}],
#  ['39959',
#   {'burnet root',
#    'gentian root',
#    'scullcap herb',
#    'spearmint',
#    'wood bethony'}],
#  ['63986',
#   {'chicken rice soup',
#    'dry mustard',
#    'flour',
#    'garlic powder',
#    'lean pork chops',
#    'oil',
#    'salt'}],
#  ['43026',
#   {'cheese', 'cornstarch', 'egg roll wrap', 'oil', 'whole green chilies'}],
#  ['23933', {'butterscotch chips', 'chinese noodles', 'salted peanuts'}],
#  ['8559',
#   {'beef broth',
#    'celery',
#    'cooking oil',
#    'ground pork',
#    'hamburger buns',
#    'onion',
#    'soy sauce'}],
#  ['23850',
#   {'broccoli floret',
#    'canola oil',
#    'cauliflower',
#    'escarole',
#    'fresh herb',
#    'garlic',
#    'great northern bean',
#    'green peas',
#    'ground coriander',
#    'onion',
#    'potato',
#    'red bell pepper',
#    'salt and pepper',
#    'salt free herb and spice seasoning mix',
#    'vegetable bouillon cubes',
#    'water'}],
#  ['76808',
#   {'boiling potatoes',
#    'coarse salt',
#    'fresh ground black pepper',
#    'fresh spinach leaves',
#    'nutmeg',
#    'salt',
#    'unsalted butter',
#    'water'}],
#  ['24701',
#   {'apple juice',
#    'broth',
#    'celery',
#    'dried thyme',
#    'fresh parsley',
#    'olive oil',
#    'onion',
#    'rolled oats',
#    'salt',
#    'scallion',
#    'spinach',
#    'white pepper'}],
#  ['83873',
#   {'all-purpose flour',
#    'boneless skinless chicken breast halves',
#    'condensed cream of chicken soup',
#    'cornstarch',
#    'egg',
#    'garlic powder',
#    'oil',
#    'paprika',
#    'salt and pepper',
#    'seasoning salt'}],
#  ['107699',
#   {'all-purpose flour',
#    'baking powder',
#    'bread',
#    'brown sugar',
#    'butter',
#    'egg',
#    'granulated sugar',
#    'ground cinnamon',
#    'milk',
#    'powdered sugar',
#    'salt',
#    'vanilla',
#    'vegetable oil'}],
#  ['49262', {'butter', 'egg yolks', 'lemon, juice of', 'salt', 'white pepper'}],
#  ['48156',
#   {'black cumin',
#    'ground black pepper',
#    'ground coriander',
#    'ground cumin',
#    'ground ginger',
#    'ground turmeric'}],
#  ['54272',
#   {'black pepper',
#    'celery',
#    'chili powder',
#    'diced tomatoes',
#    'garlic',
#    'green pepper',
#    'jalapenos',
#    'kidney beans',
#    'onion',
#    'red pepper flakes',
#    'salt',
#    'vegetarian ground beef'}],
#  ['47366',
#   {'beef bouillon cube',
#    'beef stew meat',
#    'cabbage',
#    'dried parsley',
#    'elbow macaroni',
#    'garbanzo beans',
#    'ground pepper',
#    'ground thyme',
#    'onion',
#    'parmesan cheese',
#    'salt',
#    'tomato',
#    'water',
#    'zucchini'}],
#  ['37073', {'margarine', 'red potatoes', 'rosemary'}],
#  ['44123',
#   {'black beans',
#    'broccoli floret',
#    'broccoli stem',
#    'carrot',
#    'celery',
#    'chicken stock',
#    'cornstarch',
#    'dried oregano',
#    'dried sweet basil leaves',
#    'dried thyme',
#    'dry white wine',
#    'heavy cream',
#    'onion',
#    'salt & fresh ground pepper',
#    'smoked chicken',
#    'tabasco sauce',
#    'unsalted butter',
#    'worcestershire sauce'}],
#  ['27087',
#   {'all-purpose flour',
#    'baking cocoa',
#    'baking powder',
#    'butter',
#    'egg',
#    'miniature peppermint patties',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['59952',
#   {'cheddar cheese',
#    'cornmeal',
#    'ground beef',
#    'hot chili pepper',
#    'onion',
#    'pepper',
#    'salt',
#    'sliced ripe olives',
#    'tabasco sauce',
#    'taco sauce',
#    'tomato sauce',
#    'whole kernel corn'}],
#  ['93249', {'butter', 'dry ranch dressing mix', 'french bread'}],
#  ['54100',
#   {'black pepper',
#    'dry mustard',
#    'egg substitute',
#    'fresh breadcrumb',
#    'ground venison',
#    'non-fat powdered milk',
#    'onion',
#    'salt',
#    'water',
#    'worcestershire sauce'}],
#  ['67664', {'frozen juice concentrate', 'milk', 'plain yogurt'}],
#  ['87098',
#   {'carrot',
#    'corn',
#    'diced tomatoes',
#    'green beans',
#    'low sodium chicken broth',
#    'potato',
#    'wax beans',
#    'zucchini'}],
#  ['25775',
#   {'black pepper',
#    'condensed cream of mushroom soup',
#    'crouton',
#    'egg',
#    'frozen chopped spinach',
#    'onion',
#    'salt',
#    'sharp cheddar cheese'}],
#  ['33165',
#   {'celery seed',
#    'diced pimentos',
#    'fat-free mayonnaise',
#    'garlic',
#    'green onion',
#    'low-fat sour cream',
#    'pepper',
#    'plain low-fat yogurt',
#    'prepared mustard',
#    'red potatoes',
#    'salt',
#    'sugar',
#    'white wine vinegar'}],
#  ['38798',
#   {'egg',
#    'frozen chopped spinach',
#    'garlic powder',
#    'margarine',
#    'onion',
#    'oregano',
#    'sage',
#    'soft breadcrumbs'}],
#  ['22123',
#   {'condensed cream of mushroom & garlic soup',
#    'cooking oil',
#    'cornbread mix',
#    'cream of mushroom soup',
#    'frozen vegetables',
#    'ground beef',
#    'onion',
#    'salt & pepper'}],
#  ['90921',
#   {'angel hair pasta',
#    'garlic',
#    'green onions',
#    'honey',
#    'soy sauce',
#    'stir fry vegetables',
#    'toasted sesame oil',
#    'toasted sesame seeds'}],
#  ['93959',
#   {'all-purpose flour',
#    'baking powder',
#    'baking soda',
#    'brown sugar',
#    'buckwheat flour',
#    'butter',
#    'canola oil',
#    'cinnamon',
#    'egg',
#    'flour',
#    'ground cinnamon',
#    'ground cloves',
#    'honey',
#    'low-fat buttermilk',
#    'orange juice',
#    'orange rind',
#    'pecans',
#    'salt',
#    'sugar',
#    'unsweetened cocoa',
#    'yam'}],
#  ['93958',
#   {'all-purpose flour',
#    'baking powder',
#    'baking soda',
#    'boiling water',
#    'buckwheat flour',
#    'canola oil',
#    'egg',
#    'granulated sugar',
#    'ground cinnamon',
#    'ground cloves',
#    'low-fat buttermilk',
#    'orange juice',
#    'orange rind',
#    'raisins',
#    'salt',
#    'sorghum',
#    'unsweetened cocoa',
#    'yam'}],
#  ['58224',
#   {'american cheese',
#    'beer',
#    'cayenne',
#    'garlic',
#    'ground beef',
#    'prepared yellow mustard',
#    'salt & pepper',
#    'sugar'}],
#  ['33606',
#   {'cheese',
#    'chives',
#    'cider vinegar',
#    'dill pickles',
#    'garlic powder',
#    'green onion',
#    'ham',
#    'italian seasoning',
#    'olive oil',
#    'onion powder',
#    'ripe olives',
#    'salt and pepper',
#    'sweet pepper',
#    'tomato',
#    'tri-color spiral pasta',
#    'water chestnut'}],
#  ['94710',
#   {'basil',
#    'flat leaf parsley',
#    'frozen french fries',
#    'oil',
#    'oregano',
#    'parmesan cheese',
#    'salt & freshly ground black pepper'}],
#  ['35173',
#   {'butter',
#    'cheddar cheese',
#    'deli turkey',
#    'good seasonings italian salad dressing mix',
#    'ham',
#    'mozzarella cheese',
#    'pepperoni',
#    'sandwich bun',
#    'swiss cheese'}],
#  ['83025',
#   {'all-purpose flour',
#    'baking powder',
#    'butter',
#    'egg',
#    'icing sugar',
#    'milk',
#    'salt',
#    'shortening',
#    'sugar',
#    'vanilla'}],
#  ['52804',
#   {'carrot',
#    'cinnamon',
#    'coconut',
#    'crushed pineapple',
#    'egg',
#    'nutmeg',
#    'oil',
#    'pecans',
#    'vanilla instant pudding mix',
#    'water',
#    'yellow cake mix'}],
#  ['108414',
#   {'butter',
#    'egg',
#    'heavy cream',
#    'honey',
#    'jalapenos',
#    'jiffy corn muffin mix',
#    'onion',
#    'red bell pepper',
#    'sharp cheddar cheese',
#    'whole kernel corn'}],
#  ['26995',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'butter',
#    'cinnamon',
#    'crushed pineapple',
#    'dry yeast',
#    'egg',
#    'flour',
#    'milk',
#    'nuts',
#    'raisins',
#    'salt',
#    'sugar',
#    'vanilla',
#    'vegetable oil',
#    'water'}],
#  ['53402',
#   {'cottage cheese',
#    'dried basil',
#    'egg',
#    'garlic',
#    'ground beef',
#    'ground black pepper',
#    'italian sausage',
#    'lasagna noodle',
#    'mozzarella cheese',
#    'parmesan cheese',
#    'parsley flakes',
#    'ricotta cheese',
#    'salt',
#    'tomato paste',
#    'whole tomato'}],
#  ['59632',
#   {'beef',
#    'cheese',
#    'cottage cheese',
#    'egg',
#    'frozen chopped spinach',
#    'herbs',
#    'olive oil flavored cooking spray',
#    'pepper',
#    'salt',
#    'spices',
#    'toasted wheat germ'}],
#  ['22526',
#   {'brown sugar',
#    'butter',
#    'cinnamon',
#    'instant vanilla pudding',
#    'raisins',
#    'rolls'}],
#  ['100870',
#   {'garlic',
#    'granulated sugar',
#    'ground beef',
#    'prego spaghetti sauce',
#    'stewed tomatoes',
#    'white onion'}],
#  ['84797',
#   {'beef steaks',
#    'brown sugar',
#    'dried dill weed',
#    'fresh garlic',
#    'fresh lemon juice',
#    'fresh parsley',
#    'honey',
#    'hot sauce',
#    'ketchup',
#    'sour cream',
#    'spicy mustard',
#    'vegetable oil'}],
#  ['35653',
#   {'baking powder', 'butter', 'egg', 'flour', 'milk', 'salt', 'sugar'}],
#  ['32169',
#   {'button mushrooms',
#    'chicken breasts',
#    'dried basil',
#    'dried oregano',
#    'fresh ground black pepper',
#    'fresh parsley',
#    'garlic',
#    'hot sauce',
#    'olive oil',
#    'onion',
#    'parmesan cheese',
#    'pasta',
#    'salsa',
#    'tomato',
#    'water'}],
#  ['24478', {'cider vinegar', 'fresh herb', 'fresh herbs'}],
#  ['44045',
#   {'baking powder',
#    'cream',
#    'egg',
#    'fat',
#    'flour',
#    'fresh corn',
#    'pepper',
#    'salt'}],
#  ['60219',
#   {'black olives',
#    'cheddar cheese soup',
#    'fettuccine pasta',
#    'jalapeno',
#    'milk',
#    'picante sauce'}],
#  ['81185',
#   {'cilantro',
#    'frozen peas',
#    'hass avocado',
#    'lemons, juice of',
#    'onion',
#    'salt',
#    'tomato'}],
#  ['30131',
#   {'basil',
#    'garlic powder',
#    'lemon juice',
#    'oil',
#    'pepper',
#    'soy sauce',
#    'worcestershire sauce'}],
#  ['63593',
#   {'apple', 'cream cheese', 'milk', 'pear', 'unflavored gelatin', 'yogurt'}],
#  ['43164',
#   {'bacon',
#    'bay leaf',
#    'butter',
#    'carrot',
#    'oil',
#    'onion',
#    'parsley sprigs',
#    'pepper',
#    'salt',
#    'thyme',
#    'veal roast'}],
#  ['30300', {'black pepper', 'crackers', 'mayonnaise', 'tomato'}],
#  ['78655',
#   {'brine',
#    'capers',
#    'carrot',
#    'ciabatta',
#    'fresh basil',
#    'fresh parsley',
#    'garlic',
#    'genoa salami',
#    'green olives',
#    'ham',
#    'kalamata olive',
#    'olive oil',
#    'oregano leaves',
#    'provolone cheese',
#    'red wine vinegar',
#    'sweet onion',
#    'tomato'}],
#  ['74805',
#   {'powdered sugar',
#    'vanilla',
#    'vanilla instant pudding mix',
#    'whipping cream'}],
#  ['71635',
#   {'cookie',
#    'cream cheese',
#    'gelatin',
#    'milk',
#    'miniature semisweet chocolate chips',
#    'prepared graham cracker crusts',
#    'sugar',
#    'vanilla'}],
#  ['38276',
#   {'all-purpose flour',
#    'baking powder',
#    'butter',
#    'carrot',
#    'cayenne pepper',
#    'celery',
#    'chili powder',
#    'cloves',
#    'egg',
#    'flour',
#    'green pepper',
#    'ground cumin',
#    'monterey jack cheese',
#    'onion',
#    'oregano',
#    'salt',
#    'sliced mushrooms',
#    'soy sauce',
#    'tomato',
#    'vegetable shortening',
#    'water',
#    'zucchini'}],
#  ['97052', {'half-and-half', 'salt and pepper', 'sweet butter', 'sweet corn'}],
#  ['26835',
#   {'all-purpose flour',
#    'baking soda',
#    'butter',
#    'egg',
#    'lemon, rind of',
#    'salt',
#    'sugar',
#    'vanilla',
#    'yogurt'}],
#  ['32271',
#   {'butter',
#    'egg',
#    'flour',
#    'nuts',
#    'sugar',
#    'unsweetened chocolate squares',
#    'vanilla'}],
#  ['107229',
#   {'broccoli',
#    'chili-garlic sauce',
#    'cooked chicken',
#    'fresh cilantro',
#    'fresh ginger',
#    'green onions',
#    'reduced sodium soy sauce',
#    'rice vinegar',
#    'sesame oil',
#    'sesame seeds',
#    'vegetable oil',
#    'vermicelli'}],
#  ['5060',
#   {'apples',
#    'celery',
#    'orange juice',
#    'orange rind',
#    'pecans',
#    'philadelphia cream cheese',
#    'sugar'}],
#  ['42570',
#   {'boneless chicken breast',
#    'cayenne',
#    'cumin',
#    'fresh ground pepper',
#    'garlic',
#    'lemon juice',
#    'olive oil',
#    'paprika',
#    'salt',
#    'thyme'}],
#  ['52443',
#   {'baking potato',
#    'garlic powder',
#    'mozzarella cheese',
#    'oregano leaves',
#    'parmesan cheese',
#    'part-skim ricotta cheese',
#    'tomato sauce'}],
#  ['35595',
#   {'black pepper',
#    'cornstarch',
#    'mushroom pieces',
#    'onion',
#    'sodium-free vegetable broth',
#    'tabasco sauce',
#    'tomato puree',
#    'white wine'}],
#  ['108804',
#   {'albacore tuna in water',
#    'bibb lettuce',
#    'black pepper',
#    'fresh basil',
#    'garlic',
#    'light olive oil',
#    'red sweet bell peppers',
#    'red wine vinegar',
#    'salt',
#    'scallions',
#    'white kidney beans'}],
#  ['83950',
#   {'bacon',
#    'beef consomme',
#    'black pepper',
#    'butter',
#    'carrot',
#    'celery',
#    'crushed tomatoes',
#    'dry white wine',
#    'garlic',
#    'ground pork',
#    'lean ground beef',
#    'milk',
#    'nutmeg',
#    'olive oil',
#    'onion',
#    'oregano',
#    'penne pasta',
#    'red pepper flakes',
#    'rubbed sage',
#    'salt'}],
#  ['19208', {'apples', 'red cinnamon candies', 'sugar substitute', 'water'}],
#  ['64302',
#   {'brown sugar',
#    'celery',
#    'cucumber',
#    'elbow macaroni',
#    'green pepper',
#    'ketchup',
#    'lemon juice',
#    'oil',
#    'onion',
#    'tomato'}],
#  ['35964',
#   {'baking powder',
#    'brown sugar',
#    'cocoa',
#    'flour',
#    'hot water',
#    'milk',
#    'salt',
#    'sugar',
#    'vanilla',
#    'vegetable oil'}],
#  ['71457',
#   {'apple pie filling',
#    'butter',
#    'egg',
#    'flour',
#    'milk',
#    'powdered sugar',
#    'salt',
#    'toasted almonds'}],
#  ['95926', {'bananas', 'mayonnaise', 'white bread'}],
#  ['103948',
#   {'all-purpose flour',
#    'boneless skinless chicken thighs',
#    'breadcrumbs',
#    'chicken stock',
#    'dried oregano',
#    'dried thyme',
#    'dry white wine',
#    'fresh ground black pepper',
#    'garlic powder',
#    'lean ground beef',
#    'milk',
#    'onion',
#    'poultry seasoning',
#    'salt',
#    'vegetable oil'}],
#  ['99024',
#   {'cream cheese', 'lemon juice', 'liquid smoke', 'onion', 'salmon', 'salt'}],
#  ['64045',
#   {'bean sprouts',
#    'brown sugar',
#    'carrot',
#    'desiccated coconut',
#    'garlic',
#    'ginger',
#    'green beans',
#    'ground cayenne pepper',
#    'ground coriander',
#    'ground cumin',
#    'onion',
#    'peanut oil',
#    'peanuts',
#    'red chili pepper',
#    'sambal oelek',
#    'soy sauce',
#    'tempeh',
#    'tomato',
#    'vegetable stock',
#    'water'}],
#  ['41756',
#   {'dried breadcrumbs',
#    'egg',
#    'ground beef',
#    'lemon juice',
#    'onion',
#    'salt and pepper',
#    'sugar',
#    'tomato soup',
#    'water'}],
#  ['112959',
#   {'avocado',
#    'chunky salsa',
#    'fresh cilantro',
#    'hot sauce',
#    'lime juice',
#    'salt and pepper',
#    'soft silken tofu'}],
#  ['83062',
#   {'baking soda',
#    'bananas',
#    'cinnamon',
#    'egg',
#    'flour',
#    'ground cloves',
#    'nutmeg',
#    'salt',
#    'shortening',
#    'walnuts',
#    'white sugar'}],
#  ['98930',
#   {'boneless skinless chicken breast',
#    'dried basil',
#    'lime juice',
#    'olive oil',
#    'salt and pepper',
#    'tomato'}],
#  ['83133',
#   {'beef ribs',
#    'brown sugar',
#    'fresh lemon juice',
#    'ketchup',
#    'mustard',
#    'onion',
#    'salt',
#    'vegetable oil',
#    'water',
#    'worcestershire sauce'}],
#  ['39947', {'egg whites', 'green grape', 'sugar'}],
#  ['44895',
#   {'betty crocker fudge brownie mix',
#    'egg',
#    'milk chocolate candy bars',
#    'vegetable oil',
#    'water'}],
#  ['39363',
#   {'baking powder',
#    'baking soda',
#    'bananas',
#    'butter',
#    'chocolate chips',
#    'egg',
#    'flour',
#    'nuts',
#    'salt',
#    'sugar',
#    'water'}],
#  ['62368',
#   {'brown sugar',
#    'butter',
#    'chocolate chips',
#    'cream cheese',
#    'egg',
#    'flour',
#    'oreo cookie crumbs',
#    'sour cream',
#    'sweetened condensed milk',
#    'vanilla'}],
#  ['111875',
#   {'2% low-fat milk',
#    'banana',
#    'natural-style peanut butter',
#    'sugar-free non-fat vanilla yogurt'}],
#  ['42522',
#   {'bean dip',
#    'cheddar cheese',
#    'cream cheese',
#    'sour cream',
#    'taco seasoning'}],
#  ['34930',
#   {'american cheese',
#    'bacon',
#    'dill weed',
#    'ground sirloin',
#    'iceberg lettuce',
#    "mccormick's montreal brand steak seasoning",
#    'no-salt-added ketchup',
#    'onion',
#    'tomato'}],
#  ['63793',
#   {'chat masala',
#    'chopped tomato',
#    'cucumber',
#    'paprika',
#    'plain yogurt',
#    'potato',
#    'salt'}],
#  ['61973',
#   {'baking soda',
#    'brown sugar',
#    'buttermilk',
#    'carrot',
#    'cinnamon',
#    'corn oil',
#    'egg',
#    'natural bran',
#    'raisins',
#    'salt',
#    'vanilla',
#    'whole wheat flour'}],
#  ['45859',
#   {'grand marnier',
#    'lime juice',
#    'lime wedge',
#    'limeade',
#    'tequila',
#    'triple sec'}],
#  ['58651',
#   {'brown sugar', 'butter', 'flour', 'pecans', 'semi-sweet chocolate chips'}],
#  ['59534',
#   {'butter',
#    'cappelletti pasta',
#    'cheddar cheese',
#    'chopped tomato',
#    'corn',
#    'garlic',
#    'ground beef',
#    'milk',
#    'mushrooms',
#    'onion',
#    'pepper',
#    'salt',
#    'tomato soup'}],
#  ['24137',
#   {'dry white wine',
#    'extra virgin olive oil',
#    'garlic',
#    'hot water',
#    'parsley',
#    'salt and pepper',
#    'spaghetti',
#    'squid',
#    'tomato sauce'}],
#  ['40237',
#   {'baking soda',
#    'cocoa',
#    'flour',
#    'salt',
#    'sugar',
#    'vanilla',
#    'vegetable oil',
#    'vinegar',
#    'water'}],
#  ['18537', {'applesauce', 'brown sugar', 'clove', 'pork loin chops'}],
#  ['104243',
#   {'butter',
#    'cheddar cheese',
#    'cream cheese',
#    'green olives',
#    'ham',
#    'honey mustard',
#    'leaf lettuce',
#    'mayonnaise',
#    'prepared horseradish',
#    'provolone cheese',
#    'radish sprouts',
#    'roast beef',
#    'roasted red peppers',
#    'swiss cheese',
#    'turkey',
#    'whole wheat bread dough'}],
#  ['105069',
#   {'beef broth',
#    'butter',
#    'flour',
#    'fresh dill',
#    'lemon, juice of',
#    'onion',
#    'salt and pepper',
#    'sour cream',
#    'water',
#    'wild mushrooms'}],
#  ['70099',
#   {'asian chili sauce',
#    'bean sprouts',
#    'carrot',
#    'english cucumber',
#    'fresh cilantro',
#    'fresh ginger',
#    'garlic',
#    'green onions',
#    'honey',
#    'light soy sauce',
#    'rice noodles',
#    'rice wine vinegar',
#    'sesame oil'}],
#  ['333281',
#   {'all-purpose flour',
#    'bittersweet chocolate',
#    'brewed espresso',
#    'egg',
#    'granulated sugar',
#    'kosher salt',
#    'unsalted butter',
#    'unsweetened cocoa powder',
#    'vanilla'}],
#  ['234069', {'brown sugar', 'dr. pepper cola', 'orange marmalade'}],
#  ['37841',
#   {'fish',
#    'gingerroot',
#    'low sodium soy sauce',
#    'peanut oil',
#    'rice wine',
#    'salt',
#    'scallions',
#    'sesame oil',
#    'white pepper'}],
#  ['144952',
#   {'beef broth',
#    'butter',
#    'flour',
#    'french bread',
#    'garlic',
#    'low sodium beef broth',
#    'olive oil',
#    'parmesan cheese',
#    'romano cheese',
#    'sherry wine',
#    'sugar',
#    'swiss cheese',
#    'yellow onions'}],
#  ['453467',
#   {'all-purpose flour',
#    'baking soda',
#    'brown sugar',
#    'chocolate chips',
#    'egg',
#    'margarine',
#    'salt',
#    'vanilla',
#    'water',
#    'white sugar',
#    'whole wheat flour'}],
#  ['31835',
#   {'butter',
#    'cornbread',
#    'cream of chicken soup',
#    'egg',
#    'onion',
#    'sage',
#    'squash'}],
#  ['197013',
#   {'bay leaves',
#    'bottled garlic',
#    'dried basil',
#    'dried oregano',
#    'dried parsley',
#    'garlic powder',
#    'italian sausage',
#    'olive oil',
#    'paprika',
#    'pepper',
#    'salt',
#    'sugar',
#    'tomato sauce',
#    'white onion'}],
#  ['306168',
#   {'cream of chicken soup',
#    'french-fried onions',
#    'frozen broccoli cuts',
#    'garlic powder',
#    'ground black pepper',
#    'milk',
#    'salt',
#    'sharp cheddar cheese',
#    'soy sauce'}],
#  ['286009',
#   {'all-purpose flour',
#    'almond extract',
#    'butter',
#    'egg',
#    'pure vanilla extract',
#    'sugar',
#    'whole milk'}],
#  ['24514',
#   {'artichoke hearts',
#    'egg',
#    'fresh garlic',
#    'oil',
#    'unsalted butter',
#    'unseasoned breadcrumbs'}],
#  ['42508',
#   {'barbecue sauce',
#    'black pepper',
#    'chicken',
#    'chili powder',
#    'cider vinegar',
#    'hot red pepper sauce',
#    'salt',
#    'worcestershire sauce'}],
#  ['116679',
#   {'cheddar cheese',
#    'cream cheese',
#    'dry onion soup mix',
#    'frozen broccoli',
#    'ritz cracker crumbs',
#    'sour cream',
#    'water chestnuts'}],
#  ['124286',
#   {'baking soda',
#    'cocoa powder',
#    'cool whip',
#    'flour',
#    'instant chocolate pudding mix',
#    'mayonnaise',
#    'milk',
#    'salt',
#    'sugar',
#    'vanilla',
#    'water'}],
#  ['190',
#   {'bouillon',
#    'budweiser beer',
#    'chili powder',
#    'coriander',
#    'cornmeal',
#    'cumin',
#    'flour',
#    'garlic',
#    'hunts tomato sauce',
#    'lean chuck',
#    'lean pork',
#    'louisiana hot sauce',
#    'onion',
#    'oregano leaves',
#    'paprika',
#    'sugar',
#    'unsweetened cocoa',
#    'water'}],
#  ['475785',
#   {'baby spinach',
#    'egg',
#    'fresh garlic',
#    'goat cheese',
#    'kosher salt',
#    'meatloaf mixture',
#    'olive oil',
#    'red bell pepper',
#    'simply potatoes shredded hash browns',
#    'unsalted butter',
#    'unsmoked bacon',
#    'white pepper',
#    'yellow onion'}],
#  ['17265',
#   {'dark brown sugar',
#    'egg',
#    'egg white',
#    'ground cinnamon',
#    'ground cloves',
#    'ground ginger',
#    'heavy cream',
#    'milk',
#    'nutmeg',
#    'pie crusts',
#    'pumpkin puree',
#    'salt'}],
#  ['50662',
#   {'baking powder',
#    'beef',
#    'breadcrumbs',
#    'butter',
#    'celery seed',
#    'cream of chicken soup',
#    'dry onion flakes',
#    'flour',
#    'milk',
#    'onion',
#    'paprika',
#    'poppy seed',
#    'poultry seasoning',
#    'salt',
#    'sour cream',
#    'vegetable oil'}],
#  ['177187',
#   {'baking powder',
#    'baking soda',
#    'blended oatmeal',
#    'brown sugar',
#    'butter',
#    'egg',
#    'flour',
#    'hershey chocolate candy bars',
#    'nuts',
#    'semi-sweet chocolate chips',
#    'sugar',
#    'vanilla'}],
#  ['118843',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'butter',
#    'chocolate chips',
#    'egg',
#    'flour',
#    "hershey's semi-sweet baking chocolate",
#    'nuts',
#    'oatmeal',
#    'salt',
#    'vanilla',
#    'white sugar'}],
#  ['208179', {'butter', 'flour', 'granulated sugar', 'milk', 'vanilla'}],
#  ['500166',
#   {'cheddar cheese',
#    'corn cobs',
#    'ground beef',
#    'lettuce',
#    'onion',
#    'salsa',
#    'taco seasoning',
#    'taco shells',
#    'tomato'}],
#  ['501028',
#   {'beans',
#    'beef bouillon cube',
#    'beef broth',
#    'bell peppers',
#    'black pepper',
#    'chicken bouillon cube',
#    'chunky salsa',
#    'cinnamon',
#    'cumin',
#    'dark chocolate chips',
#    'garlic',
#    'ground coriander',
#    'habanero pepper',
#    'light brown sugar',
#    'mexican chili powder',
#    'salt',
#    'sazon goya',
#    'stewing beef',
#    'stewing pork',
#    'tomato paste',
#    'tortilla chips',
#    'white onion'}],
#  ['136602',
#   {'all-purpose flour',
#    'baking soda',
#    'brown sugar',
#    'butter',
#    'cream cheese',
#    'egg',
#    'lemon zest',
#    'lime zest',
#    'orange-flavored liqueur',
#    'pecans',
#    'pitted dates',
#    'powdered sugar',
#    'salt',
#    'shortening',
#    'tequila',
#    'triple sec',
#    'warm water'}],
#  ['69190',
#   {'bouillon cubes',
#    'butter',
#    'carrot',
#    'celery',
#    'cream of celery soup',
#    'cream of chicken soup',
#    'milk',
#    'onion',
#    'potato',
#    'potato flakes',
#    'water'}],
#  ['503475',
#   {'apples',
#    'butter',
#    'cinnamon',
#    'cream',
#    'egg',
#    'flour',
#    'lemon, juice of',
#    'milk',
#    'salt',
#    'sugar'}],
#  ['522861',
#   {'butter',
#    'cheese',
#    'fresh coarse ground black pepper',
#    'garlic',
#    'macaroni',
#    'milk',
#    'onion',
#    'salt'}],
#  ['457136',
#   {'black pepper',
#    'cheese',
#    'fine semolina',
#    'heavy cream',
#    'macaroni',
#    'muscat wine',
#    'onion',
#    'potato',
#    'salt water',
#    'unsalted butter'}],
#  ['455351',
#   {'applesauce',
#    'butter',
#    'cheese',
#    'milk',
#    'onion',
#    'penne pasta',
#    'potato',
#    'salt and pepper'}],
#  ['333797', {'dried yellow peas', 'ginger', 'pork', 'salt', 'water'}],
#  ['428056',
#   {'brown mustard',
#    'carrot',
#    'clove',
#    'dried thyme',
#    'dried yellow peas',
#    'ground ginger',
#    'ham bone',
#    'onion',
#    'pepper',
#    'salt',
#    'water'}],
#  ['306245', {'butter', 'fresh spinach', 'nutmeg', 'water'}],
#  ['523359',
#   {'chili powder',
#    'cornstarch',
#    'dried onion flakes',
#    'garlic powder',
#    'granulated sugar',
#    'ground beef',
#    'ground black pepper',
#    'ground pork',
#    'paprika',
#    'salt',
#    'tomato paste',
#    'water',
#    'white vinegar',
#    'wondra flour'}],
#  ['495314',
#   {'apple cider vinegar',
#    'applesauce',
#    'cayenne',
#    'dark brown sugar',
#    'granulated garlic',
#    'liquid smoke',
#    'maple syrup',
#    'oregano',
#    'ponzu sauce',
#    'salt',
#    'tomato ketchup'}],
#  ['149593',
#   {'baking powder',
#    'baking soda',
#    'butter',
#    'egg',
#    'flour',
#    'salt',
#    'sour cream',
#    'sugar',
#    'vanilla'}],
#  ['227924',
#   {'butter', 'frozen whipped topping', 'oreo cookies', 'vanilla ice cream'}],
#  ['100540', {'butter', 'processed cheese', 'white bread'}],
#  ['155959',
#   {'balsamic vinegar',
#    'fresh ground black pepper',
#    'garlic',
#    'london broil beef',
#    'olive oil',
#    'rosemary',
#    'soy sauce',
#    'worcestershire sauce'}],
#  ['29214',
#   {'chicken broth',
#    'cornstarch',
#    'dried oregano',
#    'dried rosemary',
#    'dried thyme',
#    'dry sherry',
#    'fresh mushrooms',
#    'garlic',
#    'hot pepper sauce',
#    'margarine',
#    'nonfat dry milk powder',
#    'nonfat milk',
#    'parmesan cheese',
#    'salt and black pepper',
#    'spicy brown mustard',
#    'teriyaki sauce'}],
#  ['92533',
#   {'almonds',
#    'butter',
#    'cinnamon',
#    'cream cheese',
#    'egg',
#    'nutmeg',
#    'sour cream',
#    'splenda sugar substitute',
#    'vanilla',
#    'vanilla protein powder'}],
#  ['209203',
#   {'bacon', 'butter', 'real maple syrup', 'refrigerated buttermilk biscuits'}],
#  ['42151',
#   {'horseradish',
#    'mayonnaise',
#    'tabasco sauce',
#    'velveeta cheese',
#    'worcestershire sauce'}],
#  ['327356', {'lemon juice', 'red wine vinegar', 'water'}],
#  ['325509',
#   {'berries',
#    'ground flax seeds',
#    "i can't believe it's not butter spread",
#    'old fashioned oats',
#    'sugar-free syrup',
#    'water'}],
#  ['236184',
#   {'blueberries',
#    'cream cheese',
#    'egg',
#    'flour',
#    'french bread',
#    'frozen blueberries',
#    'maple syrup',
#    'milk',
#    'nuts',
#    'powdered sugar',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['241445',
#   {'bacon',
#    'celery',
#    'cheddar cheese',
#    'chicken broth',
#    'chives',
#    'liquid smoke',
#    'onion',
#    'red potatoes',
#    'salt',
#    'sour cream',
#    'velveeta cheese',
#    'white pepper'}],
#  ['149887',
#   {'active dry yeast',
#    'brown sugar',
#    'butter',
#    'cinnamon',
#    'cream cheese',
#    'egg',
#    'flour',
#    'granulated sugar',
#    'milk',
#    'powdered sugar',
#    'salt',
#    'vanilla pudding mix',
#    'warm water'}],
#  ['112984',
#   {'asparagus',
#    'garlic',
#    'italian seasoning',
#    'part-skim mozzarella cheese',
#    'red bell pepper',
#    'reduced-fat parmesan cheese',
#    'salt and pepper',
#    'spaghetti sauce',
#    'spaghetti squash',
#    'white mushroom'}],
#  ['200148',
#   {'coriander',
#    'cornstarch',
#    'frozen pineapple concentrate',
#    'graham cracker crumbs',
#    'lemon juice',
#    'maple syrup',
#    'margarine',
#    'oil',
#    'soft silken tofu',
#    'vanilla',
#    'vegan cream cheese',
#    'vegan sugar',
#    'water'}],
#  ['445026',
#   {'all-purpose flour',
#    'andouille sausage',
#    'celery',
#    'cooked chicken',
#    'creole seasoning',
#    'frozen black-eyed peas',
#    'garlic',
#    'green bell pepper',
#    'large raw shrimp',
#    'low sodium chicken broth',
#    'onion',
#    'vegetable oil'}],
#  ['70611',
#   {'cheddar cheese',
#    'cracker',
#    'egg',
#    'ground beef',
#    'onion',
#    'pickle',
#    'salt and pepper',
#    'thousand island dressing'}],
#  ['273326',
#   {'basil',
#    'butter',
#    'cajun spices',
#    'garlic',
#    'heavy whipping cream',
#    'lemon juice',
#    'linguine',
#    'parmesan cheese',
#    'parmesan-romano cheese mix',
#    'parsley',
#    'salmon',
#    'salt',
#    'white pepper'}],
#  ['310570', {'cottage cheese', 'egg', 'feta', 'milk', 'oil', 'phyllo dough'}],
#  ['318677',
#   {'avocado',
#    'cucumber',
#    'imitation crabmeat',
#    'lettuce',
#    'pickled ginger',
#    'seasoned rice vinegar',
#    'soy sauce',
#    'white rice'}],
#  ['80050',
#   {'baking soda',
#    'egg',
#    'flour',
#    'maraschino cherry',
#    'mincemeat',
#    'mixed candied fruit',
#    'sweetened condensed milk',
#    'walnuts'}],
#  ['269984',
#   {'baby carrots',
#    'baking powder',
#    'celery',
#    'chicken breasts',
#    'chicken stock',
#    'egg',
#    'kosher salt',
#    'matzo meal',
#    'oil',
#    'pepper',
#    'salt',
#    'sugar',
#    'white onion'}],
#  ['317508',
#   {'cheddar cheese',
#    'cream of mushroom soup',
#    'frozen southern style hash brown potatoes',
#    'poppy seed',
#    'sour cream'}],
#  ['53872',
#   {'adobo seasoning',
#    'egg',
#    'fresh garlic cloves',
#    'fresh ground pepper',
#    'ground coriander',
#    'ground sage',
#    'italian seasoned breadcrumbs',
#    'ketchup',
#    'lean ground beef',
#    'low sodium soy sauce',
#    'olive oil',
#    'oregano',
#    'red onion',
#    'sea salt',
#    'veggie shreds cheese'}],
#  ['268942',
#   {'butter',
#    'celery',
#    'cream of celery soup',
#    'green bell pepper',
#    'kraft macaroni and cheese',
#    'mushrooms',
#    'onion',
#    'tuna'}],
#  ['176110',
#   {'cider vinegar',
#    'dry mustard',
#    'garlic',
#    'ketchup',
#    'miracle whip',
#    'paprika',
#    'pepper',
#    'salt',
#    'sugar',
#    'tabasco sauce',
#    'vegetable oil'}],
#  ['205331',
#   {'extra virgin olive oil',
#    'italian parsley',
#    'kalamata olive',
#    'kosher salt & freshly ground black pepper',
#    'lemon, juice of',
#    'oregano',
#    'pepperoncini peppers',
#    'red bell pepper',
#    'red onion',
#    'red ripe tomatoes',
#    'red wine vinegar',
#    'seedless cucumber',
#    'shallot',
#    'tuna in vegetable oil',
#    'water-packed artichoke hearts'}],
#  ['165856',
#   {'buttermilk',
#    'canola oil',
#    'egg',
#    'ground black pepper',
#    'orange roughy',
#    'seasoning salt',
#    'self-rising flour'}],
#  ['474769',
#   {'all-purpose flour',
#    'bacon',
#    'egg',
#    'egg yolk',
#    'frozen spinach',
#    'garlic',
#    'goat cheese',
#    'green onion',
#    'salt',
#    'simply potatoes traditional mashed potatoes'}],
#  ['138005',
#   {'boneless pork chops',
#    'cajun seasoning',
#    'canola oil',
#    'egg',
#    'flour',
#    'ground black pepper',
#    'milk',
#    'salt and pepper',
#    'seasoning salt',
#    'self-rising flour'}],
#  ['216945',
#   {'imitation crabmeat',
#    'ramen noodles',
#    'stir fry vegetables',
#    'teriyaki marinade',
#    'water'}],
#  ['164526',
#   {'apple',
#    'banana',
#    'celery',
#    'fresh cilantro leaves',
#    'green bell pepper',
#    'ground red pepper',
#    'pesto sauce',
#    'pumpkin puree',
#    'pumpkin seeds',
#    'red onion',
#    'salt',
#    'small red potato',
#    'smooth cashew butter',
#    'vegetable broth'}],
#  ['50184',
#   {'chili powder',
#    'dry-roasted cashews',
#    'garlic',
#    'margarine',
#    'mushrooms',
#    'nutmeg',
#    'parsley',
#    'vegetable bouillon cubes',
#    'water'}],
#  ['316470',
#   {'ice cubes', 'mangoes', 'oranges', 'strawberries', 'vanilla bean'}],
#  ['343338',
#   {'fresh rosemary',
#    'garlic',
#    'leeks',
#    'olive oil',
#    'russet potatoes',
#    'salt and pepper',
#    'vegetable broth',
#    'white beans'}],
#  ['137434',
#   {'black peppercorns',
#    'boneless skinless chicken breasts',
#    'cardamom pods',
#    'chicken stock',
#    'chili powder',
#    'cinnamon stick',
#    'cloves',
#    'coriander seed',
#    'fresh coriander',
#    'fresh ginger',
#    'garlic',
#    'ground cumin',
#    'onion',
#    'salt & freshly ground black pepper',
#    'soy yogurt',
#    'turmeric'}],
#  ['95534',
#   {'beef bouillon cubes',
#    'black pepper',
#    'boiling water',
#    'dried oregano',
#    'dried thyme',
#    'garlic',
#    'garlic powder',
#    'rump roast',
#    'salt',
#    'tabasco sauce',
#    'worcestershire sauce'}],
#  ['30473', {'ginger', 'honey', 'milk', 'tea bag', 'water'}],
#  ['24470', {'ground beef', 'sausage', 'taco chips', 'velveeta cheese'}],
#  ['311991',
#   {'bell pepper',
#    'brown sugar',
#    'garlic powder',
#    'ground mustard',
#    'hamburger buns',
#    'ketchup',
#    'lean ground beef',
#    'onion',
#    'steak seasoning',
#    'tomato sauce',
#    'white vinegar',
#    'worcestershire sauce'}],
#  ['225707',
#   {'beets',
#    'carrot',
#    'fresh corn kernels',
#    'garlic',
#    'gingerroot',
#    'green onions',
#    'green peppers',
#    'honey',
#    'pepper',
#    'rice wine vinegar',
#    'safflower oil',
#    'salad greens',
#    'salad seasoning',
#    'salt',
#    'soy sauce',
#    'white mushrooms'}],
#  ['242830',
#   {'chicken broth',
#    'dry white wine',
#    'fennel seeds',
#    'fresh lemon juice',
#    'olive oil',
#    'onion',
#    'paprika',
#    'pork chops'}],
#  ['336744',
#   {'black olives',
#    'egg',
#    'garlic powder',
#    'italian seasoning',
#    'mozzarella cheese',
#    'pepperoni',
#    'ramen noodles',
#    'red bell pepper',
#    'roma tomato'}],
#  ['83542',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'egg',
#    'flour',
#    'milk',
#    'molasses',
#    'natural bran',
#    'oil',
#    'raisins',
#    'salt',
#    'sesame seeds',
#    'sunflower seeds'}],
#  ['91626',
#   {'black tea leaves',
#    'broiler',
#    'brown sugar',
#    'dry sherry',
#    'garlic',
#    'low sodium soy sauce',
#    'minced ginger',
#    'onion',
#    'orange zest',
#    'orange, juice of',
#    'peppercorn'}],
#  ['303457',
#   {'cardamom pods',
#    'cloves',
#    'coriander seed',
#    'fruit vinegar',
#    'gingerroot',
#    'kaffir lime leaves',
#    'lemongrass',
#    'peanut oil',
#    'star anise',
#    'turmeric',
#    'yoghurt'}],
#  ['176717',
#   {'blueberry pie filling',
#    'cool whip',
#    'graham wafers',
#    'vanilla pudding mix'}],
#  ['39226',
#   {'canned jalapeno slices',
#    'cayenne pepper',
#    'chili powder',
#    'cornstarch',
#    'dried onion flakes',
#    'garlic powder',
#    'onion powder',
#    'salt',
#    'sugar',
#    'tomato paste',
#    'vinegar',
#    'water'}],
#  ['216030',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'butter',
#    'cake flour',
#    'corn flakes',
#    'egg',
#    'nuts',
#    'quick-cooking oats',
#    'raisins',
#    'salt',
#    'shredded coconut',
#    'vanilla'}],
#  ['268169',
#   {'butter',
#    'italian spices',
#    'kosher salt',
#    'olive oil',
#    'onion',
#    'pepper',
#    'whole turkey'}],
#  ['98357',
#   {'cheddar cheese',
#    'chili with beans',
#    'corn chips',
#    'onion',
#    'salsa',
#    'sour cream'}],
#  ['150365',
#   {'cauliflower florets',
#    'egg',
#    'parsley sprig',
#    'pepper',
#    'plain breadcrumbs',
#    'salt',
#    'vegetable oil'}],
#  ['243251',
#   {'butter',
#    'fresh green beans',
#    'ground black pepper',
#    'kosher salt',
#    'mixed herbs',
#    'olive oil',
#    'onion',
#    'walnuts'}],
#  ['20186',
#   {'american cheese',
#    'ham',
#    'hamburger buns',
#    'ketchup',
#    'sweet pickle relish'}],
#  ['109818', {'bacon', 'carrot', 'sugar', 'tomato soup'}],
#  ['243785',
#   {'brown sugar',
#    'egg',
#    'ground beef',
#    'ketchup',
#    'lipton onion soup mix',
#    'seasoned bread crumbs'}],
#  ['207525',
#   {'bulk pork sausage',
#    'garlic powder',
#    'ground chuck',
#    'ground pepper',
#    'oregano',
#    'rye cocktail bread',
#    'velveeta cheese',
#    'worcestershire sauce'}],
#  ['226246',
#   {'brown sugar',
#    'butter',
#    'caster sugar',
#    'egg',
#    'glace cherries',
#    'milk',
#    'pineapple in syrup',
#    'self-raising flour',
#    'vanilla essence'}],
#  ['353044',
#   {'apple',
#    'banana',
#    'coconut milk',
#    'flax seed oil',
#    'greens',
#    'honey',
#    'oat bran',
#    'water'}],
#  ['263781',
#   {'green onion',
#    'hawaiian bread',
#    "hellmann's mayonnaise",
#    'knorr vegetable soup mix',
#    'sour cream',
#    'water chestnuts'}],
#  ['66932',
#   {'broccoli floret',
#    'brown rice',
#    'carrot',
#    'egg',
#    'olive oil',
#    'peas',
#    'sliced mushrooms',
#    'soy sauce'}],
#  ['48131',
#   {'egg whites',
#    'pumpkin',
#    'pumpkin pie spice',
#    'reduced fat graham cracker crust',
#    'skim milk',
#    'splenda sugar substitute'}],
#  ['32363', {'beef stew', 'biscuits'}],
#  ['293225',
#   {'baking soda',
#    'buttermilk',
#    'creamy peanut butter',
#    'espresso',
#    'extra-large eggs',
#    'heavy cream',
#    'honey roasted peanuts',
#    'light corn syrup',
#    'powdered sugar',
#    'pure vanilla extract',
#    'salt',
#    'semisweet chocolate',
#    'sugar',
#    'unbleached all-purpose flour',
#    'unsalted butter',
#    'unsweetened cocoa'}],
#  ['235173',
#   {'chipotle chile in adobo',
#    'cilantro',
#    'corn kernel',
#    'fresh lime juice',
#    'garlic',
#    'ground cumin',
#    'lime zest',
#    'olive oil',
#    'onion',
#    'red bell pepper',
#    'short-grain brown rice',
#    'yellow cornmeal'}],
#  ['226001',
#   {'all-purpose flour',
#    'butter',
#    'egg',
#    'instant vanilla pudding',
#    'water',
#    'whipped dessert topping mix'}],
#  ['220186',
#   {'celery',
#    'dijon mustard',
#    'fresh ground pepper',
#    'hard-boiled eggs',
#    'milk',
#    'miracle whip',
#    'mustard',
#    'potato',
#    'salt',
#    'sugar',
#    'white onions',
#    'white pepper'}],
#  ['217201',
#   {'black pepper',
#    'butter',
#    'cayenne pepper',
#    'chili powder',
#    'dried basil',
#    'garlic powder',
#    'lemon juice',
#    'seasoning salt',
#    'soy sauce',
#    'tea bag',
#    'water',
#    'white rice'}],
#  ['194665',
#   {'bisquick',
#    'egg',
#    'feta cheese',
#    'fresh ground pepper',
#    'frozen spinach',
#    'kalamata olive',
#    'milk',
#    'onion',
#    'oregano',
#    'roasted red pepper'}],
#  ['269909',
#   {'all-purpose flour',
#    'allspice',
#    'baking powder',
#    'baking soda',
#    'cinnamon',
#    'egg',
#    'ground cloves',
#    'nutmeg',
#    'oil',
#    'pecans',
#    'pumpkin',
#    'salt',
#    'sugar',
#    'water'}],
#  ['259693',
#   {'black pepper',
#    'boneless pork chops',
#    'dry onion soup mix',
#    'long-grain rice',
#    'vegetable oil',
#    'water'}],
#  ['161370',
#   {'allspice',
#    'boneless skinless chicken breasts',
#    'brown sugar',
#    'cayenne',
#    'chili powder',
#    'chives',
#    'cinnamon',
#    'clove',
#    'crushed tomatoes',
#    'garlic',
#    'ginger',
#    'habanero pepper',
#    'jamaican jerk spice',
#    'lime juice',
#    'nutmeg',
#    'olive oil',
#    'onion',
#    'onion flakes',
#    'pepper',
#    'red peppers',
#    'rum',
#    'sage',
#    'thyme'}],
#  ['152261',
#   {'frozen limeade concentrate', 'ice', 'lime sorbet', 'mango', 'strawberry'}],
#  ['152259',
#   {'apple juice',
#    'banana',
#    'ice',
#    'non-fat vanilla frozen yogurt',
#    'strawberry'}],
#  ['303460',
#   {'coriander seed',
#    'cumin',
#    'fish sauce',
#    'fruit vinegar',
#    'garlic',
#    'hoisin sauce',
#    'red chile',
#    'sesame oil',
#    'yoghurt'}],
#  ['270259',
#   {'all-purpose flour',
#    'butter',
#    'candy cane',
#    'egg',
#    'peppermint extract',
#    'peppermint oreos',
#    'salt',
#    'sugar',
#    'unsweetened chocolate',
#    'unsweetened cocoa powder',
#    'vanilla'}],
#  ['345123',
#   {'canola oil',
#    'celery',
#    'cooked chicken breasts',
#    'cooked rice',
#    'green grapes',
#    'mandarin oranges',
#    'mayonnaise',
#    'orange juice',
#    'pineapple tidbits',
#    'salt',
#    'slivered almonds',
#    'white vinegar'}],
#  ['125195',
#   {'celery',
#    'cheddar cheese',
#    'frozen peas',
#    'hard-boiled eggs',
#    'mayonnaise',
#    'mustard',
#    'onion',
#    'seasoning salt',
#    'sugar',
#    'sweet pickle relish'}],
#  ['141939',
#   {'all-purpose flour',
#    'black pepper',
#    'butter',
#    'buttermilk',
#    'cayenne pepper',
#    'chicken pieces',
#    'dijon mustard',
#    'dried thyme',
#    'dry breadcrumbs',
#    'fresh garlic',
#    'garlic powder',
#    'hot pepper sauce',
#    'oil',
#    'onion',
#    'paprika',
#    'parmesan cheese',
#    'seasoning salt'}],
#  ['171442',
#   {'allspice',
#    'cinnamon',
#    'fresh garlic',
#    'habanero sauce',
#    'hoisin sauce',
#    'ketchup',
#    'lemon juice',
#    'louisiana hot sauce',
#    'pepper',
#    'pork baby back ribs',
#    'seasoning salt',
#    'sugar'}],
#  ['212188',
#   {'beef stock',
#    'carrot',
#    'celery',
#    'chicken leg',
#    'corn',
#    'garlic',
#    'italian seasoning',
#    'onion',
#    'peas',
#    'pepper',
#    'red bell pepper',
#    'rotini pasta',
#    'salt',
#    'spaghetti sauce'}],
#  ['262208',
#   {'aluminum foil',
#    'margarine',
#    'mexicorn whole kernel corn',
#    'pam cooking spray',
#    'salt and pepper',
#    'sour cream',
#    'spinach dip',
#    'stove top stuffing mix monterey style with mushroom and onion'}],
#  ['207857', {'cooking onions', 'pickling spices', 'white vinegar'}],
#  ['221049',
#   {'carrot',
#    'chicken broth',
#    'cooked chicken',
#    'cooked pasta',
#    'egg',
#    'peas',
#    'soy sauce'}],
#  ['221116', {'cake crumbs', 'cool whip', 'cream cheese', 'mixed fruit'}],
#  ['130819',
#   {'butter',
#    'coconut flavoring',
#    'cool whip',
#    'egg',
#    'flour',
#    'lemon flavoring',
#    'pie crust',
#    'squash',
#    'sugar'}],
#  ['20223',
#   {'black pepper',
#    'cream of mushroom soup',
#    'dijon mustard',
#    'dried onion flakes',
#    'dried parsley flakes',
#    'garlic powder',
#    'ground cinnamon',
#    'ground cloves',
#    'ground veal',
#    'salt'}],
#  ['190108',
#   {'black pepper',
#    'brown rice',
#    'catfish nuggets',
#    'chicken stock',
#    'garlic',
#    'gumbo file',
#    'lemon',
#    'mexican-style stewed tomatoes with jalapeno peppers',
#    'okra',
#    'old bay seasoning',
#    'olive oil',
#    'oregano',
#    'parsley',
#    'red onions',
#    'red wine vinegar',
#    'seafood',
#    'small shrimp',
#    'tabasco sauce',
#    'tomato soup'}],
#  ['158372',
#   {'bacon',
#    'egg',
#    'fresh chives',
#    'mild cheddar cheese',
#    'paprika',
#    'sour cream',
#    'white vinegar'}],
#  ['219681',
#   {'chicken breasts',
#    'cracked black pepper',
#    'dried basil',
#    'dried oregano',
#    'dried parsley',
#    'garlic',
#    'garlic salt',
#    'lemon juice',
#    'olive oil',
#    'salt',
#    'sandwich buns',
#    'white vinegar'}],
#  ['261215',
#   {'baking soda',
#    'boiling water',
#    'brown sugar',
#    'cinnamon',
#    'cream',
#    'egg',
#    'flour',
#    'margarine',
#    'nutmeg',
#    'nuts',
#    'quick oats',
#    'salt',
#    'shredded coconut',
#    'vanilla'}],
#  ['179640', {'butter', 'marshmallows', 'rice krispies'}],
#  ['250883',
#   {'cool whip topping',
#    'cream cheese',
#    'frozen limeade concentrate',
#    'orange juice'}],
#  ['140855',
#   {'avocado',
#    'cheddar cheese',
#    'chili powder',
#    'corn chips',
#    'garlic',
#    'green onion',
#    'lemon juice',
#    'lettuce',
#    'pitted ripe olives',
#    'salad oil',
#    'salt',
#    'sour cream',
#    'sugar',
#    'tabasco sauce',
#    'tomato',
#    'tuna'}],
#  ['120297',
#   {'baking potatoes',
#    'chickpeas',
#    'coriander',
#    'fresh coriander',
#    'garlic',
#    'ground cumin',
#    'low-fat yogurt',
#    'olive oil',
#    'salt & freshly ground black pepper',
#    'tahini'}],
#  ['130492',
#   {'baking powder',
#    'buttermilk',
#    'egg',
#    'mayonnaise',
#    'salt',
#    'sugar',
#    'vegetable oil',
#    'yellow cornmeal'}],
#  ['164634',
#   {'apple',
#    'carrot',
#    'gingerroot',
#    'green cabbage',
#    'green onion',
#    'maple syrup',
#    'red cabbage',
#    'rice vinegar',
#    'sesame oil',
#    'soy sauce'}],
#  ['293836',
#   {'black pepper',
#    'canola oil',
#    'chicken soup powder',
#    'garlic powder',
#    'long-grain rice',
#    'orzo pasta',
#    'turmeric',
#    'water'}],
#  ['169586',
#   {'avocado',
#    'celery ribs',
#    'chicken breast',
#    'chicken broth',
#    'chipotle chiles in adobo',
#    'crushed tomatoes',
#    'cumin',
#    'ear of corn',
#    'fresh cilantro',
#    'green bell pepper',
#    'jalapeno pepper',
#    'salt and pepper',
#    'white onion'}],
#  ['261296',
#   {'dried basil',
#    'egg white',
#    'eggplant',
#    'fat free mozzarella cheese',
#    'fiber one cereal',
#    'garlic powder',
#    'italian-style tomato sauce',
#    'pepper',
#    'reduced-fat parmesan cheese',
#    'salt'}],
#  ['101115', {'beef gravy', 'egg', 'ground beef', 'onion', 'white rice'}],
#  ['271594',
#   {'beans',
#    'black-eyed peas',
#    'carrot',
#    'celery ribs',
#    'garlic',
#    'great northern beans',
#    'ham',
#    'ham bone',
#    'ham soup base',
#    'navy beans',
#    'onion',
#    'pepper',
#    'pinto beans',
#    'salt',
#    'tomatoes and green chilies',
#    'water'}],
#  ['164291',
#   {'cider vinegar',
#    'feta cheese',
#    'fresh dill',
#    'garlic',
#    'light mayonnaise',
#    'red bell pepper',
#    'skinless chicken breast half'}],
#  ['251528',
#   {'cheese ravioli',
#    'garlic salt',
#    'italian seasoning',
#    'lean ground beef',
#    'mozzarella cheese',
#    'spaghetti sauce'}],
#  ['250833',
#   {'barbecue sauce',
#    'chicken pieces',
#    'lemon juice',
#    'orange marmalade',
#    'worcestershire sauce'}],
#  ['343448',
#   {'coriander',
#    'garlic powder',
#    'ground black pepper',
#    'ground red pepper',
#    'onion powder',
#    'paprika',
#    'salt',
#    'turmeric'}],
#  ['39893',
#   {'black olives',
#    'cream cheese',
#    'green onion',
#    'green pepper',
#    'lettuce',
#    'mayonnaise',
#    'mexican blend cheese',
#    'sour cream',
#    'taco seasoning mix',
#    'tomato'}],
#  ['147477',
#   {'green bell peppers',
#    'green onions',
#    'minced clams',
#    'paprika',
#    'sharp cheddar cheese',
#    'tabasco sauce',
#    'worcestershire sauce'}],
#  ['223349',
#   {'eggplants',
#    'olive oil',
#    'olives',
#    'oregano',
#    'red bell pepper',
#    'red onion',
#    'shrimp',
#    'spaghetti squash',
#    'yellow bell pepper'}],
#  ['86768',
#   {'butter', "confectioners' sugar", 'heavy cream', 'semisweet chocolate'}],
#  ['197001',
#   {'cherry pie filling',
#    'crushed pineapple',
#    'frozen whipped topping',
#    'pecans',
#    'small marshmallow',
#    'sweetened condensed milk'}],
#  ['60938',
#   {'bacon',
#    'cheddar cheese',
#    'green onions',
#    'oil',
#    'potato',
#    'salt',
#    'sour cream'}],
#  ['228491',
#   {'boneless eye of round beef steak',
#    'canola oil',
#    'mozzarella cheese',
#    'onion',
#    'parmesan cheese',
#    'pepper',
#    'pizza sauce',
#    'plain flour',
#    'salt'}],
#  ['451515',
#   {'all-purpose flour',
#    'bacon grease',
#    'boneless country-style ribs',
#    "campbell's golden mushroom soup",
#    'ground black pepper',
#    'oregano',
#    'seasoning salt',
#    'soup mix'}],
#  ['353171', {'butter', 'egg', 'flour', 'fruit', 'milk', 'sugar'}],
#  ['354039',
#   {'apples',
#    'baby carrots',
#    'butter',
#    'cardamom',
#    'crescent roll dough',
#    'ground cinnamon',
#    'honey',
#    'sugar'}],
#  ['302399',
#   {'garlic salt',
#    'italian seasoning',
#    'mozzarella cheese',
#    'olive oil',
#    'refrigerated biscuits'}],
#  ['195736',
#   {'active dry yeast', 'butter', 'flour', 'milk', 'salt', 'sugar', 'water'}],
#  ['365946',
#   {'all-purpose flour',
#    'butter',
#    'cream cheese',
#    'egg',
#    'egg yolk',
#    'egg yolks',
#    'lemon peel',
#    'salt',
#    'sugar',
#    'vanilla',
#    'whipping cream'}],
#  ['221544',
#   {'chili sauce',
#    'country-style dijon mustard',
#    'honey',
#    'little smokies sausages'}],
#  ['175306',
#   {'bacardi dark rum',
#    'grenadine',
#    "meyer's dark rum",
#    'orange curacao',
#    'orange juice',
#    'orgeat syrup',
#    'pineapple juice',
#    'prepared sweet-and-sour mix',
#    'white rum'}],
#  ['211833',
#   {'balsamic vinaigrette',
#    'condensed chicken broth',
#    'dried thyme leaves',
#    'minute white rice',
#    'onion',
#    'pork chops',
#    'red apples',
#    'sliced mushrooms',
#    'water'}],
#  ['276567',
#   {'chili powder',
#    'fresh ground black pepper',
#    'green bell peppers',
#    'horseradish',
#    'onion',
# ...
#    'baking soda',
#    'bananas',
#    'butter',
#    'egg',
#    'nuts',
#    'sugar',
#    'vanilla'}],
#  ['79425',
#   {'butter',
#    'caramels',
#    'chocolate cake mix',
#    'chocolate chips',
#    'evaporated milk',
#    'nuts'}],
#  ['213681',
#   {'baking soda',
#    'bananas',
#    'canola oil',
#    'egg',
#    'flour',
#    'raisins',
#    'salt',
#    'sugar',
#    'walnuts'}],
#  ['121712', {'cream cheese', 'thousand island dressing'}],
#  ['155344',
#   {'chili sauce', 'mayonnaise', 'onion powder', 'sweet pickle relish'}],
#  ['175339',
#   {'baking soda',
#    'brown sugar',
#    'chocolate chips',
#    'cream of tartar',
#    'egg',
#    'flaked coconut',
#    'flour',
#    'margarine',
#    'oil',
#    'rice krispies',
#    'rolled oats',
#    'vanilla',
#    'white sugar'}],
#  ['72600',
#   {'baby spinach',
#    'bacon',
#    'buttermilk',
#    'fresh lemon juice',
#    'garlic',
#    'hardboiled egg',
#    'mushrooms',
#    'plain yogurt',
#    'sugar',
#    'unsalted sunflower seeds',
#    'white pepper'}],
#  ['50614',
#   {'bacon',
#    'cauliflower',
#    'cherry tomatoes',
#    'fresh broccoli',
#    'fresh mushrooms',
#    'frozen peas',
#    'green pepper',
#    'italian seasoning',
#    'lettuce',
#    'mayonnaise',
#    'red onion',
#    'sugar'}],
#  ['133784',
#   {'basil leaves',
#    'black pepper',
#    'celery salt',
#    'chili powder',
#    'garlic powder',
#    'ground allspice',
#    'ground oregano',
#    'marjoram leaves',
#    'onion salt',
#    'paprika',
#    'rubbed sage'}],
#  ['235003', {'beer', 'fresh jalapeno', 'ice', 'vodka'}],
#  ['140723',
#   {'anchovy fillets',
#    'baby spinach',
#    'bacon',
#    'dijon mustard',
#    'extra virgin olive oil',
#    'french bread',
#    'fresh mushrooms',
#    'garlic',
#    'lemon juice',
#    'low-fat mayonnaise',
#    'miracle whip light',
#    'oil',
#    'olive oil',
#    'parmesan cheese',
#    'worcestershire sauce'}],
#  ['326839',
#   {'dried italian seasoning',
#    'egg',
#    'ground beef',
#    'ground pepper',
#    'italian cheese blend',
#    'jumbo pasta shells',
#    'mexican blend cheese',
#    'mozzarella cheese',
#    'parmesan-romano cheese mix',
#    'parsley flakes',
#    'ricotta cheese',
#    'salt',
#    'spaghetti sauce'}],
#  ['467326',
#   {'bread machine yeast',
#    'brown sugar',
#    'oil',
#    'salt',
#    'water',
#    'white flour',
#    'whole wheat flour'}],
#  ['43669',
#   {'butter',
#    'cream-style corn',
#    'evaporated milk',
#    'onion',
#    'potato',
#    'salt and pepper',
#    'water',
#    'whole corn'}],
#  ['73566',
#   {'black pepper',
#    'extra virgin olive oil',
#    'flat leaf parsley',
#    'italian seasoned breadcrumbs',
#    'kosher salt',
#    'orecchiette',
#    'parmesan cheese',
#    'prosciutto'}],
#  ['449768',
#   {'cumin seeds', 'fresh ground black pepper', 'olive oil', 'salt', 'tomato'}],
#  ['404661',
#   {'baking soda',
#    'butter',
#    'corn syrup',
#    'molasses',
#    'salted peanuts',
#    'vanilla',
#    'white sugar'}],
#  ['381713',
#   {'bulgar wheat',
#    'cinnamon',
#    'lean ground beef',
#    'onion',
#    'plain yogurt',
#    'salt'}],
#  ['257696',
#   {'apple pie filling',
#    'egg',
#    'instant vanilla pudding',
#    'oil',
#    'water',
#    'yellow cake mix'}],
#  ['187606',
#   {'boneless skinless chicken breasts',
#    'carrot',
#    'italian dressing',
#    'potato'}],
#  ['91515', {'chocolate milk', 'cinnamon rolls', 'egg'}],
#  ['289891',
#   {'baking powder',
#    'butter',
#    'egg',
#    'flour',
#    'milk',
#    'salt',
#    'vanilla',
#    'white sugar'}],
#  ['412073',
#   {'basil',
#    'carrot',
#    'celery',
#    'garlic',
#    'ham',
#    'leeks',
#    'pepper',
#    'salt',
#    'soup mix',
#    'thyme',
#    'water',
#    'worcestershire sauce'}],
#  ['123746',
#   {'bell peppers',
#    'chili sauce',
#    'egg',
#    'garlic powder',
#    'ground beef',
#    'milk',
#    'onion',
#    'salt and pepper',
#    'saltine crackers',
#    'worcestershire sauce'}],
#  ['206020',
#   {'aluminum foil',
#    'beef tenderloin',
#    'garlic',
#    'limes, juice of',
#    'prepared horseradish',
#    'salt and pepper',
#    'sour cream',
#    'unsalted butter',
#    'worcestershire sauce'}],
#  ['345595',
#   {'baking powder',
#    'baking soda',
#    'carrot',
#    'cinnamon',
#    'cream cheese',
#    'egg',
#    'flour',
#    'margarine',
#    'oil',
#    'pineapple',
#    'powdered sugar',
#    'salt',
#    'sugar',
#    'walnuts'}],
#  ['129227',
#   {'cabbage',
#    'carrot',
#    'celery seed',
#    'mustard seeds',
#    'onion',
#    'salt',
#    'sugar',
#    'turmeric',
#    'water',
#    'white vinegar'}],
#  ['472955',
#   {'alum',
#    'pickling cucumbers',
#    'pickling spices',
#    'salt',
#    'sugar',
#    'vinegar',
#    'water'}],
#  ['17490',
#   {'alum',
#    'canning salt',
#    'cucumbers',
#    'pickling spices',
#    'sugar',
#    'vinegar'}],
#  ['130002',
#   {'allspice',
#    'baking soda',
#    'carrot',
#    'cinnamon',
#    'coconut',
#    'cream cheese',
#    'egg',
#    'flour',
#    'ground cloves',
#    'margarine',
#    'nuts',
#    'oil',
#    'powdered sugar',
#    'raisins',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['53353', {'butter', 'cream', 'lemon extract', 'maple syrup', 'nutmeats'}],
#  ['105756',
#   {'basil',
#    'beans',
#    'carrot',
#    'celery',
#    'chicken bouillon cubes',
#    'chicken broth',
#    'deli ham',
#    'lemon juice',
#    'onion',
#    'parsley',
#    'raw rice',
#    'salt',
#    'tomato',
#    'v8 vegetable juice',
#    'water'}],
#  ['307362',
#   {'hormel chili without beans',
#    'monterey jack cheese',
#    'refried beans',
#    'tortillas'}],
#  ['51803',
#   {'15 bean soup mix',
#    'black pepper',
#    'celery leaves',
#    'chicken bouillon cubes',
#    'dried parsley',
#    'dried rosemary',
#    'garlic',
#    'ham hocks',
#    'olive oil',
#    'onion',
#    'salt',
#    'whole tomatoes'}],
#  ['438263',
#   {'15 bean soup mix',
#    'beef bouillon paste',
#    'black pepper',
#    'diced tomatoes',
#    'garlic',
#    'ham bone',
#    'smoked sausage',
#    'steak sauce',
#    'water',
#    'worcestershire sauce'}],
#  ['525649',
#   {'black pepper',
#    'carrot',
#    'cayenne pepper',
#    'chili powder',
#    'condensed tomato soup',
#    'dried beans',
#    'garlic',
#    'ham',
#    'lemon',
#    'olive oil',
#    'onion',
#    'oregano',
#    'paprika',
#    'salt',
#    'smoked paprika',
#    'thyme',
#    'water'}],
#  ['115160',
#   {'baking soda',
#    'egg',
#    'flour',
#    'ground walnuts',
#    'honey',
#    'liquid honey',
#    'margarine',
#    'plain sweet biscuit crumbs',
#    'sour cream',
#    'sugar'}],
#  ['168222',
#   {'capers',
#    'chicken stock',
#    'fresh chives',
#    'fresh parsley',
#    'fresh tarragon',
#    'garlic',
#    'halibut steaks',
#    'lemon juice',
#    'salt and pepper'}],
#  ['140172',
#   {'boneless sirloin steak',
#    'lipton beefy mushroom soup mix',
#    'new potatoes',
#    'oil',
#    'peas and carrots',
#    'tomato paste',
#    'water'}],
#  ['305112',
#   {'black beans',
#    'frozen corn kernels',
#    'ground beef',
#    'taco seasoning',
#    'tomatoes and green chilies'}],
#  ['53481',
#   {'cheddar cheese',
#    'ketchup',
#    'lean ground beef',
#    'minute white rice',
#    'mustard',
#    'water'}],
#  ['76887',
#   {'chili with beans',
#    'diced tomatoes',
#    'ground beef',
#    'velveeta cheese',
#    'water',
#    'white rice'}],
#  ['392598',
#   {'boneless skinless chicken breast halves',
#    'condensed cream of chicken soup',
#    'ground pepper',
#    'instant rice',
#    'paprika',
#    'vegetable oil',
#    'water'}],
#  ['113197',
#   {'cheese',
#    'chicken breast tenders',
#    'fajita seasoning mix',
#    'lime',
#    'olive oil',
#    'onion',
#    'pepper',
#    'pico de gallo',
#    'sour cream',
#    'tortilla'}],
#  ['398071',
#   {'cheddar cheese',
#    'chicken',
#    'chicken broth',
#    'kidney beans',
#    'mexicorn',
#    'salsa',
#    'sour cream',
#    'tortilla chips'}],
#  ['66527',
#   {'boneless skinless chicken breasts',
#    'broccoli florets',
#    'condensed cream of chicken soup',
#    'milk',
#    'minute rice',
#    'vegetable oil'}],
#  ['184890',
#   {'chili powder',
#    'cumin',
#    'ground turkey',
#    'kidney beans',
#    'onion',
#    'pinto beans',
#    'salsa',
#    'salt',
#    'stewed tomatoes'}],
#  ['79046',
#   {'cheese',
#    'chili with beans',
#    'flour tortillas',
#    'sour cream',
#    'water',
#    'white minute rice'}],
#  ['356163',
#   {'broccoli',
#    'chili powder',
#    'ketchup',
#    'lean ground beef',
#    'macaroni & cheese dinner mix',
#    'water'}],
#  ['41673',
#   {'allspice',
#    'brown sugar',
#    'cinnamon',
#    'clove',
#    'onion',
#    'pepper',
#    'salt',
#    'tomato'}],
#  ['506885',
#   {'crushed red pepper flakes',
#    'fresh basil',
#    'fresh oregano',
#    'fresh parmesan cheese',
#    'garlic',
#    'grape tomatoes',
#    'pappardelle pasta',
#    'pepper',
#    'roasted cashews',
#    'sun-dried tomato packed in oil'}],
#  ['277539',
#   {'chipotle chile in adobo',
#    'garlic',
#    'ground coriander',
#    'ground cumin',
#    'low sodium chicken broth',
#    'onion',
#    'salt',
#    'tomato sauce'}],
#  ['169487',
#   {'fat free cream cheese',
#    'fat-free whipped topping',
#    'reduced fat graham cracker crust',
#    'sugar substitute'}],
#  ['317587',
#   {'fresh linguine',
#    'fresh spinach',
#    'lemon juice',
#    'parmesan cheese',
#    'pesto sauce',
#    'pine nuts',
#    'red onion',
#    'tomato'}],
#  ['20624',
#   {'boneless skinless chicken breast halves',
#    'butter',
#    'chicken broth',
#    'flour',
#    'garlic',
#    'lemon juice',
#    'oil',
#    'salt and pepper'}],
#  ['360232',
#   {'celery ribs',
#    'cracked black pepper',
#    'extra virgin olive oil',
#    'feta cheese',
#    'fresh lemon juice',
#    'fresh parsley',
#    'garbanzo beans',
#    'garlic',
#    'of fresh mint',
#    'romaine lettuce',
#    'salt',
#    'scallion',
#    'tomato'}],
#  ['246548',
#   {'assorted fresh vegetables',
#    'boneless skinless chicken breast',
#    'instant rice',
#    'italian dressing',
#    'oil',
#    'reduced-sodium fat-free chicken broth'}],
#  ['67446',
#   {'butter',
#    'cream cheese',
#    'graham cracker crumbs',
#    'instant lemon pudding',
#    'milk',
#    'powdered sugar'}],
#  ['153028',
#   {'butter', 'cocoa', "confectioners' sugar", 'peanut butter', 'vanilla'}],
#  ['172651',
#   {'italian salad dressing',
#    'parmesan cheese',
#    'smoked turkey breast',
#    'spaghetti',
#    'tomato'}],
#  ['348952',
#   {'chicken bouillon cube',
#    'frozen mixed vegetables',
#    'minute rice',
#    'oil',
#    'pork tenderloin',
#    'soy sauce',
#    'water'}],
#  ['5276',
#   {'chicken bouillon cubes',
#    'green pepper',
#    'hot pepper sauce',
#    'kidney beans',
#    'minute white rice',
#    'oil',
#    'onion',
#    'water'}],
#  ['140173',
#   {'baby peas',
#    'bacon bits',
#    'black pepper',
#    'fettuccine',
#    'garlic salt',
#    'half-and-half cream',
#    'parmesan cheese',
#    'shrimp'}],
#  ['31184',
#   {'angel hair pasta',
#    'butter',
#    'extra virgin olive oil',
#    'frozen shrimp',
#    'garlic',
#    'onion',
#    'salt & pepper',
#    'white wine'}],
#  ['164178',
#   {'celery',
#    'garlic flakes',
#    'hamburger',
#    'hot chili flakes',
#    'jalapenos',
#    'onion',
#    'sliced mushrooms',
#    'sweet green pepper',
#    'sweet red pepper',
#    'tomato sauce & mushrooms'}],
#  ['289025',
#   {'asparagus',
#    'boneless skinless chicken breast',
#    'chicken broth',
#    'chili flakes',
#    'fresh ginger',
#    'garlic',
#    'onion',
#    'rice vinegar',
#    'salt',
#    'soy sauce',
#    'white pepper'}],
#  ['287502',
#   {'dijon mustard',
#    'elbow macaroni',
#    'extra-sharp cheddar cheese',
#    'fresh ground black pepper',
#    'half-and-half',
#    'hot sauce',
#    'kosher salt',
#    'unsalted butter'}],
#  ['75079',
#   {'butter',
#    'dry onion soup mix',
#    'flour',
#    'fresh mushrooms',
#    'round steak',
#    'sour cream',
#    'water'}],
#  ['147100',
#   {'chopped tomatoes',
#    'extra lean ground beef',
#    'lettuce',
#    'mexican blend cheese',
#    'minute white rice',
#    'taco seasoning mix',
#    'water'}],
#  ['233317',
#   {'baby spinach',
#    'cornflour',
#    'dark soy sauce',
#    'lime, juice and zest of',
#    'pak choi',
#    'sunflower oil',
#    'sweet chili sauce',
#    'thai fish sauce',
#    'tiger shrimp',
#    'water'}],
#  ['109793', {'milk', 'minute rice', 'raisins', 'vanilla instant pudding mix'}],
#  ['291409',
#   {'black beans', 'fire-roasted tomatoes', 'kidney beans', 'salsa', 'water'}],
#  ['27275',
#   {'cream cheese',
#    'fettuccine pasta',
#    'margarine',
#    'milk',
#    'parmesan cheese'}],
#  ['282812',
#   {'dried fruits',
#    'honey',
#    'milk',
#    'quick oats',
#    'salt',
#    'sugar',
#    'vanilla',
#    'water'}],
#  ['311608',
#   {'15 bean mix',
#    'bay leaves',
#    'carrot',
#    'celery',
#    'chicken bouillon cubes',
#    'diced tomatoes',
#    'garlic',
#    'ham hocks',
#    'onion',
#    'pepper',
#    'seasoning salt',
#    'tomato sauce',
#    'water'}],
#  ['382234',
#   {'black-eyed peas',
#    'canned green beans',
#    'chili seasoning mix',
#    'corn chips',
#    'dark red kidney beans',
#    'green bell pepper',
#    'ground beef',
#    'ketchup',
#    'onion',
#    'red pepper flakes',
#    'salt and pepper',
#    'sharp cheddar cheese',
#    'vegetable oil',
#    'water',
#    'whole tomatoes'}],
#  ['237391',
#   {'brandy',
#    'butter',
#    'chicken liver',
#    'garlic',
#    'ground black pepper',
#    'heavy cream',
#    'marjoram',
#    'onion',
#    'sage',
#    'salt',
#    'thyme'}],
#  ['266997',
#   {'cayenne pepper',
#    'chili beans',
#    'chili powder',
#    'cumin',
#    'diced tomatoes',
#    'lean ground beef',
#    'onion',
#    'oregano',
#    'salt',
#    'sliced mushrooms',
#    'sour cream'}],
#  ['21916',
#   {'cool whip topping',
#    'frozen pound cake',
#    'jello instant vanilla pudding mix',
#    'orange liqueur',
#    'strawberries',
#    'strawberry',
#    'sugar',
#    'white chocolate baking squares'}],
#  ['229451',
#   {'boneless skinless chicken breast halves',
#    'dijon mustard',
#    'dried tarragon',
#    'fresh lemon juice',
#    'pepper',
#    'worcestershire sauce'}],
#  ['204040', {'basmati rice', 'chicken broth', 'salt and pepper'}],
#  ['82287',
#   {'black olives',
#    'cooked chicken',
#    'cream of chicken soup',
#    'green enchilada sauce',
#    'green onion',
#    'lettuce',
#    'monterey jack cheese',
#    'salsa',
#    'sour cream',
#    'tomato',
#    'tortilla chips'}],
#  ['302815', {'butter', 'garlic', 'parmesan cheese', 'pasta'}],
#  ['311842',
#   {'dried oregano',
#    'feta cheese',
#    'garlic',
#    'large shrimp',
#    'old bay seasoning',
#    'olive oil',
#    'parsley',
#    'pepper',
#    'tomato'}],
#  ['531148',
#   {'cherry tomatoes',
#    'corn kernels',
#    'herbs',
#    'large shrimp',
#    'lemon, zest of',
#    'olive oil',
#    'red onion',
#    'salt & freshly ground black pepper',
#    'snap peas',
#    'unsalted butter',
#    'zucchini'}],
#  ['364157',
#   {'dried oregano',
#    'fresh lemon juice',
#    'garlic',
#    'olive oil',
#    'parmesan cheese',
#    'salt and pepper',
#    'scallions',
#    'vegetable broth',
#    'white beans'}],
#  ['411979',
#   {'bay leaves',
#    'beans',
#    'carrot',
#    'celery',
#    'chicken stock',
#    'garlic',
#    'italian sausage',
#    'onion',
#    'oregano',
#    'tomato',
#    'water'}],
#  ['102832',
#   {'alum',
#    'cinnamon sticks',
#    'cucumbers',
#    'pickling salt',
#    'pickling spices',
#    'sugar',
#    'white vinegar'}],
#  ['246180', {'barbecue sauce', 'ginger ale', 'onion', 'pork butt'}],
#  ['224908',
#   {'brown sugar',
#    'cold water',
#    'dark molasses',
#    'strong coffee',
#    'sugar',
#    'vanilla bean',
#    'vodka'}],
#  ['364761',
#   {'carrot',
#    'celery',
#    'celery ribs',
#    'chicken bouillon cubes',
#    'chicken broth',
#    'frozen corn',
#    'frozen white corn',
#    'onion',
#    'potato',
#    'whole chickens'}],
#  ['489337',
#   {'basil',
#    'eggplant',
#    'fat-free parmesan cheese',
#    'fennel seed',
#    'lean ground turkey',
#    'low-carb marinara sauce',
#    'nonstick cooking spray',
#    'oregano leaves'}],
#  ['262448', {'mountain dew soda', 'raspberry vodka'}],
#  ['294427',
#   {'apple cider',
#    'arugula',
#    'dijon mustard',
#    'fresh thyme',
#    'gouda cheese',
#    'olive oil',
#    'pancetta',
#    'red onion',
#    'red wine vinegar',
#    'salt and pepper',
#    'shallots',
#    'sherry wine vinegar',
#    'tart apples',
#    'white cheddar cheese',
#    'white vinegar'}],
#  ['328436',
#   {'baby carrots',
#    'baking powder',
#    'baking soda',
#    "confectioners' sugar",
#    'egg',
#    'flour',
#    'light brown sugar',
#    'marshmallow cream',
#    'pumpkin pie spice',
#    'pure vanilla extract',
#    'salt',
#    'unsalted butter',
#    'vegetable oil'}],
#  ['357228',
#   {'baking soda',
#    'butter',
#    'buttermilk',
#    'cinnamon',
#    'clove',
#    'cocoa',
#    'egg',
#    'flour',
#    'nutmeg',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['50246',
#   {'almonds',
#    'cornstarch',
#    'cream of tartar',
#    'egg',
#    'egg yolks',
#    'flour',
#    'milk',
#    'powdered sugar',
#    'sugar',
#    'sweet cream'}],
#  ...]

# %% [markdown]
# Reshape the data into a vector of vectors of ingredients per recipe, to use for training a [*word2vec*](https://arxiv.org/abs/1301.3781) vector embedding model:

# %%
vectors = []

for id, ind_set in recipes:
    v = []
    
    for ind in ind_set:
        v.append(ind)

    vectors.append(v)

vectors
# Out:
# [['mixed spice',
#   'salt',
#   'mexican seasoning',
#   'winter squash',
#   'butter',
#   'honey',
#   'olive oil'],
#  ['prepared pizza crust',
#   'egg',
#   'salt and pepper',
#   'milk',
#   'sausage patty',
#   'cheese'],
#  ['yellow onions',
#   'salt',
#   'tomato paste',
#   'ground cumin',
#   'rotel tomatoes',
#   'tomato soup',
#   'ground beef',
#   'kidney beans',
#   'water',
#   'cheddar cheese',
#   'chili powder',
#   'lettuce',
#   'diced tomatoes'],
#  ['salt',
#   'new potatoes',
#   'red bell pepper',
#   'tarragon',
#   'spreadable cheese with garlic and herbs',
#   'red wine vinegar',
#   'parsley',
#   'yellow bell pepper',
#   'shallots',
#   'olive oil',
#   'pepper'],
#  ['dry mustard',
#   'salt',
#   'cinnamon oil',
#   'tomato juice',
#   'apple cider vinegar',
#   'clove oil',
#   'pepper',
#   'sugar'],
#  ['milk', 'vanilla ice cream', 'frozen apple juice concentrate', 'apple'],
#  ['ripe olives',
#   'red chile',
#   'garlic',
#   'orange rind',
#   'orange juice',
#   'extra virgin olive oil',
#   'fennel seeds',
#   'peppercorn',
#   'green olives'],
#  ['soy sauce',
#   'tomato sauce',
#   'water',
#   'honey',
#   'mirin',
#   'a.1. original sauce',
#   'fresh garlic',
#   'white vinegar',
#   'brown sugar',
#   'liquid smoke',
#   'pork spareribs',
#   'yellow onion',
#   'fresh ginger',
#   'dry mustard',
#   'fresh cilantro leaves',
#   'orange, juice of',
#   'fresh coarse ground black pepper',
#   'chili powder',
#   'salt',
#   'cinnamon sticks',
#   'cracked black pepper',
#   'cumin'],
#  ['vanilla ice cream',
#   'bananas',
#   'chocolate syrup',
#   'whipped cream',
#   'strawberry ice cream',
#   'chocolate sandwich style cookies'],
#  ['orange rind',
#   'salt',
#   'unsalted butter',
#   'bananas',
#   'baking soda',
#   'egg',
#   'fresh lemon juice',
#   'cake flour',
#   'sugar'],
#  ['prepared horseradish', 'sour cream', 'whole berry cranberry sauce'],
#  ['strawberry',
#   'vanilla wafers',
#   'walnuts',
#   'powdered sugar',
#   'egg',
#   'whipping cream',
#   'butter'],
#  ['dark brown sugar',
#   'bacon',
#   'salt',
#   'mustard powder',
#   'great northern bean',
#   'cornstarch',
#   'molasses',
#   'chicken bouillon cubes',
#   'chili powder',
#   'water',
#   'garlic powder',
#   'onion',
#   'black pepper'],
#  ['whiskey',
#   'salt',
#   'brown sugar',
#   'ham hock',
#   'molasses',
#   'hot sauce',
#   'collard greens'],
#  ['spearmint', 'scullcap herb', 'wood bethony', 'burnet root', 'gentian root'],
#  ['flour',
#   'dry mustard',
#   'chicken rice soup',
#   'salt',
#   'oil',
#   'garlic powder',
#   'lean pork chops'],
#  ['egg roll wrap', 'oil', 'cornstarch', 'whole green chilies', 'cheese'],
#  ['butterscotch chips', 'chinese noodles', 'salted peanuts'],
#  ['celery',
#   'soy sauce',
#   'beef broth',
#   'ground pork',
#   'cooking oil',
#   'hamburger buns',
#   'onion'],
#  ['broccoli floret',
#   'garlic',
#   'red bell pepper',
#   'fresh herb',
#   'green peas',
#   'potato',
#   'cauliflower',
#   'vegetable bouillon cubes',
#   'ground coriander',
#   'great northern bean',
#   'salt and pepper',
#   'canola oil',
#   'water',
#   'escarole',
#   'onion',
#   'salt free herb and spice seasoning mix'],
#  ['coarse salt',
#   'salt',
#   'fresh ground black pepper',
#   'unsalted butter',
#   'boiling potatoes',
#   'fresh spinach leaves',
#   'water',
#   'nutmeg'],
#  ['celery',
#   'salt',
#   'apple juice',
#   'dried thyme',
#   'fresh parsley',
#   'spinach',
#   'olive oil',
#   'broth',
#   'scallion',
#   'white pepper',
#   'rolled oats',
#   'onion'],
#  ['seasoning salt',
#   'paprika',
#   'egg',
#   'all-purpose flour',
#   'oil',
#   'cornstarch',
#   'salt and pepper',
#   'boneless skinless chicken breast halves',
#   'garlic powder',
#   'condensed cream of chicken soup'],
#  ['salt',
#   'bread',
#   'brown sugar',
#   'granulated sugar',
#   'powdered sugar',
#   'egg',
#   'ground cinnamon',
#   'vegetable oil',
#   'milk',
#   'all-purpose flour',
#   'butter',
#   'vanilla',
#   'baking powder'],
#  ['salt', 'lemon, juice of', 'butter', 'white pepper', 'egg yolks'],
#  ['ground turmeric',
#   'ground black pepper',
#   'ground cumin',
#   'ground coriander',
#   'ground ginger',
#   'black cumin'],
#  ['green pepper',
#   'jalapenos',
#   'celery',
#   'garlic',
#   'salt',
#   'red pepper flakes',
#   'vegetarian ground beef',
#   'chili powder',
#   'kidney beans',
#   'onion',
#   'black pepper',
#   'diced tomatoes'],
#  ['beef bouillon cube',
#   'parmesan cheese',
#   'salt',
#   'garbanzo beans',
#   'beef stew meat',
#   'ground thyme',
#   'dried parsley',
#   'cabbage',
#   'water',
#   'ground pepper',
#   'elbow macaroni',
#   'onion',
#   'zucchini',
#   'tomato'],
#  ['red potatoes', 'rosemary', 'margarine'],
#  ['celery',
#   'worcestershire sauce',
#   'carrot',
#   'broccoli floret',
#   'dry white wine',
#   'dried sweet basil leaves',
#   'unsalted butter',
#   'black beans',
#   'dried thyme',
#   'tabasco sauce',
#   'salt & fresh ground pepper',
#   'cornstarch',
#   'heavy cream',
#   'smoked chicken',
#   'chicken stock',
#   'dried oregano',
#   'broccoli stem',
#   'onion'],
#  ['salt',
#   'egg',
#   'vanilla',
#   'baking cocoa',
#   'all-purpose flour',
#   'butter',
#   'miniature peppermint patties',
#   'baking powder',
#   'sugar'],
#  ['hot chili pepper',
#   'salt',
#   'tomato sauce',
#   'whole kernel corn',
#   'tabasco sauce',
#   'sliced ripe olives',
#   'cornmeal',
#   'ground beef',
#   'taco sauce',
#   'onion',
#   'cheddar cheese',
#   'pepper'],
#  ['french bread', 'dry ranch dressing mix', 'butter'],
#  ['worcestershire sauce',
#   'ground venison',
#   'dry mustard',
#   'salt',
#   'non-fat powdered milk',
#   'fresh breadcrumb',
#   'egg substitute',
#   'water',
#   'onion',
#   'black pepper'],
#  ['milk', 'plain yogurt', 'frozen juice concentrate'],
#  ['green beans',
#   'carrot',
#   'low sodium chicken broth',
#   'potato',
#   'zucchini',
#   'wax beans',
#   'corn',
#   'diced tomatoes'],
#  ['salt',
#   'sharp cheddar cheese',
#   'egg',
#   'frozen chopped spinach',
#   'crouton',
#   'condensed cream of mushroom soup',
#   'onion',
#   'black pepper'],
#  ['red potatoes',
#   'garlic',
#   'salt',
#   'white wine vinegar',
#   'celery seed',
#   'diced pimentos',
#   'low-fat sour cream',
#   'fat-free mayonnaise',
#   'green onion',
#   'plain low-fat yogurt',
#   'prepared mustard',
#   'pepper',
#   'sugar'],
#  ['soft breadcrumbs',
#   'margarine',
#   'egg',
#   'oregano',
#   'sage',
#   'frozen chopped spinach',
#   'garlic powder',
#   'onion'],
#  ['cream of mushroom soup',
#   'cornbread mix',
#   'salt & pepper',
#   'cooking oil',
#   'frozen vegetables',
#   'ground beef',
#   'onion',
#   'condensed cream of mushroom & garlic soup'],
#  ['green onions',
#   'soy sauce',
#   'toasted sesame oil',
#   'garlic',
#   'toasted sesame seeds',
#   'angel hair pasta',
#   'stir fry vegetables',
#   'honey'],
#  ['buckwheat flour',
#   'baking soda',
#   'butter',
#   'honey',
#   'brown sugar',
#   'ground cinnamon',
#   'canola oil',
#   'baking powder',
#   'sugar',
#   'orange juice',
#   'yam',
#   'flour',
#   'ground cloves',
#   'unsweetened cocoa',
#   'orange rind',
#   'salt',
#   'low-fat buttermilk',
#   'cinnamon',
#   'egg',
#   'all-purpose flour',
#   'pecans'],
#  ['ground cloves',
#   'orange rind',
#   'unsweetened cocoa',
#   'buckwheat flour',
#   'salt',
#   'baking soda',
#   'low-fat buttermilk',
#   'granulated sugar',
#   'egg',
#   'orange juice',
#   'ground cinnamon',
#   'sorghum',
#   'canola oil',
#   'all-purpose flour',
#   'baking powder',
#   'boiling water',
#   'raisins',
#   'yam'],
#  ['prepared yellow mustard',
#   'garlic',
#   'salt & pepper',
#   'sugar',
#   'cayenne',
#   'ground beef',
#   'beer',
#   'american cheese'],
#  ['water chestnut',
#   'ripe olives',
#   'dill pickles',
#   'cider vinegar',
#   'italian seasoning',
#   'salt and pepper',
#   'cheese',
#   'sweet pepper',
#   'green onion',
#   'onion powder',
#   'garlic powder',
#   'ham',
#   'chives',
#   'olive oil',
#   'tomato',
#   'tri-color spiral pasta'],
#  ['parmesan cheese',
#   'frozen french fries',
#   'oregano',
#   'salt & freshly ground black pepper',
#   'oil',
#   'basil',
#   'flat leaf parsley'],
#  ['sandwich bun',
#   'ham',
#   'swiss cheese',
#   'mozzarella cheese',
#   'pepperoni',
#   'good seasonings italian salad dressing mix',
#   'deli turkey',
#   'butter',
#   'cheddar cheese'],
#  ['salt',
#   'egg',
#   'icing sugar',
#   'milk',
#   'shortening',
#   'all-purpose flour',
#   'butter',
#   'vanilla',
#   'baking powder',
#   'sugar'],
#  ['carrot',
#   'cinnamon',
#   'vanilla instant pudding mix',
#   'egg',
#   'yellow cake mix',
#   'oil',
#   'crushed pineapple',
#   'water',
#   'nutmeg',
#   'coconut',
#   'pecans'],
#  ['jalapenos',
#   'red bell pepper',
#   'sharp cheddar cheese',
#   'egg',
#   'whole kernel corn',
#   'heavy cream',
#   'butter',
#   'honey',
#   'jiffy corn muffin mix',
#   'onion'],
#  ['flour',
#   'dry yeast',
#   'cinnamon',
#   'salt',
#   'baking soda',
#   'brown sugar',
#   'egg',
#   'crushed pineapple',
#   'vegetable oil',
#   'milk',
#   'sugar',
#   'water',
#   'butter',
#   'vanilla',
#   'baking powder',
#   'raisins',
#   'nuts'],
#  ['parmesan cheese',
#   'garlic',
#   'salt',
#   'italian sausage',
#   'ground black pepper',
#   'lasagna noodle',
#   'dried basil',
#   'egg',
#   'tomato paste',
#   'mozzarella cheese',
#   'ricotta cheese',
#   'whole tomato',
#   'cottage cheese',
#   'ground beef',
#   'parsley flakes'],
#  ['toasted wheat germ',
#   'salt',
#   'beef',
#   'egg',
#   'herbs',
#   'frozen chopped spinach',
#   'cheese',
#   'cottage cheese',
#   'olive oil flavored cooking spray',
#   'spices',
#   'pepper'],
#  ['cinnamon',
#   'rolls',
#   'brown sugar',
#   'instant vanilla pudding',
#   'butter',
#   'raisins'],
#  ['garlic',
#   'white onion',
#   'stewed tomatoes',
#   'granulated sugar',
#   'prego spaghetti sauce',
#   'ground beef'],
#  ['sour cream',
#   'dried dill weed',
#   'brown sugar',
#   'fresh lemon juice',
#   'beef steaks',
#   'vegetable oil',
#   'fresh parsley',
#   'hot sauce',
#   'spicy mustard',
#   'ketchup',
#   'honey',
#   'fresh garlic'],
#  ['flour', 'salt', 'egg', 'milk', 'butter', 'baking powder', 'sugar'],
#  ['salsa',
#   'button mushrooms',
#   'chicken breasts',
#   'garlic',
#   'parmesan cheese',
#   'pasta',
#   'dried basil',
#   'fresh parsley',
#   'hot sauce',
#   'water',
#   'dried oregano',
#   'fresh ground black pepper',
#   'olive oil',
#   'tomato',
#   'onion'],
#  ['cider vinegar', 'fresh herbs', 'fresh herb'],
#  ['flour',
#   'salt',
#   'egg',
#   'fresh corn',
#   'fat',
#   'baking powder',
#   'pepper',
#   'cream'],
#  ['cheddar cheese soup',
#   'black olives',
#   'fettuccine pasta',
#   'milk',
#   'jalapeno',
#   'picante sauce'],
#  ['frozen peas',
#   'salt',
#   'lemons, juice of',
#   'hass avocado',
#   'onion',
#   'tomato',
#   'cilantro'],
#  ['worcestershire sauce',
#   'soy sauce',
#   'lemon juice',
#   'oil',
#   'basil',
#   'garlic powder',
#   'pepper'],
#  ['cream cheese', 'yogurt', 'unflavored gelatin', 'apple', 'milk', 'pear'],
#  ['bacon',
#   'carrot',
#   'salt',
#   'oil',
#   'veal roast',
#   'butter',
#   'onion',
#   'parsley sprigs',
#   'thyme',
#   'pepper',
#   'bay leaf'],
#  ['crackers', 'black pepper', 'tomato', 'mayonnaise'],
#  ['carrot',
#   'garlic',
#   'sweet onion',
#   'oregano leaves',
#   'kalamata olive',
#   'capers',
#   'brine',
#   'fresh basil',
#   'fresh parsley',
#   'red wine vinegar',
#   'ciabatta',
#   'green olives',
#   'provolone cheese',
#   'ham',
#   'genoa salami',
#   'olive oil',
#   'tomato'],
#  ['vanilla instant pudding mix',
#   'powdered sugar',
#   'vanilla',
#   'whipping cream'],
#  ['cream cheese',
#   'prepared graham cracker crusts',
#   'milk',
#   'gelatin',
#   'vanilla',
#   'cookie',
#   'miniature semisweet chocolate chips',
#   'sugar'],
#  ['soy sauce',
#   'carrot',
#   'oregano',
#   'cayenne pepper',
#   'water',
#   'butter',
#   'celery',
#   'monterey jack cheese',
#   'zucchini',
#   'baking powder',
#   'tomato',
#   'ground cumin',
#   'vegetable shortening',
#   'chili powder',
#   'cloves',
#   'green pepper',
#   'flour',
#   'salt',
#   'egg',
#   'sliced mushrooms',
#   'all-purpose flour',
#   'onion'],
#  ['half-and-half', 'sweet butter', 'salt and pepper', 'sweet corn'],
#  ['salt',
#   'yogurt',
#   'baking soda',
#   'egg',
#   'lemon, rind of',
#   'all-purpose flour',
#   'butter',
#   'vanilla',
#   'sugar'],
#  ['flour',
#   'egg',
#   'butter',
#   'vanilla',
#   'unsweetened chocolate squares',
#   'sugar',
#   'nuts'],
#  ['green onions',
#   'reduced sodium soy sauce',
#   'broccoli',
#   'sesame oil',
#   'fresh ginger',
#   'vegetable oil',
#   'rice vinegar',
#   'vermicelli',
#   'fresh cilantro',
#   'sesame seeds',
#   'chili-garlic sauce',
#   'cooked chicken'],
#  ['apples',
#   'orange rind',
#   'celery',
#   'orange juice',
#   'sugar',
#   'philadelphia cream cheese',
#   'pecans'],
#  ['cumin',
#   'garlic',
#   'salt',
#   'lemon juice',
#   'boneless chicken breast',
#   'paprika',
#   'cayenne',
#   'olive oil',
#   'thyme',
#   'fresh ground pepper'],
#  ['parmesan cheese',
#   'baking potato',
#   'oregano leaves',
#   'tomato sauce',
#   'mozzarella cheese',
#   'part-skim ricotta cheese',
#   'garlic powder'],
#  ['white wine',
#   'tabasco sauce',
#   'sodium-free vegetable broth',
#   'cornstarch',
#   'tomato puree',
#   'onion',
#   'black pepper',
#   'mushroom pieces'],
#  ['garlic',
#   'salt',
#   'red sweet bell peppers',
#   'light olive oil',
#   'fresh basil',
#   'scallions',
#   'red wine vinegar',
#   'white kidney beans',
#   'bibb lettuce',
#   'black pepper',
#   'albacore tuna in water'],
#  ['carrot',
#   'garlic',
#   'rubbed sage',
#   'oregano',
#   'crushed tomatoes',
#   'beef consomme',
#   'butter',
#   'black pepper',
#   'olive oil',
#   'celery',
#   'dry white wine',
#   'milk',
#   'red pepper flakes',
#   'nutmeg',
#   'bacon',
#   'penne pasta',
#   'salt',
#   'ground pork',
#   'onion',
#   'lean ground beef'],
#  ['apples', 'red cinnamon candies', 'water', 'sugar substitute'],
#  ['green pepper',
#   'celery',
#   'lemon juice',
#   'brown sugar',
#   'elbow macaroni',
#   'oil',
#   'cucumber',
#   'ketchup',
#   'onion',
#   'tomato'],
#  ['flour',
#   'hot water',
#   'salt',
#   'brown sugar',
#   'cocoa',
#   'vegetable oil',
#   'milk',
#   'vanilla',
#   'baking powder',
#   'sugar'],
#  ['flour',
#   'salt',
#   'powdered sugar',
#   'egg',
#   'apple pie filling',
#   'milk',
#   'toasted almonds',
#   'butter'],
#  ['mayonnaise', 'white bread', 'bananas'],
#  ['dry white wine',
#   'poultry seasoning',
#   'salt',
#   'fresh ground black pepper',
#   'breadcrumbs',
#   'dried thyme',
#   'all-purpose flour',
#   'vegetable oil',
#   'milk',
#   'chicken stock',
#   'garlic powder',
#   'dried oregano',
#   'lean ground beef',
#   'boneless skinless chicken thighs',
#   'onion'],
#  ['cream cheese', 'salt', 'lemon juice', 'liquid smoke', 'onion', 'salmon'],
#  ['soy sauce',
#   'carrot',
#   'garlic',
#   'vegetable stock',
#   'bean sprouts',
#   'peanut oil',
#   'water',
#   'sambal oelek',
#   'ginger',
#   'brown sugar',
#   'peanuts',
#   'ground coriander',
#   'desiccated coconut',
#   'tomato',
#   'ground cumin',
#   'tempeh',
#   'red chili pepper',
#   'green beans',
#   'ground cayenne pepper',
#   'onion'],
#  ['lemon juice',
#   'egg',
#   'salt and pepper',
#   'tomato soup',
#   'ground beef',
#   'water',
#   'dried breadcrumbs',
#   'sugar',
#   'onion'],
#  ['avocado',
#   'chunky salsa',
#   'soft silken tofu',
#   'salt and pepper',
#   'hot sauce',
#   'fresh cilantro',
#   'lime juice'],
#  ['flour',
#   'ground cloves',
#   'cinnamon',
#   'salt',
#   'bananas',
#   'baking soda',
#   'walnuts',
#   'egg',
#   'white sugar',
#   'shortening',
#   'nutmeg'],
#  ['dried basil',
#   'salt and pepper',
#   'boneless skinless chicken breast',
#   'olive oil',
#   'lime juice',
#   'tomato'],
#  ['worcestershire sauce',
#   'salt',
#   'brown sugar',
#   'beef ribs',
#   'fresh lemon juice',
#   'vegetable oil',
#   'water',
#   'mustard',
#   'ketchup',
#   'onion'],
#  ['egg whites', 'green grape', 'sugar'],
#  ['betty crocker fudge brownie mix',
#   'egg',
#   'vegetable oil',
#   'water',
#   'milk chocolate candy bars'],
#  ['flour',
#   'salt',
#   'bananas',
#   'baking soda',
#   'chocolate chips',
#   'egg',
#   'water',
#   'butter',
#   'baking powder',
#   'sugar',
#   'nuts'],
#  ['cream cheese',
#   'flour',
#   'sour cream',
#   'brown sugar',
#   'chocolate chips',
#   'egg',
#   'oreo cookie crumbs',
#   'butter',
#   'vanilla',
#   'sweetened condensed milk'],
#  ['banana',
#   'sugar-free non-fat vanilla yogurt',
#   '2% low-fat milk',
#   'natural-style peanut butter'],
#  ['cream cheese',
#   'sour cream',
#   'taco seasoning',
#   'cheddar cheese',
#   'bean dip'],
#  ['bacon',
#   "mccormick's montreal brand steak seasoning",
#   'dill weed',
#   'iceberg lettuce',
#   'no-salt-added ketchup',
#   'ground sirloin',
#   'onion',
#   'tomato',
#   'american cheese'],
#  ['salt',
#   'chopped tomato',
#   'chat masala',
#   'paprika',
#   'potato',
#   'cucumber',
#   'plain yogurt'],
#  ['carrot',
#   'cinnamon',
#   'natural bran',
#   'salt',
#   'brown sugar',
#   'baking soda',
#   'corn oil',
#   'buttermilk',
#   'egg',
#   'whole wheat flour',
#   'vanilla',
#   'raisins'],
#  ['lime wedge',
#   'tequila',
#   'triple sec',
#   'limeade',
#   'grand marnier',
#   'lime juice'],
#  ['flour', 'brown sugar', 'semi-sweet chocolate chips', 'butter', 'pecans'],
#  ['garlic',
#   'salt',
#   'chopped tomato',
#   'cappelletti pasta',
#   'milk',
#   'mushrooms',
#   'tomato soup',
#   'ground beef',
#   'butter',
#   'onion',
#   'cheddar cheese',
#   'corn',
#   'pepper'],
#  ['hot water',
#   'dry white wine',
#   'garlic',
#   'squid',
#   'tomato sauce',
#   'extra virgin olive oil',
#   'salt and pepper',
#   'parsley',
#   'spaghetti'],
#  ['flour',
#   'vinegar',
#   'salt',
#   'baking soda',
#   'cocoa',
#   'vegetable oil',
#   'water',
#   'vanilla',
#   'sugar'],
#  ['clove', 'applesauce', 'pork loin chops', 'brown sugar'],
#  ['cream cheese',
#   'turkey',
#   'radish sprouts',
#   'honey mustard',
#   'ham',
#   'swiss cheese',
#   'whole wheat bread dough',
#   'roast beef',
#   'provolone cheese',
#   'leaf lettuce',
#   'butter',
#   'green olives',
#   'cheddar cheese',
#   'prepared horseradish',
#   'roasted red peppers',
#   'mayonnaise'],
#  ['flour',
#   'sour cream',
#   'beef broth',
#   'lemon, juice of',
#   'fresh dill',
#   'salt and pepper',
#   'water',
#   'butter',
#   'onion',
#   'wild mushrooms'],
#  ['green onions',
#   'carrot',
#   'garlic',
#   'english cucumber',
#   'sesame oil',
#   'fresh ginger',
#   'rice wine vinegar',
#   'asian chili sauce',
#   'bean sprouts',
#   'honey',
#   'fresh cilantro',
#   'light soy sauce',
#   'rice noodles'],
#  ['bittersweet chocolate',
#   'unsalted butter',
#   'granulated sugar',
#   'egg',
#   'kosher salt',
#   'brewed espresso',
#   'unsweetened cocoa powder',
#   'all-purpose flour',
#   'vanilla'],
#  ['dr. pepper cola', 'orange marmalade', 'brown sugar'],
#  ['salt',
#   'sesame oil',
#   'gingerroot',
#   'scallions',
#   'fish',
#   'rice wine',
#   'peanut oil',
#   'low sodium soy sauce',
#   'white pepper'],
#  ['flour',
#   'parmesan cheese',
#   'garlic',
#   'romano cheese',
#   'french bread',
#   'beef broth',
#   'low sodium beef broth',
#   'swiss cheese',
#   'sherry wine',
#   'sugar',
#   'butter',
#   'olive oil',
#   'yellow onions'],
#  ['salt',
#   'brown sugar',
#   'baking soda',
#   'margarine',
#   'chocolate chips',
#   'egg',
#   'whole wheat flour',
#   'water',
#   'white sugar',
#   'all-purpose flour',
#   'vanilla'],
#  ['squash',
#   'egg',
#   'sage',
#   'butter',
#   'onion',
#   'cornbread',
#   'cream of chicken soup'],
#  ['salt',
#   'italian sausage',
#   'white onion',
#   'tomato sauce',
#   'paprika',
#   'dried basil',
#   'dried parsley',
#   'garlic powder',
#   'dried oregano',
#   'bay leaves',
#   'olive oil',
#   'pepper',
#   'sugar',
#   'bottled garlic'],
#  ['soy sauce',
#   'salt',
#   'ground black pepper',
#   'sharp cheddar cheese',
#   'frozen broccoli cuts',
#   'milk',
#   'garlic powder',
#   'french-fried onions',
#   'cream of chicken soup'],
#  ['egg',
#   'almond extract',
#   'all-purpose flour',
#   'whole milk',
#   'butter',
#   'pure vanilla extract',
#   'sugar'],
#  ['unsalted butter',
#   'egg',
#   'unseasoned breadcrumbs',
#   'oil',
#   'artichoke hearts',
#   'fresh garlic'],
#  ['chicken',
#   'worcestershire sauce',
#   'hot red pepper sauce',
#   'salt',
#   'cider vinegar',
#   'chili powder',
#   'black pepper',
#   'barbecue sauce'],
#  ['cream cheese',
#   'sour cream',
#   'frozen broccoli',
#   'dry onion soup mix',
#   'water chestnuts',
#   'cheddar cheese',
#   'ritz cracker crumbs'],
#  ['flour',
#   'salt',
#   'baking soda',
#   'milk',
#   'instant chocolate pudding mix',
#   'sugar',
#   'cool whip',
#   'water',
#   'vanilla',
#   'cocoa powder',
#   'mayonnaise'],
#  ['lean chuck',
#   'flour',
#   'unsweetened cocoa',
#   'hunts tomato sauce',
#   'oregano leaves',
#   'garlic',
#   'cumin',
#   'budweiser beer',
#   'paprika',
#   'cornmeal',
#   'lean pork',
#   'water',
#   'chili powder',
#   'onion',
#   'coriander',
#   'louisiana hot sauce',
#   'sugar',
#   'bouillon'],
#  ['red bell pepper',
#   'unsalted butter',
#   'simply potatoes shredded hash browns',
#   'egg',
#   'kosher salt',
#   'fresh garlic',
#   'unsmoked bacon',
#   'meatloaf mixture',
#   'olive oil',
#   'yellow onion',
#   'goat cheese',
#   'white pepper',
#   'baby spinach'],
#  ['dark brown sugar',
#   'pumpkin puree',
#   'ground cloves',
#   'salt',
#   'egg',
#   'ground cinnamon',
#   'pie crusts',
#   'milk',
#   'ground ginger',
#   'nutmeg',
#   'egg white',
#   'heavy cream'],
#  ['flour',
#   'poultry seasoning',
#   'salt',
#   'sour cream',
#   'beef',
#   'baking powder',
#   'paprika',
#   'celery seed',
#   'dry onion flakes',
#   'breadcrumbs',
#   'vegetable oil',
#   'milk',
#   'butter',
#   'onion',
#   'poppy seed',
#   'cream of chicken soup'],
#  ['flour',
#   'brown sugar',
#   'hershey chocolate candy bars',
#   'baking soda',
#   'egg',
#   'blended oatmeal',
#   'semi-sweet chocolate chips',
#   'butter',
#   'vanilla',
#   'baking powder',
#   'sugar',
#   'nuts'],
#  ['flour',
#   'salt',
#   'brown sugar',
#   'baking soda',
#   'chocolate chips',
#   'egg',
#   'oatmeal',
#   'white sugar',
#   'butter',
#   "hershey's semi-sweet baking chocolate",
#   'vanilla',
#   'baking powder',
#   'nuts'],
#  ['flour', 'granulated sugar', 'milk', 'butter', 'vanilla'],
#  ['salsa',
#   'taco seasoning',
#   'corn cobs',
#   'ground beef',
#   'taco shells',
#   'cheddar cheese',
#   'lettuce',
#   'tomato',
#   'onion'],
#  ['stewing pork',
#   'tortilla chips',
#   'garlic',
#   'white onion',
#   'beef broth',
#   'dark chocolate chips',
#   'black pepper',
#   'beef bouillon cube',
#   'chunky salsa',
#   'light brown sugar',
#   'ground coriander',
#   'beans',
#   'stewing beef',
#   'sazon goya',
#   'tomato paste',
#   'chicken bouillon cube',
#   'mexican chili powder',
#   'cinnamon',
#   'bell peppers',
#   'salt',
#   'cumin',
#   'habanero pepper'],
#  ['cream cheese',
#   'salt',
#   'baking soda',
#   'brown sugar',
#   'pitted dates',
#   'tequila',
#   'egg',
#   'powdered sugar',
#   'all-purpose flour',
#   'triple sec',
#   'shortening',
#   'butter',
#   'lime zest',
#   'warm water',
#   'lemon zest',
#   'pecans',
#   'orange-flavored liqueur'],
#  ['celery',
#   'potato flakes',
#   'carrot',
#   'bouillon cubes',
#   'cream of celery soup',
#   'potato',
#   'milk',
#   'water',
#   'butter',
#   'onion',
#   'cream of chicken soup'],
#  ['flour',
#   'apples',
#   'cinnamon',
#   'salt',
#   'egg',
#   'lemon, juice of',
#   'milk',
#   'sugar',
#   'butter',
#   'cream'],
#  ['garlic',
#   'salt',
#   'milk',
#   'fresh coarse ground black pepper',
#   'macaroni',
#   'butter',
#   'onion',
#   'cheese'],
#  ['muscat wine',
#   'salt water',
#   'fine semolina',
#   'unsalted butter',
#   'potato',
#   'macaroni',
#   'onion',
#   'black pepper',
#   'cheese',
#   'heavy cream'],
#  ['penne pasta',
#   'potato',
#   'applesauce',
#   'milk',
#   'salt and pepper',
#   'butter',
#   'onion',
#   'cheese'],
#  ['pork', 'dried yellow peas', 'salt', 'ginger', 'water'],
#  ['carrot',
#   'salt',
#   'dried yellow peas',
#   'clove',
#   'dried thyme',
#   'brown mustard',
#   'ham bone',
#   'ground ginger',
#   'water',
#   'onion',
#   'pepper'],
#  ['nutmeg', 'water', 'fresh spinach', 'butter'],
#  ['salt',
#   'wondra flour',
#   'ground black pepper',
#   'granulated sugar',
#   'paprika',
#   'ground pork',
#   'tomato paste',
#   'cornstarch',
#   'water',
#   'ground beef',
#   'garlic powder',
#   'chili powder',
#   'dried onion flakes',
#   'white vinegar'],
#  ['dark brown sugar',
#   'salt',
#   'liquid smoke',
#   'oregano',
#   'applesauce',
#   'maple syrup',
#   'apple cider vinegar',
#   'granulated garlic',
#   'cayenne',
#   'ponzu sauce',
#   'tomato ketchup'],
#  ['flour',
#   'salt',
#   'sour cream',
#   'baking soda',
#   'egg',
#   'butter',
#   'vanilla',
#   'baking powder',
#   'sugar'],
#  ['vanilla ice cream', 'frozen whipped topping', 'oreo cookies', 'butter'],
#  ['processed cheese', 'white bread', 'butter'],
#  ['worcestershire sauce',
#   'soy sauce',
#   'rosemary',
#   'garlic',
#   'balsamic vinegar',
#   'fresh ground black pepper',
#   'london broil beef',
#   'olive oil'],
#  ['fresh mushrooms',
#   'parmesan cheese',
#   'garlic',
#   'nonfat dry milk powder',
#   'margarine',
#   'chicken broth',
#   'teriyaki sauce',
#   'dried thyme',
#   'salt and black pepper',
#   'cornstarch',
#   'hot pepper sauce',
#   'spicy brown mustard',
#   'dried rosemary',
#   'dried oregano',
#   'dry sherry',
#   'nonfat milk'],
#  ['cream cheese',
#   'almonds',
#   'cinnamon',
#   'sour cream',
#   'egg',
#   'butter',
#   'nutmeg',
#   'vanilla',
#   'splenda sugar substitute',
#   'vanilla protein powder'],
#  ['bacon', 'real maple syrup', 'butter', 'refrigerated buttermilk biscuits'],
#  ['worcestershire sauce',
#   'horseradish',
#   'tabasco sauce',
#   'velveeta cheese',
#   'mayonnaise'],
#  ['red wine vinegar', 'lemon juice', 'water'],
#  ['old fashioned oats',
#   'berries',
#   'sugar-free syrup',
#   'water',
#   "i can't believe it's not butter spread",
#   'ground flax seeds'],
#  ['flour',
#   'cream cheese',
#   'salt',
#   'french bread',
#   'powdered sugar',
#   'egg',
#   'milk',
#   'maple syrup',
#   'blueberries',
#   'frozen blueberries',
#   'vanilla',
#   'sugar',
#   'nuts'],
#  ['red potatoes',
#   'bacon',
#   'celery',
#   'salt',
#   'sour cream',
#   'chicken broth',
#   'liquid smoke',
#   'velveeta cheese',
#   'onion',
#   'cheddar cheese',
#   'chives',
#   'white pepper'],
#  ['flour',
#   'cream cheese',
#   'cinnamon',
#   'salt',
#   'brown sugar',
#   'granulated sugar',
#   'active dry yeast',
#   'egg',
#   'powdered sugar',
#   'milk',
#   'vanilla pudding mix',
#   'butter',
#   'warm water'],
#  ['garlic',
#   'part-skim mozzarella cheese',
#   'red bell pepper',
#   'spaghetti squash',
#   'reduced-fat parmesan cheese',
#   'asparagus',
#   'italian seasoning',
#   'salt and pepper',
#   'white mushroom',
#   'spaghetti sauce'],
#  ['lemon juice',
#   'margarine',
#   'frozen pineapple concentrate',
#   'oil',
#   'graham cracker crumbs',
#   'vegan cream cheese',
#   'soft silken tofu',
#   'maple syrup',
#   'vegan sugar',
#   'cornstarch',
#   'water',
#   'coriander',
#   'vanilla'],
#  ['celery',
#   'garlic',
#   'low sodium chicken broth',
#   'large raw shrimp',
#   'vegetable oil',
#   'andouille sausage',
#   'frozen black-eyed peas',
#   'all-purpose flour',
#   'onion',
#   'green bell pepper',
#   'creole seasoning',
#   'cooked chicken'],
#  ['egg',
#   'thousand island dressing',
#   'salt and pepper',
#   'cracker',
#   'pickle',
#   'ground beef',
#   'onion',
#   'cheddar cheese'],
#  ['parmesan cheese',
#   'garlic',
#   'salt',
#   'lemon juice',
#   'white pepper',
#   'parsley',
#   'basil',
#   'heavy whipping cream',
#   'butter',
#   'linguine',
#   'parmesan-romano cheese mix',
#   'salmon',
#   'cajun spices'],
#  ['feta', 'egg', 'oil', 'milk', 'phyllo dough', 'cottage cheese'],
#  ['soy sauce',
#   'imitation crabmeat',
#   'avocado',
#   'seasoned rice vinegar',
#   'white rice',
#   'pickled ginger',
#   'cucumber',
#   'lettuce'],
#  ['flour',
#   'baking soda',
#   'walnuts',
#   'egg',
#   'mixed candied fruit',
#   'maraschino cherry',
#   'sweetened condensed milk',
#   'mincemeat'],
#  ['celery',
#   'chicken breasts',
#   'salt',
#   'white onion',
#   'egg',
#   'kosher salt',
#   'oil',
#   'chicken stock',
#   'matzo meal',
#   'baby carrots',
#   'baking powder',
#   'pepper',
#   'sugar'],
#  ['cream of mushroom soup',
#   'sour cream',
#   'frozen southern style hash brown potatoes',
#   'cheddar cheese',
#   'poppy seed'],
#  ['veggie shreds cheese',
#   'red onion',
#   'ground sage',
#   'egg',
#   'oregano',
#   'fresh garlic cloves',
#   'italian seasoned breadcrumbs',
#   'ground coriander',
#   'ketchup',
#   'sea salt',
#   'low sodium soy sauce',
#   'lean ground beef',
#   'olive oil',
#   'fresh ground pepper',
#   'adobo seasoning'],
#  ['celery',
#   'kraft macaroni and cheese',
#   'cream of celery soup',
#   'butter',
#   'onion',
#   'green bell pepper',
#   'mushrooms',
#   'tuna'],
#  ['dry mustard',
#   'garlic',
#   'salt',
#   'cider vinegar',
#   'paprika',
#   'miracle whip',
#   'tabasco sauce',
#   'vegetable oil',
#   'ketchup',
#   'pepper',
#   'sugar'],
#  ['kosher salt & freshly ground black pepper',
#   'water-packed artichoke hearts',
#   'pepperoncini peppers',
#   'red bell pepper',
#   'red onion',
#   'italian parsley',
#   'kalamata olive',
#   'lemon, juice of',
#   'shallot',
#   'oregano',
#   'tuna in vegetable oil',
#   'extra virgin olive oil',
#   'seedless cucumber',
#   'red wine vinegar',
#   'red ripe tomatoes'],
#  ['orange roughy',
#   'seasoning salt',
#   'ground black pepper',
#   'egg',
#   'buttermilk',
#   'canola oil',
#   'self-rising flour'],
#  ['bacon',
#   'garlic',
#   'salt',
#   'frozen spinach',
#   'egg',
#   'egg yolk',
#   'simply potatoes traditional mashed potatoes',
#   'green onion',
#   'all-purpose flour',
#   'goat cheese'],
#  ['flour',
#   'seasoning salt',
#   'ground black pepper',
#   'egg',
#   'cajun seasoning',
#   'milk',
#   'boneless pork chops',
#   'salt and pepper',
#   'canola oil',
#   'self-rising flour'],
#  ['imitation crabmeat',
#   'ramen noodles',
#   'stir fry vegetables',
#   'water',
#   'teriyaki marinade'],
#  ['celery',
#   'pumpkin puree',
#   'salt',
#   'red onion',
#   'fresh cilantro leaves',
#   'apple',
#   'green bell pepper',
#   'smooth cashew butter',
#   'pesto sauce',
#   'small red potato',
#   'ground red pepper',
#   'banana',
#   'vegetable broth',
#   'pumpkin seeds'],
#  ['garlic',
#   'margarine',
#   'vegetable bouillon cubes',
#   'parsley',
#   'water',
#   'chili powder',
#   'nutmeg',
#   'dry-roasted cashews',
#   'mushrooms'],
#  ['oranges', 'vanilla bean', 'mangoes', 'ice cubes', 'strawberries'],
#  ['white beans',
#   'fresh rosemary',
#   'garlic',
#   'vegetable broth',
#   'leeks',
#   'salt and pepper',
#   'olive oil',
#   'russet potatoes'],
#  ['turmeric',
#   'garlic',
#   'coriander seed',
#   'cinnamon stick',
#   'cardamom pods',
#   'ground cumin',
#   'salt & freshly ground black pepper',
#   'fresh ginger',
#   'fresh coriander',
#   'boneless skinless chicken breasts',
#   'chicken stock',
#   'black peppercorns',
#   'chili powder',
#   'onion',
#   'soy yogurt',
#   'cloves'],
#  ['worcestershire sauce',
#   'garlic',
#   'salt',
#   'beef bouillon cubes',
#   'dried thyme',
#   'tabasco sauce',
#   'rump roast',
#   'garlic powder',
#   'dried oregano',
#   'black pepper',
#   'boiling water'],
#  ['ginger', 'milk', 'water', 'honey', 'tea bag'],
#  ['sausage', 'velveeta cheese', 'ground beef', 'taco chips'],
#  ['ground mustard',
#   'worcestershire sauce',
#   'brown sugar',
#   'tomato sauce',
#   'hamburger buns',
#   'ketchup',
#   'garlic powder',
#   'onion',
#   'lean ground beef',
#   'bell pepper',
#   'white vinegar',
#   'steak seasoning'],
#  ['safflower oil',
#   'green onions',
#   'soy sauce',
#   'carrot',
#   'white mushrooms',
#   'salt',
#   'garlic',
#   'pepper',
#   'fresh corn kernels',
#   'gingerroot',
#   'rice wine vinegar',
#   'green peppers',
#   'salad seasoning',
#   'salad greens',
#   'honey',
#   'beets'],
#  ['dry white wine',
#   'pork chops',
#   'chicken broth',
#   'paprika',
#   'fresh lemon juice',
#   'fennel seeds',
#   'onion',
#   'olive oil'],
#  ['red bell pepper',
#   'black olives',
#   'mozzarella cheese',
#   'egg',
#   'pepperoni',
#   'italian seasoning',
#   'ramen noodles',
#   'garlic powder',
#   'roma tomato'],
#  ['flour',
#   'natural bran',
#   'salt',
#   'brown sugar',
#   'baking soda',
#   'egg',
#   'oil',
#   'sunflower seeds',
#   'milk',
#   'molasses',
#   'baking powder',
#   'sesame seeds',
#   'raisins'],
#  ['black tea leaves',
#   'broiler',
#   'garlic',
#   'brown sugar',
#   'orange, juice of',
#   'minced ginger',
#   'peppercorn',
#   'low sodium soy sauce',
#   'dry sherry',
#   'orange zest',
#   'onion'],
#  ['turmeric',
#   'gingerroot',
#   'coriander seed',
#   'cardamom pods',
#   'yoghurt',
#   'fruit vinegar',
#   'peanut oil',
#   'kaffir lime leaves',
#   'star anise',
#   'lemongrass',
#   'cloves'],
#  ['graham wafers',
#   'blueberry pie filling',
#   'vanilla pudding mix',
#   'cool whip'],
#  ['vinegar',
#   'salt',
#   'tomato paste',
#   'canned jalapeno slices',
#   'cayenne pepper',
#   'cornstarch',
#   'chili powder',
#   'water',
#   'garlic powder',
#   'onion powder',
#   'dried onion flakes',
#   'sugar'],
#  ['shredded coconut',
#   'salt',
#   'brown sugar',
#   'baking soda',
#   'egg',
#   'vanilla',
#   'corn flakes',
#   'butter',
#   'quick-cooking oats',
#   'baking powder',
#   'cake flour',
#   'raisins',
#   'nuts'],
#  ['whole turkey',
#   'kosher salt',
#   'butter',
#   'onion',
#   'olive oil',
#   'pepper',
#   'italian spices'],
#  ['salsa',
#   'corn chips',
#   'sour cream',
#   'chili with beans',
#   'onion',
#   'cheddar cheese'],
#  ['plain breadcrumbs',
#   'salt',
#   'egg',
#   'cauliflower florets',
#   'parsley sprig',
#   'vegetable oil',
#   'pepper'],
#  ['ground black pepper',
#   'walnuts',
#   'kosher salt',
#   'mixed herbs',
#   'butter',
#   'onion',
#   'fresh green beans',
#   'olive oil'],
#  ['hamburger buns',
#   'sweet pickle relish',
#   'ketchup',
#   'ham',
#   'american cheese'],
#  ['bacon', 'carrot', 'tomato soup', 'sugar'],
#  ['lipton onion soup mix',
#   'brown sugar',
#   'egg',
#   'seasoned bread crumbs',
#   'ground beef',
#   'ketchup'],
#  ['bulk pork sausage',
#   'worcestershire sauce',
#   'rye cocktail bread',
#   'oregano',
#   'velveeta cheese',
#   'garlic powder',
#   'ground chuck',
#   'ground pepper'],
#  ['glace cherries',
#   'caster sugar',
#   'self-raising flour',
#   'brown sugar',
#   'egg',
#   'pineapple in syrup',
#   'milk',
#   'vanilla essence',
#   'butter'],
#  ['coconut milk',
#   'oat bran',
#   'apple',
#   'greens',
#   'flax seed oil',
#   'water',
#   'honey',
#   'banana'],
#  ['sour cream',
#   "hellmann's mayonnaise",
#   'knorr vegetable soup mix',
#   'water chestnuts',
#   'green onion',
#   'hawaiian bread'],
#  ['broccoli floret',
#   'soy sauce',
#   'carrot',
#   'egg',
#   'sliced mushrooms',
#   'brown rice',
#   'olive oil',
#   'peas'],
#  ['skim milk',
#   'pumpkin',
#   'pumpkin pie spice',
#   'reduced fat graham cracker crust',
#   'egg whites',
#   'splenda sugar substitute'],
#  ['beef stew', 'biscuits'],
#  ['unsweetened cocoa',
#   'salt',
#   'unsalted butter',
#   'creamy peanut butter',
#   'baking soda',
#   'powdered sugar',
#   'buttermilk',
#   'espresso',
#   'light corn syrup',
#   'extra-large eggs',
#   'honey roasted peanuts',
#   'semisweet chocolate',
#   'unbleached all-purpose flour',
#   'pure vanilla extract',
#   'sugar',
#   'heavy cream'],
#  ['garlic',
#   'red bell pepper',
#   'corn kernel',
#   'cilantro',
#   'ground cumin',
#   'short-grain brown rice',
#   'chipotle chile in adobo',
#   'lime zest',
#   'yellow cornmeal',
#   'olive oil',
#   'fresh lime juice',
#   'onion'],
#  ['whipped dessert topping mix',
#   'egg',
#   'instant vanilla pudding',
#   'water',
#   'all-purpose flour',
#   'butter'],
#  ['celery',
#   'salt',
#   'white onions',
#   'miracle whip',
#   'potato',
#   'milk',
#   'dijon mustard',
#   'sugar',
#   'mustard',
#   'white pepper',
#   'hard-boiled eggs',
#   'fresh ground pepper'],
#  ['soy sauce',
#   'lemon juice',
#   'white rice',
#   'seasoning salt',
#   'dried basil',
#   'cayenne pepper',
#   'water',
#   'chili powder',
#   'garlic powder',
#   'butter',
#   'black pepper',
#   'tea bag'],
#  ['roasted red pepper',
#   'kalamata olive',
#   'frozen spinach',
#   'egg',
#   'oregano',
#   'milk',
#   'feta cheese',
#   'onion',
#   'bisquick',
#   'fresh ground pepper'],
#  ['ground cloves',
#   'cinnamon',
#   'salt',
#   'pumpkin',
#   'baking soda',
#   'egg',
#   'oil',
#   'sugar',
#   'water',
#   'all-purpose flour',
#   'nutmeg',
#   'baking powder',
#   'allspice',
#   'pecans'],
#  ['dry onion soup mix',
#   'vegetable oil',
#   'boneless pork chops',
#   'water',
#   'black pepper',
#   'long-grain rice'],
#  ['rum',
#   'garlic',
#   'clove',
#   'crushed tomatoes',
#   'red peppers',
#   'chives',
#   'olive oil',
#   'thyme',
#   'ginger',
#   'brown sugar',
#   'boneless skinless chicken breasts',
#   'cayenne',
#   'onion flakes',
#   'pepper',
#   'chili powder',
#   'nutmeg',
#   'allspice',
#   'jamaican jerk spice',
#   'lime juice',
#   'cinnamon',
#   'sage',
#   'onion',
#   'habanero pepper'],
#  ['strawberry', 'mango', 'ice', 'frozen limeade concentrate', 'lime sorbet'],
#  ['strawberry',
#   'apple juice',
#   'ice',
#   'non-fat vanilla frozen yogurt',
#   'banana'],
#  ['hoisin sauce',
#   'red chile',
#   'garlic',
#   'sesame oil',
#   'coriander seed',
#   'yoghurt',
#   'fruit vinegar',
#   'fish sauce',
#   'cumin'],
#  ['salt',
#   'peppermint oreos',
#   'egg',
#   'candy cane',
#   'vanilla',
#   'unsweetened cocoa powder',
#   'all-purpose flour',
#   'butter',
#   'unsweetened chocolate',
#   'peppermint extract',
#   'sugar'],
#  ['celery',
#   'slivered almonds',
#   'salt',
#   'cooked chicken breasts',
#   'orange juice',
#   'mandarin oranges',
#   'green grapes',
#   'canola oil',
#   'pineapple tidbits',
#   'cooked rice',
#   'white vinegar',
#   'mayonnaise'],
#  ['celery',
#   'seasoning salt',
#   'sweet pickle relish',
#   'mayonnaise',
#   'mustard',
#   'onion',
#   'cheddar cheese',
#   'hard-boiled eggs',
#   'sugar',
#   'frozen peas'],
#  ['dry breadcrumbs',
#   'parmesan cheese',
#   'butter',
#   'seasoning salt',
#   'paprika',
#   'buttermilk',
#   'all-purpose flour',
#   'oil',
#   'dried thyme',
#   'cayenne pepper',
#   'fresh garlic',
#   'dijon mustard',
#   'hot pepper sauce',
#   'garlic powder',
#   'onion',
#   'black pepper',
#   'chicken pieces'],
#  ['hoisin sauce',
#   'cinnamon',
#   'lemon juice',
#   'seasoning salt',
#   'habanero sauce',
#   'pork baby back ribs',
#   'fresh garlic',
#   'ketchup',
#   'allspice',
#   'louisiana hot sauce',
#   'pepper',
#   'sugar'],
#  ['celery',
#   'carrot',
#   'garlic',
#   'salt',
#   'red bell pepper',
#   'chicken leg',
#   'italian seasoning',
#   'peas',
#   'spaghetti sauce',
#   'beef stock',
#   'onion',
#   'corn',
#   'rotini pasta',
#   'pepper'],
#  ['sour cream',
#   'margarine',
#   'stove top stuffing mix monterey style with mushroom and onion',
#   'pam cooking spray',
#   'salt and pepper',
#   'aluminum foil',
#   'mexicorn whole kernel corn',
#   'spinach dip'],
#  ['pickling spices', 'cooking onions', 'white vinegar'],
#  ['soy sauce',
#   'carrot',
#   'chicken broth',
#   'egg',
#   'cooked pasta',
#   'peas',
#   'cooked chicken'],
#  ['cream cheese', 'mixed fruit', 'cool whip', 'cake crumbs'],
#  ['flour',
#   'squash',
#   'egg',
#   'lemon flavoring',
#   'cool whip',
#   'coconut flavoring',
#   'pie crust',
#   'butter',
#   'sugar'],
#  ['cream of mushroom soup',
#   'ground cloves',
#   'dried parsley flakes',
#   'salt',
#   'ground cinnamon',
#   'dijon mustard',
#   'ground veal',
#   'garlic powder',
#   'black pepper',
#   'dried onion flakes'],
#  ['catfish nuggets',
#   'garlic',
#   'mexican-style stewed tomatoes with jalapeno peppers',
#   'oregano',
#   'chicken stock',
#   'black pepper',
#   'olive oil',
#   'old bay seasoning',
#   'red onions',
#   'small shrimp',
#   'gumbo file',
#   'parsley',
#   'brown rice',
#   'tabasco sauce',
#   'seafood',
#   'okra',
#   'lemon',
#   'red wine vinegar',
#   'tomato soup'],
#  ['bacon',
#   'sour cream',
#   'paprika',
#   'egg',
#   'mild cheddar cheese',
#   'fresh chives',
#   'white vinegar'],
#  ['chicken breasts',
#   'garlic',
#   'salt',
#   'lemon juice',
#   'garlic salt',
#   'dried basil',
#   'dried parsley',
#   'dried oregano',
#   'cracked black pepper',
#   'olive oil',
#   'white vinegar',
#   'sandwich buns'],
#  ['flour',
#   'shredded coconut',
#   'cinnamon',
#   'salt',
#   'brown sugar',
#   'baking soda',
#   'margarine',
#   'egg',
#   'quick oats',
#   'nutmeg',
#   'vanilla',
#   'boiling water',
#   'cream',
#   'nuts'],
#  ['marshmallows', 'rice krispies', 'butter'],
#  ['cream cheese',
#   'cool whip topping',
#   'orange juice',
#   'frozen limeade concentrate'],
#  ['avocado',
#   'salt',
#   'sour cream',
#   'corn chips',
#   'lemon juice',
#   'garlic',
#   'salad oil',
#   'tabasco sauce',
#   'tuna',
#   'pitted ripe olives',
#   'green onion',
#   'chili powder',
#   'cheddar cheese',
#   'lettuce',
#   'tomato',
#   'sugar'],
#  ['tahini',
#   'garlic',
#   'low-fat yogurt',
#   'salt & freshly ground black pepper',
#   'ground cumin',
#   'fresh coriander',
#   'baking potatoes',
#   'chickpeas',
#   'coriander',
#   'olive oil'],
#  ['salt',
#   'yellow cornmeal',
#   'egg',
#   'buttermilk',
#   'mayonnaise',
#   'vegetable oil',
#   'baking powder',
#   'sugar'],
#  ['soy sauce',
#   'carrot',
#   'red cabbage',
#   'gingerroot',
#   'sesame oil',
#   'green cabbage',
#   'apple',
#   'maple syrup',
#   'rice vinegar',
#   'green onion'],
#  ['turmeric',
#   'orzo pasta',
#   'chicken soup powder',
#   'canola oil',
#   'water',
#   'garlic powder',
#   'black pepper',
#   'long-grain rice'],
#  ['jalapeno pepper',
#   'avocado',
#   'white onion',
#   'chicken broth',
#   'chicken breast',
#   'ear of corn',
#   'crushed tomatoes',
#   'chipotle chiles in adobo',
#   'celery ribs',
#   'salt and pepper',
#   'fresh cilantro',
#   'green bell pepper',
#   'cumin'],
#  ['salt',
#   'italian-style tomato sauce',
#   'eggplant',
#   'fiber one cereal',
#   'dried basil',
#   'reduced-fat parmesan cheese',
#   'garlic powder',
#   'fat free mozzarella cheese',
#   'egg white',
#   'pepper'],
#  ['white rice', 'egg', 'beef gravy', 'ground beef', 'onion'],
#  ['tomatoes and green chilies',
#   'carrot',
#   'garlic',
#   'pinto beans',
#   'ham soup base',
#   'salt',
#   'black-eyed peas',
#   'navy beans',
#   'ham bone',
#   'celery ribs',
#   'water',
#   'great northern beans',
#   'onion',
#   'ham',
#   'beans',
#   'pepper'],
#  ['skinless chicken breast half',
#   'garlic',
#   'light mayonnaise',
#   'red bell pepper',
#   'cider vinegar',
#   'feta cheese',
#   'fresh dill'],
#  ['garlic salt',
#   'mozzarella cheese',
#   'italian seasoning',
#   'spaghetti sauce',
#   'cheese ravioli',
#   'lean ground beef'],
#  ['worcestershire sauce',
#   'lemon juice',
#   'orange marmalade',
#   'chicken pieces',
#   'barbecue sauce'],
#  ['turmeric',
#   'salt',
#   'ground black pepper',
#   'paprika',
#   'garlic powder',
#   'onion powder',
#   'coriander',
#   'ground red pepper'],
#  ['cream cheese',
#   'green pepper',
#   'mexican blend cheese',
#   'sour cream',
#   'black olives',
#   'green onion',
#   'taco seasoning mix',
#   'lettuce',
#   'tomato',
#   'mayonnaise'],
#  ['minced clams',
#   'green onions',
#   'worcestershire sauce',
#   'green bell peppers',
#   'sharp cheddar cheese',
#   'paprika',
#   'tabasco sauce'],
#  ['shrimp',
#   'red bell pepper',
#   'red onion',
#   'spaghetti squash',
#   'olives',
#   'oregano',
#   'yellow bell pepper',
#   'olive oil',
#   'eggplants'],
#  ['heavy cream', 'semisweet chocolate', "confectioners' sugar", 'butter'],
#  ['pecans',
#   'crushed pineapple',
#   'frozen whipped topping',
#   'small marshmallow',
#   'cherry pie filling',
#   'sweetened condensed milk'],
#  ['bacon',
#   'green onions',
#   'salt',
#   'sour cream',
#   'oil',
#   'potato',
#   'cheddar cheese'],
#  ['plain flour',
#   'pizza sauce',
#   'parmesan cheese',
#   'salt',
#   'mozzarella cheese',
#   'canola oil',
#   'onion',
#   'boneless eye of round beef steak',
#   'pepper'],
#  ['seasoning salt',
#   'ground black pepper',
#   "campbell's golden mushroom soup",
#   'oregano',
#   'all-purpose flour',
#   'bacon grease',
#   'soup mix',
#   'boneless country-style ribs'],
#  ['flour', 'fruit', 'egg', 'milk', 'butter', 'sugar'],
#  ['apples',
#   'ground cinnamon',
#   'crescent roll dough',
#   'baby carrots',
#   'butter',
#   'honey',
#   'cardamom',
#   'sugar'],
#  ['garlic salt',
#   'mozzarella cheese',
#   'italian seasoning',
#   'olive oil',
#   'refrigerated biscuits'],
#  ['flour', 'salt', 'active dry yeast', 'milk', 'water', 'butter', 'sugar'],
#  ['cream cheese',
#   'salt',
#   'egg',
#   'lemon peel',
#   'egg yolk',
#   'whipping cream',
#   'sugar',
#   'all-purpose flour',
#   'butter',
#   'vanilla',
#   'egg yolks'],
#  ['honey',
#   'chili sauce',
#   'country-style dijon mustard',
#   'little smokies sausages'],
#  ['orange curacao',
#   'bacardi dark rum',
#   'orgeat syrup',
#   'pineapple juice',
#   'orange juice',
#   'white rum',
#   'grenadine',
#   'prepared sweet-and-sour mix',
#   "meyer's dark rum"],
#  ['balsamic vinaigrette',
#   'pork chops',
#   'sliced mushrooms',
#   'red apples',
#   'minute white rice',
#   'condensed chicken broth',
#   'water',
#   'onion',
#   'dried thyme leaves'],
#  ['reduced-calorie mayonnaise',
#   'green bell peppers',
#   'horseradish',
#   'tomato paste',
#   'red bell peppers',
#   'orange juice',
#   'plain nonfat yogurt',
#   'chili powder',
#   'fresh ground black pepper',
#   'prepared mustard',
#   'onion'],
#  ['grapes',
#   'nectarines',
#   'cold water',
#   'lemon gelatin',
#   'peach gelatin',
#   'orange juice',
#   'cool whip',
#   'strawberry gelatin',
#   'strawberries'],
#  ['flour',
#   'skim milk',
#   'fat-free evaporated milk',
#   'poultry seasoning',
#   'salt',
#   'ground marjoram',
#   'brown sugar',
#   'cayenne pepper',
#   'lean ground turkey',
#   'dried sage',
#   'garlic powder',
#   'onion flakes',
#   'pepper'],
#  ['sweet onion',
#   'seasoning salt',
#   'red bell pepper',
#   'ground black pepper',
#   'egg',
#   'cooking spray',
#   'ground beef',
#   'garlic powder',
#   'french-fried onions',
#   'barbecue sauce'],
#  ['green pepper',
#   'flour',
#   'carrot',
#   'garlic',
#   'cold water',
#   'salt',
#   'tomato sauce',
#   'beef stew meat',
#   'beef broth',
#   'crushed tomatoes',
#   'potato',
#   'beef bouillon granules',
#   'italian salad dressing',
#   'water',
#   'onion',
#   'pepper',
#   'bay leaf'],
#  ['carrot',
#   'garam masala',
#   'garlic',
#   'ghee',
#   'potato',
#   'tabasco sauce',
#   'salt and pepper',
#   'curry powder',
#   'water',
#   'kidney beans',
#   'onion'],
#  ['orange juice', 'ice cube', 'orange slice', 'ouzo'],
#  ['half-and-half',
#   'cream of mushroom soup',
#   'red pepper',
#   'salt',
#   'cream of celery soup',
#   'sherry wine',
#   'milk',
#   'old bay seasoning',
#   'pepper',
#   'crabmeat'],
#  ['chicken broth',
#   'yellow mustard',
#   'sherry wine vinegar',
#   'egg whites',
#   'skim milk',
#   'brown sugar',
#   'salt and pepper',
#   'ground sirloin',
#   'mixed mushrooms',
#   'worcestershire sauce',
#   'tomato paste',
#   'shallot',
#   'ketchup',
#   'dry sherry',
#   'bacon',
#   'flour',
#   'ground turkey',
#   'unsalted butter',
#   'ground pork',
#   'fresh parsley',
#   'panko breadcrumbs',
#   'onion'],
#  ['rosemary',
#   'garlic',
#   'new potatoes',
#   'lemon, zest of',
#   'lemon, juice of',
#   'olive oil'],
#  ['salsa',
#   'dry breadcrumbs',
#   'flour',
#   'garlic',
#   'black beans',
#   'oil',
#   'frozen corn',
#   'green chili sauce',
#   'chili powder',
#   'onion',
#   'cumin'],
#  ['green onions',
#   'ripe olives',
#   'caesar salad dressing',
#   'salt',
#   'red bell pepper',
#   'fresh spinach',
#   'sour cream',
#   'baby shrimp',
#   'mayonnaise',
#   'cheese-filled tortellini',
#   'fresh ground pepper'],
#  ['celery',
#   'worcestershire sauce',
#   'ground turkey',
#   'bell peppers',
#   'garlic',
#   'spike seasoning',
#   'fresh parsley',
#   'salt and pepper',
#   'cheese',
#   'onion',
#   'olive oil',
#   'tomato'],
#  ['cream cheese',
#   'splenda granular',
#   'cinnamon',
#   'slivered almonds',
#   'lemon juice',
#   'sour cream',
#   'egg',
#   'graham cracker crumbs',
#   'cornstarch',
#   'butter',
#   'nutmeg',
#   'vanilla',
#   'heavy whipping cream'],
#  ['soy sauce', 'oil', 'smooth peanut butter', 'ketchup', 'chicken pieces'],
#  ['salt',
#   'chicken broth',
#   'celery seed',
#   'breadcrumbs',
#   'dried thyme',
#   'dried sage',
#   'parsley',
#   'butter',
#   'onion',
#   'pepper'],
#  ['garlic',
#   'fresh oregano',
#   'fresh basil',
#   'salt and pepper',
#   'olive oil',
#   'tomato'],
#  ['shredded coconut',
#   'bittersweet chocolate',
#   'salt',
#   'coconut milk',
#   'egg',
#   'kahlua',
#   'vegetable oil',
#   'whipping cream',
#   'instant chocolate pudding mix',
#   'cornstarch',
#   'water',
#   'coco lopez',
#   "devil's food cake mix",
#   'sugar'],
#  ['old bay seasoning', 'plain tomato juice'],
#  ['carrot',
#   'canned unsweetened coconut milk',
#   'cinnamon',
#   'ground nutmeg',
#   'garlic',
#   'shallot',
#   'ground allspice',
#   'pumpkin seeds',
#   'canned pumpkin',
#   'chicken stock',
#   'curry powder',
#   'coriander',
#   'butter',
#   'banana',
#   'sweetened condensed milk',
#   'bay leaf',
#   'onion'],
#  ['parmesan cheese',
#   'garlic',
#   'salt',
#   'pepper',
#   'ghee',
#   'whole wheat bread',
#   'zucchini',
#   'tomato',
#   'mayonnaise'],
#  ['cream cheese',
#   'diced tomatoes with green chilies',
#   'diced green chilies',
#   'sausage'],
#  ['chili seasoning mix',
#   'garlic',
#   'red pepper',
#   'white onion',
#   'tomato sauce',
#   'black beans',
#   'beef broth',
#   'chilies',
#   'extra lean ground beef',
#   'chili beans with chipotle pepper',
#   'kidney beans',
#   'diced tomatoes'],
#  ['cream cheese',
#   'carrot',
#   'ground nutmeg',
#   'salt',
#   'baking soda',
#   'powdered sugar',
#   'egg',
#   'ground cinnamon',
#   'pineapple chunk',
#   'sugar',
#   'all-purpose flour',
#   'butter',
#   'vanilla',
#   'baking powder',
#   'pecans'],
#  ['flour', 'milk', 'butter', 'black pepper', 'dried beef'],
#  ['carrot',
#   'salt',
#   'potato',
#   'turnips',
#   'water',
#   'onion',
#   'pepper',
#   'split peas'],
#  ['cumin',
#   'lemon juice',
#   'sour cream',
#   'corn tortilla strips',
#   'red onion',
#   'roasted garlic and red pepper spice mix',
#   'buttermilk',
#   'steak spice',
#   'granulated garlic',
#   'salad dressing',
#   'romaine lettuce',
#   'curry powder',
#   'ketchup',
#   'cooked bacon',
#   'cherry tomatoes',
#   'hard-boiled eggs',
#   'sugar'],
#  ['fresh thyme',
#   'worcestershire sauce',
#   'salt',
#   'papaya',
#   'cayenne pepper',
#   'ground cumin',
#   'hamburger buns',
#   'lean ground beef',
#   'bibb lettuce',
#   'onion',
#   'cheddar cheese',
#   'white pepper',
#   'tomato',
#   'mayonnaise'],
#  ['flour',
#   'cinnamon',
#   'salt',
#   'baking soda',
#   'walnuts',
#   'egg',
#   'fat',
#   'zucchini',
#   'vanilla',
#   'sugar'],
#  ['dry white wine',
#   'lemon juice',
#   'peach',
#   'peach puree',
#   'lemon-flavored vodka',
#   'apple',
#   'lemon',
#   'lime',
#   'lemonade',
#   'peach schnapps',
#   'lime juice'],
#  ['ground moose',
#   'brown sugar',
#   'salt and pepper',
#   'hot sauce',
#   'ketchup',
#   'onion',
#   'prepared mustard',
#   'barbecue sauce'],
#  ['dry breadcrumbs',
#   'soy sauce',
#   'garlic',
#   'salt',
#   'brown sugar',
#   'egg',
#   'lean ground beef',
#   'pineapple chunks',
#   'cornstarch',
# ...
#   'warm water',
#   'sugar'],
#  ['yeast',
#   'salt',
#   'oat bran',
#   'egg',
#   'vegetable oil',
#   'whole wheat flour',
#   'water',
#   'white whole wheat flour',
#   'vital wheat gluten',
#   'wheat germ',
#   'sugar'],
#  ['yeast',
#   'kosher salt',
#   'whole wheat flour',
#   'warm water',
#   'vital wheat gluten'],
#  ['yeast', 'salt', 'egg', 'applesauce', 'whole wheat flour', 'water', 'honey'],
#  ['salt',
#   'egg',
#   'whole wheat flour',
#   'canola oil',
#   'water',
#   'honey',
#   'vital wheat gluten',
#   'instant yeast'],
#  ['salt',
#   'low-fat buttermilk',
#   'baking soda',
#   'granulated sugar',
#   'flax seed meal',
#   'whole wheat flour',
#   'canola oil',
#   'egg whites',
#   'baking powder'],
#  ['cinnamon',
#   'salt',
#   'baking soda',
#   'turbinado sugar',
#   'whole wheat flour',
#   'water',
#   'butter',
#   'honey',
#   'vanilla',
#   'baking powder'],
#  ['salt',
#   'low-fat buttermilk',
#   'baking soda',
#   'egg',
#   'molasses',
#   'whole wheat flour',
#   'butter',
#   'baking powder',
#   'raisins'],
#  ['baking soda',
#   'low-fat milk',
#   'fruit',
#   'egg',
#   'whole wheat flour',
#   'canola oil',
#   'vanilla',
#   'baking powder',
#   'sugar'],
#  ['salt',
#   'brown sugar',
#   'egg',
#   'milk',
#   'whole wheat flour',
#   'butter',
#   'baking powder',
#   'peanut butter'],
#  ['salt', 'whole wheat flour', 'water', 'honey', 'olive oil', 'instant yeast'],
#  ['yeast', 'salt', 'egg', 'whole wheat flour', 'water', 'honey', 'olive oil'],
#  ['gluten',
#   'sour cream',
#   'baking soda',
#   'kosher salt',
#   'milk',
#   'whole wheat flour',
#   'butter',
#   'baking powder'],
#  ['cinnamon',
#   'powdered eggs',
#   'salt',
#   'baking powder',
#   'fruit',
#   'oatmeal',
#   'egg',
#   'oil',
#   'molasses',
#   'sugar',
#   'whole wheat flour',
#   'water',
#   'powdered milk',
#   'vanilla',
#   'cocoa powder',
#   'raisins'],
#  ['cinnamon',
#   'salt',
#   'baking soda',
#   'egg',
#   'vegetable oil',
#   'whole wheat flour',
#   'zucchini',
#   'vanilla',
#   'baking powder',
#   'sugar',
#   'nuts'],
#  ['table salt',
#   'cooking oil',
#   'whole wheat flour',
#   'water',
#   'honey',
#   'instant yeast'],
#  ['bananas',
#   'baking soda',
#   'egg',
#   'all-purpose flour',
#   'butter',
#   'vanilla',
#   'sugar',
#   'nuts'],
#  ['chocolate cake mix',
#   'evaporated milk',
#   'chocolate chips',
#   'caramels',
#   'butter',
#   'nuts'],
#  ['flour',
#   'salt',
#   'bananas',
#   'baking soda',
#   'walnuts',
#   'egg',
#   'sugar',
#   'canola oil',
#   'raisins'],
#  ['cream cheese', 'thousand island dressing'],
#  ['chili sauce', 'mayonnaise', 'onion powder', 'sweet pickle relish'],
#  ['flour',
#   'rice krispies',
#   'brown sugar',
#   'baking soda',
#   'chocolate chips',
#   'margarine',
#   'egg',
#   'oil',
#   'white sugar',
#   'cream of tartar',
#   'vanilla',
#   'flaked coconut',
#   'rolled oats'],
#  ['bacon',
#   'garlic',
#   'buttermilk',
#   'fresh lemon juice',
#   'unsalted sunflower seeds',
#   'hardboiled egg',
#   'plain yogurt',
#   'white pepper',
#   'mushrooms',
#   'sugar',
#   'baby spinach'],
#  ['bacon',
#   'fresh mushrooms',
#   'green pepper',
#   'red onion',
#   'italian seasoning',
#   'cauliflower',
#   'mayonnaise',
#   'cherry tomatoes',
#   'fresh broccoli',
#   'lettuce',
#   'sugar',
#   'frozen peas'],
#  ['marjoram leaves',
#   'basil leaves',
#   'paprika',
#   'rubbed sage',
#   'ground allspice',
#   'celery salt',
#   'ground oregano',
#   'chili powder',
#   'garlic powder',
#   'black pepper',
#   'onion salt'],
#  ['vodka', 'beer', 'fresh jalapeno', 'ice'],
#  ['bacon',
#   'worcestershire sauce',
#   'parmesan cheese',
#   'low-fat mayonnaise',
#   'lemon juice',
#   'anchovy fillets',
#   'fresh mushrooms',
#   'garlic',
#   'french bread',
#   'oil',
#   'extra virgin olive oil',
#   'dijon mustard',
#   'miracle whip light',
#   'olive oil',
#   'baby spinach'],
#  ['jumbo pasta shells',
#   'mexican blend cheese',
#   'salt',
#   'italian cheese blend',
#   'egg',
#   'mozzarella cheese',
#   'ricotta cheese',
#   'spaghetti sauce',
#   'parsley flakes',
#   'ground beef',
#   'dried italian seasoning',
#   'ground pepper',
#   'parmesan-romano cheese mix'],
#  ['salt',
#   'brown sugar',
#   'oil',
#   'whole wheat flour',
#   'water',
#   'white flour',
#   'bread machine yeast'],
#  ['evaporated milk',
#   'whole corn',
#   'potato',
#   'salt and pepper',
#   'cream-style corn',
#   'water',
#   'butter',
#   'onion'],
#  ['parmesan cheese',
#   'kosher salt',
#   'prosciutto',
#   'extra virgin olive oil',
#   'flat leaf parsley',
#   'orecchiette',
#   'italian seasoned breadcrumbs',
#   'black pepper'],
#  ['salt', 'fresh ground black pepper', 'olive oil', 'cumin seeds', 'tomato'],
#  ['baking soda',
#   'molasses',
#   'corn syrup',
#   'white sugar',
#   'salted peanuts',
#   'butter',
#   'vanilla'],
#  ['cinnamon',
#   'salt',
#   'bulgar wheat',
#   'onion',
#   'lean ground beef',
#   'plain yogurt'],
#  ['egg',
#   'yellow cake mix',
#   'oil',
#   'apple pie filling',
#   'instant vanilla pudding',
#   'water'],
#  ['carrot', 'italian dressing', 'boneless skinless chicken breasts', 'potato'],
#  ['egg', 'cinnamon rolls', 'chocolate milk'],
#  ['flour',
#   'salt',
#   'egg',
#   'milk',
#   'white sugar',
#   'butter',
#   'vanilla',
#   'baking powder'],
#  ['celery',
#   'worcestershire sauce',
#   'carrot',
#   'garlic',
#   'salt',
#   'leeks',
#   'basil',
#   'water',
#   'ham',
#   'soup mix',
#   'thyme',
#   'pepper'],
#  ['worcestershire sauce',
#   'bell peppers',
#   'egg',
#   'chili sauce',
#   'milk',
#   'salt and pepper',
#   'ground beef',
#   'garlic powder',
#   'onion',
#   'saltine crackers'],
#  ['worcestershire sauce',
#   'garlic',
#   'sour cream',
#   'unsalted butter',
#   'salt and pepper',
#   'aluminum foil',
#   'limes, juice of',
#   'prepared horseradish',
#   'beef tenderloin'],
#  ['flour',
#   'cream cheese',
#   'carrot',
#   'cinnamon',
#   'salt',
#   'pineapple',
#   'baking soda',
#   'walnuts',
#   'margarine',
#   'powdered sugar',
#   'egg',
#   'oil',
#   'baking powder',
#   'sugar'],
#  ['turmeric',
#   'carrot',
#   'salt',
#   'celery seed',
#   'cabbage',
#   'water',
#   'mustard seeds',
#   'onion',
#   'white vinegar',
#   'sugar'],
#  ['pickling cucumbers',
#   'vinegar',
#   'salt',
#   'water',
#   'alum',
#   'pickling spices',
#   'sugar'],
#  ['vinegar', 'cucumbers', 'canning salt', 'alum', 'pickling spices', 'sugar'],
#  ['flour',
#   'ground cloves',
#   'cream cheese',
#   'cinnamon',
#   'salt',
#   'carrot',
#   'baking soda',
#   'allspice',
#   'margarine',
#   'powdered sugar',
#   'egg',
#   'oil',
#   'sugar',
#   'vanilla',
#   'coconut',
#   'raisins',
#   'nuts'],
#  ['maple syrup', 'nutmeats', 'lemon extract', 'butter', 'cream'],
#  ['celery',
#   'carrot',
#   'salt',
#   'raw rice',
#   'lemon juice',
#   'chicken broth',
#   'deli ham',
#   'parsley',
#   'basil',
#   'water',
#   'chicken bouillon cubes',
#   'onion',
#   'beans',
#   'tomato',
#   'v8 vegetable juice'],
#  ['hormel chili without beans',
#   'tortillas',
#   'refried beans',
#   'monterey jack cheese'],
#  ['garlic',
#   'salt',
#   'celery leaves',
#   'ham hocks',
#   'dried parsley',
#   '15 bean soup mix',
#   'chicken bouillon cubes',
#   'dried rosemary',
#   'onion',
#   'black pepper',
#   'whole tomatoes',
#   'olive oil'],
#  ['worcestershire sauce',
#   'smoked sausage',
#   'garlic',
#   'ham bone',
#   'beef bouillon paste',
#   '15 bean soup mix',
#   'steak sauce',
#   'water',
#   'black pepper',
#   'diced tomatoes'],
#  ['smoked paprika',
#   'carrot',
#   'salt',
#   'ham',
#   'garlic',
#   'paprika',
#   'oregano',
#   'cayenne pepper',
#   'lemon',
#   'condensed tomato soup',
#   'water',
#   'chili powder',
#   'onion',
#   'black pepper',
#   'olive oil',
#   'thyme',
#   'dried beans'],
#  ['flour',
#   'plain sweet biscuit crumbs',
#   'sour cream',
#   'baking soda',
#   'margarine',
#   'egg',
#   'liquid honey',
#   'honey',
#   'ground walnuts',
#   'sugar'],
#  ['garlic',
#   'lemon juice',
#   'capers',
#   'fresh chives',
#   'fresh parsley',
#   'salt and pepper',
#   'halibut steaks',
#   'chicken stock',
#   'fresh tarragon'],
#  ['new potatoes',
#   'tomato paste',
#   'oil',
#   'boneless sirloin steak',
#   'water',
#   'lipton beefy mushroom soup mix',
#   'peas and carrots'],
#  ['tomatoes and green chilies',
#   'taco seasoning',
#   'black beans',
#   'frozen corn kernels',
#   'ground beef'],
#  ['lean ground beef',
#   'minute white rice',
#   'water',
#   'mustard',
#   'ketchup',
#   'cheddar cheese'],
#  ['white rice',
#   'velveeta cheese',
#   'water',
#   'ground beef',
#   'chili with beans',
#   'diced tomatoes'],
#  ['paprika',
#   'vegetable oil',
#   'instant rice',
#   'water',
#   'boneless skinless chicken breast halves',
#   'condensed cream of chicken soup',
#   'ground pepper'],
#  ['sour cream',
#   'pepper',
#   'chicken breast tenders',
#   'lime',
#   'pico de gallo',
#   'onion',
#   'olive oil',
#   'tortilla',
#   'cheese',
#   'fajita seasoning mix'],
#  ['salsa',
#   'tortilla chips',
#   'chicken',
#   'sour cream',
#   'chicken broth',
#   'mexicorn',
#   'kidney beans',
#   'cheddar cheese'],
#  ['minute rice',
#   'broccoli florets',
#   'vegetable oil',
#   'milk',
#   'boneless skinless chicken breasts',
#   'condensed cream of chicken soup'],
#  ['salsa',
#   'ground turkey',
#   'salt',
#   'pinto beans',
#   'stewed tomatoes',
#   'chili powder',
#   'kidney beans',
#   'onion',
#   'cumin'],
#  ['sour cream',
#   'white minute rice',
#   'flour tortillas',
#   'water',
#   'chili with beans',
#   'cheese'],
#  ['broccoli',
#   'water',
#   'chili powder',
#   'ketchup',
#   'lean ground beef',
#   'macaroni & cheese dinner mix'],
#  ['cinnamon',
#   'salt',
#   'brown sugar',
#   'pepper',
#   'clove',
#   'onion',
#   'allspice',
#   'tomato'],
#  ['roasted cashews',
#   'garlic',
#   'grape tomatoes',
#   'fresh oregano',
#   'fresh parmesan cheese',
#   'fresh basil',
#   'crushed red pepper flakes',
#   'pappardelle pasta',
#   'pepper',
#   'sun-dried tomato packed in oil'],
#  ['garlic',
#   'salt',
#   'tomato sauce',
#   'low sodium chicken broth',
#   'ground cumin',
#   'ground coriander',
#   'chipotle chile in adobo',
#   'onion'],
#  ['reduced fat graham cracker crust',
#   'fat free cream cheese',
#   'fat-free whipped topping',
#   'sugar substitute'],
#  ['parmesan cheese',
#   'lemon juice',
#   'red onion',
#   'fresh spinach',
#   'pine nuts',
#   'fresh linguine',
#   'pesto sauce',
#   'tomato'],
#  ['flour',
#   'garlic',
#   'lemon juice',
#   'chicken broth',
#   'oil',
#   'salt and pepper',
#   'boneless skinless chicken breast halves',
#   'butter'],
#  ['garlic',
#   'salt',
#   'garbanzo beans',
#   'fresh lemon juice',
#   'extra virgin olive oil',
#   'celery ribs',
#   'fresh parsley',
#   'feta cheese',
#   'romaine lettuce',
#   'scallion',
#   'cracked black pepper',
#   'of fresh mint',
#   'tomato'],
#  ['oil',
#   'instant rice',
#   'italian dressing',
#   'boneless skinless chicken breast',
#   'assorted fresh vegetables',
#   'reduced-sodium fat-free chicken broth'],
#  ['cream cheese',
#   'instant lemon pudding',
#   'powdered sugar',
#   'graham cracker crumbs',
#   'milk',
#   'butter'],
#  ['cocoa', 'butter', 'vanilla', "confectioners' sugar", 'peanut butter'],
#  ['parmesan cheese',
#   'smoked turkey breast',
#   'italian salad dressing',
#   'tomato',
#   'spaghetti'],
#  ['soy sauce',
#   'minute rice',
#   'pork tenderloin',
#   'chicken bouillon cube',
#   'oil',
#   'water',
#   'frozen mixed vegetables'],
#  ['green pepper',
#   'oil',
#   'minute white rice',
#   'hot pepper sauce',
#   'chicken bouillon cubes',
#   'water',
#   'kidney beans',
#   'onion'],
#  ['shrimp',
#   'parmesan cheese',
#   'garlic salt',
#   'fettuccine',
#   'baby peas',
#   'bacon bits',
#   'black pepper',
#   'half-and-half cream'],
#  ['white wine',
#   'garlic',
#   'angel hair pasta',
#   'salt & pepper',
#   'extra virgin olive oil',
#   'frozen shrimp',
#   'butter',
#   'onion'],
#  ['celery',
#   'jalapenos',
#   'hot chili flakes',
#   'garlic flakes',
#   'sweet green pepper',
#   'sliced mushrooms',
#   'sweet red pepper',
#   'tomato sauce & mushrooms',
#   'onion',
#   'hamburger'],
#  ['soy sauce',
#   'garlic',
#   'salt',
#   'chicken broth',
#   'asparagus',
#   'chili flakes',
#   'rice vinegar',
#   'fresh ginger',
#   'boneless skinless chicken breast',
#   'white pepper',
#   'onion'],
#  ['half-and-half',
#   'unsalted butter',
#   'kosher salt',
#   'dijon mustard',
#   'hot sauce',
#   'elbow macaroni',
#   'fresh ground black pepper',
#   'extra-sharp cheddar cheese'],
#  ['fresh mushrooms',
#   'flour',
#   'sour cream',
#   'dry onion soup mix',
#   'water',
#   'round steak',
#   'butter'],
#  ['chopped tomatoes',
#   'mexican blend cheese',
#   'extra lean ground beef',
#   'minute white rice',
#   'water',
#   'taco seasoning mix',
#   'lettuce'],
#  ['cornflour',
#   'lime, juice and zest of',
#   'dark soy sauce',
#   'pak choi',
#   'water',
#   'tiger shrimp',
#   'thai fish sauce',
#   'sweet chili sauce',
#   'sunflower oil',
#   'baby spinach'],
#  ['milk', 'minute rice', 'raisins', 'vanilla instant pudding mix'],
#  ['salsa', 'black beans', 'fire-roasted tomatoes', 'water', 'kidney beans'],
#  ['cream cheese', 'parmesan cheese', 'margarine', 'fettuccine pasta', 'milk'],
#  ['salt',
#   'milk',
#   'quick oats',
#   'water',
#   'honey',
#   'vanilla',
#   'sugar',
#   'dried fruits'],
#  ['celery',
#   '15 bean mix',
#   'carrot',
#   'garlic',
#   'seasoning salt',
#   'tomato sauce',
#   'chicken bouillon cubes',
#   'water',
#   'onion',
#   'bay leaves',
#   'ham hocks',
#   'diced tomatoes',
#   'pepper'],
#  ['chili seasoning mix',
#   'corn chips',
#   'dark red kidney beans',
#   'sharp cheddar cheese',
#   'red pepper flakes',
#   'vegetable oil',
#   'salt and pepper',
#   'canned green beans',
#   'water',
#   'ground beef',
#   'ketchup',
#   'onion',
#   'whole tomatoes',
#   'green bell pepper',
#   'black-eyed peas'],
#  ['garlic',
#   'salt',
#   'ground black pepper',
#   'chicken liver',
#   'heavy cream',
#   'sage',
#   'marjoram',
#   'butter',
#   'brandy',
#   'thyme',
#   'onion'],
#  ['chili beans',
#   'salt',
#   'sour cream',
#   'oregano',
#   'cayenne pepper',
#   'sliced mushrooms',
#   'chili powder',
#   'onion',
#   'lean ground beef',
#   'cumin',
#   'diced tomatoes'],
#  ['strawberry',
#   'frozen pound cake',
#   'cool whip topping',
#   'orange liqueur',
#   'jello instant vanilla pudding mix',
#   'white chocolate baking squares',
#   'sugar',
#   'strawberries'],
#  ['worcestershire sauce',
#   'fresh lemon juice',
#   'dried tarragon',
#   'dijon mustard',
#   'boneless skinless chicken breast halves',
#   'pepper'],
#  ['chicken broth', 'salt and pepper', 'basmati rice'],
#  ['salsa',
#   'tortilla chips',
#   'sour cream',
#   'black olives',
#   'cream of chicken soup',
#   'monterey jack cheese',
#   'green enchilada sauce',
#   'green onion',
#   'lettuce',
#   'tomato',
#   'cooked chicken'],
#  ['pasta', 'parmesan cheese', 'garlic', 'butter'],
#  ['garlic',
#   'pepper',
#   'large shrimp',
#   'feta cheese',
#   'parsley',
#   'dried oregano',
#   'olive oil',
#   'old bay seasoning',
#   'tomato'],
#  ['snap peas',
#   'unsalted butter',
#   'red onion',
#   'lemon, zest of',
#   'large shrimp',
#   'salt & freshly ground black pepper',
#   'herbs',
#   'corn kernels',
#   'cherry tomatoes',
#   'zucchini',
#   'olive oil'],
#  ['parmesan cheese',
#   'white beans',
#   'vegetable broth',
#   'garlic',
#   'fresh lemon juice',
#   'scallions',
#   'salt and pepper',
#   'dried oregano',
#   'olive oil'],
#  ['celery',
#   'carrot',
#   'garlic',
#   'italian sausage',
#   'oregano',
#   'water',
#   'chicken stock',
#   'onion',
#   'bay leaves',
#   'beans',
#   'tomato'],
#  ['cinnamon sticks',
#   'pickling salt',
#   'cucumbers',
#   'alum',
#   'pickling spices',
#   'white vinegar',
#   'sugar'],
#  ['pork butt', 'ginger ale', 'barbecue sauce', 'onion'],
#  ['cold water',
#   'brown sugar',
#   'vanilla bean',
#   'strong coffee',
#   'dark molasses',
#   'vodka',
#   'sugar'],
#  ['whole chickens',
#   'celery',
#   'carrot',
#   'chicken broth',
#   'frozen corn',
#   'potato',
#   'celery ribs',
#   'chicken bouillon cubes',
#   'onion',
#   'frozen white corn'],
#  ['oregano leaves',
#   'low-carb marinara sauce',
#   'lean ground turkey',
#   'fat-free parmesan cheese',
#   'basil',
#   'eggplant',
#   'fennel seed',
#   'nonstick cooking spray'],
#  ['raspberry vodka', 'mountain dew soda'],
#  ['tart apples',
#   'fresh thyme',
#   'pancetta',
#   'white cheddar cheese',
#   'gouda cheese',
#   'red onion',
#   'apple cider',
#   'salt and pepper',
#   'red wine vinegar',
#   'dijon mustard',
#   'arugula',
#   'sherry wine vinegar',
#   'shallots',
#   'olive oil',
#   'white vinegar'],
#  ['flour',
#   'salt',
#   'baking soda',
#   'pumpkin pie spice',
#   'unsalted butter',
#   'egg',
#   'light brown sugar',
#   'vegetable oil',
#   'marshmallow cream',
#   "confectioners' sugar",
#   'baby carrots',
#   'baking powder',
#   'pure vanilla extract'],
#  ['flour',
#   'cinnamon',
#   'salt',
#   'baking soda',
#   'cocoa',
#   'clove',
#   'egg',
#   'buttermilk',
#   'butter',
#   'nutmeg',
#   'vanilla',
#   'sugar'],
#  ['flour',
#   'almonds',
#   'powdered sugar',
#   'egg',
#   'cornstarch',
#   'milk',
#   'sugar',
#   'cream of tartar',
#   'sweet cream',
#   'egg yolks'],
#  ...]

# %% [markdown]
# We'll use the [`Word2Vec`](https://radimrehurek.com/gensim/models/word2vec.html) implementation in the `gensim` library (i.e., *deep learning*) to train an embedding model.
# This approach tends to work best if the training data has at least 100K rows.
# NB: work in progress will replace `gensim` with `pytorch` instead.

# %%
import gensim

MIN_COUNT = 2
model_path = "tmp.w2v"

model = gensim.models.Word2Vec(vectors, min_count=MIN_COUNT, window=max_context)
model.save(model_path)

# %% [markdown]
# The `get_related()` function takes any ingredient as input, using the embedding model to find the most similar other ingredients – along with calculating [`levenshtein`](https://github.com/toastdriven/pylev) edit distances (string similarity) among these labels. Then it calculates *percentiles* for both metrics in [`numpy`](https://numpy.org/) and returns the results as a [`pandas`](https://pandas.pydata.org/) DataFrame.

# %%
import numpy as np
import pandas as pd
import pylev

def get_related (model, query, n=20, granularity=100):
    """return a DataFrame of the closely related items"""
    try:
        bins = np.linspace(0, 1, num=granularity, endpoint=True)

        v = sorted(
            model.wv.most_similar(positive=[query], topn=n), 
            key=lambda x: x[1], 
            reverse=True
        )
        
        df = pd.DataFrame(v, columns=["ingredient", "similarity"])
        
        s = df["similarity"]
        quantiles = s.quantile(bins, interpolation="nearest")
        df["sim_pct"] = np.digitize(s, quantiles) - 1
        
        df["levenshtein"] = [ pylev.levenshtein(d, query) / len(query) for d in df["ingredient"] ]
        s = df["levenshtein"]
        quantiles = s.quantile(bins, interpolation="nearest")
        df["lev_pct"] = granularity - np.digitize(s, quantiles)

        return df
    except KeyError:
        return pd.DataFrame(columns=["ingredient", "similarity", "percentile"])

# %% [markdown]
# Let's try this with `dried basil` as the ingredient to query, and review the top `50` most similar other ingredients returned as the DataFrame `df`:

# %%
df = get_related(model, "dried basil", n=50)
df
# Out:
#                       ingredient  similarity  sim_pct  levenshtein  lev_pct
# 0             dried basil leaves    0.686203       99     0.636364       82
# 1                      dry basil    0.638763       97     0.272727       98
# 2                 dried rosemary    0.627676       95     0.636364       82
# 3        dried italian seasoning    0.601675       93     1.272727       36
# 4                    fresh basil    0.597884       91     0.363636       96
# 5              italian seasoning    0.568717       89     1.090909       46
# 6                 dried marjoram    0.566626       87     0.636364       82
# 7          dried rosemary leaves    0.565873       85     1.181818       38
# 8         italian herb seasoning    0.554286       83     1.454545       20
# 9                  dried parsley    0.551651       81     0.454545       92
# 10      dried sweet basil leaves    0.536325       79     1.181818       38
# 11                         basil    0.506697       77     0.545455       90
# 12          dried parsley flakes    0.491033       75     1.000000       58
# 13  dried italian herb seasoning    0.470135       73     1.636364       14
# 14                   dry oregano    0.468503       71     0.818182       74
# 15            fresh basil leaves    0.467454       69     1.000000       58
# 16            dried thyme leaves    0.462502       67     1.000000       58
# 17   part-skim mozzarella cheese    0.459879       65     2.090909        0
# 18         sweet italian sausage    0.455093       63     1.545455       18
# 19                italian spices    0.454753       61     1.090909       46
# 20          quick-cooking barley    0.454275       59     1.454545       20
# 21               lasagna noodles    0.453039       57     1.181818       38
# 22             dried whole thyme    0.451908       55     1.000000       58
# 23  italian-style diced tomatoes    0.445755       53     2.090909        0
# 24     italian style breadcrumbs    0.443218       51     1.909091        8
# 25         whole wheat spaghetti    0.439855       49     1.636364       14
# 26                   dried thyme    0.439644       47     0.454545       92
# 27              italian sausages    0.438669       45     1.090909       46
# 28         italian seasoning mix    0.437540       43     1.454545       20
# 29        italian-style tomatoes    0.436734       41     1.727273       12
# 30   sweet italian sausage links    0.433589       39     2.000000        4
# 31       dried red pepper flakes    0.433394       37     1.454545       20
# 32               italian sausage    0.433083       35     1.000000       58
# 33            herb seasoning mix    0.431304       33     1.363636       32
# 34                      ditalini    0.430197       31     0.727273       80
# 35              sliced mushrooms    0.429340       29     1.000000       58
# 36          small macaroni pasta    0.428445       27     1.454545       20
# 37            hunts tomato paste    0.428205       25     1.363636       32
# 38                    ziti pasta    0.426230       23     0.636364       82
# 39       fat-free ricotta cheese    0.425293       21     1.818182       10
# 40              fresh basil leaf    0.424568       19     0.818182       74
# 41  italian seasoned breadcrumbs    0.421939       17     2.000000        4
# 42           pitted black olives    0.419117       15     1.181818       38
# 43                   feta cheese    0.418987       13     1.000000       58
# 44               fresh mushrooms    0.418562       11     1.090909       46
# 45                 parmesan rind    0.417531        9     0.909091       72
# 46                 romano cheese    0.415093        7     1.090909       46
# 47                cheese ravioli    0.413782        5     0.818182       74
# 48          bulk italian sausage    0.412068        3     1.454545       20
# 49                thin spaghetti    0.411359        1     1.090909       46

# %% [markdown]
# Note how some of the most similar items, based on vector embedding, are *synonyms* or special forms of our query `dried basil` ingredient: `dried basil leaves`, `dry basil`, `dried sweet basil leaves`, etc. These tend to rank high in terms of levenshtein distance too.

# %% [markdown]
# Let's plot the similarity measures:

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use("ggplot")

df["similarity"].plot(alpha=0.75, rot=0)
plt.show()

# %% [markdown]
# Notice the inflection points at approximately `0.57` and again at `0.47` in that plot.
# We could use some statistical techniques (e.g., clustering) to segment the similarities into a few groups:
#
#   * potential synonyms for the query
#   * potential [hypernyms and hyponyms](https://en.wikipedia.org/wiki/Hyponymy_and_hypernymy) for the query
#   * other ingredients that pair well with the query

# %% [markdown]
# In this example, below a threshold of the 75th percentile for vector embedding similarity, the related ingredients are less about being synonyms and more about other foods that pair well with basil.
#
# Let's define another function `rank_related()` which ranks the related ingredients based on a combination of these two metrics.
# This uses a cheap approximation of a [*pareto archive*](https://www.cs.bham.ac.uk/~jdk/multi/) for the ranking -- which comes in handing for recommender systems and custom search applications that must combine multiple ranking metrics:

# %%
import math

def rms (values):
    """calculate root mean square"""
    numer = sum([x for x in map(lambda x: float(x)**2.0, values)])
    denom = float(len(values))
    return math.sqrt(numer / denom)

def rank_related (df):
    df2 = df.copy(deep=True)
    df2["related"] = df2.apply(lambda row: rms([row[2], row[4]]), axis=1)
    return df2.sort_values(by=["related"], ascending=False)

# %%
rank_related(df)
# Out:
#                       ingredient  similarity  sim_pct  levenshtein  lev_pct  \
# 1                      dry basil    0.638763       97     0.272727       98
# 4                    fresh basil    0.597884       91     0.363636       96
# 0             dried basil leaves    0.686203       99     0.636364       82
# 2                 dried rosemary    0.627676       95     0.636364       82
# 9                  dried parsley    0.551651       81     0.454545       92
# 6                 dried marjoram    0.566626       87     0.636364       82
# 11                         basil    0.506697       77     0.545455       90
# 26                   dried thyme    0.439644       47     0.454545       92
# 14                   dry oregano    0.468503       71     0.818182       74
# 5              italian seasoning    0.568717       89     1.090909       46
# 3        dried italian seasoning    0.601675       93     1.272727       36
# 12          dried parsley flakes    0.491033       75     1.000000       58
# 7          dried rosemary leaves    0.565873       85     1.181818       38
# 15            fresh basil leaves    0.467454       69     1.000000       58
# 16            dried thyme leaves    0.462502       67     1.000000       58
# 10      dried sweet basil leaves    0.536325       79     1.181818       38
# 34                      ditalini    0.430197       31     0.727273       80
# 8         italian herb seasoning    0.554286       83     1.454545       20
# 38                    ziti pasta    0.426230       23     0.636364       82
# 22             dried whole thyme    0.451908       55     1.000000       58
# 19                italian spices    0.454753       61     1.090909       46
# 40              fresh basil leaf    0.424568       19     0.818182       74
# 13  dried italian herb seasoning    0.470135       73     1.636364       14
# 47                cheese ravioli    0.413782        5     0.818182       74
# 45                 parmesan rind    0.417531        9     0.909091       72
# 21               lasagna noodles    0.453039       57     1.181818       38
# 32               italian sausage    0.433083       35     1.000000       58
# 18         sweet italian sausage    0.455093       63     1.545455       18
# 17   part-skim mozzarella cheese    0.459879       65     2.090909        0
# 35              sliced mushrooms    0.429340       29     1.000000       58
# 27              italian sausages    0.438669       45     1.090909       46
# 20          quick-cooking barley    0.454275       59     1.454545       20
# 43                   feta cheese    0.418987       13     1.000000       58
# 23  italian-style diced tomatoes    0.445755       53     2.090909        0
# 24     italian style breadcrumbs    0.443218       51     1.909091        8
# 25         whole wheat spaghetti    0.439855       49     1.636364       14
# 28         italian seasoning mix    0.437540       43     1.454545       20
# 44               fresh mushrooms    0.418562       11     1.090909       46
# 46                 romano cheese    0.415093        7     1.090909       46
# 49                thin spaghetti    0.411359        1     1.090909       46
# 33            herb seasoning mix    0.431304       33     1.363636       32
# 29        italian-style tomatoes    0.436734       41     1.727273       12
# 31       dried red pepper flakes    0.433394       37     1.454545       20
# 42           pitted black olives    0.419117       15     1.181818       38
# 37            hunts tomato paste    0.428205       25     1.363636       32
# 30   sweet italian sausage links    0.433589       39     2.000000        4
# 36          small macaroni pasta    0.428445       27     1.454545       20
# 39       fat-free ricotta cheese    0.425293       21     1.818182       10
# 48          bulk italian sausage    0.412068        3     1.454545       20
# 41  italian seasoned breadcrumbs    0.421939       17     2.000000        4
#
#       related
# 1   97.501282
# 4   93.533416
# 0   90.898295
# 2   88.738380
# 9   86.674679
# 6   84.536974
# 11  83.752612
# 26  73.051352
# 14  72.515516
# 5   70.841372
# 3   70.515956
# 12  67.041032
# 7   65.836920
# 15  63.737744
# 16  62.661791
# 10  61.987902
# 34  60.667125
# 8   60.369694
# 38  60.220428
# 22  56.519908
# 19  54.023143
# 40  54.023143
# 13  52.559490
# 47  52.445210
# 45  51.307894
# 21  48.440685
# 32  47.900939
# 18  46.330336
# 17  45.961941
# 35  45.853026
# 27  45.502747
# 20  44.051107
# 43  42.029751
# 23  37.476659
# 24  36.503424
# 25  36.034705
# 28  33.533565
# 44  33.443983
# 46  32.901368
# 49  32.534597
# 33  32.503846
# 29  30.207615
# 31  29.740545
# 42  28.887714
# 37  28.714108
# 30  27.721833
# 36  23.759209
# 39  16.446884
# 48  14.300350
# 41  12.349089

# %% [markdown]
# Notice how the "synonym" cases tend to move up to the top now?
# Meanwhile while the "pairs well with" are in the lower half of the ranked list: `fresh mushrooms`, `italian turkey sausage`, `cooked spaghetti`, `white kidney beans`, etc.

# %% [markdown]
# ---
#
# ## Exercises

# %% [markdown]
# **Exercise 1:**
#
# Build a report for a *human-in-the-loop* reviewer, using the `rank_related()` function while iterating over `vocab` to make algorithmic suggestions for possible synonyms.

# %% [markdown]
# **Exercise 2:**
#
# How would you make algorithmic suggestions for a reviewer about which ingredients could be related to a query, e.g., using the `skos:broader` and `skos:narrower` relations in the [`skos`](https://www.w3.org/2004/02/skos/) vocabulary to represent *hypernyms* and *hyponyms* respectively?
# This could extend the KG to provide a kind of thesaurus about recipe ingredients.
