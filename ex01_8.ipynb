# %% [markdown]
# # Vector embedding with `gensim`
#
# Let's make use of deep learning through a technique called *embedding* -- to analyze the relatedness of the labels used for recipe ingredients.
#
# Among the most closely related ingredients:
#
#   * Some are very close synonyms and should be consolidated to improve data quality
#   * Others are interesting other ingredients that pair frequently, useful for recommendations
#
# On the one hand, this approach is quite helpful for analyzing the NLP annotations that go into a knowledge graph.
# On the other hand it can be used along with [`SKOS`](https://www.w3.org/2004/02/skos/) or similar vocabularies for ontology-based discovery within the graph, e.g., for advanced search UI.

# %% [markdown]
# ## Curating annotations
#
# We'll be working with the labels for ingredients that go into our KG.
# Looking at the raw data, there are many cases where slightly different spellings are being used for the same entity.
#
# As a first step let's define a list of synonyms to substitute, prior to running the vector embedding.
# This will help produce better quality results.
#
# Note that this kind of work comes of the general heading of *curating annotations* ... which is what we spend so much time doing in KG work.
# It's similar to how *data preparation* is ~80% of the workload for data science teams, and for good reason.

# %%
SYNONYMS = {
    "vanilla": "vanilla",
    "vanilla extract": "vanilla",

    "onions": "onion",
    "onion": "onion",
        
    "carrots": "carrot",
    "carrot": "carrot",

    "potatoes": "potato",
    "potato": "potato",
    
    "tomatoes": "tomato",
    "fresh tomatoes": "tomato",
    "fresh tomato": "tomato",
    
    "garlic": "garlic",
    "garlic clove": "garlic",
    "garlic cloves": "garlic",
}

# %% [markdown]
# ## Analyze ingredient labels from 250K recipes

# %%
import csv

MAX_ROW = 250000 # 231638

max_context = 0
min_context = 1000

recipes = []
vocab = set()

with open("dat/all_ind.csv", "r") as f:
    reader = csv.reader(f)
    next(reader, None) # remove file header

    for i, row in enumerate(reader):
        id = row[0]
        ind_set = set()
        
        # substitute synonyms
        for ind in set(eval(row[1])):
            if ind in SYNONYMS:
                ind_set.add(SYNONYMS[ind])
            else:
                ind_set.add(ind)
        
        if len(ind_set) > 1:
            recipes.append([id, ind_set])
            vocab.update(ind_set)
        
            max_context = max(max_context, len(ind_set))
            min_context = min(min_context, len(ind_set))

        if i > MAX_ROW:
            break

print("max context: {} unique ingredients per recipe".format(max_context))
print("min context: {} unique ingredients per recipe".format(min_context))
print("vocab size", len(list(vocab)))
# Out:
# max context: 43 unique ingredients per recipe
# min context: 2 unique ingredients per recipe
# vocab size 14934

# %%
recipes
# Out:
# [['137739',
#   {'butter',
#    'honey',
#    'mexican seasoning',
#    'mixed spice',
#    'olive oil',
#    'salt',
#    'winter squash'}],
#  ['31490',
#   {'cheese',
#    'eggs',
#    'milk',
#    'prepared pizza crust',
#    'salt and pepper',
#    'sausage patty'}],
#  ['112140',
#   {'cheddar cheese',
#    'chili powder',
#    'diced tomatoes',
#    'ground beef',
#    'ground cumin',
#    'kidney beans',
#    'lettuce',
#    'rotel tomatoes',
#    'salt',
#    'tomato paste',
#    'tomato soup',
#    'water',
#    'yellow onions'}],
#  ['59389',
#   {'new potatoes',
#    'olive oil',
#    'parsley',
#    'pepper',
#    'red bell pepper',
#    'red wine vinegar',
#    'salt',
#    'shallots',
#    'spreadable cheese with garlic and herbs',
#    'tarragon',
#    'yellow bell pepper'}],
#  ['44061',
#   {'apple cider vinegar',
#    'cinnamon oil',
#    'clove oil',
#    'dry mustard',
#    'pepper',
#    'salt',
#    'sugar',
#    'tomato juice'}],
#  ['5289',
#   {'apple', 'frozen apple juice concentrate', 'milk', 'vanilla ice cream'}],
#  ['25274',
#   {'extra virgin olive oil',
#    'fennel seeds',
#    'garlic',
#    'green olives',
#    'orange juice',
#    'orange rind',
#    'peppercorn',
#    'red chile',
#    'ripe olives'}],
#  ['67888',
#   {'a.1. original sauce',
#    'brown sugar',
#    'chili powder',
#    'cinnamon sticks',
#    'cracked black pepper',
#    'cumin',
#    'dry mustard',
#    'fresh cilantro leaves',
#    'fresh coarse ground black pepper',
#    'fresh garlic',
#    'fresh ginger',
#    'honey',
#    'liquid smoke',
#    'mirin',
#    'orange, juice of',
#    'pork spareribs',
#    'salt',
#    'soy sauce',
#    'tomato sauce',
#    'water',
#    'white vinegar',
#    'yellow onion'}],
#  ['70971',
#   {'bananas',
#    'chocolate sandwich style cookies',
#    'chocolate syrup',
#    'strawberry ice cream',
#    'vanilla ice cream',
#    'whipped cream'}],
#  ['75452',
#   {'baking soda',
#    'bananas',
#    'cake flour',
#    'eggs',
#    'fresh lemon juice',
#    'orange rind',
#    'salt',
#    'sugar',
#    'unsalted butter'}],
#  ['109439',
#   {'prepared horseradish', 'sour cream', 'whole berry cranberry sauce'}],
#  ['42198',
#   {'butter',
#    'eggs',
#    'powdered sugar',
#    'strawberry',
#    'vanilla wafers',
#    'walnuts',
#    'whipping cream'}],
#  ['67547',
#   {'bacon',
#    'black pepper',
#    'chicken bouillon cubes',
#    'chili powder',
#    'cornstarch',
#    'dark brown sugar',
#    'garlic powder',
#    'great northern bean',
#    'molasses',
#    'mustard powder',
#    'onion',
#    'salt',
#    'water'}],
#  ['107517',
#   {'brown sugar',
#    'collard greens',
#    'ham hock',
#    'hot sauce',
#    'molasses',
#    'salt',
#    'whiskey'}],
#  ['39959',
#   {'burnet root',
#    'gentian root',
#    'scullcap herb',
#    'spearmint',
#    'wood bethony'}],
#  ['63986',
#   {'chicken rice soup',
#    'dry mustard',
#    'flour',
#    'garlic powder',
#    'lean pork chops',
#    'oil',
#    'salt'}],
#  ['43026',
#   {'cheese', 'cornstarch', 'egg roll wrap', 'oil', 'whole green chilies'}],
#  ['23933', {'butterscotch chips', 'chinese noodles', 'salted peanuts'}],
#  ['8559',
#   {'beef broth',
#    'celery',
#    'cooking oil',
#    'ground pork',
#    'hamburger buns',
#    'onion',
#    'soy sauce'}],
#  ['23850',
#   {'broccoli floret',
#    'canola oil',
#    'cauliflower',
#    'escarole',
#    'fresh herb',
#    'garlic',
#    'great northern bean',
#    'green peas',
#    'ground coriander',
#    'onion',
#    'potato',
#    'red bell pepper',
#    'salt and pepper',
#    'salt free herb and spice seasoning mix',
#    'vegetable bouillon cubes',
#    'water'}],
#  ['76808',
#   {'boiling potatoes',
#    'coarse salt',
#    'fresh ground black pepper',
#    'fresh spinach leaves',
#    'nutmeg',
#    'salt',
#    'unsalted butter',
#    'water'}],
#  ['24701',
#   {'apple juice',
#    'broth',
#    'celery',
#    'dried thyme',
#    'fresh parsley',
#    'olive oil',
#    'onion',
#    'rolled oats',
#    'salt',
#    'scallion',
#    'spinach',
#    'white pepper'}],
#  ['83873',
#   {'all-purpose flour',
#    'boneless skinless chicken breast halves',
#    'condensed cream of chicken soup',
#    'cornstarch',
#    'egg',
#    'garlic powder',
#    'oil',
#    'paprika',
#    'salt and pepper',
#    'seasoning salt'}],
#  ['107699',
#   {'all-purpose flour',
#    'baking powder',
#    'bread',
#    'brown sugar',
#    'butter',
#    'egg',
#    'granulated sugar',
#    'ground cinnamon',
#    'milk',
#    'powdered sugar',
#    'salt',
#    'vanilla',
#    'vegetable oil'}],
#  ['49262', {'butter', 'egg yolks', 'lemon, juice of', 'salt', 'white pepper'}],
#  ['48156',
#   {'black cumin',
#    'ground black pepper',
#    'ground coriander',
#    'ground cumin',
#    'ground ginger',
#    'ground turmeric'}],
#  ['54272',
#   {'black pepper',
#    'celery',
#    'chili powder',
#    'diced tomatoes',
#    'garlic',
#    'green pepper',
#    'jalapenos',
#    'kidney beans',
#    'onion',
#    'red pepper flakes',
#    'salt',
#    'vegetarian ground beef'}],
#  ['47366',
#   {'beef bouillon cube',
#    'beef stew meat',
#    'cabbage',
#    'dried parsley',
#    'elbow macaroni',
#    'garbanzo beans',
#    'ground pepper',
#    'ground thyme',
#    'onion',
#    'parmesan cheese',
#    'salt',
#    'tomato',
#    'water',
#    'zucchini'}],
#  ['37073', {'margarine', 'red potatoes', 'rosemary'}],
#  ['44123',
#   {'black beans',
#    'broccoli floret',
#    'broccoli stem',
#    'carrot',
#    'celery',
#    'chicken stock',
#    'cornstarch',
#    'dried oregano',
#    'dried sweet basil leaves',
#    'dried thyme',
#    'dry white wine',
#    'heavy cream',
#    'onion',
#    'salt & fresh ground pepper',
#    'smoked chicken',
#    'tabasco sauce',
#    'unsalted butter',
#    'worcestershire sauce'}],
#  ['27087',
#   {'all-purpose flour',
#    'baking cocoa',
#    'baking powder',
#    'butter',
#    'eggs',
#    'miniature peppermint patties',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['59952',
#   {'cheddar cheese',
#    'cornmeal',
#    'ground beef',
#    'hot chili pepper',
#    'onion',
#    'pepper',
#    'salt',
#    'sliced ripe olives',
#    'tabasco sauce',
#    'taco sauce',
#    'tomato sauce',
#    'whole kernel corn'}],
#  ['93249', {'butter', 'dry ranch dressing mix', 'french bread'}],
#  ['54100',
#   {'black pepper',
#    'dry mustard',
#    'egg substitute',
#    'fresh breadcrumb',
#    'ground venison',
#    'non-fat powdered milk',
#    'onion',
#    'salt',
#    'water',
#    'worcestershire sauce'}],
#  ['67664', {'frozen juice concentrate', 'milk', 'plain yogurt'}],
#  ['87098',
#   {'carrot',
#    'corn',
#    'diced tomatoes',
#    'green beans',
#    'low sodium chicken broth',
#    'potato',
#    'wax beans',
#    'zucchini'}],
#  ['25775',
#   {'black pepper',
#    'condensed cream of mushroom soup',
#    'crouton',
#    'egg',
#    'frozen chopped spinach',
#    'onion',
#    'salt',
#    'sharp cheddar cheese'}],
#  ['33165',
#   {'celery seed',
#    'diced pimentos',
#    'fat-free mayonnaise',
#    'garlic',
#    'green onion',
#    'low-fat sour cream',
#    'pepper',
#    'plain low-fat yogurt',
#    'prepared mustard',
#    'red potatoes',
#    'salt',
#    'sugar',
#    'white wine vinegar'}],
#  ['38798',
#   {'eggs',
#    'frozen chopped spinach',
#    'garlic powder',
#    'margarine',
#    'onion',
#    'oregano',
#    'sage',
#    'soft breadcrumbs'}],
#  ['22123',
#   {'condensed cream of mushroom & garlic soup',
#    'cooking oil',
#    'cornbread mix',
#    'cream of mushroom soup',
#    'frozen vegetables',
#    'ground beef',
#    'onion',
#    'salt & pepper'}],
#  ['90921',
#   {'angel hair pasta',
#    'garlic',
#    'green onions',
#    'honey',
#    'soy sauce',
#    'stir fry vegetables',
#    'toasted sesame oil',
#    'toasted sesame seeds'}],
#  ['93959',
#   {'all-purpose flour',
#    'baking powder',
#    'baking soda',
#    'brown sugar',
#    'buckwheat flour',
#    'butter',
#    'canola oil',
#    'cinnamon',
#    'eggs',
#    'flour',
#    'ground cinnamon',
#    'ground cloves',
#    'honey',
#    'low-fat buttermilk',
#    'orange juice',
#    'orange rind',
#    'pecans',
#    'salt',
#    'sugar',
#    'unsweetened cocoa',
#    'yam'}],
#  ['93958',
#   {'all-purpose flour',
#    'baking powder',
#    'baking soda',
#    'boiling water',
#    'buckwheat flour',
#    'canola oil',
#    'eggs',
#    'granulated sugar',
#    'ground cinnamon',
#    'ground cloves',
#    'low-fat buttermilk',
#    'orange juice',
#    'orange rind',
#    'raisins',
#    'salt',
#    'sorghum',
#    'unsweetened cocoa',
#    'yam'}],
#  ['58224',
#   {'american cheese',
#    'beer',
#    'cayenne',
#    'garlic',
#    'ground beef',
#    'prepared yellow mustard',
#    'salt & pepper',
#    'sugar'}],
#  ['33606',
#   {'cheese',
#    'chives',
#    'cider vinegar',
#    'dill pickles',
#    'garlic powder',
#    'green onion',
#    'ham',
#    'italian seasoning',
#    'olive oil',
#    'onion powder',
#    'ripe olives',
#    'salt and pepper',
#    'sweet pepper',
#    'tomato',
#    'tri-color spiral pasta',
#    'water chestnut'}],
#  ['94710',
#   {'basil',
#    'flat leaf parsley',
#    'frozen french fries',
#    'oil',
#    'oregano',
#    'parmesan cheese',
#    'salt & freshly ground black pepper'}],
#  ['35173',
#   {'butter',
#    'cheddar cheese',
#    'deli turkey',
#    'good seasonings italian salad dressing mix',
#    'ham',
#    'mozzarella cheese',
#    'pepperoni',
#    'sandwich bun',
#    'swiss cheese'}],
#  ['83025',
#   {'all-purpose flour',
#    'baking powder',
#    'butter',
#    'eggs',
#    'icing sugar',
#    'milk',
#    'salt',
#    'shortening',
#    'sugar',
#    'vanilla'}],
#  ['52804',
#   {'carrot',
#    'cinnamon',
#    'coconut',
#    'crushed pineapple',
#    'eggs',
#    'nutmeg',
#    'oil',
#    'pecans',
#    'vanilla instant pudding mix',
#    'water',
#    'yellow cake mix'}],
#  ['108414',
#   {'butter',
#    'egg',
#    'heavy cream',
#    'honey',
#    'jalapenos',
#    'jiffy corn muffin mix',
#    'onion',
#    'red bell pepper',
#    'sharp cheddar cheese',
#    'whole kernel corn'}],
#  ['26995',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'butter',
#    'cinnamon',
#    'crushed pineapple',
#    'dry yeast',
#    'eggs',
#    'flour',
#    'milk',
#    'nuts',
#    'raisins',
#    'salt',
#    'sugar',
#    'vanilla',
#    'vegetable oil',
#    'water'}],
#  ['53402',
#   {'cottage cheese',
#    'dried basil',
#    'eggs',
#    'garlic',
#    'ground beef',
#    'ground black pepper',
#    'italian sausage',
#    'lasagna noodle',
#    'mozzarella cheese',
#    'parmesan cheese',
#    'parsley flakes',
#    'ricotta cheese',
#    'salt',
#    'tomato paste',
#    'whole tomato'}],
#  ['59632',
#   {'beef',
#    'cheese',
#    'cottage cheese',
#    'eggs',
#    'frozen chopped spinach',
#    'herbs',
#    'olive oil flavored cooking spray',
#    'pepper',
#    'salt',
#    'spices',
#    'toasted wheat germ'}],
#  ['22526',
#   {'brown sugar',
#    'butter',
#    'cinnamon',
#    'instant vanilla pudding',
#    'raisins',
#    'rolls'}],
#  ['100870',
#   {'garlic',
#    'granulated sugar',
#    'ground beef',
#    'prego spaghetti sauce',
#    'stewed tomatoes',
#    'white onion'}],
#  ['84797',
#   {'beef steaks',
#    'brown sugar',
#    'dried dill weed',
#    'fresh garlic',
#    'fresh lemon juice',
#    'fresh parsley',
#    'honey',
#    'hot sauce',
#    'ketchup',
#    'sour cream',
#    'spicy mustard',
#    'vegetable oil'}],
#  ['35653',
#   {'baking powder', 'butter', 'egg', 'flour', 'milk', 'salt', 'sugar'}],
#  ['32169',
#   {'button mushrooms',
#    'chicken breasts',
#    'dried basil',
#    'dried oregano',
#    'fresh ground black pepper',
#    'fresh parsley',
#    'garlic',
#    'hot sauce',
#    'olive oil',
#    'onion',
#    'parmesan cheese',
#    'pasta',
#    'salsa',
#    'tomato',
#    'water'}],
#  ['24478', {'cider vinegar', 'fresh herb', 'fresh herbs'}],
#  ['44045',
#   {'baking powder',
#    'cream',
#    'eggs',
#    'fat',
#    'flour',
#    'fresh corn',
#    'pepper',
#    'salt'}],
#  ['60219',
#   {'black olives',
#    'cheddar cheese soup',
#    'fettuccine pasta',
#    'jalapeno',
#    'milk',
#    'picante sauce'}],
#  ['81185',
#   {'cilantro',
#    'frozen peas',
#    'hass avocado',
#    'lemons, juice of',
#    'onion',
#    'salt',
#    'tomato'}],
#  ['30131',
#   {'basil',
#    'garlic powder',
#    'lemon juice',
#    'oil',
#    'pepper',
#    'soy sauce',
#    'worcestershire sauce'}],
#  ['63593',
#   {'apple', 'cream cheese', 'milk', 'pear', 'unflavored gelatin', 'yogurt'}],
#  ['43164',
#   {'bacon',
#    'bay leaf',
#    'butter',
#    'carrot',
#    'oil',
#    'onion',
#    'parsley sprigs',
#    'pepper',
#    'salt',
#    'thyme',
#    'veal roast'}],
#  ['30300', {'black pepper', 'crackers', 'mayonnaise', 'tomato'}],
#  ['78655',
#   {'brine',
#    'capers',
#    'carrot',
#    'ciabatta',
#    'fresh basil',
#    'fresh parsley',
#    'garlic',
#    'genoa salami',
#    'green olives',
#    'ham',
#    'kalamata olive',
#    'olive oil',
#    'oregano leaves',
#    'provolone cheese',
#    'red wine vinegar',
#    'sweet onion',
#    'tomato'}],
#  ['74805',
#   {'powdered sugar',
#    'vanilla',
#    'vanilla instant pudding mix',
#    'whipping cream'}],
#  ['71635',
#   {'cookie',
#    'cream cheese',
#    'gelatin',
#    'milk',
#    'miniature semisweet chocolate chips',
#    'prepared graham cracker crusts',
#    'sugar',
#    'vanilla'}],
#  ['38276',
#   {'all-purpose flour',
#    'baking powder',
#    'butter',
#    'carrot',
#    'cayenne pepper',
#    'celery',
#    'chili powder',
#    'cloves',
#    'egg',
#    'flour',
#    'green pepper',
#    'ground cumin',
#    'monterey jack cheese',
#    'onion',
#    'oregano',
#    'salt',
#    'sliced mushrooms',
#    'soy sauce',
#    'tomato',
#    'vegetable shortening',
#    'water',
#    'zucchini'}],
#  ['97052', {'half-and-half', 'salt and pepper', 'sweet butter', 'sweet corn'}],
#  ['26835',
#   {'all-purpose flour',
#    'baking soda',
#    'butter',
#    'eggs',
#    'lemon, rind of',
#    'salt',
#    'sugar',
#    'vanilla',
#    'yogurt'}],
#  ['32271',
#   {'butter',
#    'eggs',
#    'flour',
#    'nuts',
#    'sugar',
#    'unsweetened chocolate squares',
#    'vanilla'}],
#  ['107229',
#   {'broccoli',
#    'chili-garlic sauce',
#    'cooked chicken',
#    'fresh cilantro',
#    'fresh ginger',
#    'green onions',
#    'reduced sodium soy sauce',
#    'rice vinegar',
#    'sesame oil',
#    'sesame seeds',
#    'vegetable oil',
#    'vermicelli'}],
#  ['5060',
#   {'apples',
#    'celery',
#    'orange juice',
#    'orange rind',
#    'pecans',
#    'philadelphia cream cheese',
#    'sugar'}],
#  ['42570',
#   {'boneless chicken breast',
#    'cayenne',
#    'cumin',
#    'fresh ground pepper',
#    'garlic',
#    'lemon juice',
#    'olive oil',
#    'paprika',
#    'salt',
#    'thyme'}],
#  ['52443',
#   {'baking potato',
#    'garlic powder',
#    'mozzarella cheese',
#    'oregano leaves',
#    'parmesan cheese',
#    'part-skim ricotta cheese',
#    'tomato sauce'}],
#  ['35595',
#   {'black pepper',
#    'cornstarch',
#    'mushroom pieces',
#    'onion',
#    'sodium-free vegetable broth',
#    'tabasco sauce',
#    'tomato puree',
#    'white wine'}],
#  ['108804',
#   {'albacore tuna in water',
#    'bibb lettuce',
#    'black pepper',
#    'fresh basil',
#    'garlic',
#    'light olive oil',
#    'red sweet bell peppers',
#    'red wine vinegar',
#    'salt',
#    'scallions',
#    'white kidney beans'}],
#  ['83950',
#   {'bacon',
#    'beef consomme',
#    'black pepper',
#    'butter',
#    'carrot',
#    'celery',
#    'crushed tomatoes',
#    'dry white wine',
#    'garlic',
#    'ground pork',
#    'lean ground beef',
#    'milk',
#    'nutmeg',
#    'olive oil',
#    'onion',
#    'oregano',
#    'penne pasta',
#    'red pepper flakes',
#    'rubbed sage',
#    'salt'}],
#  ['19208', {'apples', 'red cinnamon candies', 'sugar substitute', 'water'}],
#  ['64302',
#   {'brown sugar',
#    'celery',
#    'cucumber',
#    'elbow macaroni',
#    'green pepper',
#    'ketchup',
#    'lemon juice',
#    'oil',
#    'onion',
#    'tomato'}],
#  ['35964',
#   {'baking powder',
#    'brown sugar',
#    'cocoa',
#    'flour',
#    'hot water',
#    'milk',
#    'salt',
#    'sugar',
#    'vanilla',
#    'vegetable oil'}],
#  ['71457',
#   {'apple pie filling',
#    'butter',
#    'eggs',
#    'flour',
#    'milk',
#    'powdered sugar',
#    'salt',
#    'toasted almonds'}],
#  ['95926', {'bananas', 'mayonnaise', 'white bread'}],
#  ['103948',
#   {'all-purpose flour',
#    'boneless skinless chicken thighs',
#    'breadcrumbs',
#    'chicken stock',
#    'dried oregano',
#    'dried thyme',
#    'dry white wine',
#    'fresh ground black pepper',
#    'garlic powder',
#    'lean ground beef',
#    'milk',
#    'onion',
#    'poultry seasoning',
#    'salt',
#    'vegetable oil'}],
#  ['99024',
#   {'cream cheese', 'lemon juice', 'liquid smoke', 'onion', 'salmon', 'salt'}],
#  ['64045',
#   {'bean sprouts',
#    'brown sugar',
#    'carrot',
#    'desiccated coconut',
#    'garlic',
#    'ginger',
#    'green beans',
#    'ground cayenne pepper',
#    'ground coriander',
#    'ground cumin',
#    'onion',
#    'peanut oil',
#    'peanuts',
#    'red chili pepper',
#    'sambal oelek',
#    'soy sauce',
#    'tempeh',
#    'tomato',
#    'vegetable stock',
#    'water'}],
#  ['41756',
#   {'dried breadcrumbs',
#    'eggs',
#    'ground beef',
#    'lemon juice',
#    'onion',
#    'salt and pepper',
#    'sugar',
#    'tomato soup',
#    'water'}],
#  ['112959',
#   {'avocado',
#    'chunky salsa',
#    'fresh cilantro',
#    'hot sauce',
#    'lime juice',
#    'salt and pepper',
#    'soft silken tofu'}],
#  ['83062',
#   {'baking soda',
#    'bananas',
#    'cinnamon',
#    'eggs',
#    'flour',
#    'ground cloves',
#    'nutmeg',
#    'salt',
#    'shortening',
#    'walnuts',
#    'white sugar'}],
#  ['98930',
#   {'boneless skinless chicken breast',
#    'dried basil',
#    'lime juice',
#    'olive oil',
#    'salt and pepper',
#    'tomato'}],
#  ['83133',
#   {'beef ribs',
#    'brown sugar',
#    'fresh lemon juice',
#    'ketchup',
#    'mustard',
#    'onion',
#    'salt',
#    'vegetable oil',
#    'water',
#    'worcestershire sauce'}],
#  ['39947', {'egg whites', 'green grape', 'sugar'}],
#  ['44895',
#   {'betty crocker fudge brownie mix',
#    'eggs',
#    'milk chocolate candy bars',
#    'vegetable oil',
#    'water'}],
#  ['39363',
#   {'baking powder',
#    'baking soda',
#    'bananas',
#    'butter',
#    'chocolate chips',
#    'eggs',
#    'flour',
#    'nuts',
#    'salt',
#    'sugar',
#    'water'}],
#  ['62368',
#   {'brown sugar',
#    'butter',
#    'chocolate chips',
#    'cream cheese',
#    'eggs',
#    'flour',
#    'oreo cookie crumbs',
#    'sour cream',
#    'sweetened condensed milk',
#    'vanilla'}],
#  ['111875',
#   {'2% low-fat milk',
#    'banana',
#    'natural-style peanut butter',
#    'sugar-free non-fat vanilla yogurt'}],
#  ['42522',
#   {'bean dip',
#    'cheddar cheese',
#    'cream cheese',
#    'sour cream',
#    'taco seasoning'}],
#  ['34930',
#   {'american cheese',
#    'bacon',
#    'dill weed',
#    'ground sirloin',
#    'iceberg lettuce',
#    "mccormick's montreal brand steak seasoning",
#    'no-salt-added ketchup',
#    'onion',
#    'tomato'}],
#  ['63793',
#   {'chat masala',
#    'chopped tomato',
#    'cucumber',
#    'paprika',
#    'plain yogurt',
#    'potato',
#    'salt'}],
#  ['61973',
#   {'baking soda',
#    'brown sugar',
#    'buttermilk',
#    'carrot',
#    'cinnamon',
#    'corn oil',
#    'egg',
#    'natural bran',
#    'raisins',
#    'salt',
#    'vanilla',
#    'whole wheat flour'}],
#  ['45859',
#   {'grand marnier',
#    'lime juice',
#    'lime wedge',
#    'limeade',
#    'tequila',
#    'triple sec'}],
#  ['58651',
#   {'brown sugar', 'butter', 'flour', 'pecans', 'semi-sweet chocolate chips'}],
#  ['59534',
#   {'butter',
#    'cappelletti pasta',
#    'cheddar cheese',
#    'chopped tomato',
#    'corn',
#    'garlic',
#    'ground beef',
#    'milk',
#    'mushrooms',
#    'onion',
#    'pepper',
#    'salt',
#    'tomato soup'}],
#  ['24137',
#   {'dry white wine',
#    'extra virgin olive oil',
#    'garlic',
#    'hot water',
#    'parsley',
#    'salt and pepper',
#    'spaghetti',
#    'squid',
#    'tomato sauce'}],
#  ['40237',
#   {'baking soda',
#    'cocoa',
#    'flour',
#    'salt',
#    'sugar',
#    'vanilla',
#    'vegetable oil',
#    'vinegar',
#    'water'}],
#  ['18537', {'applesauce', 'brown sugar', 'clove', 'pork loin chops'}],
#  ['104243',
#   {'butter',
#    'cheddar cheese',
#    'cream cheese',
#    'green olives',
#    'ham',
#    'honey mustard',
#    'leaf lettuce',
#    'mayonnaise',
#    'prepared horseradish',
#    'provolone cheese',
#    'radish sprouts',
#    'roast beef',
#    'roasted red peppers',
#    'swiss cheese',
#    'turkey',
#    'whole wheat bread dough'}],
#  ['105069',
#   {'beef broth',
#    'butter',
#    'flour',
#    'fresh dill',
#    'lemon, juice of',
#    'onion',
#    'salt and pepper',
#    'sour cream',
#    'water',
#    'wild mushrooms'}],
#  ['70099',
#   {'asian chili sauce',
#    'bean sprouts',
#    'carrot',
#    'english cucumber',
#    'fresh cilantro',
#    'fresh ginger',
#    'garlic',
#    'green onions',
#    'honey',
#    'light soy sauce',
#    'rice noodles',
#    'rice wine vinegar',
#    'sesame oil'}],
#  ['333281',
#   {'all-purpose flour',
#    'bittersweet chocolate',
#    'brewed espresso',
#    'eggs',
#    'granulated sugar',
#    'kosher salt',
#    'unsalted butter',
#    'unsweetened cocoa powder',
#    'vanilla'}],
#  ['234069', {'brown sugar', 'dr. pepper cola', 'orange marmalade'}],
#  ['37841',
#   {'fish',
#    'gingerroot',
#    'low sodium soy sauce',
#    'peanut oil',
#    'rice wine',
#    'salt',
#    'scallions',
#    'sesame oil',
#    'white pepper'}],
#  ['144952',
#   {'beef broth',
#    'butter',
#    'flour',
#    'french bread',
#    'garlic',
#    'low sodium beef broth',
#    'olive oil',
#    'parmesan cheese',
#    'romano cheese',
#    'sherry wine',
#    'sugar',
#    'swiss cheese',
#    'yellow onions'}],
#  ['453467',
#   {'all-purpose flour',
#    'baking soda',
#    'brown sugar',
#    'chocolate chips',
#    'eggs',
#    'margarine',
#    'salt',
#    'vanilla',
#    'water',
#    'white sugar',
#    'whole wheat flour'}],
#  ['31835',
#   {'butter',
#    'cornbread',
#    'cream of chicken soup',
#    'eggs',
#    'onion',
#    'sage',
#    'squash'}],
#  ['197013',
#   {'bay leaves',
#    'bottled garlic',
#    'dried basil',
#    'dried oregano',
#    'dried parsley',
#    'garlic powder',
#    'italian sausage',
#    'olive oil',
#    'paprika',
#    'pepper',
#    'salt',
#    'sugar',
#    'tomato sauce',
#    'white onion'}],
#  ['306168',
#   {'cream of chicken soup',
#    'french-fried onions',
#    'frozen broccoli cuts',
#    'garlic powder',
#    'ground black pepper',
#    'milk',
#    'salt',
#    'sharp cheddar cheese',
#    'soy sauce'}],
#  ['286009',
#   {'all-purpose flour',
#    'almond extract',
#    'butter',
#    'eggs',
#    'pure vanilla extract',
#    'sugar',
#    'whole milk'}],
#  ['24514',
#   {'artichoke hearts',
#    'egg',
#    'fresh garlic',
#    'oil',
#    'unsalted butter',
#    'unseasoned breadcrumbs'}],
#  ['42508',
#   {'barbecue sauce',
#    'black pepper',
#    'chicken',
#    'chili powder',
#    'cider vinegar',
#    'hot red pepper sauce',
#    'salt',
#    'worcestershire sauce'}],
#  ['116679',
#   {'cheddar cheese',
#    'cream cheese',
#    'dry onion soup mix',
#    'frozen broccoli',
#    'ritz cracker crumbs',
#    'sour cream',
#    'water chestnuts'}],
#  ['124286',
#   {'baking soda',
#    'cocoa powder',
#    'cool whip',
#    'flour',
#    'instant chocolate pudding mix',
#    'mayonnaise',
#    'milk',
#    'salt',
#    'sugar',
#    'vanilla',
#    'water'}],
#  ['190',
#   {'bouillon',
#    'budweiser beer',
#    'chili powder',
#    'coriander',
#    'cornmeal',
#    'cumin',
#    'flour',
#    'garlic',
#    'hunts tomato sauce',
#    'lean chuck',
#    'lean pork',
#    'louisiana hot sauce',
#    'onion',
#    'oregano leaves',
#    'paprika',
#    'sugar',
#    'unsweetened cocoa',
#    'water'}],
#  ['475785',
#   {'baby spinach',
#    'eggs',
#    'fresh garlic',
#    'goat cheese',
#    'kosher salt',
#    'meatloaf mixture',
#    'olive oil',
#    'red bell pepper',
#    'simply potatoes shredded hash browns',
#    'unsalted butter',
#    'unsmoked bacon',
#    'white pepper',
#    'yellow onion'}],
#  ['17265',
#   {'dark brown sugar',
#    'egg white',
#    'eggs',
#    'ground cinnamon',
#    'ground cloves',
#    'ground ginger',
#    'heavy cream',
#    'milk',
#    'nutmeg',
#    'pie crusts',
#    'pumpkin puree',
#    'salt'}],
#  ['50662',
#   {'baking powder',
#    'beef',
#    'breadcrumbs',
#    'butter',
#    'celery seed',
#    'cream of chicken soup',
#    'dry onion flakes',
#    'flour',
#    'milk',
#    'onion',
#    'paprika',
#    'poppy seed',
#    'poultry seasoning',
#    'salt',
#    'sour cream',
#    'vegetable oil'}],
#  ['177187',
#   {'baking powder',
#    'baking soda',
#    'blended oatmeal',
#    'brown sugar',
#    'butter',
#    'eggs',
#    'flour',
#    'hershey chocolate candy bars',
#    'nuts',
#    'semi-sweet chocolate chips',
#    'sugar',
#    'vanilla'}],
#  ['118843',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'butter',
#    'chocolate chips',
#    'eggs',
#    'flour',
#    "hershey's semi-sweet baking chocolate",
#    'nuts',
#    'oatmeal',
#    'salt',
#    'vanilla',
#    'white sugar'}],
#  ['208179', {'butter', 'flour', 'granulated sugar', 'milk', 'vanilla'}],
#  ['500166',
#   {'cheddar cheese',
#    'corn cobs',
#    'ground beef',
#    'lettuce',
#    'onion',
#    'salsa',
#    'taco seasoning',
#    'taco shells',
#    'tomato'}],
#  ['501028',
#   {'beans',
#    'beef bouillon cube',
#    'beef broth',
#    'bell peppers',
#    'black pepper',
#    'chicken bouillon cube',
#    'chunky salsa',
#    'cinnamon',
#    'cumin',
#    'dark chocolate chips',
#    'garlic',
#    'ground coriander',
#    'habanero pepper',
#    'light brown sugar',
#    'mexican chili powder',
#    'salt',
#    'sazon goya',
#    'stewing beef',
#    'stewing pork',
#    'tomato paste',
#    'tortilla chips',
#    'white onion'}],
#  ['136602',
#   {'all-purpose flour',
#    'baking soda',
#    'brown sugar',
#    'butter',
#    'cream cheese',
#    'egg',
#    'lemon zest',
#    'lime zest',
#    'orange-flavored liqueur',
#    'pecans',
#    'pitted dates',
#    'powdered sugar',
#    'salt',
#    'shortening',
#    'tequila',
#    'triple sec',
#    'warm water'}],
#  ['69190',
#   {'bouillon cubes',
#    'butter',
#    'carrot',
#    'celery',
#    'cream of celery soup',
#    'cream of chicken soup',
#    'milk',
#    'onion',
#    'potato',
#    'potato flakes',
#    'water'}],
#  ['503475',
#   {'apples',
#    'butter',
#    'cinnamon',
#    'cream',
#    'eggs',
#    'flour',
#    'lemon, juice of',
#    'milk',
#    'salt',
#    'sugar'}],
#  ['522861',
#   {'butter',
#    'cheese',
#    'fresh coarse ground black pepper',
#    'garlic',
#    'macaroni',
#    'milk',
#    'onion',
#    'salt'}],
#  ['457136',
#   {'black pepper',
#    'cheese',
#    'fine semolina',
#    'heavy cream',
#    'macaroni',
#    'muscat wine',
#    'onion',
#    'potato',
#    'salt water',
#    'unsalted butter'}],
#  ['455351',
#   {'applesauce',
#    'butter',
#    'cheese',
#    'milk',
#    'onion',
#    'penne pasta',
#    'potato',
#    'salt and pepper'}],
#  ['333797', {'dried yellow peas', 'ginger', 'pork', 'salt', 'water'}],
#  ['428056',
#   {'brown mustard',
#    'carrot',
#    'clove',
#    'dried thyme',
#    'dried yellow peas',
#    'ground ginger',
#    'ham bone',
#    'onion',
#    'pepper',
#    'salt',
#    'water'}],
#  ['306245', {'butter', 'fresh spinach', 'nutmeg', 'water'}],
#  ['523359',
#   {'chili powder',
#    'cornstarch',
#    'dried onion flakes',
#    'garlic powder',
#    'granulated sugar',
#    'ground beef',
#    'ground black pepper',
#    'ground pork',
#    'paprika',
#    'salt',
#    'tomato paste',
#    'water',
#    'white vinegar',
#    'wondra flour'}],
#  ['495314',
#   {'apple cider vinegar',
#    'applesauce',
#    'cayenne',
#    'dark brown sugar',
#    'granulated garlic',
#    'liquid smoke',
#    'maple syrup',
#    'oregano',
#    'ponzu sauce',
#    'salt',
#    'tomato ketchup'}],
#  ['149593',
#   {'baking powder',
#    'baking soda',
#    'butter',
#    'egg',
#    'flour',
#    'salt',
#    'sour cream',
#    'sugar',
#    'vanilla'}],
#  ['227924',
#   {'butter', 'frozen whipped topping', 'oreo cookies', 'vanilla ice cream'}],
#  ['100540', {'butter', 'processed cheese', 'white bread'}],
#  ['155959',
#   {'balsamic vinegar',
#    'fresh ground black pepper',
#    'garlic',
#    'london broil beef',
#    'olive oil',
#    'rosemary',
#    'soy sauce',
#    'worcestershire sauce'}],
#  ['29214',
#   {'chicken broth',
#    'cornstarch',
#    'dried oregano',
#    'dried rosemary',
#    'dried thyme',
#    'dry sherry',
#    'fresh mushrooms',
#    'garlic',
#    'hot pepper sauce',
#    'margarine',
#    'nonfat dry milk powder',
#    'nonfat milk',
#    'parmesan cheese',
#    'salt and black pepper',
#    'spicy brown mustard',
#    'teriyaki sauce'}],
#  ['92533',
#   {'almonds',
#    'butter',
#    'cinnamon',
#    'cream cheese',
#    'eggs',
#    'nutmeg',
#    'sour cream',
#    'splenda sugar substitute',
#    'vanilla',
#    'vanilla protein powder'}],
#  ['209203',
#   {'bacon', 'butter', 'real maple syrup', 'refrigerated buttermilk biscuits'}],
#  ['42151',
#   {'horseradish',
#    'mayonnaise',
#    'tabasco sauce',
#    'velveeta cheese',
#    'worcestershire sauce'}],
#  ['327356', {'lemon juice', 'red wine vinegar', 'water'}],
#  ['325509',
#   {'berries',
#    'ground flax seeds',
#    "i can't believe it's not butter spread",
#    'old fashioned oats',
#    'sugar-free syrup',
#    'water'}],
#  ['236184',
#   {'blueberries',
#    'cream cheese',
#    'eggs',
#    'flour',
#    'french bread',
#    'frozen blueberries',
#    'maple syrup',
#    'milk',
#    'nuts',
#    'powdered sugar',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['241445',
#   {'bacon',
#    'celery',
#    'cheddar cheese',
#    'chicken broth',
#    'chives',
#    'liquid smoke',
#    'onion',
#    'red potatoes',
#    'salt',
#    'sour cream',
#    'velveeta cheese',
#    'white pepper'}],
#  ['149887',
#   {'active dry yeast',
#    'brown sugar',
#    'butter',
#    'cinnamon',
#    'cream cheese',
#    'egg',
#    'flour',
#    'granulated sugar',
#    'milk',
#    'powdered sugar',
#    'salt',
#    'vanilla pudding mix',
#    'warm water'}],
#  ['112984',
#   {'asparagus',
#    'garlic',
#    'italian seasoning',
#    'part-skim mozzarella cheese',
#    'red bell pepper',
#    'reduced-fat parmesan cheese',
#    'salt and pepper',
#    'spaghetti sauce',
#    'spaghetti squash',
#    'white mushroom'}],
#  ['200148',
#   {'coriander',
#    'cornstarch',
#    'frozen pineapple concentrate',
#    'graham cracker crumbs',
#    'lemon juice',
#    'maple syrup',
#    'margarine',
#    'oil',
#    'soft silken tofu',
#    'vanilla',
#    'vegan cream cheese',
#    'vegan sugar',
#    'water'}],
#  ['445026',
#   {'all-purpose flour',
#    'andouille sausage',
#    'celery',
#    'cooked chicken',
#    'creole seasoning',
#    'frozen black-eyed peas',
#    'garlic',
#    'green bell pepper',
#    'large raw shrimp',
#    'low sodium chicken broth',
#    'onion',
#    'vegetable oil'}],
#  ['70611',
#   {'cheddar cheese',
#    'cracker',
#    'eggs',
#    'ground beef',
#    'onion',
#    'pickle',
#    'salt and pepper',
#    'thousand island dressing'}],
#  ['273326',
#   {'basil',
#    'butter',
#    'cajun spices',
#    'garlic',
#    'heavy whipping cream',
#    'lemon juice',
#    'linguine',
#    'parmesan cheese',
#    'parmesan-romano cheese mix',
#    'parsley',
#    'salmon',
#    'salt',
#    'white pepper'}],
#  ['310570', {'cottage cheese', 'eggs', 'feta', 'milk', 'oil', 'phyllo dough'}],
#  ['318677',
#   {'avocado',
#    'cucumber',
#    'imitation crabmeat',
#    'lettuce',
#    'pickled ginger',
#    'seasoned rice vinegar',
#    'soy sauce',
#    'white rice'}],
#  ['80050',
#   {'baking soda',
#    'eggs',
#    'flour',
#    'maraschino cherry',
#    'mincemeat',
#    'mixed candied fruit',
#    'sweetened condensed milk',
#    'walnuts'}],
#  ['269984',
#   {'baby carrots',
#    'baking powder',
#    'celery',
#    'chicken breasts',
#    'chicken stock',
#    'eggs',
#    'kosher salt',
#    'matzo meal',
#    'oil',
#    'pepper',
#    'salt',
#    'sugar',
#    'white onion'}],
#  ['317508',
#   {'cheddar cheese',
#    'cream of mushroom soup',
#    'frozen southern style hash brown potatoes',
#    'poppy seed',
#    'sour cream'}],
#  ['53872',
#   {'adobo seasoning',
#    'eggs',
#    'fresh garlic cloves',
#    'fresh ground pepper',
#    'ground coriander',
#    'ground sage',
#    'italian seasoned breadcrumbs',
#    'ketchup',
#    'lean ground beef',
#    'low sodium soy sauce',
#    'olive oil',
#    'oregano',
#    'red onion',
#    'sea salt',
#    'veggie shreds cheese'}],
#  ['268942',
#   {'butter',
#    'celery',
#    'cream of celery soup',
#    'green bell pepper',
#    'kraft macaroni and cheese',
#    'mushrooms',
#    'onion',
#    'tuna'}],
#  ['176110',
#   {'cider vinegar',
#    'dry mustard',
#    'garlic',
#    'ketchup',
#    'miracle whip',
#    'paprika',
#    'pepper',
#    'salt',
#    'sugar',
#    'tabasco sauce',
#    'vegetable oil'}],
#  ['205331',
#   {'extra virgin olive oil',
#    'italian parsley',
#    'kalamata olive',
#    'kosher salt & freshly ground black pepper',
#    'lemon, juice of',
#    'oregano',
#    'pepperoncini peppers',
#    'red bell pepper',
#    'red onion',
#    'red ripe tomatoes',
#    'red wine vinegar',
#    'seedless cucumber',
#    'shallot',
#    'tuna in vegetable oil',
#    'water-packed artichoke hearts'}],
#  ['165856',
#   {'buttermilk',
#    'canola oil',
#    'egg',
#    'ground black pepper',
#    'orange roughy',
#    'seasoning salt',
#    'self-rising flour'}],
#  ['474769',
#   {'all-purpose flour',
#    'bacon',
#    'egg yolk',
#    'eggs',
#    'frozen spinach',
#    'garlic',
#    'goat cheese',
#    'green onion',
#    'salt',
#    'simply potatoes traditional mashed potatoes'}],
#  ['138005',
#   {'boneless pork chops',
#    'cajun seasoning',
#    'canola oil',
#    'egg',
#    'flour',
#    'ground black pepper',
#    'milk',
#    'salt and pepper',
#    'seasoning salt',
#    'self-rising flour'}],
#  ['216945',
#   {'imitation crabmeat',
#    'ramen noodles',
#    'stir fry vegetables',
#    'teriyaki marinade',
#    'water'}],
#  ['164526',
#   {'apple',
#    'banana',
#    'celery',
#    'fresh cilantro leaves',
#    'green bell pepper',
#    'ground red pepper',
#    'pesto sauce',
#    'pumpkin puree',
#    'pumpkin seeds',
#    'red onion',
#    'salt',
#    'small red potato',
#    'smooth cashew butter',
#    'vegetable broth'}],
#  ['50184',
#   {'chili powder',
#    'dry-roasted cashews',
#    'garlic',
#    'margarine',
#    'mushrooms',
#    'nutmeg',
#    'parsley',
#    'vegetable bouillon cubes',
#    'water'}],
#  ['316470',
#   {'ice cubes', 'mangoes', 'oranges', 'strawberries', 'vanilla bean'}],
#  ['343338',
#   {'fresh rosemary',
#    'garlic',
#    'leeks',
#    'olive oil',
#    'russet potatoes',
#    'salt and pepper',
#    'vegetable broth',
#    'white beans'}],
#  ['137434',
#   {'black peppercorns',
#    'boneless skinless chicken breasts',
#    'cardamom pods',
#    'chicken stock',
#    'chili powder',
#    'cinnamon stick',
#    'cloves',
#    'coriander seed',
#    'fresh coriander',
#    'fresh ginger',
#    'garlic',
#    'ground cumin',
#    'onion',
#    'salt & freshly ground black pepper',
#    'soy yogurt',
#    'turmeric'}],
#  ['95534',
#   {'beef bouillon cubes',
#    'black pepper',
#    'boiling water',
#    'dried oregano',
#    'dried thyme',
#    'garlic',
#    'garlic powder',
#    'rump roast',
#    'salt',
#    'tabasco sauce',
#    'worcestershire sauce'}],
#  ['30473', {'ginger', 'honey', 'milk', 'tea bag', 'water'}],
#  ['24470', {'ground beef', 'sausage', 'taco chips', 'velveeta cheese'}],
#  ['311991',
#   {'bell pepper',
#    'brown sugar',
#    'garlic powder',
#    'ground mustard',
#    'hamburger buns',
#    'ketchup',
#    'lean ground beef',
#    'onion',
#    'steak seasoning',
#    'tomato sauce',
#    'white vinegar',
#    'worcestershire sauce'}],
#  ['225707',
#   {'beets',
#    'carrot',
#    'fresh corn kernels',
#    'garlic',
#    'gingerroot',
#    'green onions',
#    'green peppers',
#    'honey',
#    'pepper',
#    'rice wine vinegar',
#    'safflower oil',
#    'salad greens',
#    'salad seasoning',
#    'salt',
#    'soy sauce',
#    'white mushrooms'}],
#  ['242830',
#   {'chicken broth',
#    'dry white wine',
#    'fennel seeds',
#    'fresh lemon juice',
#    'olive oil',
#    'onion',
#    'paprika',
#    'pork chops'}],
#  ['336744',
#   {'black olives',
#    'eggs',
#    'garlic powder',
#    'italian seasoning',
#    'mozzarella cheese',
#    'pepperoni',
#    'ramen noodles',
#    'red bell pepper',
#    'roma tomato'}],
#  ['83542',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'eggs',
#    'flour',
#    'milk',
#    'molasses',
#    'natural bran',
#    'oil',
#    'raisins',
#    'salt',
#    'sesame seeds',
#    'sunflower seeds'}],
#  ['91626',
#   {'black tea leaves',
#    'broiler',
#    'brown sugar',
#    'dry sherry',
#    'garlic',
#    'low sodium soy sauce',
#    'minced ginger',
#    'onion',
#    'orange zest',
#    'orange, juice of',
#    'peppercorn'}],
#  ['303457',
#   {'cardamom pods',
#    'cloves',
#    'coriander seed',
#    'fruit vinegar',
#    'gingerroot',
#    'kaffir lime leaves',
#    'lemongrass',
#    'peanut oil',
#    'star anise',
#    'turmeric',
#    'yoghurt'}],
#  ['176717',
#   {'blueberry pie filling',
#    'cool whip',
#    'graham wafers',
#    'vanilla pudding mix'}],
#  ['39226',
#   {'canned jalapeno slices',
#    'cayenne pepper',
#    'chili powder',
#    'cornstarch',
#    'dried onion flakes',
#    'garlic powder',
#    'onion powder',
#    'salt',
#    'sugar',
#    'tomato paste',
#    'vinegar',
#    'water'}],
#  ['216030',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'butter',
#    'cake flour',
#    'corn flakes',
#    'eggs',
#    'nuts',
#    'quick-cooking oats',
#    'raisins',
#    'salt',
#    'shredded coconut',
#    'vanilla'}],
#  ['268169',
#   {'butter',
#    'italian spices',
#    'kosher salt',
#    'olive oil',
#    'onion',
#    'pepper',
#    'whole turkey'}],
#  ['98357',
#   {'cheddar cheese',
#    'chili with beans',
#    'corn chips',
#    'onion',
#    'salsa',
#    'sour cream'}],
#  ['150365',
#   {'cauliflower florets',
#    'egg',
#    'parsley sprig',
#    'pepper',
#    'plain breadcrumbs',
#    'salt',
#    'vegetable oil'}],
#  ['243251',
#   {'butter',
#    'fresh green beans',
#    'ground black pepper',
#    'kosher salt',
#    'mixed herbs',
#    'olive oil',
#    'onion',
#    'walnuts'}],
#  ['20186',
#   {'american cheese',
#    'ham',
#    'hamburger buns',
#    'ketchup',
#    'sweet pickle relish'}],
#  ['109818', {'bacon', 'carrot', 'sugar', 'tomato soup'}],
#  ['243785',
#   {'brown sugar',
#    'eggs',
#    'ground beef',
#    'ketchup',
#    'lipton onion soup mix',
#    'seasoned bread crumbs'}],
#  ['207525',
#   {'bulk pork sausage',
#    'garlic powder',
#    'ground chuck',
#    'ground pepper',
#    'oregano',
#    'rye cocktail bread',
#    'velveeta cheese',
#    'worcestershire sauce'}],
#  ['226246',
#   {'brown sugar',
#    'butter',
#    'caster sugar',
#    'egg',
#    'glace cherries',
#    'milk',
#    'pineapple in syrup',
#    'self-raising flour',
#    'vanilla essence'}],
#  ['353044',
#   {'apple',
#    'banana',
#    'coconut milk',
#    'flax seed oil',
#    'greens',
#    'honey',
#    'oat bran',
#    'water'}],
#  ['263781',
#   {'green onion',
#    'hawaiian bread',
#    "hellmann's mayonnaise",
#    'knorr vegetable soup mix',
#    'sour cream',
#    'water chestnuts'}],
#  ['66932',
#   {'broccoli floret',
#    'brown rice',
#    'carrot',
#    'egg',
#    'olive oil',
#    'peas',
#    'sliced mushrooms',
#    'soy sauce'}],
#  ['48131',
#   {'egg whites',
#    'pumpkin',
#    'pumpkin pie spice',
#    'reduced fat graham cracker crust',
#    'skim milk',
#    'splenda sugar substitute'}],
#  ['32363', {'beef stew', 'biscuits'}],
#  ['293225',
#   {'baking soda',
#    'buttermilk',
#    'creamy peanut butter',
#    'espresso',
#    'extra-large eggs',
#    'heavy cream',
#    'honey roasted peanuts',
#    'light corn syrup',
#    'powdered sugar',
#    'pure vanilla extract',
#    'salt',
#    'semisweet chocolate',
#    'sugar',
#    'unbleached all-purpose flour',
#    'unsalted butter',
#    'unsweetened cocoa'}],
#  ['235173',
#   {'chipotle chile in adobo',
#    'cilantro',
#    'corn kernel',
#    'fresh lime juice',
#    'garlic',
#    'ground cumin',
#    'lime zest',
#    'olive oil',
#    'onion',
#    'red bell pepper',
#    'short-grain brown rice',
#    'yellow cornmeal'}],
#  ['226001',
#   {'all-purpose flour',
#    'butter',
#    'eggs',
#    'instant vanilla pudding',
#    'water',
#    'whipped dessert topping mix'}],
#  ['220186',
#   {'celery',
#    'dijon mustard',
#    'fresh ground pepper',
#    'hard-boiled eggs',
#    'milk',
#    'miracle whip',
#    'mustard',
#    'potato',
#    'salt',
#    'sugar',
#    'white onions',
#    'white pepper'}],
#  ['217201',
#   {'black pepper',
#    'butter',
#    'cayenne pepper',
#    'chili powder',
#    'dried basil',
#    'garlic powder',
#    'lemon juice',
#    'seasoning salt',
#    'soy sauce',
#    'tea bag',
#    'water',
#    'white rice'}],
#  ['194665',
#   {'bisquick',
#    'eggs',
#    'feta cheese',
#    'fresh ground pepper',
#    'frozen spinach',
#    'kalamata olive',
#    'milk',
#    'onion',
#    'oregano',
#    'roasted red pepper'}],
#  ['269909',
#   {'all-purpose flour',
#    'allspice',
#    'baking powder',
#    'baking soda',
#    'cinnamon',
#    'eggs',
#    'ground cloves',
#    'nutmeg',
#    'oil',
#    'pecans',
#    'pumpkin',
#    'salt',
#    'sugar',
#    'water'}],
#  ['259693',
#   {'black pepper',
#    'boneless pork chops',
#    'dry onion soup mix',
#    'long-grain rice',
#    'vegetable oil',
#    'water'}],
#  ['161370',
#   {'allspice',
#    'boneless skinless chicken breasts',
#    'brown sugar',
#    'cayenne',
#    'chili powder',
#    'chives',
#    'cinnamon',
#    'clove',
#    'crushed tomatoes',
#    'garlic',
#    'ginger',
#    'habanero pepper',
#    'jamaican jerk spice',
#    'lime juice',
#    'nutmeg',
#    'olive oil',
#    'onion',
#    'onion flakes',
#    'pepper',
#    'red peppers',
#    'rum',
#    'sage',
#    'thyme'}],
#  ['152261',
#   {'frozen limeade concentrate', 'ice', 'lime sorbet', 'mango', 'strawberry'}],
#  ['152259',
#   {'apple juice',
#    'banana',
#    'ice',
#    'non-fat vanilla frozen yogurt',
#    'strawberry'}],
#  ['303460',
#   {'coriander seed',
#    'cumin',
#    'fish sauce',
#    'fruit vinegar',
#    'garlic',
#    'hoisin sauce',
#    'red chile',
#    'sesame oil',
#    'yoghurt'}],
#  ['270259',
#   {'all-purpose flour',
#    'butter',
#    'candy cane',
#    'eggs',
#    'peppermint extract',
#    'peppermint oreos',
#    'salt',
#    'sugar',
#    'unsweetened chocolate',
#    'unsweetened cocoa powder',
#    'vanilla'}],
#  ['345123',
#   {'canola oil',
#    'celery',
#    'cooked chicken breasts',
#    'cooked rice',
#    'green grapes',
#    'mandarin oranges',
#    'mayonnaise',
#    'orange juice',
#    'pineapple tidbits',
#    'salt',
#    'slivered almonds',
#    'white vinegar'}],
#  ['125195',
#   {'celery',
#    'cheddar cheese',
#    'frozen peas',
#    'hard-boiled eggs',
#    'mayonnaise',
#    'mustard',
#    'onion',
#    'seasoning salt',
#    'sugar',
#    'sweet pickle relish'}],
#  ['141939',
#   {'all-purpose flour',
#    'black pepper',
#    'butter',
#    'buttermilk',
#    'cayenne pepper',
#    'chicken pieces',
#    'dijon mustard',
#    'dried thyme',
#    'dry breadcrumbs',
#    'fresh garlic',
#    'garlic powder',
#    'hot pepper sauce',
#    'oil',
#    'onion',
#    'paprika',
#    'parmesan cheese',
#    'seasoning salt'}],
#  ['171442',
#   {'allspice',
#    'cinnamon',
#    'fresh garlic',
#    'habanero sauce',
#    'hoisin sauce',
#    'ketchup',
#    'lemon juice',
#    'louisiana hot sauce',
#    'pepper',
#    'pork baby back ribs',
#    'seasoning salt',
#    'sugar'}],
#  ['212188',
#   {'beef stock',
#    'carrot',
#    'celery',
#    'chicken leg',
#    'corn',
#    'garlic',
#    'italian seasoning',
#    'onion',
#    'peas',
#    'pepper',
#    'red bell pepper',
#    'rotini pasta',
#    'salt',
#    'spaghetti sauce'}],
#  ['262208',
#   {'aluminum foil',
#    'margarine',
#    'mexicorn whole kernel corn',
#    'pam cooking spray',
#    'salt and pepper',
#    'sour cream',
#    'spinach dip',
#    'stove top stuffing mix monterey style with mushroom and onion'}],
#  ['207857', {'cooking onions', 'pickling spices', 'white vinegar'}],
#  ['221049',
#   {'carrot',
#    'chicken broth',
#    'cooked chicken',
#    'cooked pasta',
#    'egg',
#    'peas',
#    'soy sauce'}],
#  ['221116', {'cake crumbs', 'cool whip', 'cream cheese', 'mixed fruit'}],
#  ['130819',
#   {'butter',
#    'coconut flavoring',
#    'cool whip',
#    'eggs',
#    'flour',
#    'lemon flavoring',
#    'pie crust',
#    'squash',
#    'sugar'}],
#  ['20223',
#   {'black pepper',
#    'cream of mushroom soup',
#    'dijon mustard',
#    'dried onion flakes',
#    'dried parsley flakes',
#    'garlic powder',
#    'ground cinnamon',
#    'ground cloves',
#    'ground veal',
#    'salt'}],
#  ['190108',
#   {'black pepper',
#    'brown rice',
#    'catfish nuggets',
#    'chicken stock',
#    'garlic',
#    'gumbo file',
#    'lemon',
#    'mexican-style stewed tomatoes with jalapeno peppers',
#    'okra',
#    'old bay seasoning',
#    'olive oil',
#    'oregano',
#    'parsley',
#    'red onions',
#    'red wine vinegar',
#    'seafood',
#    'small shrimp',
#    'tabasco sauce',
#    'tomato soup'}],
#  ['158372',
#   {'bacon',
#    'eggs',
#    'fresh chives',
#    'mild cheddar cheese',
#    'paprika',
#    'sour cream',
#    'white vinegar'}],
#  ['219681',
#   {'chicken breasts',
#    'cracked black pepper',
#    'dried basil',
#    'dried oregano',
#    'dried parsley',
#    'garlic',
#    'garlic salt',
#    'lemon juice',
#    'olive oil',
#    'salt',
#    'sandwich buns',
#    'white vinegar'}],
#  ['261215',
#   {'baking soda',
#    'boiling water',
#    'brown sugar',
#    'cinnamon',
#    'cream',
#    'eggs',
#    'flour',
#    'margarine',
#    'nutmeg',
#    'nuts',
#    'quick oats',
#    'salt',
#    'shredded coconut',
#    'vanilla'}],
#  ['179640', {'butter', 'marshmallows', 'rice krispies'}],
#  ['250883',
#   {'cool whip topping',
#    'cream cheese',
#    'frozen limeade concentrate',
#    'orange juice'}],
#  ['140855',
#   {'avocado',
#    'cheddar cheese',
#    'chili powder',
#    'corn chips',
#    'garlic',
#    'green onion',
#    'lemon juice',
#    'lettuce',
#    'pitted ripe olives',
#    'salad oil',
#    'salt',
#    'sour cream',
#    'sugar',
#    'tabasco sauce',
#    'tomato',
#    'tuna'}],
#  ['120297',
#   {'baking potatoes',
#    'chickpeas',
#    'coriander',
#    'fresh coriander',
#    'garlic',
#    'ground cumin',
#    'low-fat yogurt',
#    'olive oil',
#    'salt & freshly ground black pepper',
#    'tahini'}],
#  ['130492',
#   {'baking powder',
#    'buttermilk',
#    'eggs',
#    'mayonnaise',
#    'salt',
#    'sugar',
#    'vegetable oil',
#    'yellow cornmeal'}],
#  ['164634',
#   {'apple',
#    'carrot',
#    'gingerroot',
#    'green cabbage',
#    'green onion',
#    'maple syrup',
#    'red cabbage',
#    'rice vinegar',
#    'sesame oil',
#    'soy sauce'}],
#  ['293836',
#   {'black pepper',
#    'canola oil',
#    'chicken soup powder',
#    'garlic powder',
#    'long-grain rice',
#    'orzo pasta',
#    'turmeric',
#    'water'}],
#  ['169586',
#   {'avocado',
#    'celery ribs',
#    'chicken breast',
#    'chicken broth',
#    'chipotle chiles in adobo',
#    'crushed tomatoes',
#    'cumin',
#    'ear of corn',
#    'fresh cilantro',
#    'green bell pepper',
#    'jalapeno pepper',
#    'salt and pepper',
#    'white onion'}],
#  ['261296',
#   {'dried basil',
#    'egg white',
#    'eggplant',
#    'fat free mozzarella cheese',
#    'fiber one cereal',
#    'garlic powder',
#    'italian-style tomato sauce',
#    'pepper',
#    'reduced-fat parmesan cheese',
#    'salt'}],
#  ['101115', {'beef gravy', 'eggs', 'ground beef', 'onion', 'white rice'}],
#  ['271594',
#   {'beans',
#    'black-eyed peas',
#    'carrot',
#    'celery ribs',
#    'garlic',
#    'great northern beans',
#    'ham',
#    'ham bone',
#    'ham soup base',
#    'navy beans',
#    'onion',
#    'pepper',
#    'pinto beans',
#    'salt',
#    'tomatoes and green chilies',
#    'water'}],
#  ['164291',
#   {'cider vinegar',
#    'feta cheese',
#    'fresh dill',
#    'garlic',
#    'light mayonnaise',
#    'red bell pepper',
#    'skinless chicken breast half'}],
#  ['251528',
#   {'cheese ravioli',
#    'garlic salt',
#    'italian seasoning',
#    'lean ground beef',
#    'mozzarella cheese',
#    'spaghetti sauce'}],
#  ['250833',
#   {'barbecue sauce',
#    'chicken pieces',
#    'lemon juice',
#    'orange marmalade',
#    'worcestershire sauce'}],
#  ['343448',
#   {'coriander',
#    'garlic powder',
#    'ground black pepper',
#    'ground red pepper',
#    'onion powder',
#    'paprika',
#    'salt',
#    'turmeric'}],
#  ['39893',
#   {'black olives',
#    'cream cheese',
#    'green onion',
#    'green pepper',
#    'lettuce',
#    'mayonnaise',
#    'mexican blend cheese',
#    'sour cream',
#    'taco seasoning mix',
#    'tomato'}],
#  ['147477',
#   {'green bell peppers',
#    'green onions',
#    'minced clams',
#    'paprika',
#    'sharp cheddar cheese',
#    'tabasco sauce',
#    'worcestershire sauce'}],
#  ['223349',
#   {'eggplants',
#    'olive oil',
#    'olives',
#    'oregano',
#    'red bell pepper',
#    'red onion',
#    'shrimp',
#    'spaghetti squash',
#    'yellow bell pepper'}],
#  ['86768',
#   {'butter', "confectioners' sugar", 'heavy cream', 'semisweet chocolate'}],
#  ['197001',
#   {'cherry pie filling',
#    'crushed pineapple',
#    'frozen whipped topping',
#    'pecans',
#    'small marshmallow',
#    'sweetened condensed milk'}],
#  ['60938',
#   {'bacon',
#    'cheddar cheese',
#    'green onions',
#    'oil',
#    'potato',
#    'salt',
#    'sour cream'}],
#  ['228491',
#   {'boneless eye of round beef steak',
#    'canola oil',
#    'mozzarella cheese',
#    'onion',
#    'parmesan cheese',
#    'pepper',
#    'pizza sauce',
#    'plain flour',
#    'salt'}],
#  ['451515',
#   {'all-purpose flour',
#    'bacon grease',
#    'boneless country-style ribs',
#    "campbell's golden mushroom soup",
#    'ground black pepper',
#    'oregano',
#    'seasoning salt',
#    'soup mix'}],
#  ['353171', {'butter', 'eggs', 'flour', 'fruit', 'milk', 'sugar'}],
#  ['354039',
#   {'apples',
#    'baby carrots',
#    'butter',
#    'cardamom',
#    'crescent roll dough',
#    'ground cinnamon',
#    'honey',
#    'sugar'}],
#  ['302399',
#   {'garlic salt',
#    'italian seasoning',
#    'mozzarella cheese',
#    'olive oil',
#    'refrigerated biscuits'}],
#  ['195736',
#   {'active dry yeast', 'butter', 'flour', 'milk', 'salt', 'sugar', 'water'}],
#  ['365946',
#   {'all-purpose flour',
#    'butter',
#    'cream cheese',
#    'egg yolk',
#    'egg yolks',
#    'eggs',
#    'lemon peel',
#    'salt',
#    'sugar',
#    'vanilla',
#    'whipping cream'}],
#  ['221544',
#   {'chili sauce',
#    'country-style dijon mustard',
#    'honey',
#    'little smokies sausages'}],
#  ['175306',
#   {'bacardi dark rum',
#    'grenadine',
#    "meyer's dark rum",
#    'orange curacao',
#    'orange juice',
#    'orgeat syrup',
#    'pineapple juice',
#    'prepared sweet-and-sour mix',
#    'white rum'}],
#  ['211833',
#   {'balsamic vinaigrette',
#    'condensed chicken broth',
#    'dried thyme leaves',
#    'minute white rice',
#    'onion',
#    'pork chops',
#    'red apples',
#    'sliced mushrooms',
#    'water'}],
#  ['276567',
#   {'chili powder',
#    'fresh ground black pepper',
# ...
#    'baking soda',
#    'bananas',
#    'butter',
#    'egg',
#    'nuts',
#    'sugar',
#    'vanilla'}],
#  ['79425',
#   {'butter',
#    'caramels',
#    'chocolate cake mix',
#    'chocolate chips',
#    'evaporated milk',
#    'nuts'}],
#  ['213681',
#   {'baking soda',
#    'bananas',
#    'canola oil',
#    'egg',
#    'flour',
#    'raisins',
#    'salt',
#    'sugar',
#    'walnuts'}],
#  ['121712', {'cream cheese', 'thousand island dressing'}],
#  ['155344',
#   {'chili sauce', 'mayonnaise', 'onion powder', 'sweet pickle relish'}],
#  ['175339',
#   {'baking soda',
#    'brown sugar',
#    'chocolate chips',
#    'cream of tartar',
#    'egg',
#    'flaked coconut',
#    'flour',
#    'margarine',
#    'oil',
#    'rice krispies',
#    'rolled oats',
#    'vanilla',
#    'white sugar'}],
#  ['72600',
#   {'baby spinach',
#    'bacon',
#    'buttermilk',
#    'fresh lemon juice',
#    'garlic',
#    'hardboiled egg',
#    'mushrooms',
#    'plain yogurt',
#    'sugar',
#    'unsalted sunflower seeds',
#    'white pepper'}],
#  ['50614',
#   {'bacon',
#    'cauliflower',
#    'cherry tomatoes',
#    'fresh broccoli',
#    'fresh mushrooms',
#    'frozen peas',
#    'green pepper',
#    'italian seasoning',
#    'lettuce',
#    'mayonnaise',
#    'red onion',
#    'sugar'}],
#  ['133784',
#   {'basil leaves',
#    'black pepper',
#    'celery salt',
#    'chili powder',
#    'garlic powder',
#    'ground allspice',
#    'ground oregano',
#    'marjoram leaves',
#    'onion salt',
#    'paprika',
#    'rubbed sage'}],
#  ['235003', {'beer', 'fresh jalapeno', 'ice', 'vodka'}],
#  ['140723',
#   {'anchovy fillets',
#    'baby spinach',
#    'bacon',
#    'dijon mustard',
#    'extra virgin olive oil',
#    'french bread',
#    'fresh mushrooms',
#    'garlic',
#    'lemon juice',
#    'low-fat mayonnaise',
#    'miracle whip light',
#    'oil',
#    'olive oil',
#    'parmesan cheese',
#    'worcestershire sauce'}],
#  ['326839',
#   {'dried italian seasoning',
#    'eggs',
#    'ground beef',
#    'ground pepper',
#    'italian cheese blend',
#    'jumbo pasta shells',
#    'mexican blend cheese',
#    'mozzarella cheese',
#    'parmesan-romano cheese mix',
#    'parsley flakes',
#    'ricotta cheese',
#    'salt',
#    'spaghetti sauce'}],
#  ['467326',
#   {'bread machine yeast',
#    'brown sugar',
#    'oil',
#    'salt',
#    'water',
#    'white flour',
#    'whole wheat flour'}],
#  ['43669',
#   {'butter',
#    'cream-style corn',
#    'evaporated milk',
#    'onion',
#    'potato',
#    'salt and pepper',
#    'water',
#    'whole corn'}],
#  ['73566',
#   {'black pepper',
#    'extra virgin olive oil',
#    'flat leaf parsley',
#    'italian seasoned breadcrumbs',
#    'kosher salt',
#    'orecchiette',
#    'parmesan cheese',
#    'prosciutto'}],
#  ['449768',
#   {'cumin seeds', 'fresh ground black pepper', 'olive oil', 'salt', 'tomato'}],
#  ['404661',
#   {'baking soda',
#    'butter',
#    'corn syrup',
#    'molasses',
#    'salted peanuts',
#    'vanilla',
#    'white sugar'}],
#  ['381713',
#   {'bulgar wheat',
#    'cinnamon',
#    'lean ground beef',
#    'onion',
#    'plain yogurt',
#    'salt'}],
#  ['257696',
#   {'apple pie filling',
#    'egg',
#    'instant vanilla pudding',
#    'oil',
#    'water',
#    'yellow cake mix'}],
#  ['187606',
#   {'boneless skinless chicken breasts',
#    'carrot',
#    'italian dressing',
#    'potato'}],
#  ['91515', {'chocolate milk', 'cinnamon rolls', 'eggs'}],
#  ['289891',
#   {'baking powder',
#    'butter',
#    'eggs',
#    'flour',
#    'milk',
#    'salt',
#    'vanilla',
#    'white sugar'}],
#  ['412073',
#   {'basil',
#    'carrot',
#    'celery',
#    'garlic',
#    'ham',
#    'leeks',
#    'pepper',
#    'salt',
#    'soup mix',
#    'thyme',
#    'water',
#    'worcestershire sauce'}],
#  ['123746',
#   {'bell peppers',
#    'chili sauce',
#    'egg',
#    'garlic powder',
#    'ground beef',
#    'milk',
#    'onion',
#    'salt and pepper',
#    'saltine crackers',
#    'worcestershire sauce'}],
#  ['206020',
#   {'aluminum foil',
#    'beef tenderloin',
#    'garlic',
#    'limes, juice of',
#    'prepared horseradish',
#    'salt and pepper',
#    'sour cream',
#    'unsalted butter',
#    'worcestershire sauce'}],
#  ['345595',
#   {'baking powder',
#    'baking soda',
#    'carrot',
#    'cinnamon',
#    'cream cheese',
#    'eggs',
#    'flour',
#    'margarine',
#    'oil',
#    'pineapple',
#    'powdered sugar',
#    'salt',
#    'sugar',
#    'walnuts'}],
#  ['129227',
#   {'cabbage',
#    'carrot',
#    'celery seed',
#    'mustard seeds',
#    'onion',
#    'salt',
#    'sugar',
#    'turmeric',
#    'water',
#    'white vinegar'}],
#  ['472955',
#   {'alum',
#    'pickling cucumbers',
#    'pickling spices',
#    'salt',
#    'sugar',
#    'vinegar',
#    'water'}],
#  ['17490',
#   {'alum',
#    'canning salt',
#    'cucumbers',
#    'pickling spices',
#    'sugar',
#    'vinegar'}],
#  ['130002',
#   {'allspice',
#    'baking soda',
#    'carrot',
#    'cinnamon',
#    'coconut',
#    'cream cheese',
#    'eggs',
#    'flour',
#    'ground cloves',
#    'margarine',
#    'nuts',
#    'oil',
#    'powdered sugar',
#    'raisins',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['53353', {'butter', 'cream', 'lemon extract', 'maple syrup', 'nutmeats'}],
#  ['105756',
#   {'basil',
#    'beans',
#    'carrot',
#    'celery',
#    'chicken bouillon cubes',
#    'chicken broth',
#    'deli ham',
#    'lemon juice',
#    'onion',
#    'parsley',
#    'raw rice',
#    'salt',
#    'tomato',
#    'v8 vegetable juice',
#    'water'}],
#  ['307362',
#   {'hormel chili without beans',
#    'monterey jack cheese',
#    'refried beans',
#    'tortillas'}],
#  ['51803',
#   {'15 bean soup mix',
#    'black pepper',
#    'celery leaves',
#    'chicken bouillon cubes',
#    'dried parsley',
#    'dried rosemary',
#    'garlic',
#    'ham hocks',
#    'olive oil',
#    'onion',
#    'salt',
#    'whole tomatoes'}],
#  ['438263',
#   {'15 bean soup mix',
#    'beef bouillon paste',
#    'black pepper',
#    'diced tomatoes',
#    'garlic',
#    'ham bone',
#    'smoked sausage',
#    'steak sauce',
#    'water',
#    'worcestershire sauce'}],
#  ['525649',
#   {'black pepper',
#    'carrot',
#    'cayenne pepper',
#    'chili powder',
#    'condensed tomato soup',
#    'dried beans',
#    'garlic',
#    'ham',
#    'lemon',
#    'olive oil',
#    'onion',
#    'oregano',
#    'paprika',
#    'salt',
#    'smoked paprika',
#    'thyme',
#    'water'}],
#  ['115160',
#   {'baking soda',
#    'eggs',
#    'flour',
#    'ground walnuts',
#    'honey',
#    'liquid honey',
#    'margarine',
#    'plain sweet biscuit crumbs',
#    'sour cream',
#    'sugar'}],
#  ['168222',
#   {'capers',
#    'chicken stock',
#    'fresh chives',
#    'fresh parsley',
#    'fresh tarragon',
#    'garlic',
#    'halibut steaks',
#    'lemon juice',
#    'salt and pepper'}],
#  ['140172',
#   {'boneless sirloin steak',
#    'lipton beefy mushroom soup mix',
#    'new potatoes',
#    'oil',
#    'peas and carrots',
#    'tomato paste',
#    'water'}],
#  ['305112',
#   {'black beans',
#    'frozen corn kernels',
#    'ground beef',
#    'taco seasoning',
#    'tomatoes and green chilies'}],
#  ['53481',
#   {'cheddar cheese',
#    'ketchup',
#    'lean ground beef',
#    'minute white rice',
#    'mustard',
#    'water'}],
#  ['76887',
#   {'chili with beans',
#    'diced tomatoes',
#    'ground beef',
#    'velveeta cheese',
#    'water',
#    'white rice'}],
#  ['392598',
#   {'boneless skinless chicken breast halves',
#    'condensed cream of chicken soup',
#    'ground pepper',
#    'instant rice',
#    'paprika',
#    'vegetable oil',
#    'water'}],
#  ['113197',
#   {'cheese',
#    'chicken breast tenders',
#    'fajita seasoning mix',
#    'lime',
#    'olive oil',
#    'onion',
#    'pepper',
#    'pico de gallo',
#    'sour cream',
#    'tortilla'}],
#  ['398071',
#   {'cheddar cheese',
#    'chicken',
#    'chicken broth',
#    'kidney beans',
#    'mexicorn',
#    'salsa',
#    'sour cream',
#    'tortilla chips'}],
#  ['66527',
#   {'boneless skinless chicken breasts',
#    'broccoli florets',
#    'condensed cream of chicken soup',
#    'milk',
#    'minute rice',
#    'vegetable oil'}],
#  ['184890',
#   {'chili powder',
#    'cumin',
#    'ground turkey',
#    'kidney beans',
#    'onion',
#    'pinto beans',
#    'salsa',
#    'salt',
#    'stewed tomatoes'}],
#  ['79046',
#   {'cheese',
#    'chili with beans',
#    'flour tortillas',
#    'sour cream',
#    'water',
#    'white minute rice'}],
#  ['356163',
#   {'broccoli',
#    'chili powder',
#    'ketchup',
#    'lean ground beef',
#    'macaroni & cheese dinner mix',
#    'water'}],
#  ['41673',
#   {'allspice',
#    'brown sugar',
#    'cinnamon',
#    'clove',
#    'onion',
#    'pepper',
#    'salt',
#    'tomato'}],
#  ['506885',
#   {'crushed red pepper flakes',
#    'fresh basil',
#    'fresh oregano',
#    'fresh parmesan cheese',
#    'garlic',
#    'grape tomatoes',
#    'pappardelle pasta',
#    'pepper',
#    'roasted cashews',
#    'sun-dried tomato packed in oil'}],
#  ['277539',
#   {'chipotle chile in adobo',
#    'garlic',
#    'ground coriander',
#    'ground cumin',
#    'low sodium chicken broth',
#    'onion',
#    'salt',
#    'tomato sauce'}],
#  ['169487',
#   {'fat free cream cheese',
#    'fat-free whipped topping',
#    'reduced fat graham cracker crust',
#    'sugar substitute'}],
#  ['317587',
#   {'fresh linguine',
#    'fresh spinach',
#    'lemon juice',
#    'parmesan cheese',
#    'pesto sauce',
#    'pine nuts',
#    'red onion',
#    'tomato'}],
#  ['20624',
#   {'boneless skinless chicken breast halves',
#    'butter',
#    'chicken broth',
#    'flour',
#    'garlic',
#    'lemon juice',
#    'oil',
#    'salt and pepper'}],
#  ['360232',
#   {'celery ribs',
#    'cracked black pepper',
#    'extra virgin olive oil',
#    'feta cheese',
#    'fresh lemon juice',
#    'fresh parsley',
#    'garbanzo beans',
#    'garlic',
#    'of fresh mint',
#    'romaine lettuce',
#    'salt',
#    'scallion',
#    'tomato'}],
#  ['246548',
#   {'assorted fresh vegetables',
#    'boneless skinless chicken breast',
#    'instant rice',
#    'italian dressing',
#    'oil',
#    'reduced-sodium fat-free chicken broth'}],
#  ['67446',
#   {'butter',
#    'cream cheese',
#    'graham cracker crumbs',
#    'instant lemon pudding',
#    'milk',
#    'powdered sugar'}],
#  ['153028',
#   {'butter', 'cocoa', "confectioners' sugar", 'peanut butter', 'vanilla'}],
#  ['172651',
#   {'italian salad dressing',
#    'parmesan cheese',
#    'smoked turkey breast',
#    'spaghetti',
#    'tomato'}],
#  ['348952',
#   {'chicken bouillon cube',
#    'frozen mixed vegetables',
#    'minute rice',
#    'oil',
#    'pork tenderloin',
#    'soy sauce',
#    'water'}],
#  ['5276',
#   {'chicken bouillon cubes',
#    'green pepper',
#    'hot pepper sauce',
#    'kidney beans',
#    'minute white rice',
#    'oil',
#    'onion',
#    'water'}],
#  ['140173',
#   {'baby peas',
#    'bacon bits',
#    'black pepper',
#    'fettuccine',
#    'garlic salt',
#    'half-and-half cream',
#    'parmesan cheese',
#    'shrimp'}],
#  ['31184',
#   {'angel hair pasta',
#    'butter',
#    'extra virgin olive oil',
#    'frozen shrimp',
#    'garlic',
#    'onion',
#    'salt & pepper',
#    'white wine'}],
#  ['164178',
#   {'celery',
#    'garlic flakes',
#    'hamburger',
#    'hot chili flakes',
#    'jalapenos',
#    'onion',
#    'sliced mushrooms',
#    'sweet green pepper',
#    'sweet red pepper',
#    'tomato sauce & mushrooms'}],
#  ['289025',
#   {'asparagus',
#    'boneless skinless chicken breast',
#    'chicken broth',
#    'chili flakes',
#    'fresh ginger',
#    'garlic',
#    'onion',
#    'rice vinegar',
#    'salt',
#    'soy sauce',
#    'white pepper'}],
#  ['287502',
#   {'dijon mustard',
#    'elbow macaroni',
#    'extra-sharp cheddar cheese',
#    'fresh ground black pepper',
#    'half-and-half',
#    'hot sauce',
#    'kosher salt',
#    'unsalted butter'}],
#  ['75079',
#   {'butter',
#    'dry onion soup mix',
#    'flour',
#    'fresh mushrooms',
#    'round steak',
#    'sour cream',
#    'water'}],
#  ['147100',
#   {'chopped tomatoes',
#    'extra lean ground beef',
#    'lettuce',
#    'mexican blend cheese',
#    'minute white rice',
#    'taco seasoning mix',
#    'water'}],
#  ['233317',
#   {'baby spinach',
#    'cornflour',
#    'dark soy sauce',
#    'lime, juice and zest of',
#    'pak choi',
#    'sunflower oil',
#    'sweet chili sauce',
#    'thai fish sauce',
#    'tiger shrimp',
#    'water'}],
#  ['109793', {'milk', 'minute rice', 'raisins', 'vanilla instant pudding mix'}],
#  ['291409',
#   {'black beans', 'fire-roasted tomatoes', 'kidney beans', 'salsa', 'water'}],
#  ['27275',
#   {'cream cheese',
#    'fettuccine pasta',
#    'margarine',
#    'milk',
#    'parmesan cheese'}],
#  ['282812',
#   {'dried fruits',
#    'honey',
#    'milk',
#    'quick oats',
#    'salt',
#    'sugar',
#    'vanilla',
#    'water'}],
#  ['311608',
#   {'15 bean mix',
#    'bay leaves',
#    'carrot',
#    'celery',
#    'chicken bouillon cubes',
#    'diced tomatoes',
#    'garlic',
#    'ham hocks',
#    'onion',
#    'pepper',
#    'seasoning salt',
#    'tomato sauce',
#    'water'}],
#  ['382234',
#   {'black-eyed peas',
#    'canned green beans',
#    'chili seasoning mix',
#    'corn chips',
#    'dark red kidney beans',
#    'green bell pepper',
#    'ground beef',
#    'ketchup',
#    'onion',
#    'red pepper flakes',
#    'salt and pepper',
#    'sharp cheddar cheese',
#    'vegetable oil',
#    'water',
#    'whole tomatoes'}],
#  ['237391',
#   {'brandy',
#    'butter',
#    'chicken liver',
#    'garlic',
#    'ground black pepper',
#    'heavy cream',
#    'marjoram',
#    'onion',
#    'sage',
#    'salt',
#    'thyme'}],
#  ['266997',
#   {'cayenne pepper',
#    'chili beans',
#    'chili powder',
#    'cumin',
#    'diced tomatoes',
#    'lean ground beef',
#    'onion',
#    'oregano',
#    'salt',
#    'sliced mushrooms',
#    'sour cream'}],
#  ['21916',
#   {'cool whip topping',
#    'frozen pound cake',
#    'jello instant vanilla pudding mix',
#    'orange liqueur',
#    'strawberries',
#    'strawberry',
#    'sugar',
#    'white chocolate baking squares'}],
#  ['229451',
#   {'boneless skinless chicken breast halves',
#    'dijon mustard',
#    'dried tarragon',
#    'fresh lemon juice',
#    'pepper',
#    'worcestershire sauce'}],
#  ['204040', {'basmati rice', 'chicken broth', 'salt and pepper'}],
#  ['82287',
#   {'black olives',
#    'cooked chicken',
#    'cream of chicken soup',
#    'green enchilada sauce',
#    'green onion',
#    'lettuce',
#    'monterey jack cheese',
#    'salsa',
#    'sour cream',
#    'tomato',
#    'tortilla chips'}],
#  ['302815', {'butter', 'garlic', 'parmesan cheese', 'pasta'}],
#  ['311842',
#   {'dried oregano',
#    'feta cheese',
#    'garlic',
#    'large shrimp',
#    'old bay seasoning',
#    'olive oil',
#    'parsley',
#    'pepper',
#    'tomato'}],
#  ['531148',
#   {'cherry tomatoes',
#    'corn kernels',
#    'herbs',
#    'large shrimp',
#    'lemon, zest of',
#    'olive oil',
#    'red onion',
#    'salt & freshly ground black pepper',
#    'snap peas',
#    'unsalted butter',
#    'zucchini'}],
#  ['364157',
#   {'dried oregano',
#    'fresh lemon juice',
#    'garlic',
#    'olive oil',
#    'parmesan cheese',
#    'salt and pepper',
#    'scallions',
#    'vegetable broth',
#    'white beans'}],
#  ['411979',
#   {'bay leaves',
#    'beans',
#    'carrot',
#    'celery',
#    'chicken stock',
#    'garlic',
#    'italian sausage',
#    'onion',
#    'oregano',
#    'tomato',
#    'water'}],
#  ['102832',
#   {'alum',
#    'cinnamon sticks',
#    'cucumbers',
#    'pickling salt',
#    'pickling spices',
#    'sugar',
#    'white vinegar'}],
#  ['246180', {'barbecue sauce', 'ginger ale', 'onion', 'pork butt'}],
#  ['224908',
#   {'brown sugar',
#    'cold water',
#    'dark molasses',
#    'strong coffee',
#    'sugar',
#    'vanilla bean',
#    'vodka'}],
#  ['364761',
#   {'carrot',
#    'celery',
#    'celery ribs',
#    'chicken bouillon cubes',
#    'chicken broth',
#    'frozen corn',
#    'frozen white corn',
#    'onion',
#    'potato',
#    'whole chickens'}],
#  ['489337',
#   {'basil',
#    'eggplant',
#    'fat-free parmesan cheese',
#    'fennel seed',
#    'lean ground turkey',
#    'low-carb marinara sauce',
#    'nonstick cooking spray',
#    'oregano leaves'}],
#  ['262448', {'mountain dew soda', 'raspberry vodka'}],
#  ['294427',
#   {'apple cider',
#    'arugula',
#    'dijon mustard',
#    'fresh thyme',
#    'gouda cheese',
#    'olive oil',
#    'pancetta',
#    'red onion',
#    'red wine vinegar',
#    'salt and pepper',
#    'shallots',
#    'sherry wine vinegar',
#    'tart apples',
#    'white cheddar cheese',
#    'white vinegar'}],
#  ['328436',
#   {'baby carrots',
#    'baking powder',
#    'baking soda',
#    "confectioners' sugar",
#    'eggs',
#    'flour',
#    'light brown sugar',
#    'marshmallow cream',
#    'pumpkin pie spice',
#    'pure vanilla extract',
#    'salt',
#    'unsalted butter',
#    'vegetable oil'}],
#  ['357228',
#   {'baking soda',
#    'butter',
#    'buttermilk',
#    'cinnamon',
#    'clove',
#    'cocoa',
#    'egg',
#    'flour',
#    'nutmeg',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['50246',
#   {'almonds',
#    'cornstarch',
#    'cream of tartar',
#    'egg yolks',
#    'eggs',
#    'flour',
#    'milk',
#    'powdered sugar',
#    'sugar',
#    'sweet cream'}],
#  ...]

# %% [markdown]
# Reshape the data into a vector of vectors of ingredients per recipe, to use for training a *word2vec* embedding model:

# %%
vectors = []

for id, ind_set in recipes:
    v = []
    
    for ind in ind_set:
        v.append(ind)

    vectors.append(v)

vectors
# Out:
# [['winter squash',
#   'salt',
#   'olive oil',
#   'mexican seasoning',
#   'honey',
#   'butter',
#   'mixed spice'],
#  ['prepared pizza crust',
#   'eggs',
#   'salt and pepper',
#   'cheese',
#   'milk',
#   'sausage patty'],
#  ['tomato paste',
#   'diced tomatoes',
#   'salt',
#   'yellow onions',
#   'tomato soup',
#   'water',
#   'lettuce',
#   'ground beef',
#   'chili powder',
#   'rotel tomatoes',
#   'cheddar cheese',
#   'ground cumin',
#   'kidney beans'],
#  ['red bell pepper',
#   'red wine vinegar',
#   'salt',
#   'yellow bell pepper',
#   'shallots',
#   'olive oil',
#   'spreadable cheese with garlic and herbs',
#   'parsley',
#   'pepper',
#   'new potatoes',
#   'tarragon'],
#  ['dry mustard',
#   'cinnamon oil',
#   'salt',
#   'apple cider vinegar',
#   'sugar',
#   'tomato juice',
#   'clove oil',
#   'pepper'],
#  ['vanilla ice cream', 'apple', 'milk', 'frozen apple juice concentrate'],
#  ['garlic',
#   'peppercorn',
#   'orange rind',
#   'orange juice',
#   'fennel seeds',
#   'green olives',
#   'ripe olives',
#   'red chile',
#   'extra virgin olive oil'],
#  ['dry mustard',
#   'a.1. original sauce',
#   'honey',
#   'fresh cilantro leaves',
#   'mirin',
#   'cumin',
#   'chili powder',
#   'cinnamon sticks',
#   'tomato sauce',
#   'pork spareribs',
#   'salt',
#   'white vinegar',
#   'water',
#   'soy sauce',
#   'brown sugar',
#   'orange, juice of',
#   'liquid smoke',
#   'fresh garlic',
#   'fresh ginger',
#   'yellow onion',
#   'cracked black pepper',
#   'fresh coarse ground black pepper'],
#  ['vanilla ice cream',
#   'whipped cream',
#   'strawberry ice cream',
#   'bananas',
#   'chocolate syrup',
#   'chocolate sandwich style cookies'],
#  ['eggs',
#   'unsalted butter',
#   'salt',
#   'cake flour',
#   'orange rind',
#   'sugar',
#   'fresh lemon juice',
#   'bananas',
#   'baking soda'],
#  ['sour cream', 'whole berry cranberry sauce', 'prepared horseradish'],
#  ['vanilla wafers',
#   'powdered sugar',
#   'eggs',
#   'walnuts',
#   'whipping cream',
#   'butter',
#   'strawberry'],
#  ['great northern bean',
#   'bacon',
#   'salt',
#   'cornstarch',
#   'water',
#   'dark brown sugar',
#   'chicken bouillon cubes',
#   'mustard powder',
#   'black pepper',
#   'chili powder',
#   'garlic powder',
#   'molasses',
#   'onion'],
#  ['hot sauce',
#   'salt',
#   'ham hock',
#   'whiskey',
#   'brown sugar',
#   'collard greens',
#   'molasses'],
#  ['spearmint', 'gentian root', 'scullcap herb', 'burnet root', 'wood bethony'],
#  ['lean pork chops',
#   'dry mustard',
#   'salt',
#   'oil',
#   'chicken rice soup',
#   'flour',
#   'garlic powder'],
#  ['oil', 'cornstarch', 'cheese', 'whole green chilies', 'egg roll wrap'],
#  ['chinese noodles', 'salted peanuts', 'butterscotch chips'],
#  ['ground pork',
#   'hamburger buns',
#   'cooking oil',
#   'soy sauce',
#   'beef broth',
#   'celery',
#   'onion'],
#  ['garlic',
#   'vegetable bouillon cubes',
#   'great northern bean',
#   'fresh herb',
#   'red bell pepper',
#   'cauliflower',
#   'salt free herb and spice seasoning mix',
#   'salt and pepper',
#   'water',
#   'escarole',
#   'broccoli floret',
#   'green peas',
#   'ground coriander',
#   'canola oil',
#   'onion',
#   'potato'],
#  ['unsalted butter',
#   'coarse salt',
#   'salt',
#   'nutmeg',
#   'water',
#   'boiling potatoes',
#   'fresh spinach leaves',
#   'fresh ground black pepper'],
#  ['spinach',
#   'rolled oats',
#   'apple juice',
#   'salt',
#   'broth',
#   'white pepper',
#   'scallion',
#   'olive oil',
#   'celery',
#   'fresh parsley',
#   'dried thyme',
#   'onion'],
#  ['condensed cream of chicken soup',
#   'paprika',
#   'all-purpose flour',
#   'oil',
#   'cornstarch',
#   'salt and pepper',
#   'boneless skinless chicken breast halves',
#   'egg',
#   'garlic powder',
#   'seasoning salt'],
#  ['powdered sugar',
#   'all-purpose flour',
#   'ground cinnamon',
#   'salt',
#   'vanilla',
#   'granulated sugar',
#   'egg',
#   'bread',
#   'brown sugar',
#   'milk',
#   'vegetable oil',
#   'butter',
#   'baking powder'],
#  ['salt', 'white pepper', 'egg yolks', 'lemon, juice of', 'butter'],
#  ['ground black pepper',
#   'black cumin',
#   'ground turmeric',
#   'ground coriander',
#   'ground ginger',
#   'ground cumin'],
#  ['garlic',
#   'vegetarian ground beef',
#   'diced tomatoes',
#   'salt',
#   'green pepper',
#   'red pepper flakes',
#   'black pepper',
#   'chili powder',
#   'celery',
#   'jalapenos',
#   'onion',
#   'kidney beans'],
#  ['dried parsley',
#   'salt',
#   'ground pepper',
#   'ground thyme',
#   'elbow macaroni',
#   'water',
#   'beef stew meat',
#   'beef bouillon cube',
#   'cabbage',
#   'parmesan cheese',
#   'garbanzo beans',
#   'zucchini',
#   'tomato',
#   'onion'],
#  ['red potatoes', 'rosemary', 'margarine'],
#  ['dried oregano',
#   'chicken stock',
#   'unsalted butter',
#   'broccoli stem',
#   'heavy cream',
#   'cornstarch',
#   'dried sweet basil leaves',
#   'broccoli floret',
#   'dry white wine',
#   'worcestershire sauce',
#   'tabasco sauce',
#   'smoked chicken',
#   'salt & fresh ground pepper',
#   'black beans',
#   'carrot',
#   'dried thyme',
#   'celery',
#   'onion'],
#  ['eggs',
#   'all-purpose flour',
#   'vanilla',
#   'salt',
#   'sugar',
#   'butter',
#   'baking powder',
#   'miniature peppermint patties',
#   'baking cocoa'],
#  ['tomato sauce',
#   'salt',
#   'hot chili pepper',
#   'cornmeal',
#   'ground beef',
#   'sliced ripe olives',
#   'taco sauce',
#   'tabasco sauce',
#   'whole kernel corn',
#   'cheddar cheese',
#   'pepper',
#   'onion'],
#  ['dry ranch dressing mix', 'french bread', 'butter'],
#  ['egg substitute',
#   'dry mustard',
#   'salt',
#   'fresh breadcrumb',
#   'water',
#   'black pepper',
#   'worcestershire sauce',
#   'non-fat powdered milk',
#   'onion',
#   'ground venison'],
#  ['plain yogurt', 'milk', 'frozen juice concentrate'],
#  ['low sodium chicken broth',
#   'diced tomatoes',
#   'wax beans',
#   'corn',
#   'carrot',
#   'zucchini',
#   'green beans',
#   'potato'],
#  ['crouton',
#   'frozen chopped spinach',
#   'salt',
#   'sharp cheddar cheese',
#   'egg',
#   'black pepper',
#   'condensed cream of mushroom soup',
#   'onion'],
#  ['garlic',
#   'celery seed',
#   'red potatoes',
#   'low-fat sour cream',
#   'prepared mustard',
#   'white wine vinegar',
#   'salt',
#   'diced pimentos',
#   'sugar',
#   'fat-free mayonnaise',
#   'pepper',
#   'green onion',
#   'plain low-fat yogurt'],
#  ['eggs',
#   'frozen chopped spinach',
#   'margarine',
#   'soft breadcrumbs',
#   'oregano',
#   'sage',
#   'garlic powder',
#   'onion'],
#  ['frozen vegetables',
#   'cooking oil',
#   'condensed cream of mushroom & garlic soup',
#   'cream of mushroom soup',
#   'ground beef',
#   'salt & pepper',
#   'onion',
#   'cornbread mix'],
#  ['garlic',
#   'toasted sesame seeds',
#   'toasted sesame oil',
#   'angel hair pasta',
#   'soy sauce',
#   'honey',
#   'green onions',
#   'stir fry vegetables'],
#  ['pecans',
#   'sugar',
#   'honey',
#   'butter',
#   'buckwheat flour',
#   'baking powder',
#   'eggs',
#   'all-purpose flour',
#   'unsweetened cocoa',
#   'flour',
#   'cinnamon',
#   'salt',
#   'ground cinnamon',
#   'orange juice',
#   'brown sugar',
#   'yam',
#   'baking soda',
#   'ground cloves',
#   'orange rind',
#   'low-fat buttermilk',
#   'canola oil'],
#  ['eggs',
#   'sorghum',
#   'all-purpose flour',
#   'canola oil',
#   'ground cinnamon',
#   'salt',
#   'ground cloves',
#   'granulated sugar',
#   'orange rind',
#   'orange juice',
#   'unsweetened cocoa',
#   'raisins',
#   'baking powder',
#   'buckwheat flour',
#   'low-fat buttermilk',
#   'yam',
#   'baking soda',
#   'boiling water'],
#  ['garlic',
#   'american cheese',
#   'prepared yellow mustard',
#   'beer',
#   'ground beef',
#   'sugar',
#   'cayenne',
#   'salt & pepper'],
#  ['ripe olives',
#   'tri-color spiral pasta',
#   'cider vinegar',
#   'water chestnut',
#   'ham',
#   'sweet pepper',
#   'salt and pepper',
#   'cheese',
#   'onion powder',
#   'olive oil',
#   'garlic powder',
#   'italian seasoning',
#   'dill pickles',
#   'chives',
#   'green onion',
#   'tomato'],
#  ['flat leaf parsley',
#   'oregano',
#   'oil',
#   'frozen french fries',
#   'salt & freshly ground black pepper',
#   'parmesan cheese',
#   'basil'],
#  ['ham',
#   'deli turkey',
#   'butter',
#   'cheddar cheese',
#   'pepperoni',
#   'mozzarella cheese',
#   'swiss cheese',
#   'sandwich bun',
#   'good seasonings italian salad dressing mix'],
#  ['eggs',
#   'all-purpose flour',
#   'vanilla',
#   'shortening',
#   'salt',
#   'sugar',
#   'milk',
#   'butter',
#   'baking powder',
#   'icing sugar'],
#  ['eggs',
#   'coconut',
#   'cinnamon',
#   'oil',
#   'yellow cake mix',
#   'nutmeg',
#   'water',
#   'pecans',
#   'crushed pineapple',
#   'carrot',
#   'vanilla instant pudding mix'],
#  ['red bell pepper',
#   'jiffy corn muffin mix',
#   'heavy cream',
#   'sharp cheddar cheese',
#   'egg',
#   'whole kernel corn',
#   'butter',
#   'honey',
#   'jalapenos',
#   'onion'],
#  ['eggs',
#   'cinnamon',
#   'vanilla',
#   'salt',
#   'dry yeast',
#   'water',
#   'baking powder',
#   'raisins',
#   'flour',
#   'sugar',
#   'crushed pineapple',
#   'brown sugar',
#   'milk',
#   'vegetable oil',
#   'butter',
#   'nuts',
#   'baking soda'],
#  ['garlic',
#   'eggs',
#   'tomato paste',
#   'ground black pepper',
#   'ricotta cheese',
#   'salt',
#   'dried basil',
#   'parsley flakes',
#   'lasagna noodle',
#   'cottage cheese',
#   'italian sausage',
#   'ground beef',
#   'mozzarella cheese',
#   'parmesan cheese',
#   'whole tomato'],
#  ['eggs',
#   'olive oil flavored cooking spray',
#   'herbs',
#   'frozen chopped spinach',
#   'salt',
#   'toasted wheat germ',
#   'cheese',
#   'cottage cheese',
#   'pepper',
#   'beef',
#   'spices'],
#  ['rolls',
#   'cinnamon',
#   'instant vanilla pudding',
#   'raisins',
#   'brown sugar',
#   'butter'],
#  ['garlic',
#   'granulated sugar',
#   'white onion',
#   'ground beef',
#   'prego spaghetti sauce',
#   'stewed tomatoes'],
#  ['spicy mustard',
#   'hot sauce',
#   'fresh garlic',
#   'ketchup',
#   'sour cream',
#   'fresh lemon juice',
#   'brown sugar',
#   'honey',
#   'vegetable oil',
#   'beef steaks',
#   'dried dill weed',
#   'fresh parsley'],
#  ['salt', 'flour', 'sugar', 'egg', 'butter', 'milk', 'baking powder'],
#  ['garlic',
#   'dried oregano',
#   'hot sauce',
#   'button mushrooms',
#   'dried basil',
#   'water',
#   'salsa',
#   'pasta',
#   'olive oil',
#   'chicken breasts',
#   'parmesan cheese',
#   'fresh parsley',
#   'tomato',
#   'onion',
#   'fresh ground black pepper'],
#  ['fresh herbs', 'cider vinegar', 'fresh herb'],
#  ['eggs',
#   'fat',
#   'salt',
#   'flour',
#   'fresh corn',
#   'cream',
#   'baking powder',
#   'pepper'],
#  ['black olives',
#   'picante sauce',
#   'fettuccine pasta',
#   'jalapeno',
#   'milk',
#   'cheddar cheese soup'],
#  ['frozen peas',
#   'lemons, juice of',
#   'salt',
#   'hass avocado',
#   'cilantro',
#   'tomato',
#   'onion'],
#  ['oil',
#   'soy sauce',
#   'lemon juice',
#   'worcestershire sauce',
#   'garlic powder',
#   'pepper',
#   'basil'],
#  ['apple', 'pear', 'unflavored gelatin', 'cream cheese', 'milk', 'yogurt'],
#  ['bacon',
#   'veal roast',
#   'salt',
#   'oil',
#   'bay leaf',
#   'thyme',
#   'parsley sprigs',
#   'butter',
#   'carrot',
#   'pepper',
#   'onion'],
#  ['crackers', 'mayonnaise', 'black pepper', 'tomato'],
#  ['garlic',
#   'fresh parsley',
#   'brine',
#   'sweet onion',
#   'red wine vinegar',
#   'ham',
#   'ciabatta',
#   'oregano leaves',
#   'genoa salami',
#   'fresh basil',
#   'kalamata olive',
#   'olive oil',
#   'provolone cheese',
#   'carrot',
#   'green olives',
#   'capers',
#   'tomato'],
#  ['vanilla',
#   'vanilla instant pudding mix',
#   'whipping cream',
#   'powdered sugar'],
#  ['vanilla',
#   'cookie',
#   'prepared graham cracker crusts',
#   'sugar',
#   'miniature semisweet chocolate chips',
#   'gelatin',
#   'cream cheese',
#   'milk'],
#  ['oregano',
#   'butter',
#   'baking powder',
#   'monterey jack cheese',
#   'zucchini',
#   'tomato',
#   'onion',
#   'all-purpose flour',
#   'vegetable shortening',
#   'green pepper',
#   'flour',
#   'egg',
#   'chili powder',
#   'celery',
#   'cayenne pepper',
#   'ground cumin',
#   'salt',
#   'water',
#   'sliced mushrooms',
#   'soy sauce',
#   'carrot',
#   'cloves'],
#  ['half-and-half', 'salt and pepper', 'sweet corn', 'sweet butter'],
#  ['eggs',
#   'all-purpose flour',
#   'vanilla',
#   'salt',
#   'lemon, rind of',
#   'sugar',
#   'butter',
#   'yogurt',
#   'baking soda'],
#  ['eggs',
#   'vanilla',
#   'unsweetened chocolate squares',
#   'flour',
#   'sugar',
#   'butter',
#   'nuts'],
#  ['vermicelli',
#   'chili-garlic sauce',
#   'reduced sodium soy sauce',
#   'sesame oil',
#   'fresh ginger',
#   'cooked chicken',
#   'sesame seeds',
#   'rice vinegar',
#   'vegetable oil',
#   'green onions',
#   'fresh cilantro',
#   'broccoli'],
#  ['pecans',
#   'orange rind',
#   'orange juice',
#   'sugar',
#   'philadelphia cream cheese',
#   'apples',
#   'celery'],
#  ['garlic',
#   'paprika',
#   'fresh ground pepper',
#   'salt',
#   'thyme',
#   'olive oil',
#   'lemon juice',
#   'boneless chicken breast',
#   'cayenne',
#   'cumin'],
#  ['part-skim ricotta cheese',
#   'tomato sauce',
#   'oregano leaves',
#   'baking potato',
#   'mozzarella cheese',
#   'garlic powder',
#   'parmesan cheese'],
#  ['tomato puree',
#   'sodium-free vegetable broth',
#   'mushroom pieces',
#   'cornstarch',
#   'white wine',
#   'black pepper',
#   'tabasco sauce',
#   'onion'],
#  ['garlic',
#   'scallions',
#   'red wine vinegar',
#   'salt',
#   'bibb lettuce',
#   'fresh basil',
#   'black pepper',
#   'albacore tuna in water',
#   'light olive oil',
#   'white kidney beans',
#   'red sweet bell peppers'],
#  ['crushed tomatoes',
#   'oregano',
#   'penne pasta',
#   'olive oil',
#   'black pepper',
#   'butter',
#   'onion',
#   'bacon',
#   'beef consomme',
#   'dry white wine',
#   'rubbed sage',
#   'celery',
#   'salt',
#   'carrot',
#   'lean ground beef',
#   'garlic',
#   'ground pork',
#   'nutmeg',
#   'red pepper flakes',
#   'milk'],
#  ['sugar substitute', 'apples', 'water', 'red cinnamon candies'],
#  ['cucumber',
#   'oil',
#   'elbow macaroni',
#   'green pepper',
#   'ketchup',
#   'brown sugar',
#   'lemon juice',
#   'celery',
#   'tomato',
#   'onion'],
#  ['salt',
#   'vanilla',
#   'flour',
#   'sugar',
#   'brown sugar',
#   'cocoa',
#   'milk',
#   'vegetable oil',
#   'baking powder',
#   'hot water'],
#  ['eggs',
#   'powdered sugar',
#   'toasted almonds',
#   'salt',
#   'apple pie filling',
#   'flour',
#   'milk',
#   'butter'],
#  ['mayonnaise', 'white bread', 'bananas'],
#  ['dried oregano',
#   'chicken stock',
#   'all-purpose flour',
#   'salt',
#   'fresh ground black pepper',
#   'breadcrumbs',
#   'poultry seasoning',
#   'dry white wine',
#   'garlic powder',
#   'milk',
#   'vegetable oil',
#   'dried thyme',
#   'lean ground beef',
#   'onion',
#   'boneless skinless chicken thighs'],
#  ['salt', 'salmon', 'lemon juice', 'cream cheese', 'liquid smoke', 'onion'],
#  ['peanut oil',
#   'desiccated coconut',
#   'tomato',
#   'onion',
#   'red chili pepper',
#   'ground cayenne pepper',
#   'water',
#   'soy sauce',
#   'brown sugar',
#   'peanuts',
#   'carrot',
#   'sambal oelek',
#   'garlic',
#   'bean sprouts',
#   'tempeh',
#   'vegetable stock',
#   'ginger',
#   'ground coriander',
#   'green beans',
#   'ground cumin'],
#  ['eggs',
#   'salt and pepper',
#   'water',
#   'tomato soup',
#   'dried breadcrumbs',
#   'ground beef',
#   'sugar',
#   'lemon juice',
#   'onion'],
#  ['soft silken tofu',
#   'hot sauce',
#   'chunky salsa',
#   'salt and pepper',
#   'avocado',
#   'fresh cilantro',
#   'lime juice'],
#  ['eggs',
#   'cinnamon',
#   'walnuts',
#   'salt',
#   'shortening',
#   'ground cloves',
#   'nutmeg',
#   'flour',
#   'bananas',
#   'baking soda',
#   'white sugar'],
#  ['dried basil',
#   'salt and pepper',
#   'boneless skinless chicken breast',
#   'olive oil',
#   'lime juice',
#   'tomato'],
#  ['salt',
#   'water',
#   'ketchup',
#   'brown sugar',
#   'fresh lemon juice',
#   'worcestershire sauce',
#   'mustard',
#   'vegetable oil',
#   'beef ribs',
#   'onion'],
#  ['sugar', 'egg whites', 'green grape'],
#  ['eggs',
#   'water',
#   'vegetable oil',
#   'betty crocker fudge brownie mix',
#   'milk chocolate candy bars'],
#  ['eggs',
#   'salt',
#   'water',
#   'baking powder',
#   'flour',
#   'sugar',
#   'butter',
#   'bananas',
#   'nuts',
#   'baking soda',
#   'chocolate chips'],
#  ['eggs',
#   'oreo cookie crumbs',
#   'vanilla',
#   'sweetened condensed milk',
#   'flour',
#   'sour cream',
#   'brown sugar',
#   'cream cheese',
#   'butter',
#   'chocolate chips'],
#  ['2% low-fat milk',
#   'sugar-free non-fat vanilla yogurt',
#   'banana',
#   'natural-style peanut butter'],
#  ['bean dip',
#   'sour cream',
#   'cream cheese',
#   'cheddar cheese',
#   'taco seasoning'],
#  ['american cheese',
#   'bacon',
#   'ground sirloin',
#   'dill weed',
#   'iceberg lettuce',
#   'no-salt-added ketchup',
#   "mccormick's montreal brand steak seasoning",
#   'tomato',
#   'onion'],
#  ['plain yogurt',
#   'paprika',
#   'cucumber',
#   'chopped tomato',
#   'salt',
#   'chat masala',
#   'potato'],
#  ['cinnamon',
#   'salt',
#   'vanilla',
#   'buttermilk',
#   'whole wheat flour',
#   'raisins',
#   'natural bran',
#   'brown sugar',
#   'egg',
#   'carrot',
#   'baking soda',
#   'corn oil'],
#  ['grand marnier',
#   'tequila',
#   'limeade',
#   'triple sec',
#   'lime juice',
#   'lime wedge'],
#  ['semi-sweet chocolate chips', 'pecans', 'flour', 'brown sugar', 'butter'],
#  ['garlic',
#   'mushrooms',
#   'cappelletti pasta',
#   'salt',
#   'tomato soup',
#   'ground beef',
#   'milk',
#   'butter',
#   'corn',
#   'cheddar cheese',
#   'pepper',
#   'onion',
#   'chopped tomato'],
#  ['garlic',
#   'spaghetti',
#   'tomato sauce',
#   'salt and pepper',
#   'squid',
#   'dry white wine',
#   'parsley',
#   'hot water',
#   'extra virgin olive oil'],
#  ['vinegar',
#   'vanilla',
#   'salt',
#   'water',
#   'flour',
#   'sugar',
#   'cocoa',
#   'vegetable oil',
#   'baking soda'],
#  ['applesauce', 'brown sugar', 'pork loin chops', 'clove'],
#  ['prepared horseradish',
#   'roast beef',
#   'whole wheat bread dough',
#   'ham',
#   'turkey',
#   'provolone cheese',
#   'mayonnaise',
#   'honey mustard',
#   'butter',
#   'cheddar cheese',
#   'leaf lettuce',
#   'roasted red peppers',
#   'cream cheese',
#   'green olives',
#   'swiss cheese',
#   'radish sprouts'],
#  ['fresh dill',
#   'salt and pepper',
#   'water',
#   'flour',
#   'sour cream',
#   'lemon, juice of',
#   'wild mushrooms',
#   'butter',
#   'beef broth',
#   'onion'],
#  ['garlic',
#   'bean sprouts',
#   'rice wine vinegar',
#   'light soy sauce',
#   'sesame oil',
#   'asian chili sauce',
#   'carrot',
#   'fresh ginger',
#   'honey',
#   'green onions',
#   'fresh cilantro',
#   'english cucumber',
#   'rice noodles'],
#  ['eggs',
#   'unsalted butter',
#   'all-purpose flour',
#   'vanilla',
#   'granulated sugar',
#   'unsweetened cocoa powder',
#   'bittersweet chocolate',
#   'kosher salt',
#   'brewed espresso'],
#  ['brown sugar', 'dr. pepper cola', 'orange marmalade'],
#  ['peanut oil',
#   'scallions',
#   'salt',
#   'gingerroot',
#   'fish',
#   'rice wine',
#   'sesame oil',
#   'white pepper',
#   'low sodium soy sauce'],
#  ['garlic',
#   'low sodium beef broth',
#   'yellow onions',
#   'flour',
#   'olive oil',
#   'sugar',
#   'butter',
#   'beef broth',
#   'parmesan cheese',
#   'sherry wine',
#   'french bread',
#   'swiss cheese',
#   'romano cheese'],
#  ['eggs',
#   'all-purpose flour',
#   'margarine',
#   'white sugar',
#   'vanilla',
#   'salt',
#   'water',
#   'whole wheat flour',
#   'brown sugar',
#   'baking soda',
#   'chocolate chips'],
#  ['eggs',
#   'cornbread',
#   'cream of chicken soup',
#   'squash',
#   'sage',
#   'butter',
#   'onion'],
#  ['dried parsley',
#   'dried oregano',
#   'paprika',
#   'tomato sauce',
#   'salt',
#   'dried basil',
#   'bottled garlic',
#   'white onion',
#   'italian sausage',
#   'olive oil',
#   'sugar',
#   'garlic powder',
#   'pepper',
#   'bay leaves'],
#  ['frozen broccoli cuts',
#   'ground black pepper',
#   'salt',
#   'sharp cheddar cheese',
#   'cream of chicken soup',
#   'soy sauce',
#   'garlic powder',
#   'milk',
#   'french-fried onions'],
#  ['eggs',
#   'almond extract',
#   'all-purpose flour',
#   'pure vanilla extract',
#   'sugar',
#   'butter',
#   'whole milk'],
#  ['unsalted butter',
#   'fresh garlic',
#   'oil',
#   'egg',
#   'unseasoned breadcrumbs',
#   'artichoke hearts'],
#  ['cider vinegar',
#   'salt',
#   'barbecue sauce',
#   'black pepper',
#   'chili powder',
#   'worcestershire sauce',
#   'chicken',
#   'hot red pepper sauce'],
#  ['sour cream',
#   'ritz cracker crumbs',
#   'cream cheese',
#   'water chestnuts',
#   'cheddar cheese',
#   'frozen broccoli',
#   'dry onion soup mix'],
#  ['instant chocolate pudding mix',
#   'salt',
#   'vanilla',
#   'cocoa powder',
#   'water',
#   'flour',
#   'sugar',
#   'mayonnaise',
#   'baking soda',
#   'milk',
#   'cool whip'],
#  ['garlic',
#   'louisiana hot sauce',
#   'paprika',
#   'coriander',
#   'budweiser beer',
#   'hunts tomato sauce',
#   'cornmeal',
#   'water',
#   'oregano leaves',
#   'lean chuck',
#   'sugar',
#   'unsweetened cocoa',
#   'chili powder',
#   'bouillon',
#   'flour',
#   'lean pork',
#   'onion',
#   'cumin'],
#  ['red bell pepper',
#   'eggs',
#   'unsalted butter',
#   'baby spinach',
#   'fresh garlic',
#   'goat cheese',
#   'white pepper',
#   'olive oil',
#   'simply potatoes shredded hash browns',
#   'yellow onion',
#   'unsmoked bacon',
#   'kosher salt',
#   'meatloaf mixture'],
#  ['eggs',
#   'egg white',
#   'ground cinnamon',
#   'salt',
#   'ground cloves',
#   'nutmeg',
#   'heavy cream',
#   'dark brown sugar',
#   'milk',
#   'ground ginger',
#   'pie crusts',
#   'pumpkin puree'],
#  ['dry onion flakes',
#   'paprika',
#   'celery seed',
#   'salt',
#   'poppy seed',
#   'breadcrumbs',
#   'cream of chicken soup',
#   'poultry seasoning',
#   'flour',
#   'sour cream',
#   'milk',
#   'vegetable oil',
#   'butter',
#   'baking powder',
#   'beef',
#   'onion'],
#  ['eggs',
#   'nuts',
#   'semi-sweet chocolate chips',
#   'vanilla',
#   'blended oatmeal',
#   'flour',
#   'sugar',
#   'brown sugar',
#   'hershey chocolate candy bars',
#   'butter',
#   'baking powder',
#   'baking soda'],
#  ['eggs',
#   'oatmeal',
#   'white sugar',
#   'vanilla',
#   'salt',
#   'baking powder',
#   'flour',
#   'brown sugar',
#   "hershey's semi-sweet baking chocolate",
#   'butter',
#   'nuts',
#   'baking soda',
#   'chocolate chips'],
#  ['vanilla', 'granulated sugar', 'flour', 'milk', 'butter'],
#  ['taco shells',
#   'salsa',
#   'lettuce',
#   'ground beef',
#   'corn cobs',
#   'cheddar cheese',
#   'taco seasoning',
#   'tomato',
#   'onion'],
#  ['black pepper',
#   'light brown sugar',
#   'dark chocolate chips',
#   'cumin',
#   'bell peppers',
#   'chicken bouillon cube',
#   'tortilla chips',
#   'mexican chili powder',
#   'cinnamon',
#   'chunky salsa',
#   'salt',
#   'stewing pork',
#   'white onion',
#   'beef bouillon cube',
#   'habanero pepper',
#   'garlic',
#   'sazon goya',
#   'tomato paste',
#   'stewing beef',
#   'beef broth',
#   'ground coriander',
#   'beans'],
#  ['pitted dates',
#   'powdered sugar',
#   'all-purpose flour',
#   'salt',
#   'shortening',
#   'pecans',
#   'warm water',
#   'lemon zest',
#   'lime zest',
#   'egg',
#   'tequila',
#   'brown sugar',
#   'triple sec',
#   'cream cheese',
#   'butter',
#   'orange-flavored liqueur',
#   'baking soda'],
#  ['water',
#   'cream of celery soup',
#   'cream of chicken soup',
#   'bouillon cubes',
#   'butter',
#   'milk',
#   'potato flakes',
#   'carrot',
#   'celery',
#   'onion',
#   'potato'],
#  ['eggs',
#   'cinnamon',
#   'salt',
#   'flour',
#   'sugar',
#   'cream',
#   'lemon, juice of',
#   'milk',
#   'butter',
#   'apples'],
#  ['garlic',
#   'salt',
#   'cheese',
#   'macaroni',
#   'milk',
#   'butter',
#   'fresh coarse ground black pepper',
#   'onion'],
#  ['unsalted butter',
#   'muscat wine',
#   'salt water',
#   'heavy cream',
#   'cheese',
#   'macaroni',
#   'black pepper',
#   'fine semolina',
#   'onion',
#   'potato'],
#  ['penne pasta',
#   'salt and pepper',
#   'cheese',
#   'butter',
#   'milk',
#   'applesauce',
#   'onion',
#   'potato'],
#  ['salt', 'water', 'ginger', 'dried yellow peas', 'pork'],
#  ['ham bone',
#   'clove',
#   'salt',
#   'water',
#   'dried yellow peas',
#   'dried thyme',
#   'carrot',
#   'ground ginger',
#   'brown mustard',
#   'pepper',
#   'onion'],
#  ['fresh spinach', 'nutmeg', 'water', 'butter'],
#  ['ground pork',
#   'tomato paste',
#   'paprika',
#   'ground black pepper',
#   'salt',
#   'cornstarch',
#   'granulated sugar',
#   'water',
#   'white vinegar',
#   'ground beef',
#   'wondra flour',
#   'chili powder',
#   'garlic powder',
#   'dried onion flakes'],
#  ['oregano',
#   'ponzu sauce',
#   'apple cider vinegar',
#   'tomato ketchup',
#   'salt',
#   'liquid smoke',
#   'dark brown sugar',
#   'maple syrup',
#   'applesauce',
#   'granulated garlic',
#   'cayenne'],
#  ['salt',
#   'vanilla',
#   'flour',
#   'sugar',
#   'sour cream',
#   'egg',
#   'butter',
#   'baking powder',
#   'baking soda'],
#  ['vanilla ice cream', 'oreo cookies', 'frozen whipped topping', 'butter'],
#  ['white bread', 'processed cheese', 'butter'],
#  ['garlic',
#   'london broil beef',
#   'balsamic vinegar',
#   'soy sauce',
#   'olive oil',
#   'worcestershire sauce',
#   'rosemary',
#   'fresh ground black pepper'],
#  ['garlic',
#   'dried oregano',
#   'dried rosemary',
#   'margarine',
#   'spicy brown mustard',
#   'nonfat dry milk powder',
#   'chicken broth',
#   'dry sherry',
#   'cornstarch',
#   'fresh mushrooms',
#   'hot pepper sauce',
#   'teriyaki sauce',
#   'parmesan cheese',
#   'dried thyme',
#   'nonfat milk',
#   'salt and black pepper'],
#  ['eggs',
#   'cinnamon',
#   'vanilla',
#   'nutmeg',
#   'vanilla protein powder',
#   'splenda sugar substitute',
#   'sour cream',
#   'butter',
#   'cream cheese',
#   'almonds'],
#  ['bacon', 'real maple syrup', 'butter', 'refrigerated buttermilk biscuits'],
#  ['mayonnaise',
#   'worcestershire sauce',
#   'horseradish',
#   'tabasco sauce',
#   'velveeta cheese'],
#  ['red wine vinegar', 'lemon juice', 'water'],
#  ['old fashioned oats',
#   "i can't believe it's not butter spread",
#   'water',
#   'berries',
#   'ground flax seeds',
#   'sugar-free syrup'],
#  ['eggs',
#   'powdered sugar',
#   'vanilla',
#   'salt',
#   'blueberries',
#   'flour',
#   'sugar',
#   'maple syrup',
#   'milk',
#   'cream cheese',
#   'nuts',
#   'french bread',
#   'frozen blueberries'],
#  ['bacon',
#   'salt',
#   'red potatoes',
#   'chicken broth',
#   'white pepper',
#   'sour cream',
#   'celery',
#   'cheddar cheese',
#   'liquid smoke',
#   'chives',
#   'onion',
#   'velveeta cheese'],
#  ['powdered sugar',
#   'cinnamon',
#   'salt',
#   'active dry yeast',
#   'granulated sugar',
#   'warm water',
#   'flour',
#   'egg',
#   'brown sugar',
#   'milk',
#   'butter',
#   'vanilla pudding mix',
#   'cream cheese'],
#  ['red bell pepper',
#   'garlic',
#   'asparagus',
#   'salt and pepper',
#   'spaghetti squash',
#   'white mushroom',
#   'spaghetti sauce',
#   'reduced-fat parmesan cheese',
#   'italian seasoning',
#   'part-skim mozzarella cheese'],
#  ['graham cracker crumbs',
#   'soft silken tofu',
#   'coriander',
#   'margarine',
#   'frozen pineapple concentrate',
#   'vegan cream cheese',
#   'oil',
#   'cornstarch',
#   'vanilla',
#   'water',
#   'lemon juice',
#   'maple syrup',
#   'vegan sugar'],
#  ['garlic',
#   'frozen black-eyed peas',
#   'all-purpose flour',
#   'low sodium chicken broth',
#   'green bell pepper',
#   'andouille sausage',
#   'creole seasoning',
#   'cooked chicken',
#   'vegetable oil',
#   'large raw shrimp',
#   'celery',
#   'onion'],
#  ['eggs',
#   'pickle',
#   'cracker',
#   'salt and pepper',
#   'ground beef',
#   'thousand island dressing',
#   'cheddar cheese',
#   'onion'],
#  ['garlic',
#   'linguine',
#   'heavy whipping cream',
#   'cajun spices',
#   'salt',
#   'salmon',
#   'white pepper',
#   'lemon juice',
#   'parsley',
#   'butter',
#   'parmesan cheese',
#   'parmesan-romano cheese mix',
#   'basil'],
#  ['eggs', 'oil', 'cottage cheese', 'milk', 'phyllo dough', 'feta'],
#  ['white rice',
#   'cucumber',
#   'pickled ginger',
#   'seasoned rice vinegar',
#   'lettuce',
#   'avocado',
#   'soy sauce',
#   'imitation crabmeat'],
#  ['eggs',
#   'maraschino cherry',
#   'walnuts',
#   'sweetened condensed milk',
#   'flour',
#   'mincemeat',
#   'baking soda',
#   'mixed candied fruit'],
#  ['chicken stock',
#   'eggs',
#   'salt',
#   'oil',
#   'white onion',
#   'sugar',
#   'chicken breasts',
#   'baby carrots',
#   'baking powder',
#   'kosher salt',
#   'celery',
#   'matzo meal',
#   'pepper'],
#  ['poppy seed',
#   'cream of mushroom soup',
#   'sour cream',
#   'frozen southern style hash brown potatoes',
#   'cheddar cheese'],
#  ['eggs',
#   'lean ground beef',
#   'red onion',
#   'sea salt',
#   'fresh ground pepper',
#   'oregano',
#   'ketchup',
#   'olive oil',
#   'adobo seasoning',
#   'italian seasoned breadcrumbs',
#   'ground coriander',
#   'fresh garlic cloves',
#   'low sodium soy sauce',
#   'ground sage',
#   'veggie shreds cheese'],
#  ['mushrooms',
#   'kraft macaroni and cheese',
#   'green bell pepper',
#   'tuna',
#   'cream of celery soup',
#   'butter',
#   'celery',
#   'onion'],
#  ['garlic',
#   'cider vinegar',
#   'paprika',
#   'dry mustard',
#   'miracle whip',
#   'salt',
#   'ketchup',
#   'sugar',
#   'tabasco sauce',
#   'vegetable oil',
#   'pepper'],
#  ['red bell pepper',
#   'pepperoncini peppers',
#   'red ripe tomatoes',
#   'red onion',
#   'tuna in vegetable oil',
#   'water-packed artichoke hearts',
#   'red wine vinegar',
#   'oregano',
#   'seedless cucumber',
#   'shallot',
#   'lemon, juice of',
#   'kalamata olive',
#   'kosher salt & freshly ground black pepper',
#   'italian parsley',
#   'extra virgin olive oil'],
#  ['ground black pepper',
#   'buttermilk',
#   'egg',
#   'orange roughy',
#   'self-rising flour',
#   'canola oil',
#   'seasoning salt'],
#  ['garlic',
#   'eggs',
#   'bacon',
#   'all-purpose flour',
#   'simply potatoes traditional mashed potatoes',
#   'salt',
#   'goat cheese',
#   'frozen spinach',
#   'green onion',
#   'egg yolk'],
#  ['ground black pepper',
#   'cajun seasoning',
#   'salt and pepper',
#   'flour',
#   'egg',
#   'boneless pork chops',
#   'milk',
#   'self-rising flour',
#   'canola oil',
#   'seasoning salt'],
#  ['ramen noodles',
#   'water',
#   'stir fry vegetables',
#   'teriyaki marinade',
#   'imitation crabmeat'],
#  ['apple',
#   'red onion',
#   'pesto sauce',
#   'small red potato',
#   'salt',
#   'pumpkin seeds',
#   'green bell pepper',
#   'vegetable broth',
#   'smooth cashew butter',
#   'banana',
#   'fresh cilantro leaves',
#   'celery',
#   'ground red pepper',
#   'pumpkin puree'],
#  ['vegetable bouillon cubes',
#   'mushrooms',
#   'garlic',
#   'margarine',
#   'nutmeg',
#   'water',
#   'chili powder',
#   'parsley',
#   'dry-roasted cashews'],
#  ['mangoes', 'vanilla bean', 'oranges', 'strawberries', 'ice cubes'],
#  ['garlic',
#   'leeks',
#   'salt and pepper',
#   'fresh rosemary',
#   'vegetable broth',
#   'olive oil',
#   'russet potatoes',
#   'white beans'],
#  ['boneless skinless chicken breasts',
#   'chicken stock',
#   'cardamom pods',
#   'coriander seed',
#   'garlic',
#   'soy yogurt',
#   'turmeric',
#   'cinnamon stick',
#   'black peppercorns',
#   'fresh ginger',
#   'chili powder',
#   'salt & freshly ground black pepper',
#   'cloves',
#   'onion',
#   'fresh coriander',
#   'ground cumin'],
#  ['garlic',
#   'dried oregano',
#   'salt',
#   'rump roast',
#   'beef bouillon cubes',
#   'black pepper',
#   'garlic powder',
#   'tabasco sauce',
#   'worcestershire sauce',
#   'dried thyme',
#   'boiling water'],
#  ['water', 'ginger', 'milk', 'honey', 'tea bag'],
#  ['sausage', 'ground beef', 'taco chips', 'velveeta cheese'],
#  ['tomato sauce',
#   'hamburger buns',
#   'white vinegar',
#   'ketchup',
#   'brown sugar',
#   'worcestershire sauce',
#   'steak seasoning',
#   'garlic powder',
#   'onion',
#   'bell pepper',
#   'lean ground beef',
#   'ground mustard'],
#  ['garlic',
#   'fresh corn kernels',
#   'salad greens',
#   'salt',
#   'rice wine vinegar',
#   'salad seasoning',
#   'gingerroot',
#   'beets',
#   'safflower oil',
#   'soy sauce',
#   'white mushrooms',
#   'honey',
#   'green peppers',
#   'green onions',
#   'carrot',
#   'pepper'],
#  ['pork chops',
#   'paprika',
#   'chicken broth',
#   'olive oil',
#   'dry white wine',
#   'fresh lemon juice',
#   'fennel seeds',
#   'onion'],
#  ['ramen noodles',
#   'eggs',
#   'black olives',
#   'red bell pepper',
#   'roma tomato',
#   'garlic powder',
#   'mozzarella cheese',
#   'italian seasoning',
#   'pepperoni'],
#  ['eggs',
#   'salt',
#   'oil',
#   'sunflower seeds',
#   'raisins',
#   'flour',
#   'natural bran',
#   'brown sugar',
#   'sesame seeds',
#   'molasses',
#   'milk',
#   'baking powder',
#   'baking soda'],
#  ['garlic',
#   'orange zest',
#   'black tea leaves',
#   'peppercorn',
#   'dry sherry',
#   'minced ginger',
#   'broiler',
#   'brown sugar',
#   'orange, juice of',
#   'low sodium soy sauce',
#   'onion'],
#  ['coriander seed',
#   'cardamom pods',
#   'peanut oil',
#   'fruit vinegar',
#   'turmeric',
#   'gingerroot',
#   'yoghurt',
#   'kaffir lime leaves',
#   'lemongrass',
#   'star anise',
#   'cloves'],
#  ['graham wafers',
#   'cool whip',
#   'blueberry pie filling',
#   'vanilla pudding mix'],
#  ['vinegar',
#   'tomato paste',
#   'cayenne pepper',
#   'canned jalapeno slices',
#   'salt',
#   'cornstarch',
#   'water',
#   'onion powder',
#   'sugar',
#   'chili powder',
#   'garlic powder',
#   'dried onion flakes'],
#  ['eggs',
#   'quick-cooking oats',
#   'vanilla',
#   'salt',
#   'cake flour',
#   'baking powder',
#   'raisins',
#   'brown sugar',
#   'shredded coconut',
#   'butter',
#   'nuts',
#   'baking soda',
#   'corn flakes'],
#  ['italian spices',
#   'olive oil',
#   'butter',
#   'kosher salt',
#   'pepper',
#   'whole turkey',
#   'onion'],
#  ['corn chips',
#   'chili with beans',
#   'salsa',
#   'sour cream',
#   'cheddar cheese',
#   'onion'],
#  ['salt',
#   'parsley sprig',
#   'cauliflower florets',
#   'egg',
#   'vegetable oil',
#   'pepper',
#   'plain breadcrumbs'],
#  ['walnuts',
#   'ground black pepper',
#   'olive oil',
#   'butter',
#   'kosher salt',
#   'mixed herbs',
#   'fresh green beans',
#   'onion'],
#  ['american cheese',
#   'ham',
#   'hamburger buns',
#   'sweet pickle relish',
#   'ketchup'],
#  ['carrot', 'sugar', 'bacon', 'tomato soup'],
#  ['eggs',
#   'ketchup',
#   'ground beef',
#   'brown sugar',
#   'seasoned bread crumbs',
#   'lipton onion soup mix'],
#  ['bulk pork sausage',
#   'oregano',
#   'ground pepper',
#   'worcestershire sauce',
#   'garlic powder',
#   'rye cocktail bread',
#   'ground chuck',
#   'velveeta cheese'],
#  ['glace cherries',
#   'pineapple in syrup',
#   'self-raising flour',
#   'egg',
#   'brown sugar',
#   'butter',
#   'milk',
#   'vanilla essence',
#   'caster sugar'],
#  ['apple',
#   'coconut milk',
#   'oat bran',
#   'flax seed oil',
#   'water',
#   'honey',
#   'greens',
#   'banana'],
#  ["hellmann's mayonnaise",
#   'hawaiian bread',
#   'knorr vegetable soup mix',
#   'sour cream',
#   'water chestnuts',
#   'green onion'],
#  ['brown rice',
#   'peas',
#   'sliced mushrooms',
#   'broccoli floret',
#   'olive oil',
#   'egg',
#   'soy sauce',
#   'carrot'],
#  ['reduced fat graham cracker crust',
#   'pumpkin pie spice',
#   'splenda sugar substitute',
#   'skim milk',
#   'egg whites',
#   'pumpkin'],
#  ['biscuits', 'beef stew'],
#  ['honey roasted peanuts',
#   'powdered sugar',
#   'unsalted butter',
#   'pure vanilla extract',
#   'semisweet chocolate',
#   'salt',
#   'heavy cream',
#   'creamy peanut butter',
#   'buttermilk',
#   'unsweetened cocoa',
#   'sugar',
#   'espresso',
#   'extra-large eggs',
#   'light corn syrup',
#   'baking soda',
#   'unbleached all-purpose flour'],
#  ['red bell pepper',
#   'garlic',
#   'corn kernel',
#   'short-grain brown rice',
#   'yellow cornmeal',
#   'chipotle chile in adobo',
#   'lime zest',
#   'olive oil',
#   'cilantro',
#   'onion',
#   'fresh lime juice',
#   'ground cumin'],
#  ['eggs',
#   'all-purpose flour',
#   'instant vanilla pudding',
#   'water',
#   'butter',
#   'whipped dessert topping mix'],
#  ['fresh ground pepper',
#   'white onions',
#   'hard-boiled eggs',
#   'salt',
#   'miracle whip',
#   'dijon mustard',
#   'white pepper',
#   'sugar',
#   'milk',
#   'mustard',
#   'celery',
#   'potato'],
#  ['white rice',
#   'cayenne pepper',
#   'dried basil',
#   'water',
#   'soy sauce',
#   'black pepper',
#   'chili powder',
#   'garlic powder',
#   'lemon juice',
#   'butter',
#   'tea bag',
#   'seasoning salt'],
#  ['eggs',
#   'feta cheese',
#   'roasted red pepper',
#   'fresh ground pepper',
#   'oregano',
#   'bisquick',
#   'frozen spinach',
#   'kalamata olive',
#   'milk',
#   'onion'],
#  ['eggs',
#   'cinnamon',
#   'all-purpose flour',
#   'ground cloves',
#   'salt',
#   'allspice',
#   'nutmeg',
#   'water',
#   'oil',
#   'pecans',
#   'sugar',
#   'pumpkin',
#   'baking powder',
#   'baking soda'],
#  ['long-grain rice',
#   'water',
#   'black pepper',
#   'boneless pork chops',
#   'vegetable oil',
#   'dry onion soup mix'],
#  ['boneless skinless chicken breasts',
#   'crushed tomatoes',
#   'rum',
#   'jamaican jerk spice',
#   'olive oil',
#   'clove',
#   'onion',
#   'allspice',
#   'onion flakes',
#   'sage',
#   'chili powder',
#   'cinnamon',
#   'thyme',
#   'brown sugar',
#   'habanero pepper',
#   'chives',
#   'garlic',
#   'nutmeg',
#   'red peppers',
#   'ginger',
#   'pepper',
#   'cayenne',
#   'lime juice'],
#  ['frozen limeade concentrate', 'ice', 'lime sorbet', 'mango', 'strawberry'],
#  ['ice',
#   'apple juice',
#   'non-fat vanilla frozen yogurt',
#   'strawberry',
#   'banana'],
#  ['garlic',
#   'coriander seed',
#   'fruit vinegar',
#   'hoisin sauce',
#   'sesame oil',
#   'yoghurt',
#   'fish sauce',
#   'red chile',
#   'cumin'],
#  ['eggs',
#   'unsweetened chocolate',
#   'all-purpose flour',
#   'candy cane',
#   'salt',
#   'vanilla',
#   'unsweetened cocoa powder',
#   'sugar',
#   'butter',
#   'peppermint oreos',
#   'peppermint extract'],
#  ['cooked chicken breasts',
#   'salt',
#   'pineapple tidbits',
#   'green grapes',
#   'white vinegar',
#   'orange juice',
#   'slivered almonds',
#   'mayonnaise',
#   'cooked rice',
#   'celery',
#   'mandarin oranges',
#   'canola oil'],
#  ['frozen peas',
#   'hard-boiled eggs',
#   'sweet pickle relish',
#   'mayonnaise',
#   'sugar',
#   'cheddar cheese',
#   'mustard',
#   'celery',
#   'seasoning salt',
#   'onion'],
#  ['chicken pieces',
#   'paprika',
#   'all-purpose flour',
#   'dry breadcrumbs',
#   'cayenne pepper',
#   'fresh garlic',
#   'oil',
#   'buttermilk',
#   'dijon mustard',
#   'hot pepper sauce',
#   'black pepper',
#   'garlic powder',
#   'butter',
#   'parmesan cheese',
#   'dried thyme',
#   'seasoning salt',
#   'onion'],
#  ['louisiana hot sauce',
#   'cinnamon',
#   'fresh garlic',
#   'allspice',
#   'hoisin sauce',
#   'ketchup',
#   'sugar',
#   'lemon juice',
#   'pepper',
#   'habanero sauce',
#   'pork baby back ribs',
#   'seasoning salt'],
#  ['red bell pepper',
#   'garlic',
#   'peas',
#   'rotini pasta',
#   'salt',
#   'spaghetti sauce',
#   'chicken leg',
#   'celery',
#   'corn',
#   'italian seasoning',
#   'carrot',
#   'beef stock',
#   'pepper',
#   'onion'],
#  ['margarine',
#   'salt and pepper',
#   'stove top stuffing mix monterey style with mushroom and onion',
#   'spinach dip',
#   'sour cream',
#   'pam cooking spray',
#   'mexicorn whole kernel corn',
#   'aluminum foil'],
#  ['cooking onions', 'white vinegar', 'pickling spices'],
#  ['cooked pasta',
#   'peas',
#   'chicken broth',
#   'egg',
#   'soy sauce',
#   'cooked chicken',
#   'carrot'],
#  ['cake crumbs', 'cool whip', 'cream cheese', 'mixed fruit'],
#  ['eggs',
#   'lemon flavoring',
#   'squash',
#   'flour',
#   'sugar',
#   'butter',
#   'pie crust',
#   'cool whip',
#   'coconut flavoring'],
#  ['ground veal',
#   'dried parsley flakes',
#   'ground cinnamon',
#   'salt',
#   'ground cloves',
#   'dijon mustard',
#   'cream of mushroom soup',
#   'black pepper',
#   'garlic powder',
#   'dried onion flakes'],
#  ['oregano',
#   'olive oil',
#   'black pepper',
#   'red onions',
#   'chicken stock',
#   'brown rice',
#   'tabasco sauce',
#   'okra',
#   'gumbo file',
#   'mexican-style stewed tomatoes with jalapeno peppers',
#   'old bay seasoning',
#   'parsley',
#   'catfish nuggets',
#   'small shrimp',
#   'garlic',
#   'red wine vinegar',
#   'tomato soup',
#   'lemon',
#   'seafood'],
#  ['eggs',
#   'bacon',
#   'paprika',
#   'white vinegar',
#   'mild cheddar cheese',
#   'sour cream',
#   'fresh chives'],
#  ['dried parsley',
#   'dried oregano',
#   'garlic',
#   'salt',
#   'dried basil',
#   'garlic salt',
#   'white vinegar',
#   'olive oil',
#   'lemon juice',
#   'chicken breasts',
#   'cracked black pepper',
#   'sandwich buns'],
#  ['eggs',
#   'cinnamon',
#   'margarine',
#   'vanilla',
#   'salt',
#   'nutmeg',
#   'quick oats',
#   'flour',
#   'cream',
#   'brown sugar',
#   'shredded coconut',
#   'nuts',
#   'baking soda',
#   'boiling water'],
#  ['marshmallows', 'rice krispies', 'butter'],
#  ['cool whip topping',
#   'frozen limeade concentrate',
#   'cream cheese',
#   'orange juice'],
#  ['garlic',
#   'corn chips',
#   'salt',
#   'tuna',
#   'lettuce',
#   'pitted ripe olives',
#   'avocado',
#   'sour cream',
#   'lemon juice',
#   'sugar',
#   'chili powder',
#   'cheddar cheese',
#   'tabasco sauce',
#   'green onion',
#   'tomato',
#   'salad oil'],
#  ['garlic',
#   'baking potatoes',
#   'coriander',
#   'ground cumin',
#   'low-fat yogurt',
#   'olive oil',
#   'salt & freshly ground black pepper',
#   'fresh coriander',
#   'tahini',
#   'chickpeas'],
#  ['eggs',
#   'salt',
#   'yellow cornmeal',
#   'buttermilk',
#   'mayonnaise',
#   'sugar',
#   'vegetable oil',
#   'baking powder'],
#  ['apple',
#   'gingerroot',
#   'green cabbage',
#   'sesame oil',
#   'soy sauce',
#   'maple syrup',
#   'rice vinegar',
#   'red cabbage',
#   'carrot',
#   'green onion'],
#  ['long-grain rice',
#   'turmeric',
#   'water',
#   'black pepper',
#   'orzo pasta',
#   'garlic powder',
#   'chicken soup powder',
#   'canola oil'],
#  ['jalapeno pepper',
#   'crushed tomatoes',
#   'chipotle chiles in adobo',
#   'chicken broth',
#   'chicken breast',
#   'salt and pepper',
#   'white onion',
#   'ear of corn',
#   'celery ribs',
#   'avocado',
#   'fresh cilantro',
#   'green bell pepper',
#   'cumin'],
#  ['eggplant',
#   'egg white',
#   'fat free mozzarella cheese',
#   'salt',
#   'dried basil',
#   'reduced-fat parmesan cheese',
#   'fiber one cereal',
#   'garlic powder',
#   'pepper',
#   'italian-style tomato sauce'],
#  ['white rice', 'eggs', 'beef gravy', 'ground beef', 'onion'],
#  ['garlic',
#   'ham bone',
#   'tomatoes and green chilies',
#   'ham',
#   'salt',
#   'water',
#   'ham soup base',
#   'celery ribs',
#   'black-eyed peas',
#   'onion',
#   'carrot',
#   'great northern beans',
#   'pinto beans',
#   'pepper',
#   'beans',
#   'navy beans'],
#  ['red bell pepper',
#   'garlic',
#   'feta cheese',
#   'cider vinegar',
#   'fresh dill',
#   'light mayonnaise',
#   'skinless chicken breast half'],
#  ['cheese ravioli',
#   'garlic salt',
#   'spaghetti sauce',
#   'mozzarella cheese',
#   'italian seasoning',
#   'lean ground beef'],
#  ['chicken pieces',
#   'barbecue sauce',
#   'lemon juice',
#   'worcestershire sauce',
#   'orange marmalade'],
#  ['paprika',
#   'ground black pepper',
#   'coriander',
#   'salt',
#   'turmeric',
#   'onion powder',
#   'garlic powder',
#   'ground red pepper'],
#  ['black olives',
#   'mexican blend cheese',
#   'green pepper',
#   'lettuce',
#   'sour cream',
#   'taco seasoning mix',
#   'mayonnaise',
#   'cream cheese',
#   'green onion',
#   'tomato'],
#  ['minced clams',
#   'paprika',
#   'green bell peppers',
#   'sharp cheddar cheese',
#   'worcestershire sauce',
#   'tabasco sauce',
#   'green onions'],
#  ['red bell pepper',
#   'eggplants',
#   'red onion',
#   'oregano',
#   'shrimp',
#   'spaghetti squash',
#   'yellow bell pepper',
#   'olive oil',
#   'olives'],
#  ['semisweet chocolate', 'heavy cream', "confectioners' sugar", 'butter'],
#  ['cherry pie filling',
#   'small marshmallow',
#   'pecans',
#   'sweetened condensed milk',
#   'frozen whipped topping',
#   'crushed pineapple'],
#  ['bacon',
#   'salt',
#   'oil',
#   'sour cream',
#   'cheddar cheese',
#   'green onions',
#   'potato'],
#  ['pizza sauce',
#   'salt',
#   'plain flour',
#   'boneless eye of round beef steak',
#   'mozzarella cheese',
#   'parmesan cheese',
#   'pepper',
#   'canola oil',
#   'onion'],
#  ["campbell's golden mushroom soup",
#   'all-purpose flour',
#   'ground black pepper',
#   'oregano',
#   'bacon grease',
#   'boneless country-style ribs',
#   'soup mix',
#   'seasoning salt'],
#  ['eggs', 'flour', 'sugar', 'milk', 'butter', 'fruit'],
#  ['cardamom',
#   'crescent roll dough',
#   'ground cinnamon',
#   'sugar',
#   'honey',
#   'butter',
#   'baby carrots',
#   'apples'],
#  ['garlic salt',
#   'olive oil',
#   'refrigerated biscuits',
#   'mozzarella cheese',
#   'italian seasoning'],
#  ['salt', 'active dry yeast', 'water', 'flour', 'sugar', 'milk', 'butter'],
#  ['eggs',
#   'whipping cream',
#   'all-purpose flour',
#   'vanilla',
#   'salt',
#   'egg yolks',
#   'sugar',
#   'butter',
#   'cream cheese',
#   'lemon peel',
#   'egg yolk'],
#  ['country-style dijon mustard',
#   'chili sauce',
#   'honey',
#   'little smokies sausages'],
#  ['white rum',
#   'bacardi dark rum',
#   'orange juice',
#   'grenadine',
#   'orgeat syrup',
#   'orange curacao',
#   'pineapple juice',
#   'prepared sweet-and-sour mix',
#   "meyer's dark rum"],
#  ['balsamic vinaigrette',
#   'pork chops',
#   'minute white rice',
#   'dried thyme leaves',
#   'red apples',
#   'water',
#   'sliced mushrooms',
#   'condensed chicken broth',
#   'onion'],
#  ['tomato paste',
#   'green bell peppers',
#   'prepared mustard',
#   'orange juice',
#   'red bell peppers',
#   'plain nonfat yogurt',
#   'reduced-calorie mayonnaise',
#   'chili powder',
#   'horseradish',
#   'onion',
#   'fresh ground black pepper'],
#  ['cold water',
#   'lemon gelatin',
#   'grapes',
#   'nectarines',
#   'strawberries',
#   'orange juice',
#   'strawberry gelatin',
#   'peach gelatin',
#   'cool whip'],
#  ['cayenne pepper',
#   'salt',
#   'ground marjoram',
#   'fat-free evaporated milk',
#   'dried sage',
#   'poultry seasoning',
#   'onion flakes',
#   'flour',
#   'brown sugar',
#   'skim milk',
#   'garlic powder',
#   'lean ground turkey',
#   'pepper'],
#  ['red bell pepper',
#   'ground black pepper',
#   'sweet onion',
#   'ground beef',
#   'egg',
#   'barbecue sauce',
#   'garlic powder',
#   'french-fried onions',
#   'seasoning salt',
#   'cooking spray'],
#  ['cold water',
#   'italian salad dressing',
#   'garlic',
#   'crushed tomatoes',
#   'tomato sauce',
#   'salt',
#   'bay leaf',
#   'water',
#   'beef stew meat',
#   'beef bouillon granules',
#   'green pepper',
#   'flour',
#   'beef broth',
#   'carrot',
#   'pepper',
#   'onion',
#   'potato'],
#  ['garlic',
#   'kidney beans',
#   'salt and pepper',
#   'water',
#   'carrot',
#   'curry powder',
#   'garam masala',
#   'tabasco sauce',
#   'ghee',
#   'onion',
#   'potato'],
#  ['ice cube', 'ouzo', 'orange slice', 'orange juice'],
#  ['half-and-half',
#   'salt',
#   'old bay seasoning',
#   'red pepper',
#   'cream of celery soup',
#   'cream of mushroom soup',
#   'milk',
#   'sherry wine',
#   'pepper',
#   'crabmeat'],
#  ['dry sherry',
#   'salt and pepper',
#   'shallot',
#   'skim milk',
#   'egg whites',
#   'panko breadcrumbs',
#   'onion',
#   'bacon',
#   'ketchup',
#   'flour',
#   'mixed mushrooms',
#   'ground turkey',
#   'ground sirloin',
#   'brown sugar',
#   'worcestershire sauce',
#   'ground pork',
#   'tomato paste',
#   'unsalted butter',
#   'yellow mustard',
#   'chicken broth',
#   'sherry wine vinegar',
#   'fresh parsley'],
#  ['garlic',
#   'lemon, zest of',
#   'olive oil',
#   'lemon, juice of',
#   'rosemary',
#   'new potatoes'],
#  ['garlic',
#   'dry breadcrumbs',
#   'frozen corn',
#   'oil',
#   'salsa',
#   'flour',
#   'chili powder',
#   'black beans',
#   'onion',
#   'green chili sauce',
#   'cumin'],
#  ['red bell pepper',
#   'fresh ground pepper',
#   'salt',
#   'baby shrimp',
#   'sour cream',
#   'mayonnaise',
#   'cheese-filled tortellini',
#   'fresh spinach',
#   'caesar salad dressing',
#   'green onions',
#   'ripe olives'],
#  ['garlic',
#   'spike seasoning',
#   'salt and pepper',
#   'cheese',
#   'olive oil',
#   'worcestershire sauce',
#   'fresh parsley',
#   'celery',
#   'ground turkey',
#   'tomato',
#   'onion',
#   'bell peppers'],
#  ['eggs',
#   'graham cracker crumbs',
#   'cinnamon',
#   'heavy whipping cream',
#   'splenda granular',
#   'vanilla',
#   'cornstarch',
#   'nutmeg',
#   'slivered almonds',
#   'sour cream',
#   'lemon juice',
#   'butter',
#   'cream cheese'],
#  ['chicken pieces', 'oil', 'ketchup', 'soy sauce', 'smooth peanut butter'],
#  ['celery seed',
#   'salt',
#   'chicken broth',
#   'dried sage',
#   'breadcrumbs',
#   'parsley',
#   'butter',
#   'pepper',
#   'dried thyme',
#   'onion'],
#  ['garlic',
#   'fresh oregano',
#   'salt and pepper',
#   'fresh basil',
#   'olive oil',
#   'tomato'],
#  ['eggs',
#   'instant chocolate pudding mix',
#   'coconut milk',
#   'whipping cream',
#   'salt',
#   "devil's food cake mix",
#   'cornstarch',
#   'water',
#   'coco lopez',
#   'sugar',
#   'shredded coconut',
#   'bittersweet chocolate',
#   'vegetable oil',
#   'kahlua'],
#  ['old bay seasoning', 'plain tomato juice'],
#  ['garlic',
#   'chicken stock',
#   'canned unsweetened coconut milk',
#   'cinnamon',
#   'coriander',
#   'bay leaf',
#   'pumpkin seeds',
#   'sweetened condensed milk',
#   'ground allspice',
#   'shallot',
#   'curry powder',
#   'butter',
#   'ground nutmeg',
#   'onion',
#   'carrot',
#   'banana',
#   'canned pumpkin'],
#  ['garlic',
#   'pepper',
#   'salt',
#   'whole wheat bread',
#   'mayonnaise',
#   'parmesan cheese',
#   'ghee',
#   'zucchini',
#   'tomato'],
#  ['sausage',
#   'diced tomatoes with green chilies',
#   'cream cheese',
#   'diced green chilies'],
#  ['garlic',
#   'tomato sauce',
#   'diced tomatoes',
#   'chilies',
#   'white onion',
#   'red pepper',
#   'extra lean ground beef',
#   'black beans',
#   'beef broth',
#   'chili seasoning mix',
#   'chili beans with chipotle pepper',
#   'kidney beans'],
#  ['eggs',
#   'powdered sugar',
#   'all-purpose flour',
#   'ground cinnamon',
#   'salt',
#   'pecans',
#   'vanilla',
#   'pineapple chunk',
#   'sugar',
#   'ground nutmeg',
#   'butter',
#   'cream cheese',
#   'baking powder',
#   'carrot',
#   'baking soda'],
#  ['flour', 'black pepper', 'milk', 'butter', 'dried beef'],
#  ['turnips',
#   'split peas',
#   'salt',
#   'water',
#   'carrot',
#   'pepper',
#   'onion',
#   'potato'],
#  ['salad dressing',
#   'romaine lettuce',
#   'red onion',
#   'steak spice',
#   'corn tortilla strips',
#   'hard-boiled eggs',
#   'cherry tomatoes',
#   'buttermilk',
#   'ketchup',
#   'cumin',
#   'sour cream',
#   'sugar',
#   'lemon juice',
#   'roasted garlic and red pepper spice mix',
#   'curry powder',
#   'granulated garlic',
#   'cooked bacon'],
#  ['fresh thyme',
#   'cayenne pepper',
#   'ground cumin',
#   'salt',
#   'bibb lettuce',
#   'hamburger buns',
#   'white pepper',
#   'mayonnaise',
#   'worcestershire sauce',
#   'papaya',
#   'cheddar cheese',
#   'lean ground beef',
#   'tomato',
#   'onion'],
#  ['zucchini',
#   'eggs',
#   'cinnamon',
#   'fat',
#   'walnuts',
#   'vanilla',
#   'salt',
#   'flour',
#   'sugar',
#   'baking soda'],
#  ['lemon-flavored vodka',
#   'apple',
#   'lemonade',
#   'peach',
#   'peach schnapps',
#   'lime',
#   'dry white wine',
#   'lemon juice',
#   'lemon',
#   'peach puree',
#   'lime juice'],
#  ['hot sauce',
#   'prepared mustard',
#   'salt and pepper',
#   'ketchup',
#   'barbecue sauce',
#   'brown sugar',
#   'ground moose',
#   'onion'],
#  ['garlic',
#   'eggs',
#   'dry breadcrumbs',
#   'salt',
#   'sweet pepper',
#   'cornstarch',
# ...
#   'vital wheat gluten'],
#  ['oat bran',
#   'wheat germ',
#   'salt',
#   'yeast',
#   'water',
#   'whole wheat flour',
#   'egg',
#   'sugar',
#   'white whole wheat flour',
#   'vegetable oil',
#   'vital wheat gluten'],
#  ['yeast',
#   'whole wheat flour',
#   'warm water',
#   'kosher salt',
#   'vital wheat gluten'],
#  ['salt', 'yeast', 'water', 'whole wheat flour', 'egg', 'honey', 'applesauce'],
#  ['salt',
#   'water',
#   'whole wheat flour',
#   'egg',
#   'instant yeast',
#   'honey',
#   'vital wheat gluten',
#   'canola oil'],
#  ['salt',
#   'low-fat buttermilk',
#   'flax seed meal',
#   'granulated sugar',
#   'whole wheat flour',
#   'egg whites',
#   'baking powder',
#   'baking soda',
#   'canola oil'],
#  ['cinnamon',
#   'salt',
#   'vanilla',
#   'water',
#   'whole wheat flour',
#   'honey',
#   'butter',
#   'baking powder',
#   'baking soda',
#   'turbinado sugar'],
#  ['salt',
#   'baking powder',
#   'whole wheat flour',
#   'molasses',
#   'raisins',
#   'egg',
#   'butter',
#   'low-fat buttermilk',
#   'baking soda'],
#  ['vanilla',
#   'whole wheat flour',
#   'sugar',
#   'egg',
#   'low-fat milk',
#   'baking powder',
#   'baking soda',
#   'canola oil',
#   'fruit'],
#  ['peanut butter',
#   'eggs',
#   'salt',
#   'whole wheat flour',
#   'brown sugar',
#   'milk',
#   'butter',
#   'baking powder'],
#  ['salt', 'water', 'whole wheat flour', 'olive oil', 'instant yeast', 'honey'],
#  ['eggs', 'salt', 'yeast', 'water', 'whole wheat flour', 'olive oil', 'honey'],
#  ['gluten',
#   'whole wheat flour',
#   'sour cream',
#   'butter',
#   'kosher salt',
#   'milk',
#   'baking powder',
#   'baking soda'],
#  ['oatmeal',
#   'cinnamon',
#   'salt',
#   'oil',
#   'vanilla',
#   'cocoa powder',
#   'water',
#   'whole wheat flour',
#   'raisins',
#   'powdered eggs',
#   'sugar',
#   'egg',
#   'molasses',
#   'powdered milk',
#   'baking powder',
#   'fruit'],
#  ['zucchini',
#   'eggs',
#   'cinnamon',
#   'vanilla',
#   'salt',
#   'baking powder',
#   'whole wheat flour',
#   'sugar',
#   'vegetable oil',
#   'nuts',
#   'baking soda'],
#  ['table salt',
#   'water',
#   'cooking oil',
#   'whole wheat flour',
#   'instant yeast',
#   'honey'],
#  ['all-purpose flour',
#   'vanilla',
#   'sugar',
#   'egg',
#   'bananas',
#   'butter',
#   'nuts',
#   'baking soda'],
#  ['chocolate cake mix',
#   'caramels',
#   'butter',
#   'nuts',
#   'evaporated milk',
#   'chocolate chips'],
#  ['walnuts',
#   'salt',
#   'raisins',
#   'flour',
#   'sugar',
#   'egg',
#   'bananas',
#   'baking soda',
#   'canola oil'],
#  ['thousand island dressing', 'cream cheese'],
#  ['mayonnaise', 'chili sauce', 'sweet pickle relish', 'onion powder'],
#  ['cream of tartar',
#   'rolled oats',
#   'white sugar',
#   'margarine',
#   'vanilla',
#   'oil',
#   'flour',
#   'egg',
#   'brown sugar',
#   'flaked coconut',
#   'rice krispies',
#   'baking soda',
#   'chocolate chips'],
#  ['garlic',
#   'mushrooms',
#   'plain yogurt',
#   'bacon',
#   'hardboiled egg',
#   'baby spinach',
#   'buttermilk',
#   'white pepper',
#   'unsalted sunflower seeds',
#   'fresh lemon juice',
#   'sugar'],
#  ['frozen peas',
#   'fresh broccoli',
#   'red onion',
#   'bacon',
#   'cauliflower',
#   'cherry tomatoes',
#   'green pepper',
#   'lettuce',
#   'fresh mushrooms',
#   'mayonnaise',
#   'sugar',
#   'italian seasoning'],
#  ['onion salt',
#   'paprika',
#   'celery salt',
#   'marjoram leaves',
#   'ground oregano',
#   'ground allspice',
#   'basil leaves',
#   'black pepper',
#   'chili powder',
#   'garlic powder',
#   'rubbed sage'],
#  ['fresh jalapeno', 'beer', 'ice', 'vodka'],
#  ['garlic',
#   'bacon',
#   'low-fat mayonnaise',
#   'oil',
#   'anchovy fillets',
#   'baby spinach',
#   'dijon mustard',
#   'fresh mushrooms',
#   'olive oil',
#   'lemon juice',
#   'worcestershire sauce',
#   'parmesan cheese',
#   'miracle whip light',
#   'french bread',
#   'extra virgin olive oil'],
#  ['mexican blend cheese',
#   'eggs',
#   'ricotta cheese',
#   'salt',
#   'ground pepper',
#   'jumbo pasta shells',
#   'parsley flakes',
#   'spaghetti sauce',
#   'ground beef',
#   'dried italian seasoning',
#   'mozzarella cheese',
#   'italian cheese blend',
#   'parmesan-romano cheese mix'],
#  ['white flour',
#   'salt',
#   'oil',
#   'bread machine yeast',
#   'water',
#   'whole wheat flour',
#   'brown sugar'],
#  ['whole corn',
#   'salt and pepper',
#   'water',
#   'butter',
#   'cream-style corn',
#   'evaporated milk',
#   'onion',
#   'potato'],
#  ['flat leaf parsley',
#   'black pepper',
#   'italian seasoned breadcrumbs',
#   'orecchiette',
#   'prosciutto',
#   'kosher salt',
#   'parmesan cheese',
#   'extra virgin olive oil'],
#  ['salt', 'olive oil', 'cumin seeds', 'tomato', 'fresh ground black pepper'],
#  ['vanilla',
#   'salted peanuts',
#   'butter',
#   'molasses',
#   'baking soda',
#   'corn syrup',
#   'white sugar'],
#  ['plain yogurt',
#   'cinnamon',
#   'salt',
#   'bulgar wheat',
#   'lean ground beef',
#   'onion'],
#  ['oil',
#   'apple pie filling',
#   'instant vanilla pudding',
#   'water',
#   'yellow cake mix',
#   'egg'],
#  ['boneless skinless chicken breasts', 'italian dressing', 'potato', 'carrot'],
#  ['eggs', 'cinnamon rolls', 'chocolate milk'],
#  ['eggs',
#   'vanilla',
#   'salt',
#   'flour',
#   'butter',
#   'milk',
#   'baking powder',
#   'white sugar'],
#  ['garlic',
#   'leeks',
#   'salt',
#   'ham',
#   'water',
#   'thyme',
#   'soup mix',
#   'worcestershire sauce',
#   'carrot',
#   'celery',
#   'basil',
#   'pepper'],
#  ['chili sauce',
#   'salt and pepper',
#   'saltine crackers',
#   'egg',
#   'ground beef',
#   'worcestershire sauce',
#   'milk',
#   'garlic powder',
#   'onion',
#   'bell peppers'],
#  ['garlic',
#   'prepared horseradish',
#   'unsalted butter',
#   'limes, juice of',
#   'salt and pepper',
#   'sour cream',
#   'beef tenderloin',
#   'worcestershire sauce',
#   'aluminum foil'],
#  ['eggs',
#   'cinnamon',
#   'powdered sugar',
#   'walnuts',
#   'margarine',
#   'salt',
#   'oil',
#   'flour',
#   'sugar',
#   'cream cheese',
#   'pineapple',
#   'baking powder',
#   'carrot',
#   'baking soda'],
#  ['celery seed',
#   'mustard seeds',
#   'turmeric',
#   'salt',
#   'water',
#   'white vinegar',
#   'sugar',
#   'cabbage',
#   'carrot',
#   'onion'],
#  ['vinegar',
#   'pickling spices',
#   'salt',
#   'water',
#   'pickling cucumbers',
#   'sugar',
#   'alum'],
#  ['vinegar', 'pickling spices', 'cucumbers', 'sugar', 'alum', 'canning salt'],
#  ['eggs',
#   'coconut',
#   'cinnamon',
#   'powdered sugar',
#   'margarine',
#   'salt',
#   'oil',
#   'allspice',
#   'ground cloves',
#   'vanilla',
#   'raisins',
#   'flour',
#   'sugar',
#   'cream cheese',
#   'nuts',
#   'carrot',
#   'baking soda'],
#  ['nutmeats', 'cream', 'maple syrup', 'butter', 'lemon extract'],
#  ['v8 vegetable juice',
#   'deli ham',
#   'salt',
#   'chicken broth',
#   'raw rice',
#   'water',
#   'beans',
#   'chicken bouillon cubes',
#   'lemon juice',
#   'parsley',
#   'carrot',
#   'celery',
#   'basil',
#   'tomato',
#   'onion'],
#  ['tortillas',
#   'monterey jack cheese',
#   'hormel chili without beans',
#   'refried beans'],
#  ['dried parsley',
#   'ham hocks',
#   'garlic',
#   'dried rosemary',
#   'salt',
#   'whole tomatoes',
#   '15 bean soup mix',
#   'celery leaves',
#   'black pepper',
#   'olive oil',
#   'chicken bouillon cubes',
#   'onion'],
#  ['garlic',
#   'ham bone',
#   'steak sauce',
#   'diced tomatoes',
#   'water',
#   '15 bean soup mix',
#   'black pepper',
#   'worcestershire sauce',
#   'beef bouillon paste',
#   'smoked sausage'],
#  ['garlic',
#   'smoked paprika',
#   'paprika',
#   'cayenne pepper',
#   'oregano',
#   'ham',
#   'salt',
#   'water',
#   'thyme',
#   'olive oil',
#   'black pepper',
#   'chili powder',
#   'lemon',
#   'carrot',
#   'dried beans',
#   'onion',
#   'condensed tomato soup'],
#  ['eggs',
#   'margarine',
#   'flour',
#   'sugar',
#   'liquid honey',
#   'sour cream',
#   'plain sweet biscuit crumbs',
#   'honey',
#   'baking soda',
#   'ground walnuts'],
#  ['garlic',
#   'chicken stock',
#   'salt and pepper',
#   'lemon juice',
#   'halibut steaks',
#   'fresh parsley',
#   'capers',
#   'fresh tarragon',
#   'fresh chives'],
#  ['tomato paste',
#   'oil',
#   'water',
#   'boneless sirloin steak',
#   'peas and carrots',
#   'lipton beefy mushroom soup mix',
#   'new potatoes'],
#  ['tomatoes and green chilies',
#   'frozen corn kernels',
#   'ground beef',
#   'black beans',
#   'taco seasoning'],
#  ['minute white rice',
#   'water',
#   'ketchup',
#   'cheddar cheese',
#   'mustard',
#   'lean ground beef'],
#  ['white rice',
#   'diced tomatoes',
#   'chili with beans',
#   'water',
#   'ground beef',
#   'velveeta cheese'],
#  ['condensed cream of chicken soup',
#   'paprika',
#   'ground pepper',
#   'instant rice',
#   'water',
#   'boneless skinless chicken breast halves',
#   'vegetable oil'],
#  ['chicken breast tenders',
#   'fajita seasoning mix',
#   'cheese',
#   'lime',
#   'olive oil',
#   'sour cream',
#   'pico de gallo',
#   'pepper',
#   'tortilla',
#   'onion'],
#  ['chicken broth',
#   'mexicorn',
#   'salsa',
#   'tortilla chips',
#   'sour cream',
#   'chicken',
#   'cheddar cheese',
#   'kidney beans'],
#  ['boneless skinless chicken breasts',
#   'condensed cream of chicken soup',
#   'broccoli florets',
#   'milk',
#   'vegetable oil',
#   'minute rice'],
#  ['salt',
#   'kidney beans',
#   'salsa',
#   'chili powder',
#   'stewed tomatoes',
#   'ground turkey',
#   'pinto beans',
#   'onion',
#   'cumin'],
#  ['chili with beans',
#   'water',
#   'cheese',
#   'sour cream',
#   'flour tortillas',
#   'white minute rice'],
#  ['macaroni & cheese dinner mix',
#   'water',
#   'ketchup',
#   'chili powder',
#   'lean ground beef',
#   'broccoli'],
#  ['cinnamon',
#   'salt',
#   'allspice',
#   'brown sugar',
#   'pepper',
#   'clove',
#   'tomato',
#   'onion'],
#  ['garlic',
#   'grape tomatoes',
#   'fresh oregano',
#   'fresh parmesan cheese',
#   'crushed red pepper flakes',
#   'pappardelle pasta',
#   'fresh basil',
#   'sun-dried tomato packed in oil',
#   'pepper',
#   'roasted cashews'],
#  ['garlic',
#   'tomato sauce',
#   'low sodium chicken broth',
#   'ground cumin',
#   'salt',
#   'chipotle chile in adobo',
#   'ground coriander',
#   'onion'],
#  ['sugar substitute',
#   'fat free cream cheese',
#   'fat-free whipped topping',
#   'reduced fat graham cracker crust'],
#  ['red onion',
#   'pesto sauce',
#   'fresh linguine',
#   'pine nuts',
#   'lemon juice',
#   'fresh spinach',
#   'parmesan cheese',
#   'tomato'],
#  ['garlic',
#   'chicken broth',
#   'oil',
#   'salt and pepper',
#   'flour',
#   'boneless skinless chicken breast halves',
#   'lemon juice',
#   'butter'],
#  ['garlic',
#   'romaine lettuce',
#   'feta cheese',
#   'salt',
#   'celery ribs',
#   'scallion',
#   'fresh lemon juice',
#   'of fresh mint',
#   'cracked black pepper',
#   'fresh parsley',
#   'garbanzo beans',
#   'tomato',
#   'extra virgin olive oil'],
#  ['italian dressing',
#   'oil',
#   'instant rice',
#   'boneless skinless chicken breast',
#   'assorted fresh vegetables',
#   'reduced-sodium fat-free chicken broth'],
#  ['powdered sugar',
#   'graham cracker crumbs',
#   'instant lemon pudding',
#   'cream cheese',
#   'butter',
#   'milk'],
#  ['peanut butter', "confectioners' sugar", 'vanilla', 'cocoa', 'butter'],
#  ['italian salad dressing',
#   'smoked turkey breast',
#   'parmesan cheese',
#   'tomato',
#   'spaghetti'],
#  ['chicken bouillon cube',
#   'pork tenderloin',
#   'oil',
#   'water',
#   'soy sauce',
#   'frozen mixed vegetables',
#   'minute rice'],
#  ['minute white rice',
#   'oil',
#   'water',
#   'green pepper',
#   'hot pepper sauce',
#   'chicken bouillon cubes',
#   'onion',
#   'kidney beans'],
#  ['half-and-half cream',
#   'fettuccine',
#   'garlic salt',
#   'shrimp',
#   'black pepper',
#   'parmesan cheese',
#   'bacon bits',
#   'baby peas'],
#  ['garlic',
#   'extra virgin olive oil',
#   'angel hair pasta',
#   'white wine',
#   'butter',
#   'frozen shrimp',
#   'salt & pepper',
#   'onion'],
#  ['sweet green pepper',
#   'hamburger',
#   'sliced mushrooms',
#   'hot chili flakes',
#   'sweet red pepper',
#   'garlic flakes',
#   'tomato sauce & mushrooms',
#   'celery',
#   'jalapenos',
#   'onion'],
#  ['garlic',
#   'asparagus',
#   'salt',
#   'chicken broth',
#   'white pepper',
#   'boneless skinless chicken breast',
#   'fresh ginger',
#   'soy sauce',
#   'rice vinegar',
#   'chili flakes',
#   'onion'],
#  ['half-and-half',
#   'hot sauce',
#   'unsalted butter',
#   'elbow macaroni',
#   'extra-sharp cheddar cheese',
#   'dijon mustard',
#   'kosher salt',
#   'fresh ground black pepper'],
#  ['water',
#   'fresh mushrooms',
#   'flour',
#   'sour cream',
#   'dry onion soup mix',
#   'butter',
#   'round steak'],
#  ['minute white rice',
#   'mexican blend cheese',
#   'water',
#   'lettuce',
#   'extra lean ground beef',
#   'taco seasoning mix',
#   'chopped tomatoes'],
#  ['sunflower oil',
#   'lime, juice and zest of',
#   'tiger shrimp',
#   'pak choi',
#   'dark soy sauce',
#   'baby spinach',
#   'cornflour',
#   'water',
#   'thai fish sauce',
#   'sweet chili sauce'],
#  ['minute rice', 'raisins', 'milk', 'vanilla instant pudding mix'],
#  ['fire-roasted tomatoes', 'salsa', 'water', 'black beans', 'kidney beans'],
#  ['margarine', 'fettuccine pasta', 'cream cheese', 'parmesan cheese', 'milk'],
#  ['dried fruits',
#   'salt',
#   'vanilla',
#   'water',
#   'quick oats',
#   'sugar',
#   'milk',
#   'honey'],
#  ['garlic',
#   'ham hocks',
#   'pepper',
#   'tomato sauce',
#   'diced tomatoes',
#   'water',
#   '15 bean mix',
#   'chicken bouillon cubes',
#   'carrot',
#   'celery',
#   'seasoning salt',
#   'onion',
#   'bay leaves'],
#  ['dark red kidney beans',
#   'corn chips',
#   'salt and pepper',
#   'whole tomatoes',
#   'water',
#   'sharp cheddar cheese',
#   'ketchup',
#   'green bell pepper',
#   'ground beef',
#   'canned green beans',
#   'red pepper flakes',
#   'vegetable oil',
#   'chili seasoning mix',
#   'black-eyed peas',
#   'onion'],
#  ['garlic',
#   'chicken liver',
#   'ground black pepper',
#   'salt',
#   'heavy cream',
#   'thyme',
#   'sage',
#   'brandy',
#   'butter',
#   'onion',
#   'marjoram'],
#  ['cayenne pepper',
#   'diced tomatoes',
#   'salt',
#   'oregano',
#   'sliced mushrooms',
#   'sour cream',
#   'chili powder',
#   'chili beans',
#   'lean ground beef',
#   'onion',
#   'cumin'],
#  ['strawberries',
#   'sugar',
#   'cool whip topping',
#   'jello instant vanilla pudding mix',
#   'frozen pound cake',
#   'orange liqueur',
#   'strawberry',
#   'white chocolate baking squares'],
#  ['dijon mustard',
#   'boneless skinless chicken breast halves',
#   'fresh lemon juice',
#   'worcestershire sauce',
#   'pepper',
#   'dried tarragon'],
#  ['chicken broth', 'salt and pepper', 'basmati rice'],
#  ['black olives',
#   'green enchilada sauce',
#   'cream of chicken soup',
#   'salsa',
#   'tortilla chips',
#   'lettuce',
#   'sour cream',
#   'cooked chicken',
#   'monterey jack cheese',
#   'green onion',
#   'tomato'],
#  ['pasta', 'garlic', 'butter', 'parmesan cheese'],
#  ['garlic',
#   'dried oregano',
#   'feta cheese',
#   'large shrimp',
#   'old bay seasoning',
#   'olive oil',
#   'parsley',
#   'pepper',
#   'tomato'],
#  ['herbs',
#   'lemon, zest of',
#   'red onion',
#   'unsalted butter',
#   'large shrimp',
#   'cherry tomatoes',
#   'corn kernels',
#   'olive oil',
#   'salt & freshly ground black pepper',
#   'snap peas',
#   'zucchini'],
#  ['garlic',
#   'dried oregano',
#   'scallions',
#   'salt and pepper',
#   'vegetable broth',
#   'olive oil',
#   'fresh lemon juice',
#   'white beans',
#   'parmesan cheese'],
#  ['garlic',
#   'chicken stock',
#   'oregano',
#   'water',
#   'beans',
#   'italian sausage',
#   'carrot',
#   'celery',
#   'tomato',
#   'onion',
#   'bay leaves'],
#  ['cinnamon sticks',
#   'pickling spices',
#   'cucumbers',
#   'pickling salt',
#   'white vinegar',
#   'sugar',
#   'alum'],
#  ['barbecue sauce', 'pork butt', 'ginger ale', 'onion'],
#  ['cold water',
#   'vanilla bean',
#   'strong coffee',
#   'vodka',
#   'sugar',
#   'brown sugar',
#   'dark molasses'],
#  ['whole chickens',
#   'frozen corn',
#   'chicken broth',
#   'celery ribs',
#   'chicken bouillon cubes',
#   'carrot',
#   'celery',
#   'frozen white corn',
#   'onion',
#   'potato'],
#  ['eggplant',
#   'low-carb marinara sauce',
#   'oregano leaves',
#   'fat-free parmesan cheese',
#   'lean ground turkey',
#   'basil',
#   'nonstick cooking spray',
#   'fennel seed'],
#  ['mountain dew soda', 'raspberry vodka'],
#  ['white cheddar cheese',
#   'red onion',
#   'fresh thyme',
#   'apple cider',
#   'red wine vinegar',
#   'tart apples',
#   'gouda cheese',
#   'salt and pepper',
#   'sherry wine vinegar',
#   'shallots',
#   'white vinegar',
#   'dijon mustard',
#   'olive oil',
#   'pancetta',
#   'arugula'],
#  ['eggs',
#   'unsalted butter',
#   "confectioners' sugar",
#   'pure vanilla extract',
#   'light brown sugar',
#   'salt',
#   'pumpkin pie spice',
#   'flour',
#   'vegetable oil',
#   'baby carrots',
#   'baking powder',
#   'marshmallow cream',
#   'baking soda'],
#  ['cinnamon',
#   'salt',
#   'vanilla',
#   'nutmeg',
#   'buttermilk',
#   'flour',
#   'sugar',
#   'egg',
#   'butter',
#   'cocoa',
#   'clove',
#   'baking soda'],
#  ['cream of tartar',
#   'eggs',
#   'powdered sugar',
#   'cornstarch',
#   'flour',
#   'sugar',
#   'egg yolks',
#   'milk',
#   'almonds',
#   'sweet cream'],
#  ...]

# %% [markdown]
# We'll use the [`Word2Vec`](https://radimrehurek.com/gensim/models/word2vec.html) implementation in the `gensim` library (i.e., *deep learning*) to train an embedding model.
# This approach tends to work best if the training data has at least 100K rows.
# NB: work in progress will replace `gensim` with `pytorch` instead.

# %%
import gensim

MIN_COUNT = 2
model_path = "tmp.w2v"

model = gensim.models.Word2Vec(vectors, min_count=MIN_COUNT, window=max_context)
model.save(model_path)

# %% [markdown]
# The `get_related()` function takes any ingredient as input, using the embedding model to find the most similar other ingredients – along with calculating [`levenshtein`](https://github.com/toastdriven/pylev) edit distances (string similarity) among these labels. Then it calculates *percentiles* for both metrics in [`numpy`](https://numpy.org/) and returns the results as a [`pandas`](https://pandas.pydata.org/) DataFrame.

# %%
import numpy as np
import pandas as pd
import pylev

def get_related (model, query, n=20, granularity=100):
    """return a DataFrame of the closely related items"""
    try:
        bins = np.linspace(0, 1, num=granularity, endpoint=True)

        v = sorted(
            model.wv.most_similar(positive=[query], topn=n), 
            key=lambda x: x[1], 
            reverse=True
        )
        
        df = pd.DataFrame(v, columns=["ingredient", "similarity"])
        
        s = df["similarity"]
        quantiles = s.quantile(bins, interpolation="nearest")
        df["sim_pct"] = np.digitize(s, quantiles) - 1
        
        df["levenshtein"] = [ pylev.levenshtein(d, query) / len(query) for d in df["ingredient"] ]
        s = df["levenshtein"]
        quantiles = s.quantile(bins, interpolation="nearest")
        df["lev_pct"] = granularity - np.digitize(s, quantiles)

        return df
    except KeyError:
        return pd.DataFrame(columns=["ingredient", "similarity", "percentile"])

# %% [markdown]
# Let's try this with `dried basil` as the ingredient to query, and review the top `50` most similar other ingredients returned as the DataFrame `df`:

# %%
df = get_related(model, "dried basil", n=50)
df
# Out:
#                                     ingredient  similarity  sim_pct  \
# 0                           dried basil leaves    0.677402       99
# 1                                    dry basil    0.648967       97
# 2                                  fresh basil    0.612726       95
# 3                               dried rosemary    0.612686       93
# 4                      dried italian seasoning    0.601575       91
# 5                                dried parsley    0.578546       89
# 6                     dried sweet basil leaves    0.566264       87
# 7                            italian seasoning    0.556173       85
# 8                               dried marjoram    0.555573       83
# 9                        dried rosemary leaves    0.546931       81
# 10                      italian herb seasoning    0.538196       79
# 11                        dried parsley flakes    0.534940       77
# 12                                       basil    0.486175       75
# 13                          dried thyme leaves    0.484871       73
# 14                                 dried thyme    0.474082       71
# 15                                 dry oregano    0.464772       69
# 16                 part-skim mozzarella cheese    0.464195       67
# 17                              italian spices    0.463525       65
# 18                           hot pepper flakes    0.463361       63
# 19                              thin spaghetti    0.459926       61
# 20                       italian seasoning mix    0.459591       59
# 21                             italian sausage    0.454377       57
# 22                           dried whole thyme    0.443076       55
# 23                             lasagna noodles    0.442709       53
# 24                   italian style breadcrumbs    0.442620       51
# 25                      italian-style tomatoes    0.440509       49
# 26                            italian sausages    0.439104       47
# 27                       whole wheat spaghetti    0.438106       45
# 28                                   manicotti    0.431973       43
# 29                     dried red pepper flakes    0.431558       41
# 30                             fresh mushrooms    0.431016       39
# 31                            dry thyme leaves    0.431000       37
# 32                             veal neck bones    0.428785       35
# 33                        mild italian sausage    0.428170       33
# 34                      italian turkey sausage    0.427670       31
# 35                            sliced mushrooms    0.427001       29
# 36                                  dried sage    0.426689       27
# 37                          fresh basil leaves    0.426150       25
# 38                          white kidney beans    0.425887       23
# 39                dried italian herb seasoning    0.425754       21
# 40                                  orzo pasta    0.425160       19
# 41                                 sweet basil    0.424797       17
# 42                             ground rosemary    0.424685       15
# 43                        quick-cooking barley    0.424177       13
# 44  olive oil-flavored vegetable cooking spray    0.423265       11
# 45                            cooked spaghetti    0.422880        9
# 46                       cooked rigatoni pasta    0.421460        7
# 47                              dried tarragon    0.419499        5
# 48                                 dry lentils    0.418193        3
# 49                                cooked pasta    0.417445        1
#
#     levenshtein  lev_pct
# 0      0.636364       74
# 1      0.272727       98
# 2      0.363636       92
# 3      0.636364       74
# 4      1.272727       26
# 5      0.454545       88
# 6      1.181818       30
# 7      1.090909       38
# 8      0.636364       74
# 9      1.181818       30
# 10     1.454545       14
# 11     1.000000       54
# 12     0.545455       86
# 13     1.000000       54
# 14     0.454545       88
# 15     0.818182       70
# 16     2.090909        2
# 17     1.090909       38
# 18     1.272727       26
# 19     1.090909       38
# 20     1.454545       14
# 21     1.000000       54
# 22     1.000000       54
# 23     1.181818       30
# 24     1.909091        4
# 25     1.727273        6
# 26     1.090909       38
# 27     1.636364        8
# 28     0.909091       68
# 29     1.454545       14
# 30     1.090909       38
# 31     1.090909       38
# 32     1.090909       38
# 33     1.363636       22
# 34     1.545455       12
# 35     1.000000       54
# 36     0.363636       92
# 37     1.000000       54
# 38     1.181818       30
# 39     1.636364        8
# 40     0.636364       74
# 41     0.363636       92
# 42     1.000000       54
# 43     1.454545       14
# 44     3.272727        0
# 45     1.090909       38
# 46     1.363636       22
# 47     0.636364       74
# 48     0.727273       72
# 49     0.636364       74

# %% [markdown]
# Note how some of the most similar items, based on vector embedding, are *synonyms* or special forms of our query `dried basil` ingredient: `dried basil leaves`, `dry basil`, `dried sweet basil leaves`, etc. These tend to rank high in terms of levenshtein distance too.
#
# In this example, below a threshold of the 75th percentile for vector embedding similarity, the related ingredients are less about being synonyms and more about other foods that pair well with basil.
#
# Let's define another function `rank_related()` which ranks the related ingredients based on a combination of these two metrics.
# This uses a cheap approximation of a [*pareto archive*](https://www.cs.bham.ac.uk/~jdk/multi/) for the ranking -- which comes in handing for recommender systems and custom search applications that must combine multiple ranking metrics:

# %%
import math

def rms (values):
    """calculate root mean square"""
    numer = sum([x for x in map(lambda x: float(x)**2.0, values)])
    denom = float(len(values))
    return math.sqrt(numer / denom)

def rank_related (df):
    df2 = df.copy(deep=True)
    df2["related"] = df2.apply(lambda row: rms([row[2], row[4]]), axis=1)
    return df2.sort_values(by=["related"], ascending=False)

# %%
rank_related(df)
# Out:
#                                     ingredient  similarity  sim_pct  \
# 1                                    dry basil    0.648967       97
# 2                                  fresh basil    0.612726       95
# 5                                dried parsley    0.578546       89
# 0                           dried basil leaves    0.677402       99
# 3                               dried rosemary    0.612686       93
# 12                                       basil    0.486175       75
# 14                                 dried thyme    0.474082       71
# 8                               dried marjoram    0.555573       83
# 15                                 dry oregano    0.464772       69
# 36                                  dried sage    0.426689       27
# 4                      dried italian seasoning    0.601575       91
# 11                        dried parsley flakes    0.534940       77
# 41                                 sweet basil    0.424797       17
# 7                            italian seasoning    0.556173       85
# 6                     dried sweet basil leaves    0.566264       87
# 13                          dried thyme leaves    0.484871       73
# 9                        dried rosemary leaves    0.546931       81
# 28                                   manicotti    0.431973       43
# 10                      italian herb seasoning    0.538196       79
# 21                             italian sausage    0.454377       57
# 22                           dried whole thyme    0.443076       55
# 40                                  orzo pasta    0.425160       19
# 17                              italian spices    0.463525       65
# 47                              dried tarragon    0.419499        5
# 49                                cooked pasta    0.417445        1
# 48                                 dry lentils    0.418193        3
# 19                              thin spaghetti    0.459926       61
# 18                           hot pepper flakes    0.463361       63
# 16                 part-skim mozzarella cheese    0.464195       67
# 35                            sliced mushrooms    0.427001       29
# 23                             lasagna noodles    0.442709       53
# 20                       italian seasoning mix    0.459591       59
# 26                            italian sausages    0.439104       47
# 37                          fresh basil leaves    0.426150       25
# 42                             ground rosemary    0.424685       15
# 30                             fresh mushrooms    0.431016       39
# 31                            dry thyme leaves    0.431000       37
# 32                             veal neck bones    0.428785       35
# 24                   italian style breadcrumbs    0.442620       51
# 25                      italian-style tomatoes    0.440509       49
# 27                       whole wheat spaghetti    0.438106       45
# 29                     dried red pepper flakes    0.431558       41
# 33                        mild italian sausage    0.428170       33
# 45                            cooked spaghetti    0.422880        9
# 38                          white kidney beans    0.425887       23
# 34                      italian turkey sausage    0.427670       31
# 46                       cooked rigatoni pasta    0.421460        7
# 39                dried italian herb seasoning    0.425754       21
# 43                        quick-cooking barley    0.424177       13
# 44  olive oil-flavored vegetable cooking spray    0.423265       11
#
#     levenshtein  lev_pct    related
# 1      0.272727       98  97.501282
# 2      0.363636       92  93.512031
# 5      0.454545       88  88.501412
# 0      0.636364       74  87.398513
# 3      0.636364       74  84.038682
# 12     0.545455       86  80.687669
# 14     0.454545       88  79.953111
# 8      0.636364       74  78.628875
# 15     0.818182       70  69.501799
# 36     0.363636       92  67.797493
# 4      1.272727       26  66.921596
# 11     1.000000       54  66.501880
# 41     0.363636       92  66.155121
# 7      1.090909       38  65.836920
# 6      1.181818       30  65.073036
# 13     1.000000       54  64.206697
# 9      1.181818       30  61.077819
# 28     0.909091       68  56.890245
# 10     1.454545       14  56.731825
# 21     1.000000       54  55.520267
# 22     1.000000       54  54.502294
# 40     0.636364       74  54.023143
# 17     1.090909       38  53.240023
# 47     0.636364       74  52.445210
# 49     0.636364       74  52.330679
# 48     0.727273       72  50.955863
# 19     1.090909       38  50.818304
# 18     1.272727       26  48.192323
# 16     2.090909        2  47.397257
# 35     1.000000       54  43.341666
# 23     1.181818       30  43.063906
# 20     1.454545       14  42.877733
# 26     1.090909       38  42.737571
# 37     1.000000       54  42.077310
# 42     1.000000       54  39.629534
# 30     1.090909       38  38.503247
# 31     1.090909       38  37.503333
# 32     1.090909       38  36.530809
# 24     1.909091        4  36.173194
# 25     1.727273        6  34.907019
# 27     1.636364        8  32.318725
# 29     1.454545       14  30.634947
# 33     1.363636       22  28.044607
# 45     1.090909       38  27.613403
# 38     1.181818       30  26.730133
# 34     1.545455       12  23.505319
# 46     1.363636       22  16.324828
# 39     1.636364        8  15.890249
# 43     1.454545       14  13.509256
# 44     3.272727        0   7.778175

# %% [markdown]
# Notice how the "synonym" cases tend to move up to the top now?
# Meanwhile while the "pairs well with" are in the lower half of the ranked list: `fresh mushrooms`, `italian turkey sausage`, `cooked spaghetti`, `white kidney beans`, etc.

# %% [markdown]
# ---
#
# ## Exercises

# %% [markdown]
# **Exercise 1:**
#
# Use the `rank_related()` function while iterating over `vocab` to make algorithmic suggestions for possible synonyms, as a report for a *human-in-the-loop* reviewer.
