# %%
# for use in tutorial and development; do not include this `sys.path` change in production:
import sys ; sys.path.insert(0, "../")
import os ; from os.path import dirname

# %% [markdown]
# # Produce a dataset for working with PyTorch_Geometric

# %% [markdown]
# ### Initialize
# Set up the dependencies plus a reproducible environment.

# %%
from collections import defaultdict
from icecream import ic
import csv
import kglab
import pandas as pd
import pickle
import rdflib
import re
import typing

pd.set_option("max_rows", None)

# %% [markdown]
# ### Pre-defined Ingredients
# Extract and reuse as many ingredients from the FoodOn ontology as possible.

# %%
NAMESPACES = {
    "wtm":  "http://purl.org/heals/food/",
    "ind":  "http://purl.org/heals/ingredient/",
    }

ind_kg = kglab.KnowledgeGraph(
    namespaces = NAMESPACES,
    )

# %%
sparql = """
    SELECT ?ind ?label ?definition
    WHERE {
        # ?ind rdf:type wtm:Ingredient .
        # ?ind rdfs:label ?label .
        # ?ind skos:definition ?definition
    }
"""

# %%
#url = NAMESPACES["ind"]
ind_kg.load_rdf("ind.rdf", format="xml")

IND_DF = ind_kg.query_as_df(sparql)
IND_DF.head()
# Out:
#                    ind             label  \
# 0            ind:Thyme             thyme
# 1           ind:Cheese            cheese
# 2         ind:OliveOil         olive oil
# 3  ind:BlackPeppercorn  black peppercorn
# 4   ind:VanillaExtract   vanilla extract
#
#                                           definition
# 0  any of a genus (Thymus) of Eurasian mints with...
# 1  the curd of milk separated from the whey and p...
# 2  a pale yellow to yellowish-green nondrying oil...
# 3                  a dried berry of the black pepper
# 4  a solution made by macerating and percolating ...

# %% [markdown]
# How many unique ingredients have been pre-defined by FoodOn?

# %%
unique_labels = list(IND_DF.label.unique())
ic(len(unique_labels))
unique_labels
# Out:
# ic| len(unique_labels): 75
# ['thyme',
#  'cheese',
#  'olive oil',
#  'black peppercorn',
#  'vanilla extract',
#  "baker's yeast",
#  'mayonnaise',
#  'chicken egg',
#  'potato',
#  'oat',
#  'corned beef',
#  'whole wheat flour',
#  'tapioca flour',
#  'green pepper',
#  'beef',
#  'bacon',
#  'black pepper',
#  'pumpkin seed',
#  'peanut',
#  'white sugar',
#  'almond meal',
#  'banana',
#  'carrot',
#  'canola oil',
#  'chicken',
#  'brown sugar',
#  'cane sugar',
#  'almond',
#  'beef bouillon',
#  'blueberry',
#  'baking powder',
#  'baking soda',
#  'chuck roast',
#  'paprika',
#  'pecan',
#  'basil',
#  'coconut',
#  'gluten free flour',
#  'onion',
#  'green onion',
#  'coconut milk',
#  'rosemary',
#  'cornstarch',
#  'dried cranberry',
#  'cow milk',
#  'corn syrup',
#  'honey',
#  'kamut flour',
#  'salt',
#  'sesame oil',
#  'celery',
#  'balsamic vinegar',
#  'walnut',
#  'soy sauce',
#  'cocoa powder',
#  'clove',
#  'oregano',
#  'parsley',
#  'chayote squash',
#  'lamb',
#  'tomato',
#  'kamut',
#  'water',
#  'apple cider vinegar',
#  'all purpose flour',
#  'lemon juice',
#  'garlic',
#  'butter',
#  'vegetable oil',
#  'whole grain mustard',
#  'tarragon',
#  'white vinegar',
#  'chicken broth',
#  'cilantro',
#  'cabbage']

# %% [markdown]
# ### Local Class Definitions
# Define a namedtuple factor for recipes, plus a subclass of `kglab.KnowledgeGraph` specific to this application.

# %%
class Recipe (typing.NamedTuple):
    """simple representation for a parsed recipe from Food.com"""
    id: str
    definition: str
    cook_time: int
    ind_set: typing.Set[str]

# %%
class RecipeKG (kglab.KnowledgeGraph):
    _SYNONYMS = {}
    _INGREDIENTS = {}

    def add_syn (
        self,
        syn_list: list,
        targets: list,
        ) -> None:
        for syn in syn_list:
            self._SYNONYMS[syn] = set(targets)


    def map_syn (
        self,
        syn: str,
        ) -> typing.Set:
        if syn in self._SYNONYMS:
            return self._SYNONYMS[syn]
 
        return { syn }


    def add_ind (
        self,
        label: str,
        entity: str,
        *,
        descrip = "",
        ) -> None:
        self._INGREDIENTS[label] = kg.get_ns("ind")[entity]

        ind, _, descrip = IND_DF.loc[IND_DF["ind"] == f"ind:{entity}"].values[0]
        ic(entity, label, descrip)

        node = self.get_ns("ind")[entity]
        self.add( node, self.get_ns("rdf").type, self.get_ns("wtm").Ingredient )
        self.add( node, self.get_ns("skos").prefLabel, rdflib.Literal(label) )
        self.add( node, self.get_ns("skos").definition, rdflib.Literal(descrip) )


    def new_ind (
        self,
        label: str,
        entity: str,
        *,
        descrip = None,
        ) -> None:
        node = rdflib.URIRef("{}{}".format(NAMESPACES["ind"], entity))
        self._INGREDIENTS[label] = node
        
        self.add( node, self.get_ns("rdf").type, self.get_ns("wtm").Ingredient )
        self.add( node, self.get_ns("skos").prefLabel, rdflib.Literal(label) )

        if descrip:
            self.add( node, self.get_ns("skos").definition, rdflib.Literal(descrip) )

# %%
kg = RecipeKG(
    base_uri = "https://www.food.com/recipe/",
    namespaces = NAMESPACES,
    )

kg.load_rdf("recipe_lg.ttl")

# %% [markdown]
# ### Index the Labels

# %%
sparql = """
    SELECT ?ind ?label
    WHERE {
        # ?ind rdf:type wtm:Ingredient .
        # ?ind skos:prefLabel ?label .
    }
"""

# %%
df = kg.query_as_df(sparql)
df.head()
# Out:
#                 ind          label
# 0       ind:Parsley        parsley
# 1         ind:Onion          onion
# 2  ind:ChickenBroth  chicken broth
# 3   ind:GreenPepper   green pepper
# 4  ind:VegetableOil            oil

# %%
for _, row in df.iterrows():
    entity = row.ind.split(":")[1]
    kg._INGREDIENTS[row.label] = kg.get_ns("ind")[entity]

# %%
kg._INGREDIENTS
# Out:
# {'parsley': rdflib.term.URIRef('http://purl.org/heals/ingredient/Parsley'),
#  'onion': rdflib.term.URIRef('http://purl.org/heals/ingredient/Onion'),
#  'chicken broth': rdflib.term.URIRef('http://purl.org/heals/ingredient/ChickenBroth'),
#  'green pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/GreenPepper'),
#  'oil': rdflib.term.URIRef('http://purl.org/heals/ingredient/VegetableOil'),
#  'corned beef': rdflib.term.URIRef('http://purl.org/heals/ingredient/CornedBeef'),
#  'brown sugar': rdflib.term.URIRef('http://purl.org/heals/ingredient/BrownSugar'),
#  'bacon': rdflib.term.URIRef('http://purl.org/heals/ingredient/Bacon'),
#  'paprika': rdflib.term.URIRef('http://purl.org/heals/ingredient/Paprika'),
#  'lemon juice': rdflib.term.URIRef('http://purl.org/heals/ingredient/LemonJuice'),
#  'egg': rdflib.term.URIRef('http://purl.org/heals/ingredient/ChickenEgg'),
#  'gluten free flour': rdflib.term.URIRef('http://purl.org/heals/ingredient/GlutenFreeFlour'),
#  'flour': rdflib.term.URIRef('http://purl.org/heals/ingredient/AllPurposeFlour'),
#  'walnut': rdflib.term.URIRef('http://purl.org/heals/ingredient/Walnut'),
#  'peanut': rdflib.term.URIRef('http://purl.org/heals/ingredient/Peanut'),
#  'cheese': rdflib.term.URIRef('http://purl.org/heals/ingredient/Cheese'),
#  'kamut flour': rdflib.term.URIRef('http://purl.org/heals/ingredient/KamutFlour'),
#  'dried basil': rdflib.term.URIRef('http://purl.org/heals/ingredient/Basil'),
#  'cabbage': rdflib.term.URIRef('http://purl.org/heals/ingredient/Cabbage'),
#  'blueberry': rdflib.term.URIRef('http://purl.org/heals/ingredient/Blueberry'),
#  'chicken': rdflib.term.URIRef('http://purl.org/heals/ingredient/Chicken'),
#  'garlic': rdflib.term.URIRef('http://purl.org/heals/ingredient/Garlic'),
#  'oat': rdflib.term.URIRef('http://purl.org/heals/ingredient/Oat'),
#  'cocoa powder': rdflib.term.URIRef('http://purl.org/heals/ingredient/CocoaPowder'),
#  'green onion': rdflib.term.URIRef('http://purl.org/heals/ingredient/GreenOnion'),
#  'pecan': rdflib.term.URIRef('http://purl.org/heals/ingredient/Pecan'),
#  'lamb': rdflib.term.URIRef('http://purl.org/heals/ingredient/Lamb'),
#  'tarragon': rdflib.term.URIRef('http://purl.org/heals/ingredient/Tarragon'),
#  'chuck roast': rdflib.term.URIRef('http://purl.org/heals/ingredient/ChuckRoast'),
#  'thyme': rdflib.term.URIRef('http://purl.org/heals/ingredient/Thyme'),
#  'whole grain mustard': rdflib.term.URIRef('http://purl.org/heals/ingredient/WholeGrainMustard'),
#  'black peppercorn': rdflib.term.URIRef('http://purl.org/heals/ingredient/BlackPeppercorn'),
#  'cilantro': rdflib.term.URIRef('http://purl.org/heals/ingredient/Cilantro'),
#  'coconut milk': rdflib.term.URIRef('http://purl.org/heals/ingredient/CoconutMilk'),
#  'banana': rdflib.term.URIRef('http://purl.org/heals/ingredient/Banana'),
#  'almond meal': rdflib.term.URIRef('http://purl.org/heals/ingredient/AlmondMeal'),
#  'mayonnaise': rdflib.term.URIRef('http://purl.org/heals/ingredient/Mayonnaise'),
#  'vinegar': rdflib.term.URIRef('http://purl.org/heals/ingredient/AppleCiderVinegar'),
#  "baker's yeast": rdflib.term.URIRef('http://purl.org/heals/ingredient/BakersYeast'),
#  'beef bouillon': rdflib.term.URIRef('http://purl.org/heals/ingredient/BeefBouillon'),
#  'tapioca flour': rdflib.term.URIRef('http://purl.org/heals/ingredient/TapiocaFlour'),
#  'oregano': rdflib.term.URIRef('http://purl.org/heals/ingredient/Oregano'),
#  'soy sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/SoySauce'),
#  'sugar': rdflib.term.URIRef('http://purl.org/heals/ingredient/WhiteSugar'),
#  'dried cranberry': rdflib.term.URIRef('http://purl.org/heals/ingredient/DriedCranberry'),
#  'corn syrup': rdflib.term.URIRef('http://purl.org/heals/ingredient/CornSyrup'),
#  'sesame oil': rdflib.term.URIRef('http://purl.org/heals/ingredient/SesameOil'),
#  'white vinegar': rdflib.term.URIRef('http://purl.org/heals/ingredient/WhiteVinegar'),
#  'kamut': rdflib.term.URIRef('http://purl.org/heals/ingredient/Kamut'),
#  'almond': rdflib.term.URIRef('http://purl.org/heals/ingredient/Almond'),
#  'vanilla': rdflib.term.URIRef('http://purl.org/heals/ingredient/VanillaExtract'),
#  'whole wheat flour': rdflib.term.URIRef('http://purl.org/heals/ingredient/WholeWheatFlour'),
#  'baking soda': rdflib.term.URIRef('http://purl.org/heals/ingredient/BakingSoda'),
#  'canola oil': rdflib.term.URIRef('http://purl.org/heals/ingredient/CanolaOil'),
#  'butter': rdflib.term.URIRef('http://purl.org/heals/ingredient/Butter'),
#  'coconut': rdflib.term.URIRef('http://purl.org/heals/ingredient/Coconut'),
#  'rosemary': rdflib.term.URIRef('http://purl.org/heals/ingredient/Rosemary'),
#  'milk': rdflib.term.URIRef('http://purl.org/heals/ingredient/CowMilk'),
#  'olive oil': rdflib.term.URIRef('http://purl.org/heals/ingredient/OliveOil'),
#  'baking powder': rdflib.term.URIRef('http://purl.org/heals/ingredient/BakingPowder'),
#  'pumpkin seed': rdflib.term.URIRef('http://purl.org/heals/ingredient/PumpkinSeed'),
#  'beef': rdflib.term.URIRef('http://purl.org/heals/ingredient/Beef'),
#  'balsamic vinegar': rdflib.term.URIRef('http://purl.org/heals/ingredient/BalsamicVinegar'),
#  'potato': rdflib.term.URIRef('http://purl.org/heals/ingredient/Potato'),
#  'water': rdflib.term.URIRef('http://purl.org/heals/ingredient/Water'),
#  'black pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/BlackPepper'),
#  'salt': rdflib.term.URIRef('http://purl.org/heals/ingredient/Salt'),
#  'carrot': rdflib.term.URIRef('http://purl.org/heals/ingredient/Carrot'),
#  'clove': rdflib.term.URIRef('http://purl.org/heals/ingredient/Clove'),
#  'tomato': rdflib.term.URIRef('http://purl.org/heals/ingredient/Tomato'),
#  'celery': rdflib.term.URIRef('http://purl.org/heals/ingredient/Celery'),
#  'chayote squash': rdflib.term.URIRef('http://purl.org/heals/ingredient/ChayoteSquash'),
#  'cornstarch': rdflib.term.URIRef('http://purl.org/heals/ingredient/Cornstarch'),
#  'honey': rdflib.term.URIRef('http://purl.org/heals/ingredient/Honey')}

# %% [markdown]
# ### Define Synonyms
# As part of the data preparation, build a lookup table for translating ingredient names (synonyms) to the preferred labels for known ingredients:

# %%
kg.add_syn(["pepper"], ["black pepper"])
kg.add_syn(["fresh ground black pepper"], ["black pepper"])
kg.add_syn(["salt and pepper"], ["black pepper", "salt"])

kg.add_syn(["carrots"], ["carrot"])

kg.add_syn(["basil"], ["dried basil"])

kg.add_syn(["eggs", "chicken egg"], ["egg"])

kg.add_syn(["all-purpose flour"], ["flour"])
kg.add_syn(["all purpose flour"], ["flour"])

kg.add_syn(["garlic clove"], ["garlic"])
kg.add_syn(["garlic cloves"], ["garlic"])

kg.add_syn(["cow milk"], ["milk"])

kg.add_syn(["vegetable oil"], ["oil"])
kg.add_syn(["extra virgin olive oil"], ["olive oil"])
kg.add_syn(["onions"], ["onion"])

kg.add_syn(["potatoes"], ["potato"])

kg.add_syn(["cane sugar", "granulated sugar", "white sugar"], ["sugar"])

kg.add_syn(["fresh tomatoes", "tomatoes"], ["tomato"])

kg.add_syn(["vanilla extract"], ["vanilla"])
kg.add_syn(["apple cider vinegar"], ["vinegar"])

# %%
known_syn = {*{
    x 
    for l in kg._SYNONYMS.values()
    for x in l
}}

ic(len(known_syn));
# Out:
# ic| len(known_syn): 16

# %% [markdown]
# ---
# ### Analyze Ingredients
# **ITERATE HERE**:
# Analyze the ingredient labels from 250K recipes.

# %%
MAX_ROW = 250000 # 231638

max_context = 0
min_context = 1000

RECIPES: typing.List[Recipe] = []
VOCAB: typing.Set[str] = set()

with open(dirname(os.getcwd()) + "/dat/all_ind.csv", "r") as f:
    reader = csv.reader(f)
    next(reader, None) # remove file header

    for i, row in enumerate(reader):
        # parse the recipe metadata
        id = row[0]
        definition = row[1].replace("   ", " ")
        cook_time = int(row[2])

        # substitute synonyms for ingredients
        ind_set = {
            ind
            for raw_ind in eval(row[3])
            for ind in kg.map_syn(raw_ind)
        }

        if len(ind_set) > 1:
            RECIPES.append(Recipe(id, definition, cook_time, ind_set))
            VOCAB.update(ind_set)
        
            max_context = max(max_context, len(ind_set))
            min_context = min(min_context, len(ind_set))

        if i > MAX_ROW:
            break

# %%
print("max context: {} unique ingredients per recipe".format(max_context))
print("min context: {} unique ingredients per recipe".format(min_context))
print("vocab size", len(list(VOCAB)))
# Out:
# max context: 43 unique ingredients per recipe
# min context: 2 unique ingredients per recipe
# vocab size 14924

# %% [markdown]
# Use `pickle` to save this larger superset of the recipes dataset to the `tmp.pkl` file:

# %%
pickle.dump(RECIPES, open("tmp.pkl", "wb"))
RECIPES[:3]
# Out:
# [Recipe(id='137739', definition='arriba baked winter squash mexican style', cook_time=55, ind_set={'butter', 'salt', 'winter squash', 'honey', 'mixed spice', 'mexican seasoning', 'olive oil'}),
#  Recipe(id='31490', definition='a bit different  breakfast pizza', cook_time=30, ind_set={'milk', 'salt', 'egg', 'sausage patty', 'black pepper', 'prepared pizza crust', 'cheese'}),
#  Recipe(id='112140', definition='all in the kitchen  chili', cook_time=130, ind_set={'water', 'tomato soup', 'kidney beans', 'salt', 'lettuce', 'ground cumin', 'yellow onions', 'tomato paste', 'chili powder', 'rotel tomatoes', 'ground beef', 'cheddar cheese', 'diced tomatoes'})]

# %% [markdown]
# How many of the recipes are complete in the sense that each of their ingredients is known?

# %%
unknown_ind = defaultdict(int)
complete_recipes = 0

for r in RECIPES:
    has_all_ind = True
    
    for ind in r.ind_set:
        if ind not in kg._INGREDIENTS:
            unknown_ind[ind] += 1
            has_all_ind = False

    if has_all_ind:
        complete_recipes += 1

ic(max(unknown_ind.values()))
ic(complete_recipes)
# Out:
# ic| max(unknown_ind.values()): 14807
# ic| complete_recipes: 1373
# 1373

# %% [markdown]
# Which among the unknown ingredients are the most popularly used in recipes?

# %%
sorted(unknown_ind.items(), key=lambda item: item[1], reverse=True)[:20]
# Out:
# [('parmesan cheese', 14807),
#  ('cinnamon', 12560),
#  ('sour cream', 11779),
#  ('garlic powder', 10887),
#  ('cream cheese', 9827),
#  ('cheddar cheese', 8969),
#  ('unsalted butter', 8935),
#  ('worcestershire sauce', 7832),
#  ('fresh parsley', 7656),
#  ('chili powder', 6984),
#  ('ground cinnamon', 6864),
#  ('nutmeg', 6299),
#  ('cayenne pepper', 6285),
#  ('ground cumin', 6169),
#  ('ground beef', 5824),
#  ('green onions', 5814),
#  ('red onion', 5777),
#  ('walnuts', 5764),
#  ('pecans', 5752),
#  ('dijon mustard', 5599)]

# %% [markdown]
# Which among the unknown ingredients did we **miss** from the pre-defined ones in FoodOn?

# %%
MAX_ADD = 500

pre_def = list(IND_DF.label.unique())
count = 0

for label in unknown_ind:
    if label in pre_def:
        ind, _, descrip = IND_DF.loc[IND_DF["label"] == label].values[0]
        entity = ind.split(":")[1]
        ic(entity, label, descrip)
        kg.add_ind(label, entity)
    else:
        if count < MAX_ADD:
            entity = re.sub("[^0-9a-zA-Z]+", " ", label)
            entity = re.sub("[\s]+", " ", entity).strip()
            entity = entity.replace(" ", "_")
            kg.new_ind(label, entity)

            count += 1
# Out:
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node'https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451')
# ic| node: rdflib.term.URIRef('https://www.food.com/recipe/357451'

# %%
ic(len(kg._INGREDIENTS))
kg._INGREDIENTS
# Out:
# ic| len(kg._INGREDIENTS): 574
# {'parsley': rdflib.term.URIRef('http://purl.org/heals/ingredient/Parsley'),
#  'onion': rdflib.term.URIRef('http://purl.org/heals/ingredient/Onion'),
#  'chicken broth': rdflib.term.URIRef('http://purl.org/heals/ingredient/ChickenBroth'),
#  'green pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/GreenPepper'),
#  'oil': rdflib.term.URIRef('http://purl.org/heals/ingredient/VegetableOil'),
#  'corned beef': rdflib.term.URIRef('http://purl.org/heals/ingredient/CornedBeef'),
#  'brown sugar': rdflib.term.URIRef('http://purl.org/heals/ingredient/BrownSugar'),
#  'bacon': rdflib.term.URIRef('http://purl.org/heals/ingredient/Bacon'),
#  'paprika': rdflib.term.URIRef('http://purl.org/heals/ingredient/Paprika'),
#  'lemon juice': rdflib.term.URIRef('http://purl.org/heals/ingredient/LemonJuice'),
#  'egg': rdflib.term.URIRef('http://purl.org/heals/ingredient/ChickenEgg'),
#  'gluten free flour': rdflib.term.URIRef('http://purl.org/heals/ingredient/GlutenFreeFlour'),
#  'flour': rdflib.term.URIRef('http://purl.org/heals/ingredient/AllPurposeFlour'),
#  'walnut': rdflib.term.URIRef('http://purl.org/heals/ingredient/Walnut'),
#  'peanut': rdflib.term.URIRef('http://purl.org/heals/ingredient/Peanut'),
#  'cheese': rdflib.term.URIRef('http://purl.org/heals/ingredient/Cheese'),
#  'kamut flour': rdflib.term.URIRef('http://purl.org/heals/ingredient/KamutFlour'),
#  'dried basil': rdflib.term.URIRef('http://purl.org/heals/ingredient/Basil'),
#  'cabbage': rdflib.term.URIRef('http://purl.org/heals/ingredient/Cabbage'),
#  'blueberry': rdflib.term.URIRef('http://purl.org/heals/ingredient/Blueberry'),
#  'chicken': rdflib.term.URIRef('http://purl.org/heals/ingredient/Chicken'),
#  'garlic': rdflib.term.URIRef('http://purl.org/heals/ingredient/Garlic'),
#  'oat': rdflib.term.URIRef('http://purl.org/heals/ingredient/Oat'),
#  'cocoa powder': rdflib.term.URIRef('http://purl.org/heals/ingredient/CocoaPowder'),
#  'green onion': rdflib.term.URIRef('http://purl.org/heals/ingredient/GreenOnion'),
#  'pecan': rdflib.term.URIRef('http://purl.org/heals/ingredient/Pecan'),
#  'lamb': rdflib.term.URIRef('http://purl.org/heals/ingredient/Lamb'),
#  'tarragon': rdflib.term.URIRef('http://purl.org/heals/ingredient/Tarragon'),
#  'chuck roast': rdflib.term.URIRef('http://purl.org/heals/ingredient/ChuckRoast'),
#  'thyme': rdflib.term.URIRef('http://purl.org/heals/ingredient/Thyme'),
#  'whole grain mustard': rdflib.term.URIRef('http://purl.org/heals/ingredient/WholeGrainMustard'),
#  'black peppercorn': rdflib.term.URIRef('http://purl.org/heals/ingredient/BlackPeppercorn'),
#  'cilantro': rdflib.term.URIRef('http://purl.org/heals/ingredient/Cilantro'),
#  'coconut milk': rdflib.term.URIRef('http://purl.org/heals/ingredient/CoconutMilk'),
#  'banana': rdflib.term.URIRef('http://purl.org/heals/ingredient/Banana'),
#  'almond meal': rdflib.term.URIRef('http://purl.org/heals/ingredient/AlmondMeal'),
#  'mayonnaise': rdflib.term.URIRef('http://purl.org/heals/ingredient/Mayonnaise'),
#  'vinegar': rdflib.term.URIRef('http://purl.org/heals/ingredient/AppleCiderVinegar'),
#  "baker's yeast": rdflib.term.URIRef('http://purl.org/heals/ingredient/BakersYeast'),
#  'beef bouillon': rdflib.term.URIRef('http://purl.org/heals/ingredient/BeefBouillon'),
#  'tapioca flour': rdflib.term.URIRef('http://purl.org/heals/ingredient/TapiocaFlour'),
#  'oregano': rdflib.term.URIRef('http://purl.org/heals/ingredient/Oregano'),
#  'soy sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/SoySauce'),
#  'sugar': rdflib.term.URIRef('http://purl.org/heals/ingredient/WhiteSugar'),
#  'dried cranberry': rdflib.term.URIRef('http://purl.org/heals/ingredient/DriedCranberry'),
#  'corn syrup': rdflib.term.URIRef('http://purl.org/heals/ingredient/CornSyrup'),
#  'sesame oil': rdflib.term.URIRef('http://purl.org/heals/ingredient/SesameOil'),
#  'white vinegar': rdflib.term.URIRef('http://purl.org/heals/ingredient/WhiteVinegar'),
#  'kamut': rdflib.term.URIRef('http://purl.org/heals/ingredient/Kamut'),
#  'almond': rdflib.term.URIRef('http://purl.org/heals/ingredient/Almond'),
#  'vanilla': rdflib.term.URIRef('http://purl.org/heals/ingredient/VanillaExtract'),
#  'whole wheat flour': rdflib.term.URIRef('http://purl.org/heals/ingredient/WholeWheatFlour'),
#  'baking soda': rdflib.term.URIRef('http://purl.org/heals/ingredient/BakingSoda'),
#  'canola oil': rdflib.term.URIRef('http://purl.org/heals/ingredient/CanolaOil'),
#  'butter': rdflib.term.URIRef('http://purl.org/heals/ingredient/Butter'),
#  'coconut': rdflib.term.URIRef('http://purl.org/heals/ingredient/Coconut'),
#  'rosemary': rdflib.term.URIRef('http://purl.org/heals/ingredient/Rosemary'),
#  'milk': rdflib.term.URIRef('http://purl.org/heals/ingredient/CowMilk'),
#  'olive oil': rdflib.term.URIRef('http://purl.org/heals/ingredient/OliveOil'),
#  'baking powder': rdflib.term.URIRef('http://purl.org/heals/ingredient/BakingPowder'),
#  'pumpkin seed': rdflib.term.URIRef('http://purl.org/heals/ingredient/PumpkinSeed'),
#  'beef': rdflib.term.URIRef('http://purl.org/heals/ingredient/Beef'),
#  'balsamic vinegar': rdflib.term.URIRef('http://purl.org/heals/ingredient/BalsamicVinegar'),
#  'potato': rdflib.term.URIRef('http://purl.org/heals/ingredient/Potato'),
#  'water': rdflib.term.URIRef('http://purl.org/heals/ingredient/Water'),
#  'black pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/BlackPepper'),
#  'salt': rdflib.term.URIRef('http://purl.org/heals/ingredient/Salt'),
#  'carrot': rdflib.term.URIRef('http://purl.org/heals/ingredient/Carrot'),
#  'clove': rdflib.term.URIRef('http://purl.org/heals/ingredient/Clove'),
#  'tomato': rdflib.term.URIRef('http://purl.org/heals/ingredient/Tomato'),
#  'celery': rdflib.term.URIRef('http://purl.org/heals/ingredient/Celery'),
#  'chayote squash': rdflib.term.URIRef('http://purl.org/heals/ingredient/ChayoteSquash'),
#  'cornstarch': rdflib.term.URIRef('http://purl.org/heals/ingredient/Cornstarch'),
#  'honey': rdflib.term.URIRef('http://purl.org/heals/ingredient/Honey'),
#  'winter squash': rdflib.term.URIRef('http://purl.org/heals/ingredient/winter_squash'),
#  'mixed spice': rdflib.term.URIRef('http://purl.org/heals/ingredient/mixed_spice'),
#  'mexican seasoning': rdflib.term.URIRef('http://purl.org/heals/ingredient/mexican_seasoning'),
#  'sausage patty': rdflib.term.URIRef('http://purl.org/heals/ingredient/sausage_patty'),
#  'prepared pizza crust': rdflib.term.URIRef('http://purl.org/heals/ingredient/prepared_pizza_crust'),
#  'tomato soup': rdflib.term.URIRef('http://purl.org/heals/ingredient/tomato_soup'),
#  'kidney beans': rdflib.term.URIRef('http://purl.org/heals/ingredient/kidney_beans'),
#  'lettuce': rdflib.term.URIRef('http://purl.org/heals/ingredient/lettuce'),
#  'ground cumin': rdflib.term.URIRef('http://purl.org/heals/ingredient/ground_cumin'),
#  'yellow onions': rdflib.term.URIRef('http://purl.org/heals/ingredient/yellow_onions'),
#  'tomato paste': rdflib.term.URIRef('http://purl.org/heals/ingredient/tomato_paste'),
#  'chili powder': rdflib.term.URIRef('http://purl.org/heals/ingredient/chili_powder'),
#  'rotel tomatoes': rdflib.term.URIRef('http://purl.org/heals/ingredient/rotel_tomatoes'),
#  'ground beef': rdflib.term.URIRef('http://purl.org/heals/ingredient/ground_beef'),
#  'cheddar cheese': rdflib.term.URIRef('http://purl.org/heals/ingredient/cheddar_cheese'),
#  'diced tomatoes': rdflib.term.URIRef('http://purl.org/heals/ingredient/diced_tomatoes'),
#  'spreadable cheese with garlic and herbs': rdflib.term.URIRef('http://purl.org/heals/ingredient/spreadable_cheese_with_garlic_and_herbs'),
#  'shallots': rdflib.term.URIRef('http://purl.org/heals/ingredient/shallots'),
#  'new potatoes': rdflib.term.URIRef('http://purl.org/heals/ingredient/new_potatoes'),
#  'yellow bell pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/yellow_bell_pepper'),
#  'red bell pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/red_bell_pepper'),
#  'red wine vinegar': rdflib.term.URIRef('http://purl.org/heals/ingredient/red_wine_vinegar'),
#  'cinnamon oil': rdflib.term.URIRef('http://purl.org/heals/ingredient/cinnamon_oil'),
#  'tomato juice': rdflib.term.URIRef('http://purl.org/heals/ingredient/tomato_juice'),
#  'clove oil': rdflib.term.URIRef('http://purl.org/heals/ingredient/clove_oil'),
#  'dry mustard': rdflib.term.URIRef('http://purl.org/heals/ingredient/dry_mustard'),
#  'frozen apple juice concentrate': rdflib.term.URIRef('http://purl.org/heals/ingredient/frozen_apple_juice_concentrate'),
#  'apple': rdflib.term.URIRef('http://purl.org/heals/ingredient/apple'),
#  'vanilla ice cream': rdflib.term.URIRef('http://purl.org/heals/ingredient/vanilla_ice_cream'),
#  'peppercorn': rdflib.term.URIRef('http://purl.org/heals/ingredient/peppercorn'),
#  'orange juice': rdflib.term.URIRef('http://purl.org/heals/ingredient/orange_juice'),
#  'fennel seeds': rdflib.term.URIRef('http://purl.org/heals/ingredient/fennel_seeds'),
#  'ripe olives': rdflib.term.URIRef('http://purl.org/heals/ingredient/ripe_olives'),
#  'red chile': rdflib.term.URIRef('http://purl.org/heals/ingredient/red_chile'),
#  'orange rind': rdflib.term.URIRef('http://purl.org/heals/ingredient/orange_rind'),
#  'green olives': rdflib.term.URIRef('http://purl.org/heals/ingredient/green_olives'),
#  'fresh coarse ground black pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/fresh_coarse_ground_black_pepper'),
#  'mirin': rdflib.term.URIRef('http://purl.org/heals/ingredient/mirin'),
#  'orange, juice of': rdflib.term.URIRef('http://purl.org/heals/ingredient/orange_juice_of'),
#  'yellow onion': rdflib.term.URIRef('http://purl.org/heals/ingredient/yellow_onion'),
#  'cracked black pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/cracked_black_pepper'),
#  'fresh garlic': rdflib.term.URIRef('http://purl.org/heals/ingredient/fresh_garlic'),
#  'cinnamon sticks': rdflib.term.URIRef('http://purl.org/heals/ingredient/cinnamon_sticks'),
#  'fresh cilantro leaves': rdflib.term.URIRef('http://purl.org/heals/ingredient/fresh_cilantro_leaves'),
#  'liquid smoke': rdflib.term.URIRef('http://purl.org/heals/ingredient/liquid_smoke'),
#  'a.1. original sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/a_1_original_sauce'),
#  'fresh ginger': rdflib.term.URIRef('http://purl.org/heals/ingredient/fresh_ginger'),
#  'cumin': rdflib.term.URIRef('http://purl.org/heals/ingredient/cumin'),
#  'pork spareribs': rdflib.term.URIRef('http://purl.org/heals/ingredient/pork_spareribs'),
#  'tomato sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/tomato_sauce'),
#  'chocolate sandwich style cookies': rdflib.term.URIRef('http://purl.org/heals/ingredient/chocolate_sandwich_style_cookies'),
#  'whipped cream': rdflib.term.URIRef('http://purl.org/heals/ingredient/whipped_cream'),
#  'bananas': rdflib.term.URIRef('http://purl.org/heals/ingredient/bananas'),
#  'strawberry ice cream': rdflib.term.URIRef('http://purl.org/heals/ingredient/strawberry_ice_cream'),
#  'chocolate syrup': rdflib.term.URIRef('http://purl.org/heals/ingredient/chocolate_syrup'),
#  'cake flour': rdflib.term.URIRef('http://purl.org/heals/ingredient/cake_flour'),
#  'unsalted butter': rdflib.term.URIRef('http://purl.org/heals/ingredient/unsalted_butter'),
#  'fresh lemon juice': rdflib.term.URIRef('http://purl.org/heals/ingredient/fresh_lemon_juice'),
#  'whole berry cranberry sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/whole_berry_cranberry_sauce'),
#  'sour cream': rdflib.term.URIRef('http://purl.org/heals/ingredient/sour_cream'),
#  'prepared horseradish': rdflib.term.URIRef('http://purl.org/heals/ingredient/prepared_horseradish'),
#  'whipping cream': rdflib.term.URIRef('http://purl.org/heals/ingredient/whipping_cream'),
#  'powdered sugar': rdflib.term.URIRef('http://purl.org/heals/ingredient/powdered_sugar'),
#  'strawberry': rdflib.term.URIRef('http://purl.org/heals/ingredient/strawberry'),
#  'vanilla wafers': rdflib.term.URIRef('http://purl.org/heals/ingredient/vanilla_wafers'),
#  'walnuts': rdflib.term.URIRef('http://purl.org/heals/ingredient/walnuts'),
#  'garlic powder': rdflib.term.URIRef('http://purl.org/heals/ingredient/garlic_powder'),
#  'great northern bean': rdflib.term.URIRef('http://purl.org/heals/ingredient/great_northern_bean'),
#  'molasses': rdflib.term.URIRef('http://purl.org/heals/ingredient/molasses'),
#  'mustard powder': rdflib.term.URIRef('http://purl.org/heals/ingredient/mustard_powder'),
#  'chicken bouillon cubes': rdflib.term.URIRef('http://purl.org/heals/ingredient/chicken_bouillon_cubes'),
#  'dark brown sugar': rdflib.term.URIRef('http://purl.org/heals/ingredient/dark_brown_sugar'),
#  'whiskey': rdflib.term.URIRef('http://purl.org/heals/ingredient/whiskey'),
#  'hot sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/hot_sauce'),
#  'ham hock': rdflib.term.URIRef('http://purl.org/heals/ingredient/ham_hock'),
#  'collard greens': rdflib.term.URIRef('http://purl.org/heals/ingredient/collard_greens'),
#  'scullcap herb': rdflib.term.URIRef('http://purl.org/heals/ingredient/scullcap_herb'),
#  'spearmint': rdflib.term.URIRef('http://purl.org/heals/ingredient/spearmint'),
#  'wood bethony': rdflib.term.URIRef('http://purl.org/heals/ingredient/wood_bethony'),
#  'burnet root': rdflib.term.URIRef('http://purl.org/heals/ingredient/burnet_root'),
#  'gentian root': rdflib.term.URIRef('http://purl.org/heals/ingredient/gentian_root'),
#  'chicken rice soup': rdflib.term.URIRef('http://purl.org/heals/ingredient/chicken_rice_soup'),
#  'lean pork chops': rdflib.term.URIRef('http://purl.org/heals/ingredient/lean_pork_chops'),
#  'egg roll wrap': rdflib.term.URIRef('http://purl.org/heals/ingredient/egg_roll_wrap'),
#  'whole green chilies': rdflib.term.URIRef('http://purl.org/heals/ingredient/whole_green_chilies'),
#  'salted peanuts': rdflib.term.URIRef('http://purl.org/heals/ingredient/salted_peanuts'),
#  'chinese noodles': rdflib.term.URIRef('http://purl.org/heals/ingredient/chinese_noodles'),
#  'butterscotch chips': rdflib.term.URIRef('http://purl.org/heals/ingredient/butterscotch_chips'),
#  'cooking oil': rdflib.term.URIRef('http://purl.org/heals/ingredient/cooking_oil'),
#  'beef broth': rdflib.term.URIRef('http://purl.org/heals/ingredient/beef_broth'),
#  'hamburger buns': rdflib.term.URIRef('http://purl.org/heals/ingredient/hamburger_buns'),
#  'ground pork': rdflib.term.URIRef('http://purl.org/heals/ingredient/ground_pork'),
#  'green peas': rdflib.term.URIRef('http://purl.org/heals/ingredient/green_peas'),
#  'salt free herb and spice seasoning mix': rdflib.term.URIRef('http://purl.org/heals/ingredient/salt_free_herb_and_spice_seasoning_mix'),
#  'ground coriander': rdflib.term.URIRef('http://purl.org/heals/ingredient/ground_coriander'),
#  'broccoli floret': rdflib.term.URIRef('http://purl.org/heals/ingredient/broccoli_floret'),
#  'fresh herb': rdflib.term.URIRef('http://purl.org/heals/ingredient/fresh_herb'),
#  'cauliflower': rdflib.term.URIRef('http://purl.org/heals/ingredient/cauliflower'),
#  'vegetable bouillon cubes': rdflib.term.URIRef('http://purl.org/heals/ingredient/vegetable_bouillon_cubes'),
#  'escarole': rdflib.term.URIRef('http://purl.org/heals/ingredient/escarole'),
#  'nutmeg': rdflib.term.URIRef('http://purl.org/heals/ingredient/nutmeg'),
#  'boiling potatoes': rdflib.term.URIRef('http://purl.org/heals/ingredient/boiling_potatoes'),
#  'coarse salt': rdflib.term.URIRef('http://purl.org/heals/ingredient/coarse_salt'),
#  'fresh spinach leaves': rdflib.term.URIRef('http://purl.org/heals/ingredient/fresh_spinach_leaves'),
#  'dried thyme': rdflib.term.URIRef('http://purl.org/heals/ingredient/dried_thyme'),
#  'apple juice': rdflib.term.URIRef('http://purl.org/heals/ingredient/apple_juice'),
#  'fresh parsley': rdflib.term.URIRef('http://purl.org/heals/ingredient/fresh_parsley'),
#  'scallion': rdflib.term.URIRef('http://purl.org/heals/ingredient/scallion'),
#  'rolled oats': rdflib.term.URIRef('http://purl.org/heals/ingredient/rolled_oats'),
#  'white pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/white_pepper'),
#  'broth': rdflib.term.URIRef('http://purl.org/heals/ingredient/broth'),
#  'spinach': rdflib.term.URIRef('http://purl.org/heals/ingredient/spinach'),
#  'condensed cream of chicken soup': rdflib.term.URIRef('http://purl.org/heals/ingredient/condensed_cream_of_chicken_soup'),
#  'boneless skinless chicken breast halves': rdflib.term.URIRef('http://purl.org/heals/ingredient/boneless_skinless_chicken_breast_halves'),
#  'seasoning salt': rdflib.term.URIRef('http://purl.org/heals/ingredient/seasoning_salt'),
#  'ground cinnamon': rdflib.term.URIRef('http://purl.org/heals/ingredient/ground_cinnamon'),
#  'bread': rdflib.term.URIRef('http://purl.org/heals/ingredient/bread'),
#  'egg yolks': rdflib.term.URIRef('http://purl.org/heals/ingredient/egg_yolks'),
#  'lemon, juice of': rdflib.term.URIRef('http://purl.org/heals/ingredient/lemon_juice_of'),
#  'ground turmeric': rdflib.term.URIRef('http://purl.org/heals/ingredient/ground_turmeric'),
#  'black cumin': rdflib.term.URIRef('http://purl.org/heals/ingredient/black_cumin'),
#  'ground black pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/ground_black_pepper'),
#  'ground ginger': rdflib.term.URIRef('http://purl.org/heals/ingredient/ground_ginger'),
#  'vegetarian ground beef': rdflib.term.URIRef('http://purl.org/heals/ingredient/vegetarian_ground_beef'),
#  'red pepper flakes': rdflib.term.URIRef('http://purl.org/heals/ingredient/red_pepper_flakes'),
#  'jalapenos': rdflib.term.URIRef('http://purl.org/heals/ingredient/jalapenos'),
#  'beef bouillon cube': rdflib.term.URIRef('http://purl.org/heals/ingredient/beef_bouillon_cube'),
#  'garbanzo beans': rdflib.term.URIRef('http://purl.org/heals/ingredient/garbanzo_beans'),
#  'ground pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/ground_pepper'),
#  'parmesan cheese': rdflib.term.URIRef('http://purl.org/heals/ingredient/parmesan_cheese'),
#  'beef stew meat': rdflib.term.URIRef('http://purl.org/heals/ingredient/beef_stew_meat'),
#  'dried parsley': rdflib.term.URIRef('http://purl.org/heals/ingredient/dried_parsley'),
#  'ground thyme': rdflib.term.URIRef('http://purl.org/heals/ingredient/ground_thyme'),
#  'elbow macaroni': rdflib.term.URIRef('http://purl.org/heals/ingredient/elbow_macaroni'),
#  'zucchini': rdflib.term.URIRef('http://purl.org/heals/ingredient/zucchini'),
#  'margarine': rdflib.term.URIRef('http://purl.org/heals/ingredient/margarine'),
#  'red potatoes': rdflib.term.URIRef('http://purl.org/heals/ingredient/red_potatoes'),
#  'dry white wine': rdflib.term.URIRef('http://purl.org/heals/ingredient/dry_white_wine'),
#  'black beans': rdflib.term.URIRef('http://purl.org/heals/ingredient/black_beans'),
#  'salt & fresh ground pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/salt_fresh_ground_pepper'),
#  'chicken stock': rdflib.term.URIRef('http://purl.org/heals/ingredient/chicken_stock'),
#  'worcestershire sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/worcestershire_sauce'),
#  'heavy cream': rdflib.term.URIRef('http://purl.org/heals/ingredient/heavy_cream'),
#  'tabasco sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/tabasco_sauce'),
#  'smoked chicken': rdflib.term.URIRef('http://purl.org/heals/ingredient/smoked_chicken'),
#  'dried oregano': rdflib.term.URIRef('http://purl.org/heals/ingredient/dried_oregano'),
#  'broccoli stem': rdflib.term.URIRef('http://purl.org/heals/ingredient/broccoli_stem'),
#  'dried sweet basil leaves': rdflib.term.URIRef('http://purl.org/heals/ingredient/dried_sweet_basil_leaves'),
#  'baking cocoa': rdflib.term.URIRef('http://purl.org/heals/ingredient/baking_cocoa'),
#  'miniature peppermint patties': rdflib.term.URIRef('http://purl.org/heals/ingredient/miniature_peppermint_patties'),
#  'whole kernel corn': rdflib.term.URIRef('http://purl.org/heals/ingredient/whole_kernel_corn'),
#  'taco sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/taco_sauce'),
#  'hot chili pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/hot_chili_pepper'),
#  'sliced ripe olives': rdflib.term.URIRef('http://purl.org/heals/ingredient/sliced_ripe_olives'),
#  'cornmeal': rdflib.term.URIRef('http://purl.org/heals/ingredient/cornmeal'),
#  'dry ranch dressing mix': rdflib.term.URIRef('http://purl.org/heals/ingredient/dry_ranch_dressing_mix'),
#  'french bread': rdflib.term.URIRef('http://purl.org/heals/ingredient/french_bread'),
#  'egg substitute': rdflib.term.URIRef('http://purl.org/heals/ingredient/egg_substitute'),
#  'non-fat powdered milk': rdflib.term.URIRef('http://purl.org/heals/ingredient/non_fat_powdered_milk'),
#  'ground venison': rdflib.term.URIRef('http://purl.org/heals/ingredient/ground_venison'),
#  'fresh breadcrumb': rdflib.term.URIRef('http://purl.org/heals/ingredient/fresh_breadcrumb'),
#  'frozen juice concentrate': rdflib.term.URIRef('http://purl.org/heals/ingredient/frozen_juice_concentrate'),
#  'plain yogurt': rdflib.term.URIRef('http://purl.org/heals/ingredient/plain_yogurt'),
#  'low sodium chicken broth': rdflib.term.URIRef('http://purl.org/heals/ingredient/low_sodium_chicken_broth'),
#  'wax beans': rdflib.term.URIRef('http://purl.org/heals/ingredient/wax_beans'),
#  'green beans': rdflib.term.URIRef('http://purl.org/heals/ingredient/green_beans'),
#  'corn': rdflib.term.URIRef('http://purl.org/heals/ingredient/corn'),
#  'sharp cheddar cheese': rdflib.term.URIRef('http://purl.org/heals/ingredient/sharp_cheddar_cheese'),
#  'condensed cream of mushroom soup': rdflib.term.URIRef('http://purl.org/heals/ingredient/condensed_cream_of_mushroom_soup'),
#  'crouton': rdflib.term.URIRef('http://purl.org/heals/ingredient/crouton'),
#  'frozen chopped spinach': rdflib.term.URIRef('http://purl.org/heals/ingredient/frozen_chopped_spinach'),
#  'plain low-fat yogurt': rdflib.term.URIRef('http://purl.org/heals/ingredient/plain_low_fat_yogurt'),
#  'celery seed': rdflib.term.URIRef('http://purl.org/heals/ingredient/celery_seed'),
#  'low-fat sour cream': rdflib.term.URIRef('http://purl.org/heals/ingredient/low_fat_sour_cream'),
#  'prepared mustard': rdflib.term.URIRef('http://purl.org/heals/ingredient/prepared_mustard'),
#  'fat-free mayonnaise': rdflib.term.URIRef('http://purl.org/heals/ingredient/fat_free_mayonnaise'),
#  'diced pimentos': rdflib.term.URIRef('http://purl.org/heals/ingredient/diced_pimentos'),
#  'white wine vinegar': rdflib.term.URIRef('http://purl.org/heals/ingredient/white_wine_vinegar'),
#  'soft breadcrumbs': rdflib.term.URIRef('http://purl.org/heals/ingredient/soft_breadcrumbs'),
#  'sage': rdflib.term.URIRef('http://purl.org/heals/ingredient/sage'),
#  'frozen vegetables': rdflib.term.URIRef('http://purl.org/heals/ingredient/frozen_vegetables'),
#  'condensed cream of mushroom & garlic soup': rdflib.term.URIRef('http://purl.org/heals/ingredient/condensed_cream_of_mushroom_garlic_soup'),
#  'salt & pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/salt_pepper'),
#  'cornbread mix': rdflib.term.URIRef('http://purl.org/heals/ingredient/cornbread_mix'),
#  'cream of mushroom soup': rdflib.term.URIRef('http://purl.org/heals/ingredient/cream_of_mushroom_soup'),
#  'toasted sesame oil': rdflib.term.URIRef('http://purl.org/heals/ingredient/toasted_sesame_oil'),
#  'angel hair pasta': rdflib.term.URIRef('http://purl.org/heals/ingredient/angel_hair_pasta'),
#  'toasted sesame seeds': rdflib.term.URIRef('http://purl.org/heals/ingredient/toasted_sesame_seeds'),
#  'stir fry vegetables': rdflib.term.URIRef('http://purl.org/heals/ingredient/stir_fry_vegetables'),
#  'green onions': rdflib.term.URIRef('http://purl.org/heals/ingredient/green_onions'),
#  'buckwheat flour': rdflib.term.URIRef('http://purl.org/heals/ingredient/buckwheat_flour'),
#  'ground cloves': rdflib.term.URIRef('http://purl.org/heals/ingredient/ground_cloves'),
#  'yam': rdflib.term.URIRef('http://purl.org/heals/ingredient/yam'),
#  'unsweetened cocoa': rdflib.term.URIRef('http://purl.org/heals/ingredient/unsweetened_cocoa'),
#  'pecans': rdflib.term.URIRef('http://purl.org/heals/ingredient/pecans'),
#  'low-fat buttermilk': rdflib.term.URIRef('http://purl.org/heals/ingredient/low_fat_buttermilk'),
#  'cinnamon': rdflib.term.URIRef('http://purl.org/heals/ingredient/cinnamon'),
#  'raisins': rdflib.term.URIRef('http://purl.org/heals/ingredient/raisins'),
#  'boiling water': rdflib.term.URIRef('http://purl.org/heals/ingredient/boiling_water'),
#  'sorghum': rdflib.term.URIRef('http://purl.org/heals/ingredient/sorghum'),
#  'american cheese': rdflib.term.URIRef('http://purl.org/heals/ingredient/american_cheese'),
#  'prepared yellow mustard': rdflib.term.URIRef('http://purl.org/heals/ingredient/prepared_yellow_mustard'),
#  'beer': rdflib.term.URIRef('http://purl.org/heals/ingredient/beer'),
#  'cayenne': rdflib.term.URIRef('http://purl.org/heals/ingredient/cayenne'),
#  'chives': rdflib.term.URIRef('http://purl.org/heals/ingredient/chives'),
#  'sweet pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/sweet_pepper'),
#  'cider vinegar': rdflib.term.URIRef('http://purl.org/heals/ingredient/cider_vinegar'),
#  'ham': rdflib.term.URIRef('http://purl.org/heals/ingredient/ham'),
#  'italian seasoning': rdflib.term.URIRef('http://purl.org/heals/ingredient/italian_seasoning'),
#  'onion powder': rdflib.term.URIRef('http://purl.org/heals/ingredient/onion_powder'),
#  'dill pickles': rdflib.term.URIRef('http://purl.org/heals/ingredient/dill_pickles'),
#  'tri-color spiral pasta': rdflib.term.URIRef('http://purl.org/heals/ingredient/tri_color_spiral_pasta'),
#  'water chestnut': rdflib.term.URIRef('http://purl.org/heals/ingredient/water_chestnut'),
#  'salt & freshly ground black pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/salt_freshly_ground_black_pepper'),
#  'frozen french fries': rdflib.term.URIRef('http://purl.org/heals/ingredient/frozen_french_fries'),
#  'flat leaf parsley': rdflib.term.URIRef('http://purl.org/heals/ingredient/flat_leaf_parsley'),
#  'good seasonings italian salad dressing mix': rdflib.term.URIRef('http://purl.org/heals/ingredient/good_seasonings_italian_salad_dressing_mix'),
#  'sandwich bun': rdflib.term.URIRef('http://purl.org/heals/ingredient/sandwich_bun'),
#  'swiss cheese': rdflib.term.URIRef('http://purl.org/heals/ingredient/swiss_cheese'),
#  'pepperoni': rdflib.term.URIRef('http://purl.org/heals/ingredient/pepperoni'),
#  'deli turkey': rdflib.term.URIRef('http://purl.org/heals/ingredient/deli_turkey'),
#  'mozzarella cheese': rdflib.term.URIRef('http://purl.org/heals/ingredient/mozzarella_cheese'),
#  'icing sugar': rdflib.term.URIRef('http://purl.org/heals/ingredient/icing_sugar'),
#  'shortening': rdflib.term.URIRef('http://purl.org/heals/ingredient/shortening'),
#  'vanilla instant pudding mix': rdflib.term.URIRef('http://purl.org/heals/ingredient/vanilla_instant_pudding_mix'),
#  'crushed pineapple': rdflib.term.URIRef('http://purl.org/heals/ingredient/crushed_pineapple'),
#  'yellow cake mix': rdflib.term.URIRef('http://purl.org/heals/ingredient/yellow_cake_mix'),
#  'jiffy corn muffin mix': rdflib.term.URIRef('http://purl.org/heals/ingredient/jiffy_corn_muffin_mix'),
#  'nuts': rdflib.term.URIRef('http://purl.org/heals/ingredient/nuts'),
#  'dry yeast': rdflib.term.URIRef('http://purl.org/heals/ingredient/dry_yeast'),
#  'cottage cheese': rdflib.term.URIRef('http://purl.org/heals/ingredient/cottage_cheese'),
#  'ricotta cheese': rdflib.term.URIRef('http://purl.org/heals/ingredient/ricotta_cheese'),
#  'whole tomato': rdflib.term.URIRef('http://purl.org/heals/ingredient/whole_tomato'),
#  'parsley flakes': rdflib.term.URIRef('http://purl.org/heals/ingredient/parsley_flakes'),
#  'lasagna noodle': rdflib.term.URIRef('http://purl.org/heals/ingredient/lasagna_noodle'),
#  'italian sausage': rdflib.term.URIRef('http://purl.org/heals/ingredient/italian_sausage'),
#  'toasted wheat germ': rdflib.term.URIRef('http://purl.org/heals/ingredient/toasted_wheat_germ'),
#  'spices': rdflib.term.URIRef('http://purl.org/heals/ingredient/spices'),
#  'herbs': rdflib.term.URIRef('http://purl.org/heals/ingredient/herbs'),
#  'olive oil flavored cooking spray': rdflib.term.URIRef('http://purl.org/heals/ingredient/olive_oil_flavored_cooking_spray'),
#  'instant vanilla pudding': rdflib.term.URIRef('http://purl.org/heals/ingredient/instant_vanilla_pudding'),
#  'rolls': rdflib.term.URIRef('http://purl.org/heals/ingredient/rolls'),
#  'white onion': rdflib.term.URIRef('http://purl.org/heals/ingredient/white_onion'),
#  'prego spaghetti sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/prego_spaghetti_sauce'),
#  'stewed tomatoes': rdflib.term.URIRef('http://purl.org/heals/ingredient/stewed_tomatoes'),
#  'spicy mustard': rdflib.term.URIRef('http://purl.org/heals/ingredient/spicy_mustard'),
#  'dried dill weed': rdflib.term.URIRef('http://purl.org/heals/ingredient/dried_dill_weed'),
#  'ketchup': rdflib.term.URIRef('http://purl.org/heals/ingredient/ketchup'),
#  'beef steaks': rdflib.term.URIRef('http://purl.org/heals/ingredient/beef_steaks'),
#  'salsa': rdflib.term.URIRef('http://purl.org/heals/ingredient/salsa'),
#  'chicken breasts': rdflib.term.URIRef('http://purl.org/heals/ingredient/chicken_breasts'),
#  'button mushrooms': rdflib.term.URIRef('http://purl.org/heals/ingredient/button_mushrooms'),
#  'pasta': rdflib.term.URIRef('http://purl.org/heals/ingredient/pasta'),
#  'fresh herbs': rdflib.term.URIRef('http://purl.org/heals/ingredient/fresh_herbs'),
#  'fat': rdflib.term.URIRef('http://purl.org/heals/ingredient/fat'),
#  'fresh corn': rdflib.term.URIRef('http://purl.org/heals/ingredient/fresh_corn'),
#  'cream': rdflib.term.URIRef('http://purl.org/heals/ingredient/cream'),
#  'fettuccine pasta': rdflib.term.URIRef('http://purl.org/heals/ingredient/fettuccine_pasta'),
#  'black olives': rdflib.term.URIRef('http://purl.org/heals/ingredient/black_olives'),
#  'jalapeno': rdflib.term.URIRef('http://purl.org/heals/ingredient/jalapeno'),
#  'picante sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/picante_sauce'),
#  'cheddar cheese soup': rdflib.term.URIRef('http://purl.org/heals/ingredient/cheddar_cheese_soup'),
#  'lemons, juice of': rdflib.term.URIRef('http://purl.org/heals/ingredient/lemons_juice_of'),
#  'frozen peas': rdflib.term.URIRef('http://purl.org/heals/ingredient/frozen_peas'),
#  'hass avocado': rdflib.term.URIRef('http://purl.org/heals/ingredient/hass_avocado'),
#  'yogurt': rdflib.term.URIRef('http://purl.org/heals/ingredient/yogurt'),
#  'unflavored gelatin': rdflib.term.URIRef('http://purl.org/heals/ingredient/unflavored_gelatin'),
#  'pear': rdflib.term.URIRef('http://purl.org/heals/ingredient/pear'),
#  'cream cheese': rdflib.term.URIRef('http://purl.org/heals/ingredient/cream_cheese'),
#  'veal roast': rdflib.term.URIRef('http://purl.org/heals/ingredient/veal_roast'),
#  'parsley sprigs': rdflib.term.URIRef('http://purl.org/heals/ingredient/parsley_sprigs'),
#  'bay leaf': rdflib.term.URIRef('http://purl.org/heals/ingredient/bay_leaf'),
#  'crackers': rdflib.term.URIRef('http://purl.org/heals/ingredient/crackers'),
#  'kalamata olive': rdflib.term.URIRef('http://purl.org/heals/ingredient/kalamata_olive'),
#  'ciabatta': rdflib.term.URIRef('http://purl.org/heals/ingredient/ciabatta'),
#  'fresh basil': rdflib.term.URIRef('http://purl.org/heals/ingredient/fresh_basil'),
#  'brine': rdflib.term.URIRef('http://purl.org/heals/ingredient/brine'),
#  'oregano leaves': rdflib.term.URIRef('http://purl.org/heals/ingredient/oregano_leaves'),
#  'capers': rdflib.term.URIRef('http://purl.org/heals/ingredient/capers'),
#  'provolone cheese': rdflib.term.URIRef('http://purl.org/heals/ingredient/provolone_cheese'),
#  'sweet onion': rdflib.term.URIRef('http://purl.org/heals/ingredient/sweet_onion'),
#  'genoa salami': rdflib.term.URIRef('http://purl.org/heals/ingredient/genoa_salami'),
#  'gelatin': rdflib.term.URIRef('http://purl.org/heals/ingredient/gelatin'),
#  'cookie': rdflib.term.URIRef('http://purl.org/heals/ingredient/cookie'),
#  'prepared graham cracker crusts': rdflib.term.URIRef('http://purl.org/heals/ingredient/prepared_graham_cracker_crusts'),
#  'miniature semisweet chocolate chips': rdflib.term.URIRef('http://purl.org/heals/ingredient/miniature_semisweet_chocolate_chips'),
#  'monterey jack cheese': rdflib.term.URIRef('http://purl.org/heals/ingredient/monterey_jack_cheese'),
#  'cloves': rdflib.term.URIRef('http://purl.org/heals/ingredient/cloves'),
#  'cayenne pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/cayenne_pepper'),
#  'vegetable shortening': rdflib.term.URIRef('http://purl.org/heals/ingredient/vegetable_shortening'),
#  'sliced mushrooms': rdflib.term.URIRef('http://purl.org/heals/ingredient/sliced_mushrooms'),
#  'half-and-half': rdflib.term.URIRef('http://purl.org/heals/ingredient/half_and_half'),
#  'sweet corn': rdflib.term.URIRef('http://purl.org/heals/ingredient/sweet_corn'),
#  'sweet butter': rdflib.term.URIRef('http://purl.org/heals/ingredient/sweet_butter'),
#  'lemon, rind of': rdflib.term.URIRef('http://purl.org/heals/ingredient/lemon_rind_of'),
#  'unsweetened chocolate squares': rdflib.term.URIRef('http://purl.org/heals/ingredient/unsweetened_chocolate_squares'),
#  'reduced sodium soy sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/reduced_sodium_soy_sauce'),
#  'sesame seeds': rdflib.term.URIRef('http://purl.org/heals/ingredient/sesame_seeds'),
#  'chili-garlic sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/chili_garlic_sauce'),
#  'rice vinegar': rdflib.term.URIRef('http://purl.org/heals/ingredient/rice_vinegar'),
#  'cooked chicken': rdflib.term.URIRef('http://purl.org/heals/ingredient/cooked_chicken'),
#  'broccoli': rdflib.term.URIRef('http://purl.org/heals/ingredient/broccoli'),
#  'vermicelli': rdflib.term.URIRef('http://purl.org/heals/ingredient/vermicelli'),
#  'fresh cilantro': rdflib.term.URIRef('http://purl.org/heals/ingredient/fresh_cilantro'),
#  'philadelphia cream cheese': rdflib.term.URIRef('http://purl.org/heals/ingredient/philadelphia_cream_cheese'),
#  'apples': rdflib.term.URIRef('http://purl.org/heals/ingredient/apples'),
#  'boneless chicken breast': rdflib.term.URIRef('http://purl.org/heals/ingredient/boneless_chicken_breast'),
#  'fresh ground pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/fresh_ground_pepper'),
#  'baking potato': rdflib.term.URIRef('http://purl.org/heals/ingredient/baking_potato'),
#  'part-skim ricotta cheese': rdflib.term.URIRef('http://purl.org/heals/ingredient/part_skim_ricotta_cheese'),
#  'white wine': rdflib.term.URIRef('http://purl.org/heals/ingredient/white_wine'),
#  'tomato puree': rdflib.term.URIRef('http://purl.org/heals/ingredient/tomato_puree'),
#  'sodium-free vegetable broth': rdflib.term.URIRef('http://purl.org/heals/ingredient/sodium_free_vegetable_broth'),
#  'mushroom pieces': rdflib.term.URIRef('http://purl.org/heals/ingredient/mushroom_pieces'),
#  'white kidney beans': rdflib.term.URIRef('http://purl.org/heals/ingredient/white_kidney_beans'),
#  'albacore tuna in water': rdflib.term.URIRef('http://purl.org/heals/ingredient/albacore_tuna_in_water'),
#  'scallions': rdflib.term.URIRef('http://purl.org/heals/ingredient/scallions'),
#  'bibb lettuce': rdflib.term.URIRef('http://purl.org/heals/ingredient/bibb_lettuce'),
#  'light olive oil': rdflib.term.URIRef('http://purl.org/heals/ingredient/light_olive_oil'),
#  'red sweet bell peppers': rdflib.term.URIRef('http://purl.org/heals/ingredient/red_sweet_bell_peppers'),
#  'crushed tomatoes': rdflib.term.URIRef('http://purl.org/heals/ingredient/crushed_tomatoes'),
#  'lean ground beef': rdflib.term.URIRef('http://purl.org/heals/ingredient/lean_ground_beef'),
#  'penne pasta': rdflib.term.URIRef('http://purl.org/heals/ingredient/penne_pasta'),
#  'beef consomme': rdflib.term.URIRef('http://purl.org/heals/ingredient/beef_consomme'),
#  'rubbed sage': rdflib.term.URIRef('http://purl.org/heals/ingredient/rubbed_sage'),
#  'red cinnamon candies': rdflib.term.URIRef('http://purl.org/heals/ingredient/red_cinnamon_candies'),
#  'sugar substitute': rdflib.term.URIRef('http://purl.org/heals/ingredient/sugar_substitute'),
#  'fresh tomato': rdflib.term.URIRef('http://purl.org/heals/ingredient/fresh_tomato'),
#  'cucumber': rdflib.term.URIRef('http://purl.org/heals/ingredient/cucumber'),
#  'hot water': rdflib.term.URIRef('http://purl.org/heals/ingredient/hot_water'),
#  'cocoa': rdflib.term.URIRef('http://purl.org/heals/ingredient/cocoa'),
#  'apple pie filling': rdflib.term.URIRef('http://purl.org/heals/ingredient/apple_pie_filling'),
#  'toasted almonds': rdflib.term.URIRef('http://purl.org/heals/ingredient/toasted_almonds'),
#  'white bread': rdflib.term.URIRef('http://purl.org/heals/ingredient/white_bread'),
#  'poultry seasoning': rdflib.term.URIRef('http://purl.org/heals/ingredient/poultry_seasoning'),
#  'breadcrumbs': rdflib.term.URIRef('http://purl.org/heals/ingredient/breadcrumbs'),
#  'boneless skinless chicken thighs': rdflib.term.URIRef('http://purl.org/heals/ingredient/boneless_skinless_chicken_thighs'),
#  'salmon': rdflib.term.URIRef('http://purl.org/heals/ingredient/salmon'),
#  'peanut oil': rdflib.term.URIRef('http://purl.org/heals/ingredient/peanut_oil'),
#  'vegetable stock': rdflib.term.URIRef('http://purl.org/heals/ingredient/vegetable_stock'),
#  'ground cayenne pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/ground_cayenne_pepper'),
#  'red chili pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/red_chili_pepper'),
#  'bean sprouts': rdflib.term.URIRef('http://purl.org/heals/ingredient/bean_sprouts'),
#  'sambal oelek': rdflib.term.URIRef('http://purl.org/heals/ingredient/sambal_oelek'),
#  'ginger': rdflib.term.URIRef('http://purl.org/heals/ingredient/ginger'),
#  'desiccated coconut': rdflib.term.URIRef('http://purl.org/heals/ingredient/desiccated_coconut'),
#  'peanuts': rdflib.term.URIRef('http://purl.org/heals/ingredient/peanuts'),
#  'tempeh': rdflib.term.URIRef('http://purl.org/heals/ingredient/tempeh'),
#  'dried breadcrumbs': rdflib.term.URIRef('http://purl.org/heals/ingredient/dried_breadcrumbs'),
#  'avocado': rdflib.term.URIRef('http://purl.org/heals/ingredient/avocado'),
#  'chunky salsa': rdflib.term.URIRef('http://purl.org/heals/ingredient/chunky_salsa'),
#  'lime juice': rdflib.term.URIRef('http://purl.org/heals/ingredient/lime_juice'),
#  'soft silken tofu': rdflib.term.URIRef('http://purl.org/heals/ingredient/soft_silken_tofu'),
#  'boneless skinless chicken breast': rdflib.term.URIRef('http://purl.org/heals/ingredient/boneless_skinless_chicken_breast'),
#  'mustard': rdflib.term.URIRef('http://purl.org/heals/ingredient/mustard'),
#  'beef ribs': rdflib.term.URIRef('http://purl.org/heals/ingredient/beef_ribs'),
#  'egg whites': rdflib.term.URIRef('http://purl.org/heals/ingredient/egg_whites'),
#  'green grape': rdflib.term.URIRef('http://purl.org/heals/ingredient/green_grape'),
#  'betty crocker fudge brownie mix': rdflib.term.URIRef('http://purl.org/heals/ingredient/betty_crocker_fudge_brownie_mix'),
#  'milk chocolate candy bars': rdflib.term.URIRef('http://purl.org/heals/ingredient/milk_chocolate_candy_bars'),
#  'chocolate chips': rdflib.term.URIRef('http://purl.org/heals/ingredient/chocolate_chips'),
#  'sweetened condensed milk': rdflib.term.URIRef('http://purl.org/heals/ingredient/sweetened_condensed_milk'),
#  'oreo cookie crumbs': rdflib.term.URIRef('http://purl.org/heals/ingredient/oreo_cookie_crumbs'),
#  'sugar-free non-fat vanilla yogurt': rdflib.term.URIRef('http://purl.org/heals/ingredient/sugar_free_non_fat_vanilla_yogurt'),
#  '2% low-fat milk': rdflib.term.URIRef('http://purl.org/heals/ingredient/2_low_fat_milk'),
#  'natural-style peanut butter': rdflib.term.URIRef('http://purl.org/heals/ingredient/natural_style_peanut_butter'),
#  'taco seasoning': rdflib.term.URIRef('http://purl.org/heals/ingredient/taco_seasoning'),
#  'bean dip': rdflib.term.URIRef('http://purl.org/heals/ingredient/bean_dip'),
#  "mccormick's montreal brand steak seasoning": rdflib.term.URIRef('http://purl.org/heals/ingredient/mccormick_s_montreal_brand_steak_seasoning'),
#  'iceberg lettuce': rdflib.term.URIRef('http://purl.org/heals/ingredient/iceberg_lettuce'),
#  'no-salt-added ketchup': rdflib.term.URIRef('http://purl.org/heals/ingredient/no_salt_added_ketchup'),
#  'dill weed': rdflib.term.URIRef('http://purl.org/heals/ingredient/dill_weed'),
#  'ground sirloin': rdflib.term.URIRef('http://purl.org/heals/ingredient/ground_sirloin'),
#  'chat masala': rdflib.term.URIRef('http://purl.org/heals/ingredient/chat_masala'),
#  'chopped tomato': rdflib.term.URIRef('http://purl.org/heals/ingredient/chopped_tomato'),
#  'corn oil': rdflib.term.URIRef('http://purl.org/heals/ingredient/corn_oil'),
#  'natural bran': rdflib.term.URIRef('http://purl.org/heals/ingredient/natural_bran'),
#  'buttermilk': rdflib.term.URIRef('http://purl.org/heals/ingredient/buttermilk'),
#  'tequila': rdflib.term.URIRef('http://purl.org/heals/ingredient/tequila'),
#  'triple sec': rdflib.term.URIRef('http://purl.org/heals/ingredient/triple_sec'),
#  'grand marnier': rdflib.term.URIRef('http://purl.org/heals/ingredient/grand_marnier'),
#  'limeade': rdflib.term.URIRef('http://purl.org/heals/ingredient/limeade'),
#  'lime wedge': rdflib.term.URIRef('http://purl.org/heals/ingredient/lime_wedge'),
#  'semi-sweet chocolate chips': rdflib.term.URIRef('http://purl.org/heals/ingredient/semi_sweet_chocolate_chips'),
#  'cappelletti pasta': rdflib.term.URIRef('http://purl.org/heals/ingredient/cappelletti_pasta'),
#  'mushrooms': rdflib.term.URIRef('http://purl.org/heals/ingredient/mushrooms'),
#  'spaghetti': rdflib.term.URIRef('http://purl.org/heals/ingredient/spaghetti'),
#  'squid': rdflib.term.URIRef('http://purl.org/heals/ingredient/squid'),
#  'applesauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/applesauce'),
#  'pork loin chops': rdflib.term.URIRef('http://purl.org/heals/ingredient/pork_loin_chops'),
#  'radish sprouts': rdflib.term.URIRef('http://purl.org/heals/ingredient/radish_sprouts'),
#  'honey mustard': rdflib.term.URIRef('http://purl.org/heals/ingredient/honey_mustard'),
#  'whole wheat bread dough': rdflib.term.URIRef('http://purl.org/heals/ingredient/whole_wheat_bread_dough'),
#  'roasted red peppers': rdflib.term.URIRef('http://purl.org/heals/ingredient/roasted_red_peppers'),
#  'turkey': rdflib.term.URIRef('http://purl.org/heals/ingredient/turkey'),
#  'leaf lettuce': rdflib.term.URIRef('http://purl.org/heals/ingredient/leaf_lettuce'),
#  'roast beef': rdflib.term.URIRef('http://purl.org/heals/ingredient/roast_beef'),
#  'wild mushrooms': rdflib.term.URIRef('http://purl.org/heals/ingredient/wild_mushrooms'),
#  'fresh dill': rdflib.term.URIRef('http://purl.org/heals/ingredient/fresh_dill'),
#  'rice wine vinegar': rdflib.term.URIRef('http://purl.org/heals/ingredient/rice_wine_vinegar'),
#  'asian chili sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/asian_chili_sauce'),
#  'rice noodles': rdflib.term.URIRef('http://purl.org/heals/ingredient/rice_noodles'),
#  'english cucumber': rdflib.term.URIRef('http://purl.org/heals/ingredient/english_cucumber'),
#  'light soy sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/light_soy_sauce'),
#  'kosher salt': rdflib.term.URIRef('http://purl.org/heals/ingredient/kosher_salt'),
#  'brewed espresso': rdflib.term.URIRef('http://purl.org/heals/ingredient/brewed_espresso'),
#  'unsweetened cocoa powder': rdflib.term.URIRef('http://purl.org/heals/ingredient/unsweetened_cocoa_powder'),
#  'bittersweet chocolate': rdflib.term.URIRef('http://purl.org/heals/ingredient/bittersweet_chocolate'),
#  'dr. pepper cola': rdflib.term.URIRef('http://purl.org/heals/ingredient/dr_pepper_cola'),
#  'orange marmalade': rdflib.term.URIRef('http://purl.org/heals/ingredient/orange_marmalade'),
#  'low sodium soy sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/low_sodium_soy_sauce'),
#  'fish': rdflib.term.URIRef('http://purl.org/heals/ingredient/fish'),
#  'gingerroot': rdflib.term.URIRef('http://purl.org/heals/ingredient/gingerroot'),
#  'rice wine': rdflib.term.URIRef('http://purl.org/heals/ingredient/rice_wine'),
#  'romano cheese': rdflib.term.URIRef('http://purl.org/heals/ingredient/romano_cheese'),
#  'sherry wine': rdflib.term.URIRef('http://purl.org/heals/ingredient/sherry_wine'),
#  'low sodium beef broth': rdflib.term.URIRef('http://purl.org/heals/ingredient/low_sodium_beef_broth'),
#  'squash': rdflib.term.URIRef('http://purl.org/heals/ingredient/squash'),
#  'cream of chicken soup': rdflib.term.URIRef('http://purl.org/heals/ingredient/cream_of_chicken_soup'),
#  'cornbread': rdflib.term.URIRef('http://purl.org/heals/ingredient/cornbread'),
#  'bay leaves': rdflib.term.URIRef('http://purl.org/heals/ingredient/bay_leaves'),
#  'bottled garlic': rdflib.term.URIRef('http://purl.org/heals/ingredient/bottled_garlic'),
#  'frozen broccoli cuts': rdflib.term.URIRef('http://purl.org/heals/ingredient/frozen_broccoli_cuts'),
#  'french-fried onions': rdflib.term.URIRef('http://purl.org/heals/ingredient/french_fried_onions'),
#  'almond extract': rdflib.term.URIRef('http://purl.org/heals/ingredient/almond_extract'),
#  'whole milk': rdflib.term.URIRef('http://purl.org/heals/ingredient/whole_milk'),
#  'pure vanilla extract': rdflib.term.URIRef('http://purl.org/heals/ingredient/pure_vanilla_extract'),
#  'unseasoned breadcrumbs': rdflib.term.URIRef('http://purl.org/heals/ingredient/unseasoned_breadcrumbs'),
#  'artichoke hearts': rdflib.term.URIRef('http://purl.org/heals/ingredient/artichoke_hearts'),
#  'barbecue sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/barbecue_sauce'),
#  'hot red pepper sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/hot_red_pepper_sauce'),
#  'frozen broccoli': rdflib.term.URIRef('http://purl.org/heals/ingredient/frozen_broccoli'),
#  'water chestnuts': rdflib.term.URIRef('http://purl.org/heals/ingredient/water_chestnuts'),
#  'ritz cracker crumbs': rdflib.term.URIRef('http://purl.org/heals/ingredient/ritz_cracker_crumbs'),
#  'dry onion soup mix': rdflib.term.URIRef('http://purl.org/heals/ingredient/dry_onion_soup_mix'),
#  'cool whip': rdflib.term.URIRef('http://purl.org/heals/ingredient/cool_whip'),
#  'instant chocolate pudding mix': rdflib.term.URIRef('http://purl.org/heals/ingredient/instant_chocolate_pudding_mix'),
#  'bouillon': rdflib.term.URIRef('http://purl.org/heals/ingredient/bouillon'),
#  'louisiana hot sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/louisiana_hot_sauce'),
#  'hunts tomato sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/hunts_tomato_sauce'),
#  'budweiser beer': rdflib.term.URIRef('http://purl.org/heals/ingredient/budweiser_beer'),
#  'coriander': rdflib.term.URIRef('http://purl.org/heals/ingredient/coriander'),
#  'lean chuck': rdflib.term.URIRef('http://purl.org/heals/ingredient/lean_chuck'),
#  'lean pork': rdflib.term.URIRef('http://purl.org/heals/ingredient/lean_pork'),
#  'simply potatoes shredded hash browns': rdflib.term.URIRef('http://purl.org/heals/ingredient/simply_potatoes_shredded_hash_browns'),
#  'unsmoked bacon': rdflib.term.URIRef('http://purl.org/heals/ingredient/unsmoked_bacon'),
#  'meatloaf mixture': rdflib.term.URIRef('http://purl.org/heals/ingredient/meatloaf_mixture'),
#  'baby spinach': rdflib.term.URIRef('http://purl.org/heals/ingredient/baby_spinach'),
#  'goat cheese': rdflib.term.URIRef('http://purl.org/heals/ingredient/goat_cheese'),
#  'pumpkin puree': rdflib.term.URIRef('http://purl.org/heals/ingredient/pumpkin_puree'),
#  'egg white': rdflib.term.URIRef('http://purl.org/heals/ingredient/egg_white'),
#  'pie crusts': rdflib.term.URIRef('http://purl.org/heals/ingredient/pie_crusts'),
#  'poppy seed': rdflib.term.URIRef('http://purl.org/heals/ingredient/poppy_seed'),
#  'dry onion flakes': rdflib.term.URIRef('http://purl.org/heals/ingredient/dry_onion_flakes'),
#  'blended oatmeal': rdflib.term.URIRef('http://purl.org/heals/ingredient/blended_oatmeal'),
#  'hershey chocolate candy bars': rdflib.term.URIRef('http://purl.org/heals/ingredient/hershey_chocolate_candy_bars'),
#  'oatmeal': rdflib.term.URIRef('http://purl.org/heals/ingredient/oatmeal'),
#  "hershey's semi-sweet baking chocolate": rdflib.term.URIRef('http://purl.org/heals/ingredient/hershey_s_semi_sweet_baking_chocolate'),
#  'taco shells': rdflib.term.URIRef('http://purl.org/heals/ingredient/taco_shells'),
#  'corn cobs': rdflib.term.URIRef('http://purl.org/heals/ingredient/corn_cobs'),
#  'mexican chili powder': rdflib.term.URIRef('http://purl.org/heals/ingredient/mexican_chili_powder'),
#  'dark chocolate chips': rdflib.term.URIRef('http://purl.org/heals/ingredient/dark_chocolate_chips'),
#  'habanero pepper': rdflib.term.URIRef('http://purl.org/heals/ingredient/habanero_pepper'),
#  'sazon goya': rdflib.term.URIRef('http://purl.org/heals/ingredient/sazon_goya'),
#  'light brown sugar': rdflib.term.URIRef('http://purl.org/heals/ingredient/light_brown_sugar'),
#  'beans': rdflib.term.URIRef('http://purl.org/heals/ingredient/beans'),
#  'stewing pork': rdflib.term.URIRef('http://purl.org/heals/ingredient/stewing_pork'),
#  'stewing beef': rdflib.term.URIRef('http://purl.org/heals/ingredient/stewing_beef'),
#  'bell peppers': rdflib.term.URIRef('http://purl.org/heals/ingredient/bell_peppers'),
#  'tortilla chips': rdflib.term.URIRef('http://purl.org/heals/ingredient/tortilla_chips'),
#  'chicken bouillon cube': rdflib.term.URIRef('http://purl.org/heals/ingredient/chicken_bouillon_cube'),
#  'pitted dates': rdflib.term.URIRef('http://purl.org/heals/ingredient/pitted_dates'),
#  'warm water': rdflib.term.URIRef('http://purl.org/heals/ingredient/warm_water'),
#  'orange-flavored liqueur': rdflib.term.URIRef('http://purl.org/heals/ingredient/orange_flavored_liqueur'),
#  'lime zest': rdflib.term.URIRef('http://purl.org/heals/ingredient/lime_zest'),
#  'lemon zest': rdflib.term.URIRef('http://purl.org/heals/ingredient/lemon_zest'),
#  'cream of celery soup': rdflib.term.URIRef('http://purl.org/heals/ingredient/cream_of_celery_soup'),
#  'potato flakes': rdflib.term.URIRef('http://purl.org/heals/ingredient/potato_flakes'),
#  'bouillon cubes': rdflib.term.URIRef('http://purl.org/heals/ingredient/bouillon_cubes'),
#  'macaroni': rdflib.term.URIRef('http://purl.org/heals/ingredient/macaroni'),
#  'muscat wine': rdflib.term.URIRef('http://purl.org/heals/ingredient/muscat_wine'),
#  'salt water': rdflib.term.URIRef('http://purl.org/heals/ingredient/salt_water'),
#  'fine semolina': rdflib.term.URIRef('http://purl.org/heals/ingredient/fine_semolina'),
#  'dried yellow peas': rdflib.term.URIRef('http://purl.org/heals/ingredient/dried_yellow_peas'),
#  'pork': rdflib.term.URIRef('http://purl.org/heals/ingredient/pork'),
#  'brown mustard': rdflib.term.URIRef('http://purl.org/heals/ingredient/brown_mustard'),
#  'ham bone': rdflib.term.URIRef('http://purl.org/heals/ingredient/ham_bone'),
#  'fresh spinach': rdflib.term.URIRef('http://purl.org/heals/ingredient/fresh_spinach'),
#  'wondra flour': rdflib.term.URIRef('http://purl.org/heals/ingredient/wondra_flour'),
#  'dried onion flakes': rdflib.term.URIRef('http://purl.org/heals/ingredient/dried_onion_flakes'),
#  'maple syrup': rdflib.term.URIRef('http://purl.org/heals/ingredient/maple_syrup'),
#  'tomato ketchup': rdflib.term.URIRef('http://purl.org/heals/ingredient/tomato_ketchup'),
#  'granulated garlic': rdflib.term.URIRef('http://purl.org/heals/ingredient/granulated_garlic'),
#  'ponzu sauce': rdflib.term.URIRef('http://purl.org/heals/ingredient/ponzu_sauce'),
#  'frozen whipped topping': rdflib.term.URIRef('http://purl.org/heals/ingredient/frozen_whipped_topping'),
#  'oreo cookies': rdflib.term.URIRef('http://purl.org/heals/ingredient/oreo_cookies'),
#  'processed cheese': rdflib.term.URIRef('http://purl.org/heals/ingredient/processed_cheese'),
#  'london broil beef': rdflib.term.URIRef('http://purl.org/heals/ingredient/london_broil_beef'),
#  'dry sherry': rdflib.term.URIRef('http://purl.org/heals/ingredient/dry_sherry'),
#  'dried rosemary': rdflib.term.URIRef('http://purl.org/heals/ingredient/dried_rosemary')}

# %% [markdown]
# Which among the pre-defined ingredients did we **miss** from adding to our KG?

# %%
for label in pre_def:
    if label not in kg._SYNONYMS and label not in kg._INGREDIENTS:
        ind, _, descrip = IND_DF.loc[IND_DF["label"] == label].values[0]
        entity = ind.split(":")[1]
        ic(entity, label, descrip)
        kg.add_ind(label, entity)

# %% [markdown]
# For each identified "miss":
#
#   * add to the synonyms list as needed
#   * iterate from the `Analyze Ingredients` section forward

# %% [markdown]
# ### Construct KG
# Add the recipe entities to the KG:

# %%
for r in RECIPES:
    has_all_ind = True
    
    for ind in r.ind_set:
        if ind not in kg._INGREDIENTS:
            unknown_ind[ind] += 1
            has_all_ind = False

    if has_all_ind:
        node = rdflib.URIRef(f"https://www.food.com/recipe/{r.id}")
        kg.add( node, kg.get_ns("rdf").type, kg.get_ns("wtm").Recipe )
        kg.add( node, kg.get_ns("skos").definition, rdflib.Literal(r.definition) )

        code_time_node = rdflib.Literal(f"PT{r.cook_time}M", datatype=kg.get_ns("xsd").duration)
        kg.add( node, kg.get_ns("wtm").hasCookTime, code_time_node)

        for ind in r.ind_set:
            if ind == "cream of tartar":
                ic(node)
                break

            obj = kg._INGREDIENTS[ind]
            kg.add( node, kg.get_ns("wtm").hasIngredient, obj )

# %% [markdown]
# How many recipes dow we have now?

# %%
sparql = """
    SELECT ?rec
    WHERE {
        # ?rec rdf:type wtm:Recipe .
    }
"""

df = kg.query_as_df(sparql)
len(df)
# Out:
# 15407

# %%
measure = kglab.Measure()
measure.measure_graph(kg)

ic(measure.get_edge_count())
ic(measure.get_node_count())
# Out:
# ic| measure.get_edge_count(): 160980
# ic| measure.get_node_count(): 15983
# 15983

# %% [markdown]
# Serialize a "checkpoint" of our larger KG:

# %%
kg.save_rdf("recipe_lg.ttl")

# %%
1 / 0 # stop execution
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-26-a2092b948eca> in <module>
# ----> 1 1 / 0 # stop execution
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ---

# %% [markdown]
# ## Gensim Embedding...
#
# Now reshape this data into a vector of vectors of ingredients per recipe, to use for training a [*word2vec*](https://arxiv.org/abs/1301.3781) vector embedding model:

# %%
vectors = [
    [
        ind
        for ind in ind_set
    ]
    for id, ind_set in recipes
]

vectors[:3]

# %% [markdown]
# We'll use the [`Word2Vec`](https://radimrehurek.com/gensim/models/word2vec.html) implementation in the `gensim` library (i.e., *deep learning*) to train an embedding model.
# This approach tends to work best if the training data has at least 100K rows.
#
# Let's also show how to serialize the *word2vec* results, saving them to the `tmp.w2v` file so they could be restored later for other use cases.
#
# NB: there is work in progress which will replace `gensim` with `pytorch` instead.

# %%
import gensim

MIN_COUNT = 2
model_path = "tmp.w2v"

model = gensim.models.Word2Vec(vectors, min_count=MIN_COUNT, window=max_context)
model.save(model_path)

# %% [markdown]
# The `get_related()` function takes any ingredient as input, using the embedding model to find the most similar other ingredients – along with calculating [`levenshtein`](https://github.com/toastdriven/pylev) edit distances (string similarity) among these labels. Then it calculates *percentiles* for both metrics in [`numpy`](https://numpy.org/) and returns the results as a [`pandas`](https://pandas.pydata.org/) DataFrame.

# %%
import numpy as np
import pandas as pd
import pylev

def term_ratio (target, description):
    d_set = set(description.split(" "))
    num_inter = len(d_set.intersection(target))
    return num_inter / float(len(target))


def get_related (model, query, target, n=20, granularity=100):
    """return a DataFrame of the closely related items"""
    try:
        bins = np.linspace(0, 1, num=granularity, endpoint=True)

        v = sorted(
            model.wv.most_similar(positive=[query], topn=n), 
            key=lambda x: x[1], 
            reverse=True
        )
        
        df = pd.DataFrame(v, columns=["ingredient", "similarity"])
        
        s = df["similarity"]
        quantiles = s.quantile(bins, interpolation="nearest")
        df["sim_pct"] = np.digitize(s, quantiles) - 1
        
        df["levenshtein"] = [ pylev.levenshtein(d, query) / len(query) for d in df["ingredient"] ]
        s = df["levenshtein"]
        quantiles = s.quantile(bins, interpolation="nearest")
        df["lev_pct"] = granularity - np.digitize(s, quantiles)

        df["term_ratio"] = [ term_ratio(target, d) for d in df["ingredient"] ]

        return df
    except KeyError:
        return pd.DataFrame(columns=["ingredient", "similarity", "percentile"])

# %% [markdown]
# Let's try this with `dried basil` as the ingredient to query, and review the top `50` most similar other ingredients returned as the DataFrame `df`:

# %%
pd.set_option("max_rows", None)

target = set([ "basil" ])

df = get_related(model, "dried basil", target, n=50)
df

# %% [markdown]
# Note how some of the most similar items, based on vector embedding, are *synonyms* or special forms of our query `dried basil` ingredient: `dried basil leaves`, `dry basil`, `dried sweet basil leaves`, etc. These tend to rank high in terms of levenshtein distance too.

# %% [markdown]
# Let's plot the similarity measures:

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use("ggplot")

df["similarity"].plot(alpha=0.75, rot=0)
plt.show()

# %% [markdown]
# Notice the inflection points at approximately `0.56` and again at `0.47` in that plot.
# We could use some statistical techniques (e.g., clustering) to segment the similarities into a few groups:
#
#   * highest similarity – potential synonyms for the query
#   * mid-range similarity – potential [hypernyms and hyponyms](https://en.wikipedia.org/wiki/Hyponymy_and_hypernymy) for the query
#   * long-tail similarity – other ingredients that pair well with the query

# %% [markdown]
# In this example, below a threshold of the 75th percentile for vector embedding similarity, the related ingredients are less about being synonyms and more about other foods that pair well with basil.
#
# Let's define another function `rank_related()` which ranks the related ingredients based on a combination of these two metrics.
# This uses a cheap approximation of a [*pareto archive*](https://www.cs.bham.ac.uk/~jdk/multi/) for the ranking -- which comes in handy for recommender systems and custom search applications that must combine multiple ranking metrics:

# %%
from kglab import root_mean_square

def rank_related (df):
    df2 = df.copy(deep=True)
    df2["related"] = df2.apply(lambda row: root_mean_square([ row[2], row[4] ]), axis=1)
    return df2.sort_values(by=["related"], ascending=False)

# %%
df = rank_related(df)
df

# %% [markdown]
# Notice how the "synonym" cases tend to move up to the top now?
# Meanwhile while the "pairs well with" are in the lower half of the ranked list: `fresh mushrooms`, `italian turkey sausage`, `cooked spaghetti`, `white kidney beans`, etc.

# %%
df.loc[ (df["related"] >= 50) & (df["term_ratio"] > 0) ]

# %% [markdown]
# ---
#
# ## Exercises

# %% [markdown]
# **Exercise 1:**
#
# Build a report for a *human-in-the-loop* reviewer, using the `rank_related()` function while iterating over `vocab` to make algorithmic suggestions for possible synonyms.

# %% [markdown]
# **Exercise 2:**
#
# How would you make algorithmic suggestions for a reviewer about which ingredients could be related to a query, e.g., using the `skos:broader` and `skos:narrower` relations in the [`skos`](https://www.w3.org/2004/02/skos/) vocabulary to represent *hypernyms* and *hyponyms* respectively?
# This could extend the KG to provide a kind of thesaurus about recipe ingredients.
