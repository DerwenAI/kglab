# %% [markdown]
# # Vector embedding with `gensim`
#
# Let's make use of deep learning through a technique called *embedding* – to analyze the relatedness of the labels used for recipe ingredients.
#
# Among the most closely related ingredients:
#
#   * Some are very close synonyms and should be consolidated to improve data quality
#   * Others are interesting other ingredients that pair frequently, useful for recommendations
#
# On the one hand, this approach is quite helpful for analyzing the NLP annotations that go into a knowledge graph.
# On the other hand it can be used along with [`SKOS`](https://www.w3.org/2004/02/skos/) or similar vocabularies for ontology-based discovery within the graph, e.g., for advanced search UI.

# %% [markdown]
# ## Curating annotations
#
# We'll be working with the labels for ingredients that go into our KG.
# Looking at the raw data, there are many cases where slightly different spellings are being used for the same entity.
#
# As a first step let's define a list of synonyms to substitute, prior to running the vector embedding.
# This will help produce better quality results.
#
# Note that this kind of work comes of the general heading of *curating annotations* ... which is what we spend so much time doing in KG work.
# It's similar to how *data preparation* is ~80% of the workload for data science teams, and for good reason.

# %%
SYNONYMS = {
    "pepper": "black pepper",
    "black pepper": "black pepper",
    
    "egg": "egg",
    "eggs": "egg",

    "vanilla": "vanilla",
    "vanilla extract": "vanilla",
    
    "flour": "flour",
    "all-purpose flour": "flour",

    "onions": "onion",
    "onion": "onion",
        
    "carrots": "carrot",
    "carrot": "carrot",

    "potatoes": "potato",
    "potato": "potato",
    
    "tomatoes": "tomato",
    "fresh tomatoes": "tomato",
    "fresh tomato": "tomato",
    
    "garlic": "garlic",
    "garlic clove": "garlic",
    "garlic cloves": "garlic",
}

# %% [markdown]
# ## Analyze ingredient labels from 250K recipes

# %%
import csv

MAX_ROW = 250000 # 231638

max_context = 0
min_context = 1000

recipes = []
vocab = set()

with open("../dat/all_ind.csv", "r") as f:
    reader = csv.reader(f)
    next(reader, None) # remove file header

    for i, row in enumerate(reader):
        id = row[0]
        ind_set = set()
        
        # substitute synonyms
        for ind in set(eval(row[3])):
            if ind in SYNONYMS:
                ind_set.add(SYNONYMS[ind])
            else:
                ind_set.add(ind)
        
        if len(ind_set) > 1:
            recipes.append([id, ind_set])
            vocab.update(ind_set)
        
            max_context = max(max_context, len(ind_set))
            min_context = min(min_context, len(ind_set))

        if i > MAX_ROW:
            break

print("max context: {} unique ingredients per recipe".format(max_context))
print("min context: {} unique ingredients per recipe".format(min_context))
print("vocab size", len(list(vocab)))
# Out:
# max context: 43 unique ingredients per recipe
# min context: 2 unique ingredients per recipe
# vocab size 14931

# %% [markdown]
# Since we've performed this data preparation work, let's use `pickle` to save this larger superset of the recipes dataset to the `tmp.pkl` file.
# Then we can restore it later for other use cases:

# %%
import pickle

pickle.dump(recipes, open("tmp.pkl", "wb"))

recipes
# Out:
# [['137739',
#   {'butter',
#    'honey',
#    'mexican seasoning',
#    'mixed spice',
#    'olive oil',
#    'salt',
#    'winter squash'}],
#  ['31490',
#   {'cheese',
#    'egg',
#    'milk',
#    'prepared pizza crust',
#    'salt and pepper',
#    'sausage patty'}],
#  ['112140',
#   {'cheddar cheese',
#    'chili powder',
#    'diced tomatoes',
#    'ground beef',
#    'ground cumin',
#    'kidney beans',
#    'lettuce',
#    'rotel tomatoes',
#    'salt',
#    'tomato paste',
#    'tomato soup',
#    'water',
#    'yellow onions'}],
#  ['59389',
#   {'black pepper',
#    'new potatoes',
#    'olive oil',
#    'parsley',
#    'red bell pepper',
#    'red wine vinegar',
#    'salt',
#    'shallots',
#    'spreadable cheese with garlic and herbs',
#    'tarragon',
#    'yellow bell pepper'}],
#  ['44061',
#   {'apple cider vinegar',
#    'black pepper',
#    'cinnamon oil',
#    'clove oil',
#    'dry mustard',
#    'salt',
#    'sugar',
#    'tomato juice'}],
#  ['5289',
#   {'apple', 'frozen apple juice concentrate', 'milk', 'vanilla ice cream'}],
#  ['25274',
#   {'extra virgin olive oil',
#    'fennel seeds',
#    'garlic',
#    'green olives',
#    'orange juice',
#    'orange rind',
#    'peppercorn',
#    'red chile',
#    'ripe olives'}],
#  ['67888',
#   {'a.1. original sauce',
#    'brown sugar',
#    'chili powder',
#    'cinnamon sticks',
#    'cracked black pepper',
#    'cumin',
#    'dry mustard',
#    'fresh cilantro leaves',
#    'fresh coarse ground black pepper',
#    'fresh garlic',
#    'fresh ginger',
#    'honey',
#    'liquid smoke',
#    'mirin',
#    'orange, juice of',
#    'pork spareribs',
#    'salt',
#    'soy sauce',
#    'tomato sauce',
#    'water',
#    'white vinegar',
#    'yellow onion'}],
#  ['70971',
#   {'bananas',
#    'chocolate sandwich style cookies',
#    'chocolate syrup',
#    'strawberry ice cream',
#    'vanilla ice cream',
#    'whipped cream'}],
#  ['75452',
#   {'baking soda',
#    'bananas',
#    'cake flour',
#    'egg',
#    'fresh lemon juice',
#    'orange rind',
#    'salt',
#    'sugar',
#    'unsalted butter'}],
#  ['109439',
#   {'prepared horseradish', 'sour cream', 'whole berry cranberry sauce'}],
#  ['42198',
#   {'butter',
#    'egg',
#    'powdered sugar',
#    'strawberry',
#    'vanilla wafers',
#    'walnuts',
#    'whipping cream'}],
#  ['67547',
#   {'bacon',
#    'black pepper',
#    'chicken bouillon cubes',
#    'chili powder',
#    'cornstarch',
#    'dark brown sugar',
#    'garlic powder',
#    'great northern bean',
#    'molasses',
#    'mustard powder',
#    'onion',
#    'salt',
#    'water'}],
#  ['107517',
#   {'brown sugar',
#    'collard greens',
#    'ham hock',
#    'hot sauce',
#    'molasses',
#    'salt',
#    'whiskey'}],
#  ['39959',
#   {'burnet root',
#    'gentian root',
#    'scullcap herb',
#    'spearmint',
#    'wood bethony'}],
#  ['63986',
#   {'chicken rice soup',
#    'dry mustard',
#    'flour',
#    'garlic powder',
#    'lean pork chops',
#    'oil',
#    'salt'}],
#  ['43026',
#   {'cheese', 'cornstarch', 'egg roll wrap', 'oil', 'whole green chilies'}],
#  ['23933', {'butterscotch chips', 'chinese noodles', 'salted peanuts'}],
#  ['8559',
#   {'beef broth',
#    'celery',
#    'cooking oil',
#    'ground pork',
#    'hamburger buns',
#    'onion',
#    'soy sauce'}],
#  ['23850',
#   {'broccoli floret',
#    'canola oil',
#    'cauliflower',
#    'escarole',
#    'fresh herb',
#    'garlic',
#    'great northern bean',
#    'green peas',
#    'ground coriander',
#    'onion',
#    'potato',
#    'red bell pepper',
#    'salt and pepper',
#    'salt free herb and spice seasoning mix',
#    'vegetable bouillon cubes',
#    'water'}],
#  ['76808',
#   {'boiling potatoes',
#    'coarse salt',
#    'fresh ground black pepper',
#    'fresh spinach leaves',
#    'nutmeg',
#    'salt',
#    'unsalted butter',
#    'water'}],
#  ['24701',
#   {'apple juice',
#    'broth',
#    'celery',
#    'dried thyme',
#    'fresh parsley',
#    'olive oil',
#    'onion',
#    'rolled oats',
#    'salt',
#    'scallion',
#    'spinach',
#    'white pepper'}],
#  ['83873',
#   {'boneless skinless chicken breast halves',
#    'condensed cream of chicken soup',
#    'cornstarch',
#    'egg',
#    'flour',
#    'garlic powder',
#    'oil',
#    'paprika',
#    'salt and pepper',
#    'seasoning salt'}],
#  ['107699',
#   {'baking powder',
#    'bread',
#    'brown sugar',
#    'butter',
#    'egg',
#    'flour',
#    'granulated sugar',
#    'ground cinnamon',
#    'milk',
#    'powdered sugar',
#    'salt',
#    'vanilla',
#    'vegetable oil'}],
#  ['49262', {'butter', 'egg yolks', 'lemon, juice of', 'salt', 'white pepper'}],
#  ['48156',
#   {'black cumin',
#    'ground black pepper',
#    'ground coriander',
#    'ground cumin',
#    'ground ginger',
#    'ground turmeric'}],
#  ['54272',
#   {'black pepper',
#    'celery',
#    'chili powder',
#    'diced tomatoes',
#    'garlic',
#    'green pepper',
#    'jalapenos',
#    'kidney beans',
#    'onion',
#    'red pepper flakes',
#    'salt',
#    'vegetarian ground beef'}],
#  ['47366',
#   {'beef bouillon cube',
#    'beef stew meat',
#    'cabbage',
#    'dried parsley',
#    'elbow macaroni',
#    'garbanzo beans',
#    'ground pepper',
#    'ground thyme',
#    'onion',
#    'parmesan cheese',
#    'salt',
#    'tomato',
#    'water',
#    'zucchini'}],
#  ['37073', {'margarine', 'red potatoes', 'rosemary'}],
#  ['44123',
#   {'black beans',
#    'broccoli floret',
#    'broccoli stem',
#    'carrot',
#    'celery',
#    'chicken stock',
#    'cornstarch',
#    'dried oregano',
#    'dried sweet basil leaves',
#    'dried thyme',
#    'dry white wine',
#    'heavy cream',
#    'onion',
#    'salt & fresh ground pepper',
#    'smoked chicken',
#    'tabasco sauce',
#    'unsalted butter',
#    'worcestershire sauce'}],
#  ['27087',
#   {'baking cocoa',
#    'baking powder',
#    'butter',
#    'egg',
#    'flour',
#    'miniature peppermint patties',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['59952',
#   {'black pepper',
#    'cheddar cheese',
#    'cornmeal',
#    'ground beef',
#    'hot chili pepper',
#    'onion',
#    'salt',
#    'sliced ripe olives',
#    'tabasco sauce',
#    'taco sauce',
#    'tomato sauce',
#    'whole kernel corn'}],
#  ['93249', {'butter', 'dry ranch dressing mix', 'french bread'}],
#  ['54100',
#   {'black pepper',
#    'dry mustard',
#    'egg substitute',
#    'fresh breadcrumb',
#    'ground venison',
#    'non-fat powdered milk',
#    'onion',
#    'salt',
#    'water',
#    'worcestershire sauce'}],
#  ['67664', {'frozen juice concentrate', 'milk', 'plain yogurt'}],
#  ['87098',
#   {'carrot',
#    'corn',
#    'diced tomatoes',
#    'green beans',
#    'low sodium chicken broth',
#    'potato',
#    'wax beans',
#    'zucchini'}],
#  ['25775',
#   {'black pepper',
#    'condensed cream of mushroom soup',
#    'crouton',
#    'egg',
#    'frozen chopped spinach',
#    'onion',
#    'salt',
#    'sharp cheddar cheese'}],
#  ['33165',
#   {'black pepper',
#    'celery seed',
#    'diced pimentos',
#    'fat-free mayonnaise',
#    'garlic',
#    'green onion',
#    'low-fat sour cream',
#    'plain low-fat yogurt',
#    'prepared mustard',
#    'red potatoes',
#    'salt',
#    'sugar',
#    'white wine vinegar'}],
#  ['38798',
#   {'egg',
#    'frozen chopped spinach',
#    'garlic powder',
#    'margarine',
#    'onion',
#    'oregano',
#    'sage',
#    'soft breadcrumbs'}],
#  ['22123',
#   {'condensed cream of mushroom & garlic soup',
#    'cooking oil',
#    'cornbread mix',
#    'cream of mushroom soup',
#    'frozen vegetables',
#    'ground beef',
#    'onion',
#    'salt & pepper'}],
#  ['90921',
#   {'angel hair pasta',
#    'garlic',
#    'green onions',
#    'honey',
#    'soy sauce',
#    'stir fry vegetables',
#    'toasted sesame oil',
#    'toasted sesame seeds'}],
#  ['93959',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'buckwheat flour',
#    'butter',
#    'canola oil',
#    'cinnamon',
#    'egg',
#    'flour',
#    'ground cinnamon',
#    'ground cloves',
#    'honey',
#    'low-fat buttermilk',
#    'orange juice',
#    'orange rind',
#    'pecans',
#    'salt',
#    'sugar',
#    'unsweetened cocoa',
#    'yam'}],
#  ['93958',
#   {'baking powder',
#    'baking soda',
#    'boiling water',
#    'buckwheat flour',
#    'canola oil',
#    'egg',
#    'flour',
#    'granulated sugar',
#    'ground cinnamon',
#    'ground cloves',
#    'low-fat buttermilk',
#    'orange juice',
#    'orange rind',
#    'raisins',
#    'salt',
#    'sorghum',
#    'unsweetened cocoa',
#    'yam'}],
#  ['58224',
#   {'american cheese',
#    'beer',
#    'cayenne',
#    'garlic',
#    'ground beef',
#    'prepared yellow mustard',
#    'salt & pepper',
#    'sugar'}],
#  ['33606',
#   {'cheese',
#    'chives',
#    'cider vinegar',
#    'dill pickles',
#    'garlic powder',
#    'green onion',
#    'ham',
#    'italian seasoning',
#    'olive oil',
#    'onion powder',
#    'ripe olives',
#    'salt and pepper',
#    'sweet pepper',
#    'tomato',
#    'tri-color spiral pasta',
#    'water chestnut'}],
#  ['94710',
#   {'basil',
#    'flat leaf parsley',
#    'frozen french fries',
#    'oil',
#    'oregano',
#    'parmesan cheese',
#    'salt & freshly ground black pepper'}],
#  ['35173',
#   {'butter',
#    'cheddar cheese',
#    'deli turkey',
#    'good seasonings italian salad dressing mix',
#    'ham',
#    'mozzarella cheese',
#    'pepperoni',
#    'sandwich bun',
#    'swiss cheese'}],
#  ['83025',
#   {'baking powder',
#    'butter',
#    'egg',
#    'flour',
#    'icing sugar',
#    'milk',
#    'salt',
#    'shortening',
#    'sugar',
#    'vanilla'}],
#  ['52804',
#   {'carrot',
#    'cinnamon',
#    'coconut',
#    'crushed pineapple',
#    'egg',
#    'nutmeg',
#    'oil',
#    'pecans',
#    'vanilla instant pudding mix',
#    'water',
#    'yellow cake mix'}],
#  ['108414',
#   {'butter',
#    'egg',
#    'heavy cream',
#    'honey',
#    'jalapenos',
#    'jiffy corn muffin mix',
#    'onion',
#    'red bell pepper',
#    'sharp cheddar cheese',
#    'whole kernel corn'}],
#  ['26995',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'butter',
#    'cinnamon',
#    'crushed pineapple',
#    'dry yeast',
#    'egg',
#    'flour',
#    'milk',
#    'nuts',
#    'raisins',
#    'salt',
#    'sugar',
#    'vanilla',
#    'vegetable oil',
#    'water'}],
#  ['53402',
#   {'cottage cheese',
#    'dried basil',
#    'egg',
#    'garlic',
#    'ground beef',
#    'ground black pepper',
#    'italian sausage',
#    'lasagna noodle',
#    'mozzarella cheese',
#    'parmesan cheese',
#    'parsley flakes',
#    'ricotta cheese',
#    'salt',
#    'tomato paste',
#    'whole tomato'}],
#  ['59632',
#   {'beef',
#    'black pepper',
#    'cheese',
#    'cottage cheese',
#    'egg',
#    'frozen chopped spinach',
#    'herbs',
#    'olive oil flavored cooking spray',
#    'salt',
#    'spices',
#    'toasted wheat germ'}],
#  ['22526',
#   {'brown sugar',
#    'butter',
#    'cinnamon',
#    'instant vanilla pudding',
#    'raisins',
#    'rolls'}],
#  ['100870',
#   {'garlic',
#    'granulated sugar',
#    'ground beef',
#    'prego spaghetti sauce',
#    'stewed tomatoes',
#    'white onion'}],
#  ['84797',
#   {'beef steaks',
#    'brown sugar',
#    'dried dill weed',
#    'fresh garlic',
#    'fresh lemon juice',
#    'fresh parsley',
#    'honey',
#    'hot sauce',
#    'ketchup',
#    'sour cream',
#    'spicy mustard',
#    'vegetable oil'}],
#  ['35653',
#   {'baking powder', 'butter', 'egg', 'flour', 'milk', 'salt', 'sugar'}],
#  ['32169',
#   {'button mushrooms',
#    'chicken breasts',
#    'dried basil',
#    'dried oregano',
#    'fresh ground black pepper',
#    'fresh parsley',
#    'garlic',
#    'hot sauce',
#    'olive oil',
#    'onion',
#    'parmesan cheese',
#    'pasta',
#    'salsa',
#    'tomato',
#    'water'}],
#  ['24478', {'cider vinegar', 'fresh herb', 'fresh herbs'}],
#  ['44045',
#   {'baking powder',
#    'black pepper',
#    'cream',
#    'egg',
#    'fat',
#    'flour',
#    'fresh corn',
#    'salt'}],
#  ['60219',
#   {'black olives',
#    'cheddar cheese soup',
#    'fettuccine pasta',
#    'jalapeno',
#    'milk',
#    'picante sauce'}],
#  ['81185',
#   {'cilantro',
#    'frozen peas',
#    'hass avocado',
#    'lemons, juice of',
#    'onion',
#    'salt',
#    'tomato'}],
#  ['30131',
#   {'basil',
#    'black pepper',
#    'garlic powder',
#    'lemon juice',
#    'oil',
#    'soy sauce',
#    'worcestershire sauce'}],
#  ['63593',
#   {'apple', 'cream cheese', 'milk', 'pear', 'unflavored gelatin', 'yogurt'}],
#  ['43164',
#   {'bacon',
#    'bay leaf',
#    'black pepper',
#    'butter',
#    'carrot',
#    'oil',
#    'onion',
#    'parsley sprigs',
#    'salt',
#    'thyme',
#    'veal roast'}],
#  ['30300', {'black pepper', 'crackers', 'mayonnaise', 'tomato'}],
#  ['78655',
#   {'brine',
#    'capers',
#    'carrot',
#    'ciabatta',
#    'fresh basil',
#    'fresh parsley',
#    'garlic',
#    'genoa salami',
#    'green olives',
#    'ham',
#    'kalamata olive',
#    'olive oil',
#    'oregano leaves',
#    'provolone cheese',
#    'red wine vinegar',
#    'sweet onion',
#    'tomato'}],
#  ['74805',
#   {'powdered sugar',
#    'vanilla',
#    'vanilla instant pudding mix',
#    'whipping cream'}],
#  ['71635',
#   {'cookie',
#    'cream cheese',
#    'gelatin',
#    'milk',
#    'miniature semisweet chocolate chips',
#    'prepared graham cracker crusts',
#    'sugar',
#    'vanilla'}],
#  ['38276',
#   {'baking powder',
#    'butter',
#    'carrot',
#    'cayenne pepper',
#    'celery',
#    'chili powder',
#    'cloves',
#    'egg',
#    'flour',
#    'green pepper',
#    'ground cumin',
#    'monterey jack cheese',
#    'onion',
#    'oregano',
#    'salt',
#    'sliced mushrooms',
#    'soy sauce',
#    'tomato',
#    'vegetable shortening',
#    'water',
#    'zucchini'}],
#  ['97052', {'half-and-half', 'salt and pepper', 'sweet butter', 'sweet corn'}],
#  ['26835',
#   {'baking soda',
#    'butter',
#    'egg',
#    'flour',
#    'lemon, rind of',
#    'salt',
#    'sugar',
#    'vanilla',
#    'yogurt'}],
#  ['32271',
#   {'butter',
#    'egg',
#    'flour',
#    'nuts',
#    'sugar',
#    'unsweetened chocolate squares',
#    'vanilla'}],
#  ['107229',
#   {'broccoli',
#    'chili-garlic sauce',
#    'cooked chicken',
#    'fresh cilantro',
#    'fresh ginger',
#    'green onions',
#    'reduced sodium soy sauce',
#    'rice vinegar',
#    'sesame oil',
#    'sesame seeds',
#    'vegetable oil',
#    'vermicelli'}],
#  ['5060',
#   {'apples',
#    'celery',
#    'orange juice',
#    'orange rind',
#    'pecans',
#    'philadelphia cream cheese',
#    'sugar'}],
#  ['42570',
#   {'boneless chicken breast',
#    'cayenne',
#    'cumin',
#    'fresh ground pepper',
#    'garlic',
#    'lemon juice',
#    'olive oil',
#    'paprika',
#    'salt',
#    'thyme'}],
#  ['52443',
#   {'baking potato',
#    'garlic powder',
#    'mozzarella cheese',
#    'oregano leaves',
#    'parmesan cheese',
#    'part-skim ricotta cheese',
#    'tomato sauce'}],
#  ['35595',
#   {'black pepper',
#    'cornstarch',
#    'mushroom pieces',
#    'onion',
#    'sodium-free vegetable broth',
#    'tabasco sauce',
#    'tomato puree',
#    'white wine'}],
#  ['108804',
#   {'albacore tuna in water',
#    'bibb lettuce',
#    'black pepper',
#    'fresh basil',
#    'garlic',
#    'light olive oil',
#    'red sweet bell peppers',
#    'red wine vinegar',
#    'salt',
#    'scallions',
#    'white kidney beans'}],
#  ['83950',
#   {'bacon',
#    'beef consomme',
#    'black pepper',
#    'butter',
#    'carrot',
#    'celery',
#    'crushed tomatoes',
#    'dry white wine',
#    'garlic',
#    'ground pork',
#    'lean ground beef',
#    'milk',
#    'nutmeg',
#    'olive oil',
#    'onion',
#    'oregano',
#    'penne pasta',
#    'red pepper flakes',
#    'rubbed sage',
#    'salt'}],
#  ['19208', {'apples', 'red cinnamon candies', 'sugar substitute', 'water'}],
#  ['64302',
#   {'brown sugar',
#    'celery',
#    'cucumber',
#    'elbow macaroni',
#    'green pepper',
#    'ketchup',
#    'lemon juice',
#    'oil',
#    'onion',
#    'tomato'}],
#  ['35964',
#   {'baking powder',
#    'brown sugar',
#    'cocoa',
#    'flour',
#    'hot water',
#    'milk',
#    'salt',
#    'sugar',
#    'vanilla',
#    'vegetable oil'}],
#  ['71457',
#   {'apple pie filling',
#    'butter',
#    'egg',
#    'flour',
#    'milk',
#    'powdered sugar',
#    'salt',
#    'toasted almonds'}],
#  ['95926', {'bananas', 'mayonnaise', 'white bread'}],
#  ['103948',
#   {'boneless skinless chicken thighs',
#    'breadcrumbs',
#    'chicken stock',
#    'dried oregano',
#    'dried thyme',
#    'dry white wine',
#    'flour',
#    'fresh ground black pepper',
#    'garlic powder',
#    'lean ground beef',
#    'milk',
#    'onion',
#    'poultry seasoning',
#    'salt',
#    'vegetable oil'}],
#  ['99024',
#   {'cream cheese', 'lemon juice', 'liquid smoke', 'onion', 'salmon', 'salt'}],
#  ['64045',
#   {'bean sprouts',
#    'brown sugar',
#    'carrot',
#    'desiccated coconut',
#    'garlic',
#    'ginger',
#    'green beans',
#    'ground cayenne pepper',
#    'ground coriander',
#    'ground cumin',
#    'onion',
#    'peanut oil',
#    'peanuts',
#    'red chili pepper',
#    'sambal oelek',
#    'soy sauce',
#    'tempeh',
#    'tomato',
#    'vegetable stock',
#    'water'}],
#  ['41756',
#   {'dried breadcrumbs',
#    'egg',
#    'ground beef',
#    'lemon juice',
#    'onion',
#    'salt and pepper',
#    'sugar',
#    'tomato soup',
#    'water'}],
#  ['112959',
#   {'avocado',
#    'chunky salsa',
#    'fresh cilantro',
#    'hot sauce',
#    'lime juice',
#    'salt and pepper',
#    'soft silken tofu'}],
#  ['83062',
#   {'baking soda',
#    'bananas',
#    'cinnamon',
#    'egg',
#    'flour',
#    'ground cloves',
#    'nutmeg',
#    'salt',
#    'shortening',
#    'walnuts',
#    'white sugar'}],
#  ['98930',
#   {'boneless skinless chicken breast',
#    'dried basil',
#    'lime juice',
#    'olive oil',
#    'salt and pepper',
#    'tomato'}],
#  ['83133',
#   {'beef ribs',
#    'brown sugar',
#    'fresh lemon juice',
#    'ketchup',
#    'mustard',
#    'onion',
#    'salt',
#    'vegetable oil',
#    'water',
#    'worcestershire sauce'}],
#  ['39947', {'egg whites', 'green grape', 'sugar'}],
#  ['44895',
#   {'betty crocker fudge brownie mix',
#    'egg',
#    'milk chocolate candy bars',
#    'vegetable oil',
#    'water'}],
#  ['39363',
#   {'baking powder',
#    'baking soda',
#    'bananas',
#    'butter',
#    'chocolate chips',
#    'egg',
#    'flour',
#    'nuts',
#    'salt',
#    'sugar',
#    'water'}],
#  ['62368',
#   {'brown sugar',
#    'butter',
#    'chocolate chips',
#    'cream cheese',
#    'egg',
#    'flour',
#    'oreo cookie crumbs',
#    'sour cream',
#    'sweetened condensed milk',
#    'vanilla'}],
#  ['111875',
#   {'2% low-fat milk',
#    'banana',
#    'natural-style peanut butter',
#    'sugar-free non-fat vanilla yogurt'}],
#  ['42522',
#   {'bean dip',
#    'cheddar cheese',
#    'cream cheese',
#    'sour cream',
#    'taco seasoning'}],
#  ['34930',
#   {'american cheese',
#    'bacon',
#    'dill weed',
#    'ground sirloin',
#    'iceberg lettuce',
#    "mccormick's montreal brand steak seasoning",
#    'no-salt-added ketchup',
#    'onion',
#    'tomato'}],
#  ['63793',
#   {'chat masala',
#    'chopped tomato',
#    'cucumber',
#    'paprika',
#    'plain yogurt',
#    'potato',
#    'salt'}],
#  ['61973',
#   {'baking soda',
#    'brown sugar',
#    'buttermilk',
#    'carrot',
#    'cinnamon',
#    'corn oil',
#    'egg',
#    'natural bran',
#    'raisins',
#    'salt',
#    'vanilla',
#    'whole wheat flour'}],
#  ['45859',
#   {'grand marnier',
#    'lime juice',
#    'lime wedge',
#    'limeade',
#    'tequila',
#    'triple sec'}],
#  ['58651',
#   {'brown sugar', 'butter', 'flour', 'pecans', 'semi-sweet chocolate chips'}],
#  ['59534',
#   {'black pepper',
#    'butter',
#    'cappelletti pasta',
#    'cheddar cheese',
#    'chopped tomato',
#    'corn',
#    'garlic',
#    'ground beef',
#    'milk',
#    'mushrooms',
#    'onion',
#    'salt',
#    'tomato soup'}],
#  ['24137',
#   {'dry white wine',
#    'extra virgin olive oil',
#    'garlic',
#    'hot water',
#    'parsley',
#    'salt and pepper',
#    'spaghetti',
#    'squid',
#    'tomato sauce'}],
#  ['40237',
#   {'baking soda',
#    'cocoa',
#    'flour',
#    'salt',
#    'sugar',
#    'vanilla',
#    'vegetable oil',
#    'vinegar',
#    'water'}],
#  ['18537', {'applesauce', 'brown sugar', 'clove', 'pork loin chops'}],
#  ['104243',
#   {'butter',
#    'cheddar cheese',
#    'cream cheese',
#    'green olives',
#    'ham',
#    'honey mustard',
#    'leaf lettuce',
#    'mayonnaise',
#    'prepared horseradish',
#    'provolone cheese',
#    'radish sprouts',
#    'roast beef',
#    'roasted red peppers',
#    'swiss cheese',
#    'turkey',
#    'whole wheat bread dough'}],
#  ['105069',
#   {'beef broth',
#    'butter',
#    'flour',
#    'fresh dill',
#    'lemon, juice of',
#    'onion',
#    'salt and pepper',
#    'sour cream',
#    'water',
#    'wild mushrooms'}],
#  ['70099',
#   {'asian chili sauce',
#    'bean sprouts',
#    'carrot',
#    'english cucumber',
#    'fresh cilantro',
#    'fresh ginger',
#    'garlic',
#    'green onions',
#    'honey',
#    'light soy sauce',
#    'rice noodles',
#    'rice wine vinegar',
#    'sesame oil'}],
#  ['333281',
#   {'bittersweet chocolate',
#    'brewed espresso',
#    'egg',
#    'flour',
#    'granulated sugar',
#    'kosher salt',
#    'unsalted butter',
#    'unsweetened cocoa powder',
#    'vanilla'}],
#  ['234069', {'brown sugar', 'dr. pepper cola', 'orange marmalade'}],
#  ['37841',
#   {'fish',
#    'gingerroot',
#    'low sodium soy sauce',
#    'peanut oil',
#    'rice wine',
#    'salt',
#    'scallions',
#    'sesame oil',
#    'white pepper'}],
#  ['144952',
#   {'beef broth',
#    'butter',
#    'flour',
#    'french bread',
#    'garlic',
#    'low sodium beef broth',
#    'olive oil',
#    'parmesan cheese',
#    'romano cheese',
#    'sherry wine',
#    'sugar',
#    'swiss cheese',
#    'yellow onions'}],
#  ['453467',
#   {'baking soda',
#    'brown sugar',
#    'chocolate chips',
#    'egg',
#    'flour',
#    'margarine',
#    'salt',
#    'vanilla',
#    'water',
#    'white sugar',
#    'whole wheat flour'}],
#  ['31835',
#   {'butter',
#    'cornbread',
#    'cream of chicken soup',
#    'egg',
#    'onion',
#    'sage',
#    'squash'}],
#  ['197013',
#   {'bay leaves',
#    'black pepper',
#    'bottled garlic',
#    'dried basil',
#    'dried oregano',
#    'dried parsley',
#    'garlic powder',
#    'italian sausage',
#    'olive oil',
#    'paprika',
#    'salt',
#    'sugar',
#    'tomato sauce',
#    'white onion'}],
#  ['306168',
#   {'cream of chicken soup',
#    'french-fried onions',
#    'frozen broccoli cuts',
#    'garlic powder',
#    'ground black pepper',
#    'milk',
#    'salt',
#    'sharp cheddar cheese',
#    'soy sauce'}],
#  ['286009',
#   {'almond extract',
#    'butter',
#    'egg',
#    'flour',
#    'pure vanilla extract',
#    'sugar',
#    'whole milk'}],
#  ['24514',
#   {'artichoke hearts',
#    'egg',
#    'fresh garlic',
#    'oil',
#    'unsalted butter',
#    'unseasoned breadcrumbs'}],
#  ['42508',
#   {'barbecue sauce',
#    'black pepper',
#    'chicken',
#    'chili powder',
#    'cider vinegar',
#    'hot red pepper sauce',
#    'salt',
#    'worcestershire sauce'}],
#  ['116679',
#   {'cheddar cheese',
#    'cream cheese',
#    'dry onion soup mix',
#    'frozen broccoli',
#    'ritz cracker crumbs',
#    'sour cream',
#    'water chestnuts'}],
#  ['124286',
#   {'baking soda',
#    'cocoa powder',
#    'cool whip',
#    'flour',
#    'instant chocolate pudding mix',
#    'mayonnaise',
#    'milk',
#    'salt',
#    'sugar',
#    'vanilla',
#    'water'}],
#  ['190',
#   {'bouillon',
#    'budweiser beer',
#    'chili powder',
#    'coriander',
#    'cornmeal',
#    'cumin',
#    'flour',
#    'garlic',
#    'hunts tomato sauce',
#    'lean chuck',
#    'lean pork',
#    'louisiana hot sauce',
#    'onion',
#    'oregano leaves',
#    'paprika',
#    'sugar',
#    'unsweetened cocoa',
#    'water'}],
#  ['475785',
#   {'baby spinach',
#    'egg',
#    'fresh garlic',
#    'goat cheese',
#    'kosher salt',
#    'meatloaf mixture',
#    'olive oil',
#    'red bell pepper',
#    'simply potatoes shredded hash browns',
#    'unsalted butter',
#    'unsmoked bacon',
#    'white pepper',
#    'yellow onion'}],
#  ['17265',
#   {'dark brown sugar',
#    'egg',
#    'egg white',
#    'ground cinnamon',
#    'ground cloves',
#    'ground ginger',
#    'heavy cream',
#    'milk',
#    'nutmeg',
#    'pie crusts',
#    'pumpkin puree',
#    'salt'}],
#  ['50662',
#   {'baking powder',
#    'beef',
#    'breadcrumbs',
#    'butter',
#    'celery seed',
#    'cream of chicken soup',
#    'dry onion flakes',
#    'flour',
#    'milk',
#    'onion',
#    'paprika',
#    'poppy seed',
#    'poultry seasoning',
#    'salt',
#    'sour cream',
#    'vegetable oil'}],
#  ['177187',
#   {'baking powder',
#    'baking soda',
#    'blended oatmeal',
#    'brown sugar',
#    'butter',
#    'egg',
#    'flour',
#    'hershey chocolate candy bars',
#    'nuts',
#    'semi-sweet chocolate chips',
#    'sugar',
#    'vanilla'}],
#  ['118843',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'butter',
#    'chocolate chips',
#    'egg',
#    'flour',
#    "hershey's semi-sweet baking chocolate",
#    'nuts',
#    'oatmeal',
#    'salt',
#    'vanilla',
#    'white sugar'}],
#  ['208179', {'butter', 'flour', 'granulated sugar', 'milk', 'vanilla'}],
#  ['500166',
#   {'cheddar cheese',
#    'corn cobs',
#    'ground beef',
#    'lettuce',
#    'onion',
#    'salsa',
#    'taco seasoning',
#    'taco shells',
#    'tomato'}],
#  ['501028',
#   {'beans',
#    'beef bouillon cube',
#    'beef broth',
#    'bell peppers',
#    'black pepper',
#    'chicken bouillon cube',
#    'chunky salsa',
#    'cinnamon',
#    'cumin',
#    'dark chocolate chips',
#    'garlic',
#    'ground coriander',
#    'habanero pepper',
#    'light brown sugar',
#    'mexican chili powder',
#    'salt',
#    'sazon goya',
#    'stewing beef',
#    'stewing pork',
#    'tomato paste',
#    'tortilla chips',
#    'white onion'}],
#  ['136602',
#   {'baking soda',
#    'brown sugar',
#    'butter',
#    'cream cheese',
#    'egg',
#    'flour',
#    'lemon zest',
#    'lime zest',
#    'orange-flavored liqueur',
#    'pecans',
#    'pitted dates',
#    'powdered sugar',
#    'salt',
#    'shortening',
#    'tequila',
#    'triple sec',
#    'warm water'}],
#  ['69190',
#   {'bouillon cubes',
#    'butter',
#    'carrot',
#    'celery',
#    'cream of celery soup',
#    'cream of chicken soup',
#    'milk',
#    'onion',
#    'potato',
#    'potato flakes',
#    'water'}],
#  ['503475',
#   {'apples',
#    'butter',
#    'cinnamon',
#    'cream',
#    'egg',
#    'flour',
#    'lemon, juice of',
#    'milk',
#    'salt',
#    'sugar'}],
#  ['522861',
#   {'butter',
#    'cheese',
#    'fresh coarse ground black pepper',
#    'garlic',
#    'macaroni',
#    'milk',
#    'onion',
#    'salt'}],
#  ['457136',
#   {'black pepper',
#    'cheese',
#    'fine semolina',
#    'heavy cream',
#    'macaroni',
#    'muscat wine',
#    'onion',
#    'potato',
#    'salt water',
#    'unsalted butter'}],
#  ['455351',
#   {'applesauce',
#    'butter',
#    'cheese',
#    'milk',
#    'onion',
#    'penne pasta',
#    'potato',
#    'salt and pepper'}],
#  ['333797', {'dried yellow peas', 'ginger', 'pork', 'salt', 'water'}],
#  ['428056',
#   {'black pepper',
#    'brown mustard',
#    'carrot',
#    'clove',
#    'dried thyme',
#    'dried yellow peas',
#    'ground ginger',
#    'ham bone',
#    'onion',
#    'salt',
#    'water'}],
#  ['306245', {'butter', 'fresh spinach', 'nutmeg', 'water'}],
#  ['523359',
#   {'chili powder',
#    'cornstarch',
#    'dried onion flakes',
#    'garlic powder',
#    'granulated sugar',
#    'ground beef',
#    'ground black pepper',
#    'ground pork',
#    'paprika',
#    'salt',
#    'tomato paste',
#    'water',
#    'white vinegar',
#    'wondra flour'}],
#  ['495314',
#   {'apple cider vinegar',
#    'applesauce',
#    'cayenne',
#    'dark brown sugar',
#    'granulated garlic',
#    'liquid smoke',
#    'maple syrup',
#    'oregano',
#    'ponzu sauce',
#    'salt',
#    'tomato ketchup'}],
#  ['149593',
#   {'baking powder',
#    'baking soda',
#    'butter',
#    'egg',
#    'flour',
#    'salt',
#    'sour cream',
#    'sugar',
#    'vanilla'}],
#  ['227924',
#   {'butter', 'frozen whipped topping', 'oreo cookies', 'vanilla ice cream'}],
#  ['100540', {'butter', 'processed cheese', 'white bread'}],
#  ['155959',
#   {'balsamic vinegar',
#    'fresh ground black pepper',
#    'garlic',
#    'london broil beef',
#    'olive oil',
#    'rosemary',
#    'soy sauce',
#    'worcestershire sauce'}],
#  ['29214',
#   {'chicken broth',
#    'cornstarch',
#    'dried oregano',
#    'dried rosemary',
#    'dried thyme',
#    'dry sherry',
#    'fresh mushrooms',
#    'garlic',
#    'hot pepper sauce',
#    'margarine',
#    'nonfat dry milk powder',
#    'nonfat milk',
#    'parmesan cheese',
#    'salt and black pepper',
#    'spicy brown mustard',
#    'teriyaki sauce'}],
#  ['92533',
#   {'almonds',
#    'butter',
#    'cinnamon',
#    'cream cheese',
#    'egg',
#    'nutmeg',
#    'sour cream',
#    'splenda sugar substitute',
#    'vanilla',
#    'vanilla protein powder'}],
#  ['209203',
#   {'bacon', 'butter', 'real maple syrup', 'refrigerated buttermilk biscuits'}],
#  ['42151',
#   {'horseradish',
#    'mayonnaise',
#    'tabasco sauce',
#    'velveeta cheese',
#    'worcestershire sauce'}],
#  ['327356', {'lemon juice', 'red wine vinegar', 'water'}],
#  ['325509',
#   {'berries',
#    'ground flax seeds',
#    "i can't believe it's not butter spread",
#    'old fashioned oats',
#    'sugar-free syrup',
#    'water'}],
#  ['236184',
#   {'blueberries',
#    'cream cheese',
#    'egg',
#    'flour',
#    'french bread',
#    'frozen blueberries',
#    'maple syrup',
#    'milk',
#    'nuts',
#    'powdered sugar',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['241445',
#   {'bacon',
#    'celery',
#    'cheddar cheese',
#    'chicken broth',
#    'chives',
#    'liquid smoke',
#    'onion',
#    'red potatoes',
#    'salt',
#    'sour cream',
#    'velveeta cheese',
#    'white pepper'}],
#  ['149887',
#   {'active dry yeast',
#    'brown sugar',
#    'butter',
#    'cinnamon',
#    'cream cheese',
#    'egg',
#    'flour',
#    'granulated sugar',
#    'milk',
#    'powdered sugar',
#    'salt',
#    'vanilla pudding mix',
#    'warm water'}],
#  ['112984',
#   {'asparagus',
#    'garlic',
#    'italian seasoning',
#    'part-skim mozzarella cheese',
#    'red bell pepper',
#    'reduced-fat parmesan cheese',
#    'salt and pepper',
#    'spaghetti sauce',
#    'spaghetti squash',
#    'white mushroom'}],
#  ['200148',
#   {'coriander',
#    'cornstarch',
#    'frozen pineapple concentrate',
#    'graham cracker crumbs',
#    'lemon juice',
#    'maple syrup',
#    'margarine',
#    'oil',
#    'soft silken tofu',
#    'vanilla',
#    'vegan cream cheese',
#    'vegan sugar',
#    'water'}],
#  ['445026',
#   {'andouille sausage',
#    'celery',
#    'cooked chicken',
#    'creole seasoning',
#    'flour',
#    'frozen black-eyed peas',
#    'garlic',
#    'green bell pepper',
#    'large raw shrimp',
#    'low sodium chicken broth',
#    'onion',
#    'vegetable oil'}],
#  ['70611',
#   {'cheddar cheese',
#    'cracker',
#    'egg',
#    'ground beef',
#    'onion',
#    'pickle',
#    'salt and pepper',
#    'thousand island dressing'}],
#  ['273326',
#   {'basil',
#    'butter',
#    'cajun spices',
#    'garlic',
#    'heavy whipping cream',
#    'lemon juice',
#    'linguine',
#    'parmesan cheese',
#    'parmesan-romano cheese mix',
#    'parsley',
#    'salmon',
#    'salt',
#    'white pepper'}],
#  ['310570', {'cottage cheese', 'egg', 'feta', 'milk', 'oil', 'phyllo dough'}],
#  ['318677',
#   {'avocado',
#    'cucumber',
#    'imitation crabmeat',
#    'lettuce',
#    'pickled ginger',
#    'seasoned rice vinegar',
#    'soy sauce',
#    'white rice'}],
#  ['80050',
#   {'baking soda',
#    'egg',
#    'flour',
#    'maraschino cherry',
#    'mincemeat',
#    'mixed candied fruit',
#    'sweetened condensed milk',
#    'walnuts'}],
#  ['269984',
#   {'baby carrots',
#    'baking powder',
#    'black pepper',
#    'celery',
#    'chicken breasts',
#    'chicken stock',
#    'egg',
#    'kosher salt',
#    'matzo meal',
#    'oil',
#    'salt',
#    'sugar',
#    'white onion'}],
#  ['317508',
#   {'cheddar cheese',
#    'cream of mushroom soup',
#    'frozen southern style hash brown potatoes',
#    'poppy seed',
#    'sour cream'}],
#  ['53872',
#   {'adobo seasoning',
#    'egg',
#    'fresh garlic cloves',
#    'fresh ground pepper',
#    'ground coriander',
#    'ground sage',
#    'italian seasoned breadcrumbs',
#    'ketchup',
#    'lean ground beef',
#    'low sodium soy sauce',
#    'olive oil',
#    'oregano',
#    'red onion',
#    'sea salt',
#    'veggie shreds cheese'}],
#  ['268942',
#   {'butter',
#    'celery',
#    'cream of celery soup',
#    'green bell pepper',
#    'kraft macaroni and cheese',
#    'mushrooms',
#    'onion',
#    'tuna'}],
#  ['176110',
#   {'black pepper',
#    'cider vinegar',
#    'dry mustard',
#    'garlic',
#    'ketchup',
#    'miracle whip',
#    'paprika',
#    'salt',
#    'sugar',
#    'tabasco sauce',
#    'vegetable oil'}],
#  ['205331',
#   {'extra virgin olive oil',
#    'italian parsley',
#    'kalamata olive',
#    'kosher salt & freshly ground black pepper',
#    'lemon, juice of',
#    'oregano',
#    'pepperoncini peppers',
#    'red bell pepper',
#    'red onion',
#    'red ripe tomatoes',
#    'red wine vinegar',
#    'seedless cucumber',
#    'shallot',
#    'tuna in vegetable oil',
#    'water-packed artichoke hearts'}],
#  ['165856',
#   {'buttermilk',
#    'canola oil',
#    'egg',
#    'ground black pepper',
#    'orange roughy',
#    'seasoning salt',
#    'self-rising flour'}],
#  ['474769',
#   {'bacon',
#    'egg',
#    'egg yolk',
#    'flour',
#    'frozen spinach',
#    'garlic',
#    'goat cheese',
#    'green onion',
#    'salt',
#    'simply potatoes traditional mashed potatoes'}],
#  ['138005',
#   {'boneless pork chops',
#    'cajun seasoning',
#    'canola oil',
#    'egg',
#    'flour',
#    'ground black pepper',
#    'milk',
#    'salt and pepper',
#    'seasoning salt',
#    'self-rising flour'}],
#  ['216945',
#   {'imitation crabmeat',
#    'ramen noodles',
#    'stir fry vegetables',
#    'teriyaki marinade',
#    'water'}],
#  ['164526',
#   {'apple',
#    'banana',
#    'celery',
#    'fresh cilantro leaves',
#    'green bell pepper',
#    'ground red pepper',
#    'pesto sauce',
#    'pumpkin puree',
#    'pumpkin seeds',
#    'red onion',
#    'salt',
#    'small red potato',
#    'smooth cashew butter',
#    'vegetable broth'}],
#  ['50184',
#   {'chili powder',
#    'dry-roasted cashews',
#    'garlic',
#    'margarine',
#    'mushrooms',
#    'nutmeg',
#    'parsley',
#    'vegetable bouillon cubes',
#    'water'}],
#  ['316470',
#   {'ice cubes', 'mangoes', 'oranges', 'strawberries', 'vanilla bean'}],
#  ['343338',
#   {'fresh rosemary',
#    'garlic',
#    'leeks',
#    'olive oil',
#    'russet potatoes',
#    'salt and pepper',
#    'vegetable broth',
#    'white beans'}],
#  ['137434',
#   {'black peppercorns',
#    'boneless skinless chicken breasts',
#    'cardamom pods',
#    'chicken stock',
#    'chili powder',
#    'cinnamon stick',
#    'cloves',
#    'coriander seed',
#    'fresh coriander',
#    'fresh ginger',
#    'garlic',
#    'ground cumin',
#    'onion',
#    'salt & freshly ground black pepper',
#    'soy yogurt',
#    'turmeric'}],
#  ['95534',
#   {'beef bouillon cubes',
#    'black pepper',
#    'boiling water',
#    'dried oregano',
#    'dried thyme',
#    'garlic',
#    'garlic powder',
#    'rump roast',
#    'salt',
#    'tabasco sauce',
#    'worcestershire sauce'}],
#  ['30473', {'ginger', 'honey', 'milk', 'tea bag', 'water'}],
#  ['24470', {'ground beef', 'sausage', 'taco chips', 'velveeta cheese'}],
#  ['311991',
#   {'bell pepper',
#    'brown sugar',
#    'garlic powder',
#    'ground mustard',
#    'hamburger buns',
#    'ketchup',
#    'lean ground beef',
#    'onion',
#    'steak seasoning',
#    'tomato sauce',
#    'white vinegar',
#    'worcestershire sauce'}],
#  ['225707',
#   {'beets',
#    'black pepper',
#    'carrot',
#    'fresh corn kernels',
#    'garlic',
#    'gingerroot',
#    'green onions',
#    'green peppers',
#    'honey',
#    'rice wine vinegar',
#    'safflower oil',
#    'salad greens',
#    'salad seasoning',
#    'salt',
#    'soy sauce',
#    'white mushrooms'}],
#  ['242830',
#   {'chicken broth',
#    'dry white wine',
#    'fennel seeds',
#    'fresh lemon juice',
#    'olive oil',
#    'onion',
#    'paprika',
#    'pork chops'}],
#  ['336744',
#   {'black olives',
#    'egg',
#    'garlic powder',
#    'italian seasoning',
#    'mozzarella cheese',
#    'pepperoni',
#    'ramen noodles',
#    'red bell pepper',
#    'roma tomato'}],
#  ['83542',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'egg',
#    'flour',
#    'milk',
#    'molasses',
#    'natural bran',
#    'oil',
#    'raisins',
#    'salt',
#    'sesame seeds',
#    'sunflower seeds'}],
#  ['91626',
#   {'black tea leaves',
#    'broiler',
#    'brown sugar',
#    'dry sherry',
#    'garlic',
#    'low sodium soy sauce',
#    'minced ginger',
#    'onion',
#    'orange zest',
#    'orange, juice of',
#    'peppercorn'}],
#  ['303457',
#   {'cardamom pods',
#    'cloves',
#    'coriander seed',
#    'fruit vinegar',
#    'gingerroot',
#    'kaffir lime leaves',
#    'lemongrass',
#    'peanut oil',
#    'star anise',
#    'turmeric',
#    'yoghurt'}],
#  ['176717',
#   {'blueberry pie filling',
#    'cool whip',
#    'graham wafers',
#    'vanilla pudding mix'}],
#  ['39226',
#   {'canned jalapeno slices',
#    'cayenne pepper',
#    'chili powder',
#    'cornstarch',
#    'dried onion flakes',
#    'garlic powder',
#    'onion powder',
#    'salt',
#    'sugar',
#    'tomato paste',
#    'vinegar',
#    'water'}],
#  ['216030',
#   {'baking powder',
#    'baking soda',
#    'brown sugar',
#    'butter',
#    'cake flour',
#    'corn flakes',
#    'egg',
#    'nuts',
#    'quick-cooking oats',
#    'raisins',
#    'salt',
#    'shredded coconut',
#    'vanilla'}],
#  ['268169',
#   {'black pepper',
#    'butter',
#    'italian spices',
#    'kosher salt',
#    'olive oil',
#    'onion',
#    'whole turkey'}],
#  ['98357',
#   {'cheddar cheese',
#    'chili with beans',
#    'corn chips',
#    'onion',
#    'salsa',
#    'sour cream'}],
#  ['150365',
#   {'black pepper',
#    'cauliflower florets',
#    'egg',
#    'parsley sprig',
#    'plain breadcrumbs',
#    'salt',
#    'vegetable oil'}],
#  ['243251',
#   {'butter',
#    'fresh green beans',
#    'ground black pepper',
#    'kosher salt',
#    'mixed herbs',
#    'olive oil',
#    'onion',
#    'walnuts'}],
#  ['20186',
#   {'american cheese',
#    'ham',
#    'hamburger buns',
#    'ketchup',
#    'sweet pickle relish'}],
#  ['109818', {'bacon', 'carrot', 'sugar', 'tomato soup'}],
#  ['243785',
#   {'brown sugar',
#    'egg',
#    'ground beef',
#    'ketchup',
#    'lipton onion soup mix',
#    'seasoned bread crumbs'}],
#  ['207525',
#   {'bulk pork sausage',
#    'garlic powder',
#    'ground chuck',
#    'ground pepper',
#    'oregano',
#    'rye cocktail bread',
#    'velveeta cheese',
#    'worcestershire sauce'}],
#  ['226246',
#   {'brown sugar',
#    'butter',
#    'caster sugar',
#    'egg',
#    'glace cherries',
#    'milk',
#    'pineapple in syrup',
#    'self-raising flour',
#    'vanilla essence'}],
#  ['353044',
#   {'apple',
#    'banana',
#    'coconut milk',
#    'flax seed oil',
#    'greens',
#    'honey',
#    'oat bran',
#    'water'}],
#  ['263781',
#   {'green onion',
#    'hawaiian bread',
#    "hellmann's mayonnaise",
#    'knorr vegetable soup mix',
#    'sour cream',
#    'water chestnuts'}],
#  ['66932',
#   {'broccoli floret',
#    'brown rice',
#    'carrot',
#    'egg',
#    'olive oil',
#    'peas',
#    'sliced mushrooms',
#    'soy sauce'}],
#  ['48131',
#   {'egg whites',
#    'pumpkin',
#    'pumpkin pie spice',
#    'reduced fat graham cracker crust',
#    'skim milk',
#    'splenda sugar substitute'}],
#  ['32363', {'beef stew', 'biscuits'}],
#  ['293225',
#   {'baking soda',
#    'buttermilk',
#    'creamy peanut butter',
#    'espresso',
#    'extra-large eggs',
#    'heavy cream',
#    'honey roasted peanuts',
#    'light corn syrup',
#    'powdered sugar',
#    'pure vanilla extract',
#    'salt',
#    'semisweet chocolate',
#    'sugar',
#    'unbleached all-purpose flour',
#    'unsalted butter',
#    'unsweetened cocoa'}],
#  ['235173',
#   {'chipotle chile in adobo',
#    'cilantro',
#    'corn kernel',
#    'fresh lime juice',
#    'garlic',
#    'ground cumin',
#    'lime zest',
#    'olive oil',
#    'onion',
#    'red bell pepper',
#    'short-grain brown rice',
#    'yellow cornmeal'}],
#  ['226001',
#   {'butter',
#    'egg',
#    'flour',
#    'instant vanilla pudding',
#    'water',
#    'whipped dessert topping mix'}],
#  ['220186',
#   {'celery',
#    'dijon mustard',
#    'fresh ground pepper',
#    'hard-boiled eggs',
#    'milk',
#    'miracle whip',
#    'mustard',
#    'potato',
#    'salt',
#    'sugar',
#    'white onions',
#    'white pepper'}],
#  ['217201',
#   {'black pepper',
#    'butter',
#    'cayenne pepper',
#    'chili powder',
#    'dried basil',
#    'garlic powder',
#    'lemon juice',
#    'seasoning salt',
#    'soy sauce',
#    'tea bag',
#    'water',
#    'white rice'}],
#  ['194665',
#   {'bisquick',
#    'egg',
#    'feta cheese',
#    'fresh ground pepper',
#    'frozen spinach',
#    'kalamata olive',
#    'milk',
#    'onion',
#    'oregano',
#    'roasted red pepper'}],
#  ['269909',
#   {'allspice',
#    'baking powder',
#    'baking soda',
#    'cinnamon',
#    'egg',
#    'flour',
#    'ground cloves',
#    'nutmeg',
#    'oil',
#    'pecans',
#    'pumpkin',
#    'salt',
#    'sugar',
#    'water'}],
#  ['259693',
#   {'black pepper',
#    'boneless pork chops',
#    'dry onion soup mix',
#    'long-grain rice',
#    'vegetable oil',
#    'water'}],
#  ['161370',
#   {'allspice',
#    'black pepper',
#    'boneless skinless chicken breasts',
#    'brown sugar',
#    'cayenne',
#    'chili powder',
#    'chives',
#    'cinnamon',
#    'clove',
#    'crushed tomatoes',
#    'garlic',
#    'ginger',
#    'habanero pepper',
#    'jamaican jerk spice',
#    'lime juice',
#    'nutmeg',
#    'olive oil',
#    'onion',
#    'onion flakes',
#    'red peppers',
#    'rum',
#    'sage',
#    'thyme'}],
#  ['152261',
#   {'frozen limeade concentrate', 'ice', 'lime sorbet', 'mango', 'strawberry'}],
#  ['152259',
#   {'apple juice',
#    'banana',
#    'ice',
#    'non-fat vanilla frozen yogurt',
#    'strawberry'}],
#  ['303460',
#   {'coriander seed',
#    'cumin',
#    'fish sauce',
#    'fruit vinegar',
#    'garlic',
#    'hoisin sauce',
#    'red chile',
#    'sesame oil',
#    'yoghurt'}],
#  ['270259',
#   {'butter',
#    'candy cane',
#    'egg',
#    'flour',
#    'peppermint extract',
#    'peppermint oreos',
#    'salt',
#    'sugar',
#    'unsweetened chocolate',
#    'unsweetened cocoa powder',
#    'vanilla'}],
#  ['345123',
#   {'canola oil',
#    'celery',
#    'cooked chicken breasts',
#    'cooked rice',
#    'green grapes',
#    'mandarin oranges',
#    'mayonnaise',
#    'orange juice',
#    'pineapple tidbits',
#    'salt',
#    'slivered almonds',
#    'white vinegar'}],
#  ['125195',
#   {'celery',
#    'cheddar cheese',
#    'frozen peas',
#    'hard-boiled eggs',
#    'mayonnaise',
#    'mustard',
#    'onion',
#    'seasoning salt',
#    'sugar',
#    'sweet pickle relish'}],
#  ['141939',
#   {'black pepper',
#    'butter',
#    'buttermilk',
#    'cayenne pepper',
#    'chicken pieces',
#    'dijon mustard',
#    'dried thyme',
#    'dry breadcrumbs',
#    'flour',
#    'fresh garlic',
#    'garlic powder',
#    'hot pepper sauce',
#    'oil',
#    'onion',
#    'paprika',
#    'parmesan cheese',
#    'seasoning salt'}],
#  ['171442',
#   {'allspice',
#    'black pepper',
#    'cinnamon',
#    'fresh garlic',
#    'habanero sauce',
#    'hoisin sauce',
#    'ketchup',
#    'lemon juice',
#    'louisiana hot sauce',
#    'pork baby back ribs',
#    'seasoning salt',
#    'sugar'}],
#  ['212188',
#   {'beef stock',
#    'black pepper',
#    'carrot',
#    'celery',
#    'chicken leg',
#    'corn',
#    'garlic',
#    'italian seasoning',
#    'onion',
#    'peas',
#    'red bell pepper',
#    'rotini pasta',
#    'salt',
#    'spaghetti sauce'}],
#  ['262208',
#   {'aluminum foil',
#    'margarine',
#    'mexicorn whole kernel corn',
#    'pam cooking spray',
#    'salt and pepper',
#    'sour cream',
#    'spinach dip',
#    'stove top stuffing mix monterey style with mushroom and onion'}],
#  ['207857', {'cooking onions', 'pickling spices', 'white vinegar'}],
#  ['221049',
#   {'carrot',
#    'chicken broth',
#    'cooked chicken',
#    'cooked pasta',
#    'egg',
#    'peas',
#    'soy sauce'}],
#  ['221116', {'cake crumbs', 'cool whip', 'cream cheese', 'mixed fruit'}],
#  ['130819',
#   {'butter',
#    'coconut flavoring',
#    'cool whip',
#    'egg',
#    'flour',
#    'lemon flavoring',
#    'pie crust',
#    'squash',
#    'sugar'}],
#  ['20223',
#   {'black pepper',
#    'cream of mushroom soup',
#    'dijon mustard',
#    'dried onion flakes',
#    'dried parsley flakes',
#    'garlic powder',
#    'ground cinnamon',
#    'ground cloves',
#    'ground veal',
#    'salt'}],
#  ['190108',
#   {'black pepper',
#    'brown rice',
#    'catfish nuggets',
#    'chicken stock',
#    'garlic',
#    'gumbo file',
#    'lemon',
#    'mexican-style stewed tomatoes with jalapeno peppers',
#    'okra',
#    'old bay seasoning',
#    'olive oil',
#    'oregano',
#    'parsley',
#    'red onions',
#    'red wine vinegar',
#    'seafood',
#    'small shrimp',
#    'tabasco sauce',
#    'tomato soup'}],
#  ['158372',
#   {'bacon',
#    'egg',
#    'fresh chives',
#    'mild cheddar cheese',
#    'paprika',
#    'sour cream',
#    'white vinegar'}],
#  ['219681',
#   {'chicken breasts',
#    'cracked black pepper',
#    'dried basil',
#    'dried oregano',
#    'dried parsley',
#    'garlic',
#    'garlic salt',
#    'lemon juice',
#    'olive oil',
#    'salt',
#    'sandwich buns',
#    'white vinegar'}],
#  ['261215',
#   {'baking soda',
#    'boiling water',
#    'brown sugar',
#    'cinnamon',
#    'cream',
#    'egg',
#    'flour',
#    'margarine',
#    'nutmeg',
#    'nuts',
#    'quick oats',
#    'salt',
#    'shredded coconut',
#    'vanilla'}],
#  ['179640', {'butter', 'marshmallows', 'rice krispies'}],
#  ['250883',
#   {'cool whip topping',
#    'cream cheese',
#    'frozen limeade concentrate',
#    'orange juice'}],
#  ['140855',
#   {'avocado',
#    'cheddar cheese',
#    'chili powder',
#    'corn chips',
#    'garlic',
#    'green onion',
#    'lemon juice',
#    'lettuce',
#    'pitted ripe olives',
#    'salad oil',
#    'salt',
#    'sour cream',
#    'sugar',
#    'tabasco sauce',
#    'tomato',
#    'tuna'}],
#  ['120297',
#   {'baking potatoes',
#    'chickpeas',
#    'coriander',
#    'fresh coriander',
#    'garlic',
#    'ground cumin',
#    'low-fat yogurt',
#    'olive oil',
#    'salt & freshly ground black pepper',
#    'tahini'}],
#  ['130492',
#   {'baking powder',
#    'buttermilk',
#    'egg',
#    'mayonnaise',
#    'salt',
#    'sugar',
#    'vegetable oil',
#    'yellow cornmeal'}],
#  ['164634',
#   {'apple',
#    'carrot',
#    'gingerroot',
#    'green cabbage',
#    'green onion',
#    'maple syrup',
#    'red cabbage',
#    'rice vinegar',
#    'sesame oil',
#    'soy sauce'}],
#  ['293836',
#   {'black pepper',
#    'canola oil',
#    'chicken soup powder',
#    'garlic powder',
#    'long-grain rice',
#    'orzo pasta',
#    'turmeric',
#    'water'}],
#  ['169586',
#   {'avocado',
#    'celery ribs',
#    'chicken breast',
#    'chicken broth',
#    'chipotle chiles in adobo',
#    'crushed tomatoes',
#    'cumin',
#    'ear of corn',
#    'fresh cilantro',
#    'green bell pepper',
#    'jalapeno pepper',
#    'salt and pepper',
#    'white onion'}],
#  ['261296',
#   {'black pepper',
#    'dried basil',
#    'egg white',
#    'eggplant',
#    'fat free mozzarella cheese',
#    'fiber one cereal',
#    'garlic powder',
#    'italian-style tomato sauce',
#    'reduced-fat parmesan cheese',
#    'salt'}],
#  ['101115', {'beef gravy', 'egg', 'ground beef', 'onion', 'white rice'}],
#  ['271594',
#   {'beans',
#    'black pepper',
#    'black-eyed peas',
#    'carrot',
#    'celery ribs',
#    'garlic',
#    'great northern beans',
#    'ham',
#    'ham bone',
#    'ham soup base',
#    'navy beans',
#    'onion',
#    'pinto beans',
#    'salt',
#    'tomatoes and green chilies',
#    'water'}],
#  ['164291',
#   {'cider vinegar',
#    'feta cheese',
#    'fresh dill',
#    'garlic',
#    'light mayonnaise',
#    'red bell pepper',
#    'skinless chicken breast half'}],
#  ['251528',
#   {'cheese ravioli',
#    'garlic salt',
#    'italian seasoning',
#    'lean ground beef',
#    'mozzarella cheese',
#    'spaghetti sauce'}],
#  ['250833',
#   {'barbecue sauce',
#    'chicken pieces',
#    'lemon juice',
#    'orange marmalade',
#    'worcestershire sauce'}],
#  ['343448',
#   {'coriander',
#    'garlic powder',
#    'ground black pepper',
#    'ground red pepper',
#    'onion powder',
#    'paprika',
#    'salt',
#    'turmeric'}],
#  ['39893',
#   {'black olives',
#    'cream cheese',
#    'green onion',
#    'green pepper',
#    'lettuce',
#    'mayonnaise',
#    'mexican blend cheese',
#    'sour cream',
#    'taco seasoning mix',
#    'tomato'}],
#  ['147477',
#   {'green bell peppers',
#    'green onions',
#    'minced clams',
#    'paprika',
#    'sharp cheddar cheese',
#    'tabasco sauce',
#    'worcestershire sauce'}],
#  ['223349',
#   {'eggplants',
#    'olive oil',
#    'olives',
#    'oregano',
#    'red bell pepper',
#    'red onion',
#    'shrimp',
#    'spaghetti squash',
#    'yellow bell pepper'}],
#  ['86768',
#   {'butter', "confectioners' sugar", 'heavy cream', 'semisweet chocolate'}],
#  ['197001',
#   {'cherry pie filling',
#    'crushed pineapple',
#    'frozen whipped topping',
#    'pecans',
#    'small marshmallow',
#    'sweetened condensed milk'}],
#  ['60938',
#   {'bacon',
#    'cheddar cheese',
#    'green onions',
#    'oil',
#    'potato',
#    'salt',
#    'sour cream'}],
#  ['228491',
#   {'black pepper',
#    'boneless eye of round beef steak',
#    'canola oil',
#    'mozzarella cheese',
#    'onion',
#    'parmesan cheese',
#    'pizza sauce',
#    'plain flour',
#    'salt'}],
#  ['451515',
#   {'bacon grease',
#    'boneless country-style ribs',
#    "campbell's golden mushroom soup",
#    'flour',
#    'ground black pepper',
#    'oregano',
#    'seasoning salt',
#    'soup mix'}],
#  ['353171', {'butter', 'egg', 'flour', 'fruit', 'milk', 'sugar'}],
#  ['354039',
#   {'apples',
#    'baby carrots',
#    'butter',
#    'cardamom',
#    'crescent roll dough',
#    'ground cinnamon',
#    'honey',
#    'sugar'}],
#  ['302399',
#   {'garlic salt',
#    'italian seasoning',
#    'mozzarella cheese',
#    'olive oil',
#    'refrigerated biscuits'}],
#  ['195736',
#   {'active dry yeast', 'butter', 'flour', 'milk', 'salt', 'sugar', 'water'}],
#  ['365946',
#   {'butter',
#    'cream cheese',
#    'egg',
#    'egg yolk',
#    'egg yolks',
#    'flour',
#    'lemon peel',
#    'salt',
#    'sugar',
#    'vanilla',
#    'whipping cream'}],
#  ['221544',
#   {'chili sauce',
#    'country-style dijon mustard',
#    'honey',
#    'little smokies sausages'}],
#  ['175306',
#   {'bacardi dark rum',
#    'grenadine',
#    "meyer's dark rum",
#    'orange curacao',
#    'orange juice',
#    'orgeat syrup',
#    'pineapple juice',
#    'prepared sweet-and-sour mix',
#    'white rum'}],
#  ['211833',
#   {'balsamic vinaigrette',
#    'condensed chicken broth',
#    'dried thyme leaves',
#    'minute white rice',
#    'onion',
#    'pork chops',
#    'red apples',
#    'sliced mushrooms',
#    'water'}],
#  ['276567',
#   {'chili powder',
#    'fresh ground black pepper',
#    'green bell peppers',
#    'horseradish',
#    'onion',
#    'orange juice',
#    'plain nonfat yogurt',
#    'prepared mustard',
#    'red bell peppers',
#    'reduced-calorie mayonnaise',
# ...
#    'egg',
#    'flour',
#    'nuts',
#    'sugar',
#    'vanilla'}],
#  ['79425',
#   {'butter',
#    'caramels',
#    'chocolate cake mix',
#    'chocolate chips',
#    'evaporated milk',
#    'nuts'}],
#  ['213681',
#   {'baking soda',
#    'bananas',
#    'canola oil',
#    'egg',
#    'flour',
#    'raisins',
#    'salt',
#    'sugar',
#    'walnuts'}],
#  ['121712', {'cream cheese', 'thousand island dressing'}],
#  ['155344',
#   {'chili sauce', 'mayonnaise', 'onion powder', 'sweet pickle relish'}],
#  ['175339',
#   {'baking soda',
#    'brown sugar',
#    'chocolate chips',
#    'cream of tartar',
#    'egg',
#    'flaked coconut',
#    'flour',
#    'margarine',
#    'oil',
#    'rice krispies',
#    'rolled oats',
#    'vanilla',
#    'white sugar'}],
#  ['72600',
#   {'baby spinach',
#    'bacon',
#    'buttermilk',
#    'fresh lemon juice',
#    'garlic',
#    'hardboiled egg',
#    'mushrooms',
#    'plain yogurt',
#    'sugar',
#    'unsalted sunflower seeds',
#    'white pepper'}],
#  ['50614',
#   {'bacon',
#    'cauliflower',
#    'cherry tomatoes',
#    'fresh broccoli',
#    'fresh mushrooms',
#    'frozen peas',
#    'green pepper',
#    'italian seasoning',
#    'lettuce',
#    'mayonnaise',
#    'red onion',
#    'sugar'}],
#  ['133784',
#   {'basil leaves',
#    'black pepper',
#    'celery salt',
#    'chili powder',
#    'garlic powder',
#    'ground allspice',
#    'ground oregano',
#    'marjoram leaves',
#    'onion salt',
#    'paprika',
#    'rubbed sage'}],
#  ['235003', {'beer', 'fresh jalapeno', 'ice', 'vodka'}],
#  ['140723',
#   {'anchovy fillets',
#    'baby spinach',
#    'bacon',
#    'dijon mustard',
#    'extra virgin olive oil',
#    'french bread',
#    'fresh mushrooms',
#    'garlic',
#    'lemon juice',
#    'low-fat mayonnaise',
#    'miracle whip light',
#    'oil',
#    'olive oil',
#    'parmesan cheese',
#    'worcestershire sauce'}],
#  ['326839',
#   {'dried italian seasoning',
#    'egg',
#    'ground beef',
#    'ground pepper',
#    'italian cheese blend',
#    'jumbo pasta shells',
#    'mexican blend cheese',
#    'mozzarella cheese',
#    'parmesan-romano cheese mix',
#    'parsley flakes',
#    'ricotta cheese',
#    'salt',
#    'spaghetti sauce'}],
#  ['467326',
#   {'bread machine yeast',
#    'brown sugar',
#    'oil',
#    'salt',
#    'water',
#    'white flour',
#    'whole wheat flour'}],
#  ['43669',
#   {'butter',
#    'cream-style corn',
#    'evaporated milk',
#    'onion',
#    'potato',
#    'salt and pepper',
#    'water',
#    'whole corn'}],
#  ['73566',
#   {'black pepper',
#    'extra virgin olive oil',
#    'flat leaf parsley',
#    'italian seasoned breadcrumbs',
#    'kosher salt',
#    'orecchiette',
#    'parmesan cheese',
#    'prosciutto'}],
#  ['449768',
#   {'cumin seeds', 'fresh ground black pepper', 'olive oil', 'salt', 'tomato'}],
#  ['404661',
#   {'baking soda',
#    'butter',
#    'corn syrup',
#    'molasses',
#    'salted peanuts',
#    'vanilla',
#    'white sugar'}],
#  ['381713',
#   {'bulgar wheat',
#    'cinnamon',
#    'lean ground beef',
#    'onion',
#    'plain yogurt',
#    'salt'}],
#  ['257696',
#   {'apple pie filling',
#    'egg',
#    'instant vanilla pudding',
#    'oil',
#    'water',
#    'yellow cake mix'}],
#  ['187606',
#   {'boneless skinless chicken breasts',
#    'carrot',
#    'italian dressing',
#    'potato'}],
#  ['91515', {'chocolate milk', 'cinnamon rolls', 'egg'}],
#  ['289891',
#   {'baking powder',
#    'butter',
#    'egg',
#    'flour',
#    'milk',
#    'salt',
#    'vanilla',
#    'white sugar'}],
#  ['412073',
#   {'basil',
#    'black pepper',
#    'carrot',
#    'celery',
#    'garlic',
#    'ham',
#    'leeks',
#    'salt',
#    'soup mix',
#    'thyme',
#    'water',
#    'worcestershire sauce'}],
#  ['123746',
#   {'bell peppers',
#    'chili sauce',
#    'egg',
#    'garlic powder',
#    'ground beef',
#    'milk',
#    'onion',
#    'salt and pepper',
#    'saltine crackers',
#    'worcestershire sauce'}],
#  ['206020',
#   {'aluminum foil',
#    'beef tenderloin',
#    'garlic',
#    'limes, juice of',
#    'prepared horseradish',
#    'salt and pepper',
#    'sour cream',
#    'unsalted butter',
#    'worcestershire sauce'}],
#  ['345595',
#   {'baking powder',
#    'baking soda',
#    'carrot',
#    'cinnamon',
#    'cream cheese',
#    'egg',
#    'flour',
#    'margarine',
#    'oil',
#    'pineapple',
#    'powdered sugar',
#    'salt',
#    'sugar',
#    'walnuts'}],
#  ['129227',
#   {'cabbage',
#    'carrot',
#    'celery seed',
#    'mustard seeds',
#    'onion',
#    'salt',
#    'sugar',
#    'turmeric',
#    'water',
#    'white vinegar'}],
#  ['472955',
#   {'alum',
#    'pickling cucumbers',
#    'pickling spices',
#    'salt',
#    'sugar',
#    'vinegar',
#    'water'}],
#  ['17490',
#   {'alum',
#    'canning salt',
#    'cucumbers',
#    'pickling spices',
#    'sugar',
#    'vinegar'}],
#  ['130002',
#   {'allspice',
#    'baking soda',
#    'carrot',
#    'cinnamon',
#    'coconut',
#    'cream cheese',
#    'egg',
#    'flour',
#    'ground cloves',
#    'margarine',
#    'nuts',
#    'oil',
#    'powdered sugar',
#    'raisins',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['53353', {'butter', 'cream', 'lemon extract', 'maple syrup', 'nutmeats'}],
#  ['105756',
#   {'basil',
#    'beans',
#    'carrot',
#    'celery',
#    'chicken bouillon cubes',
#    'chicken broth',
#    'deli ham',
#    'lemon juice',
#    'onion',
#    'parsley',
#    'raw rice',
#    'salt',
#    'tomato',
#    'v8 vegetable juice',
#    'water'}],
#  ['307362',
#   {'hormel chili without beans',
#    'monterey jack cheese',
#    'refried beans',
#    'tortillas'}],
#  ['51803',
#   {'15 bean soup mix',
#    'black pepper',
#    'celery leaves',
#    'chicken bouillon cubes',
#    'dried parsley',
#    'dried rosemary',
#    'garlic',
#    'ham hocks',
#    'olive oil',
#    'onion',
#    'salt',
#    'whole tomatoes'}],
#  ['438263',
#   {'15 bean soup mix',
#    'beef bouillon paste',
#    'black pepper',
#    'diced tomatoes',
#    'garlic',
#    'ham bone',
#    'smoked sausage',
#    'steak sauce',
#    'water',
#    'worcestershire sauce'}],
#  ['525649',
#   {'black pepper',
#    'carrot',
#    'cayenne pepper',
#    'chili powder',
#    'condensed tomato soup',
#    'dried beans',
#    'garlic',
#    'ham',
#    'lemon',
#    'olive oil',
#    'onion',
#    'oregano',
#    'paprika',
#    'salt',
#    'smoked paprika',
#    'thyme',
#    'water'}],
#  ['115160',
#   {'baking soda',
#    'egg',
#    'flour',
#    'ground walnuts',
#    'honey',
#    'liquid honey',
#    'margarine',
#    'plain sweet biscuit crumbs',
#    'sour cream',
#    'sugar'}],
#  ['168222',
#   {'capers',
#    'chicken stock',
#    'fresh chives',
#    'fresh parsley',
#    'fresh tarragon',
#    'garlic',
#    'halibut steaks',
#    'lemon juice',
#    'salt and pepper'}],
#  ['140172',
#   {'boneless sirloin steak',
#    'lipton beefy mushroom soup mix',
#    'new potatoes',
#    'oil',
#    'peas and carrots',
#    'tomato paste',
#    'water'}],
#  ['305112',
#   {'black beans',
#    'frozen corn kernels',
#    'ground beef',
#    'taco seasoning',
#    'tomatoes and green chilies'}],
#  ['53481',
#   {'cheddar cheese',
#    'ketchup',
#    'lean ground beef',
#    'minute white rice',
#    'mustard',
#    'water'}],
#  ['76887',
#   {'chili with beans',
#    'diced tomatoes',
#    'ground beef',
#    'velveeta cheese',
#    'water',
#    'white rice'}],
#  ['392598',
#   {'boneless skinless chicken breast halves',
#    'condensed cream of chicken soup',
#    'ground pepper',
#    'instant rice',
#    'paprika',
#    'vegetable oil',
#    'water'}],
#  ['113197',
#   {'black pepper',
#    'cheese',
#    'chicken breast tenders',
#    'fajita seasoning mix',
#    'lime',
#    'olive oil',
#    'onion',
#    'pico de gallo',
#    'sour cream',
#    'tortilla'}],
#  ['398071',
#   {'cheddar cheese',
#    'chicken',
#    'chicken broth',
#    'kidney beans',
#    'mexicorn',
#    'salsa',
#    'sour cream',
#    'tortilla chips'}],
#  ['66527',
#   {'boneless skinless chicken breasts',
#    'broccoli florets',
#    'condensed cream of chicken soup',
#    'milk',
#    'minute rice',
#    'vegetable oil'}],
#  ['184890',
#   {'chili powder',
#    'cumin',
#    'ground turkey',
#    'kidney beans',
#    'onion',
#    'pinto beans',
#    'salsa',
#    'salt',
#    'stewed tomatoes'}],
#  ['79046',
#   {'cheese',
#    'chili with beans',
#    'flour tortillas',
#    'sour cream',
#    'water',
#    'white minute rice'}],
#  ['356163',
#   {'broccoli',
#    'chili powder',
#    'ketchup',
#    'lean ground beef',
#    'macaroni & cheese dinner mix',
#    'water'}],
#  ['41673',
#   {'allspice',
#    'black pepper',
#    'brown sugar',
#    'cinnamon',
#    'clove',
#    'onion',
#    'salt',
#    'tomato'}],
#  ['506885',
#   {'black pepper',
#    'crushed red pepper flakes',
#    'fresh basil',
#    'fresh oregano',
#    'fresh parmesan cheese',
#    'garlic',
#    'grape tomatoes',
#    'pappardelle pasta',
#    'roasted cashews',
#    'sun-dried tomato packed in oil'}],
#  ['277539',
#   {'chipotle chile in adobo',
#    'garlic',
#    'ground coriander',
#    'ground cumin',
#    'low sodium chicken broth',
#    'onion',
#    'salt',
#    'tomato sauce'}],
#  ['169487',
#   {'fat free cream cheese',
#    'fat-free whipped topping',
#    'reduced fat graham cracker crust',
#    'sugar substitute'}],
#  ['317587',
#   {'fresh linguine',
#    'fresh spinach',
#    'lemon juice',
#    'parmesan cheese',
#    'pesto sauce',
#    'pine nuts',
#    'red onion',
#    'tomato'}],
#  ['20624',
#   {'boneless skinless chicken breast halves',
#    'butter',
#    'chicken broth',
#    'flour',
#    'garlic',
#    'lemon juice',
#    'oil',
#    'salt and pepper'}],
#  ['360232',
#   {'celery ribs',
#    'cracked black pepper',
#    'extra virgin olive oil',
#    'feta cheese',
#    'fresh lemon juice',
#    'fresh parsley',
#    'garbanzo beans',
#    'garlic',
#    'of fresh mint',
#    'romaine lettuce',
#    'salt',
#    'scallion',
#    'tomato'}],
#  ['246548',
#   {'assorted fresh vegetables',
#    'boneless skinless chicken breast',
#    'instant rice',
#    'italian dressing',
#    'oil',
#    'reduced-sodium fat-free chicken broth'}],
#  ['67446',
#   {'butter',
#    'cream cheese',
#    'graham cracker crumbs',
#    'instant lemon pudding',
#    'milk',
#    'powdered sugar'}],
#  ['153028',
#   {'butter', 'cocoa', "confectioners' sugar", 'peanut butter', 'vanilla'}],
#  ['172651',
#   {'italian salad dressing',
#    'parmesan cheese',
#    'smoked turkey breast',
#    'spaghetti',
#    'tomato'}],
#  ['348952',
#   {'chicken bouillon cube',
#    'frozen mixed vegetables',
#    'minute rice',
#    'oil',
#    'pork tenderloin',
#    'soy sauce',
#    'water'}],
#  ['5276',
#   {'chicken bouillon cubes',
#    'green pepper',
#    'hot pepper sauce',
#    'kidney beans',
#    'minute white rice',
#    'oil',
#    'onion',
#    'water'}],
#  ['140173',
#   {'baby peas',
#    'bacon bits',
#    'black pepper',
#    'fettuccine',
#    'garlic salt',
#    'half-and-half cream',
#    'parmesan cheese',
#    'shrimp'}],
#  ['31184',
#   {'angel hair pasta',
#    'butter',
#    'extra virgin olive oil',
#    'frozen shrimp',
#    'garlic',
#    'onion',
#    'salt & pepper',
#    'white wine'}],
#  ['164178',
#   {'celery',
#    'garlic flakes',
#    'hamburger',
#    'hot chili flakes',
#    'jalapenos',
#    'onion',
#    'sliced mushrooms',
#    'sweet green pepper',
#    'sweet red pepper',
#    'tomato sauce & mushrooms'}],
#  ['289025',
#   {'asparagus',
#    'boneless skinless chicken breast',
#    'chicken broth',
#    'chili flakes',
#    'fresh ginger',
#    'garlic',
#    'onion',
#    'rice vinegar',
#    'salt',
#    'soy sauce',
#    'white pepper'}],
#  ['287502',
#   {'dijon mustard',
#    'elbow macaroni',
#    'extra-sharp cheddar cheese',
#    'fresh ground black pepper',
#    'half-and-half',
#    'hot sauce',
#    'kosher salt',
#    'unsalted butter'}],
#  ['75079',
#   {'butter',
#    'dry onion soup mix',
#    'flour',
#    'fresh mushrooms',
#    'round steak',
#    'sour cream',
#    'water'}],
#  ['147100',
#   {'chopped tomatoes',
#    'extra lean ground beef',
#    'lettuce',
#    'mexican blend cheese',
#    'minute white rice',
#    'taco seasoning mix',
#    'water'}],
#  ['233317',
#   {'baby spinach',
#    'cornflour',
#    'dark soy sauce',
#    'lime, juice and zest of',
#    'pak choi',
#    'sunflower oil',
#    'sweet chili sauce',
#    'thai fish sauce',
#    'tiger shrimp',
#    'water'}],
#  ['109793', {'milk', 'minute rice', 'raisins', 'vanilla instant pudding mix'}],
#  ['291409',
#   {'black beans', 'fire-roasted tomatoes', 'kidney beans', 'salsa', 'water'}],
#  ['27275',
#   {'cream cheese',
#    'fettuccine pasta',
#    'margarine',
#    'milk',
#    'parmesan cheese'}],
#  ['282812',
#   {'dried fruits',
#    'honey',
#    'milk',
#    'quick oats',
#    'salt',
#    'sugar',
#    'vanilla',
#    'water'}],
#  ['311608',
#   {'15 bean mix',
#    'bay leaves',
#    'black pepper',
#    'carrot',
#    'celery',
#    'chicken bouillon cubes',
#    'diced tomatoes',
#    'garlic',
#    'ham hocks',
#    'onion',
#    'seasoning salt',
#    'tomato sauce',
#    'water'}],
#  ['382234',
#   {'black-eyed peas',
#    'canned green beans',
#    'chili seasoning mix',
#    'corn chips',
#    'dark red kidney beans',
#    'green bell pepper',
#    'ground beef',
#    'ketchup',
#    'onion',
#    'red pepper flakes',
#    'salt and pepper',
#    'sharp cheddar cheese',
#    'vegetable oil',
#    'water',
#    'whole tomatoes'}],
#  ['237391',
#   {'brandy',
#    'butter',
#    'chicken liver',
#    'garlic',
#    'ground black pepper',
#    'heavy cream',
#    'marjoram',
#    'onion',
#    'sage',
#    'salt',
#    'thyme'}],
#  ['266997',
#   {'cayenne pepper',
#    'chili beans',
#    'chili powder',
#    'cumin',
#    'diced tomatoes',
#    'lean ground beef',
#    'onion',
#    'oregano',
#    'salt',
#    'sliced mushrooms',
#    'sour cream'}],
#  ['21916',
#   {'cool whip topping',
#    'frozen pound cake',
#    'jello instant vanilla pudding mix',
#    'orange liqueur',
#    'strawberries',
#    'strawberry',
#    'sugar',
#    'white chocolate baking squares'}],
#  ['229451',
#   {'black pepper',
#    'boneless skinless chicken breast halves',
#    'dijon mustard',
#    'dried tarragon',
#    'fresh lemon juice',
#    'worcestershire sauce'}],
#  ['204040', {'basmati rice', 'chicken broth', 'salt and pepper'}],
#  ['82287',
#   {'black olives',
#    'cooked chicken',
#    'cream of chicken soup',
#    'green enchilada sauce',
#    'green onion',
#    'lettuce',
#    'monterey jack cheese',
#    'salsa',
#    'sour cream',
#    'tomato',
#    'tortilla chips'}],
#  ['302815', {'butter', 'garlic', 'parmesan cheese', 'pasta'}],
#  ['311842',
#   {'black pepper',
#    'dried oregano',
#    'feta cheese',
#    'garlic',
#    'large shrimp',
#    'old bay seasoning',
#    'olive oil',
#    'parsley',
#    'tomato'}],
#  ['531148',
#   {'cherry tomatoes',
#    'corn kernels',
#    'herbs',
#    'large shrimp',
#    'lemon, zest of',
#    'olive oil',
#    'red onion',
#    'salt & freshly ground black pepper',
#    'snap peas',
#    'unsalted butter',
#    'zucchini'}],
#  ['364157',
#   {'dried oregano',
#    'fresh lemon juice',
#    'garlic',
#    'olive oil',
#    'parmesan cheese',
#    'salt and pepper',
#    'scallions',
#    'vegetable broth',
#    'white beans'}],
#  ['411979',
#   {'bay leaves',
#    'beans',
#    'carrot',
#    'celery',
#    'chicken stock',
#    'garlic',
#    'italian sausage',
#    'onion',
#    'oregano',
#    'tomato',
#    'water'}],
#  ['102832',
#   {'alum',
#    'cinnamon sticks',
#    'cucumbers',
#    'pickling salt',
#    'pickling spices',
#    'sugar',
#    'white vinegar'}],
#  ['246180', {'barbecue sauce', 'ginger ale', 'onion', 'pork butt'}],
#  ['224908',
#   {'brown sugar',
#    'cold water',
#    'dark molasses',
#    'strong coffee',
#    'sugar',
#    'vanilla bean',
#    'vodka'}],
#  ['364761',
#   {'carrot',
#    'celery',
#    'celery ribs',
#    'chicken bouillon cubes',
#    'chicken broth',
#    'frozen corn',
#    'frozen white corn',
#    'onion',
#    'potato',
#    'whole chickens'}],
#  ['489337',
#   {'basil',
#    'eggplant',
#    'fat-free parmesan cheese',
#    'fennel seed',
#    'lean ground turkey',
#    'low-carb marinara sauce',
#    'nonstick cooking spray',
#    'oregano leaves'}],
#  ['262448', {'mountain dew soda', 'raspberry vodka'}],
#  ['294427',
#   {'apple cider',
#    'arugula',
#    'dijon mustard',
#    'fresh thyme',
#    'gouda cheese',
#    'olive oil',
#    'pancetta',
#    'red onion',
#    'red wine vinegar',
#    'salt and pepper',
#    'shallots',
#    'sherry wine vinegar',
#    'tart apples',
#    'white cheddar cheese',
#    'white vinegar'}],
#  ['328436',
#   {'baby carrots',
#    'baking powder',
#    'baking soda',
#    "confectioners' sugar",
#    'egg',
#    'flour',
#    'light brown sugar',
#    'marshmallow cream',
#    'pumpkin pie spice',
#    'pure vanilla extract',
#    'salt',
#    'unsalted butter',
#    'vegetable oil'}],
#  ['357228',
#   {'baking soda',
#    'butter',
#    'buttermilk',
#    'cinnamon',
#    'clove',
#    'cocoa',
#    'egg',
#    'flour',
#    'nutmeg',
#    'salt',
#    'sugar',
#    'vanilla'}],
#  ['50246',
#   {'almonds',
#    'cornstarch',
#    'cream of tartar',
#    'egg',
#    'egg yolks',
#    'flour',
#    'milk',
#    'powdered sugar',
#    'sugar',
#    'sweet cream'}],
#  ...]

# %% [markdown]
# Reshape the data into a vector of vectors of ingredients per recipe, to use for training a [*word2vec*](https://arxiv.org/abs/1301.3781) vector embedding model:

# %%
vectors = []

for id, ind_set in recipes:
    v = []
    
    for ind in ind_set:
        v.append(ind)

    vectors.append(v)

vectors
# Out:
# [['winter squash',
#   'honey',
#   'mixed spice',
#   'salt',
#   'olive oil',
#   'mexican seasoning',
#   'butter'],
#  ['milk',
#   'sausage patty',
#   'salt and pepper',
#   'prepared pizza crust',
#   'cheese',
#   'egg'],
#  ['chili powder',
#   'rotel tomatoes',
#   'lettuce',
#   'water',
#   'ground beef',
#   'salt',
#   'ground cumin',
#   'cheddar cheese',
#   'yellow onions',
#   'tomato soup',
#   'diced tomatoes',
#   'kidney beans',
#   'tomato paste'],
#  ['red wine vinegar',
#   'tarragon',
#   'parsley',
#   'red bell pepper',
#   'salt',
#   'spreadable cheese with garlic and herbs',
#   'olive oil',
#   'shallots',
#   'new potatoes',
#   'black pepper',
#   'yellow bell pepper'],
#  ['apple cider vinegar',
#   'tomato juice',
#   'cinnamon oil',
#   'clove oil',
#   'salt',
#   'sugar',
#   'black pepper',
#   'dry mustard'],
#  ['frozen apple juice concentrate', 'apple', 'vanilla ice cream', 'milk'],
#  ['ripe olives',
#   'fennel seeds',
#   'garlic',
#   'peppercorn',
#   'orange rind',
#   'red chile',
#   'orange juice',
#   'green olives',
#   'extra virgin olive oil'],
#  ['fresh garlic',
#   'white vinegar',
#   'liquid smoke',
#   'mirin',
#   'tomato sauce',
#   'brown sugar',
#   'orange, juice of',
#   'salt',
#   'cracked black pepper',
#   'cumin',
#   'fresh coarse ground black pepper',
#   'fresh ginger',
#   'chili powder',
#   'water',
#   'cinnamon sticks',
#   'dry mustard',
#   'soy sauce',
#   'fresh cilantro leaves',
#   'honey',
#   'pork spareribs',
#   'a.1. original sauce',
#   'yellow onion'],
#  ['chocolate sandwich style cookies',
#   'chocolate syrup',
#   'whipped cream',
#   'bananas',
#   'vanilla ice cream',
#   'strawberry ice cream'],
#  ['fresh lemon juice',
#   'baking soda',
#   'salt',
#   'bananas',
#   'sugar',
#   'unsalted butter',
#   'orange rind',
#   'egg',
#   'cake flour'],
#  ['prepared horseradish', 'sour cream', 'whole berry cranberry sauce'],
#  ['vanilla wafers',
#   'whipping cream',
#   'strawberry',
#   'walnuts',
#   'powdered sugar',
#   'butter',
#   'egg'],
#  ['chili powder',
#   'mustard powder',
#   'molasses',
#   'water',
#   'cornstarch',
#   'salt',
#   'dark brown sugar',
#   'great northern bean',
#   'onion',
#   'garlic powder',
#   'bacon',
#   'black pepper',
#   'chicken bouillon cubes'],
#  ['molasses',
#   'salt',
#   'collard greens',
#   'hot sauce',
#   'ham hock',
#   'brown sugar',
#   'whiskey'],
#  ['spearmint', 'scullcap herb', 'burnet root', 'wood bethony', 'gentian root'],
#  ['flour',
#   'salt',
#   'oil',
#   'chicken rice soup',
#   'garlic powder',
#   'lean pork chops',
#   'dry mustard'],
#  ['cornstarch', 'egg roll wrap', 'oil', 'cheese', 'whole green chilies'],
#  ['chinese noodles', 'salted peanuts', 'butterscotch chips'],
#  ['soy sauce',
#   'onion',
#   'ground pork',
#   'hamburger buns',
#   'cooking oil',
#   'celery',
#   'beef broth'],
#  ['canola oil',
#   'salt free herb and spice seasoning mix',
#   'water',
#   'broccoli floret',
#   'green peas',
#   'red bell pepper',
#   'ground coriander',
#   'fresh herb',
#   'cauliflower',
#   'vegetable bouillon cubes',
#   'garlic',
#   'salt and pepper',
#   'great northern bean',
#   'onion',
#   'escarole',
#   'potato'],
#  ['boiling potatoes',
#   'water',
#   'fresh ground black pepper',
#   'salt',
#   'nutmeg',
#   'unsalted butter',
#   'fresh spinach leaves',
#   'coarse salt'],
#  ['rolled oats',
#   'dried thyme',
#   'broth',
#   'salt',
#   'spinach',
#   'apple juice',
#   'onion',
#   'olive oil',
#   'white pepper',
#   'scallion',
#   'fresh parsley',
#   'celery'],
#  ['boneless skinless chicken breast halves',
#   'flour',
#   'cornstarch',
#   'condensed cream of chicken soup',
#   'salt and pepper',
#   'oil',
#   'seasoning salt',
#   'garlic powder',
#   'paprika',
#   'egg'],
#  ['flour',
#   'milk',
#   'vegetable oil',
#   'baking powder',
#   'salt',
#   'bread',
#   'vanilla',
#   'powdered sugar',
#   'granulated sugar',
#   'butter',
#   'egg',
#   'brown sugar',
#   'ground cinnamon'],
#  ['salt', 'white pepper', 'butter', 'lemon, juice of', 'egg yolks'],
#  ['ground coriander',
#   'ground black pepper',
#   'ground cumin',
#   'ground turmeric',
#   'ground ginger',
#   'black cumin'],
#  ['chili powder',
#   'jalapenos',
#   'diced tomatoes',
#   'red pepper flakes',
#   'green pepper',
#   'celery',
#   'salt',
#   'garlic',
#   'vegetarian ground beef',
#   'onion',
#   'black pepper',
#   'kidney beans'],
#  ['ground thyme',
#   'tomato',
#   'water',
#   'elbow macaroni',
#   'zucchini',
#   'dried parsley',
#   'salt',
#   'cabbage',
#   'ground pepper',
#   'beef stew meat',
#   'onion',
#   'beef bouillon cube',
#   'parmesan cheese',
#   'garbanzo beans'],
#  ['margarine', 'rosemary', 'red potatoes'],
#  ['dried thyme',
#   'salt & fresh ground pepper',
#   'chicken stock',
#   'black beans',
#   'broccoli floret',
#   'cornstarch',
#   'carrot',
#   'dried sweet basil leaves',
#   'broccoli stem',
#   'onion',
#   'dried oregano',
#   'unsalted butter',
#   'smoked chicken',
#   'dry white wine',
#   'worcestershire sauce',
#   'heavy cream',
#   'tabasco sauce',
#   'celery'],
#  ['flour',
#   'baking powder',
#   'miniature peppermint patties',
#   'salt',
#   'vanilla',
#   'sugar',
#   'baking cocoa',
#   'butter',
#   'egg'],
#  ['tomato sauce',
#   'cornmeal',
#   'whole kernel corn',
#   'ground beef',
#   'taco sauce',
#   'salt',
#   'cheddar cheese',
#   'onion',
#   'hot chili pepper',
#   'sliced ripe olives',
#   'black pepper',
#   'tabasco sauce'],
#  ['dry ranch dressing mix', 'butter', 'french bread'],
#  ['water',
#   'fresh breadcrumb',
#   'salt',
#   'onion',
#   'non-fat powdered milk',
#   'worcestershire sauce',
#   'black pepper',
#   'ground venison',
#   'egg substitute',
#   'dry mustard'],
#  ['plain yogurt', 'frozen juice concentrate', 'milk'],
#  ['corn',
#   'low sodium chicken broth',
#   'zucchini',
#   'carrot',
#   'green beans',
#   'wax beans',
#   'diced tomatoes',
#   'potato'],
#  ['crouton',
#   'salt',
#   'onion',
#   'black pepper',
#   'sharp cheddar cheese',
#   'frozen chopped spinach',
#   'condensed cream of mushroom soup',
#   'egg'],
#  ['fat-free mayonnaise',
#   'green onion',
#   'diced pimentos',
#   'salt',
#   'white wine vinegar',
#   'red potatoes',
#   'sugar',
#   'garlic',
#   'plain low-fat yogurt',
#   'low-fat sour cream',
#   'prepared mustard',
#   'celery seed',
#   'black pepper'],
#  ['soft breadcrumbs',
#   'onion',
#   'sage',
#   'garlic powder',
#   'oregano',
#   'frozen chopped spinach',
#   'egg',
#   'margarine'],
#  ['ground beef',
#   'salt & pepper',
#   'onion',
#   'frozen vegetables',
#   'cornbread mix',
#   'cooking oil',
#   'condensed cream of mushroom & garlic soup',
#   'cream of mushroom soup'],
#  ['honey',
#   'stir fry vegetables',
#   'soy sauce',
#   'green onions',
#   'toasted sesame oil',
#   'garlic',
#   'toasted sesame seeds',
#   'angel hair pasta'],
#  ['cinnamon',
#   'baking soda',
#   'yam',
#   'unsweetened cocoa',
#   'orange rind',
#   'orange juice',
#   'butter',
#   'brown sugar',
#   'pecans',
#   'salt',
#   'low-fat buttermilk',
#   'egg',
#   'canola oil',
#   'buckwheat flour',
#   'sugar',
#   'flour',
#   'honey',
#   'baking powder',
#   'ground cloves',
#   'ground cinnamon'],
#  ['canola oil',
#   'buckwheat flour',
#   'baking soda',
#   'flour',
#   'raisins',
#   'baking powder',
#   'salt',
#   'yam',
#   'low-fat buttermilk',
#   'unsweetened cocoa',
#   'ground cloves',
#   'orange rind',
#   'sorghum',
#   'orange juice',
#   'granulated sugar',
#   'egg',
#   'boiling water',
#   'ground cinnamon'],
#  ['american cheese',
#   'ground beef',
#   'salt & pepper',
#   'garlic',
#   'cayenne',
#   'sugar',
#   'beer',
#   'prepared yellow mustard'],
#  ['onion powder',
#   'tomato',
#   'tri-color spiral pasta',
#   'water chestnut',
#   'ripe olives',
#   'cider vinegar',
#   'salt and pepper',
#   'dill pickles',
#   'olive oil',
#   'italian seasoning',
#   'garlic powder',
#   'cheese',
#   'sweet pepper',
#   'green onion',
#   'ham',
#   'chives'],
#  ['basil',
#   'oil',
#   'salt & freshly ground black pepper',
#   'frozen french fries',
#   'oregano',
#   'parmesan cheese',
#   'flat leaf parsley'],
#  ['deli turkey',
#   'pepperoni',
#   'swiss cheese',
#   'mozzarella cheese',
#   'good seasonings italian salad dressing mix',
#   'cheddar cheese',
#   'sandwich bun',
#   'ham',
#   'butter'],
#  ['shortening',
#   'milk',
#   'flour',
#   'icing sugar',
#   'baking powder',
#   'salt',
#   'vanilla',
#   'sugar',
#   'butter',
#   'egg'],
#  ['cinnamon',
#   'coconut',
#   'water',
#   'carrot',
#   'pecans',
#   'crushed pineapple',
#   'oil',
#   'nutmeg',
#   'vanilla instant pudding mix',
#   'yellow cake mix',
#   'egg'],
#  ['jiffy corn muffin mix',
#   'jalapenos',
#   'whole kernel corn',
#   'honey',
#   'red bell pepper',
#   'onion',
#   'sharp cheddar cheese',
#   'heavy cream',
#   'butter',
#   'egg'],
#  ['nuts',
#   'cinnamon',
#   'flour',
#   'milk',
#   'water',
#   'baking soda',
#   'vegetable oil',
#   'raisins',
#   'baking powder',
#   'crushed pineapple',
#   'dry yeast',
#   'salt',
#   'sugar',
#   'vanilla',
#   'butter',
#   'egg',
#   'brown sugar'],
#  ['mozzarella cheese',
#   'ground beef',
#   'cottage cheese',
#   'whole tomato',
#   'salt',
#   'garlic',
#   'dried basil',
#   'lasagna noodle',
#   'parsley flakes',
#   'ricotta cheese',
#   'italian sausage',
#   'ground black pepper',
#   'parmesan cheese',
#   'egg',
#   'tomato paste'],
#  ['olive oil flavored cooking spray',
#   'cottage cheese',
#   'beef',
#   'salt',
#   'toasted wheat germ',
#   'herbs',
#   'spices',
#   'cheese',
#   'frozen chopped spinach',
#   'black pepper',
#   'egg'],
#  ['cinnamon',
#   'rolls',
#   'raisins',
#   'instant vanilla pudding',
#   'butter',
#   'brown sugar'],
#  ['ground beef',
#   'white onion',
#   'garlic',
#   'stewed tomatoes',
#   'prego spaghetti sauce',
#   'granulated sugar'],
#  ['fresh lemon juice',
#   'honey',
#   'dried dill weed',
#   'vegetable oil',
#   'ketchup',
#   'beef steaks',
#   'fresh garlic',
#   'spicy mustard',
#   'hot sauce',
#   'fresh parsley',
#   'sour cream',
#   'brown sugar'],
#  ['flour', 'milk', 'baking powder', 'salt', 'sugar', 'butter', 'egg'],
#  ['button mushrooms',
#   'tomato',
#   'water',
#   'salsa',
#   'fresh ground black pepper',
#   'garlic',
#   'dried basil',
#   'chicken breasts',
#   'onion',
#   'dried oregano',
#   'olive oil',
#   'pasta',
#   'hot sauce',
#   'parmesan cheese',
#   'fresh parsley'],
#  ['fresh herbs', 'fresh herb', 'cider vinegar'],
#  ['flour',
#   'fresh corn',
#   'baking powder',
#   'cream',
#   'salt',
#   'fat',
#   'black pepper',
#   'egg'],
#  ['milk',
#   'black olives',
#   'cheddar cheese soup',
#   'fettuccine pasta',
#   'picante sauce',
#   'jalapeno'],
#  ['tomato',
#   'cilantro',
#   'frozen peas',
#   'salt',
#   'onion',
#   'lemons, juice of',
#   'hass avocado'],
#  ['lemon juice',
#   'soy sauce',
#   'basil',
#   'oil',
#   'garlic powder',
#   'worcestershire sauce',
#   'black pepper'],
#  ['cream cheese', 'yogurt', 'milk', 'unflavored gelatin', 'apple', 'pear'],
#  ['bay leaf',
#   'carrot',
#   'thyme',
#   'salt',
#   'oil',
#   'parsley sprigs',
#   'onion',
#   'veal roast',
#   'bacon',
#   'black pepper',
#   'butter'],
#  ['crackers', 'black pepper', 'mayonnaise', 'tomato'],
#  ['red wine vinegar',
#   'tomato',
#   'ciabatta',
#   'carrot',
#   'capers',
#   'sweet onion',
#   'genoa salami',
#   'garlic',
#   'oregano leaves',
#   'olive oil',
#   'fresh basil',
#   'brine',
#   'kalamata olive',
#   'ham',
#   'green olives',
#   'provolone cheese',
#   'fresh parsley'],
#  ['powdered sugar',
#   'vanilla instant pudding mix',
#   'whipping cream',
#   'vanilla'],
#  ['cookie',
#   'gelatin',
#   'cream cheese',
#   'milk',
#   'vanilla',
#   'sugar',
#   'miniature semisweet chocolate chips',
#   'prepared graham cracker crusts'],
#  ['sliced mushrooms',
#   'green pepper',
#   'monterey jack cheese',
#   'butter',
#   'celery',
#   'tomato',
#   'carrot',
#   'cloves',
#   'cayenne pepper',
#   'ground cumin',
#   'salt',
#   'onion',
#   'vegetable shortening',
#   'egg',
#   'chili powder',
#   'water',
#   'oregano',
#   'flour',
#   'soy sauce',
#   'zucchini',
#   'baking powder'],
#  ['half-and-half', 'sweet corn', 'salt and pepper', 'sweet butter'],
#  ['baking soda',
#   'yogurt',
#   'flour',
#   'salt',
#   'sugar',
#   'vanilla',
#   'lemon, rind of',
#   'butter',
#   'egg'],
#  ['nuts',
#   'flour',
#   'unsweetened chocolate squares',
#   'vanilla',
#   'sugar',
#   'butter',
#   'egg'],
#  ['green onions',
#   'vegetable oil',
#   'chili-garlic sauce',
#   'fresh cilantro',
#   'rice vinegar',
#   'vermicelli',
#   'sesame seeds',
#   'reduced sodium soy sauce',
#   'cooked chicken',
#   'broccoli',
#   'sesame oil',
#   'fresh ginger'],
#  ['philadelphia cream cheese',
#   'pecans',
#   'sugar',
#   'orange rind',
#   'orange juice',
#   'apples',
#   'celery'],
#  ['lemon juice',
#   'thyme',
#   'salt',
#   'garlic',
#   'cayenne',
#   'fresh ground pepper',
#   'olive oil',
#   'paprika',
#   'cumin',
#   'boneless chicken breast'],
#  ['mozzarella cheese',
#   'baking potato',
#   'oregano leaves',
#   'garlic powder',
#   'part-skim ricotta cheese',
#   'parmesan cheese',
#   'tomato sauce'],
#  ['cornstarch',
#   'white wine',
#   'sodium-free vegetable broth',
#   'onion',
#   'tomato puree',
#   'mushroom pieces',
#   'black pepper',
#   'tabasco sauce'],
#  ['red wine vinegar',
#   'red sweet bell peppers',
#   'light olive oil',
#   'salt',
#   'garlic',
#   'scallions',
#   'albacore tuna in water',
#   'fresh basil',
#   'bibb lettuce',
#   'black pepper',
#   'white kidney beans'],
#  ['crushed tomatoes',
#   'black pepper',
#   'butter',
#   'celery',
#   'carrot',
#   'salt',
#   'onion',
#   'olive oil',
#   'beef consomme',
#   'nutmeg',
#   'penne pasta',
#   'ground pork',
#   'lean ground beef',
#   'milk',
#   'garlic',
#   'bacon',
#   'dry white wine',
#   'oregano',
#   'rubbed sage',
#   'red pepper flakes'],
#  ['red cinnamon candies', 'apples', 'sugar substitute', 'water'],
#  ['tomato',
#   'lemon juice',
#   'elbow macaroni',
#   'green pepper',
#   'ketchup',
#   'oil',
#   'cucumber',
#   'onion',
#   'celery',
#   'brown sugar'],
#  ['flour',
#   'milk',
#   'cocoa',
#   'vegetable oil',
#   'baking powder',
#   'hot water',
#   'salt',
#   'sugar',
#   'vanilla',
#   'brown sugar'],
#  ['flour',
#   'milk',
#   'toasted almonds',
#   'salt',
#   'apple pie filling',
#   'powdered sugar',
#   'butter',
#   'egg'],
#  ['white bread', 'mayonnaise', 'bananas'],
#  ['dried thyme',
#   'breadcrumbs',
#   'flour',
#   'milk',
#   'vegetable oil',
#   'fresh ground black pepper',
#   'salt',
#   'dried oregano',
#   'onion',
#   'boneless skinless chicken thighs',
#   'garlic powder',
#   'dry white wine',
#   'lean ground beef',
#   'chicken stock',
#   'poultry seasoning'],
#  ['cream cheese', 'lemon juice', 'salt', 'onion', 'liquid smoke', 'salmon'],
#  ['green beans',
#   'sambal oelek',
#   'brown sugar',
#   'tomato',
#   'desiccated coconut',
#   'ground coriander',
#   'ginger',
#   'carrot',
#   'ground cumin',
#   'tempeh',
#   'onion',
#   'vegetable stock',
#   'water',
#   'garlic',
#   'peanut oil',
#   'bean sprouts',
#   'soy sauce',
#   'peanuts',
#   'ground cayenne pepper',
#   'red chili pepper'],
#  ['lemon juice',
#   'water',
#   'ground beef',
#   'salt and pepper',
#   'dried breadcrumbs',
#   'sugar',
#   'onion',
#   'tomato soup',
#   'egg'],
#  ['chunky salsa',
#   'salt and pepper',
#   'avocado',
#   'fresh cilantro',
#   'lime juice',
#   'hot sauce',
#   'soft silken tofu'],
#  ['cinnamon',
#   'shortening',
#   'flour',
#   'baking soda',
#   'white sugar',
#   'salt',
#   'walnuts',
#   'bananas',
#   'nutmeg',
#   'ground cloves',
#   'egg'],
#  ['tomato',
#   'boneless skinless chicken breast',
#   'salt and pepper',
#   'dried basil',
#   'olive oil',
#   'lime juice'],
#  ['fresh lemon juice',
#   'water',
#   'vegetable oil',
#   'mustard',
#   'ketchup',
#   'salt',
#   'onion',
#   'beef ribs',
#   'worcestershire sauce',
#   'brown sugar'],
#  ['green grape', 'egg whites', 'sugar'],
#  ['milk chocolate candy bars',
#   'water',
#   'vegetable oil',
#   'betty crocker fudge brownie mix',
#   'egg'],
#  ['nuts',
#   'baking soda',
#   'water',
#   'chocolate chips',
#   'flour',
#   'baking powder',
#   'salt',
#   'bananas',
#   'sugar',
#   'butter',
#   'egg'],
#  ['cream cheese',
#   'flour',
#   'chocolate chips',
#   'oreo cookie crumbs',
#   'vanilla',
#   'sweetened condensed milk',
#   'butter',
#   'egg',
#   'brown sugar',
#   'sour cream'],
#  ['2% low-fat milk',
#   'banana',
#   'natural-style peanut butter',
#   'sugar-free non-fat vanilla yogurt'],
#  ['cream cheese',
#   'taco seasoning',
#   'bean dip',
#   'cheddar cheese',
#   'sour cream'],
#  ['tomato',
#   'american cheese',
#   'no-salt-added ketchup',
#   "mccormick's montreal brand steak seasoning",
#   'onion',
#   'bacon',
#   'iceberg lettuce',
#   'dill weed',
#   'ground sirloin'],
#  ['chopped tomato',
#   'salt',
#   'cucumber',
#   'plain yogurt',
#   'paprika',
#   'chat masala',
#   'potato'],
#  ['cinnamon',
#   'buttermilk',
#   'baking soda',
#   'corn oil',
#   'natural bran',
#   'carrot',
#   'raisins',
#   'salt',
#   'whole wheat flour',
#   'vanilla',
#   'egg',
#   'brown sugar'],
#  ['grand marnier',
#   'tequila',
#   'triple sec',
#   'lime juice',
#   'limeade',
#   'lime wedge'],
#  ['flour', 'semi-sweet chocolate chips', 'pecans', 'butter', 'brown sugar'],
#  ['milk',
#   'ground beef',
#   'corn',
#   'chopped tomato',
#   'mushrooms',
#   'salt',
#   'garlic',
#   'cheddar cheese',
#   'cappelletti pasta',
#   'onion',
#   'tomato soup',
#   'black pepper',
#   'butter'],
#  ['tomato sauce',
#   'hot water',
#   'salt and pepper',
#   'garlic',
#   'dry white wine',
#   'spaghetti',
#   'extra virgin olive oil',
#   'parsley',
#   'squid'],
#  ['flour',
#   'baking soda',
#   'cocoa',
#   'water',
#   'vegetable oil',
#   'salt',
#   'sugar',
#   'vinegar',
#   'vanilla'],
#  ['applesauce', 'pork loin chops', 'brown sugar', 'clove'],
#  ['swiss cheese',
#   'roasted red peppers',
#   'whole wheat bread dough',
#   'mayonnaise',
#   'cream cheese',
#   'cheddar cheese',
#   'radish sprouts',
#   'honey mustard',
#   'turkey',
#   'prepared horseradish',
#   'butter',
#   'roast beef',
#   'ham',
#   'green olives',
#   'provolone cheese',
#   'leaf lettuce'],
#  ['flour',
#   'water',
#   'salt and pepper',
#   'fresh dill',
#   'wild mushrooms',
#   'onion',
#   'butter',
#   'sour cream',
#   'lemon, juice of',
#   'beef broth'],
#  ['honey',
#   'rice wine vinegar',
#   'green onions',
#   'carrot',
#   'bean sprouts',
#   'garlic',
#   'fresh cilantro',
#   'light soy sauce',
#   'english cucumber',
#   'asian chili sauce',
#   'sesame oil',
#   'rice noodles',
#   'fresh ginger'],
#  ['flour',
#   'unsweetened cocoa powder',
#   'brewed espresso',
#   'bittersweet chocolate',
#   'kosher salt',
#   'vanilla',
#   'unsalted butter',
#   'granulated sugar',
#   'egg'],
#  ['dr. pepper cola', 'orange marmalade', 'brown sugar'],
#  ['salt',
#   'scallions',
#   'peanut oil',
#   'fish',
#   'rice wine',
#   'white pepper',
#   'gingerroot',
#   'low sodium soy sauce',
#   'sesame oil'],
#  ['swiss cheese',
#   'romano cheese',
#   'flour',
#   'low sodium beef broth',
#   'garlic',
#   'sherry wine',
#   'sugar',
#   'olive oil',
#   'yellow onions',
#   'parmesan cheese',
#   'butter',
#   'french bread',
#   'beef broth'],
#  ['baking soda',
#   'water',
#   'chocolate chips',
#   'flour',
#   'white sugar',
#   'salt',
#   'whole wheat flour',
#   'vanilla',
#   'margarine',
#   'egg',
#   'brown sugar'],
#  ['onion',
#   'sage',
#   'cornbread',
#   'cream of chicken soup',
#   'squash',
#   'butter',
#   'egg'],
#  ['bottled garlic',
#   'bay leaves',
#   'dried parsley',
#   'white onion',
#   'salt',
#   'sugar',
#   'dried basil',
#   'olive oil',
#   'dried oregano',
#   'garlic powder',
#   'italian sausage',
#   'paprika',
#   'black pepper',
#   'tomato sauce'],
#  ['milk',
#   'soy sauce',
#   'frozen broccoli cuts',
#   'salt',
#   'garlic powder',
#   'sharp cheddar cheese',
#   'french-fried onions',
#   'cream of chicken soup',
#   'ground black pepper'],
#  ['flour',
#   'sugar',
#   'pure vanilla extract',
#   'whole milk',
#   'butter',
#   'egg',
#   'almond extract'],
#  ['oil',
#   'unsalted butter',
#   'fresh garlic',
#   'unseasoned breadcrumbs',
#   'egg',
#   'artichoke hearts'],
#  ['chili powder',
#   'barbecue sauce',
#   'hot red pepper sauce',
#   'cider vinegar',
#   'salt',
#   'chicken',
#   'worcestershire sauce',
#   'black pepper'],
#  ['cream cheese',
#   'frozen broccoli',
#   'cheddar cheese',
#   'ritz cracker crumbs',
#   'water chestnuts',
#   'dry onion soup mix',
#   'sour cream'],
#  ['flour',
#   'mayonnaise',
#   'baking soda',
#   'cocoa powder',
#   'water',
#   'milk',
#   'cool whip',
#   'salt',
#   'instant chocolate pudding mix',
#   'sugar',
#   'vanilla'],
#  ['chili powder',
#   'flour',
#   'water',
#   'lean chuck',
#   'garlic',
#   'budweiser beer',
#   'oregano leaves',
#   'sugar',
#   'onion',
#   'unsweetened cocoa',
#   'coriander',
#   'hunts tomato sauce',
#   'louisiana hot sauce',
#   'paprika',
#   'cumin',
#   'cornmeal',
#   'lean pork',
#   'bouillon'],
#  ['unsmoked bacon',
#   'red bell pepper',
#   'meatloaf mixture',
#   'goat cheese',
#   'kosher salt',
#   'yellow onion',
#   'olive oil',
#   'simply potatoes shredded hash browns',
#   'unsalted butter',
#   'fresh garlic',
#   'baby spinach',
#   'white pepper',
#   'egg'],
#  ['pumpkin puree',
#   'milk',
#   'egg white',
#   'salt',
#   'dark brown sugar',
#   'nutmeg',
#   'heavy cream',
#   'ground ginger',
#   'ground cloves',
#   'egg',
#   'pie crusts',
#   'ground cinnamon'],
#  ['breadcrumbs',
#   'flour',
#   'milk',
#   'vegetable oil',
#   'beef',
#   'baking powder',
#   'salt',
#   'onion',
#   'poppy seed',
#   'cream of chicken soup',
#   'paprika',
#   'celery seed',
#   'butter',
#   'sour cream',
#   'dry onion flakes',
#   'poultry seasoning'],
#  ['nuts',
#   'baking soda',
#   'flour',
#   'semi-sweet chocolate chips',
#   'blended oatmeal',
#   'baking powder',
#   'vanilla',
#   'sugar',
#   'butter',
#   'hershey chocolate candy bars',
#   'egg',
#   'brown sugar'],
#  ['nuts',
#   'flour',
#   'baking soda',
#   'chocolate chips',
#   'white sugar',
#   'baking powder',
#   'salt',
#   'vanilla',
#   'oatmeal',
#   "hershey's semi-sweet baking chocolate",
#   'butter',
#   'egg',
#   'brown sugar'],
#  ['flour', 'milk', 'vanilla', 'granulated sugar', 'butter'],
#  ['taco shells',
#   'lettuce',
#   'tomato',
#   'salsa',
#   'ground beef',
#   'taco seasoning',
#   'cheddar cheese',
#   'onion',
#   'corn cobs'],
#  ['cinnamon',
#   'white onion',
#   'stewing beef',
#   'light brown sugar',
#   'stewing pork',
#   'black pepper',
#   'tomato paste',
#   'chunky salsa',
#   'ground coriander',
#   'salt',
#   'dark chocolate chips',
#   'bell peppers',
#   'cumin',
#   'beef broth',
#   'chicken bouillon cube',
#   'garlic',
#   'sazon goya',
#   'habanero pepper',
#   'beans',
#   'tortilla chips',
#   'beef bouillon cube',
#   'mexican chili powder'],
#  ['shortening',
#   'tequila',
#   'baking soda',
#   'warm water',
#   'cream cheese',
#   'flour',
#   'triple sec',
#   'lime zest',
#   'pecans',
#   'salt',
#   'powdered sugar',
#   'orange-flavored liqueur',
#   'lemon zest',
#   'pitted dates',
#   'butter',
#   'egg',
#   'brown sugar'],
#  ['cream of celery soup',
#   'potato',
#   'water',
#   'milk',
#   'carrot',
#   'onion',
#   'cream of chicken soup',
#   'bouillon cubes',
#   'butter',
#   'celery',
#   'potato flakes'],
#  ['cinnamon',
#   'flour',
#   'milk',
#   'cream',
#   'salt',
#   'sugar',
#   'apples',
#   'butter',
#   'egg',
#   'lemon, juice of'],
#  ['milk',
#   'macaroni',
#   'salt',
#   'garlic',
#   'onion',
#   'cheese',
#   'butter',
#   'fresh coarse ground black pepper'],
#  ['macaroni',
#   'onion',
#   'unsalted butter',
#   'salt water',
#   'cheese',
#   'heavy cream',
#   'black pepper',
#   'muscat wine',
#   'fine semolina',
#   'potato'],
#  ['milk',
#   'salt and pepper',
#   'applesauce',
#   'onion',
#   'penne pasta',
#   'cheese',
#   'butter',
#   'potato'],
#  ['water', 'dried yellow peas', 'ginger', 'salt', 'pork'],
#  ['dried thyme',
#   'water',
#   'dried yellow peas',
#   'carrot',
#   'salt',
#   'brown mustard',
#   'ham bone',
#   'onion',
#   'ground ginger',
#   'black pepper',
#   'clove'],
#  ['nutmeg', 'fresh spinach', 'butter', 'water'],
#  ['chili powder',
#   'water',
#   'ground beef',
#   'cornstarch',
#   'dried onion flakes',
#   'salt',
#   'ground black pepper',
#   'garlic powder',
#   'white vinegar',
#   'wondra flour',
#   'ground pork',
#   'paprika',
#   'granulated sugar',
#   'tomato paste'],
#  ['granulated garlic',
#   'apple cider vinegar',
#   'ponzu sauce',
#   'salt',
#   'dark brown sugar',
#   'cayenne',
#   'applesauce',
#   'tomato ketchup',
#   'maple syrup',
#   'liquid smoke',
#   'oregano'],
#  ['flour',
#   'baking soda',
#   'baking powder',
#   'salt',
#   'sugar',
#   'vanilla',
#   'butter',
#   'sour cream',
#   'egg'],
#  ['frozen whipped topping', 'butter', 'vanilla ice cream', 'oreo cookies'],
#  ['butter', 'white bread', 'processed cheese'],
#  ['rosemary',
#   'soy sauce',
#   'fresh ground black pepper',
#   'garlic',
#   'london broil beef',
#   'olive oil',
#   'balsamic vinegar',
#   'worcestershire sauce'],
#  ['dried thyme',
#   'spicy brown mustard',
#   'nonfat dry milk powder',
#   'cornstarch',
#   'chicken broth',
#   'garlic',
#   'fresh mushrooms',
#   'hot pepper sauce',
#   'dry sherry',
#   'dried oregano',
#   'nonfat milk',
#   'teriyaki sauce',
#   'dried rosemary',
#   'salt and black pepper',
#   'margarine',
#   'parmesan cheese'],
#  ['cinnamon',
#   'cream cheese',
#   'vanilla',
#   'vanilla protein powder',
#   'nutmeg',
#   'almonds',
#   'splenda sugar substitute',
#   'butter',
#   'egg',
#   'sour cream'],
#  ['refrigerated buttermilk biscuits', 'butter', 'bacon', 'real maple syrup'],
#  ['mayonnaise',
#   'tabasco sauce',
#   'velveeta cheese',
#   'worcestershire sauce',
#   'horseradish'],
#  ['red wine vinegar', 'lemon juice', 'water'],
#  ['sugar-free syrup',
#   'water',
#   'old fashioned oats',
#   'ground flax seeds',
#   'berries',
#   "i can't believe it's not butter spread"],
#  ['nuts',
#   'cream cheese',
#   'flour',
#   'milk',
#   'blueberries',
#   'salt',
#   'frozen blueberries',
#   'vanilla',
#   'sugar',
#   'powdered sugar',
#   'maple syrup',
#   'egg',
#   'french bread'],
#  ['celery',
#   'velveeta cheese',
#   'chicken broth',
#   'salt',
#   'cheddar cheese',
#   'red potatoes',
#   'onion',
#   'bacon',
#   'white pepper',
#   'liquid smoke',
#   'sour cream',
#   'chives'],
#  ['cinnamon',
#   'cream cheese',
#   'flour',
#   'milk',
#   'warm water',
#   'active dry yeast',
#   'salt',
#   'powdered sugar',
#   'vanilla pudding mix',
#   'granulated sugar',
#   'butter',
#   'egg',
#   'brown sugar'],
#  ['reduced-fat parmesan cheese',
#   'spaghetti sauce',
#   'red bell pepper',
#   'part-skim mozzarella cheese',
#   'asparagus',
#   'salt and pepper',
#   'garlic',
#   'spaghetti squash',
#   'italian seasoning',
#   'white mushroom'],
#  ['lemon juice',
#   'water',
#   'cornstarch',
#   'oil',
#   'vanilla',
#   'vegan sugar',
#   'frozen pineapple concentrate',
#   'graham cracker crumbs',
#   'coriander',
#   'maple syrup',
#   'margarine',
#   'soft silken tofu',
#   'vegan cream cheese'],
#  ['green bell pepper',
#   'flour',
#   'andouille sausage',
#   'low sodium chicken broth',
#   'creole seasoning',
#   'vegetable oil',
#   'large raw shrimp',
#   'celery',
#   'garlic',
#   'onion',
#   'cooked chicken',
#   'frozen black-eyed peas'],
#  ['ground beef',
#   'salt and pepper',
#   'cheddar cheese',
#   'pickle',
#   'thousand island dressing',
#   'onion',
#   'cracker',
#   'egg'],
#  ['lemon juice',
#   'linguine',
#   'heavy whipping cream',
#   'basil',
#   'salt',
#   'garlic',
#   'parmesan-romano cheese mix',
#   'white pepper',
#   'parmesan cheese',
#   'cajun spices',
#   'parsley',
#   'butter',
#   'salmon'],
#  ['milk', 'phyllo dough', 'cottage cheese', 'oil', 'feta', 'egg'],
#  ['lettuce',
#   'soy sauce',
#   'imitation crabmeat',
#   'pickled ginger',
#   'cucumber',
#   'avocado',
#   'white rice',
#   'seasoned rice vinegar'],
#  ['flour',
#   'baking soda',
#   'maraschino cherry',
#   'walnuts',
#   'mincemeat',
#   'egg',
#   'sweetened condensed milk',
#   'mixed candied fruit'],
#  ['chicken stock',
#   'baking powder',
#   'white onion',
#   'kosher salt',
#   'oil',
#   'salt',
#   'chicken breasts',
#   'sugar',
#   'baby carrots',
#   'matzo meal',
#   'black pepper',
#   'egg',
#   'celery'],
#  ['cheddar cheese',
#   'poppy seed',
#   'frozen southern style hash brown potatoes',
#   'cream of mushroom soup',
#   'sour cream'],
#  ['ground coriander',
#   'ground sage',
#   'ketchup',
#   'fresh ground pepper',
#   'olive oil',
#   'red onion',
#   'adobo seasoning',
#   'sea salt',
#   'italian seasoned breadcrumbs',
#   'veggie shreds cheese',
#   'oregano',
#   'low sodium soy sauce',
#   'egg',
#   'fresh garlic cloves',
#   'lean ground beef'],
#  ['cream of celery soup',
#   'green bell pepper',
#   'celery',
#   'kraft macaroni and cheese',
#   'mushrooms',
#   'onion',
#   'butter',
#   'tuna'],
#  ['vegetable oil',
#   'ketchup',
#   'cider vinegar',
#   'salt',
#   'sugar',
#   'miracle whip',
#   'garlic',
#   'paprika',
#   'black pepper',
#   'tabasco sauce',
#   'dry mustard'],
#  ['red wine vinegar',
#   'tuna in vegetable oil',
#   'kosher salt & freshly ground black pepper',
#   'water-packed artichoke hearts',
#   'red bell pepper',
#   'shallot',
#   'pepperoncini peppers',
#   'seedless cucumber',
#   'italian parsley',
#   'red onion',
#   'red ripe tomatoes',
#   'oregano',
#   'kalamata olive',
#   'extra virgin olive oil',
#   'lemon, juice of'],
#  ['canola oil',
#   'buttermilk',
#   'orange roughy',
#   'self-rising flour',
#   'seasoning salt',
#   'ground black pepper',
#   'egg'],
#  ['flour',
#   'green onion',
#   'goat cheese',
#   'salt',
#   'garlic',
#   'bacon',
#   'frozen spinach',
#   'egg yolk',
#   'egg',
#   'simply potatoes traditional mashed potatoes'],
#  ['canola oil',
#   'flour',
#   'milk',
#   'salt and pepper',
#   'self-rising flour',
#   'seasoning salt',
#   'cajun seasoning',
#   'ground black pepper',
#   'egg',
#   'boneless pork chops'],
#  ['water',
#   'stir fry vegetables',
#   'imitation crabmeat',
#   'ramen noodles',
#   'teriyaki marinade'],
#  ['pumpkin puree',
#   'green bell pepper',
#   'ground red pepper',
#   'fresh cilantro leaves',
#   'vegetable broth',
#   'salt',
#   'pesto sauce',
#   'red onion',
#   'banana',
#   'smooth cashew butter',
#   'apple',
#   'pumpkin seeds',
#   'small red potato',
#   'celery'],
#  ['chili powder',
#   'water',
#   'mushrooms',
#   'vegetable bouillon cubes',
#   'garlic',
#   'nutmeg',
#   'margarine',
#   'dry-roasted cashews',
#   'parsley'],
#  ['oranges', 'vanilla bean', 'mangoes', 'strawberries', 'ice cubes'],
#  ['fresh rosemary',
#   'salt and pepper',
#   'vegetable broth',
#   'garlic',
#   'olive oil',
#   'russet potatoes',
#   'leeks',
#   'white beans'],
#  ['chili powder',
#   'chicken stock',
#   'turmeric',
#   'cardamom pods',
#   'cloves',
#   'black peppercorns',
#   'boneless skinless chicken breasts',
#   'cinnamon stick',
#   'ground cumin',
#   'garlic',
#   'coriander seed',
#   'salt & freshly ground black pepper',
#   'onion',
#   'soy yogurt',
#   'fresh coriander',
#   'fresh ginger'],
#  ['dried thyme',
#   'beef bouillon cubes',
#   'rump roast',
#   'salt',
#   'garlic',
#   'dried oregano',
#   'garlic powder',
#   'worcestershire sauce',
#   'black pepper',
#   'tabasco sauce',
#   'boiling water'],
#  ['water', 'honey', 'tea bag', 'milk', 'ginger'],
#  ['sausage', 'velveeta cheese', 'ground beef', 'taco chips'],
#  ['tomato sauce',
#   'ketchup',
#   'onion',
#   'steak seasoning',
#   'bell pepper',
#   'white vinegar',
#   'garlic powder',
#   'worcestershire sauce',
#   'hamburger buns',
#   'ground mustard',
#   'brown sugar',
#   'lean ground beef'],
#  ['safflower oil',
#   'honey',
#   'green onions',
#   'fresh corn kernels',
#   'green peppers',
#   'rice wine vinegar',
#   'soy sauce',
#   'salad greens',
#   'salt',
#   'garlic',
#   'carrot',
#   'beets',
#   'white mushrooms',
#   'gingerroot',
#   'black pepper',
#   'salad seasoning'],
#  ['fresh lemon juice',
#   'chicken broth',
#   'fennel seeds',
#   'onion',
#   'olive oil',
#   'dry white wine',
#   'paprika',
#   'pork chops'],
#  ['pepperoni',
#   'roma tomato',
#   'mozzarella cheese',
#   'red bell pepper',
#   'black olives',
#   'italian seasoning',
#   'ramen noodles',
#   'garlic powder',
#   'egg'],
#  ['molasses',
#   'baking soda',
#   'flour',
#   'milk',
#   'natural bran',
#   'raisins',
#   'baking powder',
#   'sunflower seeds',
#   'salt',
#   'oil',
#   'sesame seeds',
#   'egg',
#   'brown sugar'],
#  ['orange, juice of',
#   'low sodium soy sauce',
#   'peppercorn',
#   'garlic',
#   'broiler',
#   'dry sherry',
#   'onion',
#   'orange zest',
#   'black tea leaves',
#   'minced ginger',
#   'brown sugar'],
#  ['turmeric',
#   'fruit vinegar',
#   'cardamom pods',
#   'yoghurt',
#   'cloves',
#   'peanut oil',
#   'coriander seed',
#   'gingerroot',
#   'kaffir lime leaves',
#   'star anise',
#   'lemongrass'],
#  ['graham wafers',
#   'cool whip',
#   'vanilla pudding mix',
#   'blueberry pie filling'],
#  ['chili powder',
#   'onion powder',
#   'water',
#   'cornstarch',
#   'dried onion flakes',
#   'canned jalapeno slices',
#   'salt',
#   'cayenne pepper',
#   'vinegar',
#   'sugar',
#   'garlic powder',
#   'tomato paste'],
#  ['nuts',
#   'baking soda',
#   'quick-cooking oats',
#   'raisins',
#   'brown sugar',
#   'baking powder',
#   'salt',
#   'vanilla',
#   'cake flour',
#   'shredded coconut',
#   'butter',
#   'egg',
#   'corn flakes'],
#  ['kosher salt',
#   'italian spices',
#   'whole turkey',
#   'olive oil',
#   'onion',
#   'black pepper',
#   'butter'],
#  ['salsa',
#   'cheddar cheese',
#   'corn chips',
#   'onion',
#   'chili with beans',
#   'sour cream'],
#  ['plain breadcrumbs',
#   'cauliflower florets',
#   'vegetable oil',
#   'salt',
#   'parsley sprig',
#   'black pepper',
#   'egg'],
#  ['fresh green beans',
#   'kosher salt',
#   'walnuts',
#   'olive oil',
#   'onion',
#   'ground black pepper',
#   'butter',
#   'mixed herbs'],
#  ['american cheese',
#   'ketchup',
#   'sweet pickle relish',
#   'hamburger buns',
#   'ham'],
#  ['carrot', 'tomato soup', 'bacon', 'sugar'],
#  ['ground beef',
#   'seasoned bread crumbs',
#   'ketchup',
#   'lipton onion soup mix',
#   'egg',
#   'brown sugar'],
#  ['bulk pork sausage',
#   'velveeta cheese',
#   'ground pepper',
#   'ground chuck',
#   'garlic powder',
#   'worcestershire sauce',
#   'oregano',
#   'rye cocktail bread'],
#  ['milk',
#   'self-raising flour',
#   'caster sugar',
#   'butter',
#   'pineapple in syrup',
#   'glace cherries',
#   'vanilla essence',
#   'egg',
#   'brown sugar'],
#  ['coconut milk',
#   'greens',
#   'water',
#   'honey',
#   'banana',
#   'apple',
#   'oat bran',
#   'flax seed oil'],
#  ["hellmann's mayonnaise",
#   'knorr vegetable soup mix',
#   'water chestnuts',
#   'hawaiian bread',
#   'green onion',
#   'sour cream'],
#  ['broccoli floret',
#   'soy sauce',
#   'sliced mushrooms',
#   'carrot',
#   'brown rice',
#   'olive oil',
#   'peas',
#   'egg'],
#  ['reduced fat graham cracker crust',
#   'pumpkin',
#   'egg whites',
#   'pumpkin pie spice',
#   'splenda sugar substitute',
#   'skim milk'],
#  ['biscuits', 'beef stew'],
#  ['unbleached all-purpose flour',
#   'light corn syrup',
#   'buttermilk',
#   'baking soda',
#   'honey roasted peanuts',
#   'espresso',
#   'salt',
#   'unsweetened cocoa',
#   'sugar',
#   'powdered sugar',
#   'semisweet chocolate',
#   'unsalted butter',
#   'pure vanilla extract',
#   'creamy peanut butter',
#   'extra-large eggs',
#   'heavy cream'],
#  ['yellow cornmeal',
#   'cilantro',
#   'red bell pepper',
#   'lime zest',
#   'ground cumin',
#   'garlic',
#   'corn kernel',
#   'short-grain brown rice',
#   'olive oil',
#   'onion',
#   'fresh lime juice',
#   'chipotle chile in adobo'],
#  ['flour',
#   'water',
#   'whipped dessert topping mix',
#   'instant vanilla pudding',
#   'butter',
#   'egg'],
#  ['milk',
#   'white onions',
#   'mustard',
#   'salt',
#   'miracle whip',
#   'sugar',
#   'fresh ground pepper',
#   'dijon mustard',
#   'white pepper',
#   'hard-boiled eggs',
#   'celery',
#   'potato'],
#  ['chili powder',
#   'lemon juice',
#   'water',
#   'soy sauce',
#   'tea bag',
#   'cayenne pepper',
#   'white rice',
#   'dried basil',
#   'seasoning salt',
#   'garlic powder',
#   'black pepper',
#   'butter'],
#  ['milk',
#   'roasted red pepper',
#   'feta cheese',
#   'fresh ground pepper',
#   'onion',
#   'frozen spinach',
#   'oregano',
#   'kalamata olive',
#   'egg',
#   'bisquick'],
#  ['cinnamon',
#   'baking soda',
#   'water',
#   'flour',
#   'allspice',
#   'pumpkin',
#   'baking powder',
#   'pecans',
#   'salt',
#   'oil',
#   'sugar',
#   'nutmeg',
#   'ground cloves',
#   'egg'],
#  ['water',
#   'vegetable oil',
#   'long-grain rice',
#   'dry onion soup mix',
#   'black pepper',
#   'boneless pork chops'],
#  ['cinnamon',
#   'crushed tomatoes',
#   'rum',
#   'lime juice',
#   'red peppers',
#   'black pepper',
#   'brown sugar',
#   'allspice',
#   'ginger',
#   'cayenne',
#   'nutmeg',
#   'olive oil',
#   'onion',
#   'sage',
#   'onion flakes',
#   'clove',
#   'chili powder',
#   'thyme',
#   'garlic',
#   'habanero pepper',
#   'boneless skinless chicken breasts',
#   'jamaican jerk spice',
#   'chives'],
#  ['lime sorbet', 'strawberry', 'frozen limeade concentrate', 'mango', 'ice'],
#  ['non-fat vanilla frozen yogurt',
#   'strawberry',
#   'apple juice',
#   'banana',
#   'ice'],
#  ['fish sauce',
#   'fruit vinegar',
#   'yoghurt',
#   'garlic',
#   'coriander seed',
#   'red chile',
#   'cumin',
#   'hoisin sauce',
#   'sesame oil'],
#  ['flour',
#   'unsweetened chocolate',
#   'unsweetened cocoa powder',
#   'candy cane',
#   'salt',
#   'peppermint oreos',
#   'vanilla',
#   'sugar',
#   'peppermint extract',
#   'butter',
#   'egg'],
#  ['canola oil',
#   'mayonnaise',
#   'slivered almonds',
#   'cooked rice',
#   'pineapple tidbits',
#   'salt',
#   'cooked chicken breasts',
#   'white vinegar',
#   'mandarin oranges',
#   'orange juice',
#   'green grapes',
#   'celery'],
#  ['mayonnaise',
#   'frozen peas',
#   'mustard',
#   'cheddar cheese',
#   'sugar',
#   'onion',
#   'sweet pickle relish',
#   'seasoning salt',
#   'hard-boiled eggs',
#   'celery'],
#  ['dried thyme',
#   'buttermilk',
#   'flour',
#   'cayenne pepper',
#   'oil',
#   'hot pepper sauce',
#   'seasoning salt',
#   'chicken pieces',
#   'fresh garlic',
#   'dijon mustard',
#   'garlic powder',
#   'onion',
#   'paprika',
#   'parmesan cheese',
#   'black pepper',
#   'butter',
#   'dry breadcrumbs'],
#  ['cinnamon',
#   'habanero sauce',
#   'lemon juice',
#   'allspice',
#   'pork baby back ribs',
#   'ketchup',
#   'sugar',
#   'seasoning salt',
#   'fresh garlic',
#   'louisiana hot sauce',
#   'black pepper',
#   'hoisin sauce'],
#  ['rotini pasta',
#   'corn',
#   'spaghetti sauce',
#   'carrot',
#   'red bell pepper',
#   'salt',
#   'garlic',
#   'beef stock',
#   'onion',
#   'italian seasoning',
#   'peas',
#   'chicken leg',
#   'black pepper',
#   'celery'],
#  ['mexicorn whole kernel corn',
#   'pam cooking spray',
#   'stove top stuffing mix monterey style with mushroom and onion',
#   'salt and pepper',
#   'spinach dip',
#   'margarine',
#   'sour cream',
#   'aluminum foil'],
#  ['cooking onions', 'white vinegar', 'pickling spices'],
#  ['soy sauce',
#   'carrot',
#   'chicken broth',
#   'cooked pasta',
#   'peas',
#   'cooked chicken',
#   'egg'],
#  ['mixed fruit', 'cake crumbs', 'cool whip', 'cream cheese'],
#  ['flour',
#   'squash',
#   'cool whip',
#   'lemon flavoring',
#   'sugar',
#   'coconut flavoring',
#   'pie crust',
#   'butter',
#   'egg'],
#  ['dried onion flakes',
#   'dried parsley flakes',
#   'salt',
#   'ground veal',
#   'dijon mustard',
#   'garlic powder',
#   'ground cloves',
#   'black pepper',
#   'cream of mushroom soup',
#   'ground cinnamon'],
#  ['catfish nuggets',
#   'red wine vinegar',
#   'seafood',
#   'gumbo file',
#   'tomato soup',
#   'parsley',
#   'black pepper',
#   'chicken stock',
#   'red onions',
#   'olive oil',
#   'mexican-style stewed tomatoes with jalapeno peppers',
#   'small shrimp',
#   'lemon',
#   'brown rice',
#   'garlic',
#   'okra',
#   'oregano',
#   'old bay seasoning',
#   'tabasco sauce'],
#  ['mild cheddar cheese',
#   'bacon',
#   'white vinegar',
#   'fresh chives',
#   'paprika',
#   'egg',
#   'sour cream'],
#  ['sandwich buns',
#   'lemon juice',
#   'dried parsley',
#   'salt',
#   'garlic',
#   'dried basil',
#   'chicken breasts',
#   'olive oil',
#   'dried oregano',
#   'white vinegar',
#   'cracked black pepper',
#   'garlic salt'],
#  ['nuts',
#   'quick oats',
#   'cinnamon',
#   'flour',
#   'baking soda',
#   'cream',
#   'salt',
#   'vanilla',
#   'nutmeg',
#   'margarine',
#   'shredded coconut',
#   'egg',
#   'boiling water',
#   'brown sugar'],
#  ['marshmallows', 'butter', 'rice krispies'],
#  ['frozen limeade concentrate',
#   'orange juice',
#   'cream cheese',
#   'cool whip topping'],
#  ['chili powder',
#   'salad oil',
#   'lettuce',
#   'lemon juice',
#   'tomato',
#   'cheddar cheese',
#   'pitted ripe olives',
#   'corn chips',
#   'avocado',
#   'sugar',
#   'salt',
#   'garlic',
#   'green onion',
#   'tabasco sauce',
#   'tuna',
#   'sour cream'],
#  ['chickpeas',
#   'baking potatoes',
#   'ground cumin',
#   'salt & freshly ground black pepper',
#   'garlic',
#   'coriander',
#   'olive oil',
#   'tahini',
#   'low-fat yogurt',
#   'fresh coriander'],
#  ['buttermilk',
#   'mayonnaise',
#   'yellow cornmeal',
#   'vegetable oil',
#   'baking powder',
#   'salt',
#   'sugar',
#   'egg'],
#  ['soy sauce',
#   'carrot',
#   'rice vinegar',
#   'green cabbage',
#   'red cabbage',
#   'apple',
#   'maple syrup',
#   'gingerroot',
#   'green onion',
#   'sesame oil'],
#  ['canola oil',
#   'water',
#   'chicken soup powder',
#   'turmeric',
#   'long-grain rice',
#   'garlic powder',
#   'black pepper',
#   'orzo pasta'],
#  ['green bell pepper',
#   'ear of corn',
#   'cumin',
#   'chicken broth',
#   'salt and pepper',
#   'white onion',
#   'fresh cilantro',
#   'avocado',
#   'chicken breast',
#   'crushed tomatoes',
#   'jalapeno pepper',
#   'celery ribs',
#   'chipotle chiles in adobo'],
#  ['fiber one cereal',
#   'fat free mozzarella cheese',
#   'reduced-fat parmesan cheese',
#   'egg white',
#   'salt',
#   'dried basil',
#   'garlic powder',
#   'italian-style tomato sauce',
#   'black pepper',
#   'eggplant'],
#  ['ground beef', 'beef gravy', 'white rice', 'onion', 'egg'],
#  ['pinto beans',
#   'beans',
#   'black-eyed peas',
#   'water',
#   'great northern beans',
#   'navy beans',
#   'carrot',
#   'ham',
#   'salt',
#   'garlic',
#   'ham bone',
#   'onion',
#   'tomatoes and green chilies',
#   'ham soup base',
#   'celery ribs',
#   'black pepper'],
#  ['skinless chicken breast half',
#   'red bell pepper',
#   'feta cheese',
#   'cider vinegar',
#   'fresh dill',
#   'garlic',
#   'light mayonnaise'],
#  ['mozzarella cheese',
#   'spaghetti sauce',
#   'italian seasoning',
#   'garlic salt',
#   'cheese ravioli',
#   'lean ground beef'],
#  ['barbecue sauce',
#   'lemon juice',
#   'chicken pieces',
#   'worcestershire sauce',
#   'orange marmalade'],
#  ['onion powder',
#   'ground red pepper',
#   'turmeric',
#   'paprika',
#   'salt',
#   'coriander',
#   'garlic powder',
#   'ground black pepper'],
#  ['lettuce',
#   'cream cheese',
#   'mayonnaise',
#   'taco seasoning mix',
#   'tomato',
#   'black olives',
#   'green pepper',
#   'green onion',
#   'sour cream',
#   'mexican blend cheese'],
#  ['green bell peppers',
#   'green onions',
#   'minced clams',
#   'sharp cheddar cheese',
#   'worcestershire sauce',
#   'paprika',
#   'tabasco sauce'],
#  ['red bell pepper',
#   'olives',
#   'spaghetti squash',
#   'olive oil',
#   'red onion',
#   'shrimp',
#   'oregano',
#   'eggplants',
#   'yellow bell pepper'],
#  ['heavy cream', "confectioners' sugar", 'butter', 'semisweet chocolate'],
#  ['cherry pie filling',
#   'pecans',
#   'crushed pineapple',
#   'sweetened condensed milk',
#   'frozen whipped topping',
#   'small marshmallow'],
#  ['green onions',
#   'salt',
#   'cheddar cheese',
#   'oil',
#   'bacon',
#   'sour cream',
#   'potato'],
#  ['plain flour',
#   'canola oil',
#   'boneless eye of round beef steak',
#   'mozzarella cheese',
#   'salt',
#   'onion',
#   'parmesan cheese',
#   'black pepper',
#   'pizza sauce'],
#  ['flour',
#   'boneless country-style ribs',
#   'bacon grease',
#   'ground black pepper',
#   'soup mix',
#   'seasoning salt',
#   'oregano',
#   "campbell's golden mushroom soup"],
#  ['flour', 'milk', 'fruit', 'sugar', 'butter', 'egg'],
#  ['honey',
#   'sugar',
#   'baby carrots',
#   'cardamom',
#   'butter',
#   'apples',
#   'crescent roll dough',
#   'ground cinnamon'],
#  ['mozzarella cheese',
#   'refrigerated biscuits',
#   'olive oil',
#   'italian seasoning',
#   'garlic salt'],
#  ['flour', 'milk', 'water', 'active dry yeast', 'salt', 'sugar', 'butter'],
#  ['cream cheese',
#   'flour',
#   'whipping cream',
#   'salt',
#   'sugar',
#   'vanilla',
#   'lemon peel',
#   'egg yolk',
#   'butter',
#   'egg',
#   'egg yolks'],
#  ['little smokies sausages',
#   'chili sauce',
#   'country-style dijon mustard',
#   'honey'],
#  ['grenadine',
#   'bacardi dark rum',
#   'orgeat syrup',
#   'orange curacao',
#   'prepared sweet-and-sour mix',
#   'orange juice',
#   'pineapple juice',
#   "meyer's dark rum",
#   'white rum'],
#  ['water',
#   'sliced mushrooms',
#   'minute white rice',
#   'condensed chicken broth',
#   'dried thyme leaves',
#   'onion',
#   'pork chops',
#   'balsamic vinaigrette',
#   'red apples'],
#  ['chili powder',
#   'reduced-calorie mayonnaise',
#   'green bell peppers',
#   'fresh ground black pepper',
#   'red bell peppers',
#   'plain nonfat yogurt',
#   'onion',
#   'prepared mustard',
#   'orange juice',
#   'horseradish',
#   'tomato paste'],
#  ['nectarines',
#   'cold water',
#   'cool whip',
#   'strawberries',
#   'peach gelatin',
#   'strawberry gelatin',
#   'grapes',
#   'orange juice',
#   'lemon gelatin'],
#  ['flour',
#   'salt',
#   'ground marjoram',
#   'lean ground turkey',
#   'cayenne pepper',
#   'fat-free evaporated milk',
#   'garlic powder',
#   'dried sage',
#   'onion flakes',
#   'black pepper',
#   'skim milk',
#   'brown sugar',
#   'poultry seasoning'],
#  ['barbecue sauce',
#   'ground beef',
#   'red bell pepper',
#   'sweet onion',
#   'cooking spray',
#   'seasoning salt',
#   'garlic powder',
#   'french-fried onions',
#   'ground black pepper',
#   'egg'],
#  ['flour',
#   'bay leaf',
#   'water',
#   'cold water',
#   'carrot',
#   'green pepper',
#   'italian salad dressing',
#   'salt',
#   'garlic',
#   'crushed tomatoes',
#   'beef stew meat',
#   'onion',
#   'black pepper',
#   'beef bouillon granules',
#   'tomato sauce',
#   'potato',
#   'beef broth'],
#  ['water',
#   'carrot',
#   'garam masala',
#   'salt and pepper',
#   'garlic',
#   'onion',
#   'ghee',
#   'curry powder',
#   'tabasco sauce',
#   'kidney beans',
#   'potato'],
#  ['ice cube', 'ouzo', 'orange slice', 'orange juice'],
#  ['cream of celery soup',
#   'crabmeat',
#   'milk',
#   'salt',
#   'sherry wine',
#   'red pepper',
#   'half-and-half',
#   'black pepper',
#   'cream of mushroom soup',
#   'old bay seasoning'],
#  ['brown sugar',
#   'tomato paste',
#   'chicken broth',
#   'onion',
#   'dry sherry',
#   'unsalted butter',
#   'ground pork',
#   'skim milk',
#   'salt and pepper',
#   'egg whites',
#   'bacon',
#   'worcestershire sauce',
#   'yellow mustard',
#   'fresh parsley',
#   'flour',
#   'shallot',
#   'ketchup',
#   'sherry wine vinegar',
#   'panko breadcrumbs',
#   'ground turkey',
#   'ground sirloin',
#   'mixed mushrooms'],
#  ['rosemary',
#   'garlic',
#   'olive oil',
#   'new potatoes',
#   'lemon, zest of',
#   'lemon, juice of'],
#  ['chili powder',
#   'flour',
#   'black beans',
#   'salsa',
#   'green chili sauce',
#   'garlic',
#   'oil',
#   'onion',
#   'frozen corn',
#   'cumin',
#   'dry breadcrumbs'],
#  ['fresh spinach',
#   'mayonnaise',
#   'green onions',
#   'red bell pepper',
#   'cheese-filled tortellini',
#   'ripe olives',
#   'salt',
#   'fresh ground pepper',
#   'baby shrimp',
#   'sour cream',
#   'caesar salad dressing'],
#  ['tomato',
#   'salt and pepper',
#   'garlic',
#   'bell peppers',
#   'olive oil',
#   'onion',
#   'ground turkey',
#   'worcestershire sauce',
#   'cheese',
#   'fresh parsley',
#   'celery',
#   'spike seasoning'],
#  ['cinnamon',
#   'lemon juice',
#   'cream cheese',
#   'slivered almonds',
#   'heavy whipping cream',
#   'splenda granular',
#   'cornstarch',
#   'vanilla',
#   'graham cracker crumbs',
#   'nutmeg',
#   'butter',
#   'egg',
#   'sour cream'],
#  ['smooth peanut butter', 'soy sauce', 'ketchup', 'oil', 'chicken pieces'],
#  ['dried thyme',
#   'breadcrumbs',
#   'parsley',
#   'chicken broth',
#   'salt',
#   'onion',
#   'dried sage',
#   'celery seed',
#   'black pepper',
#   'butter'],
#  ['tomato',
#   'salt and pepper',
#   'garlic',
#   'olive oil',
#   'fresh basil',
#   'fresh oregano'],
#  ['coconut milk',
#   'kahlua',
#   'water',
#   'whipping cream',
#   'vegetable oil',
#   'cornstarch',
#   'coco lopez',
#   'instant chocolate pudding mix',
#   'bittersweet chocolate',
#   "devil's food cake mix",
#   'sugar',
#   'salt',
#   'shredded coconut',
#   'egg'],
#  ['old bay seasoning', 'plain tomato juice'],
#  ['cinnamon',
#   'bay leaf',
#   'ground allspice',
#   'carrot',
#   'shallot',
#   'ground nutmeg',
#   'canned unsweetened coconut milk',
#   'garlic',
#   'coriander',
#   'onion',
#   'banana',
#   'canned pumpkin',
#   'pumpkin seeds',
#   'butter',
#   'curry powder',
#   'chicken stock',
#   'sweetened condensed milk'],
#  ['whole wheat bread',
#   'tomato',
#   'mayonnaise',
#   'zucchini',
#   'salt',
#   'garlic',
#   'parmesan cheese',
#   'black pepper',
#   'ghee'],
#  ['cream cheese',
#   'diced tomatoes with green chilies',
#   'diced green chilies',
#   'sausage'],
#  ['black beans',
#   'chili beans with chipotle pepper',
#   'white onion',
#   'garlic',
#   'red pepper',
#   'chili seasoning mix',
#   'extra lean ground beef',
#   'diced tomatoes',
#   'tomato sauce',
#   'kidney beans',
#   'chilies',
#   'beef broth'],
#  ['cream cheese',
#   'baking soda',
#   'flour',
#   'carrot',
#   'baking powder',
#   'ground nutmeg',
#   'pecans',
#   'salt',
#   'sugar',
#   'vanilla',
#   'powdered sugar',
#   'pineapple chunk',
#   'butter',
#   'egg',
#   'ground cinnamon'],
#  ['flour', 'milk', 'dried beef', 'black pepper', 'butter'],
#  ['water',
#   'carrot',
#   'salt',
#   'onion',
#   'split peas',
#   'black pepper',
#   'potato',
#   'turnips'],
#  ['granulated garlic',
#   'buttermilk',
#   'lemon juice',
#   'roasted garlic and red pepper spice mix',
#   'salad dressing',
#   'ketchup',
#   'cherry tomatoes',
#   'sugar',
#   'romaine lettuce',
#   'red onion',
#   'corn tortilla strips',
#   'steak spice',
#   'cumin',
#   'hard-boiled eggs',
#   'curry powder',
#   'sour cream',
#   'cooked bacon'],
#  ['fresh thyme',
#   'tomato',
#   'mayonnaise',
#   'cayenne pepper',
#   'ground cumin',
#   'cheddar cheese',
#   'salt',
#   'papaya',
#   'onion',
#   'white pepper',
#   'bibb lettuce',
#   'hamburger buns',
#   'worcestershire sauce',
#   'lean ground beef'],
#  ['cinnamon',
#   'flour',
#   'baking soda',
#   'zucchini',
#   'salt',
#   'fat',
#   'sugar',
#   'vanilla',
#   'walnuts',
#   'egg'],
#  ['lemon',
#   'lime',
#   'lemon juice',
#   'lemonade',
#   'peach puree',
#   'peach schnapps',
#   'apple',
#   'dry white wine',
#   'lime juice',
#   'peach',
#   'lemon-flavored vodka'],
#  ['barbecue sauce',
#   'salt and pepper',
#   'ketchup',
#   'onion',
#   'prepared mustard',
#   'hot sauce',
#   'ground moose',
#   'brown sugar'],
#  ['pineapple chunks',
#   'soy sauce',
#   'cornstarch',
#   'ketchup',
#   'salt',
#   'garlic',
#   'onion',
#   'white vinegar',
#   'sweet pepper',
#   'black pepper',
#   'egg',
#   'dry breadcrumbs',
#   'brown sugar',
#   'lean ground beef'],
#  ['chicken wings', 'soy sauce', 'dark brown sugar'],
# ...
#  ['water',
#   'vegetable oil',
#   'whole wheat flour',
#   'salt',
#   'white whole wheat flour',
#   'sugar',
#   'wheat germ',
#   'vital wheat gluten',
#   'oat bran',
#   'egg',
#   'yeast'],
#  ['warm water',
#   'whole wheat flour',
#   'kosher salt',
#   'vital wheat gluten',
#   'yeast'],
#  ['water', 'honey', 'whole wheat flour', 'salt', 'applesauce', 'egg', 'yeast'],
#  ['canola oil',
#   'water',
#   'honey',
#   'whole wheat flour',
#   'salt',
#   'vital wheat gluten',
#   'instant yeast',
#   'egg'],
#  ['canola oil',
#   'baking soda',
#   'baking powder',
#   'whole wheat flour',
#   'salt',
#   'low-fat buttermilk',
#   'egg whites',
#   'flax seed meal',
#   'granulated sugar'],
#  ['cinnamon',
#   'baking soda',
#   'water',
#   'honey',
#   'baking powder',
#   'salt',
#   'whole wheat flour',
#   'vanilla',
#   'butter',
#   'turbinado sugar'],
#  ['molasses',
#   'baking soda',
#   'raisins',
#   'baking powder',
#   'whole wheat flour',
#   'salt',
#   'low-fat buttermilk',
#   'butter',
#   'egg'],
#  ['canola oil',
#   'low-fat milk',
#   'baking soda',
#   'fruit',
#   'baking powder',
#   'whole wheat flour',
#   'sugar',
#   'vanilla',
#   'egg'],
#  ['peanut butter',
#   'milk',
#   'baking powder',
#   'whole wheat flour',
#   'salt',
#   'butter',
#   'egg',
#   'brown sugar'],
#  ['water', 'honey', 'whole wheat flour', 'salt', 'olive oil', 'instant yeast'],
#  ['water', 'honey', 'whole wheat flour', 'salt', 'olive oil', 'egg', 'yeast'],
#  ['baking soda',
#   'milk',
#   'baking powder',
#   'whole wheat flour',
#   'kosher salt',
#   'gluten',
#   'butter',
#   'sour cream'],
#  ['cinnamon',
#   'molasses',
#   'water',
#   'cocoa powder',
#   'raisins',
#   'baking powder',
#   'fruit',
#   'whole wheat flour',
#   'salt',
#   'oil',
#   'sugar',
#   'vanilla',
#   'powdered eggs',
#   'oatmeal',
#   'powdered milk',
#   'egg'],
#  ['nuts',
#   'cinnamon',
#   'baking soda',
#   'zucchini',
#   'vegetable oil',
#   'baking powder',
#   'whole wheat flour',
#   'salt',
#   'vanilla',
#   'sugar',
#   'egg'],
#  ['water',
#   'honey',
#   'whole wheat flour',
#   'cooking oil',
#   'instant yeast',
#   'table salt'],
#  ['baking soda',
#   'flour',
#   'bananas',
#   'sugar',
#   'vanilla',
#   'butter',
#   'nuts',
#   'egg'],
#  ['chocolate cake mix',
#   'chocolate chips',
#   'caramels',
#   'evaporated milk',
#   'butter',
#   'nuts'],
#  ['canola oil',
#   'flour',
#   'baking soda',
#   'raisins',
#   'salt',
#   'walnuts',
#   'sugar',
#   'bananas',
#   'egg'],
#  ['thousand island dressing', 'cream cheese'],
#  ['sweet pickle relish', 'onion powder', 'mayonnaise', 'chili sauce'],
#  ['rolled oats',
#   'baking soda',
#   'flour',
#   'chocolate chips',
#   'white sugar',
#   'oil',
#   'vanilla',
#   'cream of tartar',
#   'rice krispies',
#   'margarine',
#   'egg',
#   'flaked coconut',
#   'brown sugar'],
#  ['fresh lemon juice',
#   'buttermilk',
#   'mushrooms',
#   'garlic',
#   'sugar',
#   'unsalted sunflower seeds',
#   'plain yogurt',
#   'bacon',
#   'baby spinach',
#   'white pepper',
#   'hardboiled egg'],
#  ['lettuce',
#   'mayonnaise',
#   'fresh broccoli',
#   'frozen peas',
#   'green pepper',
#   'cauliflower',
#   'cherry tomatoes',
#   'sugar',
#   'fresh mushrooms',
#   'red onion',
#   'italian seasoning',
#   'bacon'],
#  ['chili powder',
#   'celery salt',
#   'ground oregano',
#   'ground allspice',
#   'rubbed sage',
#   'basil leaves',
#   'onion salt',
#   'garlic powder',
#   'paprika',
#   'black pepper',
#   'marjoram leaves'],
#  ['beer', 'ice', 'vodka', 'fresh jalapeno'],
#  ['miracle whip light',
#   'lemon juice',
#   'oil',
#   'garlic',
#   'anchovy fillets',
#   'fresh mushrooms',
#   'olive oil',
#   'dijon mustard',
#   'bacon',
#   'baby spinach',
#   'worcestershire sauce',
#   'parmesan cheese',
#   'extra virgin olive oil',
#   'low-fat mayonnaise',
#   'french bread'],
#  ['italian cheese blend',
#   'mozzarella cheese',
#   'ground beef',
#   'dried italian seasoning',
#   'spaghetti sauce',
#   'jumbo pasta shells',
#   'salt',
#   'ground pepper',
#   'parmesan-romano cheese mix',
#   'parsley flakes',
#   'ricotta cheese',
#   'egg',
#   'mexican blend cheese'],
#  ['water',
#   'white flour',
#   'whole wheat flour',
#   'oil',
#   'salt',
#   'bread machine yeast',
#   'brown sugar'],
#  ['water',
#   'salt and pepper',
#   'onion',
#   'cream-style corn',
#   'evaporated milk',
#   'whole corn',
#   'butter',
#   'potato'],
#  ['prosciutto',
#   'kosher salt',
#   'orecchiette',
#   'italian seasoned breadcrumbs',
#   'parmesan cheese',
#   'black pepper',
#   'extra virgin olive oil',
#   'flat leaf parsley'],
#  ['tomato', 'fresh ground black pepper', 'salt', 'olive oil', 'cumin seeds'],
#  ['molasses',
#   'baking soda',
#   'corn syrup',
#   'white sugar',
#   'vanilla',
#   'salted peanuts',
#   'butter'],
#  ['cinnamon',
#   'bulgar wheat',
#   'salt',
#   'plain yogurt',
#   'onion',
#   'lean ground beef'],
#  ['water',
#   'oil',
#   'instant vanilla pudding',
#   'apple pie filling',
#   'yellow cake mix',
#   'egg'],
#  ['boneless skinless chicken breasts', 'italian dressing', 'potato', 'carrot'],
#  ['chocolate milk', 'egg', 'cinnamon rolls'],
#  ['flour',
#   'milk',
#   'white sugar',
#   'baking powder',
#   'salt',
#   'vanilla',
#   'butter',
#   'egg'],
#  ['water',
#   'carrot',
#   'thyme',
#   'basil',
#   'ham',
#   'salt',
#   'garlic',
#   'soup mix',
#   'worcestershire sauce',
#   'black pepper',
#   'celery',
#   'leeks'],
#  ['milk',
#   'ground beef',
#   'chili sauce',
#   'salt and pepper',
#   'bell peppers',
#   'onion',
#   'garlic powder',
#   'worcestershire sauce',
#   'saltine crackers',
#   'egg'],
#  ['salt and pepper',
#   'garlic',
#   'prepared horseradish',
#   'unsalted butter',
#   'beef tenderloin',
#   'limes, juice of',
#   'sour cream',
#   'worcestershire sauce',
#   'aluminum foil'],
#  ['cinnamon',
#   'cream cheese',
#   'flour',
#   'baking soda',
#   'carrot',
#   'baking powder',
#   'salt',
#   'oil',
#   'walnuts',
#   'sugar',
#   'powdered sugar',
#   'pineapple',
#   'egg',
#   'margarine'],
#  ['water',
#   'turmeric',
#   'carrot',
#   'salt',
#   'cabbage',
#   'sugar',
#   'mustard seeds',
#   'onion',
#   'white vinegar',
#   'celery seed'],
#  ['alum',
#   'water',
#   'salt',
#   'pickling spices',
#   'vinegar',
#   'pickling cucumbers',
#   'sugar'],
#  ['cucumbers', 'alum', 'pickling spices', 'sugar', 'vinegar', 'canning salt'],
#  ['nuts',
#   'cinnamon',
#   'cream cheese',
#   'flour',
#   'baking soda',
#   'allspice',
#   'coconut',
#   'raisins',
#   'carrot',
#   'salt',
#   'oil',
#   'sugar',
#   'vanilla',
#   'powdered sugar',
#   'ground cloves',
#   'egg',
#   'margarine'],
#  ['cream', 'lemon extract', 'maple syrup', 'nutmeats', 'butter'],
#  ['beans',
#   'lemon juice',
#   'water',
#   'raw rice',
#   'tomato',
#   'carrot',
#   'chicken broth',
#   'basil',
#   'deli ham',
#   'salt',
#   'v8 vegetable juice',
#   'onion',
#   'parsley',
#   'chicken bouillon cubes',
#   'celery'],
#  ['refried beans',
#   'monterey jack cheese',
#   'tortillas',
#   'hormel chili without beans'],
#  ['ham hocks',
#   'dried parsley',
#   'salt',
#   'garlic',
#   'onion',
#   'olive oil',
#   'whole tomatoes',
#   'dried rosemary',
#   'celery leaves',
#   'black pepper',
#   'chicken bouillon cubes',
#   '15 bean soup mix'],
#  ['water',
#   'beef bouillon paste',
#   'garlic',
#   'ham bone',
#   'black pepper',
#   'worcestershire sauce',
#   'diced tomatoes',
#   'smoked sausage',
#   '15 bean soup mix',
#   'steak sauce'],
#  ['chili powder',
#   'lemon',
#   'water',
#   'dried beans',
#   'carrot',
#   'thyme',
#   'ham',
#   'oregano',
#   'cayenne pepper',
#   'salt',
#   'garlic',
#   'onion',
#   'olive oil',
#   'smoked paprika',
#   'condensed tomato soup',
#   'paprika',
#   'black pepper'],
#  ['ground walnuts',
#   'baking soda',
#   'flour',
#   'honey',
#   'sugar',
#   'plain sweet biscuit crumbs',
#   'liquid honey',
#   'margarine',
#   'egg',
#   'sour cream'],
#  ['lemon juice',
#   'capers',
#   'salt and pepper',
#   'garlic',
#   'fresh chives',
#   'halibut steaks',
#   'fresh tarragon',
#   'chicken stock',
#   'fresh parsley'],
#  ['water',
#   'oil',
#   'peas and carrots',
#   'new potatoes',
#   'boneless sirloin steak',
#   'lipton beefy mushroom soup mix',
#   'tomato paste'],
#  ['frozen corn kernels',
#   'black beans',
#   'ground beef',
#   'taco seasoning',
#   'tomatoes and green chilies'],
#  ['water',
#   'minute white rice',
#   'mustard',
#   'cheddar cheese',
#   'ketchup',
#   'lean ground beef'],
#  ['water',
#   'ground beef',
#   'velveeta cheese',
#   'white rice',
#   'chili with beans',
#   'diced tomatoes'],
#  ['boneless skinless chicken breast halves',
#   'water',
#   'vegetable oil',
#   'condensed cream of chicken soup',
#   'paprika',
#   'ground pepper',
#   'instant rice'],
#  ['lime',
#   'chicken breast tenders',
#   'fajita seasoning mix',
#   'onion',
#   'olive oil',
#   'pico de gallo',
#   'cheese',
#   'black pepper',
#   'sour cream',
#   'tortilla'],
#  ['salsa',
#   'chicken broth',
#   'cheddar cheese',
#   'tortilla chips',
#   'mexicorn',
#   'chicken',
#   'sour cream',
#   'kidney beans'],
#  ['milk',
#   'vegetable oil',
#   'condensed cream of chicken soup',
#   'minute rice',
#   'boneless skinless chicken breasts',
#   'broccoli florets'],
#  ['pinto beans',
#   'chili powder',
#   'salsa',
#   'salt',
#   'stewed tomatoes',
#   'onion',
#   'ground turkey',
#   'cumin',
#   'kidney beans'],
#  ['water',
#   'white minute rice',
#   'flour tortillas',
#   'cheese',
#   'chili with beans',
#   'sour cream'],
#  ['chili powder',
#   'water',
#   'ketchup',
#   'macaroni & cheese dinner mix',
#   'broccoli',
#   'lean ground beef'],
#  ['cinnamon',
#   'tomato',
#   'allspice',
#   'salt',
#   'onion',
#   'black pepper',
#   'brown sugar',
#   'clove'],
#  ['pappardelle pasta',
#   'fresh parmesan cheese',
#   'crushed red pepper flakes',
#   'grape tomatoes',
#   'garlic',
#   'sun-dried tomato packed in oil',
#   'fresh basil',
#   'roasted cashews',
#   'fresh oregano',
#   'black pepper'],
#  ['low sodium chicken broth',
#   'ground coriander',
#   'salt',
#   'ground cumin',
#   'garlic',
#   'onion',
#   'chipotle chile in adobo',
#   'tomato sauce'],
#  ['fat-free whipped topping',
#   'reduced fat graham cracker crust',
#   'fat free cream cheese',
#   'sugar substitute'],
#  ['tomato',
#   'fresh spinach',
#   'lemon juice',
#   'pesto sauce',
#   'red onion',
#   'parmesan cheese',
#   'fresh linguine',
#   'pine nuts'],
#  ['boneless skinless chicken breast halves',
#   'lemon juice',
#   'flour',
#   'chicken broth',
#   'salt and pepper',
#   'oil',
#   'garlic',
#   'butter'],
#  ['fresh lemon juice',
#   'tomato',
#   'garbanzo beans',
#   'feta cheese',
#   'salt',
#   'garlic',
#   'cracked black pepper',
#   'extra virgin olive oil',
#   'of fresh mint',
#   'celery ribs',
#   'fresh parsley',
#   'scallion',
#   'romaine lettuce'],
#  ['boneless skinless chicken breast',
#   'oil',
#   'assorted fresh vegetables',
#   'instant rice',
#   'reduced-sodium fat-free chicken broth',
#   'italian dressing'],
#  ['cream cheese',
#   'milk',
#   'instant lemon pudding',
#   'powdered sugar',
#   'graham cracker crumbs',
#   'butter'],
#  ["confectioners' sugar", 'peanut butter', 'cocoa', 'vanilla', 'butter'],
#  ['tomato',
#   'italian salad dressing',
#   'spaghetti',
#   'parmesan cheese',
#   'smoked turkey breast'],
#  ['water',
#   'soy sauce',
#   'chicken bouillon cube',
#   'oil',
#   'minute rice',
#   'pork tenderloin',
#   'frozen mixed vegetables'],
#  ['water',
#   'green pepper',
#   'minute white rice',
#   'oil',
#   'onion',
#   'hot pepper sauce',
#   'chicken bouillon cubes',
#   'kidney beans'],
#  ['baby peas',
#   'bacon bits',
#   'half-and-half cream',
#   'shrimp',
#   'parmesan cheese',
#   'garlic salt',
#   'black pepper',
#   'fettuccine'],
#  ['salt & pepper',
#   'garlic',
#   'onion',
#   'angel hair pasta',
#   'frozen shrimp',
#   'white wine',
#   'butter',
#   'extra virgin olive oil'],
#  ['jalapenos',
#   'tomato sauce & mushrooms',
#   'sweet green pepper',
#   'sliced mushrooms',
#   'hamburger',
#   'sweet red pepper',
#   'onion',
#   'hot chili flakes',
#   'garlic flakes',
#   'celery'],
#  ['chili flakes',
#   'soy sauce',
#   'chicken broth',
#   'boneless skinless chicken breast',
#   'asparagus',
#   'salt',
#   'garlic',
#   'rice vinegar',
#   'onion',
#   'white pepper',
#   'fresh ginger'],
#  ['extra-sharp cheddar cheese',
#   'elbow macaroni',
#   'fresh ground black pepper',
#   'kosher salt',
#   'unsalted butter',
#   'dijon mustard',
#   'hot sauce',
#   'half-and-half'],
#  ['flour',
#   'water',
#   'fresh mushrooms',
#   'dry onion soup mix',
#   'round steak',
#   'butter',
#   'sour cream'],
#  ['lettuce',
#   'taco seasoning mix',
#   'water',
#   'minute white rice',
#   'chopped tomatoes',
#   'extra lean ground beef',
#   'mexican blend cheese'],
#  ['tiger shrimp',
#   'pak choi',
#   'cornflour',
#   'dark soy sauce',
#   'sunflower oil',
#   'water',
#   'sweet chili sauce',
#   'baby spinach',
#   'lime, juice and zest of',
#   'thai fish sauce'],
#  ['vanilla instant pudding mix', 'milk', 'minute rice', 'raisins'],
#  ['black beans', 'salsa', 'fire-roasted tomatoes', 'water', 'kidney beans'],
#  ['cream cheese', 'milk', 'fettuccine pasta', 'margarine', 'parmesan cheese'],
#  ['quick oats',
#   'water',
#   'honey',
#   'milk',
#   'salt',
#   'dried fruits',
#   'sugar',
#   'vanilla'],
#  ['water',
#   'bay leaves',
#   'diced tomatoes',
#   'ham hocks',
#   'carrot',
#   'garlic',
#   'onion',
#   'seasoning salt',
#   '15 bean mix',
#   'black pepper',
#   'chicken bouillon cubes',
#   'tomato sauce',
#   'celery'],
#  ['green bell pepper',
#   'water',
#   'ground beef',
#   'black-eyed peas',
#   'vegetable oil',
#   'canned green beans',
#   'red pepper flakes',
#   'salt and pepper',
#   'ketchup',
#   'corn chips',
#   'onion',
#   'whole tomatoes',
#   'sharp cheddar cheese',
#   'dark red kidney beans',
#   'chili seasoning mix'],
#  ['marjoram',
#   'thyme',
#   'brandy',
#   'salt',
#   'garlic',
#   'chicken liver',
#   'onion',
#   'heavy cream',
#   'sage',
#   'ground black pepper',
#   'butter'],
#  ['chili powder',
#   'sliced mushrooms',
#   'salt',
#   'cayenne pepper',
#   'onion',
#   'chili beans',
#   'oregano',
#   'cumin',
#   'diced tomatoes',
#   'sour cream',
#   'lean ground beef'],
#  ['cool whip topping',
#   'strawberry',
#   'white chocolate baking squares',
#   'sugar',
#   'frozen pound cake',
#   'strawberries',
#   'orange liqueur',
#   'jello instant vanilla pudding mix'],
#  ['fresh lemon juice',
#   'boneless skinless chicken breast halves',
#   'dried tarragon',
#   'dijon mustard',
#   'worcestershire sauce',
#   'black pepper'],
#  ['basmati rice', 'chicken broth', 'salt and pepper'],
#  ['lettuce',
#   'tomato',
#   'salsa',
#   'black olives',
#   'monterey jack cheese',
#   'green enchilada sauce',
#   'tortilla chips',
#   'cream of chicken soup',
#   'green onion',
#   'cooked chicken',
#   'sour cream'],
#  ['parmesan cheese', 'butter', 'garlic', 'pasta'],
#  ['tomato',
#   'parsley',
#   'feta cheese',
#   'garlic',
#   'dried oregano',
#   'olive oil',
#   'old bay seasoning',
#   'black pepper',
#   'large shrimp'],
#  ['zucchini',
#   'corn kernels',
#   'cherry tomatoes',
#   'salt & freshly ground black pepper',
#   'olive oil',
#   'red onion',
#   'unsalted butter',
#   'herbs',
#   'lemon, zest of',
#   'snap peas',
#   'large shrimp'],
#  ['fresh lemon juice',
#   'salt and pepper',
#   'vegetable broth',
#   'scallions',
#   'garlic',
#   'olive oil',
#   'dried oregano',
#   'parmesan cheese',
#   'white beans'],
#  ['beans',
#   'tomato',
#   'water',
#   'bay leaves',
#   'carrot',
#   'garlic',
#   'onion',
#   'italian sausage',
#   'oregano',
#   'chicken stock',
#   'celery'],
#  ['cucumbers',
#   'alum',
#   'pickling salt',
#   'cinnamon sticks',
#   'pickling spices',
#   'sugar',
#   'white vinegar'],
#  ['pork butt', 'onion', 'barbecue sauce', 'ginger ale'],
#  ['dark molasses',
#   'cold water',
#   'vanilla bean',
#   'strong coffee',
#   'sugar',
#   'vodka',
#   'brown sugar'],
#  ['frozen white corn',
#   'carrot',
#   'chicken broth',
#   'whole chickens',
#   'onion',
#   'frozen corn',
#   'celery ribs',
#   'chicken bouillon cubes',
#   'celery',
#   'potato'],
#  ['fennel seed',
#   'nonstick cooking spray',
#   'low-carb marinara sauce',
#   'basil',
#   'lean ground turkey',
#   'oregano leaves',
#   'fat-free parmesan cheese',
#   'eggplant'],
#  ['raspberry vodka', 'mountain dew soda'],
#  ['fresh thyme',
#   'red wine vinegar',
#   'salt and pepper',
#   'apple cider',
#   'sherry wine vinegar',
#   'olive oil',
#   'red onion',
#   'shallots',
#   'white vinegar',
#   'dijon mustard',
#   'arugula',
#   'tart apples',
#   'gouda cheese',
#   'white cheddar cheese',
#   'pancetta'],
#  ["confectioners' sugar",
#   'baking soda',
#   'flour',
#   'vegetable oil',
#   'baking powder',
#   'salt',
#   'marshmallow cream',
#   'light brown sugar',
#   'unsalted butter',
#   'pure vanilla extract',
#   'baby carrots',
#   'pumpkin pie spice',
#   'egg'],
#  ['cinnamon',
#   'buttermilk',
#   'flour',
#   'baking soda',
#   'cocoa',
#   'salt',
#   'sugar',
#   'vanilla',
#   'nutmeg',
#   'butter',
#   'egg',
#   'clove'],
#  ['sweet cream',
#   'flour',
#   'milk',
#   'cornstarch',
#   'sugar',
#   'powdered sugar',
#   'cream of tartar',
#   'almonds',
#   'egg',
#   'egg yolks'],
#  ...]

# %% [markdown]
# We'll use the [`Word2Vec`](https://radimrehurek.com/gensim/models/word2vec.html) implementation in the `gensim` library (i.e., *deep learning*) to train an embedding model.
# This approach tends to work best if the training data has at least 100K rows.
#
# Let's also show how to serialize the *word2vec* results, saving them to the `tmp.w2v` file so they could be restored later for other use cases.
#
# NB: there is work in progress which will replace `gensim` with `pytorch` instead.

# %%
import gensim

MIN_COUNT = 2
model_path = "tmp.w2v"

model = gensim.models.Word2Vec(vectors, min_count=MIN_COUNT, window=max_context)
model.save(model_path)

# %% [markdown]
# The `get_related()` function takes any ingredient as input, using the embedding model to find the most similar other ingredients – along with calculating [`levenshtein`](https://github.com/toastdriven/pylev) edit distances (string similarity) among these labels. Then it calculates *percentiles* for both metrics in [`numpy`](https://numpy.org/) and returns the results as a [`pandas`](https://pandas.pydata.org/) DataFrame.

# %%
import numpy as np
import pandas as pd
import pylev

def get_related (model, query, n=20, granularity=100):
    """return a DataFrame of the closely related items"""
    try:
        bins = np.linspace(0, 1, num=granularity, endpoint=True)

        v = sorted(
            model.wv.most_similar(positive=[query], topn=n), 
            key=lambda x: x[1], 
            reverse=True
        )
        
        df = pd.DataFrame(v, columns=["ingredient", "similarity"])
        
        s = df["similarity"]
        quantiles = s.quantile(bins, interpolation="nearest")
        df["sim_pct"] = np.digitize(s, quantiles) - 1
        
        df["levenshtein"] = [ pylev.levenshtein(d, query) / len(query) for d in df["ingredient"] ]
        s = df["levenshtein"]
        quantiles = s.quantile(bins, interpolation="nearest")
        df["lev_pct"] = granularity - np.digitize(s, quantiles)

        return df
    except KeyError:
        return pd.DataFrame(columns=["ingredient", "similarity", "percentile"])

# %% [markdown]
# Let's try this with `dried basil` as the ingredient to query, and review the top `50` most similar other ingredients returned as the DataFrame `df`:

# %%
df = get_related(model, "dried basil", n=50)

pd.set_option("max_rows", None)
df
# Out:
#                       ingredient  similarity  sim_pct  levenshtein  lev_pct
# 0             dried basil leaves    0.666573       99     0.636364       76
# 1                      dry basil    0.619557       97     0.272727       98
# 2                    fresh basil    0.615189       95     0.363636       92
# 3        dried italian seasoning    0.611792       93     1.272727       28
# 4                 dried rosemary    0.607231       91     0.636364       76
# 5       dried sweet basil leaves    0.577864       89     1.181818       36
# 6         italian herb seasoning    0.570702       87     1.454545       16
# 7                  dried parsley    0.565170       85     0.454545       88
# 8                 dried marjoram    0.561841       83     0.636364       76
# 9              italian seasoning    0.559847       81     1.090909       44
# 10         dried rosemary leaves    0.557721       79     1.181818       36
# 11                         basil    0.533492       77     0.545455       86
# 12                 parmesan rind    0.518059       75     0.909091       68
# 13            hunts tomato paste    0.509193       73     1.363636       24
# 14             dried whole thyme    0.504048       71     1.000000       58
# 15          dried parsley flakes    0.494847       69     1.000000       58
# 16        feta cheese with herbs    0.478575       67     1.818182        4
# 17                italian spices    0.477972       65     1.090909       44
# 18  dried italian herb seasoning    0.471290       63     1.636364        8
# 19            dried thyme leaves    0.470149       61     1.000000       58
# 20       dried red pepper flakes    0.468225       59     1.454545       16
# 21                   sweet basil    0.466180       57     0.363636       92
# 22              fresh basil leaf    0.462858       55     0.818182       72
# 23            fresh basil leaves    0.462330       53     1.000000       58
# 24        italian turkey sausage    0.459434       51     1.545455       12
# 25                   dried thyme    0.450766       49     0.454545       88
# 26         italian seasoning mix    0.449365       47     1.454545       16
# 27              italian sausages    0.446250       45     1.090909       44
# 28                  chianti wine    0.445253       43     0.909091       68
# 29        t-bone type lamb chops    0.445107       41     1.727273        6
# 30   part-skim mozzarella cheese    0.444935       39     2.090909        0
# 31          small macaroni pasta    0.444103       37     1.454545       16
# 32         whole wheat spaghetti    0.443062       35     1.636364        8
# 33                    dried sage    0.442246       33     0.363636       92
# 34               button mushroom    0.438722       31     1.181818       36
# 35           mixed italian herbs    0.437975       29     1.272727       28
# 36               lasagna noodles    0.435232       27     1.181818       36
# 37           dried summer savory    0.434360       25     1.090909       44
# 38     italian style breadcrumbs    0.432203       23     1.909091        2
# 39          dried oregano leaves    0.431096       21     1.090909       44
# 40         sweet italian sausage    0.429054       19     1.545455       12
# 41                dried tarragon    0.428510       17     0.636364       76
# 42               fresh mushrooms    0.428468       15     1.090909       44
# 43              sliced mushrooms    0.427994       13     1.000000       58
# 44             hot pepper flakes    0.426394       11     1.272727       28
# 45          mild italian sausage    0.426245        9     1.363636       24
# 46                  cooked pasta    0.426143        7     0.636364       76
# 47              cooked spaghetti    0.424579        5     1.090909       44
# 48                   rubbed sage    0.422315        3     0.727273       74
# 49             spaghetti noodles    0.420759        1     1.272727       28

# %% [markdown]
# Note how some of the most similar items, based on vector embedding, are *synonyms* or special forms of our query `dried basil` ingredient: `dried basil leaves`, `dry basil`, `dried sweet basil leaves`, etc. These tend to rank high in terms of levenshtein distance too.

# %% [markdown]
# Let's plot the similarity measures:

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use("ggplot")

df["similarity"].plot(alpha=0.75, rot=0)
plt.show()

# %% [markdown]
# Notice the inflection points at approximately `0.57` and again at `0.47` in that plot.
# We could use some statistical techniques (e.g., clustering) to segment the similarities into a few groups:
#
#   * highest similarity – potential synonyms for the query
#   * mid-range similarity – potential [hypernyms and hyponyms](https://en.wikipedia.org/wiki/Hyponymy_and_hypernymy) for the query
#   * long-tail similarity – other ingredients that pair well with the query

# %% [markdown]
# In this example, below a threshold of the 75th percentile for vector embedding similarity, the related ingredients are less about being synonyms and more about other foods that pair well with basil.
#
# Let's define another function `rank_related()` which ranks the related ingredients based on a combination of these two metrics.
# This uses a cheap approximation of a [*pareto archive*](https://www.cs.bham.ac.uk/~jdk/multi/) for the ranking -- which comes in handing for recommender systems and custom search applications that must combine multiple ranking metrics:

# %%
import math

def rms (values):
    """calculate root mean square"""
    numer = sum([x for x in map(lambda x: float(x)**2.0, values)])
    denom = float(len(values))
    return math.sqrt(numer / denom)

def rank_related (df):
    df2 = df.copy(deep=True)
    df2["related"] = df2.apply(lambda row: rms([row[2], row[4]]), axis=1)
    return df2.sort_values(by=["related"], ascending=False)

# %%
rank_related(df)
# Out:
#                       ingredient  similarity  sim_pct  levenshtein  lev_pct  \
# 1                      dry basil    0.619557       97     0.272727       98
# 2                    fresh basil    0.615189       95     0.363636       92
# 0             dried basil leaves    0.666573       99     0.636364       76
# 7                  dried parsley    0.565170       85     0.454545       88
# 4                 dried rosemary    0.607231       91     0.636364       76
# 11                         basil    0.533492       77     0.545455       86
# 8                 dried marjoram    0.561841       83     0.636364       76
# 21                   sweet basil    0.466180       57     0.363636       92
# 12                 parmesan rind    0.518059       75     0.909091       68
# 25                   dried thyme    0.450766       49     0.454545       88
# 33                    dried sage    0.442246       33     0.363636       92
# 3        dried italian seasoning    0.611792       93     1.272727       28
# 5       dried sweet basil leaves    0.577864       89     1.181818       36
# 9              italian seasoning    0.559847       81     1.090909       44
# 14             dried whole thyme    0.504048       71     1.000000       58
# 22              fresh basil leaf    0.462858       55     0.818182       72
# 15          dried parsley flakes    0.494847       69     1.000000       58
# 6         italian herb seasoning    0.570702       87     1.454545       16
# 10         dried rosemary leaves    0.557721       79     1.181818       36
# 19            dried thyme leaves    0.470149       61     1.000000       58
# 28                  chianti wine    0.445253       43     0.909091       68
# 23            fresh basil leaves    0.462330       53     1.000000       58
# 17                italian spices    0.477972       65     1.090909       44
# 41                dried tarragon    0.428510       17     0.636364       76
# 13            hunts tomato paste    0.509193       73     1.363636       24
# 46                  cooked pasta    0.426143        7     0.636364       76
# 48                   rubbed sage    0.422315        3     0.727273       74
# 16        feta cheese with herbs    0.478575       67     1.818182        4
# 18  dried italian herb seasoning    0.471290       63     1.636364        8
# 27              italian sausages    0.446250       45     1.090909       44
# 20       dried red pepper flakes    0.468225       59     1.454545       16
# 43              sliced mushrooms    0.427994       13     1.000000       58
# 24        italian turkey sausage    0.459434       51     1.545455       12
# 37           dried summer savory    0.434360       25     1.090909       44
# 26         italian seasoning mix    0.449365       47     1.454545       16
# 39          dried oregano leaves    0.431096       21     1.090909       44
# 34               button mushroom    0.438722       31     1.181818       36
# 42               fresh mushrooms    0.428468       15     1.090909       44
# 36               lasagna noodles    0.435232       27     1.181818       36
# 47              cooked spaghetti    0.424579        5     1.090909       44
# 29        t-bone type lamb chops    0.445107       41     1.727273        6
# 35           mixed italian herbs    0.437975       29     1.272727       28
# 31          small macaroni pasta    0.444103       37     1.454545       16
# 30   part-skim mozzarella cheese    0.444935       39     2.090909        0
# 32         whole wheat spaghetti    0.443062       35     1.636364        8
# 44             hot pepper flakes    0.426394       11     1.272727       28
# 49             spaghetti noodles    0.420759        1     1.272727       28
# 45          mild italian sausage    0.426245        9     1.363636       24
# 38     italian style breadcrumbs    0.432203       23     1.909091        2
# 40         sweet italian sausage    0.429054       19     1.545455       12
#
#       related
# 1   97.501282
# 2   93.512031
# 0   88.252479
# 7   86.513005
# 4   83.836150
# 11  81.624139
# 8   79.577007
# 21  76.527773
# 12  71.585613
# 25  71.221486
# 33  69.112228
# 3   68.676779
# 5   67.885934
# 9   65.180519
# 14  64.826692
# 22  64.066372
# 15  63.737744
# 6   62.549980
# 10  61.388110
# 19  59.518905
# 28  56.890245
# 23  55.556278
# 17  55.502252
# 41  55.068140
# 13  54.336912
# 46  53.967583
# 48  52.368884
# 16  47.460510
# 18  44.905456
# 27  44.502809
# 20  43.226149
# 43  42.029751
# 24  37.047267
# 37  35.784075
# 26  35.106979
# 39  34.474628
# 34  33.593154
# 42  32.870960
# 36  31.819805
# 47  31.312937
# 29  29.300171
# 35  28.504386
# 31  28.504386
# 30  27.577164
# 32  25.387005
# 44  21.272047
# 49  19.811613
# 45  18.124569
# 38  16.324828
# 40  15.890249

# %% [markdown]
# Notice how the "synonym" cases tend to move up to the top now?
# Meanwhile while the "pairs well with" are in the lower half of the ranked list: `fresh mushrooms`, `italian turkey sausage`, `cooked spaghetti`, `white kidney beans`, etc.

# %% [markdown]
# ---
#
# ## Exercises

# %% [markdown]
# **Exercise 1:**
#
# Build a report for a *human-in-the-loop* reviewer, using the `rank_related()` function while iterating over `vocab` to make algorithmic suggestions for possible synonyms.

# %% [markdown]
# **Exercise 2:**
#
# How would you make algorithmic suggestions for a reviewer about which ingredients could be related to a query, e.g., using the `skos:broader` and `skos:narrower` relations in the [`skos`](https://www.w3.org/2004/02/skos/) vocabulary to represent *hypernyms* and *hyponyms* respectively?
# This could extend the KG to provide a kind of thesaurus about recipe ingredients.
