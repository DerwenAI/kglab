# %% [markdown]
# # Data Prep
#
# First, download the [Kaggle dataset](https://www.kaggle.com/shuyangli94/food-com-recipes-and-user-interactions/metadata) and inflate/rename it as the `food_com` directory.
# Then load as a `pandas` dataframe:

# %%
import pandas as pd

df_raw = pd.read_csv("food_com/RAW_recipes.csv")
df_raw.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8

# %% [markdown]
# We'll keep a subset of the available columns. Let's avoid republishing the entire dataset.

# %%
df = df_raw[["id", "name", "minutes", "tags", "description", "ingredients"]]
df.head()
# Out:
#        id                                        name  minutes  \
# 0  137739  arriba   baked winter squash mexican style       55
# 1   31490            a bit different  breakfast pizza       30
# 2  112140                   all in the kitchen  chili      130
# 3   59389                          alouette  potatoes       45
# 4   44061          amish  tomato ketchup  for canning      190
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...

# %% [markdown]
# Next, let's constrain the recipes to those which have common ingredients:

# %%
common_ingredient = {
    "water": "Water",
    "salt": "Salt",
    "pepper": "BlackPepper",
    "black pepper": "BlackPepper",
    
    "baking powder": "BakingPowder",
    "baking soda": "BakingSoda",

    "vanilla": "VanillaExtract",
    "vanilla extract": "VanillaExtract",

    "butter": "Butter",
    "milk": "CowMilk",
    "egg": "ChickenEgg",
    "eggs": "ChickenEgg",

    "sugar": "WhiteSugar",
    "brown sugar": "BrownSugar",
    "honey": "Honey",

    "flour": "AllPurposeFlour",
    "all-purpose flour": "AllPurposeFlour",
    "whole wheat flour": "WholeWheatFlour",

    "olive oil": "OliveOil",
    "vinegar": "AppleCiderVinegar",

    "onion": "Onion",
    "onions": "Onion",
    "garlic": "Garlic",
    "garlic clove": "Garlic",
    "garlic cloves": "Garlic",
    "cabbage": "Cabbage",
    "carrot": "Carrot",
    "carrots": "Carrot",
    "celery": "Celery",
    "potato": "Potato",
    "potatoes": "Potato",
    "tomato": "Tomato",
    "tomatoes": "Tomato",
}

# %%
from collections import defaultdict

counts = defaultdict(int)
simple_recipes = set([])

for index, row in df.iterrows():
    ind_list = eval(row["ingredients"])
    all_known = True

    for ind in ind_list:
        ingredient = ind.strip()
        counts[ingredient] += 1
        
        if ingredient not in common_ingredient:
            all_known = False

    if all_known:
        simple_recipes.add(row["id"])
        print(row["name"], len(ind_list))

print("---")

for k, v in sorted(counts.items(), key=lambda kv: kv[1], reverse=True)[:100]:
    if k not in common_ingredient:
        print(v, k)
    
print(len(simple_recipes))
# Out:
# make it your way  shortcakes 7
# better  cake mix 3
# 1 bowl 1 person mashed potatoes 5
# 1 1 1 tempura batter 3
# 2 step pound cake  for a kitchen aide mixer 6
# 30 minute baked potato 2
# 40 second omelet 3
# a 1 dumplings 4
# ableskiver   danish doughnuts 6
# afghan eggs and tomato  tukhum bonjan or agay bonjan 4
# all purpose dinner crepes batter 5
# all purpose quick mix with 28 variations 5
# american style vanilla biscotti 7
# amish butterscotch brownies 7
# amish dumplings 4
# amish friendship starter 3
# ann s shortbread 4
# anna s brilliant biscuits 5
# another perfect poached egg 4
# anya s dutch pancakes 5
# anytime crepes 3
# apple and banana sauce 6
# astoria frosting 6
# av s  biscoitos  portuguese biscotti cookies 5
# baby dutchman 5
# baked eggs in tomatoes 5
# baked finnish pancakes 6
# baked potato onion wrap ups 2
# baked potatoes 2
# bakes   baking powder biscuits from barbados 8
# baking powder dumplings 5
# bannock 5
# basic biscotti recipe 7
# basic biscuits 5
# basic biscuits my style 5
# basic crepes 5
# basic crepes ii 5
# basic crepes mix in blender 5
# basic dessert crepes batter 6
# basic muffins 7
# basic muffins  with variation options 7
# basic omelet 4
# basic pastry crust 4
# basic pound cake 7
# basic recipe for phyllo dough 4
# basic rotis or chappatis 2
# basic roux 2
# basic shortbread cookies 5
# basic vanilla muffins for dinner  not sweet 8
# basic white sauce 3
# basic white sauce bechamel sauce 5
# basted eggs 5
# batter  for deep frying 5
# batter for fish or chicken 5
# batter fried anything 6
# beat and bake madeira cake 7
# beaten biscuits 5
# beaumont inn cookies 6
# bee or wasp sting soother 2
# belgian waffle cookies 6
# bermuda johnny bread  caribbean 7
# best glazed carrots 3
# best pancakes ever 7
# best ever homemade pancakes 7
# simple shortbread 3
# simple sugar syrup 2
# simple syrup 2
# simple syrups 2
# simple vanilla ice milk 3
# simple  fast and super fluffy pancakes 8
# single crepe 6
# skordalia  garlic sauce 5
# slovak egg dumplings 4
# slow roasted garlic 3
# small batch popovers 4
# smul paj  crumb pie 3
# snack crackers 7
# soft custard 5
# southern biscuit muffins 5
# southern biscuits mufffins 5
# spaetzel 4
# spaetzel dumplings 4
# spaetzels 7
# spaetzle   basic recipe   art culinaire issue 5
# spaetzle   german 5
# spaetzle   hungarian 4
# spaetzle dumplings 6
# spanish omelet 4
# spanish potato tortilla 4
# spanish tortilla  potato omelette 5
# spatzle 5
# spatzle  little german noodle dumplings 7
# spreadable roasted garlic 2
# spritz cookies with four variations 6
# st  patrick s shamrock cookies 5
# stamp  mold butter cookies 5
# steamed carrots in the buff 2
# steamed eggs  kai meung 2
# steamed mamon  filipino sponge cake 8
# storing garlic in oil 2
# stoved tatties 4
# stupid simple sugar cookies 6
# sugar   browned potatoes 4
# sugar bread 7
# sugar cookie perfection 7
# sugar cookies 7
# sugar cookies  cut out 6
# sugar cookies for ceramic cookie molds 7
# sugar topped butter cookies 6
# sunday supper waffles 7
# sunset scallop   potatoes and carrots 8
# super easy 4 ingredient lace cookies 4
# super puffy german pancake 5
# super easy shortbread  3 ingredients 3
# susan s honey bee butter 2
# suzi s pop over puffs 6
# swabian noodles  spatzle 4
# swedish country style scrambled eggs 6
# swedish pancakes 4
# swedish pancakes  plattar 6
# swedish scones 6
# sweet coffee house scones 8
# sweet glazed carrots 3
# swiss spaetzle  very easy homemade noodle 5
# takakau  maori bread 3
# tattie scones  potato scones or potato cakes 4
# tea biscuits 5
# teething biscuits 4
# tennessee honey glazed carrots 5
# the best ever waffles 7
# the best scrambled eggs 3
# the easiest  shortcrust pastry 3
# the easiest latkes 4
# the easiest perfect hard boiled eggs  technique 2
# the fluffiest pancakes you will ever have 7
# the humble fried egg 3
# the simple but perfect pancake 8
# thin pancakes 6
# thin pancakes  palacsinta 6
# tjock pan kaka  swedish thick pancake 5
# tomato and onion salad 5
# tomato dumplings 7
# tomato paste 2
# traditional chapatis 2
# turkish cabbage salad  lahana salata 6
# tushennaya markov  braised carrots 5
# twin mountain muffins 7
# ukrainian lokshyna  egg noodles 4
# ultimate cloud biscuits 6
# uncle don s swedish pancakes 5
# unemployment cake  poudding chomeur 9
# unknownchef86 s dehydrated sliced potatoes  dried 2
# unleavened bread 5
# unleavened communion bread 6
# vanilla coke syrup  non alcoholic 4
# vanilla milk 3
# vanilla wafer cookies 7
# vegan egg replacer   substitute 4
# velvet cakes 7
# very easy hash brown 3
# very vanilla cupcakes 8
# victorian hot milk sponge cake 7
# wallis  crepes 4
# welsh onion cake 5
# wheat thins 6
# whipped cream like frosting 5
# whipped honey butter with varieties 2
# white cake 8
# white cupcakes 7
# white sauce  cheesy or not  medium sauce 4
# white sauce base 4
# white trash cookbook dumplings 4
# whole wheat pasta noodles 4
# whole wheat popovers 6
# wicklewood s all too easy all in one white sauce 3
# wonton wrappers 5
# wonton wrappers made at home 4
# world s lightest pancakes 7
# yellow cake 8
# yellow cake for strawberries and whipped cream 7
# yorkhire pudding aka popovers 4
# ziplock vanilla ice cream 3
# zwiebeln salat  swiss onion salad 5
# ---
# 15415 salt and pepper
# 14807 parmesan cheese
# 14233 lemon juice
# 13912 vegetable oil
# 12560 cinnamon
# 11779 sour cream
# 10887 garlic powder
# 9925 oil
# 9827 cream cheese
# 8969 cheddar cheese
# 8935 unsalted butter
# 8856 soy sauce
# 8736 mayonnaise
# 7982 paprika
# 7963 chicken broth
# 7832 worcestershire sauce
# 7704 extra virgin olive oil
# 7656 fresh parsley
# 7486 cornstarch
# 7160 fresh ground black pepper
# 7001 parsley
# 6984 chili powder
# 6948 bacon
# 6864 ground cinnamon
# 6299 nutmeg
# 6285 cayenne pepper
# 6254 granulated sugar
# 6169 ground cumin
# 5824 ground beef
# 5814 green onions
# 5777 red onion
# 5765 walnuts
# 5752 pecans
# 5599 dijon mustard
# 5585 green onion
# 5583 kosher salt
# 5377 powdered sugar
# 5311 fresh lemon juice
# 5201 heavy cream
# 5077 margarine
# 4980 mozzarella cheese
# 4882 dried oregano
# 4702 orange juice
# 4591 zucchini
# 4487 raisins
# 4450 red bell pepper
# 4402 tomato sauce
# 4360 fresh cilantro
# 4352 chicken stock
# 4335 tomato paste
# 4315 canola oil
# 4301 green pepper
# 4255 fresh ginger
# 4233 cumin
# 4185 oregano
# 3994 boneless skinless chicken breasts
# 3936 ground black pepper
# 3901 ketchup
# 3848 balsamic vinegar
# 3825 buttermilk
# 3749 lime juice
# 3742 cilantro
# 3655 ground ginger
# 3636 fresh basil
# 3600 ginger
# 3598 onion powder
# 3533 dried thyme
# 3462 diced tomatoes
# 3287 green bell pepper
# 3258 egg whites
# 3253 dried basil
# 613

# %% [markdown]
# That gives us several hundred recipes as a working set to build the KG examples. Let's create a subset of the dataframe and save it to the `recipes.csv` file:

# %%
df_simple = df[df["id"].isin(simple_recipes)]
df_simple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 613 entries, 56 to 231625
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           613 non-null    int64
#  1   name         613 non-null    object
#  2   minutes      613 non-null    int64
#  3   tags         613 non-null    object
#  4   description  598 non-null    object
#  5   ingredients  613 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 33.5+ KB

# %%
df_simple.to_csv("recipes.csv", index=False)

# %% [markdown]
# We'll also keep a list of **all** ingredients, to use for the embedding example"

# %%
df_ind = df_raw[["id", "ingredients"]]
df_ind.head()
# Out:
#        id                                        ingredients
# 0  137739  ['winter squash', 'mexican seasoning', 'mixed ...
# 1   31490  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  112140  ['ground beef', 'yellow onions', 'diced tomato...
# 3   59389  ['spreadable cheese with garlic and herbs', 'n...
# 4   44061  ['tomato juice', 'apple cider vinegar', 'sugar...

# %%
df_ind.to_csv("all_ind.csv", index=False)
